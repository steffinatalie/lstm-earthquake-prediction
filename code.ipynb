# %%
import numpy as np
import matplotlib.pyplot as plt
import math
from collections import Counter
import pandas as pd

# %%
bali = pd.read_csv('bali_min4.csv')
jabar = pd.read_csv('jawabarat_min4.csv')
# df = pd.concat([bali, jabar], axis=0)
jatengjatim = pd.read_csv('jatengjatim_min4.csv')
# df = pd.concat([bali, jatengjatim], axis=0)
# df = pd.concat([jabar, jatengjatim], axis=0)
df = pd.concat([bali, jabar, jatengjatim], axis=0)
# df = pd.read_csv('southern_california_min25.csv')
df['timestamp'] = pd.to_datetime(df['time'], errors='coerce', utc=False)
df['Datetime'] = df['timestamp']
df.set_index('timestamp', inplace=True)
df = df.sort_index(ascending=True)
df
# Out:
#                                                       time  latitude  \
# timestamp
# 1995-01-01 02:02:25.490000+00:00  1995-01-01T02:02:25.490Z  -10.9270
# 1995-01-07 15:02:59.810000+00:00  1995-01-07T15:02:59.810Z   -9.0250
# 1995-01-07 18:37:28.920000+00:00  1995-01-07T18:37:28.920Z   -9.2310
# 1995-01-19 09:19:57.180000+00:00  1995-01-19T09:19:57.180Z  -10.7640
# 1995-02-16 16:27:25.400000+00:00  1995-02-16T16:27:25.400Z  -10.0560
# ...                                                    ...       ...
# 2020-12-20 15:16:45.796000+00:00  2020-12-20T15:16:45.796Z   -9.2506
# 2020-12-20 15:53:57.395000+00:00  2020-12-20T15:53:57.395Z   -9.2936
# 2020-12-22 03:27:21.031000+00:00  2020-12-22T03:27:21.031Z   -9.5505
# 2020-12-24 22:09:10.232000+00:00  2020-12-24T22:09:10.232Z   -9.0282
# 2020-12-26 18:23:21.550000+00:00  2020-12-26T18:23:21.550Z   -9.0928
#
#                                   longitude   depth  mag magType  nst    gap  \
# timestamp
# 1995-01-01 02:02:25.490000+00:00   113.0110   18.90  4.5      mb  NaN    NaN
# 1995-01-07 15:02:59.810000+00:00   110.7550  114.80  4.7      mb  NaN    NaN
# 1995-01-07 18:37:28.920000+00:00   117.1110   33.00  4.2      mb  NaN    NaN
# 1995-01-19 09:19:57.180000+00:00   117.1200   33.00  4.9      mb  NaN    NaN
# 1995-02-16 16:27:25.400000+00:00   113.8580   33.00  4.0      mb  NaN    NaN
# ...                                     ...     ...  ...     ...  ...    ...
# 2020-12-20 15:16:45.796000+00:00   110.8510   35.00  4.2      mb  NaN  148.0
# 2020-12-20 15:53:57.395000+00:00   112.1503   35.00  4.3      mb  NaN   53.0
# 2020-12-22 03:27:21.031000+00:00   112.5698   35.00  4.1      mb  NaN  120.0
# 2020-12-24 22:09:10.232000+00:00   117.3729  104.10  4.4      mb  NaN   95.0
# 2020-12-26 18:23:21.550000+00:00   117.1835   63.84  4.1      mb  NaN   71.0
#
#                                    dmin   rms  ...  \
# timestamp                                      ...
# 1995-01-01 02:02:25.490000+00:00    NaN  1.20  ...
# 1995-01-07 15:02:59.810000+00:00    NaN  0.80  ...
# 1995-01-07 18:37:28.920000+00:00    NaN  0.90  ...
# 1995-01-19 09:19:57.180000+00:00    NaN  1.30  ...
# 1995-02-16 16:27:25.400000+00:00    NaN  0.40  ...
# ...                                 ...   ...  ...
# 2020-12-20 15:16:45.796000+00:00  1.368  0.58  ...
# 2020-12-20 15:53:57.395000+00:00  2.114  0.90  ...
# 2020-12-22 03:27:21.031000+00:00  1.896  0.94  ...
# 2020-12-24 22:09:10.232000+00:00  3.231  0.54  ...
# 2020-12-26 18:23:21.550000+00:00  3.059  0.62  ...
#
#                                                                   place  \
# timestamp
# 1995-01-01 02:02:25.490000+00:00         294 km S of Kencong, Indonesia
# 1995-01-07 15:02:59.810000+00:00       126 km SSE of Pundong, Indonesia
# 1995-01-07 18:37:28.920000+00:00  88 km SSW of Sumbawa Besar, Indonesia
# 1995-01-19 09:19:57.180000+00:00         246 km SSE of Praya, Indonesia
# 1995-02-16 16:27:25.400000+00:00   186 km S of Gambiran Satu, Indonesia
# ...                                                                 ...
# 2020-12-20 15:16:45.796000+00:00       153 km SSE of Pundong, Indonesia
# 2020-12-20 15:53:57.395000+00:00  130 km SSW of Sumberpucung, Indonesia
# 2020-12-22 03:27:21.031000+00:00          149 km S of Dampit, Indonesia
# 2020-12-24 22:09:10.232000+00:00    59 km S of Sumbawa Besar, Indonesia
# 2020-12-26 18:23:21.550000+00:00  71 km SSW of Sumbawa Besar, Indonesia
#
#                                         type horizontalError depthError  \
# timestamp
# 1995-01-01 02:02:25.490000+00:00  earthquake             NaN        8.5
# 1995-01-07 15:02:59.810000+00:00  earthquake             NaN       21.5
# 1995-01-07 18:37:28.920000+00:00  earthquake             NaN        NaN
# 1995-01-19 09:19:57.180000+00:00  earthquake             NaN        NaN
# 1995-02-16 16:27:25.400000+00:00  earthquake             NaN        NaN
# ...                                      ...             ...        ...
# 2020-12-20 15:16:45.796000+00:00  earthquake             8.9        1.9
# 2020-12-20 15:53:57.395000+00:00  earthquake             5.3        2.0
# 2020-12-22 03:27:21.031000+00:00  earthquake             5.6        1.9
# 2020-12-24 22:09:10.232000+00:00  earthquake             7.6        8.3
# 2020-12-26 18:23:21.550000+00:00  earthquake             7.1        8.5
#
#                                  magError  magNst    status  locationSource  \
# timestamp
# 1995-01-01 02:02:25.490000+00:00      NaN     4.0  reviewed              us
# 1995-01-07 15:02:59.810000+00:00      NaN    12.0  reviewed              us
# 1995-01-07 18:37:28.920000+00:00      NaN     5.0  reviewed              us
# 1995-01-19 09:19:57.180000+00:00      NaN     8.0  reviewed              us
# 1995-02-16 16:27:25.400000+00:00      NaN     5.0  reviewed              us
# ...                                   ...     ...       ...             ...
# 2020-12-20 15:16:45.796000+00:00    0.186     8.0  reviewed              us
# 2020-12-20 15:53:57.395000+00:00    0.142    14.0  reviewed              us
# 2020-12-22 03:27:21.031000+00:00    0.175     9.0  reviewed              us
# 2020-12-24 22:09:10.232000+00:00    0.134    16.0  reviewed              us
# 2020-12-26 18:23:21.550000+00:00    0.165    13.0  reviewed              us
#
#                                   magSource                         Datetime
# timestamp
# 1995-01-01 02:02:25.490000+00:00         us 1995-01-01 02:02:25.490000+00:00
# 1995-01-07 15:02:59.810000+00:00         us 1995-01-07 15:02:59.810000+00:00
# 1995-01-07 18:37:28.920000+00:00         us 1995-01-07 18:37:28.920000+00:00
# 1995-01-19 09:19:57.180000+00:00         us 1995-01-19 09:19:57.180000+00:00
# 1995-02-16 16:27:25.400000+00:00         us 1995-02-16 16:27:25.400000+00:00
# ...                                     ...                              ...
# 2020-12-20 15:16:45.796000+00:00         us 2020-12-20 15:16:45.796000+00:00
# 2020-12-20 15:53:57.395000+00:00         us 2020-12-20 15:53:57.395000+00:00
# 2020-12-22 03:27:21.031000+00:00         us 2020-12-22 03:27:21.031000+00:00
# 2020-12-24 22:09:10.232000+00:00         us 2020-12-24 22:09:10.232000+00:00
# 2020-12-26 18:23:21.550000+00:00         us 2020-12-26 18:23:21.550000+00:00
#
# [1698 rows x 23 columns]

# %%
df = df[['depth', 'mag']]
df
# Out:
#                                    depth  mag
# timestamp
# 1995-01-01 02:02:25.490000+00:00   18.90  4.5
# 1995-01-07 15:02:59.810000+00:00  114.80  4.7
# 1995-01-07 18:37:28.920000+00:00   33.00  4.2
# 1995-01-19 09:19:57.180000+00:00   33.00  4.9
# 1995-02-16 16:27:25.400000+00:00   33.00  4.0
# ...                                  ...  ...
# 2020-12-20 15:16:45.796000+00:00   35.00  4.2
# 2020-12-20 15:53:57.395000+00:00   35.00  4.3
# 2020-12-22 03:27:21.031000+00:00   35.00  4.1
# 2020-12-24 22:09:10.232000+00:00  104.10  4.4
# 2020-12-26 18:23:21.550000+00:00   63.84  4.1
#
# [1698 rows x 2 columns]

# %%
print(df.isna().sum())
# Out:
# depth    0
# mag      0
# dtype: int64

# %%
mag_unique, frequency = np.unique(df['mag'], return_counts=True)

plt.figure(figsize=(10,8))
plt.hist(df['mag'], bins=1000, color='black', edgecolor='black')

bins = [0, 20, 40, 60]

from matplotlib.ticker import MultipleLocator
# Set x-axis scale to increment by 0.5
plt.gca().xaxis.set_major_locator(MultipleLocator(0.2))
# Add titles and labels
plt.title('Frequency by Magnitude')
plt.xlabel('Magnitude')
plt.ylabel('Frequency')
plt.xticks(fontsize=12, fontname='Times New Roman', rotation=45)

# Show the plot
plt.show()

# %%
mag_filter = 4.5
depth_filter = 100
resample_rate = '1M'

# %%
# def occurence_criterion(raw_array):
#     print(raw_array)
#     print("---------------------")
#     target = -1
#     if len(raw_array) > 0:
#         if raw_array['earthquake'].eq(1).any():
#             target = 1
#         if raw_array['earthquake'].eq(0).any():
#             target = 0
#     if len(raw_array) == 0:
#         target = 0

        
#     return target

# earthquake_occurence = df.resample(resample_rate).apply(occurence_criterion)

# earthquake_occurence = earthquake_occurence.to_frame(name='earthquake')

# earthquake_occurence = earthquake_occurence.sort_index(ascending=True)
# earthquake_occurence['earthquake'].value_counts()

# %%
# Initialize the 'ED' column with NaN values
df['ED'] = np.nan

# Filter the dataframe for earthquakes with magnitude greater than mag_filter
filtered_df = df[df['mag'] > mag_filter]

n = 50

# Calculate the elapsed days for the last n earthquake events
for i in range(n, len(filtered_df)):
    current_time = filtered_df.index[i]
    past_time = filtered_df.index[i-n]
    elapsed_days = (current_time - past_time).days
    df.loc[current_time, 'ED'] = elapsed_days

# Fill NaN values in 'ED' column
for i in range(len(df)):
    if pd.isna(df.iloc[i]['ED']):
        # Find the latest valid 'ED' value before the current index
        last_valid_index = df.iloc[:i]['ED'].last_valid_index()
        if last_valid_index is not None:
            time_since_last_valid = (df.index[i] - last_valid_index).days
            df.at[df.index[i], 'ED'] = df.at[last_valid_index, 'ED'] + time_since_last_valid

# df = df.dropna(subset=['ED'])
df
# Out:
# C:\Users\SteinSteffi1\AppData\Local\Temp\ipykernel_18492\388928700.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['ED'] = np.nan
#                                    depth  mag     ED
# timestamp
# 1995-01-01 02:02:25.490000+00:00   18.90  4.5    NaN
# 1995-01-07 15:02:59.810000+00:00  114.80  4.7    NaN
# 1995-01-07 18:37:28.920000+00:00   33.00  4.2    NaN
# 1995-01-19 09:19:57.180000+00:00   33.00  4.9    NaN
# 1995-02-16 16:27:25.400000+00:00   33.00  4.0    NaN
# ...                                  ...  ...    ...
# 2020-12-20 15:16:45.796000+00:00   35.00  4.2  875.0
# 2020-12-20 15:53:57.395000+00:00   35.00  4.3  875.0
# 2020-12-22 03:27:21.031000+00:00   35.00  4.1  876.0
# 2020-12-24 22:09:10.232000+00:00  104.10  4.4  878.0
# 2020-12-26 18:23:21.550000+00:00   63.84  4.1  879.0
#
# [1698 rows x 3 columns]

# %%
# Initialize the 'energy_squared' and 'cumulative_energy_squared' columns with NaN values
df['energy_squared_root'] = np.nan
df['cumulative_energy_squared'] = np.nan

df['energy'] = 10**(11.8+1.5*df['mag'])

# Calculate the energy squared for each data point
df['energy_squared_root'] = np.sqrt(df['energy'])

# Calculate the cumulative sum of energy squared for the last 50 data points
# for i in range(n, len(df)):
#     df.iloc[i, df.columns.get_loc('cumulative_energy_squared')] = df.iloc[i-n:i]['energy_squared_root'].sum()

df['cumulative_energy_squared'] = df['energy_squared_root'].rolling(n).sum()

# Calculate the RSRER
df['RSRER'] = df['cumulative_energy_squared'] / df['ED']

df['mean_mag'] = df['mag'].rolling(n).mean()
df['min_mag'] = df['mag'].rolling(n).min()
df['b_value'] = np.log10(np.e)/(df['mean_mag'] - df['min_mag'])

df['event_counts'] = df['mag'].rolling(n).apply(lambda x: (x > mag_filter).sum(), raw=True)
df['a_value'] = (np.log10(df['event_counts']) + df['b_value']*df['min_mag'])/n
# df['MSD'] = np.sum((np.log10(df['event_counts'])-(df['a_value']-(df['b_value']*df['mag'])))**2)/(n-1)
df['max_mag'] = df['mag'].rolling(n).max()
df['MD'] = df['a_value']/df['b_value'] - df['max_mag']
# print(df['event_counts'])

df
# Out:
# C:\Users\SteinSteffi1\AppData\Local\Temp\ipykernel_18492\2738765218.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['energy_squared_root'] = np.nan
# C:\Users\SteinSteffi1\AppData\Local\Temp\ipykernel_18492\2738765218.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['cumulative_energy_squared'] = np.nan
# C:\Users\SteinSteffi1\AppData\Local\Temp\ipykernel_18492\2738765218.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['energy'] = 10**(11.8+1.5*df['mag'])
# C:\Users\SteinSteffi1\AppData\Local\Temp\ipykernel_18492\2738765218.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['energy_squared_root'] = np.sqrt(df['energy'])
# C:\Users\SteinSteffi1\AppData\Local\Temp\ipykernel_18492\2738765218.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['cumulative_energy_squared'] = df['energy_squared_root'].rolling(n).sum()
# C:\Users\SteinSteffi1\AppData\Local\Temp\ipykernel_18492\2738765218.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['RSRER'] = df['cumulative_energy_squared'] / df['ED']
# C:\Users\SteinSteffi1\AppData\Local\Temp\ipykernel_18492\2738765218.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['mean_mag'] = df['mag'].rolling(n).mean()
# C:\Users\SteinSteffi1\AppData\Local\Temp\ipykernel_18492\2738765218.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['min_mag'] = df['mag'].rolling(n).min()
# C:\Users\SteinSteffi1\AppData\Local\Temp\ipykernel_18492\2738765218.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['b_value'] = np.log10(np.e)/(df['mean_mag'] - df['min_mag'])
# C:\Users\SteinSteffi1\AppData\Local\Temp\ipykernel_18492\2738765218.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['event_counts'] = df['mag'].rolling(n).apply(lambda x: (x > mag_filter).sum(), raw=True)
# C:\Users\SteinSteffi1\AppData\Local\Temp\ipykernel_18492\2738765218.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['a_value'] = (np.log10(df['event_counts']) + df['b_value']*df['min_mag'])/n
# C:\Users\SteinSteffi1\AppData\Local\Temp\ipykernel_18492\2738765218.py:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['max_mag'] = df['mag'].rolling(n).max()
# C:\Users\SteinSteffi1\AppData\Local\Temp\ipykernel_18492\2738765218.py:27: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['MD'] = df['a_value']/df['b_value'] - df['max_mag']
#                                    depth  mag     ED  energy_squared_root  \
# timestamp
# 1995-01-01 02:02:25.490000+00:00   18.90  4.5    NaN         1.883649e+09
# 1995-01-07 15:02:59.810000+00:00  114.80  4.7    NaN         2.660725e+09
# 1995-01-07 18:37:28.920000+00:00   33.00  4.2    NaN         1.122018e+09
# 1995-01-19 09:19:57.180000+00:00   33.00  4.9    NaN         3.758374e+09
# 1995-02-16 16:27:25.400000+00:00   33.00  4.0    NaN         7.943282e+08
# ...                                  ...  ...    ...                  ...
# 2020-12-20 15:16:45.796000+00:00   35.00  4.2  875.0         1.122018e+09
# 2020-12-20 15:53:57.395000+00:00   35.00  4.3  875.0         1.333521e+09
# 2020-12-22 03:27:21.031000+00:00   35.00  4.1  876.0         9.440609e+08
# 2020-12-24 22:09:10.232000+00:00  104.10  4.4  878.0         1.584893e+09
# 2020-12-26 18:23:21.550000+00:00   63.84  4.1  879.0         9.440609e+08
#
#                                   cumulative_energy_squared        energy  \
# timestamp
# 1995-01-01 02:02:25.490000+00:00                        NaN  3.548134e+18
# 1995-01-07 15:02:59.810000+00:00                        NaN  7.079458e+18
# 1995-01-07 18:37:28.920000+00:00                        NaN  1.258925e+18
# 1995-01-19 09:19:57.180000+00:00                        NaN  1.412538e+19
# 1995-02-16 16:27:25.400000+00:00                        NaN  6.309573e+17
# ...                                                     ...           ...
# 2020-12-20 15:16:45.796000+00:00               9.353097e+10  1.258925e+18
# 2020-12-20 15:53:57.395000+00:00               9.353097e+10  1.778279e+18
# 2020-12-22 03:27:21.031000+00:00               9.259138e+10  8.912509e+17
# 2020-12-24 22:09:10.232000+00:00               9.259138e+10  2.511886e+18
# 2020-12-26 18:23:21.550000+00:00               9.220192e+10  8.912509e+17
#
#                                          RSRER  mean_mag  min_mag   b_value  \
# timestamp
# 1995-01-01 02:02:25.490000+00:00           NaN       NaN      NaN       NaN
# 1995-01-07 15:02:59.810000+00:00           NaN       NaN      NaN       NaN
# 1995-01-07 18:37:28.920000+00:00           NaN       NaN      NaN       NaN
# 1995-01-19 09:19:57.180000+00:00           NaN       NaN      NaN       NaN
# 1995-02-16 16:27:25.400000+00:00           NaN       NaN      NaN       NaN
# ...                                        ...       ...      ...       ...
# 2020-12-20 15:16:45.796000+00:00  1.068925e+08     4.430      4.0  1.009987
# 2020-12-20 15:53:57.395000+00:00  1.068925e+08     4.430      4.0  1.009987
# 2020-12-22 03:27:21.031000+00:00  1.056979e+08     4.422      4.0  1.029134
# 2020-12-24 22:09:10.232000+00:00  1.054572e+08     4.422      4.0  1.029134
# 2020-12-26 18:23:21.550000+00:00  1.048941e+08     4.418      4.0  1.038982
#
#                                   event_counts   a_value  max_mag        MD
# timestamp
# 1995-01-01 02:02:25.490000+00:00           NaN       NaN      NaN       NaN
# 1995-01-07 15:02:59.810000+00:00           NaN       NaN      NaN       NaN
# 1995-01-07 18:37:28.920000+00:00           NaN       NaN      NaN       NaN
# 1995-01-19 09:19:57.180000+00:00           NaN       NaN      NaN       NaN
# 1995-02-16 16:27:25.400000+00:00           NaN       NaN      NaN       NaN
# ...                                        ...       ...      ...       ...
# 2020-12-20 15:16:45.796000+00:00          13.0  0.103078      5.2 -5.097941
# 2020-12-20 15:53:57.395000+00:00          13.0  0.103078      5.2 -5.097941
# 2020-12-22 03:27:21.031000+00:00          13.0  0.104610      5.2 -5.098352
# 2020-12-24 22:09:10.232000+00:00          13.0  0.104610      5.2 -5.098352
# 2020-12-26 18:23:21.550000+00:00          13.0  0.105397      5.2 -5.098557
#
# [1698 rows x 14 columns]

# %%
# Drop the intermediate columns
df.drop(columns=['energy_squared_root', 'cumulative_energy_squared', 'mean_mag', 'min_mag', 'event_counts', 'a_value', 'max_mag'], inplace=True)
# Out:
# C:\Users\SteinSteffi1\AppData\Local\Temp\ipykernel_18492\1093842324.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.drop(columns=['energy_squared_root', 'cumulative_energy_squared', 'mean_mag', 'min_mag', 'event_counts', 'a_value', 'max_mag'], inplace=True)

# %%
df.dropna(subset=['RSRER'], inplace=True)
df.isna().sum()
# Out:
# C:\Users\SteinSteffi1\AppData\Local\Temp\ipykernel_18492\2534608267.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.dropna(subset=['RSRER'], inplace=True)
# depth      0
# mag        0
# ED         0
# energy     0
# RSRER      0
# b_value    0
# MD         0
# dtype: int64

# %%
df['earthquake'] = np.where((df['mag'] > mag_filter) & (df['depth'] < depth_filter), 1, 
                            np.where(df['mag']<=mag_filter, -1, 0) )

df['earthquake'].value_counts()
# Out:
# C:\Users\SteinSteffi1\AppData\Local\Temp\ipykernel_18492\14959589.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['earthquake'] = np.where((df['mag'] > mag_filter) & (df['depth'] < depth_filter), 1,
# earthquake
# -1    845
#  1    673
#  0      3
# Name: count, dtype: int64

# %%
def occurence_criterion(raw_array):
    # print(raw_array)
    # print("---------------------")
    target = -1
    if len(raw_array) > 0:
        if raw_array['earthquake'].eq(1).any():
            target = 1
        if raw_array['earthquake'].eq(0).any():
            target = 0
    if len(raw_array) == 0:
        target = 0

        
    return target


earthquake_occurence = df[['earthquake']].resample(resample_rate).apply(occurence_criterion)
print(earthquake_occurence.value_counts())
monthly_df = df.resample(resample_rate).mean()
monthly_df = monthly_df.fillna(0)
monthly_df['earthquake'] = earthquake_occurence
print(monthly_df)
# Out:
# C:\Users\SteinSteffi1\AppData\Local\Temp\ipykernel_18492\3388938703.py:17: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   earthquake_occurence = df[['earthquake']].resample(resample_rate).apply(occurence_criterion)
#  1    186
# -1     47
#  0     14
# Name: count, dtype: int64
#                                depth       mag           ED        energy  \
# timestamp
# 2000-06-30 00:00:00+00:00  42.400000  4.466667  1976.333333  3.760890e+18
# 2000-07-31 00:00:00+00:00  61.000000  4.300000  1911.666667  2.473703e+18
# 2000-08-31 00:00:00+00:00  69.166667  4.733333  1802.666667  8.052972e+18
# 2000-09-30 00:00:00+00:00  33.000000  4.800000  1720.000000  1.000000e+19
# 2000-10-31 00:00:00+00:00  33.000000  4.400000  1708.666667  5.511537e+18
# ...                              ...       ...          ...           ...
# 2020-08-31 00:00:00+00:00  29.616667  4.683333   769.500000  1.302972e+19
# 2020-09-30 00:00:00+00:00  38.920000  4.500000   783.250000  5.029166e+18
# 2020-10-31 00:00:00+00:00  39.796667  4.400000   813.666667  3.848987e+18
# 2020-11-30 00:00:00+00:00   0.000000  0.000000     0.000000  0.000000e+00
# 2020-12-31 00:00:00+00:00  48.049091  4.281818   870.909091  2.118022e+18
#
#                                   RSRER   b_value        MD  earthquake
# timestamp
# 2000-06-30 00:00:00+00:00  6.731465e+07  0.787837 -5.686084           1
# 2000-07-31 00:00:00+00:00  6.605044e+07  0.806484 -5.686699           1
# 2000-08-31 00:00:00+00:00  6.976356e+07  0.789647 -5.685196           1
# 2000-09-30 00:00:00+00:00  7.443554e+07  0.770026 -5.683691           1
# 2000-10-31 00:00:00+00:00  7.245997e+07  0.802452 -5.685743           1
# ...                                 ...       ...       ...         ...
# 2020-08-31 00:00:00+00:00  1.229447e+08  0.996355 -4.929817           1
# 2020-09-30 00:00:00+00:00  1.258752e+08  0.961991 -5.095252           1
# 2020-10-31 00:00:00+00:00  1.249103e+08  0.928547 -5.093374           1
# 2020-11-30 00:00:00+00:00  0.000000e+00  0.000000  0.000000           0
# 2020-12-31 00:00:00+00:00  1.102451e+08  0.984145 -5.096561           1
#
# [247 rows x 8 columns]
# C:\Users\SteinSteffi1\AppData\Local\Temp\ipykernel_18492\3388938703.py:19: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   monthly_df = df.resample(resample_rate).mean()

# %%
df = monthly_df[['depth', 'mag', 'ED', 'RSRER', 'b_value', 'MD', 'earthquake']]
# df = monthly_df[['mag', 'ED','MD', 'earthquake']]
df
# Out:
#                                depth       mag           ED         RSRER  \
# timestamp
# 2000-06-30 00:00:00+00:00  42.400000  4.466667  1976.333333  6.731465e+07
# 2000-07-31 00:00:00+00:00  61.000000  4.300000  1911.666667  6.605044e+07
# 2000-08-31 00:00:00+00:00  69.166667  4.733333  1802.666667  6.976356e+07
# 2000-09-30 00:00:00+00:00  33.000000  4.800000  1720.000000  7.443554e+07
# 2000-10-31 00:00:00+00:00  33.000000  4.400000  1708.666667  7.245997e+07
# ...                              ...       ...          ...           ...
# 2020-08-31 00:00:00+00:00  29.616667  4.683333   769.500000  1.229447e+08
# 2020-09-30 00:00:00+00:00  38.920000  4.500000   783.250000  1.258752e+08
# 2020-10-31 00:00:00+00:00  39.796667  4.400000   813.666667  1.249103e+08
# 2020-11-30 00:00:00+00:00   0.000000  0.000000     0.000000  0.000000e+00
# 2020-12-31 00:00:00+00:00  48.049091  4.281818   870.909091  1.102451e+08
#
#                             b_value        MD  earthquake
# timestamp
# 2000-06-30 00:00:00+00:00  0.787837 -5.686084           1
# 2000-07-31 00:00:00+00:00  0.806484 -5.686699           1
# 2000-08-31 00:00:00+00:00  0.789647 -5.685196           1
# 2000-09-30 00:00:00+00:00  0.770026 -5.683691           1
# 2000-10-31 00:00:00+00:00  0.802452 -5.685743           1
# ...                             ...       ...         ...
# 2020-08-31 00:00:00+00:00  0.996355 -4.929817           1
# 2020-09-30 00:00:00+00:00  0.961991 -5.095252           1
# 2020-10-31 00:00:00+00:00  0.928547 -5.093374           1
# 2020-11-30 00:00:00+00:00  0.000000  0.000000           0
# 2020-12-31 00:00:00+00:00  0.984145 -5.096561           1
#
# [247 rows x 7 columns]

# %%
correlation_matrix = df.corr()
correlation_matrix
# Out:
#                depth       mag        ED     RSRER   b_value        MD  \
# depth       1.000000  0.450107  0.356803 -0.176684  0.507566 -0.475532
# mag         0.450107  1.000000  0.453395  0.097815  0.675032 -0.936609
# ED          0.356803  0.453395  1.000000 -0.285788  0.225485 -0.469613
# RSRER      -0.176684  0.097815 -0.285788  1.000000 -0.043020 -0.082054
# b_value     0.507566  0.675032  0.225485 -0.043020  1.000000 -0.571020
# MD         -0.475532 -0.936609 -0.469613 -0.082054 -0.571020  1.000000
# earthquake -0.142769  0.266427  0.010623  0.090382  0.042685 -0.166463
#
#             earthquake
# depth        -0.142769
# mag           0.266427
# ED            0.010623
# RSRER         0.090382
# b_value       0.042685
# MD           -0.166463
# earthquake    1.000000

# %%
# Replace infinite values with a large number
df.replace([np.inf, -np.inf], 1e10, inplace=True)
# Out:
# C:\Users\SteinSteffi1\AppData\Local\Temp\ipykernel_18492\2297783001.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.replace([np.inf, -np.inf], 1e10, inplace=True)

# %%
from sklearn.preprocessing import MinMaxScaler

# Initialize the MinMaxScaler with the desired feature range
scaler = MinMaxScaler(feature_range=(-1, 1))

# Apply the scaler to the dataframe
df[df.columns] = scaler.fit_transform(df)

# Display the scaled dataframe
df
# Out:
# C:\Users\SteinSteffi1\AppData\Local\Temp\ipykernel_18492\3980167207.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[df.columns] = scaler.fit_transform(df)
#                               depth       mag        ED     RSRER   b_value  \
# timestamp
# 2000-06-30 00:00:00+00:00 -0.096334  0.654321  1.000000 -0.986537  0.060149
# 2000-07-31 00:00:00+00:00  0.300085  0.592593  0.934559 -0.986790  0.085240
# 2000-08-31 00:00:00+00:00  0.474140  0.753086  0.824254 -0.986047  0.062584
# 2000-09-30 00:00:00+00:00 -0.296675  0.777778  0.740597 -0.985113  0.036181
# 2000-10-31 00:00:00+00:00 -0.296675  0.629630  0.729128 -0.985508  0.079816
# ...                             ...       ...       ...       ...       ...
# 2020-08-31 00:00:00+00:00 -0.368784  0.734568 -0.221285 -0.975411  0.340739
# 2020-09-30 00:00:00+00:00 -0.170503  0.666667 -0.207371 -0.974825  0.294497
# 2020-10-31 00:00:00+00:00 -0.151819  0.629630 -0.176590 -0.975018  0.249494
# 2020-11-30 00:00:00+00:00 -1.000000 -1.000000 -1.000000 -1.000000 -1.000000
# 2020-12-31 00:00:00+00:00  0.024064  0.585859 -0.118662 -0.977951  0.324309
#
#                                  MD  earthquake
# timestamp
# 2000-06-30 00:00:00+00:00 -0.726867         1.0
# 2000-07-31 00:00:00+00:00 -0.727054         1.0
# 2000-08-31 00:00:00+00:00 -0.726597         1.0
# 2000-09-30 00:00:00+00:00 -0.726140         1.0
# 2000-10-31 00:00:00+00:00 -0.726764         1.0
# ...                             ...         ...
# 2020-08-31 00:00:00+00:00 -0.497188         1.0
# 2020-09-30 00:00:00+00:00 -0.547431         1.0
# 2020-10-31 00:00:00+00:00 -0.546861         1.0
# 2020-11-30 00:00:00+00:00  1.000000         0.0
# 2020-12-31 00:00:00+00:00 -0.547829         1.0
#
# [247 rows x 7 columns]

# %%
import numpy as np

def create_lstm_dataset(df, lookback, n_future):
    """
    Creates an LSTM dataset from the given DataFrame.

    Parameters:
    - df: pandas DataFrame containing features.
    - lookback: Number of past timesteps to include in each X sample.

    Returns:
    - X: 3D NumPy array of shape (samples, lookback, features)
    - Y: 1D NumPy array of shape (samples,)
    """
    data = df.values  # Convert dataframe to NumPy array
    X, Y = [], []
    
    for i in range(len(data) - lookback):
        X.append(data[i:i + lookback, :7])  # First 6 columns
        Y.append(data[(i + lookback):(i + lookback + n_future), -1])     # 7th column as label
    
    return np.array(X), np.array(Y)
look_back = 10
X, Y = create_lstm_dataset(df, lookback=look_back, n_future=1)

print(X.shape)  # (number of samples, lookback, 6)
print(Y.shape)  # (number of samples,)
# Out:
# (237, 10, 7)
# (237, 1)

# %%
from sklearn.model_selection import train_test_split

# Split the data
X_train, X_val, Y_train, Y_val = train_test_split(X, Y, test_size=0.15, shuffle=False)

# Print the shapes of the resulting datasets
print("X_train shape:", X_train.shape)
print("X_val shape:", X_val.shape)
print("Y_train shape:", Y_train.shape)
print("Y_val shape:", Y_val.shape)
# Out:
# X_train shape: (201, 10, 7)
# X_val shape: (36, 10, 7)
# Y_train shape: (201, 1)
# Y_val shape: (36, 1)

# %%
print(X_train[0])
# Out:
# [[-0.09633419  0.65432099  1.         -0.98653707  0.06014875 -0.7268671
#    1.        ]
#  [ 0.30008525  0.59259259  0.93455895 -0.98678991  0.0852403  -0.72705386
#    1.        ]
#  [ 0.47414038  0.75308642  0.82425367 -0.98604729  0.06258435 -0.72659745
#    1.        ]
#  [-0.29667519  0.77777778  0.74059707 -0.98511289  0.03618064 -0.72614031
#    1.        ]
#  [-0.29667519  0.62962963  0.72912801 -0.98550801  0.07981557 -0.72676354
#    1.        ]
#  [-0.29667519  0.81481481  0.72744139 -0.98527461  0.06643409 -0.72645313
#    1.        ]
#  [-0.29667519  0.51851852  0.73351324 -0.98543589  0.08223311 -0.72660954
#   -1.        ]
#  [-0.29667519  0.98148148  0.64547141 -0.98354231  0.03664993 -0.7260717
#    1.        ]
#  [-0.29667519  0.75925926  0.61308821 -0.98239227 -0.01281664 -0.72525052
#    1.        ]
#  [-0.29667519  0.76851852  0.61055827 -0.98189796 -0.0332126  -0.72489985
#    1.        ]]

# %%
# Count occurrences of 0 and 1 in Y_train
unique_train, counts_train = np.unique(Y_train, return_counts=True)
print("Y_train counts:", dict(zip(unique_train, counts_train)))

# Count occurrences of 0 and 1 in Y_val
unique_val, counts_val = np.unique(Y_val, return_counts=True)
print("Y_val counts:", dict(zip(unique_val, counts_val)))
# Out:
# Y_train counts: {-1.0: 39, 0.0: 9, 1.0: 153}
# Y_val counts: {-1.0: 7, 0.0: 5, 1.0: 24}

# %%
# root mean squared error (rmse) for regression (only for Keras tensors)
def rmse(y_true, y_pred):
    from keras import backend
    return backend.sqrt(backend.mean(backend.square(y_pred - y_true), axis=-1))

# mean squared error (mse) for regression  (only for Keras tensors)
def mse(y_true, y_pred):
    from keras import backend
    return backend.mean(backend.square(y_pred - y_true), axis=-1)

# coefficient of determination (R^2) for regression  (only for Keras tensors)
def r_square(y_true, y_pred):
    from keras import backend as K
    SS_res =  K.sum(K.square(y_true - y_pred)) 
    SS_tot = K.sum(K.square(y_true - K.mean(y_true))) 
    return ( 1 - SS_res/(SS_tot + K.epsilon()) )

# %%
# import tensorflow as tf
# from tensorflow.keras.layers import *
# from tensorflow.keras.models import Model
# from tensorflow.keras.layers import Input, LSTM, Dense, Layer, Dropout

# from tensorflow.keras.optimizers.legacy import Adam

# from tensorflow.keras.regularizers import L1L2
# from tensorflow.keras.layers import Layer, Dense, Dot, Activation

# from tensorflow.keras.callbacks import Callback, EarlyStopping

# from tensorflow.keras import backend as K

# from matplotlib import pyplot as plt

# K.clear_session()

   
# l1 = 0.0001
# l2 = 0.0001

# lstm_dropout = 0.2
# recurrent_dropout = 0.1
# dense_dropout = 0.2
# loss = 'mse'

# n_target = Y_train.shape[-2:]

# regularization_criteria = L1L2(l1=l1, l2=l2)

# n_target_y = Y_train.shape[-1]

# def build_model(input_shape):
#     input_layer = Input(shape=input_shape, name='Input_1')
#     sequence = input_layer
#     sequence = LSTM(20, return_sequences = True,  name="LSTM-1", kernel_regularizer = regularization_criteria, dropout=lstm_dropout, recurrent_dropout=recurrent_dropout)(input_layer)
#     sequence = Flatten()(sequence)
#     # sequence = Dropout(dense_dropout)(sequence)
#     # sequence = LSTM(16, return_sequences = False,  name="LSTM-2", kernel_regularizer = regularization_criteria, dropout=lstm_dropout, recurrent_dropout=recurrent_dropout)(sequence)
#     # sequence = Dense(4, activation = 'tanh', name='Dense_3')(sequence)
#     sequence = Dense(n_target_y, activation = 'tanh', name='Dense_4')(sequence)
#     output_layer = sequence

#     model = Model(inputs=input_layer, outputs=output_layer)

#     return model

# input_shape = (look_back, X_train.shape[2])

# learning_rate = 0.0005

# optimizer = Adam(learning_rate=learning_rate)

# model = build_model(input_shape)
# model.compile(optimizer=optimizer, loss=loss, metrics=[mse, rmse, r_square])
# model.summary()

# import time

# start_time = time.time()

# # early_stopping = EarlyStopping(monitor='val_loss', patience=500, restore_best_weights=True)

# history = model.fit(X_train, Y_train, epochs=700, batch_size=64, validation_data=(X_val, Y_val),
#                     # callbacks=[early_stopping]
#                     )

# end_time = time.time()
# difference_in_seconds = end_time - start_time
# print(f"The difference in seconds is: {difference_in_seconds}")

# %%
import tensorflow as tf
from tensorflow.keras.layers import *
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, LSTM, Dense, Layer, Dropout

from tensorflow.keras.optimizers.legacy import Adam

from tensorflow.keras.regularizers import L1L2
from tensorflow.keras.layers import Layer, Dense, Dot, Activation

from tensorflow.keras.callbacks import Callback, EarlyStopping

from tensorflow.keras import backend as K

from matplotlib import pyplot as plt

K.clear_session()

   
l1 = 0.0
l2 = 0.0

lstm_dropout = 0.0
recurrent_dropout = 0.0
dense_dropout = 0.1
loss = 'mse'

n_target = Y_train.shape[-2:]

regularization_criteria = L1L2(l1=l1, l2=l2)

n_target_y = Y_train.shape[-1]

def build_model(input_shape):
    input_layer = Input(shape=input_shape, name='Input_1')
    sequence = input_layer
    sequence = LSTM(50, return_sequences = True,  name="LSTM-1", kernel_regularizer = regularization_criteria, dropout=lstm_dropout, recurrent_dropout=recurrent_dropout)(input_layer)
    
    sequence = Flatten()(sequence)
    sequence = Dense(20, activation = 'tanh', name='Dense_2')(sequence)
    sequence = Dropout(0.3)(sequence)
    # sequence = LSTM(16, return_sequences = False,  name="LSTM-2", kernel_regularizer = regularization_criteria, dropout=lstm_dropout, recurrent_dropout=recurrent_dropout)(sequence)
    sequence = Dense(10, activation = 'tanh', name='Dense_3')(sequence)
    sequence = Dense(n_target_y, activation = 'sigmoid', name='Dense_4')(sequence)
    output_layer = sequence

    model = Model(inputs=input_layer, outputs=output_layer)

    return model

input_shape = (look_back, X_train.shape[2])

learning_rate = 0.001

optimizer = Adam(learning_rate=learning_rate)

model = build_model(input_shape)
model.compile(optimizer=optimizer, loss=loss, metrics=[mse])
model.summary()

import time

start_time = time.time()

early_stopping = EarlyStopping(monitor='val_loss', patience=700, restore_best_weights=True)

history = model.fit(X_train, Y_train, epochs=1000, batch_size=64, validation_data=(X_val, Y_val),
                    callbacks=[early_stopping]
                    )

end_time = time.time()
difference_in_seconds = end_time - start_time
print(f"The difference in seconds is: {difference_in_seconds}")
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  Input_1 (InputLayer)        [(None, 10, 7)]           0
#
#  LSTM-1 (LSTM)               (None, 10, 50)            11600
#
#  flatten (Flatten)           (None, 500)               0
#
#  Dense_2 (Dense)             (None, 20)                10020
#
#  dropout (Dropout)           (None, 20)                0
#
#  Dense_3 (Dense)             (None, 10)                210
#
#  Dense_4 (Dense)             (None, 1)                 11
#
# =================================================================
# Total params: 21,841
# Trainable params: 21,841
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/1000
# 4/4 [==============================] - 10s 541ms/step - loss: 0.6430 - mse: 0.6430 - val_loss: 0.6459 - val_mse: 0.6459
# Epoch 2/1000
# 4/4 [==============================] - 0s 103ms/step - loss: 0.6335 - mse: 0.6335 - val_loss: 0.6399 - val_mse: 0.6399
# Epoch 3/1000
# 4/4 [==============================] - 0s 40ms/step - loss: 0.6333 - mse: 0.6333 - val_loss: 0.6433 - val_mse: 0.6433
# Epoch 4/1000
# 4/4 [==============================] - 0s 34ms/step - loss: 0.6311 - mse: 0.6311 - val_loss: 0.6481 - val_mse: 0.6481
# Epoch 5/1000
# 4/4 [==============================] - 0s 98ms/step - loss: 0.6235 - mse: 0.6235 - val_loss: 0.6395 - val_mse: 0.6395
# Epoch 6/1000
# 4/4 [==============================] - 0s 70ms/step - loss: 0.6247 - mse: 0.6247 - val_loss: 0.6414 - val_mse: 0.6414
# Epoch 7/1000
# 4/4 [==============================] - 0s 38ms/step - loss: 0.6187 - mse: 0.6187 - val_loss: 0.6494 - val_mse: 0.6494
# Epoch 8/1000
# 4/4 [==============================] - 0s 61ms/step - loss: 0.6232 - mse: 0.6232 - val_loss: 0.6586 - val_mse: 0.6586
# Epoch 9/1000
# 4/4 [==============================] - 0s 53ms/step - loss: 0.6232 - mse: 0.6232 - val_loss: 0.6570 - val_mse: 0.6570
# Epoch 10/1000
# 4/4 [==============================] - 0s 30ms/step - loss: 0.6153 - mse: 0.6153 - val_loss: 0.6553 - val_mse: 0.6553
# Epoch 11/1000
# 4/4 [==============================] - 0s 38ms/step - loss: 0.6072 - mse: 0.6072 - val_loss: 0.6522 - val_mse: 0.6522
# Epoch 12/1000
# 4/4 [==============================] - 0s 59ms/step - loss: 0.6113 - mse: 0.6113 - val_loss: 0.6512 - val_mse: 0.6512
# Epoch 13/1000
# 4/4 [==============================] - 0s 33ms/step - loss: 0.6132 - mse: 0.6132 - val_loss: 0.6582 - val_mse: 0.6582
# Epoch 14/1000
# 4/4 [==============================] - 0s 26ms/step - loss: 0.6146 - mse: 0.6146 - val_loss: 0.6722 - val_mse: 0.6722
# Epoch 15/1000
# 4/4 [==============================] - 0s 27ms/step - loss: 0.6123 - mse: 0.6123 - val_loss: 0.6743 - val_mse: 0.6743
# Epoch 16/1000
# 4/4 [==============================] - 0s 25ms/step - loss: 0.6097 - mse: 0.6097 - val_loss: 0.6667 - val_mse: 0.6667
# Epoch 17/1000
# 4/4 [==============================] - 0s 25ms/step - loss: 0.6022 - mse: 0.6022 - val_loss: 0.6529 - val_mse: 0.6529
# Epoch 18/1000
# 4/4 [==============================] - 0s 25ms/step - loss: 0.6128 - mse: 0.6128 - val_loss: 0.6517 - val_mse: 0.6517
# Epoch 19/1000
# 4/4 [==============================] - 0s 25ms/step - loss: 0.6016 - mse: 0.6016 - val_loss: 0.6448 - val_mse: 0.6448
# Epoch 20/1000
# 4/4 [==============================] - 0s 24ms/step - loss: 0.6069 - mse: 0.6069 - val_loss: 0.6419 - val_mse: 0.6419
# Epoch 21/1000
# 4/4 [==============================] - 0s 26ms/step - loss: 0.6030 - mse: 0.6030 - val_loss: 0.6421 - val_mse: 0.6421
# Epoch 22/1000
# 4/4 [==============================] - 0s 31ms/step - loss: 0.5906 - mse: 0.5906 - val_loss: 0.6590 - val_mse: 0.6590
# Epoch 23/1000
# 4/4 [==============================] - 0s 39ms/step - loss: 0.5955 - mse: 0.5955 - val_loss: 0.6691 - val_mse: 0.6691
# Epoch 24/1000
# 4/4 [==============================] - 0s 52ms/step - loss: 0.5934 - mse: 0.5934 - val_loss: 0.6656 - val_mse: 0.6656
# Epoch 25/1000
# 4/4 [==============================] - 0s 49ms/step - loss: 0.5855 - mse: 0.5855 - val_loss: 0.6544 - val_mse: 0.6544
# Epoch 26/1000
# 4/4 [==============================] - 0s 41ms/step - loss: 0.5934 - mse: 0.5934 - val_loss: 0.6503 - val_mse: 0.6503
# Epoch 27/1000
# 4/4 [==============================] - 0s 46ms/step - loss: 0.5946 - mse: 0.5946 - val_loss: 0.6509 - val_mse: 0.6509
# Epoch 28/1000
# 4/4 [==============================] - 0s 56ms/step - loss: 0.5923 - mse: 0.5923 - val_loss: 0.6505 - val_mse: 0.6505
# Epoch 29/1000
# 4/4 [==============================] - 0s 94ms/step - loss: 0.5974 - mse: 0.5974 - val_loss: 0.6625 - val_mse: 0.6625
# Epoch 30/1000
# 4/4 [==============================] - 0s 41ms/step - loss: 0.5838 - mse: 0.5838 - val_loss: 0.6818 - val_mse: 0.6818
# Epoch 31/1000
# 4/4 [==============================] - 0s 41ms/step - loss: 0.5920 - mse: 0.5920 - val_loss: 0.6647 - val_mse: 0.6647
# Epoch 32/1000
# 4/4 [==============================] - 0s 58ms/step - loss: 0.5887 - mse: 0.5887 - val_loss: 0.6543 - val_mse: 0.6543
# Epoch 33/1000
# 4/4 [==============================] - 0s 58ms/step - loss: 0.5843 - mse: 0.5843 - val_loss: 0.6548 - val_mse: 0.6548
# Epoch 34/1000
# 4/4 [==============================] - 0s 35ms/step - loss: 0.5868 - mse: 0.5868 - val_loss: 0.6599 - val_mse: 0.6599
# Epoch 35/1000
# 4/4 [==============================] - 0s 35ms/step - loss: 0.5740 - mse: 0.5740 - val_loss: 0.6781 - val_mse: 0.6781
# Epoch 36/1000
# 4/4 [==============================] - 0s 45ms/step - loss: 0.5813 - mse: 0.5813 - val_loss: 0.6853 - val_mse: 0.6853
# Epoch 37/1000
# 4/4 [==============================] - 0s 61ms/step - loss: 0.5750 - mse: 0.5750 - val_loss: 0.6791 - val_mse: 0.6791
# Epoch 38/1000
# 4/4 [==============================] - 0s 52ms/step - loss: 0.5694 - mse: 0.5694 - val_loss: 0.6800 - val_mse: 0.6800
# Epoch 39/1000
# 4/4 [==============================] - 0s 68ms/step - loss: 0.5764 - mse: 0.5764 - val_loss: 0.6808 - val_mse: 0.6808
# Epoch 40/1000
# 4/4 [==============================] - 0s 41ms/step - loss: 0.5620 - mse: 0.5620 - val_loss: 0.6767 - val_mse: 0.6767
# Epoch 41/1000
# 4/4 [==============================] - 0s 37ms/step - loss: 0.5764 - mse: 0.5764 - val_loss: 0.6748 - val_mse: 0.6748
# Epoch 42/1000
# 4/4 [==============================] - 0s 42ms/step - loss: 0.5765 - mse: 0.5765 - val_loss: 0.6837 - val_mse: 0.6837
# Epoch 43/1000
# 4/4 [==============================] - 0s 42ms/step - loss: 0.5706 - mse: 0.5706 - val_loss: 0.6911 - val_mse: 0.6911
# Epoch 44/1000
# 4/4 [==============================] - 0s 53ms/step - loss: 0.5661 - mse: 0.5661 - val_loss: 0.6864 - val_mse: 0.6864
# Epoch 45/1000
# 4/4 [==============================] - 0s 38ms/step - loss: 0.5635 - mse: 0.5635 - val_loss: 0.6851 - val_mse: 0.6851
# Epoch 46/1000
# 4/4 [==============================] - 0s 33ms/step - loss: 0.5695 - mse: 0.5695 - val_loss: 0.6884 - val_mse: 0.6884
# Epoch 47/1000
# 4/4 [==============================] - 0s 56ms/step - loss: 0.5674 - mse: 0.5674 - val_loss: 0.7005 - val_mse: 0.7005
# Epoch 48/1000
# 4/4 [==============================] - 0s 53ms/step - loss: 0.5634 - mse: 0.5634 - val_loss: 0.7200 - val_mse: 0.7200
# Epoch 49/1000
# 4/4 [==============================] - 0s 37ms/step - loss: 0.5677 - mse: 0.5677 - val_loss: 0.6956 - val_mse: 0.6956
# Epoch 50/1000
# 4/4 [==============================] - 0s 30ms/step - loss: 0.5660 - mse: 0.5660 - val_loss: 0.6909 - val_mse: 0.6909
# Epoch 51/1000
# 4/4 [==============================] - 0s 33ms/step - loss: 0.5710 - mse: 0.5710 - val_loss: 0.6999 - val_mse: 0.6999
# Epoch 52/1000
# 4/4 [==============================] - 0s 29ms/step - loss: 0.5578 - mse: 0.5578 - val_loss: 0.7133 - val_mse: 0.7133
# Epoch 53/1000
# 4/4 [==============================] - 0s 31ms/step - loss: 0.5631 - mse: 0.5631 - val_loss: 0.7327 - val_mse: 0.7327
# Epoch 54/1000
# 4/4 [==============================] - 0s 31ms/step - loss: 0.5758 - mse: 0.5758 - val_loss: 0.7364 - val_mse: 0.7364
# Epoch 55/1000
# 4/4 [==============================] - 0s 30ms/step - loss: 0.5608 - mse: 0.5608 - val_loss: 0.7281 - val_mse: 0.7281
# Epoch 56/1000
# 4/4 [==============================] - 0s 28ms/step - loss: 0.5450 - mse: 0.5450 - val_loss: 0.7221 - val_mse: 0.7221
# Epoch 57/1000
# 4/4 [==============================] - 0s 40ms/step - loss: 0.5498 - mse: 0.5498 - val_loss: 0.7195 - val_mse: 0.7195
# Epoch 58/1000
# 4/4 [==============================] - 0s 55ms/step - loss: 0.5455 - mse: 0.5455 - val_loss: 0.7213 - val_mse: 0.7213
# Epoch 59/1000
# 4/4 [==============================] - 0s 45ms/step - loss: 0.5515 - mse: 0.5515 - val_loss: 0.7174 - val_mse: 0.7174
# Epoch 60/1000
# 4/4 [==============================] - 0s 40ms/step - loss: 0.5397 - mse: 0.5397 - val_loss: 0.7181 - val_mse: 0.7181
# Epoch 61/1000
# 4/4 [==============================] - 0s 42ms/step - loss: 0.5510 - mse: 0.5510 - val_loss: 0.7195 - val_mse: 0.7195
# Epoch 62/1000
# 4/4 [==============================] - 0s 43ms/step - loss: 0.5562 - mse: 0.5562 - val_loss: 0.7248 - val_mse: 0.7248
# Epoch 63/1000
# 4/4 [==============================] - 0s 34ms/step - loss: 0.5397 - mse: 0.5397 - val_loss: 0.7335 - val_mse: 0.7335
# Epoch 64/1000
# 4/4 [==============================] - 0s 53ms/step - loss: 0.5466 - mse: 0.5466 - val_loss: 0.7421 - val_mse: 0.7421
# Epoch 65/1000
# 4/4 [==============================] - 0s 59ms/step - loss: 0.5372 - mse: 0.5372 - val_loss: 0.7434 - val_mse: 0.7434
# Epoch 66/1000
# 4/4 [==============================] - 0s 67ms/step - loss: 0.5447 - mse: 0.5447 - val_loss: 0.7445 - val_mse: 0.7445
# Epoch 67/1000
# 4/4 [==============================] - 0s 55ms/step - loss: 0.5361 - mse: 0.5361 - val_loss: 0.7424 - val_mse: 0.7424
# Epoch 68/1000
# 4/4 [==============================] - 0s 53ms/step - loss: 0.5436 - mse: 0.5436 - val_loss: 0.7417 - val_mse: 0.7417
# Epoch 69/1000
# 4/4 [==============================] - 0s 54ms/step - loss: 0.5372 - mse: 0.5372 - val_loss: 0.7391 - val_mse: 0.7391
# Epoch 70/1000
# 4/4 [==============================] - 0s 45ms/step - loss: 0.5308 - mse: 0.5308 - val_loss: 0.7399 - val_mse: 0.7399
# Epoch 71/1000
# 4/4 [==============================] - 0s 43ms/step - loss: 0.5314 - mse: 0.5314 - val_loss: 0.7422 - val_mse: 0.7422
# Epoch 72/1000
# 4/4 [==============================] - 0s 25ms/step - loss: 0.5426 - mse: 0.5426 - val_loss: 0.7436 - val_mse: 0.7436
# Epoch 73/1000
# 4/4 [==============================] - 0s 26ms/step - loss: 0.5207 - mse: 0.5207 - val_loss: 0.7390 - val_mse: 0.7390
# Epoch 74/1000
# 4/4 [==============================] - 0s 27ms/step - loss: 0.5346 - mse: 0.5346 - val_loss: 0.7465 - val_mse: 0.7465
# Epoch 75/1000
# 4/4 [==============================] - 0s 45ms/step - loss: 0.5331 - mse: 0.5331 - val_loss: 0.7529 - val_mse: 0.7529
# Epoch 76/1000
# 4/4 [==============================] - 0s 36ms/step - loss: 0.5299 - mse: 0.5299 - val_loss: 0.7550 - val_mse: 0.7550
# Epoch 77/1000
# 4/4 [==============================] - 0s 26ms/step - loss: 0.5229 - mse: 0.5229 - val_loss: 0.7641 - val_mse: 0.7641
# Epoch 78/1000
# 4/4 [==============================] - 0s 33ms/step - loss: 0.5139 - mse: 0.5139 - val_loss: 0.7714 - val_mse: 0.7714
# Epoch 79/1000
# 4/4 [==============================] - 0s 26ms/step - loss: 0.5305 - mse: 0.5305 - val_loss: 0.7771 - val_mse: 0.7771
# Epoch 80/1000
# 4/4 [==============================] - 0s 26ms/step - loss: 0.5294 - mse: 0.5294 - val_loss: 0.7835 - val_mse: 0.7835
# Epoch 81/1000
# 4/4 [==============================] - 0s 31ms/step - loss: 0.5234 - mse: 0.5234 - val_loss: 0.7773 - val_mse: 0.7773
# Epoch 82/1000
# 4/4 [==============================] - 0s 31ms/step - loss: 0.5204 - mse: 0.5204 - val_loss: 0.7664 - val_mse: 0.7664
# Epoch 83/1000
# 4/4 [==============================] - 0s 26ms/step - loss: 0.5330 - mse: 0.5330 - val_loss: 0.7765 - val_mse: 0.7765
# Epoch 84/1000
# 4/4 [==============================] - 0s 26ms/step - loss: 0.5292 - mse: 0.5292 - val_loss: 0.7952 - val_mse: 0.7952
# Epoch 85/1000
# 4/4 [==============================] - 0s 34ms/step - loss: 0.5199 - mse: 0.5199 - val_loss: 0.7990 - val_mse: 0.7990
# Epoch 86/1000
# 4/4 [==============================] - 0s 28ms/step - loss: 0.5279 - mse: 0.5279 - val_loss: 0.7900 - val_mse: 0.7900
# Epoch 87/1000
# 4/4 [==============================] - 0s 45ms/step - loss: 0.5202 - mse: 0.5202 - val_loss: 0.7799 - val_mse: 0.7799
# Epoch 88/1000
# 4/4 [==============================] - 0s 43ms/step - loss: 0.5042 - mse: 0.5042 - val_loss: 0.7709 - val_mse: 0.7709
# Epoch 89/1000
# 4/4 [==============================] - 0s 25ms/step - loss: 0.5144 - mse: 0.5144 - val_loss: 0.7704 - val_mse: 0.7704
# Epoch 90/1000
# 4/4 [==============================] - 0s 26ms/step - loss: 0.5178 - mse: 0.5178 - val_loss: 0.7734 - val_mse: 0.7734
# Epoch 91/1000
# 4/4 [==============================] - 0s 25ms/step - loss: 0.5030 - mse: 0.5030 - val_loss: 0.7748 - val_mse: 0.7748
# Epoch 92/1000
# 4/4 [==============================] - 0s 26ms/step - loss: 0.4971 - mse: 0.4971 - val_loss: 0.7739 - val_mse: 0.7739
# Epoch 93/1000
# 4/4 [==============================] - 0s 26ms/step - loss: 0.4987 - mse: 0.4987 - val_loss: 0.7641 - val_mse: 0.7641
# Epoch 94/1000
# 4/4 [==============================] - 0s 26ms/step - loss: 0.5209 - mse: 0.5209 - val_loss: 0.7709 - val_mse: 0.7709
# Epoch 95/1000
# 4/4 [==============================] - 0s 31ms/step - loss: 0.5081 - mse: 0.5081 - val_loss: 0.7808 - val_mse: 0.7808
# Epoch 96/1000
# 4/4 [==============================] - 0s 32ms/step - loss: 0.5046 - mse: 0.5046 - val_loss: 0.7880 - val_mse: 0.7880
# Epoch 97/1000
# 4/4 [==============================] - 0s 26ms/step - loss: 0.5055 - mse: 0.5055 - val_loss: 0.7823 - val_mse: 0.7823
# Epoch 98/1000
# 4/4 [==============================] - 0s 25ms/step - loss: 0.5067 - mse: 0.5067 - val_loss: 0.7872 - val_mse: 0.7872
# Epoch 99/1000
# 4/4 [==============================] - 0s 31ms/step - loss: 0.5097 - mse: 0.5097 - val_loss: 0.7936 - val_mse: 0.7936
# Epoch 100/1000
# 4/4 [==============================] - 0s 31ms/step - loss: 0.5076 - mse: 0.5076 - val_loss: 0.7852 - val_mse: 0.7852
# Epoch 101/1000
# 4/4 [==============================] - 0s 44ms/step - loss: 0.5121 - mse: 0.5121 - val_loss: 0.7733 - val_mse: 0.7733
# Epoch 102/1000
# 4/4 [==============================] - 0s 26ms/step - loss: 0.5080 - mse: 0.5080 - val_loss: 0.7874 - val_mse: 0.7874
# Epoch 103/1000
# 4/4 [==============================] - 0s 33ms/step - loss: 0.5039 - mse: 0.5039 - val_loss: 0.7940 - val_mse: 0.7940
# Epoch 104/1000
# 4/4 [==============================] - 0s 26ms/step - loss: 0.4903 - mse: 0.4903 - val_loss: 0.7860 - val_mse: 0.7860
# Epoch 105/1000
# 4/4 [==============================] - 0s 31ms/step - loss: 0.4789 - mse: 0.4789 - val_loss: 0.7853 - val_mse: 0.7853
# Epoch 106/1000
# 4/4 [==============================] - 0s 40ms/step - loss: 0.4895 - mse: 0.4895 - val_loss: 0.7835 - val_mse: 0.7835
# Epoch 107/1000
# 4/4 [==============================] - 0s 28ms/step - loss: 0.4954 - mse: 0.4954 - val_loss: 0.7861 - val_mse: 0.7861
# Epoch 108/1000
# 4/4 [==============================] - 0s 37ms/step - loss: 0.4927 - mse: 0.4927 - val_loss: 0.7910 - val_mse: 0.7910
# Epoch 109/1000
# 4/4 [==============================] - 0s 35ms/step - loss: 0.4844 - mse: 0.4844 - val_loss: 0.7995 - val_mse: 0.7995
# Epoch 110/1000
# 4/4 [==============================] - 0s 32ms/step - loss: 0.4856 - mse: 0.4856 - val_loss: 0.8042 - val_mse: 0.8042
# Epoch 111/1000
# 4/4 [==============================] - 0s 25ms/step - loss: 0.4885 - mse: 0.4885 - val_loss: 0.7835 - val_mse: 0.7835
# Epoch 112/1000
# 4/4 [==============================] - 0s 26ms/step - loss: 0.4763 - mse: 0.4763 - val_loss: 0.7746 - val_mse: 0.7746
# Epoch 113/1000
# 4/4 [==============================] - 0s 27ms/step - loss: 0.4718 - mse: 0.4718 - val_loss: 0.7769 - val_mse: 0.7769
# Epoch 114/1000
# 4/4 [==============================] - 0s 34ms/step - loss: 0.4585 - mse: 0.4585 - val_loss: 0.7833 - val_mse: 0.7833
# Epoch 115/1000
# 4/4 [==============================] - 0s 26ms/step - loss: 0.4648 - mse: 0.4648 - val_loss: 0.7930 - val_mse: 0.7930
# Epoch 116/1000
# 4/4 [==============================] - 0s 25ms/step - loss: 0.4816 - mse: 0.4816 - val_loss: 0.7923 - val_mse: 0.7923
# Epoch 117/1000
# 4/4 [==============================] - 0s 26ms/step - loss: 0.4670 - mse: 0.4670 - val_loss: 0.8060 - val_mse: 0.8060
# Epoch 118/1000
# 4/4 [==============================] - 0s 26ms/step - loss: 0.4694 - mse: 0.4694 - val_loss: 0.8133 - val_mse: 0.8133
# Epoch 119/1000
# 4/4 [==============================] - 0s 34ms/step - loss: 0.4669 - mse: 0.4669 - val_loss: 0.8077 - val_mse: 0.8077
# Epoch 120/1000
# 4/4 [==============================] - 0s 27ms/step - loss: 0.4540 - mse: 0.4540 - val_loss: 0.7887 - val_mse: 0.7887
# Epoch 121/1000
# 4/4 [==============================] - 0s 33ms/step - loss: 0.4728 - mse: 0.4728 - val_loss: 0.7899 - val_mse: 0.7899
# Epoch 122/1000
# 4/4 [==============================] - 0s 25ms/step - loss: 0.4580 - mse: 0.4580 - val_loss: 0.8071 - val_mse: 0.8071
# Epoch 123/1000
# 4/4 [==============================] - 0s 26ms/step - loss: 0.4509 - mse: 0.4509 - val_loss: 0.7873 - val_mse: 0.7873
# Epoch 124/1000
# 4/4 [==============================] - 0s 26ms/step - loss: 0.4559 - mse: 0.4559 - val_loss: 0.7768 - val_mse: 0.7768
# Epoch 125/1000
# 4/4 [==============================] - 0s 27ms/step - loss: 0.4437 - mse: 0.4437 - val_loss: 0.8015 - val_mse: 0.8015
# Epoch 126/1000
# 4/4 [==============================] - 0s 32ms/step - loss: 0.4637 - mse: 0.4637 - val_loss: 0.8294 - val_mse: 0.8294
# Epoch 127/1000
# 4/4 [==============================] - 0s 31ms/step - loss: 0.4519 - mse: 0.4519 - val_loss: 0.8199 - val_mse: 0.8199
# Epoch 128/1000
# 4/4 [==============================] - 0s 26ms/step - loss: 0.4551 - mse: 0.4551 - val_loss: 0.7854 - val_mse: 0.7854
# Epoch 129/1000
# 4/4 [==============================] - 0s 27ms/step - loss: 0.4593 - mse: 0.4593 - val_loss: 0.7837 - val_mse: 0.7837
# Epoch 130/1000
# 4/4 [==============================] - 0s 33ms/step - loss: 0.4556 - mse: 0.4556 - val_loss: 0.7876 - val_mse: 0.7876
# Epoch 131/1000
# 4/4 [==============================] - 0s 26ms/step - loss: 0.4339 - mse: 0.4339 - val_loss: 0.8248 - val_mse: 0.8248
# Epoch 132/1000
# 4/4 [==============================] - 0s 25ms/step - loss: 0.4405 - mse: 0.4405 - val_loss: 0.8106 - val_mse: 0.8106
# Epoch 133/1000
# 4/4 [==============================] - 0s 27ms/step - loss: 0.4394 - mse: 0.4394 - val_loss: 0.7926 - val_mse: 0.7926
# Epoch 134/1000
# 4/4 [==============================] - 0s 28ms/step - loss: 0.4444 - mse: 0.4444 - val_loss: 0.7980 - val_mse: 0.7980
# Epoch 135/1000
# 4/4 [==============================] - 0s 26ms/step - loss: 0.4218 - mse: 0.4218 - val_loss: 0.8127 - val_mse: 0.8127
# Epoch 136/1000
# 4/4 [==============================] - 0s 27ms/step - loss: 0.4176 - mse: 0.4176 - val_loss: 0.8244 - val_mse: 0.8244
# Epoch 137/1000
# 4/4 [==============================] - 0s 35ms/step - loss: 0.4172 - mse: 0.4172 - val_loss: 0.8298 - val_mse: 0.8298
# Epoch 138/1000
# 4/4 [==============================] - 0s 43ms/step - loss: 0.4133 - mse: 0.4133 - val_loss: 0.8121 - val_mse: 0.8121
# Epoch 139/1000
# 4/4 [==============================] - 0s 42ms/step - loss: 0.4050 - mse: 0.4050 - val_loss: 0.8172 - val_mse: 0.8172
# Epoch 140/1000
# 4/4 [==============================] - 0s 27ms/step - loss: 0.4052 - mse: 0.4052 - val_loss: 0.8336 - val_mse: 0.8336
# Epoch 141/1000
# 4/4 [==============================] - 0s 39ms/step - loss: 0.3970 - mse: 0.3970 - val_loss: 0.8239 - val_mse: 0.8239
# Epoch 142/1000
# 4/4 [==============================] - 0s 31ms/step - loss: 0.3921 - mse: 0.3921 - val_loss: 0.8371 - val_mse: 0.8371
# Epoch 143/1000
# 4/4 [==============================] - 0s 25ms/step - loss: 0.3802 - mse: 0.3802 - val_loss: 0.8544 - val_mse: 0.8544
# Epoch 144/1000
# 4/4 [==============================] - 0s 25ms/step - loss: 0.3923 - mse: 0.3923 - val_loss: 0.8511 - val_mse: 0.8511
# Epoch 145/1000
# 4/4 [==============================] - 0s 27ms/step - loss: 0.3766 - mse: 0.3766 - val_loss: 0.8398 - val_mse: 0.8398
# Epoch 146/1000
# 4/4 [==============================] - 0s 25ms/step - loss: 0.3755 - mse: 0.3755 - val_loss: 0.8372 - val_mse: 0.8372
# Epoch 147/1000
# 4/4 [==============================] - 0s 25ms/step - loss: 0.3963 - mse: 0.3963 - val_loss: 0.8315 - val_mse: 0.8315
# Epoch 148/1000
# 4/4 [==============================] - 0s 26ms/step - loss: 0.3641 - mse: 0.3641 - val_loss: 0.8182 - val_mse: 0.8182
# Epoch 149/1000
# 4/4 [==============================] - 0s 26ms/step - loss: 0.3790 - mse: 0.3790 - val_loss: 0.8374 - val_mse: 0.8374
# Epoch 150/1000
# 4/4 [==============================] - 0s 27ms/step - loss: 0.3698 - mse: 0.3698 - val_loss: 0.8478 - val_mse: 0.8478
# Epoch 151/1000
# 4/4 [==============================] - 0s 35ms/step - loss: 0.3765 - mse: 0.3765 - val_loss: 0.8165 - val_mse: 0.8165
# Epoch 152/1000
# 4/4 [==============================] - 0s 43ms/step - loss: 0.3753 - mse: 0.3753 - val_loss: 0.8027 - val_mse: 0.8027
# Epoch 153/1000
# 4/4 [==============================] - 0s 30ms/step - loss: 0.3560 - mse: 0.3560 - val_loss: 0.8130 - val_mse: 0.8130
# Epoch 154/1000
# 4/4 [==============================] - 0s 36ms/step - loss: 0.3698 - mse: 0.3698 - val_loss: 0.8334 - val_mse: 0.8334
# Epoch 155/1000
# 4/4 [==============================] - 0s 32ms/step - loss: 0.3541 - mse: 0.3541 - val_loss: 0.8381 - val_mse: 0.8381
# Epoch 156/1000
# 4/4 [==============================] - 0s 31ms/step - loss: 0.3608 - mse: 0.3608 - val_loss: 0.8488 - val_mse: 0.8488
# Epoch 157/1000
# 4/4 [==============================] - 0s 35ms/step - loss: 0.3543 - mse: 0.3543 - val_loss: 0.8567 - val_mse: 0.8567
# Epoch 158/1000
# 4/4 [==============================] - 0s 33ms/step - loss: 0.3457 - mse: 0.3457 - val_loss: 0.8184 - val_mse: 0.8184
# Epoch 159/1000
# 4/4 [==============================] - 0s 32ms/step - loss: 0.3334 - mse: 0.3334 - val_loss: 0.8216 - val_mse: 0.8216
# Epoch 160/1000
# 4/4 [==============================] - 0s 25ms/step - loss: 0.3428 - mse: 0.3428 - val_loss: 0.8643 - val_mse: 0.8643
# Epoch 161/1000
# 4/4 [==============================] - 0s 25ms/step - loss: 0.3384 - mse: 0.3384 - val_loss: 0.8580 - val_mse: 0.8580
# Epoch 162/1000
# 4/4 [==============================] - 0s 25ms/step - loss: 0.3638 - mse: 0.3638 - val_loss: 0.8394 - val_mse: 0.8394
# Epoch 163/1000
# 4/4 [==============================] - 0s 32ms/step - loss: 0.3386 - mse: 0.3386 - val_loss: 0.8437 - val_mse: 0.8437
# Epoch 164/1000
# 4/4 [==============================] - 0s 24ms/step - loss: 0.3574 - mse: 0.3574 - val_loss: 0.8395 - val_mse: 0.8395
# Epoch 165/1000
# 4/4 [==============================] - 0s 33ms/step - loss: 0.3443 - mse: 0.3443 - val_loss: 0.8507 - val_mse: 0.8507
# Epoch 166/1000
# 4/4 [==============================] - 0s 26ms/step - loss: 0.3705 - mse: 0.3705 - val_loss: 0.8555 - val_mse: 0.8555
# Epoch 167/1000
# 4/4 [==============================] - 0s 27ms/step - loss: 0.3477 - mse: 0.3477 - val_loss: 0.8640 - val_mse: 0.8640
# Epoch 168/1000
# 4/4 [==============================] - 0s 32ms/step - loss: 0.3298 - mse: 0.3298 - val_loss: 0.8135 - val_mse: 0.8135
# Epoch 169/1000
# 4/4 [==============================] - 0s 26ms/step - loss: 0.3430 - mse: 0.3430 - val_loss: 0.8137 - val_mse: 0.8137
# Epoch 170/1000
# 4/4 [==============================] - 0s 25ms/step - loss: 0.3321 - mse: 0.3321 - val_loss: 0.8254 - val_mse: 0.8254
# Epoch 171/1000
# 4/4 [==============================] - 0s 27ms/step - loss: 0.3340 - mse: 0.3340 - val_loss: 0.8308 - val_mse: 0.8308
# Epoch 172/1000
# 4/4 [==============================] - 0s 31ms/step - loss: 0.3406 - mse: 0.3406 - val_loss: 0.8284 - val_mse: 0.8284
# Epoch 173/1000
# 4/4 [==============================] - 0s 32ms/step - loss: 0.3320 - mse: 0.3320 - val_loss: 0.8469 - val_mse: 0.8469
# Epoch 174/1000
# 4/4 [==============================] - 0s 26ms/step - loss: 0.3376 - mse: 0.3376 - val_loss: 0.8688 - val_mse: 0.8688
# Epoch 175/1000
# 4/4 [==============================] - 0s 26ms/step - loss: 0.3136 - mse: 0.3136 - val_loss: 0.8502 - val_mse: 0.8502
# Epoch 176/1000
# 4/4 [==============================] - 0s 26ms/step - loss: 0.3316 - mse: 0.3316 - val_loss: 0.8699 - val_mse: 0.8699
# Epoch 177/1000
# 4/4 [==============================] - 0s 25ms/step - loss: 0.3324 - mse: 0.3324 - val_loss: 0.8909 - val_mse: 0.8909
# Epoch 178/1000
# 4/4 [==============================] - 0s 25ms/step - loss: 0.3133 - mse: 0.3133 - val_loss: 0.8900 - val_mse: 0.8900
# Epoch 179/1000
# 4/4 [==============================] - 0s 31ms/step - loss: 0.3119 - mse: 0.3119 - val_loss: 0.8894 - val_mse: 0.8894
# Epoch 180/1000
# 4/4 [==============================] - 0s 33ms/step - loss: 0.3090 - mse: 0.3090 - val_loss: 0.8832 - val_mse: 0.8832
# Epoch 181/1000
# 4/4 [==============================] - 0s 27ms/step - loss: 0.3072 - mse: 0.3072 - val_loss: 0.8965 - val_mse: 0.8965
# Epoch 182/1000
# 4/4 [==============================] - 0s 42ms/step - loss: 0.2962 - mse: 0.2962 - val_loss: 0.8746 - val_mse: 0.8746
# Epoch 183/1000
# 4/4 [==============================] - 0s 25ms/step - loss: 0.2950 - mse: 0.2950 - val_loss: 0.8823 - val_mse: 0.8823
# Epoch 184/1000
# 4/4 [==============================] - 0s 31ms/step - loss: 0.3181 - mse: 0.3181 - val_loss: 0.8839 - val_mse: 0.8839
# Epoch 185/1000
# 4/4 [==============================] - 0s 26ms/step - loss: 0.3048 - mse: 0.3048 - val_loss: 0.8966 - val_mse: 0.8966
# Epoch 186/1000
# 4/4 [==============================] - 0s 26ms/step - loss: 0.3011 - mse: 0.3011 - val_loss: 0.8901 - val_mse: 0.8901
# Epoch 187/1000
# 4/4 [==============================] - 0s 25ms/step - loss: 0.2955 - mse: 0.2955 - val_loss: 0.8894 - val_mse: 0.8894
# Epoch 188/1000
# 4/4 [==============================] - 0s 30ms/step - loss: 0.3007 - mse: 0.3007 - val_loss: 0.8865 - val_mse: 0.8865
# Epoch 189/1000
# 4/4 [==============================] - 0s 34ms/step - loss: 0.2976 - mse: 0.2976 - val_loss: 0.8229 - val_mse: 0.8229
# Epoch 190/1000
# 4/4 [==============================] - 0s 35ms/step - loss: 0.3175 - mse: 0.3175 - val_loss: 0.8595 - val_mse: 0.8595
# Epoch 191/1000
# 4/4 [==============================] - 0s 35ms/step - loss: 0.2906 - mse: 0.2906 - val_loss: 0.8828 - val_mse: 0.8828
# Epoch 192/1000
# 4/4 [==============================] - 0s 33ms/step - loss: 0.2787 - mse: 0.2787 - val_loss: 0.9016 - val_mse: 0.9016
# Epoch 193/1000
# 4/4 [==============================] - 0s 26ms/step - loss: 0.2896 - mse: 0.2896 - val_loss: 0.8981 - val_mse: 0.8981
# Epoch 194/1000
# 4/4 [==============================] - 0s 26ms/step - loss: 0.2770 - mse: 0.2770 - val_loss: 0.8769 - val_mse: 0.8769
# Epoch 195/1000
# 4/4 [==============================] - 0s 26ms/step - loss: 0.2882 - mse: 0.2882 - val_loss: 0.8649 - val_mse: 0.8649
# Epoch 196/1000
# 4/4 [==============================] - 0s 27ms/step - loss: 0.2728 - mse: 0.2728 - val_loss: 0.8728 - val_mse: 0.8728
# Epoch 197/1000
# 4/4 [==============================] - 0s 35ms/step - loss: 0.2855 - mse: 0.2855 - val_loss: 0.8943 - val_mse: 0.8943
# Epoch 198/1000
# 4/4 [==============================] - 0s 35ms/step - loss: 0.2666 - mse: 0.2666 - val_loss: 0.8957 - val_mse: 0.8957
# Epoch 199/1000
# 4/4 [==============================] - 0s 32ms/step - loss: 0.2655 - mse: 0.2655 - val_loss: 0.9020 - val_mse: 0.9020
# Epoch 200/1000
# 4/4 [==============================] - 0s 31ms/step - loss: 0.2623 - mse: 0.2623 - val_loss: 0.9044 - val_mse: 0.9044
# Epoch 201/1000
# 4/4 [==============================] - 0s 25ms/step - loss: 0.2650 - mse: 0.2650 - val_loss: 0.9005 - val_mse: 0.9005
# Epoch 202/1000
# 4/4 [==============================] - 0s 31ms/step - loss: 0.2686 - mse: 0.2686 - val_loss: 0.9043 - val_mse: 0.9043
# Epoch 203/1000
# 4/4 [==============================] - 0s 26ms/step - loss: 0.2616 - mse: 0.2616 - val_loss: 0.9181 - val_mse: 0.9181
# Epoch 204/1000
# 4/4 [==============================] - 0s 25ms/step - loss: 0.2585 - mse: 0.2585 - val_loss: 0.9240 - val_mse: 0.9240
# Epoch 205/1000
# 4/4 [==============================] - 0s 31ms/step - loss: 0.2559 - mse: 0.2559 - val_loss: 0.9200 - val_mse: 0.9200
# Epoch 206/1000
# 4/4 [==============================] - 0s 27ms/step - loss: 0.2700 - mse: 0.2700 - val_loss: 0.9508 - val_mse: 0.9508
# Epoch 207/1000
# 4/4 [==============================] - 0s 25ms/step - loss: 0.2591 - mse: 0.2591 - val_loss: 0.9704 - val_mse: 0.9704
# Epoch 208/1000
# 4/4 [==============================] - 0s 27ms/step - loss: 0.2577 - mse: 0.2577 - val_loss: 0.9625 - val_mse: 0.9625
# Epoch 209/1000
# 4/4 [==============================] - 0s 44ms/step - loss: 0.2889 - mse: 0.2889 - val_loss: 0.9504 - val_mse: 0.9504
# Epoch 210/1000
# 4/4 [==============================] - 0s 26ms/step - loss: 0.2797 - mse: 0.2797 - val_loss: 0.9080 - val_mse: 0.9080
# Epoch 211/1000
# 4/4 [==============================] - 0s 25ms/step - loss: 0.2706 - mse: 0.2706 - val_loss: 0.8862 - val_mse: 0.8862
# Epoch 212/1000
# 4/4 [==============================] - 0s 30ms/step - loss: 0.2653 - mse: 0.2653 - val_loss: 0.9182 - val_mse: 0.9182
# Epoch 213/1000
# 4/4 [==============================] - 0s 32ms/step - loss: 0.2820 - mse: 0.2820 - val_loss: 0.9150 - val_mse: 0.9150
# Epoch 214/1000
# 4/4 [==============================] - 0s 34ms/step - loss: 0.3024 - mse: 0.3024 - val_loss: 0.8864 - val_mse: 0.8864
# Epoch 215/1000
# 4/4 [==============================] - 0s 27ms/step - loss: 0.3478 - mse: 0.3478 - val_loss: 0.9259 - val_mse: 0.9259
# Epoch 216/1000
# 4/4 [==============================] - 0s 30ms/step - loss: 0.3140 - mse: 0.3140 - val_loss: 0.9575 - val_mse: 0.9575
# Epoch 217/1000
# 4/4 [==============================] - 0s 32ms/step - loss: 0.3250 - mse: 0.3250 - val_loss: 0.9477 - val_mse: 0.9477
# Epoch 218/1000
# 4/4 [==============================] - 0s 33ms/step - loss: 0.2842 - mse: 0.2842 - val_loss: 0.9375 - val_mse: 0.9375
# Epoch 219/1000
# 4/4 [==============================] - 0s 30ms/step - loss: 0.2720 - mse: 0.2720 - val_loss: 0.9312 - val_mse: 0.9312
# Epoch 220/1000
# 4/4 [==============================] - 0s 31ms/step - loss: 0.2610 - mse: 0.2610 - val_loss: 0.9247 - val_mse: 0.9247
# Epoch 221/1000
# 4/4 [==============================] - 0s 32ms/step - loss: 0.2588 - mse: 0.2588 - val_loss: 0.9117 - val_mse: 0.9117
# Epoch 222/1000
# 4/4 [==============================] - 0s 25ms/step - loss: 0.2512 - mse: 0.2512 - val_loss: 0.9176 - val_mse: 0.9176
# Epoch 223/1000
# 4/4 [==============================] - 0s 26ms/step - loss: 0.2465 - mse: 0.2465 - val_loss: 0.9427 - val_mse: 0.9427
# Epoch 224/1000
# 4/4 [==============================] - 0s 26ms/step - loss: 0.2476 - mse: 0.2476 - val_loss: 0.9499 - val_mse: 0.9499
# Epoch 225/1000
# 4/4 [==============================] - 0s 25ms/step - loss: 0.2449 - mse: 0.2449 - val_loss: 0.9221 - val_mse: 0.9221
# Epoch 226/1000
# 4/4 [==============================] - 0s 27ms/step - loss: 0.2361 - mse: 0.2361 - val_loss: 0.9078 - val_mse: 0.9078
# Epoch 227/1000
# 4/4 [==============================] - 0s 32ms/step - loss: 0.2350 - mse: 0.2350 - val_loss: 0.9082 - val_mse: 0.9082
# Epoch 228/1000
# 4/4 [==============================] - 0s 31ms/step - loss: 0.2464 - mse: 0.2464 - val_loss: 0.9135 - val_mse: 0.9135
# Epoch 229/1000
# 4/4 [==============================] - 0s 26ms/step - loss: 0.2378 - mse: 0.2378 - val_loss: 0.9203 - val_mse: 0.9203
# Epoch 230/1000
# 4/4 [==============================] - 0s 25ms/step - loss: 0.2511 - mse: 0.2511 - val_loss: 0.9237 - val_mse: 0.9237
# Epoch 231/1000
# 4/4 [==============================] - 0s 27ms/step - loss: 0.2390 - mse: 0.2390 - val_loss: 0.9458 - val_mse: 0.9458
# Epoch 232/1000
# 4/4 [==============================] - 0s 27ms/step - loss: 0.2469 - mse: 0.2469 - val_loss: 0.9387 - val_mse: 0.9387
# Epoch 233/1000
# 4/4 [==============================] - 0s 35ms/step - loss: 0.2341 - mse: 0.2341 - val_loss: 0.9031 - val_mse: 0.9031
# Epoch 234/1000
# 4/4 [==============================] - 0s 26ms/step - loss: 0.2367 - mse: 0.2367 - val_loss: 0.9110 - val_mse: 0.9110
# Epoch 235/1000
# 4/4 [==============================] - 0s 28ms/step - loss: 0.2416 - mse: 0.2416 - val_loss: 0.9220 - val_mse: 0.9220
# Epoch 236/1000
# 4/4 [==============================] - 0s 27ms/step - loss: 0.2381 - mse: 0.2381 - val_loss: 0.9515 - val_mse: 0.9515
# Epoch 237/1000
# 4/4 [==============================] - 0s 25ms/step - loss: 0.2339 - mse: 0.2339 - val_loss: 0.9918 - val_mse: 0.9918
# Epoch 238/1000
# 4/4 [==============================] - 0s 27ms/step - loss: 0.2408 - mse: 0.2408 - val_loss: 0.9959 - val_mse: 0.9959
# Epoch 239/1000
# 4/4 [==============================] - 0s 37ms/step - loss: 0.2366 - mse: 0.2366 - val_loss: 0.9864 - val_mse: 0.9864
# Epoch 240/1000
# 4/4 [==============================] - 0s 61ms/step - loss: 0.2314 - mse: 0.2314 - val_loss: 0.9772 - val_mse: 0.9772
# Epoch 241/1000
# 4/4 [==============================] - 0s 27ms/step - loss: 0.2283 - mse: 0.2283 - val_loss: 0.9785 - val_mse: 0.9785
# Epoch 242/1000
# 4/4 [==============================] - 0s 34ms/step - loss: 0.2302 - mse: 0.2302 - val_loss: 0.9690 - val_mse: 0.9690
# Epoch 243/1000
# 4/4 [==============================] - 0s 26ms/step - loss: 0.2292 - mse: 0.2292 - val_loss: 0.9650 - val_mse: 0.9650
# Epoch 244/1000
# 4/4 [==============================] - 0s 25ms/step - loss: 0.2286 - mse: 0.2286 - val_loss: 0.9627 - val_mse: 0.9627
# Epoch 245/1000
# 4/4 [==============================] - 0s 39ms/step - loss: 0.2309 - mse: 0.2309 - val_loss: 0.9558 - val_mse: 0.9558
# Epoch 246/1000
# 4/4 [==============================] - 0s 45ms/step - loss: 0.2383 - mse: 0.2383 - val_loss: 0.9712 - val_mse: 0.9712
# Epoch 247/1000
# 4/4 [==============================] - 0s 32ms/step - loss: 0.2319 - mse: 0.2319 - val_loss: 0.9946 - val_mse: 0.9946
# Epoch 248/1000
# 4/4 [==============================] - 0s 27ms/step - loss: 0.2315 - mse: 0.2315 - val_loss: 0.9932 - val_mse: 0.9932
# Epoch 249/1000
# 4/4 [==============================] - 0s 27ms/step - loss: 0.2288 - mse: 0.2288 - val_loss: 0.9867 - val_mse: 0.9867
# Epoch 250/1000
# 4/4 [==============================] - 0s 35ms/step - loss: 0.2282 - mse: 0.2282 - val_loss: 0.9886 - val_mse: 0.9886
# Epoch 251/1000
# 4/4 [==============================] - 0s 26ms/step - loss: 0.2277 - mse: 0.2277 - val_loss: 0.9943 - val_mse: 0.9943
# Epoch 252/1000
# 4/4 [==============================] - 0s 35ms/step - loss: 0.2246 - mse: 0.2246 - val_loss: 0.9788 - val_mse: 0.9788
# Epoch 253/1000
# 4/4 [==============================] - 0s 26ms/step - loss: 0.2333 - mse: 0.2333 - val_loss: 0.9550 - val_mse: 0.9550
# Epoch 254/1000
# 4/4 [==============================] - 0s 25ms/step - loss: 0.2257 - mse: 0.2257 - val_loss: 0.9489 - val_mse: 0.9489
# Epoch 255/1000
# 4/4 [==============================] - 0s 25ms/step - loss: 0.2258 - mse: 0.2258 - val_loss: 0.9515 - val_mse: 0.9515
# Epoch 256/1000
# 4/4 [==============================] - 0s 25ms/step - loss: 0.2288 - mse: 0.2288 - val_loss: 0.9618 - val_mse: 0.9618
# Epoch 257/1000
# 4/4 [==============================] - 0s 35ms/step - loss: 0.2240 - mse: 0.2240 - val_loss: 0.9672 - val_mse: 0.9672
# Epoch 258/1000
# 4/4 [==============================] - 0s 26ms/step - loss: 0.2247 - mse: 0.2247 - val_loss: 0.9639 - val_mse: 0.9639
# Epoch 259/1000
# 4/4 [==============================] - 0s 39ms/step - loss: 0.2256 - mse: 0.2256 - val_loss: 0.9522 - val_mse: 0.9522
# Epoch 260/1000
# 4/4 [==============================] - 0s 35ms/step - loss: 0.2256 - mse: 0.2256 - val_loss: 0.9410 - val_mse: 0.9410
# Epoch 261/1000
# 4/4 [==============================] - 0s 32ms/step - loss: 0.2242 - mse: 0.2242 - val_loss: 0.9375 - val_mse: 0.9375
# Epoch 262/1000
# 4/4 [==============================] - 0s 32ms/step - loss: 0.2245 - mse: 0.2245 - val_loss: 0.9341 - val_mse: 0.9341
# Epoch 263/1000
# 4/4 [==============================] - 0s 34ms/step - loss: 0.2249 - mse: 0.2249 - val_loss: 0.9305 - val_mse: 0.9305
# Epoch 264/1000
# 4/4 [==============================] - 0s 30ms/step - loss: 0.2228 - mse: 0.2228 - val_loss: 0.9317 - val_mse: 0.9317
# Epoch 265/1000
# 4/4 [==============================] - 0s 28ms/step - loss: 0.2248 - mse: 0.2248 - val_loss: 0.9329 - val_mse: 0.9329
# Epoch 266/1000
# 4/4 [==============================] - 0s 35ms/step - loss: 0.2254 - mse: 0.2254 - val_loss: 0.9372 - val_mse: 0.9372
# Epoch 267/1000
# 4/4 [==============================] - 0s 44ms/step - loss: 0.2240 - mse: 0.2240 - val_loss: 0.9430 - val_mse: 0.9430
# Epoch 268/1000
# 4/4 [==============================] - 0s 25ms/step - loss: 0.2230 - mse: 0.2230 - val_loss: 0.9439 - val_mse: 0.9439
# Epoch 269/1000
# 4/4 [==============================] - 0s 30ms/step - loss: 0.2231 - mse: 0.2231 - val_loss: 0.9399 - val_mse: 0.9399
# Epoch 270/1000
# 4/4 [==============================] - 0s 25ms/step - loss: 0.2240 - mse: 0.2240 - val_loss: 0.9340 - val_mse: 0.9340
# Epoch 271/1000
# 4/4 [==============================] - 0s 25ms/step - loss: 0.2253 - mse: 0.2253 - val_loss: 0.9246 - val_mse: 0.9246
# Epoch 272/1000
# 4/4 [==============================] - 0s 26ms/step - loss: 0.2283 - mse: 0.2283 - val_loss: 0.9275 - val_mse: 0.9275
# Epoch 273/1000
# 4/4 [==============================] - 0s 26ms/step - loss: 0.2353 - mse: 0.2353 - val_loss: 0.9271 - val_mse: 0.9271
# Epoch 274/1000
# 4/4 [==============================] - 0s 25ms/step - loss: 0.2298 - mse: 0.2298 - val_loss: 0.9443 - val_mse: 0.9443
# Epoch 275/1000
# 4/4 [==============================] - 0s 25ms/step - loss: 0.2251 - mse: 0.2251 - val_loss: 0.9692 - val_mse: 0.9692
# Epoch 276/1000
# 4/4 [==============================] - 0s 25ms/step - loss: 0.2260 - mse: 0.2260 - val_loss: 0.9669 - val_mse: 0.9669
# Epoch 277/1000
# 4/4 [==============================] - 0s 26ms/step - loss: 0.2234 - mse: 0.2234 - val_loss: 0.9674 - val_mse: 0.9674
# Epoch 278/1000
# 4/4 [==============================] - 0s 25ms/step - loss: 0.2253 - mse: 0.2253 - val_loss: 0.9607 - val_mse: 0.9607
# Epoch 279/1000
# 4/4 [==============================] - 0s 26ms/step - loss: 0.2256 - mse: 0.2256 - val_loss: 0.9514 - val_mse: 0.9514
# Epoch 280/1000
# 4/4 [==============================] - 0s 25ms/step - loss: 0.2402 - mse: 0.2402 - val_loss: 0.9332 - val_mse: 0.9332
# Epoch 281/1000
# 4/4 [==============================] - 0s 26ms/step - loss: 0.2256 - mse: 0.2256 - val_loss: 0.9218 - val_mse: 0.9218
# Epoch 282/1000
# 4/4 [==============================] - 0s 26ms/step - loss: 0.2283 - mse: 0.2283 - val_loss: 0.9138 - val_mse: 0.9138
# Epoch 283/1000
# 4/4 [==============================] - 0s 26ms/step - loss: 0.2271 - mse: 0.2271 - val_loss: 0.9197 - val_mse: 0.9197
# Epoch 284/1000
# 4/4 [==============================] - 0s 26ms/step - loss: 0.2256 - mse: 0.2256 - val_loss: 0.9277 - val_mse: 0.9277
# Epoch 285/1000
# 4/4 [==============================] - 0s 25ms/step - loss: 0.2231 - mse: 0.2231 - val_loss: 0.9369 - val_mse: 0.9369
# Epoch 286/1000
# 4/4 [==============================] - 0s 30ms/step - loss: 0.2246 - mse: 0.2246 - val_loss: 0.9449 - val_mse: 0.9449
# Epoch 287/1000
# 4/4 [==============================] - 0s 64ms/step - loss: 0.2245 - mse: 0.2245 - val_loss: 0.9501 - val_mse: 0.9501
# Epoch 288/1000
# 4/4 [==============================] - 0s 35ms/step - loss: 0.2244 - mse: 0.2244 - val_loss: 0.9575 - val_mse: 0.9575
# Epoch 289/1000
# 4/4 [==============================] - 0s 32ms/step - loss: 0.2230 - mse: 0.2230 - val_loss: 0.9619 - val_mse: 0.9619
# Epoch 290/1000
# 4/4 [==============================] - 0s 25ms/step - loss: 0.2239 - mse: 0.2239 - val_loss: 0.9585 - val_mse: 0.9585
# Epoch 291/1000
# 4/4 [==============================] - 0s 25ms/step - loss: 0.2222 - mse: 0.2222 - val_loss: 0.9548 - val_mse: 0.9548
# Epoch 292/1000
# 4/4 [==============================] - 0s 31ms/step - loss: 0.2234 - mse: 0.2234 - val_loss: 0.9529 - val_mse: 0.9529
# Epoch 293/1000
# 4/4 [==============================] - 0s 32ms/step - loss: 0.2240 - mse: 0.2240 - val_loss: 0.9545 - val_mse: 0.9545
# Epoch 294/1000
# 4/4 [==============================] - 0s 25ms/step - loss: 0.2233 - mse: 0.2233 - val_loss: 0.9617 - val_mse: 0.9617
# Epoch 295/1000
# 4/4 [==============================] - 0s 24ms/step - loss: 0.2240 - mse: 0.2240 - val_loss: 0.9624 - val_mse: 0.9624
# Epoch 296/1000
# 4/4 [==============================] - 0s 25ms/step - loss: 0.2248 - mse: 0.2248 - val_loss: 0.9587 - val_mse: 0.9587
# Epoch 297/1000
# 4/4 [==============================] - 0s 26ms/step - loss: 0.2214 - mse: 0.2214 - val_loss: 0.9523 - val_mse: 0.9523
# Epoch 298/1000
# 4/4 [==============================] - 0s 30ms/step - loss: 0.2221 - mse: 0.2221 - val_loss: 0.9455 - val_mse: 0.9455
# Epoch 299/1000
# 4/4 [==============================] - 0s 33ms/step - loss: 0.2232 - mse: 0.2232 - val_loss: 0.9317 - val_mse: 0.9317
# Epoch 300/1000
# 4/4 [==============================] - 0s 46ms/step - loss: 0.2212 - mse: 0.2212 - val_loss: 0.9135 - val_mse: 0.9135
# Epoch 301/1000
# 4/4 [==============================] - 0s 29ms/step - loss: 0.2235 - mse: 0.2235 - val_loss: 0.9076 - val_mse: 0.9076
# Epoch 302/1000
# 4/4 [==============================] - 0s 43ms/step - loss: 0.2219 - mse: 0.2219 - val_loss: 0.9462 - val_mse: 0.9462
# Epoch 303/1000
# 4/4 [==============================] - 0s 30ms/step - loss: 0.2455 - mse: 0.2455 - val_loss: 0.9460 - val_mse: 0.9460
# Epoch 304/1000
# 4/4 [==============================] - 0s 34ms/step - loss: 0.2360 - mse: 0.2360 - val_loss: 0.9300 - val_mse: 0.9300
# Epoch 305/1000
# 4/4 [==============================] - 0s 31ms/step - loss: 0.2354 - mse: 0.2354 - val_loss: 0.9394 - val_mse: 0.9394
# Epoch 306/1000
# 4/4 [==============================] - 0s 36ms/step - loss: 0.2323 - mse: 0.2323 - val_loss: 0.9551 - val_mse: 0.9551
# Epoch 307/1000
# 4/4 [==============================] - 0s 33ms/step - loss: 0.2328 - mse: 0.2328 - val_loss: 0.9514 - val_mse: 0.9514
# Epoch 308/1000
# 4/4 [==============================] - 0s 33ms/step - loss: 0.2313 - mse: 0.2313 - val_loss: 0.9403 - val_mse: 0.9403
# Epoch 309/1000
# 4/4 [==============================] - 0s 26ms/step - loss: 0.2310 - mse: 0.2310 - val_loss: 0.9373 - val_mse: 0.9373
# Epoch 310/1000
# 4/4 [==============================] - 0s 25ms/step - loss: 0.2317 - mse: 0.2317 - val_loss: 0.9373 - val_mse: 0.9373
# Epoch 311/1000
# 4/4 [==============================] - 0s 25ms/step - loss: 0.2269 - mse: 0.2269 - val_loss: 0.9363 - val_mse: 0.9363
# Epoch 312/1000
# 4/4 [==============================] - 0s 32ms/step - loss: 0.2225 - mse: 0.2225 - val_loss: 0.9383 - val_mse: 0.9383
# Epoch 313/1000
# 4/4 [==============================] - 0s 25ms/step - loss: 0.2223 - mse: 0.2223 - val_loss: 0.9484 - val_mse: 0.9484
# Epoch 314/1000
# 4/4 [==============================] - 0s 65ms/step - loss: 0.2229 - mse: 0.2229 - val_loss: 0.9496 - val_mse: 0.9496
# Epoch 315/1000
# 4/4 [==============================] - 0s 29ms/step - loss: 0.2221 - mse: 0.2221 - val_loss: 0.9435 - val_mse: 0.9435
# Epoch 316/1000
# 4/4 [==============================] - 0s 24ms/step - loss: 0.2322 - mse: 0.2322 - val_loss: 0.9286 - val_mse: 0.9286
# Epoch 317/1000
# 4/4 [==============================] - 0s 30ms/step - loss: 0.2295 - mse: 0.2295 - val_loss: 0.9316 - val_mse: 0.9316
# Epoch 318/1000
# 4/4 [==============================] - 0s 25ms/step - loss: 0.2228 - mse: 0.2228 - val_loss: 0.9338 - val_mse: 0.9338
# Epoch 319/1000
# 4/4 [==============================] - 0s 30ms/step - loss: 0.2229 - mse: 0.2229 - val_loss: 0.9330 - val_mse: 0.9330
# Epoch 320/1000
# 4/4 [==============================] - 0s 35ms/step - loss: 0.2251 - mse: 0.2251 - val_loss: 0.9529 - val_mse: 0.9529
# Epoch 321/1000
# 4/4 [==============================] - 0s 37ms/step - loss: 0.2227 - mse: 0.2227 - val_loss: 0.9733 - val_mse: 0.9733
# Epoch 322/1000
# 4/4 [==============================] - 0s 26ms/step - loss: 0.2220 - mse: 0.2220 - val_loss: 0.9835 - val_mse: 0.9835
# Epoch 323/1000
# 4/4 [==============================] - 0s 26ms/step - loss: 0.2220 - mse: 0.2220 - val_loss: 0.9697 - val_mse: 0.9697
# Epoch 324/1000
# 4/4 [==============================] - 0s 25ms/step - loss: 0.2210 - mse: 0.2210 - val_loss: 0.9305 - val_mse: 0.9305
# Epoch 325/1000
# 4/4 [==============================] - 0s 26ms/step - loss: 0.2223 - mse: 0.2223 - val_loss: 0.9203 - val_mse: 0.9203
# Epoch 326/1000
# 4/4 [==============================] - 0s 27ms/step - loss: 0.2214 - mse: 0.2214 - val_loss: 0.9263 - val_mse: 0.9263
# Epoch 327/1000
# 4/4 [==============================] - 0s 31ms/step - loss: 0.2210 - mse: 0.2210 - val_loss: 0.9434 - val_mse: 0.9434
# Epoch 328/1000
# 4/4 [==============================] - 0s 25ms/step - loss: 0.2206 - mse: 0.2206 - val_loss: 0.9583 - val_mse: 0.9583
# Epoch 329/1000
# 4/4 [==============================] - 0s 26ms/step - loss: 0.2207 - mse: 0.2207 - val_loss: 0.9735 - val_mse: 0.9735
# Epoch 330/1000
# 4/4 [==============================] - 0s 25ms/step - loss: 0.2211 - mse: 0.2211 - val_loss: 0.9794 - val_mse: 0.9794
# Epoch 331/1000
# 4/4 [==============================] - 0s 26ms/step - loss: 0.2210 - mse: 0.2210 - val_loss: 0.9740 - val_mse: 0.9740
# Epoch 332/1000
# 4/4 [==============================] - 0s 28ms/step - loss: 0.2210 - mse: 0.2210 - val_loss: 0.9670 - val_mse: 0.9670
# Epoch 333/1000
# 4/4 [==============================] - 0s 35ms/step - loss: 0.2207 - mse: 0.2207 - val_loss: 0.9626 - val_mse: 0.9626
# Epoch 334/1000
# 4/4 [==============================] - 0s 31ms/step - loss: 0.2206 - mse: 0.2206 - val_loss: 0.9587 - val_mse: 0.9587
# Epoch 335/1000
# 4/4 [==============================] - 0s 36ms/step - loss: 0.2210 - mse: 0.2210 - val_loss: 0.9552 - val_mse: 0.9552
# Epoch 336/1000
# 4/4 [==============================] - 0s 35ms/step - loss: 0.2208 - mse: 0.2208 - val_loss: 0.9515 - val_mse: 0.9515
# Epoch 337/1000
# 4/4 [==============================] - 0s 25ms/step - loss: 0.2217 - mse: 0.2217 - val_loss: 0.9480 - val_mse: 0.9480
# Epoch 338/1000
# 4/4 [==============================] - 0s 29ms/step - loss: 0.2202 - mse: 0.2202 - val_loss: 0.9459 - val_mse: 0.9459
# Epoch 339/1000
# 4/4 [==============================] - 0s 35ms/step - loss: 0.2201 - mse: 0.2201 - val_loss: 0.9437 - val_mse: 0.9437
# Epoch 340/1000
# 4/4 [==============================] - 0s 75ms/step - loss: 0.2207 - mse: 0.2207 - val_loss: 0.9433 - val_mse: 0.9433
# Epoch 341/1000
# 4/4 [==============================] - 0s 45ms/step - loss: 0.2203 - mse: 0.2203 - val_loss: 0.9435 - val_mse: 0.9435
# Epoch 342/1000
# 4/4 [==============================] - 0s 34ms/step - loss: 0.2207 - mse: 0.2207 - val_loss: 0.9474 - val_mse: 0.9474
# Epoch 343/1000
# 4/4 [==============================] - 0s 30ms/step - loss: 0.2204 - mse: 0.2204 - val_loss: 0.9535 - val_mse: 0.9535
# Epoch 344/1000
# 4/4 [==============================] - 0s 26ms/step - loss: 0.2206 - mse: 0.2206 - val_loss: 0.9553 - val_mse: 0.9553
# Epoch 345/1000
# 4/4 [==============================] - 0s 25ms/step - loss: 0.2207 - mse: 0.2207 - val_loss: 0.9429 - val_mse: 0.9429
# Epoch 346/1000
# 4/4 [==============================] - 0s 36ms/step - loss: 0.2210 - mse: 0.2210 - val_loss: 0.9351 - val_mse: 0.9351
# Epoch 347/1000
# 4/4 [==============================] - 0s 28ms/step - loss: 0.2211 - mse: 0.2211 - val_loss: 0.9337 - val_mse: 0.9337
# Epoch 348/1000
# 4/4 [==============================] - 0s 41ms/step - loss: 0.2205 - mse: 0.2205 - val_loss: 0.9318 - val_mse: 0.9318
# Epoch 349/1000
# 4/4 [==============================] - 0s 35ms/step - loss: 0.2204 - mse: 0.2204 - val_loss: 0.9316 - val_mse: 0.9316
# Epoch 350/1000
# 4/4 [==============================] - 0s 26ms/step - loss: 0.2204 - mse: 0.2204 - val_loss: 0.9328 - val_mse: 0.9328
# Epoch 351/1000
# 4/4 [==============================] - 0s 25ms/step - loss: 0.2201 - mse: 0.2201 - val_loss: 0.9356 - val_mse: 0.9356
# Epoch 352/1000
# ...
# 4/4 [==============================] - 0s 25ms/step - loss: 0.2193 - mse: 0.2193 - val_loss: 0.8917 - val_mse: 0.8917
# Epoch 587/1000
# 4/4 [==============================] - 0s 24ms/step - loss: 0.2194 - mse: 0.2194 - val_loss: 0.8942 - val_mse: 0.8942
# Epoch 588/1000
# 4/4 [==============================] - 0s 33ms/step - loss: 0.2193 - mse: 0.2193 - val_loss: 0.8962 - val_mse: 0.8962
# Epoch 589/1000
# 4/4 [==============================] - 0s 30ms/step - loss: 0.2193 - mse: 0.2193 - val_loss: 0.8971 - val_mse: 0.8971
# Epoch 590/1000
# 4/4 [==============================] - 0s 33ms/step - loss: 0.2193 - mse: 0.2193 - val_loss: 0.8963 - val_mse: 0.8963
# Epoch 591/1000
# 4/4 [==============================] - 0s 28ms/step - loss: 0.2193 - mse: 0.2193 - val_loss: 0.8958 - val_mse: 0.8958
# Epoch 592/1000
# 4/4 [==============================] - 0s 27ms/step - loss: 0.2193 - mse: 0.2193 - val_loss: 0.8966 - val_mse: 0.8966
# Epoch 593/1000
# 4/4 [==============================] - 0s 37ms/step - loss: 0.2194 - mse: 0.2194 - val_loss: 0.8974 - val_mse: 0.8974
# Epoch 594/1000
# 4/4 [==============================] - 0s 27ms/step - loss: 0.2193 - mse: 0.2193 - val_loss: 0.8966 - val_mse: 0.8966
# Epoch 595/1000
# 4/4 [==============================] - 0s 31ms/step - loss: 0.2193 - mse: 0.2193 - val_loss: 0.8948 - val_mse: 0.8948
# Epoch 596/1000
# 4/4 [==============================] - 0s 26ms/step - loss: 0.2193 - mse: 0.2193 - val_loss: 0.8928 - val_mse: 0.8928
# Epoch 597/1000
# 4/4 [==============================] - 0s 26ms/step - loss: 0.2192 - mse: 0.2192 - val_loss: 0.8923 - val_mse: 0.8923
# Epoch 598/1000
# 4/4 [==============================] - 0s 26ms/step - loss: 0.2193 - mse: 0.2193 - val_loss: 0.8945 - val_mse: 0.8945
# Epoch 599/1000
# 4/4 [==============================] - 0s 25ms/step - loss: 0.2194 - mse: 0.2194 - val_loss: 0.8963 - val_mse: 0.8963
# Epoch 600/1000
# 4/4 [==============================] - 0s 59ms/step - loss: 0.2193 - mse: 0.2193 - val_loss: 0.8966 - val_mse: 0.8966
# Epoch 601/1000
# 4/4 [==============================] - 0s 31ms/step - loss: 0.2193 - mse: 0.2193 - val_loss: 0.8963 - val_mse: 0.8963
# Epoch 602/1000
# 4/4 [==============================] - 0s 27ms/step - loss: 0.2193 - mse: 0.2193 - val_loss: 0.8964 - val_mse: 0.8964
# Epoch 603/1000
# 4/4 [==============================] - 0s 43ms/step - loss: 0.2192 - mse: 0.2192 - val_loss: 0.8959 - val_mse: 0.8959
# Epoch 604/1000
# 4/4 [==============================] - 0s 31ms/step - loss: 0.2192 - mse: 0.2192 - val_loss: 0.8955 - val_mse: 0.8955
# Epoch 605/1000
# 4/4 [==============================] - 0s 41ms/step - loss: 0.2193 - mse: 0.2193 - val_loss: 0.8937 - val_mse: 0.8937
# Epoch 606/1000
# 4/4 [==============================] - 0s 45ms/step - loss: 0.2192 - mse: 0.2192 - val_loss: 0.8920 - val_mse: 0.8920
# Epoch 607/1000
# 4/4 [==============================] - 0s 26ms/step - loss: 0.2194 - mse: 0.2194 - val_loss: 0.8902 - val_mse: 0.8902
# Epoch 608/1000
# 4/4 [==============================] - 0s 25ms/step - loss: 0.2193 - mse: 0.2193 - val_loss: 0.8895 - val_mse: 0.8895
# Epoch 609/1000
# 4/4 [==============================] - 0s 25ms/step - loss: 0.2192 - mse: 0.2192 - val_loss: 0.8896 - val_mse: 0.8896
# Epoch 610/1000
# 4/4 [==============================] - 0s 27ms/step - loss: 0.2192 - mse: 0.2192 - val_loss: 0.8908 - val_mse: 0.8908
# Epoch 611/1000
# 4/4 [==============================] - 0s 27ms/step - loss: 0.2192 - mse: 0.2192 - val_loss: 0.8918 - val_mse: 0.8918
# Epoch 612/1000
# 4/4 [==============================] - 0s 25ms/step - loss: 0.2192 - mse: 0.2192 - val_loss: 0.8929 - val_mse: 0.8929
# Epoch 613/1000
# 4/4 [==============================] - 0s 26ms/step - loss: 0.2193 - mse: 0.2193 - val_loss: 0.8919 - val_mse: 0.8919
# Epoch 614/1000
# 4/4 [==============================] - 0s 26ms/step - loss: 0.2192 - mse: 0.2192 - val_loss: 0.8885 - val_mse: 0.8885
# Epoch 615/1000
# 4/4 [==============================] - 0s 27ms/step - loss: 0.2192 - mse: 0.2192 - val_loss: 0.8878 - val_mse: 0.8878
# Epoch 616/1000
# 4/4 [==============================] - 0s 32ms/step - loss: 0.2192 - mse: 0.2192 - val_loss: 0.8877 - val_mse: 0.8877
# Epoch 617/1000
# 4/4 [==============================] - 0s 28ms/step - loss: 0.2192 - mse: 0.2192 - val_loss: 0.8878 - val_mse: 0.8878
# Epoch 618/1000
# 4/4 [==============================] - 0s 80ms/step - loss: 0.2193 - mse: 0.2193 - val_loss: 0.8880 - val_mse: 0.8880
# Epoch 619/1000
# 4/4 [==============================] - 0s 51ms/step - loss: 0.2192 - mse: 0.2192 - val_loss: 0.8882 - val_mse: 0.8882
# Epoch 620/1000
# 4/4 [==============================] - 0s 25ms/step - loss: 0.2192 - mse: 0.2192 - val_loss: 0.8880 - val_mse: 0.8880
# Epoch 621/1000
# 4/4 [==============================] - 0s 32ms/step - loss: 0.2193 - mse: 0.2193 - val_loss: 0.8873 - val_mse: 0.8873
# Epoch 622/1000
# 4/4 [==============================] - 0s 26ms/step - loss: 0.2192 - mse: 0.2192 - val_loss: 0.8881 - val_mse: 0.8881
# Epoch 623/1000
# 4/4 [==============================] - 0s 27ms/step - loss: 0.2192 - mse: 0.2192 - val_loss: 0.8894 - val_mse: 0.8894
# Epoch 624/1000
# 4/4 [==============================] - 0s 32ms/step - loss: 0.2193 - mse: 0.2193 - val_loss: 0.8921 - val_mse: 0.8921
# Epoch 625/1000
# 4/4 [==============================] - 0s 26ms/step - loss: 0.2193 - mse: 0.2193 - val_loss: 0.8938 - val_mse: 0.8938
# Epoch 626/1000
# 4/4 [==============================] - 0s 26ms/step - loss: 0.2192 - mse: 0.2192 - val_loss: 0.8941 - val_mse: 0.8941
# Epoch 627/1000
# 4/4 [==============================] - 0s 26ms/step - loss: 0.2193 - mse: 0.2193 - val_loss: 0.8951 - val_mse: 0.8951
# Epoch 628/1000
# 4/4 [==============================] - 0s 30ms/step - loss: 0.2192 - mse: 0.2192 - val_loss: 0.8954 - val_mse: 0.8954
# Epoch 629/1000
# 4/4 [==============================] - 0s 36ms/step - loss: 0.2192 - mse: 0.2192 - val_loss: 0.8949 - val_mse: 0.8949
# Epoch 630/1000
# 4/4 [==============================] - 0s 44ms/step - loss: 0.2192 - mse: 0.2192 - val_loss: 0.8943 - val_mse: 0.8943
# Epoch 631/1000
# 4/4 [==============================] - 0s 24ms/step - loss: 0.2192 - mse: 0.2192 - val_loss: 0.8954 - val_mse: 0.8954
# Epoch 632/1000
# 4/4 [==============================] - 0s 25ms/step - loss: 0.2192 - mse: 0.2192 - val_loss: 0.8959 - val_mse: 0.8959
# Epoch 633/1000
# 4/4 [==============================] - 0s 37ms/step - loss: 0.2192 - mse: 0.2192 - val_loss: 0.8961 - val_mse: 0.8961
# Epoch 634/1000
# 4/4 [==============================] - 0s 24ms/step - loss: 0.2192 - mse: 0.2192 - val_loss: 0.8969 - val_mse: 0.8969
# Epoch 635/1000
# 4/4 [==============================] - 0s 61ms/step - loss: 0.2192 - mse: 0.2192 - val_loss: 0.8972 - val_mse: 0.8972
# Epoch 636/1000
# 4/4 [==============================] - 0s 25ms/step - loss: 0.2191 - mse: 0.2191 - val_loss: 0.8969 - val_mse: 0.8969
# Epoch 637/1000
# 4/4 [==============================] - 0s 24ms/step - loss: 0.2192 - mse: 0.2192 - val_loss: 0.8957 - val_mse: 0.8957
# Epoch 638/1000
# 4/4 [==============================] - 0s 26ms/step - loss: 0.2192 - mse: 0.2192 - val_loss: 0.8943 - val_mse: 0.8943
# Epoch 639/1000
# 4/4 [==============================] - 0s 26ms/step - loss: 0.2192 - mse: 0.2192 - val_loss: 0.8940 - val_mse: 0.8940
# Epoch 640/1000
# 4/4 [==============================] - 0s 25ms/step - loss: 0.2192 - mse: 0.2192 - val_loss: 0.8934 - val_mse: 0.8934
# Epoch 641/1000
# 4/4 [==============================] - 0s 25ms/step - loss: 0.2191 - mse: 0.2191 - val_loss: 0.8937 - val_mse: 0.8937
# Epoch 642/1000
# 4/4 [==============================] - 0s 26ms/step - loss: 0.2191 - mse: 0.2191 - val_loss: 0.8939 - val_mse: 0.8939
# Epoch 643/1000
# 4/4 [==============================] - 0s 33ms/step - loss: 0.2192 - mse: 0.2192 - val_loss: 0.8939 - val_mse: 0.8939
# Epoch 644/1000
# 4/4 [==============================] - 0s 31ms/step - loss: 0.2192 - mse: 0.2192 - val_loss: 0.8945 - val_mse: 0.8945
# Epoch 645/1000
# 4/4 [==============================] - 0s 26ms/step - loss: 0.2190 - mse: 0.2190 - val_loss: 0.8970 - val_mse: 0.8970
# Epoch 646/1000
# 4/4 [==============================] - 0s 25ms/step - loss: 0.2191 - mse: 0.2191 - val_loss: 0.8967 - val_mse: 0.8967
# Epoch 647/1000
# 4/4 [==============================] - 0s 26ms/step - loss: 0.2192 - mse: 0.2192 - val_loss: 0.8943 - val_mse: 0.8943
# Epoch 648/1000
# 4/4 [==============================] - 0s 28ms/step - loss: 0.2192 - mse: 0.2192 - val_loss: 0.8939 - val_mse: 0.8939
# Epoch 649/1000
# 4/4 [==============================] - 0s 45ms/step - loss: 0.2192 - mse: 0.2192 - val_loss: 0.8922 - val_mse: 0.8922
# Epoch 650/1000
# 4/4 [==============================] - 0s 33ms/step - loss: 0.2192 - mse: 0.2192 - val_loss: 0.8908 - val_mse: 0.8908
# Epoch 651/1000
# 4/4 [==============================] - 0s 26ms/step - loss: 0.2192 - mse: 0.2192 - val_loss: 0.8898 - val_mse: 0.8898
# Epoch 652/1000
# 4/4 [==============================] - 0s 25ms/step - loss: 0.2192 - mse: 0.2192 - val_loss: 0.8892 - val_mse: 0.8892
# Epoch 653/1000
# 4/4 [==============================] - 0s 63ms/step - loss: 0.2192 - mse: 0.2192 - val_loss: 0.8890 - val_mse: 0.8890
# Epoch 654/1000
# 4/4 [==============================] - 0s 26ms/step - loss: 0.2191 - mse: 0.2191 - val_loss: 0.8886 - val_mse: 0.8886
# Epoch 655/1000
# 4/4 [==============================] - 0s 27ms/step - loss: 0.2191 - mse: 0.2191 - val_loss: 0.8891 - val_mse: 0.8891
# Epoch 656/1000
# 4/4 [==============================] - 0s 33ms/step - loss: 0.2192 - mse: 0.2192 - val_loss: 0.8892 - val_mse: 0.8892
# Epoch 657/1000
# 4/4 [==============================] - 0s 32ms/step - loss: 0.2192 - mse: 0.2192 - val_loss: 0.8896 - val_mse: 0.8896
# Epoch 658/1000
# 4/4 [==============================] - 0s 25ms/step - loss: 0.2192 - mse: 0.2192 - val_loss: 0.8897 - val_mse: 0.8897
# Epoch 659/1000
# 4/4 [==============================] - 0s 26ms/step - loss: 0.2191 - mse: 0.2191 - val_loss: 0.8913 - val_mse: 0.8913
# Epoch 660/1000
# 4/4 [==============================] - 0s 24ms/step - loss: 0.2192 - mse: 0.2192 - val_loss: 0.8937 - val_mse: 0.8937
# Epoch 661/1000
# 4/4 [==============================] - 0s 28ms/step - loss: 0.2192 - mse: 0.2192 - val_loss: 0.8970 - val_mse: 0.8970
# Epoch 662/1000
# 4/4 [==============================] - 0s 51ms/step - loss: 0.2192 - mse: 0.2192 - val_loss: 0.8973 - val_mse: 0.8973
# Epoch 663/1000
# 4/4 [==============================] - 0s 34ms/step - loss: 0.2191 - mse: 0.2191 - val_loss: 0.8966 - val_mse: 0.8966
# Epoch 664/1000
# 4/4 [==============================] - 0s 35ms/step - loss: 0.2191 - mse: 0.2191 - val_loss: 0.8950 - val_mse: 0.8950
# Epoch 665/1000
# 4/4 [==============================] - 0s 36ms/step - loss: 0.2192 - mse: 0.2192 - val_loss: 0.8931 - val_mse: 0.8931
# Epoch 666/1000
# 4/4 [==============================] - 0s 47ms/step - loss: 0.2192 - mse: 0.2192 - val_loss: 0.8927 - val_mse: 0.8927
# Epoch 667/1000
# 4/4 [==============================] - 0s 75ms/step - loss: 0.2192 - mse: 0.2192 - val_loss: 0.8946 - val_mse: 0.8946
# Epoch 668/1000
# 4/4 [==============================] - 0s 31ms/step - loss: 0.2192 - mse: 0.2192 - val_loss: 0.9035 - val_mse: 0.9035
# Epoch 669/1000
# 4/4 [==============================] - 0s 44ms/step - loss: 0.2193 - mse: 0.2193 - val_loss: 0.9052 - val_mse: 0.9052
# Epoch 670/1000
# 4/4 [==============================] - 0s 26ms/step - loss: 0.2192 - mse: 0.2192 - val_loss: 0.9030 - val_mse: 0.9030
# Epoch 671/1000
# 4/4 [==============================] - 0s 26ms/step - loss: 0.2192 - mse: 0.2192 - val_loss: 0.9002 - val_mse: 0.9002
# Epoch 672/1000
# 4/4 [==============================] - 0s 26ms/step - loss: 0.2192 - mse: 0.2192 - val_loss: 0.8977 - val_mse: 0.8977
# Epoch 673/1000
# 4/4 [==============================] - 0s 26ms/step - loss: 0.2191 - mse: 0.2191 - val_loss: 0.8959 - val_mse: 0.8959
# Epoch 674/1000
# 4/4 [==============================] - 0s 25ms/step - loss: 0.2191 - mse: 0.2191 - val_loss: 0.8950 - val_mse: 0.8950
# Epoch 675/1000
# 4/4 [==============================] - 0s 27ms/step - loss: 0.2192 - mse: 0.2192 - val_loss: 0.8952 - val_mse: 0.8952
# Epoch 676/1000
# 4/4 [==============================] - 0s 44ms/step - loss: 0.2190 - mse: 0.2190 - val_loss: 0.8961 - val_mse: 0.8961
# Epoch 677/1000
# 4/4 [==============================] - 0s 39ms/step - loss: 0.2192 - mse: 0.2192 - val_loss: 0.8957 - val_mse: 0.8957
# Epoch 678/1000
# 4/4 [==============================] - 0s 26ms/step - loss: 0.2190 - mse: 0.2190 - val_loss: 0.8958 - val_mse: 0.8958
# Epoch 679/1000
# 4/4 [==============================] - 0s 32ms/step - loss: 0.2191 - mse: 0.2191 - val_loss: 0.8964 - val_mse: 0.8964
# Epoch 680/1000
# 4/4 [==============================] - 0s 27ms/step - loss: 0.2191 - mse: 0.2191 - val_loss: 0.8971 - val_mse: 0.8971
# Epoch 681/1000
# 4/4 [==============================] - 0s 39ms/step - loss: 0.2191 - mse: 0.2191 - val_loss: 0.8984 - val_mse: 0.8984
# Epoch 682/1000
# 4/4 [==============================] - 0s 26ms/step - loss: 0.2191 - mse: 0.2191 - val_loss: 0.8996 - val_mse: 0.8996
# Epoch 683/1000
# 4/4 [==============================] - 0s 39ms/step - loss: 0.2190 - mse: 0.2190 - val_loss: 0.9010 - val_mse: 0.9010
# Epoch 684/1000
# 4/4 [==============================] - 0s 25ms/step - loss: 0.2190 - mse: 0.2190 - val_loss: 0.9024 - val_mse: 0.9024
# Epoch 685/1000
# 4/4 [==============================] - 0s 31ms/step - loss: 0.2189 - mse: 0.2189 - val_loss: 0.9033 - val_mse: 0.9033
# Epoch 686/1000
# 4/4 [==============================] - 0s 26ms/step - loss: 0.2185 - mse: 0.2185 - val_loss: 0.9136 - val_mse: 0.9136
# Epoch 687/1000
# 4/4 [==============================] - 0s 26ms/step - loss: 0.2180 - mse: 0.2180 - val_loss: 0.9414 - val_mse: 0.9414
# Epoch 688/1000
# 4/4 [==============================] - 0s 24ms/step - loss: 0.2170 - mse: 0.2170 - val_loss: 0.9421 - val_mse: 0.9421
# Epoch 689/1000
# 4/4 [==============================] - 0s 26ms/step - loss: 0.2239 - mse: 0.2239 - val_loss: 0.9434 - val_mse: 0.9434
# Epoch 690/1000
# 4/4 [==============================] - 0s 25ms/step - loss: 0.2198 - mse: 0.2198 - val_loss: 0.9405 - val_mse: 0.9405
# Epoch 691/1000
# 4/4 [==============================] - 0s 27ms/step - loss: 0.2180 - mse: 0.2180 - val_loss: 0.9474 - val_mse: 0.9474
# Epoch 692/1000
# 4/4 [==============================] - 0s 32ms/step - loss: 0.2199 - mse: 0.2199 - val_loss: 0.9105 - val_mse: 0.9105
# Epoch 693/1000
# 4/4 [==============================] - 0s 27ms/step - loss: 0.2183 - mse: 0.2183 - val_loss: 0.9224 - val_mse: 0.9224
# Epoch 694/1000
# 4/4 [==============================] - 0s 49ms/step - loss: 0.2162 - mse: 0.2162 - val_loss: 0.8984 - val_mse: 0.8984
# Epoch 695/1000
# 4/4 [==============================] - 0s 35ms/step - loss: 0.2156 - mse: 0.2156 - val_loss: 0.9103 - val_mse: 0.9103
# Epoch 696/1000
# 4/4 [==============================] - 0s 27ms/step - loss: 0.2160 - mse: 0.2160 - val_loss: 0.9198 - val_mse: 0.9198
# Epoch 697/1000
# 4/4 [==============================] - 0s 26ms/step - loss: 0.2190 - mse: 0.2190 - val_loss: 0.9029 - val_mse: 0.9029
# Epoch 698/1000
# 4/4 [==============================] - 0s 66ms/step - loss: 0.2145 - mse: 0.2145 - val_loss: 0.9050 - val_mse: 0.9050
# Epoch 699/1000
# 4/4 [==============================] - 0s 32ms/step - loss: 0.2172 - mse: 0.2172 - val_loss: 0.8978 - val_mse: 0.8978
# Epoch 700/1000
# 4/4 [==============================] - 0s 26ms/step - loss: 0.2155 - mse: 0.2155 - val_loss: 0.9243 - val_mse: 0.9243
# Epoch 701/1000
# 4/4 [==============================] - 0s 26ms/step - loss: 0.2283 - mse: 0.2283 - val_loss: 0.9212 - val_mse: 0.9212
# Epoch 702/1000
# 4/4 [==============================] - 0s 25ms/step - loss: 0.2288 - mse: 0.2288 - val_loss: 0.9813 - val_mse: 0.9813
# Epoch 703/1000
# 4/4 [==============================] - 0s 31ms/step - loss: 0.2452 - mse: 0.2452 - val_loss: 0.9195 - val_mse: 0.9195
# Epoch 704/1000
# 4/4 [==============================] - 0s 48ms/step - loss: 0.2852 - mse: 0.2852 - val_loss: 0.9523 - val_mse: 0.9523
# Epoch 705/1000
# 4/4 [==============================] - 0s 49ms/step - loss: 0.3115 - mse: 0.3115 - val_loss: 0.8601 - val_mse: 0.8601
# The difference in seconds is: 91.97436547279358

# %%
# import keras_tuner as kt
# import tensorflow as tf
# from tensorflow import keras
# from tensorflow.keras.layers import LSTM, Bidirectional, Dense, Dropout, Flatten

# def build_model(hp):
#     model = keras.Sequential()
    
#     model.add(LSTM(units=hp.Int('lstm_units', min_value=16, max_value=128, step=16),
#                    return_sequences=True,
#                      input_shape=(look_back, X_train.shape[2])))
    
#     # model.add(Dropout(hp.Float('dropout', min_value=0.0, max_value=0.5, step=0.1)))
    
#     # model.add(Bidirectional(LSTM(units=hp.Int('bidirectional_units', min_value=4, max_value=16, step=4),
#     #                              return_sequences=True)))
    
#     # model.add(Bidirectional(LSTM(units=hp.Int('bidirectional_units', min_value=4, max_value=32, step=4),
#     #                              return_sequences=True)))
    
#     model.add(Flatten())
    
#     model.add(Dropout(hp.Float('dropout', min_value=0.0, max_value=0.5, step=0.1)))
    
#     model.add(Dense(hp.Float('dense_units', min_value=0, max_value=32, step=8), activation='tanh'))
    
#     model.add(Dense(1, activation='tanh'))
    
#     model.compile(optimizer=keras.optimizers.Adam(hp.Choice('learning_rate', values=[1e-4, 1e-5])),
#                     loss='mse',
#                     metrics=[rmse, r_square])
    
#     return model

# %%
# import keras_tuner as kt
# import tensorflow as tf
# from tensorflow import keras
# from tensorflow.keras.layers import LSTM, Bidirectional, Dense, Dropout, Flatten, Attention, Input
# from tensorflow.keras.models import Model

# def build_model(hp):
#     inputs = Input(shape=(look_back, X_train.shape[2]))
    
#     lstm_out = LSTM(units=60,
#                     return_sequences=True)(inputs)

    
#     flatten = Flatten()(lstm_out)
    
#     dropout = Dropout(hp.Float('dropout', min_value=0.0, max_value=0.5, step=0.1))(flatten)
    
#     dense = Dense(hp.Int('dense_units', min_value=0, max_value=32, step=4), activation='tanh')(dropout)
    
#     output = Dense(1, activation='tanh')(dense)
    
#     model = Model(inputs=inputs, outputs=output)
    
#     model.compile(optimizer=keras.optimizers.Adam(hp.Choice('learning_rate', values=[1e-4, 1e-5])),
#                   loss='mse',
#                   metrics=[rmse, r_square])
    
#     return model

# %%
# tuner = kt.RandomSearch(build_model,
#                         objective=kt.Objective("val_r_square", direction="max"),
#                         max_trials=20,
#                         executions_per_trial=2,
#                         directory='my_dir',
#                         project_name='earthquake')

# %%
# tuner.search(X_train, Y_train, epochs=150, validation_data=(X_val, Y_val))

# %%
# from tensorflow.keras.callbacks import Callback, EarlyStopping
# best_hps = tuner.get_best_hyperparameters(num_trials=5)[0]

# # print(f"Best LSTM units: {best_hps.get('lstm_units')}")
# # print(f"Best BiLSTM usage: {best_hps.get('bidirectional_units')}")
# print(f"Best Dropout Rate: {best_hps.get('dropout')}")
# print(f"Best Dense Units: {best_hps.get('dense_units')}")
# print(f"Best Learning Rate: {best_hps.get('learning_rate')}")

# # Train the best model
# best_model = tuner.hypermodel.build(best_hps)
# early_stopping = EarlyStopping(monitor='val_loss', patience=700, restore_best_weights=True)
# history = best_model.fit(X_train, Y_train, epochs=1000, validation_data=(X_val, Y_val), callbacks=[early_stopping])

# %%
# # Generate predictions for the training set
# Y_train_pred = best_model.predict(X_train)

# # Plot the true values and predictions
# plt.figure(figsize=(10, 6))
# plt.plot(Y_train, label='True Values', color='blue',  marker='o')
# plt.plot(Y_train_pred, label='Predictions', color='red', linestyle='dashed', marker='o')
# plt.title('Training True Values vs Predictions')
# plt.xlabel('Sample Index')
# plt.ylabel('Value')
# plt.legend()
# plt.show()

# %%
# # Generate predictions for the validation set
# Y_val_pred = best_model.predict(X_val)

# # Plot the true values and predictions
# plt.figure(figsize=(10, 6))
# plt.plot(Y_val, label='True Values', color='blue', marker='o')
# plt.plot(Y_val_pred, label='Predictions', color='red', linestyle='dashed', marker='o')
# plt.title('Validation True Values vs Predictions')
# plt.xlabel('Sample Index')
# plt.ylabel('Value')
# plt.legend()
# plt.show()

# %%
# # Generate predictions for the validation set
# Y_val_pred = best_model.predict(X_val)
# Y_val_pred = np.where(Y_val_pred > 0.5, 1,np.where(Y_val_pred<-0.5, -1, 0) )

# # Plot the true values and predictions
# plt.figure(figsize=(10, 6))
# plt.plot(Y_val, label='True Values', color='blue', marker='o')
# plt.plot(Y_val_pred, label='Predictions', color='red', linestyle='dashed', marker='o')
# plt.title('Validation True Values vs Predictions')
# plt.xlabel('Sample Index')
# plt.ylabel('Value')
# plt.legend()
# plt.show()

# %%
# from sklearn.metrics import confusion_matrix

# # Create confusion matrix
# conf_matrix = confusion_matrix(Y_val.flatten(), Y_val_pred.flatten())

# # Print the confusion matrix
# print("Confusion Matrix:")
# print(conf_matrix)

# %%
# # Calculate total accuracy
# total_accuracy = np.sum(Y_val.flatten() == Y_val_pred.flatten()) / len(Y_val)
# print(f"Total Accuracy: {total_accuracy * 100:.2f}%")

# %%
# Create a mask to filter out values in Y_test that are not equal to 0
mask = Y_val != 0
# print(X_test.shape)
# Apply the mask to filter X_test and Y_test
X_test_filtered = np.array([x for x, m in zip(X_val, mask) if m])
Y_test_filtered = Y_val[mask]

# Print the shapes of the filtered arrays to verify
print(X_test_filtered.shape)
print(Y_test_filtered.shape)
# Out:
# (31, 10, 7)
# (31,)

# %%
# # Generate predictions for the validation set
# Y_val_pred = best_model.predict(X_test_filtered)
# Y_val_pred = np.where(Y_val_pred > 0.15, 1, -1)

# # Plot the true values and predictions
# plt.figure(figsize=(10, 6))
# plt.plot(Y_test_filtered, label='True Values', color='blue', marker='o')
# plt.plot(Y_val_pred, label='Predictions', color='red', linestyle='dashed', marker='o')
# plt.title('Validation True Values vs Predictions')
# plt.xlabel('Sample Index')
# plt.ylabel('Value')
# plt.legend()
# plt.show()

# %%
# from sklearn.metrics import confusion_matrix

# # Create confusion matrix
# conf_matrix = confusion_matrix(Y_test_filtered.flatten(), Y_val_pred.flatten())

# # Print the confusion matrix
# print("Confusion Matrix:")
# print(conf_matrix)

# %%
# # Calculate total accuracy
# total_accuracy = np.sum(Y_test_filtered.flatten() == Y_val_pred.flatten()) / len(Y_test_filtered)
# print(f"Total Accuracy: {total_accuracy * 100:.2f}%")

# %%
# import tensorflow as tf
# from tensorflow.keras.layers import *
# from tensorflow.keras.models import Model
# from tensorflow.keras.layers import Input, LSTM, Dense, Layer, Dropout

# from tensorflow.keras.optimizers.legacy import Adam

# from tensorflow.keras.regularizers import L1L2
# from tensorflow.keras.layers import Layer, Dense, Dot, Activation

# from tensorflow.keras.callbacks import Callback, EarlyStopping

# from tensorflow.keras import backend as K

# from matplotlib import pyplot as plt

# K.clear_session()

   
# l1 = 0.0
# l2 = 0.0

# lstm_dropout = 0.0
# recurrent_dropout = 0.0
# dense_dropout = 0.1
# loss = 'mse'

# n_target = Y_train.shape[-2:]

# regularization_criteria = L1L2(l1=l1, l2=l2)

# n_target_y = Y_train.shape[-1]

# def build_model(input_shape):
#     input_layer = Input(shape=input_shape, name='Input_1')
#     sequence = input_layer
#     sequence = LSTM(60, return_sequences = True,  name="LSTM-1", kernel_regularizer = regularization_criteria, dropout=lstm_dropout, recurrent_dropout=recurrent_dropout)(input_layer)
    
#     sequence = Flatten()(sequence)
#     sequence = Dropout(0.2)(sequence)
#     # sequence = LSTM(16, return_sequences = False,  name="LSTM-2", kernel_regularizer = regularization_criteria, dropout=lstm_dropout, recurrent_dropout=recurrent_dropout)(sequence)
#     sequence = Dense(12, activation = 'tanh', name='Dense_3')(sequence)
#     sequence = Dense(n_target_y, activation = 'tanh', name='Dense_4')(sequence)
#     output_layer = sequence

#     model = Model(inputs=input_layer, outputs=output_layer)

#     return model

# input_shape = (look_back, X_train.shape[2])

# learning_rate = 0.0001

# optimizer = Adam(learning_rate=learning_rate)

# model = build_model(input_shape)
# model.compile(optimizer=optimizer, loss=loss, metrics=[mse, rmse, r_square])
# model.summary()

# import time

# start_time = time.time()

# early_stopping = EarlyStopping(monitor='val_loss', patience=700, restore_best_weights=True)

# history = model.fit(X_train, Y_train, epochs=1000, batch_size=64, validation_data=(X_val, Y_val),
#                     callbacks=[early_stopping]
#                     )

# end_time = time.time()
# difference_in_seconds = end_time - start_time
# print(f"The difference in seconds is: {difference_in_seconds}")

# %%
# Extract the metrics from the history object
loss = history.history['loss']
val_loss = history.history['val_loss']
# r_square = history.history['r_square']
# val_r_square = history.history['val_r_square']

# Plot loss and val_loss
plt.figure(figsize=(12, 6))
plt.plot(loss, label='Training Loss', color='blue')
plt.plot(val_loss, label='Validation Loss', color='orange')
plt.title('Training Loss vs Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.grid()
plt.show()

# Plot r_square and val_r_square
# plt.figure(figsize=(12, 6))
# plt.plot(r_square, label='Training R^2', color='green')
# plt.plot(val_r_square, label='Validation R^2', color='red')
# plt.title('Training R^2 vs Validation R^2')
# plt.xlabel('Epochs')
# plt.ylabel('R^2')
# plt.legend()
# plt.grid()
# plt.show()

# %%
# Find the minimum loss for training and validation
min_training_loss = min(loss)
min_validation_loss = min(val_loss)

# Print the results
print(f"Minimum Training Loss: {min_training_loss}")
print(f"Minimum Validation Loss: {min_validation_loss}")
# Out:
# Minimum Training Loss: 0.21450887620449066
# Minimum Validation Loss: 0.6395257711410522

# %%
# Find the maximum R² values for training and validation
# max_r_square_train = max(r_square)
# max_r_square_val = max(val_r_square)

# # Print the results
# print(f"Maximum Training R²: {max_r_square_train}")
# print(f"Maximum Validation R²: {max_r_square_val}")

# %%
# model = best_model

# %%
# Generate predictions for the training set
Y_train_pred = model.predict(X_train)

# Plot the true values and predictions
plt.figure(figsize=(10, 6))
plt.plot(Y_train, label='True Values', color='blue',  marker='o')
plt.plot(Y_train_pred, label='Predictions', color='red', linestyle='dashed', marker='o')
plt.title('Training True Values vs Predictions')
plt.xlabel('Sample Index')
plt.ylabel('Value')
plt.legend()
plt.show()
# Out:
# 7/7 [==============================] - 0s 6ms/step

# %%
# Generate predictions for the validation set
Y_val_pred = model.predict(X_val)

# Plot the true values and predictions
plt.figure(figsize=(10, 6))
plt.plot(Y_val, label='True Values', color='blue', marker='o')
plt.plot(Y_val_pred, label='Predictions', color='red', linestyle='dashed', marker='o')
plt.title('Validation True Values vs Predictions')
plt.xlabel('Sample Index')
plt.ylabel('Value')
plt.legend()
plt.show()
# Out:
# 2/2 [==============================] - 0s 6ms/step

# %%
# Generate predictions for the validation set
Y_val_pred = model.predict(X_val)
Y_val_pred = np.where(Y_val_pred > 0.5, 1,np.where(Y_val_pred<-0.5, -1, 0) )

# Plot the true values and predictions
plt.figure(figsize=(10, 6))
plt.plot(Y_val, label='True Values', color='blue', marker='o')
plt.plot(Y_val_pred, label='Predictions', color='red', linestyle='dashed', marker='o')
plt.title('Validation True Values vs Predictions')
plt.xlabel('Sample Index')
plt.ylabel('Value')
plt.legend()
plt.show()
# Out:
# 2/2 [==============================] - 0s 6ms/step

# %%
import matplotlib.pyplot as plt
import numpy as np

# Generate predictions for the validation set
Y_val_pred = model.predict(X_val)
Y_val_pred = np.where(Y_val_pred > 0.5, 1, np.where(Y_val_pred < -0.5, -1, 0))

# Plot
plt.figure(figsize=(12, 6))

# Add soft gray vertical lines for each sample
for i in range(len(Y_val)):
    plt.axvline(x=i, color='gray', linestyle='-', linewidth=0.5, alpha=0.3)

# Plot true values and predictions as scatter
plt.scatter(range(len(Y_val)), Y_val, label='True Values', color='blue', marker='o')
plt.scatter(range(len(Y_val_pred)), Y_val_pred, label='Predictions', color='red', marker='o')

# Styling
plt.title('Validation True Values vs Predictions')
plt.xlabel('Sample Index')
plt.ylabel('Value')
plt.legend()
plt.grid(False)  # Remove default grid
plt.tight_layout()
plt.show()
# Out:
# 2/2 [==============================] - 0s 11ms/step

# %%
from sklearn.metrics import confusion_matrix

# Create confusion matrix
conf_matrix = confusion_matrix(Y_val.flatten(), Y_val_pred.flatten())

# Print the confusion matrix
print("Confusion Matrix:")
print(conf_matrix)
# Out:
# Confusion Matrix:
# [[ 0  1  6]
#  [ 0  0  5]
#  [ 0  6 18]]

# %%
# Calculate total accuracy
total_accuracy = np.sum(Y_val.flatten() == Y_val_pred.flatten()) / len(Y_val)
print(f"Total Accuracy: {total_accuracy * 100:.2f}%")
# Out:
# Total Accuracy: 50.00%

# %%
# Generate predictions for the validation set
Y_val_pred = model.predict(X_test_filtered)
Y_val_pred = np.where(Y_val_pred > 0.42, 1, -1)

# Plot the true values and predictions
plt.figure(figsize=(10, 6))
plt.plot(Y_test_filtered, label='True Values', color='blue', marker='o')
plt.plot(Y_val_pred, label='Predictions', color='red', linestyle='dashed', marker='o')
plt.title('Validation True Values vs Predictions')
plt.xlabel('Sample Index')
plt.ylabel('Value')
plt.legend()
plt.show()
# Out:
# 1/1 [==============================] - 0s 28ms/step

# %%
import matplotlib.pyplot as plt
import numpy as np

# Generate predictions for the validation set
Y_val_pred = model.predict(X_test_filtered)
Y_val_pred = np.where(Y_val_pred > 0.2, 1, -1)

# Plot the true values and predictions
plt.figure(figsize=(12, 6))

# Add soft gray vertical lines for each sample index
for i in range(len(Y_test_filtered)):
    plt.axvline(x=i, color='gray', linestyle='-', linewidth=0.5, alpha=0.7)

# Plot using scatter (no connecting lines)
plt.scatter(range(len(Y_test_filtered)), Y_test_filtered, label='True Values', color='blue', marker='o')
plt.scatter(range(len(Y_val_pred)), Y_val_pred, label='Predictions', color='red', marker='o')

# Labels and title
plt.title('Validation True Values vs Predictions')
plt.xlabel('Sample Index')
plt.ylabel('Value')
plt.legend()
plt.grid(False)
plt.tight_layout()
plt.show()
# Out:
# 1/1 [==============================] - 0s 27ms/step

# %%
import matplotlib.pyplot as plt
import numpy as np

# Generate predictions for the validation set
Y_val_pred = model.predict(X_test_filtered)
Y_val_pred = np.where(Y_val_pred > 0.42, 1, -1)

# Flatten if needed
Y_val_pred = Y_val_pred.flatten()
Y_test_filtered = Y_test_filtered.flatten()

# Prepare index and classification of correctness
indices = np.arange(len(Y_test_filtered))
correct = Y_val_pred == Y_test_filtered
incorrect = ~correct

# Plot the figure
plt.figure(figsize=(12, 6))

# Add vertical gray lines
for i in range(len(Y_test_filtered)):
    plt.axvline(x=i, color='gray', linestyle='-', linewidth=0.7, alpha=0.7)

# Plot true values as reference shadow
# plt.scatter(indices, Y_test_filtered, color='blue', label='True Value (Reference)', marker='o', alpha=0.3)

# Plot correct predictions (overlapping with true values)
plt.scatter(indices[correct], Y_val_pred[correct], color='blue', marker='o', label='Correct Prediction')

# Plot incorrect predictions
plt.scatter(indices[incorrect], Y_val_pred[incorrect], color='red', marker='o', label='Incorrect Prediction')

# Labels and title
plt.title('Testing True Values vs Predictions')
plt.xlabel('Sample Index')
plt.ylabel('Value')
plt.legend()
plt.grid(False)
plt.tight_layout()
plt.show()
# Out:
# 1/1 [==============================] - 0s 34ms/step

# %%
from sklearn.metrics import confusion_matrix

# Create confusion matrix
conf_matrix = confusion_matrix(Y_test_filtered.flatten(), Y_val_pred.flatten())

# Print the confusion matrix
print("Confusion Matrix:")
print(conf_matrix)
# Out:
# Confusion Matrix:
# [[ 0  7]
#  [ 0 24]]

# %%
# Calculate total accuracy
total_accuracy = np.sum(Y_test_filtered.flatten() == Y_val_pred.flatten()) / len(Y_test_filtered)
print(f"Total Accuracy: {total_accuracy * 100:.2f}%")
# Out:
# Total Accuracy: 77.42%
