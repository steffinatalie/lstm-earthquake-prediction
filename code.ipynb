# %%
import numpy as np
import matplotlib.pyplot as plt
import math
from collections import Counter
import pandas as pd

# %%
bali = pd.read_csv('bali_min4.csv')
jabar = pd.read_csv('jawabarat_min4.csv')
# df = pd.concat([bali, jabar], axis=0)
jatengjatim = pd.read_csv('jatengjatim_min4.csv')
# df = pd.concat([bali, jatengjatim], axis=0)
# df = pd.concat([jabar, jatengjatim], axis=0)
df = pd.concat([bali, jabar, jatengjatim], axis=0)
# df = pd.read_csv('southern_california_min25.csv')
df['timestamp'] = pd.to_datetime(df['time'], errors='coerce', utc=False)
df['Datetime'] = df['timestamp']
df.set_index('timestamp', inplace=True)
df = df.sort_index(ascending=True)
df
# Out:
#                                                       time  latitude  \
# timestamp
# 1995-01-01 02:02:25.490000+00:00  1995-01-01T02:02:25.490Z  -10.9270
# 1995-01-07 15:02:59.810000+00:00  1995-01-07T15:02:59.810Z   -9.0250
# 1995-01-07 18:37:28.920000+00:00  1995-01-07T18:37:28.920Z   -9.2310
# 1995-01-19 09:19:57.180000+00:00  1995-01-19T09:19:57.180Z  -10.7640
# 1995-02-16 16:27:25.400000+00:00  1995-02-16T16:27:25.400Z  -10.0560
# ...                                                    ...       ...
# 2020-12-20 15:16:45.796000+00:00  2020-12-20T15:16:45.796Z   -9.2506
# 2020-12-20 15:53:57.395000+00:00  2020-12-20T15:53:57.395Z   -9.2936
# 2020-12-22 03:27:21.031000+00:00  2020-12-22T03:27:21.031Z   -9.5505
# 2020-12-24 22:09:10.232000+00:00  2020-12-24T22:09:10.232Z   -9.0282
# 2020-12-26 18:23:21.550000+00:00  2020-12-26T18:23:21.550Z   -9.0928
#
#                                   longitude   depth  mag magType  nst    gap  \
# timestamp
# 1995-01-01 02:02:25.490000+00:00   113.0110   18.90  4.5      mb  NaN    NaN
# 1995-01-07 15:02:59.810000+00:00   110.7550  114.80  4.7      mb  NaN    NaN
# 1995-01-07 18:37:28.920000+00:00   117.1110   33.00  4.2      mb  NaN    NaN
# 1995-01-19 09:19:57.180000+00:00   117.1200   33.00  4.9      mb  NaN    NaN
# 1995-02-16 16:27:25.400000+00:00   113.8580   33.00  4.0      mb  NaN    NaN
# ...                                     ...     ...  ...     ...  ...    ...
# 2020-12-20 15:16:45.796000+00:00   110.8510   35.00  4.2      mb  NaN  148.0
# 2020-12-20 15:53:57.395000+00:00   112.1503   35.00  4.3      mb  NaN   53.0
# 2020-12-22 03:27:21.031000+00:00   112.5698   35.00  4.1      mb  NaN  120.0
# 2020-12-24 22:09:10.232000+00:00   117.3729  104.10  4.4      mb  NaN   95.0
# 2020-12-26 18:23:21.550000+00:00   117.1835   63.84  4.1      mb  NaN   71.0
#
#                                    dmin   rms  ...  \
# timestamp                                      ...
# 1995-01-01 02:02:25.490000+00:00    NaN  1.20  ...
# 1995-01-07 15:02:59.810000+00:00    NaN  0.80  ...
# 1995-01-07 18:37:28.920000+00:00    NaN  0.90  ...
# 1995-01-19 09:19:57.180000+00:00    NaN  1.30  ...
# 1995-02-16 16:27:25.400000+00:00    NaN  0.40  ...
# ...                                 ...   ...  ...
# 2020-12-20 15:16:45.796000+00:00  1.368  0.58  ...
# 2020-12-20 15:53:57.395000+00:00  2.114  0.90  ...
# 2020-12-22 03:27:21.031000+00:00  1.896  0.94  ...
# 2020-12-24 22:09:10.232000+00:00  3.231  0.54  ...
# 2020-12-26 18:23:21.550000+00:00  3.059  0.62  ...
#
#                                                                   place  \
# timestamp
# 1995-01-01 02:02:25.490000+00:00         294 km S of Kencong, Indonesia
# 1995-01-07 15:02:59.810000+00:00       126 km SSE of Pundong, Indonesia
# 1995-01-07 18:37:28.920000+00:00  88 km SSW of Sumbawa Besar, Indonesia
# 1995-01-19 09:19:57.180000+00:00         246 km SSE of Praya, Indonesia
# 1995-02-16 16:27:25.400000+00:00   186 km S of Gambiran Satu, Indonesia
# ...                                                                 ...
# 2020-12-20 15:16:45.796000+00:00       153 km SSE of Pundong, Indonesia
# 2020-12-20 15:53:57.395000+00:00  130 km SSW of Sumberpucung, Indonesia
# 2020-12-22 03:27:21.031000+00:00          149 km S of Dampit, Indonesia
# 2020-12-24 22:09:10.232000+00:00    59 km S of Sumbawa Besar, Indonesia
# 2020-12-26 18:23:21.550000+00:00  71 km SSW of Sumbawa Besar, Indonesia
#
#                                         type horizontalError depthError  \
# timestamp
# 1995-01-01 02:02:25.490000+00:00  earthquake             NaN        8.5
# 1995-01-07 15:02:59.810000+00:00  earthquake             NaN       21.5
# 1995-01-07 18:37:28.920000+00:00  earthquake             NaN        NaN
# 1995-01-19 09:19:57.180000+00:00  earthquake             NaN        NaN
# 1995-02-16 16:27:25.400000+00:00  earthquake             NaN        NaN
# ...                                      ...             ...        ...
# 2020-12-20 15:16:45.796000+00:00  earthquake             8.9        1.9
# 2020-12-20 15:53:57.395000+00:00  earthquake             5.3        2.0
# 2020-12-22 03:27:21.031000+00:00  earthquake             5.6        1.9
# 2020-12-24 22:09:10.232000+00:00  earthquake             7.6        8.3
# 2020-12-26 18:23:21.550000+00:00  earthquake             7.1        8.5
#
#                                  magError  magNst    status  locationSource  \
# timestamp
# 1995-01-01 02:02:25.490000+00:00      NaN     4.0  reviewed              us
# 1995-01-07 15:02:59.810000+00:00      NaN    12.0  reviewed              us
# 1995-01-07 18:37:28.920000+00:00      NaN     5.0  reviewed              us
# 1995-01-19 09:19:57.180000+00:00      NaN     8.0  reviewed              us
# 1995-02-16 16:27:25.400000+00:00      NaN     5.0  reviewed              us
# ...                                   ...     ...       ...             ...
# 2020-12-20 15:16:45.796000+00:00    0.186     8.0  reviewed              us
# 2020-12-20 15:53:57.395000+00:00    0.142    14.0  reviewed              us
# 2020-12-22 03:27:21.031000+00:00    0.175     9.0  reviewed              us
# 2020-12-24 22:09:10.232000+00:00    0.134    16.0  reviewed              us
# 2020-12-26 18:23:21.550000+00:00    0.165    13.0  reviewed              us
#
#                                   magSource                         Datetime
# timestamp
# 1995-01-01 02:02:25.490000+00:00         us 1995-01-01 02:02:25.490000+00:00
# 1995-01-07 15:02:59.810000+00:00         us 1995-01-07 15:02:59.810000+00:00
# 1995-01-07 18:37:28.920000+00:00         us 1995-01-07 18:37:28.920000+00:00
# 1995-01-19 09:19:57.180000+00:00         us 1995-01-19 09:19:57.180000+00:00
# 1995-02-16 16:27:25.400000+00:00         us 1995-02-16 16:27:25.400000+00:00
# ...                                     ...                              ...
# 2020-12-20 15:16:45.796000+00:00         us 2020-12-20 15:16:45.796000+00:00
# 2020-12-20 15:53:57.395000+00:00         us 2020-12-20 15:53:57.395000+00:00
# 2020-12-22 03:27:21.031000+00:00         us 2020-12-22 03:27:21.031000+00:00
# 2020-12-24 22:09:10.232000+00:00         us 2020-12-24 22:09:10.232000+00:00
# 2020-12-26 18:23:21.550000+00:00         us 2020-12-26 18:23:21.550000+00:00
#
# [1698 rows x 23 columns]

# %%
df = df[['depth', 'mag']]
df
# Out:
#                                    depth  mag
# timestamp
# 1995-01-01 02:02:25.490000+00:00   18.90  4.5
# 1995-01-07 15:02:59.810000+00:00  114.80  4.7
# 1995-01-07 18:37:28.920000+00:00   33.00  4.2
# 1995-01-19 09:19:57.180000+00:00   33.00  4.9
# 1995-02-16 16:27:25.400000+00:00   33.00  4.0
# ...                                  ...  ...
# 2020-12-20 15:16:45.796000+00:00   35.00  4.2
# 2020-12-20 15:53:57.395000+00:00   35.00  4.3
# 2020-12-22 03:27:21.031000+00:00   35.00  4.1
# 2020-12-24 22:09:10.232000+00:00  104.10  4.4
# 2020-12-26 18:23:21.550000+00:00   63.84  4.1
#
# [1698 rows x 2 columns]

# %%
print(df.isna().sum())
# Out:
# depth    0
# mag      0
# dtype: int64

# %%
mag_unique, frequency = np.unique(df['mag'], return_counts=True)

plt.figure(figsize=(10,8))
plt.hist(df['mag'], bins=1000, color='black', edgecolor='black')

bins = [0, 20, 40, 60]

from matplotlib.ticker import MultipleLocator
# Set x-axis scale to increment by 0.5
plt.gca().xaxis.set_major_locator(MultipleLocator(0.2))
# Add titles and labels
plt.title('Frequency by Magnitude')
plt.xlabel('Magnitude')
plt.ylabel('Frequency')
plt.xticks(fontsize=12, fontname='Times New Roman', rotation=45)

# Show the plot
plt.show()

# %%
mag_filter = 4.4
depth_filter = 100
resample_rate = '2W'

# %%
# def occurence_criterion(raw_array):
#     print(raw_array)
#     print("---------------------")
#     target = -1
#     if len(raw_array) > 0:
#         if raw_array['earthquake'].eq(1).any():
#             target = 1
#         if raw_array['earthquake'].eq(0).any():
#             target = 0
#     if len(raw_array) == 0:
#         target = 0

        
#     return target

# earthquake_occurence = df.resample(resample_rate).apply(occurence_criterion)

# earthquake_occurence = earthquake_occurence.to_frame(name='earthquake')

# earthquake_occurence = earthquake_occurence.sort_index(ascending=True)
# earthquake_occurence['earthquake'].value_counts()

# %%
# Initialize the 'ED' column with NaN values
df['ED'] = np.nan

# Filter the dataframe for earthquakes with magnitude greater than mag_filter
filtered_df = df[df['mag'] > mag_filter]

n = 50

# Calculate the elapsed days for the last n earthquake events
for i in range(n, len(filtered_df)):
    current_time = filtered_df.index[i]
    past_time = filtered_df.index[i-n]
    elapsed_days = (current_time - past_time).days
    df.loc[current_time, 'ED'] = elapsed_days

# Fill NaN values in 'ED' column
for i in range(len(df)):
    if pd.isna(df.iloc[i]['ED']):
        # Find the latest valid 'ED' value before the current index
        last_valid_index = df.iloc[:i]['ED'].last_valid_index()
        if last_valid_index is not None:
            time_since_last_valid = (df.index[i] - last_valid_index).days
            df.at[df.index[i], 'ED'] = df.at[last_valid_index, 'ED'] + time_since_last_valid

# df = df.dropna(subset=['ED'])
df
# Out:
# C:\Users\SteinSteffi1\AppData\Local\Temp\ipykernel_18944\388928700.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['ED'] = np.nan
#                                    depth  mag     ED
# timestamp
# 1995-01-01 02:02:25.490000+00:00   18.90  4.5    NaN
# 1995-01-07 15:02:59.810000+00:00  114.80  4.7    NaN
# 1995-01-07 18:37:28.920000+00:00   33.00  4.2    NaN
# 1995-01-19 09:19:57.180000+00:00   33.00  4.9    NaN
# 1995-02-16 16:27:25.400000+00:00   33.00  4.0    NaN
# ...                                  ...  ...    ...
# 2020-12-20 15:16:45.796000+00:00   35.00  4.2  653.0
# 2020-12-20 15:53:57.395000+00:00   35.00  4.3  653.0
# 2020-12-22 03:27:21.031000+00:00   35.00  4.1  654.0
# 2020-12-24 22:09:10.232000+00:00  104.10  4.4  656.0
# 2020-12-26 18:23:21.550000+00:00   63.84  4.1  657.0
#
# [1698 rows x 3 columns]

# %%
# Initialize the 'energy_squared' and 'cumulative_energy_squared' columns with NaN values
df['energy_squared_root'] = np.nan
df['cumulative_energy_squared'] = np.nan

df['energy'] = 10**(11.8+1.5*df['mag'])

# Calculate the energy squared for each data point
df['energy_squared_root'] = np.sqrt(df['energy'])

# Calculate the cumulative sum of energy squared for the last 50 data points
# for i in range(n, len(df)):
#     df.iloc[i, df.columns.get_loc('cumulative_energy_squared')] = df.iloc[i-n:i]['energy_squared_root'].sum()

df['cumulative_energy_squared'] = df['energy_squared_root'].rolling(n).sum()

# Calculate the RSRER
df['RSRER'] = df['cumulative_energy_squared'] / df['ED']

df['mean_mag'] = df['mag'].rolling(n).mean()
df['min_mag'] = df['mag'].rolling(n).min()
df['b_value'] = np.log10(np.e)/(df['mean_mag'] - df['min_mag'])

df['event_counts'] = df['mag'].rolling(n).apply(lambda x: (x > mag_filter).sum(), raw=True)
df['a_value'] = (np.log10(df['event_counts']) + df['b_value']*df['min_mag'])/n
# df['MSD'] = np.sum((np.log10(df['event_counts'])-(df['a_value']-(df['b_value']*df['mag'])))**2)/(n-1)
df['max_mag'] = df['mag'].rolling(n).max()
df['MD'] = df['a_value']/df['b_value'] - df['max_mag']
# print(df['event_counts'])

df
# Out:
# C:\Users\SteinSteffi1\AppData\Local\Temp\ipykernel_18944\2738765218.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['energy_squared_root'] = np.nan
# C:\Users\SteinSteffi1\AppData\Local\Temp\ipykernel_18944\2738765218.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['cumulative_energy_squared'] = np.nan
# C:\Users\SteinSteffi1\AppData\Local\Temp\ipykernel_18944\2738765218.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['energy'] = 10**(11.8+1.5*df['mag'])
# C:\Users\SteinSteffi1\AppData\Local\Temp\ipykernel_18944\2738765218.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['energy_squared_root'] = np.sqrt(df['energy'])
# C:\Users\SteinSteffi1\AppData\Local\Temp\ipykernel_18944\2738765218.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['cumulative_energy_squared'] = df['energy_squared_root'].rolling(n).sum()
# C:\Users\SteinSteffi1\AppData\Local\Temp\ipykernel_18944\2738765218.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['RSRER'] = df['cumulative_energy_squared'] / df['ED']
# C:\Users\SteinSteffi1\AppData\Local\Temp\ipykernel_18944\2738765218.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['mean_mag'] = df['mag'].rolling(n).mean()
# C:\Users\SteinSteffi1\AppData\Local\Temp\ipykernel_18944\2738765218.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['min_mag'] = df['mag'].rolling(n).min()
# C:\Users\SteinSteffi1\AppData\Local\Temp\ipykernel_18944\2738765218.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['b_value'] = np.log10(np.e)/(df['mean_mag'] - df['min_mag'])
# C:\Users\SteinSteffi1\AppData\Local\Temp\ipykernel_18944\2738765218.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['event_counts'] = df['mag'].rolling(n).apply(lambda x: (x > mag_filter).sum(), raw=True)
# C:\Users\SteinSteffi1\AppData\Local\Temp\ipykernel_18944\2738765218.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['a_value'] = (np.log10(df['event_counts']) + df['b_value']*df['min_mag'])/n
# C:\Users\SteinSteffi1\AppData\Local\Temp\ipykernel_18944\2738765218.py:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['max_mag'] = df['mag'].rolling(n).max()
# C:\Users\SteinSteffi1\AppData\Local\Temp\ipykernel_18944\2738765218.py:27: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['MD'] = df['a_value']/df['b_value'] - df['max_mag']
#                                    depth  mag     ED  energy_squared_root  \
# timestamp
# 1995-01-01 02:02:25.490000+00:00   18.90  4.5    NaN         1.883649e+09
# 1995-01-07 15:02:59.810000+00:00  114.80  4.7    NaN         2.660725e+09
# 1995-01-07 18:37:28.920000+00:00   33.00  4.2    NaN         1.122018e+09
# 1995-01-19 09:19:57.180000+00:00   33.00  4.9    NaN         3.758374e+09
# 1995-02-16 16:27:25.400000+00:00   33.00  4.0    NaN         7.943282e+08
# ...                                  ...  ...    ...                  ...
# 2020-12-20 15:16:45.796000+00:00   35.00  4.2  653.0         1.122018e+09
# 2020-12-20 15:53:57.395000+00:00   35.00  4.3  653.0         1.333521e+09
# 2020-12-22 03:27:21.031000+00:00   35.00  4.1  654.0         9.440609e+08
# 2020-12-24 22:09:10.232000+00:00  104.10  4.4  656.0         1.584893e+09
# 2020-12-26 18:23:21.550000+00:00   63.84  4.1  657.0         9.440609e+08
#
#                                   cumulative_energy_squared        energy  \
# timestamp
# 1995-01-01 02:02:25.490000+00:00                        NaN  3.548134e+18
# 1995-01-07 15:02:59.810000+00:00                        NaN  7.079458e+18
# 1995-01-07 18:37:28.920000+00:00                        NaN  1.258925e+18
# 1995-01-19 09:19:57.180000+00:00                        NaN  1.412538e+19
# 1995-02-16 16:27:25.400000+00:00                        NaN  6.309573e+17
# ...                                                     ...           ...
# 2020-12-20 15:16:45.796000+00:00               9.353097e+10  1.258925e+18
# 2020-12-20 15:53:57.395000+00:00               9.353097e+10  1.778279e+18
# 2020-12-22 03:27:21.031000+00:00               9.259138e+10  8.912509e+17
# 2020-12-24 22:09:10.232000+00:00               9.259138e+10  2.511886e+18
# 2020-12-26 18:23:21.550000+00:00               9.220192e+10  8.912509e+17
#
#                                          RSRER  mean_mag  min_mag   b_value  \
# timestamp
# 1995-01-01 02:02:25.490000+00:00           NaN       NaN      NaN       NaN
# 1995-01-07 15:02:59.810000+00:00           NaN       NaN      NaN       NaN
# 1995-01-07 18:37:28.920000+00:00           NaN       NaN      NaN       NaN
# 1995-01-19 09:19:57.180000+00:00           NaN       NaN      NaN       NaN
# 1995-02-16 16:27:25.400000+00:00           NaN       NaN      NaN       NaN
# ...                                        ...       ...      ...       ...
# 2020-12-20 15:16:45.796000+00:00  1.432327e+08     4.430      4.0  1.009987
# 2020-12-20 15:53:57.395000+00:00  1.432327e+08     4.430      4.0  1.009987
# 2020-12-22 03:27:21.031000+00:00  1.415770e+08     4.422      4.0  1.029134
# 2020-12-24 22:09:10.232000+00:00  1.411454e+08     4.422      4.0  1.029134
# 2020-12-26 18:23:21.550000+00:00  1.403378e+08     4.418      4.0  1.038982
#
#                                   event_counts   a_value  max_mag        MD
# timestamp
# 1995-01-01 02:02:25.490000+00:00           NaN       NaN      NaN       NaN
# 1995-01-07 15:02:59.810000+00:00           NaN       NaN      NaN       NaN
# 1995-01-07 18:37:28.920000+00:00           NaN       NaN      NaN       NaN
# 1995-01-19 09:19:57.180000+00:00           NaN       NaN      NaN       NaN
# 1995-02-16 16:27:25.400000+00:00           NaN       NaN      NaN       NaN
# ...                                        ...       ...      ...       ...
# 2020-12-20 15:16:45.796000+00:00          20.0  0.106820      5.2 -5.094237
# 2020-12-20 15:53:57.395000+00:00          20.0  0.106820      5.2 -5.094237
# 2020-12-22 03:27:21.031000+00:00          19.0  0.107906      5.2 -5.095149
# 2020-12-24 22:09:10.232000+00:00          19.0  0.107906      5.2 -5.095149
# 2020-12-26 18:23:21.550000+00:00          19.0  0.108694      5.2 -5.095384
#
# [1698 rows x 14 columns]

# %%
# Drop the intermediate columns
df.drop(columns=['energy_squared_root', 'cumulative_energy_squared', 'mean_mag', 'min_mag', 'event_counts', 'a_value', 'max_mag'], inplace=True)
# Out:
# C:\Users\SteinSteffi1\AppData\Local\Temp\ipykernel_18944\1093842324.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.drop(columns=['energy_squared_root', 'cumulative_energy_squared', 'mean_mag', 'min_mag', 'event_counts', 'a_value', 'max_mag'], inplace=True)

# %%
df.dropna(subset=['RSRER'], inplace=True)
df.isna().sum()
# Out:
# C:\Users\SteinSteffi1\AppData\Local\Temp\ipykernel_18944\2534608267.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.dropna(subset=['RSRER'], inplace=True)
# depth      0
# mag        0
# ED         0
# energy     0
# RSRER      0
# b_value    0
# MD         0
# dtype: int64

# %%
df['earthquake'] = np.where((df['mag'] > mag_filter) & (df['depth'] < depth_filter), 1, 
                            np.where(df['mag']<=mag_filter, -1, 0) )

df['earthquake'].value_counts()
# Out:
# C:\Users\SteinSteffi1\AppData\Local\Temp\ipykernel_18944\14959589.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['earthquake'] = np.where((df['mag'] > mag_filter) & (df['depth'] < depth_filter), 1,
# earthquake
#  1    835
# -1    719
#  0      4
# Name: count, dtype: int64

# %%
def occurence_criterion(raw_array):
    # print(raw_array)
    # print("---------------------")
    target = -1
    if len(raw_array) > 0:
        if raw_array['earthquake'].eq(1).any():
            target = 1
        if raw_array['earthquake'].eq(0).any():
            target = 0
    if len(raw_array) == 0:
        target = 0

        
    return target


earthquake_occurence = df[['earthquake']].resample(resample_rate).apply(occurence_criterion)
print(earthquake_occurence.value_counts())
monthly_df = df.resample(resample_rate).mean()
monthly_df = monthly_df.fillna(0)
monthly_df['earthquake'] = earthquake_occurence
print(monthly_df)
# Out:
#  1    308
# -1    134
#  0    122
# Name: count, dtype: int64
#                              depth       mag           ED        energy  \
# timestamp
# 1999-05-30 00:00:00+00:00  33.0000  4.500000  1607.000000  3.548134e+18
# 1999-06-13 00:00:00+00:00  33.0000  4.500000  1618.000000  3.548134e+18
# 1999-06-27 00:00:00+00:00  33.0000  4.700000  1617.000000  7.079458e+18
# 1999-07-11 00:00:00+00:00  33.0000  4.200000  1623.000000  1.258925e+18
# 1999-07-25 00:00:00+00:00  58.7000  4.200000  1637.000000  1.258925e+18
# ...                            ...       ...          ...           ...
# 2020-11-01 00:00:00+00:00  39.3040  4.440000   659.800000  4.047822e+18
# 2020-11-15 00:00:00+00:00   0.0000  0.000000     0.000000  0.000000e+00
# 2020-11-29 00:00:00+00:00   0.0000  0.000000     0.000000  0.000000e+00
# 2020-12-13 00:00:00+00:00  45.6000  4.366667   684.333333  3.249663e+18
# 2020-12-27 00:00:00+00:00  48.9675  4.250000   652.625000  1.693657e+18
#
#                                   RSRER   b_value        MD  earthquake
# timestamp
# 1999-05-30 00:00:00+00:00  6.178684e+07  1.085736 -5.496877           1
# 1999-06-13 00:00:00+00:00  6.183751e+07  1.069691 -5.496091           1
# 1999-06-27 00:00:00+00:00  6.282733e+07  1.043977 -5.495076           1
# 1999-07-11 00:00:00+00:00  6.270471e+07  1.038982 -5.494956          -1
# 1999-07-25 00:00:00+00:00  6.227716e+07  1.034034 -5.494836          -1
# ...                                 ...       ...       ...         ...
# 2020-11-01 00:00:00+00:00  1.548856e+08  0.922511 -5.090642           1
# 2020-11-15 00:00:00+00:00  0.000000e+00  0.000000  0.000000           0
# 2020-11-29 00:00:00+00:00  0.000000e+00  0.000000  0.000000           0
# 2020-12-13 00:00:00+00:00  1.462111e+08  0.935991 -5.091315           1
# 2020-12-27 00:00:00+00:00  1.447719e+08  1.002203 -5.093956           1
#
# [564 rows x 8 columns]

# %%
df = monthly_df[['depth', 'mag', 'ED', 'RSRER', 'b_value', 'MD', 'earthquake']]
# df = monthly_df[['mag', 'ED','MD', 'earthquake']]
df
# Out:
#                              depth       mag           ED         RSRER  \
# timestamp
# 1999-05-30 00:00:00+00:00  33.0000  4.500000  1607.000000  6.178684e+07
# 1999-06-13 00:00:00+00:00  33.0000  4.500000  1618.000000  6.183751e+07
# 1999-06-27 00:00:00+00:00  33.0000  4.700000  1617.000000  6.282733e+07
# 1999-07-11 00:00:00+00:00  33.0000  4.200000  1623.000000  6.270471e+07
# 1999-07-25 00:00:00+00:00  58.7000  4.200000  1637.000000  6.227716e+07
# ...                            ...       ...          ...           ...
# 2020-11-01 00:00:00+00:00  39.3040  4.440000   659.800000  1.548856e+08
# 2020-11-15 00:00:00+00:00   0.0000  0.000000     0.000000  0.000000e+00
# 2020-11-29 00:00:00+00:00   0.0000  0.000000     0.000000  0.000000e+00
# 2020-12-13 00:00:00+00:00  45.6000  4.366667   684.333333  1.462111e+08
# 2020-12-27 00:00:00+00:00  48.9675  4.250000   652.625000  1.447719e+08
#
#                             b_value        MD  earthquake
# timestamp
# 1999-05-30 00:00:00+00:00  1.085736 -5.496877           1
# 1999-06-13 00:00:00+00:00  1.069691 -5.496091           1
# 1999-06-27 00:00:00+00:00  1.043977 -5.495076           1
# 1999-07-11 00:00:00+00:00  1.038982 -5.494956          -1
# 1999-07-25 00:00:00+00:00  1.034034 -5.494836          -1
# ...                             ...       ...         ...
# 2020-11-01 00:00:00+00:00  0.922511 -5.090642           1
# 2020-11-15 00:00:00+00:00  0.000000  0.000000           0
# 2020-11-29 00:00:00+00:00  0.000000  0.000000           0
# 2020-12-13 00:00:00+00:00  0.935991 -5.091315           1
# 2020-12-27 00:00:00+00:00  1.002203 -5.093956           1
#
# [564 rows x 7 columns]

# %%
correlation_matrix = df.corr()
correlation_matrix
# Out:
#                depth       mag        ED     RSRER   b_value        MD  \
# depth       1.000000  0.715202  0.615462 -0.004448  0.719121 -0.722318
# mag         0.715202  1.000000  0.735872  0.202525  0.899763 -0.983103
# ED          0.615462  0.735872  1.000000 -0.103967  0.649686 -0.741686
# RSRER      -0.004448  0.202525 -0.103967  1.000000  0.121326 -0.196370
# b_value     0.719121  0.899763  0.649686  0.121326  1.000000 -0.873125
# MD         -0.722318 -0.983103 -0.741686 -0.196370 -0.873125  1.000000
# earthquake  0.047972  0.271443  0.142584  0.093125  0.137031 -0.192644
#
#             earthquake
# depth         0.047972
# mag           0.271443
# ED            0.142584
# RSRER         0.093125
# b_value       0.137031
# MD           -0.192644
# earthquake    1.000000

# %%
# Replace infinite values with a large number
df.replace([np.inf, -np.inf], 1e10, inplace=True)
# Out:
# C:\Users\SteinSteffi1\AppData\Local\Temp\ipykernel_18944\2297783001.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.replace([np.inf, -np.inf], 1e10, inplace=True)

# %%
from sklearn.preprocessing import MinMaxScaler

# Initialize the MinMaxScaler with the desired feature range
scaler = MinMaxScaler(feature_range=(-1, 1))

# Apply the scaler to the dataframe
df[df.columns] = scaler.fit_transform(df)

# Display the scaled dataframe
df
# Out:
# C:\Users\SteinSteffi1\AppData\Local\Temp\ipykernel_18944\3980167207.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[df.columns] = scaler.fit_transform(df)
#                               depth       mag        ED     RSRER   b_value  \
# timestamp
# 1999-05-30 00:00:00+00:00 -0.362688  0.500000  0.946699 -0.989126  0.453044
# 1999-06-13 00:00:00+00:00 -0.362688  0.500000  0.960024 -0.989117  0.431570
# 1999-06-27 00:00:00+00:00 -0.362688  0.566667  0.958813 -0.988942  0.397157
# 1999-07-11 00:00:00+00:00 -0.362688  0.400000  0.966081 -0.988964  0.390473
# 1999-07-25 00:00:00+00:00  0.133642  0.400000  0.983041 -0.989039  0.383851
# ...                             ...       ...       ...       ...       ...
# 2020-11-01 00:00:00+00:00 -0.240942  0.480000 -0.200727 -0.972740  0.234599
# 2020-11-15 00:00:00+00:00 -1.000000 -1.000000 -1.000000 -1.000000 -1.000000
# 2020-11-29 00:00:00+00:00 -1.000000 -1.000000 -1.000000 -1.000000 -1.000000
# 2020-12-13 00:00:00+00:00 -0.119351  0.455556 -0.171007 -0.974267  0.252639
# 2020-12-27 00:00:00+00:00 -0.054316  0.416667 -0.209419 -0.974520  0.341251
#
#                                  MD  earthquake
# timestamp
# 1999-05-30 00:00:00+00:00 -0.669690         1.0
# 1999-06-13 00:00:00+00:00 -0.669451         1.0
# 1999-06-27 00:00:00+00:00 -0.669143         1.0
# 1999-07-11 00:00:00+00:00 -0.669106        -1.0
# 1999-07-25 00:00:00+00:00 -0.669070        -1.0
# ...                             ...         ...
# 2020-11-01 00:00:00+00:00 -0.546295         1.0
# 2020-11-15 00:00:00+00:00  1.000000         0.0
# 2020-11-29 00:00:00+00:00  1.000000         0.0
# 2020-12-13 00:00:00+00:00 -0.546499         1.0
# 2020-12-27 00:00:00+00:00 -0.547302         1.0
#
# [564 rows x 7 columns]

# %%
import numpy as np

def create_lstm_dataset(df, lookback, n_future):
    """
    Creates an LSTM dataset from the given DataFrame.

    Parameters:
    - df: pandas DataFrame containing features.
    - lookback: Number of past timesteps to include in each X sample.

    Returns:
    - X: 3D NumPy array of shape (samples, lookback, features)
    - Y: 1D NumPy array of shape (samples,)
    """
    data = df.values  # Convert dataframe to NumPy array
    X, Y = [], []
    
    for i in range(len(data) - lookback):
        X.append(data[i:i + lookback, :7])  # First 6 columns
        Y.append(data[(i + lookback):(i + lookback + n_future), -1])     # 7th column as label
    
    return np.array(X), np.array(Y)
look_back = 10
X, Y = create_lstm_dataset(df, lookback=look_back, n_future=1)

print(X.shape)  # (number of samples, lookback, 6)
print(Y.shape)  # (number of samples,)
# Out:
# (554, 10, 7)
# (554, 1)

# %%
from sklearn.model_selection import train_test_split

# Split the data
X_train, X_val, Y_train, Y_val = train_test_split(X, Y, test_size=0.1, shuffle=False)

# Print the shapes of the resulting datasets
print("X_train shape:", X_train.shape)
print("X_val shape:", X_val.shape)
print("Y_train shape:", Y_train.shape)
print("Y_val shape:", Y_val.shape)
# Out:
# X_train shape: (498, 10, 7)
# X_val shape: (56, 10, 7)
# Y_train shape: (498, 1)
# Y_val shape: (56, 1)

# %%
print(X_train[0])
# Out:
# [[-0.3626883   0.5         0.94669897 -0.98912553  0.45304377 -0.66968988
#    1.        ]
#  [-0.3626883   0.5         0.96002423 -0.98911662  0.43157021 -0.66945117
#    1.        ]
#  [-0.3626883   0.56666667  0.95881284 -0.98894241  0.39715747 -0.66914267
#    1.        ]
#  [-0.3626883   0.4         0.96608116 -0.98896399  0.3904725  -0.66910627
#   -1.        ]
#  [ 0.13364233  0.4         0.98304058 -0.98903924  0.38385121 -0.66906987
#   -1.        ]
#  [-0.3626883   0.46666667  1.         -0.98913218  0.38385121 -0.66906987
#   -1.        ]
#  [-0.3626883   0.56666667  0.85584494 -0.98823953  0.37729267 -0.66903347
#    1.        ]
#  [ 0.06991116  0.55        0.86250757 -0.98800437  0.33670439 -0.66873108
#    1.        ]
#  [-1.         -1.         -1.         -1.         -1.          1.
#    0.        ]
#  [-1.         -1.         -1.         -1.         -1.          1.
#    0.        ]]

# %%
# Count occurrences of 0 and 1 in Y_train
unique_train, counts_train = np.unique(Y_train, return_counts=True)
print("Y_train counts:", dict(zip(unique_train, counts_train)))

# Count occurrences of 0 and 1 in Y_val
unique_val, counts_val = np.unique(Y_val, return_counts=True)
print("Y_val counts:", dict(zip(unique_val, counts_val)))
# Out:
# Y_train counts: {-1.0: 121, 0.0: 109, 1.0: 268}
# Y_val counts: {-1.0: 10, 0.0: 11, 1.0: 35}

# %%
# root mean squared error (rmse) for regression (only for Keras tensors)
def rmse(y_true, y_pred):
    from keras import backend
    return backend.sqrt(backend.mean(backend.square(y_pred - y_true), axis=-1))

# mean squared error (mse) for regression  (only for Keras tensors)
def mse(y_true, y_pred):
    from keras import backend
    return backend.mean(backend.square(y_pred - y_true), axis=-1)

# coefficient of determination (R^2) for regression  (only for Keras tensors)
def r_square(y_true, y_pred):
    from keras import backend as K
    SS_res =  K.sum(K.square(y_true - y_pred)) 
    SS_tot = K.sum(K.square(y_true - K.mean(y_true))) 
    return ( 1 - SS_res/(SS_tot + K.epsilon()) )

# %%
# import tensorflow as tf
# from tensorflow.keras.layers import *
# from tensorflow.keras.models import Model
# from tensorflow.keras.layers import Input, LSTM, Dense, Layer, Dropout

# from tensorflow.keras.optimizers.legacy import Adam

# from tensorflow.keras.regularizers import L1L2
# from tensorflow.keras.layers import Layer, Dense, Dot, Activation

# from tensorflow.keras.callbacks import Callback, EarlyStopping

# from tensorflow.keras import backend as K

# from matplotlib import pyplot as plt

# K.clear_session()

   
# l1 = 0.0001
# l2 = 0.0001

# lstm_dropout = 0.2
# recurrent_dropout = 0.1
# dense_dropout = 0.2
# loss = 'mse'

# n_target = Y_train.shape[-2:]

# regularization_criteria = L1L2(l1=l1, l2=l2)

# n_target_y = Y_train.shape[-1]

# def build_model(input_shape):
#     input_layer = Input(shape=input_shape, name='Input_1')
#     sequence = input_layer
#     sequence = LSTM(20, return_sequences = True,  name="LSTM-1", kernel_regularizer = regularization_criteria, dropout=lstm_dropout, recurrent_dropout=recurrent_dropout)(input_layer)
#     sequence = Flatten()(sequence)
#     # sequence = Dropout(dense_dropout)(sequence)
#     # sequence = LSTM(16, return_sequences = False,  name="LSTM-2", kernel_regularizer = regularization_criteria, dropout=lstm_dropout, recurrent_dropout=recurrent_dropout)(sequence)
#     # sequence = Dense(4, activation = 'tanh', name='Dense_3')(sequence)
#     sequence = Dense(n_target_y, activation = 'tanh', name='Dense_4')(sequence)
#     output_layer = sequence

#     model = Model(inputs=input_layer, outputs=output_layer)

#     return model

# input_shape = (look_back, X_train.shape[2])

# learning_rate = 0.0005

# optimizer = Adam(learning_rate=learning_rate)

# model = build_model(input_shape)
# model.compile(optimizer=optimizer, loss=loss, metrics=[mse, rmse, r_square])
# model.summary()

# import time

# start_time = time.time()

# # early_stopping = EarlyStopping(monitor='val_loss', patience=500, restore_best_weights=True)

# history = model.fit(X_train, Y_train, epochs=700, batch_size=64, validation_data=(X_val, Y_val),
#                     # callbacks=[early_stopping]
#                     )

# end_time = time.time()
# difference_in_seconds = end_time - start_time
# print(f"The difference in seconds is: {difference_in_seconds}")

# %%
# import tensorflow as tf
# from tensorflow.keras.layers import *
# from tensorflow.keras.models import Model
# from tensorflow.keras.layers import Input, LSTM, Dense, Layer, Dropout

# from tensorflow.keras.optimizers.legacy import Adam

# from tensorflow.keras.regularizers import L1L2
# from tensorflow.keras.layers import Layer, Dense, Dot, Activation

# from tensorflow.keras.callbacks import Callback, EarlyStopping

# from tensorflow.keras import backend as K

# from matplotlib import pyplot as plt

# K.clear_session()

   
# l1 = 0.0
# l2 = 0.0

# lstm_dropout = 0.0
# recurrent_dropout = 0.0
# dense_dropout = 0.1
# loss = 'mse'

# n_target = Y_train.shape[-2:]

# regularization_criteria = L1L2(l1=l1, l2=l2)

# n_target_y = Y_train.shape[-1]

# def build_model(input_shape):
#     input_layer = Input(shape=input_shape, name='Input_1')
#     sequence = input_layer
#     sequence = LSTM(50, return_sequences = True,  name="LSTM-1", kernel_regularizer = regularization_criteria, dropout=lstm_dropout, recurrent_dropout=recurrent_dropout)(input_layer)
    
#     sequence = Flatten()(sequence)
#     sequence = Dense(20, activation = 'tanh', name='Dense_2')(sequence)
#     sequence = Dropout(0.3)(sequence)
#     # sequence = LSTM(16, return_sequences = False,  name="LSTM-2", kernel_regularizer = regularization_criteria, dropout=lstm_dropout, recurrent_dropout=recurrent_dropout)(sequence)
#     sequence = Dense(10, activation = 'tanh', name='Dense_3')(sequence)
#     sequence = Dense(n_target_y, activation = 'sigmoid', name='Dense_4')(sequence)
#     output_layer = sequence

#     model = Model(inputs=input_layer, outputs=output_layer)

#     return model

# input_shape = (look_back, X_train.shape[2])

# learning_rate = 0.001

# optimizer = Adam(learning_rate=learning_rate)

# model = build_model(input_shape)
# model.compile(optimizer=optimizer, loss=loss, metrics=[mse])
# model.summary()

# import time

# start_time = time.time()

# early_stopping = EarlyStopping(monitor='val_loss', patience=700, restore_best_weights=True)

# history = model.fit(X_train, Y_train, epochs=1000, batch_size=64, validation_data=(X_val, Y_val),
#                     callbacks=[early_stopping]
#                     )

# end_time = time.time()
# difference_in_seconds = end_time - start_time
# print(f"The difference in seconds is: {difference_in_seconds}")

# %%
# import keras_tuner as kt
# import tensorflow as tf
# from tensorflow import keras
# from tensorflow.keras.layers import LSTM, Bidirectional, Dense, Dropout, Flatten

# def build_model(hp):
#     model = keras.Sequential()
    
#     model.add(LSTM(units=hp.Int('lstm_units', min_value=16, max_value=128, step=16),
#                    return_sequences=True,
#                      input_shape=(look_back, X_train.shape[2])))
    
#     # model.add(Dropout(hp.Float('dropout', min_value=0.0, max_value=0.5, step=0.1)))
    
#     # model.add(Bidirectional(LSTM(units=hp.Int('bidirectional_units', min_value=4, max_value=16, step=4),
#     #                              return_sequences=True)))
    
#     # model.add(Bidirectional(LSTM(units=hp.Int('bidirectional_units', min_value=4, max_value=32, step=4),
#     #                              return_sequences=True)))
    
#     model.add(Flatten())
    
#     model.add(Dropout(hp.Float('dropout', min_value=0.0, max_value=0.5, step=0.1)))
    
#     model.add(Dense(hp.Float('dense_units', min_value=0, max_value=32, step=8), activation='tanh'))
    
#     model.add(Dense(1, activation='tanh'))
    
#     model.compile(optimizer=keras.optimizers.Adam(hp.Choice('learning_rate', values=[1e-4, 1e-5])),
#                     loss='mse',
#                     metrics=[rmse, r_square])
    
#     return model

# %%
# import keras_tuner as kt
# import tensorflow as tf
# from tensorflow import keras
# from tensorflow.keras.layers import LSTM, Bidirectional, Dense, Dropout, Flatten, Attention, Input
# from tensorflow.keras.models import Model

# def build_model(hp):
#     inputs = Input(shape=(look_back, X_train.shape[2]))
    
#     lstm_out = LSTM(units=60,
#                     return_sequences=True)(inputs)

    
#     flatten = Flatten()(lstm_out)
    
#     dropout = Dropout(hp.Float('dropout', min_value=0.0, max_value=0.5, step=0.1))(flatten)
    
#     dense = Dense(hp.Int('dense_units', min_value=0, max_value=32, step=4), activation='tanh')(dropout)
    
#     output = Dense(1, activation='tanh')(dense)
    
#     model = Model(inputs=inputs, outputs=output)
    
#     model.compile(optimizer=keras.optimizers.Adam(hp.Choice('learning_rate', values=[1e-4, 1e-5])),
#                   loss='mse',
#                   metrics=[rmse, r_square])
    
#     return model

# %%
# tuner = kt.RandomSearch(build_model,
#                         objective=kt.Objective("val_r_square", direction="max"),
#                         max_trials=20,
#                         executions_per_trial=2,
#                         directory='my_dir',
#                         project_name='earthquake')

# %%
# tuner.search(X_train, Y_train, epochs=150, validation_data=(X_val, Y_val))

# %%
# from tensorflow.keras.callbacks import Callback, EarlyStopping
# best_hps = tuner.get_best_hyperparameters(num_trials=5)[0]

# # print(f"Best LSTM units: {best_hps.get('lstm_units')}")
# # print(f"Best BiLSTM usage: {best_hps.get('bidirectional_units')}")
# print(f"Best Dropout Rate: {best_hps.get('dropout')}")
# print(f"Best Dense Units: {best_hps.get('dense_units')}")
# print(f"Best Learning Rate: {best_hps.get('learning_rate')}")

# # Train the best model
# best_model = tuner.hypermodel.build(best_hps)
# early_stopping = EarlyStopping(monitor='val_loss', patience=700, restore_best_weights=True)
# history = best_model.fit(X_train, Y_train, epochs=1000, validation_data=(X_val, Y_val), callbacks=[early_stopping])

# %%
# # Generate predictions for the training set
# Y_train_pred = best_model.predict(X_train)

# # Plot the true values and predictions
# plt.figure(figsize=(10, 6))
# plt.plot(Y_train, label='True Values', color='blue',  marker='o')
# plt.plot(Y_train_pred, label='Predictions', color='red', linestyle='dashed', marker='o')
# plt.title('Training True Values vs Predictions')
# plt.xlabel('Sample Index')
# plt.ylabel('Value')
# plt.legend()
# plt.show()

# %%
# # Generate predictions for the validation set
# Y_val_pred = best_model.predict(X_val)

# # Plot the true values and predictions
# plt.figure(figsize=(10, 6))
# plt.plot(Y_val, label='True Values', color='blue', marker='o')
# plt.plot(Y_val_pred, label='Predictions', color='red', linestyle='dashed', marker='o')
# plt.title('Validation True Values vs Predictions')
# plt.xlabel('Sample Index')
# plt.ylabel('Value')
# plt.legend()
# plt.show()

# %%
# # Generate predictions for the validation set
# Y_val_pred = best_model.predict(X_val)
# Y_val_pred = np.where(Y_val_pred > 0.5, 1,np.where(Y_val_pred<-0.5, -1, 0) )

# # Plot the true values and predictions
# plt.figure(figsize=(10, 6))
# plt.plot(Y_val, label='True Values', color='blue', marker='o')
# plt.plot(Y_val_pred, label='Predictions', color='red', linestyle='dashed', marker='o')
# plt.title('Validation True Values vs Predictions')
# plt.xlabel('Sample Index')
# plt.ylabel('Value')
# plt.legend()
# plt.show()

# %%
# from sklearn.metrics import confusion_matrix

# # Create confusion matrix
# conf_matrix = confusion_matrix(Y_val.flatten(), Y_val_pred.flatten())

# # Print the confusion matrix
# print("Confusion Matrix:")
# print(conf_matrix)

# %%
# # Calculate total accuracy
# total_accuracy = np.sum(Y_val.flatten() == Y_val_pred.flatten()) / len(Y_val)
# print(f"Total Accuracy: {total_accuracy * 100:.2f}%")

# %%
# Create a mask to filter out values in Y_test that are not equal to 0
mask = Y_val != 0
# print(X_test.shape)
# Apply the mask to filter X_test and Y_test
X_test_filtered = np.array([x for x, m in zip(X_val, mask) if m])
Y_test_filtered = Y_val[mask]

# Print the shapes of the filtered arrays to verify
print(X_test_filtered.shape)
print(Y_test_filtered.shape)
# Out:
# (45, 10, 7)
# (45,)

# %%
# # Generate predictions for the validation set
# Y_val_pred = best_model.predict(X_test_filtered)
# Y_val_pred = np.where(Y_val_pred > 0.15, 1, -1)

# # Plot the true values and predictions
# plt.figure(figsize=(10, 6))
# plt.plot(Y_test_filtered, label='True Values', color='blue', marker='o')
# plt.plot(Y_val_pred, label='Predictions', color='red', linestyle='dashed', marker='o')
# plt.title('Validation True Values vs Predictions')
# plt.xlabel('Sample Index')
# plt.ylabel('Value')
# plt.legend()
# plt.show()

# %%
# from sklearn.metrics import confusion_matrix

# # Create confusion matrix
# conf_matrix = confusion_matrix(Y_test_filtered.flatten(), Y_val_pred.flatten())

# # Print the confusion matrix
# print("Confusion Matrix:")
# print(conf_matrix)

# %%
# # Calculate total accuracy
# total_accuracy = np.sum(Y_test_filtered.flatten() == Y_val_pred.flatten()) / len(Y_test_filtered)
# print(f"Total Accuracy: {total_accuracy * 100:.2f}%")

# %%
import tensorflow as tf
from tensorflow.keras.layers import *
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, LSTM, Dense, Layer, Dropout

from tensorflow.keras.optimizers.legacy import Adam

from tensorflow.keras.regularizers import L1L2
from tensorflow.keras.layers import Layer, Dense, Dot, Activation

from tensorflow.keras.callbacks import Callback, EarlyStopping

from tensorflow.keras import backend as K

from matplotlib import pyplot as plt

K.clear_session()

   
l1 = 0.0
l2 = 0.0

lstm_dropout = 0.0
recurrent_dropout = 0.0
dense_dropout = 0.1
loss = 'mse'

n_target = Y_train.shape[-2:]

regularization_criteria = L1L2(l1=l1, l2=l2)

n_target_y = Y_train.shape[-1]

def build_model(input_shape):
    input_layer = Input(shape=input_shape, name='Input_1')
    sequence = input_layer
    sequence = LSTM(60, return_sequences = True,  name="LSTM-1", activation='tanh', recurrent_activation='tanh',kernel_regularizer = regularization_criteria, dropout=lstm_dropout, recurrent_dropout=recurrent_dropout)(input_layer)
    
    sequence = Flatten()(sequence)
    sequence = Dropout(0.2)(sequence)
    # sequence = LSTM(16, return_sequences = False,  name="LSTM-2", kernel_regularizer = regularization_criteria, dropout=lstm_dropout, recurrent_dropout=recurrent_dropout)(sequence)
    sequence = Dense(12, activation = 'tanh', name='Dense_3')(sequence)
    sequence = Dense(n_target_y, activation = 'tanh', name='Dense_4')(sequence)
    output_layer = sequence

    model = Model(inputs=input_layer, outputs=output_layer)

    return model

input_shape = (look_back, X_train.shape[2])

learning_rate = 0.0001

optimizer = Adam(learning_rate=learning_rate)

model = build_model(input_shape)
model.compile(optimizer=optimizer, loss=loss, metrics=[mse, rmse, r_square])
model.summary()

import time

start_time = time.time()

early_stopping = EarlyStopping(monitor='val_loss', patience=700, restore_best_weights=True)

history = model.fit(X_train, Y_train, epochs=1000, batch_size=64, validation_data=(X_val, Y_val),
                    callbacks=[early_stopping]
                    )

end_time = time.time()
difference_in_seconds = end_time - start_time
print(f"The difference in seconds is: {difference_in_seconds}")
# Out:
# WARNING:tensorflow:Layer LSTM-1 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  Input_1 (InputLayer)        [(None, 10, 7)]           0
#
#  LSTM-1 (LSTM)               (None, 10, 60)            16320
#
#  flatten (Flatten)           (None, 600)               0
#
#  dropout (Dropout)           (None, 600)               0
#
#  Dense_3 (Dense)             (None, 12)                7212
#
#  Dense_4 (Dense)             (None, 1)                 13
#
# =================================================================
# Total params: 23,545
# Trainable params: 23,545
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/1000
# 8/8 [==============================] - 3s 71ms/step - loss: 0.7738 - mse: 0.7738 - rmse: 0.7811 - r_square: -0.1456 - val_loss: 0.7859 - val_mse: 0.7859 - val_rmse: 0.7989 - val_r_square: -0.3006
# Epoch 2/1000
# 8/8 [==============================] - 0s 38ms/step - loss: 0.7683 - mse: 0.7683 - rmse: 0.7801 - r_square: -0.1284 - val_loss: 0.7780 - val_mse: 0.7780 - val_rmse: 0.7964 - val_r_square: -0.2875
# Epoch 3/1000
# 8/8 [==============================] - 0s 37ms/step - loss: 0.7624 - mse: 0.7624 - rmse: 0.7791 - r_square: -0.1101 - val_loss: 0.7705 - val_mse: 0.7705 - val_rmse: 0.7940 - val_r_square: -0.2751
# Epoch 4/1000
# 8/8 [==============================] - 0s 37ms/step - loss: 0.7586 - mse: 0.7586 - rmse: 0.7795 - r_square: -0.1027 - val_loss: 0.7627 - val_mse: 0.7627 - val_rmse: 0.7915 - val_r_square: -0.2622
# Epoch 5/1000
# 8/8 [==============================] - 0s 37ms/step - loss: 0.7532 - mse: 0.7532 - rmse: 0.7779 - r_square: -0.1233 - val_loss: 0.7552 - val_mse: 0.7552 - val_rmse: 0.7889 - val_r_square: -0.2497
# Epoch 6/1000
# 8/8 [==============================] - 0s 37ms/step - loss: 0.7485 - mse: 0.7485 - rmse: 0.7772 - r_square: -0.0977 - val_loss: 0.7473 - val_mse: 0.7473 - val_rmse: 0.7862 - val_r_square: -0.2367
# Epoch 7/1000
# 8/8 [==============================] - 0s 36ms/step - loss: 0.7435 - mse: 0.7435 - rmse: 0.7768 - r_square: -0.0983 - val_loss: 0.7394 - val_mse: 0.7394 - val_rmse: 0.7834 - val_r_square: -0.2236
# Epoch 8/1000
# 8/8 [==============================] - 0s 36ms/step - loss: 0.7384 - mse: 0.7384 - rmse: 0.7755 - r_square: -0.0819 - val_loss: 0.7311 - val_mse: 0.7311 - val_rmse: 0.7804 - val_r_square: -0.2098
# Epoch 9/1000
# 8/8 [==============================] - 0s 38ms/step - loss: 0.7323 - mse: 0.7323 - rmse: 0.7742 - r_square: -0.0676 - val_loss: 0.7229 - val_mse: 0.7229 - val_rmse: 0.7773 - val_r_square: -0.1963
# Epoch 10/1000
# 8/8 [==============================] - 0s 38ms/step - loss: 0.7278 - mse: 0.7278 - rmse: 0.7736 - r_square: -0.0665 - val_loss: 0.7142 - val_mse: 0.7142 - val_rmse: 0.7740 - val_r_square: -0.1820
# Epoch 11/1000
# 8/8 [==============================] - 0s 40ms/step - loss: 0.7252 - mse: 0.7252 - rmse: 0.7743 - r_square: -0.0535 - val_loss: 0.7054 - val_mse: 0.7054 - val_rmse: 0.7704 - val_r_square: -0.1673
# Epoch 12/1000
# 8/8 [==============================] - 0s 36ms/step - loss: 0.7193 - mse: 0.7193 - rmse: 0.7722 - r_square: -0.0903 - val_loss: 0.6976 - val_mse: 0.6976 - val_rmse: 0.7671 - val_r_square: -0.1544
# Epoch 13/1000
# 8/8 [==============================] - 0s 38ms/step - loss: 0.7162 - mse: 0.7162 - rmse: 0.7717 - r_square: -0.0436 - val_loss: 0.6884 - val_mse: 0.6884 - val_rmse: 0.7631 - val_r_square: -0.1393
# Epoch 14/1000
# 8/8 [==============================] - 0s 44ms/step - loss: 0.7115 - mse: 0.7115 - rmse: 0.7698 - r_square: -0.0358 - val_loss: 0.6806 - val_mse: 0.6806 - val_rmse: 0.7595 - val_r_square: -0.1263
# Epoch 15/1000
# 8/8 [==============================] - 0s 43ms/step - loss: 0.7081 - mse: 0.7081 - rmse: 0.7693 - r_square: -0.0279 - val_loss: 0.6735 - val_mse: 0.6735 - val_rmse: 0.7560 - val_r_square: -0.1145
# Epoch 16/1000
# 8/8 [==============================] - 0s 38ms/step - loss: 0.7069 - mse: 0.7069 - rmse: 0.7692 - r_square: -0.0342 - val_loss: 0.6673 - val_mse: 0.6673 - val_rmse: 0.7529 - val_r_square: -0.1043
# Epoch 17/1000
# 8/8 [==============================] - 0s 40ms/step - loss: 0.7028 - mse: 0.7028 - rmse: 0.7677 - r_square: -0.0316 - val_loss: 0.6613 - val_mse: 0.6613 - val_rmse: 0.7497 - val_r_square: -0.0943
# Epoch 18/1000
# 8/8 [==============================] - 0s 37ms/step - loss: 0.7016 - mse: 0.7016 - rmse: 0.7668 - r_square: -0.0256 - val_loss: 0.6552 - val_mse: 0.6552 - val_rmse: 0.7463 - val_r_square: -0.0843
# Epoch 19/1000
# 8/8 [==============================] - 0s 40ms/step - loss: 0.6985 - mse: 0.6985 - rmse: 0.7656 - r_square: -0.0425 - val_loss: 0.6518 - val_mse: 0.6518 - val_rmse: 0.7443 - val_r_square: -0.0787
# Epoch 20/1000
# 8/8 [==============================] - 0s 37ms/step - loss: 0.6982 - mse: 0.6982 - rmse: 0.7650 - r_square: -0.0174 - val_loss: 0.6470 - val_mse: 0.6470 - val_rmse: 0.7414 - val_r_square: -0.0707
# Epoch 21/1000
# 8/8 [==============================] - 0s 39ms/step - loss: 0.6980 - mse: 0.6980 - rmse: 0.7642 - r_square: -0.0147 - val_loss: 0.6435 - val_mse: 0.6435 - val_rmse: 0.7392 - val_r_square: -0.0649
# Epoch 22/1000
# 8/8 [==============================] - 0s 40ms/step - loss: 0.6958 - mse: 0.6958 - rmse: 0.7634 - r_square: -0.0182 - val_loss: 0.6411 - val_mse: 0.6411 - val_rmse: 0.7376 - val_r_square: -0.0610
# Epoch 23/1000
# 8/8 [==============================] - 0s 37ms/step - loss: 0.6963 - mse: 0.6963 - rmse: 0.7631 - r_square: -0.0086 - val_loss: 0.6391 - val_mse: 0.6391 - val_rmse: 0.7363 - val_r_square: -0.0576
# Epoch 24/1000
# 8/8 [==============================] - 0s 38ms/step - loss: 0.6960 - mse: 0.6960 - rmse: 0.7628 - r_square: -0.0212 - val_loss: 0.6380 - val_mse: 0.6380 - val_rmse: 0.7355 - val_r_square: -0.0558
# Epoch 25/1000
# 8/8 [==============================] - 0s 37ms/step - loss: 0.6945 - mse: 0.6945 - rmse: 0.7618 - r_square: -0.0240 - val_loss: 0.6375 - val_mse: 0.6375 - val_rmse: 0.7352 - val_r_square: -0.0550
# Epoch 26/1000
# 8/8 [==============================] - 0s 47ms/step - loss: 0.6938 - mse: 0.6938 - rmse: 0.7612 - r_square: -0.0087 - val_loss: 0.6362 - val_mse: 0.6362 - val_rmse: 0.7343 - val_r_square: -0.0529
# Epoch 27/1000
# 8/8 [==============================] - 0s 40ms/step - loss: 0.6951 - mse: 0.6951 - rmse: 0.7622 - r_square: -0.0134 - val_loss: 0.6349 - val_mse: 0.6349 - val_rmse: 0.7333 - val_r_square: -0.0507
# Epoch 28/1000
# 8/8 [==============================] - 0s 39ms/step - loss: 0.6935 - mse: 0.6935 - rmse: 0.7607 - r_square: -0.0095 - val_loss: 0.6341 - val_mse: 0.6341 - val_rmse: 0.7327 - val_r_square: -0.0494
# Epoch 29/1000
# 8/8 [==============================] - 0s 39ms/step - loss: 0.6933 - mse: 0.6933 - rmse: 0.7606 - r_square: -0.0099 - val_loss: 0.6337 - val_mse: 0.6337 - val_rmse: 0.7324 - val_r_square: -0.0487
# Epoch 30/1000
# 8/8 [==============================] - 0s 39ms/step - loss: 0.6939 - mse: 0.6939 - rmse: 0.7614 - r_square: -0.0356 - val_loss: 0.6340 - val_mse: 0.6340 - val_rmse: 0.7327 - val_r_square: -0.0492
# Epoch 31/1000
# 8/8 [==============================] - 0s 37ms/step - loss: 0.6921 - mse: 0.6921 - rmse: 0.7598 - r_square: -0.0136 - val_loss: 0.6340 - val_mse: 0.6340 - val_rmse: 0.7327 - val_r_square: -0.0492
# Epoch 32/1000
# 8/8 [==============================] - 0s 40ms/step - loss: 0.6935 - mse: 0.6935 - rmse: 0.7607 - r_square: -0.0148 - val_loss: 0.6346 - val_mse: 0.6346 - val_rmse: 0.7331 - val_r_square: -0.0502
# Epoch 33/1000
# 8/8 [==============================] - 0s 37ms/step - loss: 0.6929 - mse: 0.6929 - rmse: 0.7604 - r_square: -0.0159 - val_loss: 0.6350 - val_mse: 0.6350 - val_rmse: 0.7334 - val_r_square: -0.0508
# Epoch 34/1000
# 8/8 [==============================] - 0s 39ms/step - loss: 0.6917 - mse: 0.6917 - rmse: 0.7593 - r_square: -0.0023 - val_loss: 0.6352 - val_mse: 0.6352 - val_rmse: 0.7336 - val_r_square: -0.0512
# Epoch 35/1000
# 8/8 [==============================] - 0s 38ms/step - loss: 0.6902 - mse: 0.6902 - rmse: 0.7588 - r_square: -0.0299 - val_loss: 0.6343 - val_mse: 0.6343 - val_rmse: 0.7329 - val_r_square: -0.0497
# Epoch 36/1000
# 8/8 [==============================] - 0s 39ms/step - loss: 0.6915 - mse: 0.6915 - rmse: 0.7597 - r_square: -0.0260 - val_loss: 0.6344 - val_mse: 0.6344 - val_rmse: 0.7330 - val_r_square: -0.0498
# Epoch 37/1000
# 8/8 [==============================] - 0s 40ms/step - loss: 0.6884 - mse: 0.6884 - rmse: 0.7574 - r_square: -8.5028e-04 - val_loss: 0.6342 - val_mse: 0.6342 - val_rmse: 0.7328 - val_r_square: -0.0496
# Epoch 38/1000
# 8/8 [==============================] - 0s 42ms/step - loss: 0.6935 - mse: 0.6935 - rmse: 0.7604 - r_square: -0.0106 - val_loss: 0.6337 - val_mse: 0.6337 - val_rmse: 0.7324 - val_r_square: -0.0487
# Epoch 39/1000
# 8/8 [==============================] - 0s 38ms/step - loss: 0.6897 - mse: 0.6897 - rmse: 0.7583 - r_square: -0.0040 - val_loss: 0.6337 - val_mse: 0.6337 - val_rmse: 0.7324 - val_r_square: -0.0488
# Epoch 40/1000
# 8/8 [==============================] - 0s 41ms/step - loss: 0.6884 - mse: 0.6884 - rmse: 0.7575 - r_square: -0.0025 - val_loss: 0.6340 - val_mse: 0.6340 - val_rmse: 0.7326 - val_r_square: -0.0492
# Epoch 41/1000
# 8/8 [==============================] - 0s 41ms/step - loss: 0.6906 - mse: 0.6906 - rmse: 0.7585 - r_square: -0.0123 - val_loss: 0.6348 - val_mse: 0.6348 - val_rmse: 0.7332 - val_r_square: -0.0506
# Epoch 42/1000
# 8/8 [==============================] - 0s 39ms/step - loss: 0.6879 - mse: 0.6879 - rmse: 0.7567 - r_square: -0.0091 - val_loss: 0.6355 - val_mse: 0.6355 - val_rmse: 0.7337 - val_r_square: -0.0517
# Epoch 43/1000
# 8/8 [==============================] - 0s 43ms/step - loss: 0.6872 - mse: 0.6872 - rmse: 0.7571 - r_square: -0.0081 - val_loss: 0.6351 - val_mse: 0.6351 - val_rmse: 0.7333 - val_r_square: -0.0510
# Epoch 44/1000
# 8/8 [==============================] - 0s 40ms/step - loss: 0.6864 - mse: 0.6864 - rmse: 0.7562 - r_square: -0.0088 - val_loss: 0.6348 - val_mse: 0.6348 - val_rmse: 0.7330 - val_r_square: -0.0504
# Epoch 45/1000
# 8/8 [==============================] - 0s 39ms/step - loss: 0.6870 - mse: 0.6870 - rmse: 0.7564 - r_square: -0.0146 - val_loss: 0.6349 - val_mse: 0.6349 - val_rmse: 0.7331 - val_r_square: -0.0507
# Epoch 46/1000
# 8/8 [==============================] - 0s 42ms/step - loss: 0.6861 - mse: 0.6861 - rmse: 0.7562 - r_square: 0.0020 - val_loss: 0.6348 - val_mse: 0.6348 - val_rmse: 0.7329 - val_r_square: -0.0504
# Epoch 47/1000
# 8/8 [==============================] - 0s 38ms/step - loss: 0.6862 - mse: 0.6862 - rmse: 0.7563 - r_square: 0.0017 - val_loss: 0.6350 - val_mse: 0.6350 - val_rmse: 0.7330 - val_r_square: -0.0508
# Epoch 48/1000
# 8/8 [==============================] - 0s 41ms/step - loss: 0.6852 - mse: 0.6852 - rmse: 0.7558 - r_square: 0.0080 - val_loss: 0.6355 - val_mse: 0.6355 - val_rmse: 0.7334 - val_r_square: -0.0517
# Epoch 49/1000
# 8/8 [==============================] - 0s 39ms/step - loss: 0.6834 - mse: 0.6834 - rmse: 0.7541 - r_square: -2.2509e-04 - val_loss: 0.6358 - val_mse: 0.6358 - val_rmse: 0.7335 - val_r_square: -0.0521
# Epoch 50/1000
# 8/8 [==============================] - 0s 41ms/step - loss: 0.6856 - mse: 0.6856 - rmse: 0.7560 - r_square: -0.0074 - val_loss: 0.6370 - val_mse: 0.6370 - val_rmse: 0.7344 - val_r_square: -0.0542
# Epoch 51/1000
# 8/8 [==============================] - 0s 47ms/step - loss: 0.6857 - mse: 0.6857 - rmse: 0.7558 - r_square: -0.0092 - val_loss: 0.6374 - val_mse: 0.6374 - val_rmse: 0.7345 - val_r_square: -0.0547
# Epoch 52/1000
# 8/8 [==============================] - 0s 41ms/step - loss: 0.6848 - mse: 0.6848 - rmse: 0.7549 - r_square: 0.0037 - val_loss: 0.6376 - val_mse: 0.6376 - val_rmse: 0.7346 - val_r_square: -0.0551
# Epoch 53/1000
# 8/8 [==============================] - 0s 41ms/step - loss: 0.6823 - mse: 0.6823 - rmse: 0.7539 - r_square: -0.0110 - val_loss: 0.6380 - val_mse: 0.6380 - val_rmse: 0.7349 - val_r_square: -0.0558
# Epoch 54/1000
# 8/8 [==============================] - 0s 39ms/step - loss: 0.6832 - mse: 0.6832 - rmse: 0.7545 - r_square: 0.0090 - val_loss: 0.6382 - val_mse: 0.6382 - val_rmse: 0.7350 - val_r_square: -0.0562
# Epoch 55/1000
# 8/8 [==============================] - 0s 42ms/step - loss: 0.6812 - mse: 0.6812 - rmse: 0.7531 - r_square: 0.0092 - val_loss: 0.6384 - val_mse: 0.6384 - val_rmse: 0.7350 - val_r_square: -0.0565
# Epoch 56/1000
# 8/8 [==============================] - 0s 38ms/step - loss: 0.6802 - mse: 0.6802 - rmse: 0.7522 - r_square: 0.0120 - val_loss: 0.6380 - val_mse: 0.6380 - val_rmse: 0.7346 - val_r_square: -0.0559
# Epoch 57/1000
# 8/8 [==============================] - 0s 40ms/step - loss: 0.6822 - mse: 0.6822 - rmse: 0.7530 - r_square: 0.0068 - val_loss: 0.6380 - val_mse: 0.6380 - val_rmse: 0.7345 - val_r_square: -0.0559
# Epoch 58/1000
# 8/8 [==============================] - 0s 42ms/step - loss: 0.6809 - mse: 0.6809 - rmse: 0.7529 - r_square: 0.0090 - val_loss: 0.6381 - val_mse: 0.6381 - val_rmse: 0.7345 - val_r_square: -0.0560
# Epoch 59/1000
# 8/8 [==============================] - 0s 40ms/step - loss: 0.6805 - mse: 0.6805 - rmse: 0.7522 - r_square: 0.0085 - val_loss: 0.6393 - val_mse: 0.6393 - val_rmse: 0.7352 - val_r_square: -0.0579
# Epoch 60/1000
# 8/8 [==============================] - 0s 41ms/step - loss: 0.6781 - mse: 0.6781 - rmse: 0.7511 - r_square: 0.0180 - val_loss: 0.6403 - val_mse: 0.6403 - val_rmse: 0.7358 - val_r_square: -0.0597
# Epoch 61/1000
# 8/8 [==============================] - 0s 41ms/step - loss: 0.6776 - mse: 0.6776 - rmse: 0.7507 - r_square: -0.0024 - val_loss: 0.6413 - val_mse: 0.6413 - val_rmse: 0.7364 - val_r_square: -0.0613
# Epoch 62/1000
# 8/8 [==============================] - 1s 74ms/step - loss: 0.6771 - mse: 0.6771 - rmse: 0.7506 - r_square: 0.0066 - val_loss: 0.6415 - val_mse: 0.6415 - val_rmse: 0.7364 - val_r_square: -0.0617
# Epoch 63/1000
# 8/8 [==============================] - 1s 73ms/step - loss: 0.6765 - mse: 0.6765 - rmse: 0.7503 - r_square: 0.0153 - val_loss: 0.6411 - val_mse: 0.6411 - val_rmse: 0.7359 - val_r_square: -0.0609
# Epoch 64/1000
# 8/8 [==============================] - 1s 72ms/step - loss: 0.6785 - mse: 0.6785 - rmse: 0.7509 - r_square: 0.0072 - val_loss: 0.6414 - val_mse: 0.6414 - val_rmse: 0.7359 - val_r_square: -0.0615
# Epoch 65/1000
# 8/8 [==============================] - 1s 71ms/step - loss: 0.6761 - mse: 0.6761 - rmse: 0.7490 - r_square: 0.0143 - val_loss: 0.6415 - val_mse: 0.6415 - val_rmse: 0.7358 - val_r_square: -0.0615
# Epoch 66/1000
# 8/8 [==============================] - 1s 74ms/step - loss: 0.6788 - mse: 0.6788 - rmse: 0.7500 - r_square: 0.0112 - val_loss: 0.6426 - val_mse: 0.6426 - val_rmse: 0.7364 - val_r_square: -0.0634
# Epoch 67/1000
# 8/8 [==============================] - 1s 91ms/step - loss: 0.6757 - mse: 0.6757 - rmse: 0.7487 - r_square: 0.0215 - val_loss: 0.6438 - val_mse: 0.6438 - val_rmse: 0.7371 - val_r_square: -0.0654
# Epoch 68/1000
# 8/8 [==============================] - 1s 75ms/step - loss: 0.6726 - mse: 0.6726 - rmse: 0.7473 - r_square: 0.0122 - val_loss: 0.6447 - val_mse: 0.6447 - val_rmse: 0.7375 - val_r_square: -0.0668
# Epoch 69/1000
# 8/8 [==============================] - 1s 72ms/step - loss: 0.6753 - mse: 0.6753 - rmse: 0.7486 - r_square: 0.0221 - val_loss: 0.6449 - val_mse: 0.6449 - val_rmse: 0.7375 - val_r_square: -0.0672
# Epoch 70/1000
# 8/8 [==============================] - 1s 72ms/step - loss: 0.6725 - mse: 0.6725 - rmse: 0.7466 - r_square: 0.0268 - val_loss: 0.6451 - val_mse: 0.6451 - val_rmse: 0.7375 - val_r_square: -0.0675
# Epoch 71/1000
# 8/8 [==============================] - 1s 73ms/step - loss: 0.6718 - mse: 0.6718 - rmse: 0.7463 - r_square: 0.0259 - val_loss: 0.6457 - val_mse: 0.6457 - val_rmse: 0.7377 - val_r_square: -0.0686
# Epoch 72/1000
# 8/8 [==============================] - 1s 71ms/step - loss: 0.6728 - mse: 0.6728 - rmse: 0.7464 - r_square: 0.0102 - val_loss: 0.6472 - val_mse: 0.6472 - val_rmse: 0.7384 - val_r_square: -0.0710
# Epoch 73/1000
# 8/8 [==============================] - 1s 73ms/step - loss: 0.6689 - mse: 0.6689 - rmse: 0.7446 - r_square: 0.0230 - val_loss: 0.6473 - val_mse: 0.6473 - val_rmse: 0.7383 - val_r_square: -0.0713
# Epoch 74/1000
# 8/8 [==============================] - 1s 74ms/step - loss: 0.6680 - mse: 0.6680 - rmse: 0.7438 - r_square: 0.0280 - val_loss: 0.6476 - val_mse: 0.6476 - val_rmse: 0.7382 - val_r_square: -0.0716
# Epoch 75/1000
# 8/8 [==============================] - 1s 74ms/step - loss: 0.6681 - mse: 0.6681 - rmse: 0.7440 - r_square: 0.0304 - val_loss: 0.6488 - val_mse: 0.6488 - val_rmse: 0.7388 - val_r_square: -0.0737
# Epoch 76/1000
# 8/8 [==============================] - 1s 71ms/step - loss: 0.6674 - mse: 0.6674 - rmse: 0.7432 - r_square: 0.0091 - val_loss: 0.6492 - val_mse: 0.6492 - val_rmse: 0.7388 - val_r_square: -0.0743
# Epoch 77/1000
# 8/8 [==============================] - 1s 72ms/step - loss: 0.6686 - mse: 0.6686 - rmse: 0.7439 - r_square: 0.0249 - val_loss: 0.6506 - val_mse: 0.6506 - val_rmse: 0.7394 - val_r_square: -0.0766
# Epoch 78/1000
# 8/8 [==============================] - 1s 97ms/step - loss: 0.6656 - mse: 0.6656 - rmse: 0.7414 - r_square: 0.0241 - val_loss: 0.6516 - val_mse: 0.6516 - val_rmse: 0.7398 - val_r_square: -0.0784
# Epoch 79/1000
# 8/8 [==============================] - 1s 73ms/step - loss: 0.6643 - mse: 0.6643 - rmse: 0.7417 - r_square: 0.0208 - val_loss: 0.6534 - val_mse: 0.6534 - val_rmse: 0.7406 - val_r_square: -0.0813
# Epoch 80/1000
# 8/8 [==============================] - 1s 75ms/step - loss: 0.6626 - mse: 0.6626 - rmse: 0.7405 - r_square: 0.0286 - val_loss: 0.6535 - val_mse: 0.6535 - val_rmse: 0.7403 - val_r_square: -0.0815
# Epoch 81/1000
# 8/8 [==============================] - 1s 74ms/step - loss: 0.6626 - mse: 0.6626 - rmse: 0.7404 - r_square: 0.0228 - val_loss: 0.6542 - val_mse: 0.6542 - val_rmse: 0.7405 - val_r_square: -0.0826
# Epoch 82/1000
# 8/8 [==============================] - 1s 72ms/step - loss: 0.6627 - mse: 0.6627 - rmse: 0.7396 - r_square: 0.0330 - val_loss: 0.6551 - val_mse: 0.6551 - val_rmse: 0.7407 - val_r_square: -0.0841
# Epoch 83/1000
# 8/8 [==============================] - 1s 74ms/step - loss: 0.6643 - mse: 0.6643 - rmse: 0.7403 - r_square: 0.0333 - val_loss: 0.6565 - val_mse: 0.6565 - val_rmse: 0.7413 - val_r_square: -0.0864
# Epoch 84/1000
# 8/8 [==============================] - 1s 73ms/step - loss: 0.6600 - mse: 0.6600 - rmse: 0.7375 - r_square: 0.0426 - val_loss: 0.6577 - val_mse: 0.6577 - val_rmse: 0.7417 - val_r_square: -0.0884
# Epoch 85/1000
# 8/8 [==============================] - 1s 73ms/step - loss: 0.6588 - mse: 0.6588 - rmse: 0.7364 - r_square: 0.0476 - val_loss: 0.6589 - val_mse: 0.6589 - val_rmse: 0.7421 - val_r_square: -0.0904
# Epoch 86/1000
# 8/8 [==============================] - 1s 72ms/step - loss: 0.6611 - mse: 0.6611 - rmse: 0.7373 - r_square: 0.0372 - val_loss: 0.6610 - val_mse: 0.6610 - val_rmse: 0.7431 - val_r_square: -0.0939
# Epoch 87/1000
# 8/8 [==============================] - 1s 72ms/step - loss: 0.6590 - mse: 0.6590 - rmse: 0.7361 - r_square: 0.0424 - val_loss: 0.6607 - val_mse: 0.6607 - val_rmse: 0.7425 - val_r_square: -0.0934
# Epoch 88/1000
# 8/8 [==============================] - 1s 73ms/step - loss: 0.6617 - mse: 0.6617 - rmse: 0.7381 - r_square: 0.0410 - val_loss: 0.6616 - val_mse: 0.6616 - val_rmse: 0.7428 - val_r_square: -0.0949
# Epoch 89/1000
# 8/8 [==============================] - 1s 91ms/step - loss: 0.6545 - mse: 0.6545 - rmse: 0.7328 - r_square: 0.0363 - val_loss: 0.6639 - val_mse: 0.6639 - val_rmse: 0.7438 - val_r_square: -0.0987
# Epoch 90/1000
# 8/8 [==============================] - 1s 73ms/step - loss: 0.6554 - mse: 0.6554 - rmse: 0.7341 - r_square: 0.0370 - val_loss: 0.6652 - val_mse: 0.6652 - val_rmse: 0.7443 - val_r_square: -0.1009
# Epoch 91/1000
# 8/8 [==============================] - 1s 73ms/step - loss: 0.6560 - mse: 0.6560 - rmse: 0.7329 - r_square: 0.0429 - val_loss: 0.6643 - val_mse: 0.6643 - val_rmse: 0.7434 - val_r_square: -0.0993
# Epoch 92/1000
# 8/8 [==============================] - 1s 73ms/step - loss: 0.6560 - mse: 0.6560 - rmse: 0.7329 - r_square: 0.0421 - val_loss: 0.6634 - val_mse: 0.6634 - val_rmse: 0.7425 - val_r_square: -0.0979
# Epoch 93/1000
# 8/8 [==============================] - 1s 73ms/step - loss: 0.6526 - mse: 0.6526 - rmse: 0.7302 - r_square: 0.0495 - val_loss: 0.6657 - val_mse: 0.6657 - val_rmse: 0.7435 - val_r_square: -0.1017
# Epoch 94/1000
# 8/8 [==============================] - 1s 78ms/step - loss: 0.6571 - mse: 0.6571 - rmse: 0.7333 - r_square: 0.0356 - val_loss: 0.6661 - val_mse: 0.6661 - val_rmse: 0.7435 - val_r_square: -0.1022
# Epoch 95/1000
# 8/8 [==============================] - 1s 76ms/step - loss: 0.6554 - mse: 0.6554 - rmse: 0.7330 - r_square: 0.0504 - val_loss: 0.6685 - val_mse: 0.6685 - val_rmse: 0.7446 - val_r_square: -0.1063
# Epoch 96/1000
# 8/8 [==============================] - 1s 71ms/step - loss: 0.6511 - mse: 0.6511 - rmse: 0.7284 - r_square: 0.0557 - val_loss: 0.6700 - val_mse: 0.6700 - val_rmse: 0.7453 - val_r_square: -0.1088
# Epoch 97/1000
# 8/8 [==============================] - 1s 71ms/step - loss: 0.6495 - mse: 0.6495 - rmse: 0.7303 - r_square: 0.0470 - val_loss: 0.6717 - val_mse: 0.6717 - val_rmse: 0.7459 - val_r_square: -0.1116
# Epoch 98/1000
# 8/8 [==============================] - 1s 80ms/step - loss: 0.6520 - mse: 0.6520 - rmse: 0.7294 - r_square: 0.0542 - val_loss: 0.6734 - val_mse: 0.6734 - val_rmse: 0.7465 - val_r_square: -0.1144
# Epoch 99/1000
# 8/8 [==============================] - 1s 72ms/step - loss: 0.6493 - mse: 0.6493 - rmse: 0.7286 - r_square: 0.0423 - val_loss: 0.6736 - val_mse: 0.6736 - val_rmse: 0.7461 - val_r_square: -0.1147
# Epoch 100/1000
# 8/8 [==============================] - 1s 74ms/step - loss: 0.6483 - mse: 0.6483 - rmse: 0.7269 - r_square: 0.0520 - val_loss: 0.6749 - val_mse: 0.6749 - val_rmse: 0.7465 - val_r_square: -0.1168
# Epoch 101/1000
# 8/8 [==============================] - 1s 73ms/step - loss: 0.6493 - mse: 0.6493 - rmse: 0.7283 - r_square: 0.0569 - val_loss: 0.6762 - val_mse: 0.6762 - val_rmse: 0.7469 - val_r_square: -0.1191
# Epoch 102/1000
# 8/8 [==============================] - 1s 73ms/step - loss: 0.6478 - mse: 0.6478 - rmse: 0.7257 - r_square: 0.0533 - val_loss: 0.6771 - val_mse: 0.6771 - val_rmse: 0.7471 - val_r_square: -0.1205
# Epoch 103/1000
# 8/8 [==============================] - 1s 75ms/step - loss: 0.6467 - mse: 0.6467 - rmse: 0.7242 - r_square: 0.0547 - val_loss: 0.6776 - val_mse: 0.6776 - val_rmse: 0.7472 - val_r_square: -0.1214
# Epoch 104/1000
# 8/8 [==============================] - 1s 70ms/step - loss: 0.6403 - mse: 0.6403 - rmse: 0.7224 - r_square: 0.0648 - val_loss: 0.6787 - val_mse: 0.6787 - val_rmse: 0.7474 - val_r_square: -0.1232
# Epoch 105/1000
# 8/8 [==============================] - 1s 70ms/step - loss: 0.6452 - mse: 0.6452 - rmse: 0.7238 - r_square: 0.0648 - val_loss: 0.6808 - val_mse: 0.6808 - val_rmse: 0.7481 - val_r_square: -0.1267
# Epoch 106/1000
# 8/8 [==============================] - 1s 70ms/step - loss: 0.6432 - mse: 0.6432 - rmse: 0.7225 - r_square: 0.0672 - val_loss: 0.6817 - val_mse: 0.6817 - val_rmse: 0.7483 - val_r_square: -0.1281
# Epoch 107/1000
# 8/8 [==============================] - 1s 70ms/step - loss: 0.6463 - mse: 0.6463 - rmse: 0.7240 - r_square: 0.0557 - val_loss: 0.6815 - val_mse: 0.6815 - val_rmse: 0.7478 - val_r_square: -0.1277
# Epoch 108/1000
# 8/8 [==============================] - 1s 73ms/step - loss: 0.6402 - mse: 0.6402 - rmse: 0.7215 - r_square: 0.0490 - val_loss: 0.6813 - val_mse: 0.6813 - val_rmse: 0.7473 - val_r_square: -0.1274
# Epoch 109/1000
# 8/8 [==============================] - 1s 94ms/step - loss: 0.6396 - mse: 0.6396 - rmse: 0.7213 - r_square: 0.0520 - val_loss: 0.6832 - val_mse: 0.6832 - val_rmse: 0.7482 - val_r_square: -0.1306
# Epoch 110/1000
# 8/8 [==============================] - 1s 71ms/step - loss: 0.6404 - mse: 0.6404 - rmse: 0.7208 - r_square: 0.0658 - val_loss: 0.6854 - val_mse: 0.6854 - val_rmse: 0.7492 - val_r_square: -0.1343
# Epoch 111/1000
# 8/8 [==============================] - 1s 75ms/step - loss: 0.6446 - mse: 0.6446 - rmse: 0.7218 - r_square: 0.0628 - val_loss: 0.6871 - val_mse: 0.6871 - val_rmse: 0.7499 - val_r_square: -0.1370
# Epoch 112/1000
# 8/8 [==============================] - 1s 72ms/step - loss: 0.6402 - mse: 0.6402 - rmse: 0.7200 - r_square: 0.0721 - val_loss: 0.6882 - val_mse: 0.6882 - val_rmse: 0.7503 - val_r_square: -0.1389
# Epoch 113/1000
# 8/8 [==============================] - 1s 73ms/step - loss: 0.6367 - mse: 0.6367 - rmse: 0.7183 - r_square: 0.0711 - val_loss: 0.6919 - val_mse: 0.6919 - val_rmse: 0.7523 - val_r_square: -0.1450
# Epoch 114/1000
# 8/8 [==============================] - 1s 70ms/step - loss: 0.6399 - mse: 0.6399 - rmse: 0.7202 - r_square: 0.0751 - val_loss: 0.6919 - val_mse: 0.6919 - val_rmse: 0.7521 - val_r_square: -0.1449
# Epoch 115/1000
# 8/8 [==============================] - 1s 73ms/step - loss: 0.6354 - mse: 0.6354 - rmse: 0.7167 - r_square: 0.0823 - val_loss: 0.6928 - val_mse: 0.6928 - val_rmse: 0.7525 - val_r_square: -0.1464
# Epoch 116/1000
# 8/8 [==============================] - 1s 70ms/step - loss: 0.6273 - mse: 0.6273 - rmse: 0.7124 - r_square: 0.0923 - val_loss: 0.6939 - val_mse: 0.6939 - val_rmse: 0.7529 - val_r_square: -0.1483
# Epoch 117/1000
# 8/8 [==============================] - 1s 71ms/step - loss: 0.6380 - mse: 0.6380 - rmse: 0.7168 - r_square: 0.0740 - val_loss: 0.6945 - val_mse: 0.6945 - val_rmse: 0.7529 - val_r_square: -0.1493
# Epoch 118/1000
# 8/8 [==============================] - 1s 82ms/step - loss: 0.6343 - mse: 0.6343 - rmse: 0.7163 - r_square: 0.0699 - val_loss: 0.6951 - val_mse: 0.6951 - val_rmse: 0.7531 - val_r_square: -0.1503
# Epoch 119/1000
# 8/8 [==============================] - 1s 90ms/step - loss: 0.6304 - mse: 0.6304 - rmse: 0.7140 - r_square: 0.0786 - val_loss: 0.6988 - val_mse: 0.6988 - val_rmse: 0.7551 - val_r_square: -0.1564
# Epoch 120/1000
# 8/8 [==============================] - 1s 70ms/step - loss: 0.6293 - mse: 0.6293 - rmse: 0.7138 - r_square: 0.0711 - val_loss: 0.6990 - val_mse: 0.6990 - val_rmse: 0.7550 - val_r_square: -0.1568
# Epoch 121/1000
# 8/8 [==============================] - 1s 73ms/step - loss: 0.6273 - mse: 0.6273 - rmse: 0.7095 - r_square: 0.0696 - val_loss: 0.6989 - val_mse: 0.6989 - val_rmse: 0.7549 - val_r_square: -0.1567
# Epoch 122/1000
# 8/8 [==============================] - 1s 70ms/step - loss: 0.6323 - mse: 0.6323 - rmse: 0.7130 - r_square: 0.0824 - val_loss: 0.7010 - val_mse: 0.7010 - val_rmse: 0.7560 - val_r_square: -0.1601
# Epoch 123/1000
# 8/8 [==============================] - 1s 70ms/step - loss: 0.6280 - mse: 0.6280 - rmse: 0.7107 - r_square: 0.0838 - val_loss: 0.7029 - val_mse: 0.7029 - val_rmse: 0.7570 - val_r_square: -0.1633
# Epoch 124/1000
# 8/8 [==============================] - 1s 72ms/step - loss: 0.6282 - mse: 0.6282 - rmse: 0.7115 - r_square: 0.0871 - val_loss: 0.7045 - val_mse: 0.7045 - val_rmse: 0.7579 - val_r_square: -0.1659
# Epoch 125/1000
# 8/8 [==============================] - 1s 101ms/step - loss: 0.6238 - mse: 0.6238 - rmse: 0.7095 - r_square: 0.0879 - val_loss: 0.7045 - val_mse: 0.7045 - val_rmse: 0.7577 - val_r_square: -0.1659
# Epoch 126/1000
# 8/8 [==============================] - 1s 76ms/step - loss: 0.6168 - mse: 0.6168 - rmse: 0.7057 - r_square: 0.1020 - val_loss: 0.7096 - val_mse: 0.7096 - val_rmse: 0.7608 - val_r_square: -0.1744
# Epoch 127/1000
# 8/8 [==============================] - 1s 72ms/step - loss: 0.6284 - mse: 0.6284 - rmse: 0.7118 - r_square: 0.0801 - val_loss: 0.7115 - val_mse: 0.7115 - val_rmse: 0.7617 - val_r_square: -0.1775
# Epoch 128/1000
# 8/8 [==============================] - 1s 89ms/step - loss: 0.6294 - mse: 0.6294 - rmse: 0.7104 - r_square: 0.0862 - val_loss: 0.7112 - val_mse: 0.7112 - val_rmse: 0.7614 - val_r_square: -0.1769
# Epoch 129/1000
# 8/8 [==============================] - 1s 72ms/step - loss: 0.6219 - mse: 0.6219 - rmse: 0.7069 - r_square: 0.0763 - val_loss: 0.7093 - val_mse: 0.7093 - val_rmse: 0.7601 - val_r_square: -0.1738
# Epoch 130/1000
# 8/8 [==============================] - 1s 69ms/step - loss: 0.6212 - mse: 0.6212 - rmse: 0.7064 - r_square: 0.0831 - val_loss: 0.7135 - val_mse: 0.7135 - val_rmse: 0.7625 - val_r_square: -0.1808
# Epoch 131/1000
# 8/8 [==============================] - 1s 95ms/step - loss: 0.6183 - mse: 0.6183 - rmse: 0.7062 - r_square: 0.0978 - val_loss: 0.7119 - val_mse: 0.7119 - val_rmse: 0.7614 - val_r_square: -0.1781
# Epoch 132/1000
# 8/8 [==============================] - 1s 71ms/step - loss: 0.6251 - mse: 0.6251 - rmse: 0.7099 - r_square: 0.0915 - val_loss: 0.7124 - val_mse: 0.7124 - val_rmse: 0.7617 - val_r_square: -0.1790
# Epoch 133/1000
# 8/8 [==============================] - 1s 71ms/step - loss: 0.6153 - mse: 0.6153 - rmse: 0.7028 - r_square: 0.0953 - val_loss: 0.7106 - val_mse: 0.7106 - val_rmse: 0.7603 - val_r_square: -0.1759
# Epoch 134/1000
# 8/8 [==============================] - 1s 73ms/step - loss: 0.6128 - mse: 0.6128 - rmse: 0.7012 - r_square: 0.1068 - val_loss: 0.7136 - val_mse: 0.7136 - val_rmse: 0.7620 - val_r_square: -0.1810
# Epoch 135/1000
# 8/8 [==============================] - 1s 87ms/step - loss: 0.6164 - mse: 0.6164 - rmse: 0.7037 - r_square: 0.0997 - val_loss: 0.7160 - val_mse: 0.7160 - val_rmse: 0.7632 - val_r_square: -0.1848
# Epoch 136/1000
# 8/8 [==============================] - 1s 89ms/step - loss: 0.6088 - mse: 0.6088 - rmse: 0.6982 - r_square: 0.1138 - val_loss: 0.7148 - val_mse: 0.7148 - val_rmse: 0.7622 - val_r_square: -0.1829
# Epoch 137/1000
# 8/8 [==============================] - 1s 102ms/step - loss: 0.6097 - mse: 0.6097 - rmse: 0.6983 - r_square: 0.1070 - val_loss: 0.7169 - val_mse: 0.7169 - val_rmse: 0.7633 - val_r_square: -0.1863
# Epoch 138/1000
# 8/8 [==============================] - 1s 90ms/step - loss: 0.6088 - mse: 0.6088 - rmse: 0.6980 - r_square: 0.1130 - val_loss: 0.7193 - val_mse: 0.7193 - val_rmse: 0.7646 - val_r_square: -0.1903
# Epoch 139/1000
# 8/8 [==============================] - 1s 93ms/step - loss: 0.6128 - mse: 0.6128 - rmse: 0.6990 - r_square: 0.1167 - val_loss: 0.7223 - val_mse: 0.7223 - val_rmse: 0.7664 - val_r_square: -0.1953
# Epoch 140/1000
# 8/8 [==============================] - 1s 86ms/step - loss: 0.6088 - mse: 0.6088 - rmse: 0.6981 - r_square: 0.1023 - val_loss: 0.7233 - val_mse: 0.7233 - val_rmse: 0.7669 - val_r_square: -0.1969
# Epoch 141/1000
# 8/8 [==============================] - 1s 77ms/step - loss: 0.6005 - mse: 0.6005 - rmse: 0.6929 - r_square: 0.1280 - val_loss: 0.7252 - val_mse: 0.7252 - val_rmse: 0.7679 - val_r_square: -0.2002
# Epoch 142/1000
# 8/8 [==============================] - 1s 72ms/step - loss: 0.6081 - mse: 0.6081 - rmse: 0.6958 - r_square: 0.1075 - val_loss: 0.7266 - val_mse: 0.7266 - val_rmse: 0.7685 - val_r_square: -0.2025
# Epoch 143/1000
# 8/8 [==============================] - 1s 72ms/step - loss: 0.6111 - mse: 0.6111 - rmse: 0.6976 - r_square: 0.1108 - val_loss: 0.7303 - val_mse: 0.7303 - val_rmse: 0.7709 - val_r_square: -0.2086
# Epoch 144/1000
# 8/8 [==============================] - 1s 76ms/step - loss: 0.6045 - mse: 0.6045 - rmse: 0.6978 - r_square: 0.1068 - val_loss: 0.7315 - val_mse: 0.7315 - val_rmse: 0.7713 - val_r_square: -0.2106
# Epoch 145/1000
# 8/8 [==============================] - 1s 96ms/step - loss: 0.6090 - mse: 0.6090 - rmse: 0.6973 - r_square: 0.1170 - val_loss: 0.7305 - val_mse: 0.7305 - val_rmse: 0.7702 - val_r_square: -0.2089
# Epoch 146/1000
# 8/8 [==============================] - 1s 74ms/step - loss: 0.6035 - mse: 0.6035 - rmse: 0.6937 - r_square: 0.1031 - val_loss: 0.7314 - val_mse: 0.7314 - val_rmse: 0.7706 - val_r_square: -0.2103
# Epoch 147/1000
# 8/8 [==============================] - 1s 73ms/step - loss: 0.5999 - mse: 0.5999 - rmse: 0.6891 - r_square: 0.1257 - val_loss: 0.7349 - val_mse: 0.7349 - val_rmse: 0.7727 - val_r_square: -0.2162
# Epoch 148/1000
# 8/8 [==============================] - 1s 73ms/step - loss: 0.6088 - mse: 0.6088 - rmse: 0.6971 - r_square: 0.1092 - val_loss: 0.7377 - val_mse: 0.7377 - val_rmse: 0.7743 - val_r_square: -0.2208
# Epoch 149/1000
# 8/8 [==============================] - 1s 73ms/step - loss: 0.5996 - mse: 0.5996 - rmse: 0.6912 - r_square: 0.1117 - val_loss: 0.7387 - val_mse: 0.7387 - val_rmse: 0.7749 - val_r_square: -0.2225
# Epoch 150/1000
# 8/8 [==============================] - 1s 71ms/step - loss: 0.6007 - mse: 0.6007 - rmse: 0.6899 - r_square: 0.1256 - val_loss: 0.7368 - val_mse: 0.7368 - val_rmse: 0.7736 - val_r_square: -0.2193
# Epoch 151/1000
# 8/8 [==============================] - 1s 74ms/step - loss: 0.5993 - mse: 0.5993 - rmse: 0.6907 - r_square: 0.1209 - val_loss: 0.7353 - val_mse: 0.7353 - val_rmse: 0.7723 - val_r_square: -0.2169
# Epoch 152/1000
# 8/8 [==============================] - 1s 74ms/step - loss: 0.6014 - mse: 0.6014 - rmse: 0.6902 - r_square: 0.1313 - val_loss: 0.7390 - val_mse: 0.7390 - val_rmse: 0.7746 - val_r_square: -0.2229
# Epoch 153/1000
# 8/8 [==============================] - 1s 71ms/step - loss: 0.5952 - mse: 0.5952 - rmse: 0.6867 - r_square: 0.1215 - val_loss: 0.7429 - val_mse: 0.7429 - val_rmse: 0.7768 - val_r_square: -0.2295
# Epoch 154/1000
# 8/8 [==============================] - 1s 88ms/step - loss: 0.5927 - mse: 0.5927 - rmse: 0.6869 - r_square: 0.1367 - val_loss: 0.7427 - val_mse: 0.7427 - val_rmse: 0.7765 - val_r_square: -0.2291
# Epoch 155/1000
# 8/8 [==============================] - 1s 71ms/step - loss: 0.5921 - mse: 0.5921 - rmse: 0.6839 - r_square: 0.1183 - val_loss: 0.7499 - val_mse: 0.7499 - val_rmse: 0.7807 - val_r_square: -0.2410
# Epoch 156/1000
# 8/8 [==============================] - 1s 74ms/step - loss: 0.5890 - mse: 0.5890 - rmse: 0.6837 - r_square: 0.1411 - val_loss: 0.7458 - val_mse: 0.7458 - val_rmse: 0.7780 - val_r_square: -0.2342
# Epoch 157/1000
# 8/8 [==============================] - 1s 72ms/step - loss: 0.5954 - mse: 0.5954 - rmse: 0.6849 - r_square: 0.1400 - val_loss: 0.7482 - val_mse: 0.7482 - val_rmse: 0.7792 - val_r_square: -0.2381
# Epoch 158/1000
# 8/8 [==============================] - 1s 71ms/step - loss: 0.5877 - mse: 0.5877 - rmse: 0.6828 - r_square: 0.1468 - val_loss: 0.7454 - val_mse: 0.7454 - val_rmse: 0.7774 - val_r_square: -0.2336
# Epoch 159/1000
# 8/8 [==============================] - 1s 71ms/step - loss: 0.5818 - mse: 0.5818 - rmse: 0.6796 - r_square: 0.1431 - val_loss: 0.7468 - val_mse: 0.7468 - val_rmse: 0.7780 - val_r_square: -0.2358
# Epoch 160/1000
# 8/8 [==============================] - 1s 72ms/step - loss: 0.5870 - mse: 0.5870 - rmse: 0.6801 - r_square: 0.1394 - val_loss: 0.7504 - val_mse: 0.7504 - val_rmse: 0.7800 - val_r_square: -0.2418
# Epoch 161/1000
# 8/8 [==============================] - 1s 80ms/step - loss: 0.5935 - mse: 0.5935 - rmse: 0.6847 - r_square: 0.1155 - val_loss: 0.7472 - val_mse: 0.7472 - val_rmse: 0.7778 - val_r_square: -0.2365
# Epoch 162/1000
# 8/8 [==============================] - 1s 70ms/step - loss: 0.5872 - mse: 0.5872 - rmse: 0.6799 - r_square: 0.1426 - val_loss: 0.7544 - val_mse: 0.7544 - val_rmse: 0.7823 - val_r_square: -0.2484
# Epoch 163/1000
# 8/8 [==============================] - 1s 92ms/step - loss: 0.5852 - mse: 0.5852 - rmse: 0.6805 - r_square: 0.1378 - val_loss: 0.7609 - val_mse: 0.7609 - val_rmse: 0.7865 - val_r_square: -0.2592
# Epoch 164/1000
# 8/8 [==============================] - 1s 72ms/step - loss: 0.5832 - mse: 0.5832 - rmse: 0.6817 - r_square: 0.1507 - val_loss: 0.7611 - val_mse: 0.7611 - val_rmse: 0.7865 - val_r_square: -0.2595
# Epoch 165/1000
# 8/8 [==============================] - 1s 72ms/step - loss: 0.5901 - mse: 0.5901 - rmse: 0.6817 - r_square: 0.1218 - val_loss: 0.7561 - val_mse: 0.7561 - val_rmse: 0.7830 - val_r_square: -0.2512
# Epoch 166/1000
# 8/8 [==============================] - 1s 95ms/step - loss: 0.5766 - mse: 0.5766 - rmse: 0.6729 - r_square: 0.1655 - val_loss: 0.7585 - val_mse: 0.7585 - val_rmse: 0.7843 - val_r_square: -0.2553
# Epoch 167/1000
# 8/8 [==============================] - 1s 75ms/step - loss: 0.5754 - mse: 0.5754 - rmse: 0.6742 - r_square: 0.1420 - val_loss: 0.7581 - val_mse: 0.7581 - val_rmse: 0.7840 - val_r_square: -0.2546
# Epoch 168/1000
# 8/8 [==============================] - 1s 73ms/step - loss: 0.5810 - mse: 0.5810 - rmse: 0.6735 - r_square: 0.1460 - val_loss: 0.7575 - val_mse: 0.7575 - val_rmse: 0.7833 - val_r_square: -0.2535
# Epoch 169/1000
# 8/8 [==============================] - 1s 71ms/step - loss: 0.5660 - mse: 0.5660 - rmse: 0.6678 - r_square: 0.1715 - val_loss: 0.7590 - val_mse: 0.7590 - val_rmse: 0.7843 - val_r_square: -0.2561
# Epoch 170/1000
# 8/8 [==============================] - 1s 89ms/step - loss: 0.5725 - mse: 0.5725 - rmse: 0.6701 - r_square: 0.1551 - val_loss: 0.7610 - val_mse: 0.7610 - val_rmse: 0.7853 - val_r_square: -0.2594
# Epoch 171/1000
# 8/8 [==============================] - 1s 73ms/step - loss: 0.5705 - mse: 0.5705 - rmse: 0.6678 - r_square: 0.1546 - val_loss: 0.7691 - val_mse: 0.7691 - val_rmse: 0.7902 - val_r_square: -0.2728
# Epoch 172/1000
# 8/8 [==============================] - 1s 72ms/step - loss: 0.5812 - mse: 0.5812 - rmse: 0.6729 - r_square: 0.1306 - val_loss: 0.7671 - val_mse: 0.7671 - val_rmse: 0.7886 - val_r_square: -0.2695
# Epoch 173/1000
# 8/8 [==============================] - 1s 71ms/step - loss: 0.5759 - mse: 0.5759 - rmse: 0.6720 - r_square: 0.1548 - val_loss: 0.7638 - val_mse: 0.7638 - val_rmse: 0.7863 - val_r_square: -0.2640
# Epoch 174/1000
# 8/8 [==============================] - 1s 78ms/step - loss: 0.5705 - mse: 0.5705 - rmse: 0.6681 - r_square: 0.1741 - val_loss: 0.7607 - val_mse: 0.7607 - val_rmse: 0.7841 - val_r_square: -0.2588
# Epoch 175/1000
# 8/8 [==============================] - 1s 72ms/step - loss: 0.5660 - mse: 0.5660 - rmse: 0.6641 - r_square: 0.1812 - val_loss: 0.7627 - val_mse: 0.7627 - val_rmse: 0.7854 - val_r_square: -0.2622
# Epoch 176/1000
# 8/8 [==============================] - 1s 72ms/step - loss: 0.5595 - mse: 0.5595 - rmse: 0.6622 - r_square: 0.1877 - val_loss: 0.7698 - val_mse: 0.7698 - val_rmse: 0.7899 - val_r_square: -0.2739
# Epoch 177/1000
# 8/8 [==============================] - 1s 95ms/step - loss: 0.5681 - mse: 0.5681 - rmse: 0.6643 - r_square: 0.1665 - val_loss: 0.7702 - val_mse: 0.7702 - val_rmse: 0.7898 - val_r_square: -0.2745
# Epoch 178/1000
# 8/8 [==============================] - 1s 72ms/step - loss: 0.5666 - mse: 0.5666 - rmse: 0.6651 - r_square: 0.1773 - val_loss: 0.7736 - val_mse: 0.7736 - val_rmse: 0.7916 - val_r_square: -0.2802
# Epoch 179/1000
# 8/8 [==============================] - 1s 69ms/step - loss: 0.5542 - mse: 0.5542 - rmse: 0.6576 - r_square: 0.1950 - val_loss: 0.7773 - val_mse: 0.7773 - val_rmse: 0.7937 - val_r_square: -0.2863
# Epoch 180/1000
# 8/8 [==============================] - 1s 70ms/step - loss: 0.5643 - mse: 0.5643 - rmse: 0.6621 - r_square: 0.1562 - val_loss: 0.7787 - val_mse: 0.7787 - val_rmse: 0.7944 - val_r_square: -0.2887
# Epoch 181/1000
# 8/8 [==============================] - 1s 76ms/step - loss: 0.5662 - mse: 0.5662 - rmse: 0.6624 - r_square: 0.1821 - val_loss: 0.7845 - val_mse: 0.7845 - val_rmse: 0.7977 - val_r_square: -0.2983
# Epoch 182/1000
# 8/8 [==============================] - 1s 74ms/step - loss: 0.5687 - mse: 0.5687 - rmse: 0.6641 - r_square: 0.1741 - val_loss: 0.7848 - val_mse: 0.7848 - val_rmse: 0.7978 - val_r_square: -0.2988
# Epoch 183/1000
# 8/8 [==============================] - 1s 83ms/step - loss: 0.5624 - mse: 0.5624 - rmse: 0.6601 - r_square: 0.1764 - val_loss: 0.7869 - val_mse: 0.7869 - val_rmse: 0.7990 - val_r_square: -0.3022
# Epoch 184/1000
# 8/8 [==============================] - 1s 76ms/step - loss: 0.5644 - mse: 0.5644 - rmse: 0.6606 - r_square: 0.1630 - val_loss: 0.7819 - val_mse: 0.7819 - val_rmse: 0.7960 - val_r_square: -0.2940
# Epoch 185/1000
# 8/8 [==============================] - 1s 91ms/step - loss: 0.5627 - mse: 0.5627 - rmse: 0.6600 - r_square: 0.1626 - val_loss: 0.7790 - val_mse: 0.7790 - val_rmse: 0.7939 - val_r_square: -0.2891
# Epoch 186/1000
# 8/8 [==============================] - 1s 75ms/step - loss: 0.5537 - mse: 0.5537 - rmse: 0.6535 - r_square: 0.2040 - val_loss: 0.7800 - val_mse: 0.7800 - val_rmse: 0.7945 - val_r_square: -0.2907
# Epoch 187/1000
# 8/8 [==============================] - 1s 70ms/step - loss: 0.5506 - mse: 0.5506 - rmse: 0.6549 - r_square: 0.1894 - val_loss: 0.7848 - val_mse: 0.7848 - val_rmse: 0.7973 - val_r_square: -0.2987
# Epoch 188/1000
# 8/8 [==============================] - 1s 74ms/step - loss: 0.5464 - mse: 0.5464 - rmse: 0.6485 - r_square: 0.2050 - val_loss: 0.7837 - val_mse: 0.7837 - val_rmse: 0.7965 - val_r_square: -0.2969
# Epoch 189/1000
# 8/8 [==============================] - 1s 72ms/step - loss: 0.5439 - mse: 0.5439 - rmse: 0.6487 - r_square: 0.2113 - val_loss: 0.7891 - val_mse: 0.7891 - val_rmse: 0.7995 - val_r_square: -0.3059
# Epoch 190/1000
# 8/8 [==============================] - 1s 72ms/step - loss: 0.5437 - mse: 0.5437 - rmse: 0.6441 - r_square: 0.2070 - val_loss: 0.7875 - val_mse: 0.7875 - val_rmse: 0.7982 - val_r_square: -0.3032
# Epoch 191/1000
# 8/8 [==============================] - 1s 75ms/step - loss: 0.5490 - mse: 0.5490 - rmse: 0.6502 - r_square: 0.1806 - val_loss: 0.7900 - val_mse: 0.7900 - val_rmse: 0.7994 - val_r_square: -0.3074
# Epoch 192/1000
# 8/8 [==============================] - 1s 77ms/step - loss: 0.5595 - mse: 0.5595 - rmse: 0.6570 - r_square: 0.1705 - val_loss: 0.7969 - val_mse: 0.7969 - val_rmse: 0.8033 - val_r_square: -0.3188
# Epoch 193/1000
# 8/8 [==============================] - 1s 91ms/step - loss: 0.5495 - mse: 0.5495 - rmse: 0.6504 - r_square: 0.1864 - val_loss: 0.8011 - val_mse: 0.8011 - val_rmse: 0.8060 - val_r_square: -0.3257
# Epoch 194/1000
# 8/8 [==============================] - 1s 73ms/step - loss: 0.5478 - mse: 0.5478 - rmse: 0.6496 - r_square: 0.1900 - val_loss: 0.8033 - val_mse: 0.8033 - val_rmse: 0.8069 - val_r_square: -0.3293
# Epoch 195/1000
# 8/8 [==============================] - 1s 73ms/step - loss: 0.5618 - mse: 0.5618 - rmse: 0.6560 - r_square: 0.1796 - val_loss: 0.7936 - val_mse: 0.7936 - val_rmse: 0.8009 - val_r_square: -0.3133
# Epoch 196/1000
# 8/8 [==============================] - 1s 74ms/step - loss: 0.5399 - mse: 0.5399 - rmse: 0.6435 - r_square: 0.1890 - val_loss: 0.7998 - val_mse: 0.7998 - val_rmse: 0.8047 - val_r_square: -0.3236
# Epoch 197/1000
# 8/8 [==============================] - 1s 75ms/step - loss: 0.5391 - mse: 0.5391 - rmse: 0.6451 - r_square: 0.2183 - val_loss: 0.7942 - val_mse: 0.7942 - val_rmse: 0.8010 - val_r_square: -0.3144
# Epoch 198/1000
# 8/8 [==============================] - 1s 73ms/step - loss: 0.5413 - mse: 0.5413 - rmse: 0.6431 - r_square: 0.1971 - val_loss: 0.7959 - val_mse: 0.7959 - val_rmse: 0.8020 - val_r_square: -0.3172
# Epoch 199/1000
# 8/8 [==============================] - 1s 73ms/step - loss: 0.5286 - mse: 0.5286 - rmse: 0.6344 - r_square: 0.2205 - val_loss: 0.7997 - val_mse: 0.7997 - val_rmse: 0.8042 - val_r_square: -0.3234
# Epoch 200/1000
# 8/8 [==============================] - 1s 92ms/step - loss: 0.5403 - mse: 0.5403 - rmse: 0.6407 - r_square: 0.1997 - val_loss: 0.8053 - val_mse: 0.8053 - val_rmse: 0.8075 - val_r_square: -0.3326
# Epoch 201/1000
# 8/8 [==============================] - 1s 73ms/step - loss: 0.5356 - mse: 0.5356 - rmse: 0.6420 - r_square: 0.2109 - val_loss: 0.8135 - val_mse: 0.8135 - val_rmse: 0.8122 - val_r_square: -0.3462
# Epoch 202/1000
# 8/8 [==============================] - 1s 75ms/step - loss: 0.5387 - mse: 0.5387 - rmse: 0.6427 - r_square: 0.2214 - val_loss: 0.8117 - val_mse: 0.8117 - val_rmse: 0.8109 - val_r_square: -0.3432
# Epoch 203/1000
# 8/8 [==============================] - 1s 74ms/step - loss: 0.5383 - mse: 0.5383 - rmse: 0.6390 - r_square: 0.2189 - val_loss: 0.8074 - val_mse: 0.8074 - val_rmse: 0.8082 - val_r_square: -0.3362
# Epoch 204/1000
# 8/8 [==============================] - 1s 72ms/step - loss: 0.5434 - mse: 0.5434 - rmse: 0.6453 - r_square: 0.2108 - val_loss: 0.8039 - val_mse: 0.8039 - val_rmse: 0.8060 - val_r_square: -0.3304
# Epoch 205/1000
# 8/8 [==============================] - 1s 73ms/step - loss: 0.5250 - mse: 0.5250 - rmse: 0.6331 - r_square: 0.2324 - val_loss: 0.8044 - val_mse: 0.8044 - val_rmse: 0.8061 - val_r_square: -0.3312
# Epoch 206/1000
# 8/8 [==============================] - 1s 97ms/step - loss: 0.5440 - mse: 0.5440 - rmse: 0.6409 - r_square: 0.1910 - val_loss: 0.8081 - val_mse: 0.8081 - val_rmse: 0.8082 - val_r_square: -0.3373
# Epoch 207/1000
# 8/8 [==============================] - 1s 73ms/step - loss: 0.5336 - mse: 0.5336 - rmse: 0.6374 - r_square: 0.2175 - val_loss: 0.8131 - val_mse: 0.8131 - val_rmse: 0.8111 - val_r_square: -0.3456
# Epoch 208/1000
# 8/8 [==============================] - 1s 76ms/step - loss: 0.5182 - mse: 0.5182 - rmse: 0.6300 - r_square: 0.2432 - val_loss: 0.8166 - val_mse: 0.8166 - val_rmse: 0.8127 - val_r_square: -0.3514
# Epoch 209/1000
# 8/8 [==============================] - 1s 79ms/step - loss: 0.5301 - mse: 0.5301 - rmse: 0.6350 - r_square: 0.2332 - val_loss: 0.8194 - val_mse: 0.8194 - val_rmse: 0.8141 - val_r_square: -0.3560
# Epoch 210/1000
# 8/8 [==============================] - 1s 75ms/step - loss: 0.5339 - mse: 0.5339 - rmse: 0.6325 - r_square: 0.2152 - val_loss: 0.8225 - val_mse: 0.8225 - val_rmse: 0.8157 - val_r_square: -0.3612
# Epoch 211/1000
# 8/8 [==============================] - 1s 75ms/step - loss: 0.5317 - mse: 0.5317 - rmse: 0.6346 - r_square: 0.2293 - val_loss: 0.8244 - val_mse: 0.8244 - val_rmse: 0.8167 - val_r_square: -0.3644
# Epoch 212/1000
# 8/8 [==============================] - 1s 72ms/step - loss: 0.5336 - mse: 0.5336 - rmse: 0.6363 - r_square: 0.2226 - val_loss: 0.8122 - val_mse: 0.8122 - val_rmse: 0.8097 - val_r_square: -0.3441
# Epoch 213/1000
# 8/8 [==============================] - 1s 93ms/step - loss: 0.5209 - mse: 0.5209 - rmse: 0.6260 - r_square: 0.2433 - val_loss: 0.8185 - val_mse: 0.8185 - val_rmse: 0.8133 - val_r_square: -0.3545
# Epoch 214/1000
# 8/8 [==============================] - 1s 74ms/step - loss: 0.5306 - mse: 0.5306 - rmse: 0.6311 - r_square: 0.2188 - val_loss: 0.8108 - val_mse: 0.8108 - val_rmse: 0.8086 - val_r_square: -0.3417
# Epoch 215/1000
# 8/8 [==============================] - 1s 75ms/step - loss: 0.5267 - mse: 0.5267 - rmse: 0.6324 - r_square: 0.2309 - val_loss: 0.8227 - val_mse: 0.8227 - val_rmse: 0.8153 - val_r_square: -0.3615
# Epoch 216/1000
# 8/8 [==============================] - 1s 77ms/step - loss: 0.5373 - mse: 0.5373 - rmse: 0.6392 - r_square: 0.2093 - val_loss: 0.8312 - val_mse: 0.8312 - val_rmse: 0.8200 - val_r_square: -0.3755
# Epoch 217/1000
# 8/8 [==============================] - 1s 75ms/step - loss: 0.5198 - mse: 0.5198 - rmse: 0.6309 - r_square: 0.2441 - val_loss: 0.8293 - val_mse: 0.8293 - val_rmse: 0.8189 - val_r_square: -0.3724
# Epoch 218/1000
# 8/8 [==============================] - 1s 74ms/step - loss: 0.5209 - mse: 0.5209 - rmse: 0.6291 - r_square: 0.2346 - val_loss: 0.8301 - val_mse: 0.8301 - val_rmse: 0.8189 - val_r_square: -0.3737
# Epoch 219/1000
# 8/8 [==============================] - 1s 75ms/step - loss: 0.5247 - mse: 0.5247 - rmse: 0.6282 - r_square: 0.2382 - val_loss: 0.8233 - val_mse: 0.8233 - val_rmse: 0.8147 - val_r_square: -0.3625
# Epoch 220/1000
# 8/8 [==============================] - 1s 95ms/step - loss: 0.5222 - mse: 0.5222 - rmse: 0.6272 - r_square: 0.2398 - val_loss: 0.8281 - val_mse: 0.8281 - val_rmse: 0.8173 - val_r_square: -0.3704
# Epoch 221/1000
# 8/8 [==============================] - 1s 74ms/step - loss: 0.5252 - mse: 0.5252 - rmse: 0.6240 - r_square: 0.2341 - val_loss: 0.8300 - val_mse: 0.8300 - val_rmse: 0.8182 - val_r_square: -0.3735
# Epoch 222/1000
# 8/8 [==============================] - 1s 72ms/step - loss: 0.5203 - mse: 0.5203 - rmse: 0.6223 - r_square: 0.2407 - val_loss: 0.8304 - val_mse: 0.8304 - val_rmse: 0.8182 - val_r_square: -0.3743
# Epoch 223/1000
# ...
# 8/8 [==============================] - 1s 65ms/step - loss: 0.1710 - mse: 0.1710 - rmse: 0.2776 - r_square: 0.7477 - val_loss: 1.4972 - val_mse: 1.4972 - val_rmse: 0.9611 - val_r_square: -1.4777
# Epoch 664/1000
# 8/8 [==============================] - 1s 72ms/step - loss: 0.1887 - mse: 0.1887 - rmse: 0.2888 - r_square: 0.7255 - val_loss: 1.4795 - val_mse: 1.4795 - val_rmse: 0.9524 - val_r_square: -1.4484
# Epoch 665/1000
# 8/8 [==============================] - 1s 72ms/step - loss: 0.1785 - mse: 0.1785 - rmse: 0.2767 - r_square: 0.7362 - val_loss: 1.4558 - val_mse: 1.4558 - val_rmse: 0.9419 - val_r_square: -1.4091
# Epoch 666/1000
# 8/8 [==============================] - 1s 80ms/step - loss: 0.1955 - mse: 0.1955 - rmse: 0.2912 - r_square: 0.7147 - val_loss: 1.4728 - val_mse: 1.4728 - val_rmse: 0.9504 - val_r_square: -1.4373
# Epoch 667/1000
# 8/8 [==============================] - 0s 54ms/step - loss: 0.1960 - mse: 0.1960 - rmse: 0.2885 - r_square: 0.7041 - val_loss: 1.4844 - val_mse: 1.4844 - val_rmse: 0.9551 - val_r_square: -1.4565
# Epoch 668/1000
# 8/8 [==============================] - 0s 55ms/step - loss: 0.1950 - mse: 0.1950 - rmse: 0.2870 - r_square: 0.7106 - val_loss: 1.4621 - val_mse: 1.4621 - val_rmse: 0.9454 - val_r_square: -1.4197
# Epoch 669/1000
# 8/8 [==============================] - 1s 66ms/step - loss: 0.1826 - mse: 0.1826 - rmse: 0.2827 - r_square: 0.7391 - val_loss: 1.4788 - val_mse: 1.4788 - val_rmse: 0.9551 - val_r_square: -1.4472
# Epoch 670/1000
# 8/8 [==============================] - 1s 89ms/step - loss: 0.1839 - mse: 0.1839 - rmse: 0.2809 - r_square: 0.7337 - val_loss: 1.4831 - val_mse: 1.4831 - val_rmse: 0.9565 - val_r_square: -1.4543
# Epoch 671/1000
# 8/8 [==============================] - 0s 53ms/step - loss: 0.1763 - mse: 0.1763 - rmse: 0.2789 - r_square: 0.7345 - val_loss: 1.4949 - val_mse: 1.4949 - val_rmse: 0.9608 - val_r_square: -1.4739
# Epoch 672/1000
# 8/8 [==============================] - 0s 52ms/step - loss: 0.1901 - mse: 0.1901 - rmse: 0.2881 - r_square: 0.7198 - val_loss: 1.4755 - val_mse: 1.4755 - val_rmse: 0.9510 - val_r_square: -1.4417
# Epoch 673/1000
# 8/8 [==============================] - 1s 90ms/step - loss: 0.1771 - mse: 0.1771 - rmse: 0.2776 - r_square: 0.7416 - val_loss: 1.4753 - val_mse: 1.4753 - val_rmse: 0.9498 - val_r_square: -1.4414
# Epoch 674/1000
# 8/8 [==============================] - 1s 84ms/step - loss: 0.1842 - mse: 0.1842 - rmse: 0.2754 - r_square: 0.7147 - val_loss: 1.4916 - val_mse: 1.4916 - val_rmse: 0.9563 - val_r_square: -1.4684
# Epoch 675/1000
# 8/8 [==============================] - 1s 71ms/step - loss: 0.1895 - mse: 0.1895 - rmse: 0.2861 - r_square: 0.7259 - val_loss: 1.5186 - val_mse: 1.5186 - val_rmse: 0.9685 - val_r_square: -1.5132
# Epoch 676/1000
# 8/8 [==============================] - 1s 89ms/step - loss: 0.1808 - mse: 0.1808 - rmse: 0.2795 - r_square: 0.7312 - val_loss: 1.4838 - val_mse: 1.4838 - val_rmse: 0.9526 - val_r_square: -1.4555
# Epoch 677/1000
# 8/8 [==============================] - 1s 79ms/step - loss: 0.1766 - mse: 0.1766 - rmse: 0.2768 - r_square: 0.7365 - val_loss: 1.4807 - val_mse: 1.4807 - val_rmse: 0.9502 - val_r_square: -1.4503
# Epoch 678/1000
# 8/8 [==============================] - 1s 65ms/step - loss: 0.1840 - mse: 0.1840 - rmse: 0.2808 - r_square: 0.7257 - val_loss: 1.4866 - val_mse: 1.4866 - val_rmse: 0.9545 - val_r_square: -1.4601
# Epoch 679/1000
# 8/8 [==============================] - 1s 69ms/step - loss: 0.1752 - mse: 0.1752 - rmse: 0.2724 - r_square: 0.7454 - val_loss: 1.4922 - val_mse: 1.4922 - val_rmse: 0.9563 - val_r_square: -1.4694
# Epoch 680/1000
# 8/8 [==============================] - 1s 71ms/step - loss: 0.1679 - mse: 0.1679 - rmse: 0.2619 - r_square: 0.7468 - val_loss: 1.4836 - val_mse: 1.4836 - val_rmse: 0.9508 - val_r_square: -1.4551
# Epoch 681/1000
# 8/8 [==============================] - 0s 55ms/step - loss: 0.1800 - mse: 0.1800 - rmse: 0.2786 - r_square: 0.7387 - val_loss: 1.4798 - val_mse: 1.4798 - val_rmse: 0.9496 - val_r_square: -1.4489
# Epoch 682/1000
# 8/8 [==============================] - 0s 51ms/step - loss: 0.1775 - mse: 0.1775 - rmse: 0.2675 - r_square: 0.7410 - val_loss: 1.4862 - val_mse: 1.4862 - val_rmse: 0.9531 - val_r_square: -1.4595
# Epoch 683/1000
# 8/8 [==============================] - 1s 88ms/step - loss: 0.1877 - mse: 0.1877 - rmse: 0.2824 - r_square: 0.7205 - val_loss: 1.4781 - val_mse: 1.4781 - val_rmse: 0.9493 - val_r_square: -1.4461
# Epoch 684/1000
# 8/8 [==============================] - 1s 88ms/step - loss: 0.1812 - mse: 0.1812 - rmse: 0.2702 - r_square: 0.7340 - val_loss: 1.4771 - val_mse: 1.4771 - val_rmse: 0.9482 - val_r_square: -1.4445
# Epoch 685/1000
# 8/8 [==============================] - 1s 70ms/step - loss: 0.1687 - mse: 0.1687 - rmse: 0.2648 - r_square: 0.7559 - val_loss: 1.4749 - val_mse: 1.4749 - val_rmse: 0.9475 - val_r_square: -1.4408
# Epoch 686/1000
# 8/8 [==============================] - 0s 54ms/step - loss: 0.1804 - mse: 0.1804 - rmse: 0.2745 - r_square: 0.7376 - val_loss: 1.4852 - val_mse: 1.4852 - val_rmse: 0.9509 - val_r_square: -1.4578
# Epoch 687/1000
# 8/8 [==============================] - 1s 89ms/step - loss: 0.1727 - mse: 0.1727 - rmse: 0.2633 - r_square: 0.7474 - val_loss: 1.4807 - val_mse: 1.4807 - val_rmse: 0.9496 - val_r_square: -1.4504
# Epoch 688/1000
# 8/8 [==============================] - 0s 57ms/step - loss: 0.1792 - mse: 0.1792 - rmse: 0.2740 - r_square: 0.7238 - val_loss: 1.4942 - val_mse: 1.4942 - val_rmse: 0.9563 - val_r_square: -1.4727
# Epoch 689/1000
# 8/8 [==============================] - 0s 58ms/step - loss: 0.1808 - mse: 0.1808 - rmse: 0.2710 - r_square: 0.7378 - val_loss: 1.4743 - val_mse: 1.4743 - val_rmse: 0.9464 - val_r_square: -1.4398
# Epoch 690/1000
# 8/8 [==============================] - 0s 53ms/step - loss: 0.1766 - mse: 0.1766 - rmse: 0.2681 - r_square: 0.7409 - val_loss: 1.4686 - val_mse: 1.4686 - val_rmse: 0.9438 - val_r_square: -1.4304
# Epoch 691/1000
# 8/8 [==============================] - 1s 91ms/step - loss: 0.1714 - mse: 0.1714 - rmse: 0.2660 - r_square: 0.7471 - val_loss: 1.4724 - val_mse: 1.4724 - val_rmse: 0.9460 - val_r_square: -1.4367
# Epoch 692/1000
# 8/8 [==============================] - 1s 73ms/step - loss: 0.1827 - mse: 0.1827 - rmse: 0.2780 - r_square: 0.7291 - val_loss: 1.4881 - val_mse: 1.4881 - val_rmse: 0.9531 - val_r_square: -1.4626
# Epoch 693/1000
# 8/8 [==============================] - 1s 61ms/step - loss: 0.1943 - mse: 0.1943 - rmse: 0.2849 - r_square: 0.7125 - val_loss: 1.5096 - val_mse: 1.5096 - val_rmse: 0.9627 - val_r_square: -1.4982
# Epoch 694/1000
# 8/8 [==============================] - 1s 67ms/step - loss: 0.1802 - mse: 0.1802 - rmse: 0.2742 - r_square: 0.7375 - val_loss: 1.5074 - val_mse: 1.5074 - val_rmse: 0.9604 - val_r_square: -1.4945
# Epoch 695/1000
# 8/8 [==============================] - 1s 85ms/step - loss: 0.1787 - mse: 0.1787 - rmse: 0.2762 - r_square: 0.7355 - val_loss: 1.4802 - val_mse: 1.4802 - val_rmse: 0.9480 - val_r_square: -1.4495
# Epoch 696/1000
# 8/8 [==============================] - 0s 55ms/step - loss: 0.1586 - mse: 0.1586 - rmse: 0.2521 - r_square: 0.7714 - val_loss: 1.4931 - val_mse: 1.4931 - val_rmse: 0.9562 - val_r_square: -1.4709
# Epoch 697/1000
# 8/8 [==============================] - 0s 54ms/step - loss: 0.1700 - mse: 0.1700 - rmse: 0.2627 - r_square: 0.7498 - val_loss: 1.4731 - val_mse: 1.4731 - val_rmse: 0.9441 - val_r_square: -1.4378
# Epoch 698/1000
# 8/8 [==============================] - 1s 86ms/step - loss: 0.1786 - mse: 0.1786 - rmse: 0.2660 - r_square: 0.7384 - val_loss: 1.4768 - val_mse: 1.4768 - val_rmse: 0.9450 - val_r_square: -1.4439
# Epoch 699/1000
# 8/8 [==============================] - 1s 65ms/step - loss: 0.1742 - mse: 0.1742 - rmse: 0.2659 - r_square: 0.7459 - val_loss: 1.4892 - val_mse: 1.4892 - val_rmse: 0.9504 - val_r_square: -1.4645
# Epoch 700/1000
# 8/8 [==============================] - 0s 57ms/step - loss: 0.1495 - mse: 0.1495 - rmse: 0.2473 - r_square: 0.7776 - val_loss: 1.4904 - val_mse: 1.4904 - val_rmse: 0.9506 - val_r_square: -1.4665
# Epoch 701/1000
# 8/8 [==============================] - 0s 57ms/step - loss: 0.1630 - mse: 0.1630 - rmse: 0.2600 - r_square: 0.7579 - val_loss: 1.4650 - val_mse: 1.4650 - val_rmse: 0.9378 - val_r_square: -1.4244
# Epoch 702/1000
# 8/8 [==============================] - 1s 90ms/step - loss: 0.1714 - mse: 0.1714 - rmse: 0.2678 - r_square: 0.7541 - val_loss: 1.4821 - val_mse: 1.4821 - val_rmse: 0.9476 - val_r_square: -1.4527
# Epoch 703/1000
# 8/8 [==============================] - 1s 62ms/step - loss: 0.1688 - mse: 0.1688 - rmse: 0.2684 - r_square: 0.7461 - val_loss: 1.4825 - val_mse: 1.4825 - val_rmse: 0.9486 - val_r_square: -1.4534
# Epoch 704/1000
# 8/8 [==============================] - 0s 52ms/step - loss: 0.1761 - mse: 0.1761 - rmse: 0.2692 - r_square: 0.7430 - val_loss: 1.4671 - val_mse: 1.4671 - val_rmse: 0.9415 - val_r_square: -1.4278
# Epoch 705/1000
# 8/8 [==============================] - 0s 54ms/step - loss: 0.1715 - mse: 0.1715 - rmse: 0.2657 - r_square: 0.7509 - val_loss: 1.4546 - val_mse: 1.4546 - val_rmse: 0.9343 - val_r_square: -1.4072
# Epoch 706/1000
# 8/8 [==============================] - 1s 88ms/step - loss: 0.1795 - mse: 0.1795 - rmse: 0.2728 - r_square: 0.7305 - val_loss: 1.4813 - val_mse: 1.4813 - val_rmse: 0.9490 - val_r_square: -1.4515
# Epoch 707/1000
# 8/8 [==============================] - 0s 58ms/step - loss: 0.1667 - mse: 0.1667 - rmse: 0.2602 - r_square: 0.7450 - val_loss: 1.4669 - val_mse: 1.4669 - val_rmse: 0.9407 - val_r_square: -1.4275
# Epoch 708/1000
# 8/8 [==============================] - 1s 69ms/step - loss: 0.1686 - mse: 0.1686 - rmse: 0.2612 - r_square: 0.7485 - val_loss: 1.4992 - val_mse: 1.4992 - val_rmse: 0.9553 - val_r_square: -1.4810
# Epoch 709/1000
# 8/8 [==============================] - 1s 78ms/step - loss: 0.1779 - mse: 0.1779 - rmse: 0.2712 - r_square: 0.7476 - val_loss: 1.5149 - val_mse: 1.5149 - val_rmse: 0.9612 - val_r_square: -1.5070
# Epoch 710/1000
# 8/8 [==============================] - 1s 69ms/step - loss: 0.1682 - mse: 0.1682 - rmse: 0.2614 - r_square: 0.7462 - val_loss: 1.5167 - val_mse: 1.5167 - val_rmse: 0.9607 - val_r_square: -1.5099
# Epoch 711/1000
# 8/8 [==============================] - 1s 65ms/step - loss: 0.1635 - mse: 0.1635 - rmse: 0.2521 - r_square: 0.7637 - val_loss: 1.5039 - val_mse: 1.5039 - val_rmse: 0.9540 - val_r_square: -1.4887
# Epoch 712/1000
# 8/8 [==============================] - 1s 71ms/step - loss: 0.1721 - mse: 0.1721 - rmse: 0.2686 - r_square: 0.7460 - val_loss: 1.5221 - val_mse: 1.5221 - val_rmse: 0.9623 - val_r_square: -1.5189
# Epoch 713/1000
# 8/8 [==============================] - 1s 69ms/step - loss: 0.1911 - mse: 0.1911 - rmse: 0.2765 - r_square: 0.7187 - val_loss: 1.5074 - val_mse: 1.5074 - val_rmse: 0.9567 - val_r_square: -1.4945
# Epoch 714/1000
# 8/8 [==============================] - 1s 71ms/step - loss: 0.1752 - mse: 0.1752 - rmse: 0.2666 - r_square: 0.7339 - val_loss: 1.5038 - val_mse: 1.5038 - val_rmse: 0.9581 - val_r_square: -1.4885
# Epoch 715/1000
# 8/8 [==============================] - 1s 75ms/step - loss: 0.1752 - mse: 0.1752 - rmse: 0.2653 - r_square: 0.7417 - val_loss: 1.5123 - val_mse: 1.5123 - val_rmse: 0.9640 - val_r_square: -1.5027
# Epoch 716/1000
# 8/8 [==============================] - 0s 54ms/step - loss: 0.1598 - mse: 0.1598 - rmse: 0.2553 - r_square: 0.7615 - val_loss: 1.4846 - val_mse: 1.4846 - val_rmse: 0.9500 - val_r_square: -1.4568
# Epoch 717/1000
# 8/8 [==============================] - 1s 72ms/step - loss: 0.1752 - mse: 0.1752 - rmse: 0.2667 - r_square: 0.7425 - val_loss: 1.4730 - val_mse: 1.4730 - val_rmse: 0.9413 - val_r_square: -1.4376
# Epoch 718/1000
# 8/8 [==============================] - 1s 64ms/step - loss: 0.1673 - mse: 0.1673 - rmse: 0.2614 - r_square: 0.7518 - val_loss: 1.5199 - val_mse: 1.5199 - val_rmse: 0.9653 - val_r_square: -1.5152
# Epoch 719/1000
# 8/8 [==============================] - 0s 54ms/step - loss: 0.1708 - mse: 0.1708 - rmse: 0.2667 - r_square: 0.7454 - val_loss: 1.5025 - val_mse: 1.5025 - val_rmse: 0.9569 - val_r_square: -1.4865
# Epoch 720/1000
# 8/8 [==============================] - 1s 72ms/step - loss: 0.1737 - mse: 0.1737 - rmse: 0.2623 - r_square: 0.7417 - val_loss: 1.4496 - val_mse: 1.4496 - val_rmse: 0.9293 - val_r_square: -1.3990
# Epoch 721/1000
# 8/8 [==============================] - 1s 73ms/step - loss: 0.1771 - mse: 0.1771 - rmse: 0.2720 - r_square: 0.7374 - val_loss: 1.4833 - val_mse: 1.4833 - val_rmse: 0.9486 - val_r_square: -1.4546
# Epoch 722/1000
# 8/8 [==============================] - 0s 55ms/step - loss: 0.1569 - mse: 0.1569 - rmse: 0.2469 - r_square: 0.7617 - val_loss: 1.5072 - val_mse: 1.5072 - val_rmse: 0.9608 - val_r_square: -1.4942
# Epoch 723/1000
# 8/8 [==============================] - 0s 53ms/step - loss: 0.1733 - mse: 0.1733 - rmse: 0.2623 - r_square: 0.7431 - val_loss: 1.4772 - val_mse: 1.4772 - val_rmse: 0.9465 - val_r_square: -1.4446
# Epoch 724/1000
# 8/8 [==============================] - 1s 77ms/step - loss: 0.1765 - mse: 0.1765 - rmse: 0.2691 - r_square: 0.7334 - val_loss: 1.4727 - val_mse: 1.4727 - val_rmse: 0.9427 - val_r_square: -1.4372
# Epoch 725/1000
# 8/8 [==============================] - 1s 69ms/step - loss: 0.1594 - mse: 0.1594 - rmse: 0.2527 - r_square: 0.7646 - val_loss: 1.4819 - val_mse: 1.4819 - val_rmse: 0.9445 - val_r_square: -1.4524
# Epoch 726/1000
# 8/8 [==============================] - 0s 55ms/step - loss: 0.1721 - mse: 0.1721 - rmse: 0.2598 - r_square: 0.7520 - val_loss: 1.4649 - val_mse: 1.4649 - val_rmse: 0.9352 - val_r_square: -1.4242
# Epoch 727/1000
# 8/8 [==============================] - 1s 60ms/step - loss: 0.1686 - mse: 0.1686 - rmse: 0.2563 - r_square: 0.7462 - val_loss: 1.4776 - val_mse: 1.4776 - val_rmse: 0.9397 - val_r_square: -1.4453
# Epoch 728/1000
# 8/8 [==============================] - 1s 66ms/step - loss: 0.1597 - mse: 0.1597 - rmse: 0.2501 - r_square: 0.7643 - val_loss: 1.4681 - val_mse: 1.4681 - val_rmse: 0.9358 - val_r_square: -1.4296
# Epoch 729/1000
# 8/8 [==============================] - 1s 69ms/step - loss: 0.1677 - mse: 0.1677 - rmse: 0.2548 - r_square: 0.7533 - val_loss: 1.4667 - val_mse: 1.4667 - val_rmse: 0.9375 - val_r_square: -1.4272
# Epoch 730/1000
# 8/8 [==============================] - 1s 68ms/step - loss: 0.1678 - mse: 0.1678 - rmse: 0.2539 - r_square: 0.7530 - val_loss: 1.4957 - val_mse: 1.4957 - val_rmse: 0.9524 - val_r_square: -1.4753
# Epoch 731/1000
# 8/8 [==============================] - 0s 53ms/step - loss: 0.1538 - mse: 0.1538 - rmse: 0.2456 - r_square: 0.7743 - val_loss: 1.5152 - val_mse: 1.5152 - val_rmse: 0.9604 - val_r_square: -1.5075
# Epoch 732/1000
# 8/8 [==============================] - 1s 69ms/step - loss: 0.1543 - mse: 0.1543 - rmse: 0.2469 - r_square: 0.7712 - val_loss: 1.4798 - val_mse: 1.4798 - val_rmse: 0.9413 - val_r_square: -1.4490
# Epoch 733/1000
# 8/8 [==============================] - 1s 94ms/step - loss: 0.1755 - mse: 0.1755 - rmse: 0.2639 - r_square: 0.7238 - val_loss: 1.4766 - val_mse: 1.4766 - val_rmse: 0.9390 - val_r_square: -1.4435
# Epoch 734/1000
# 8/8 [==============================] - 0s 58ms/step - loss: 0.1600 - mse: 0.1600 - rmse: 0.2547 - r_square: 0.7598 - val_loss: 1.5131 - val_mse: 1.5131 - val_rmse: 0.9594 - val_r_square: -1.5040
# Epoch 735/1000
# 8/8 [==============================] - 1s 108ms/step - loss: 0.1558 - mse: 0.1558 - rmse: 0.2431 - r_square: 0.7708 - val_loss: 1.4710 - val_mse: 1.4710 - val_rmse: 0.9365 - val_r_square: -1.4343
# Epoch 736/1000
# 8/8 [==============================] - 1s 68ms/step - loss: 0.1564 - mse: 0.1564 - rmse: 0.2485 - r_square: 0.7695 - val_loss: 1.4737 - val_mse: 1.4737 - val_rmse: 0.9382 - val_r_square: -1.4388
# Epoch 737/1000
# 8/8 [==============================] - 0s 56ms/step - loss: 0.1513 - mse: 0.1513 - rmse: 0.2418 - r_square: 0.7807 - val_loss: 1.4845 - val_mse: 1.4845 - val_rmse: 0.9447 - val_r_square: -1.4567
# Epoch 738/1000
# 8/8 [==============================] - 1s 96ms/step - loss: 0.1664 - mse: 0.1664 - rmse: 0.2583 - r_square: 0.7576 - val_loss: 1.4665 - val_mse: 1.4665 - val_rmse: 0.9357 - val_r_square: -1.4269
# The difference in seconds is: 445.40091252326965

# %%
# Extract the metrics from the history object
loss = history.history['loss']
val_loss = history.history['val_loss']
r_square = history.history['r_square']
val_r_square = history.history['val_r_square']

# Plot loss and val_loss
plt.figure(figsize=(12, 6))
plt.plot(loss, label='Training Loss', color='blue')
plt.plot(val_loss, label='Validation Loss', color='orange')
plt.title('Training Loss vs Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.grid()
plt.show()

# Plot r_square and val_r_square
plt.figure(figsize=(12, 6))
plt.plot(r_square, label='Training R^2', color='green')
plt.plot(val_r_square, label='Validation R^2', color='red')
plt.title('Training R^2 vs Validation R^2')
plt.xlabel('Epochs')
plt.ylabel('R^2')
plt.legend()
plt.grid()
plt.show()

# %%
# Find the minimum loss for training and validation
min_training_loss = min(loss)
min_validation_loss = min(val_loss)

# Print the results
print(f"Minimum Training Loss: {min_training_loss}")
print(f"Minimum Validation Loss: {min_validation_loss}")
# Out:
# Minimum Training Loss: 0.14953526854515076
# Minimum Validation Loss: 0.6337112784385681

# %%
# Find the maximum R² values for training and validation
# max_r_square_train = max(r_square)
# max_r_square_val = max(val_r_square)

# # Print the results
# print(f"Maximum Training R²: {max_r_square_train}")
# print(f"Maximum Validation R²: {max_r_square_val}")

# %%
# model = best_model

# %%
# Generate predictions for the training set
Y_train_pred = model.predict(X_train)

# Plot the true values and predictions
plt.figure(figsize=(10, 6))
plt.plot(Y_train, label='True Values', color='blue',  marker='o')
plt.plot(Y_train_pred, label='Predictions', color='red', linestyle='dashed', marker='o')
plt.title('Training True Values vs Predictions')
plt.xlabel('Sample Index')
plt.ylabel('Value')
plt.legend()
plt.show()
# Out:
# 16/16 [==============================] - 0s 8ms/step

# %%
# Generate predictions for the validation set
Y_val_pred = model.predict(X_val)

# Plot the true values and predictions
plt.figure(figsize=(10, 6))
plt.plot(Y_val, label='True Values', color='blue', marker='o')
plt.plot(Y_val_pred, label='Predictions', color='red', linestyle='dashed', marker='o')
plt.title('Validation True Values vs Predictions')
plt.xlabel('Sample Index')
plt.ylabel('Value')
plt.legend()
plt.show()
# Out:
# 2/2 [==============================] - 0s 9ms/step

# %%
# Generate predictions for the validation set
Y_val_pred = model.predict(X_val)
Y_val_pred = np.where(Y_val_pred > 0.5, 1,np.where(Y_val_pred<-0.5, -1, 0) )

# Plot the true values and predictions
plt.figure(figsize=(10, 6))
plt.plot(Y_val, label='True Values', color='blue', marker='o')
plt.plot(Y_val_pred, label='Predictions', color='red', linestyle='dashed', marker='o')
plt.title('Validation True Values vs Predictions')
plt.xlabel('Sample Index')
plt.ylabel('Value')
plt.legend()
plt.show()
# Out:
# 2/2 [==============================] - 0s 9ms/step

# %%
import matplotlib.pyplot as plt
import numpy as np

# Generate predictions for the validation set
Y_val_pred = model.predict(X_val)
Y_val_pred = np.where(Y_val_pred > 0.5, 1, np.where(Y_val_pred < -0.5, -1, 0))

# Plot
plt.figure(figsize=(12, 6))

# Add soft gray vertical lines for each sample
for i in range(len(Y_val)):
    plt.axvline(x=i, color='gray', linestyle='-', linewidth=0.5, alpha=0.3)

# Plot true values and predictions as scatter
plt.scatter(range(len(Y_val)), Y_val, label='True Values', color='blue', marker='o')
plt.scatter(range(len(Y_val_pred)), Y_val_pred, label='Predictions', color='red', marker='o')

# Styling
plt.title('Validation True Values vs Predictions')
plt.xlabel('Sample Index')
plt.ylabel('Value')
plt.legend()
plt.grid(False)  # Remove default grid
plt.tight_layout()
plt.show()
# Out:
# 2/2 [==============================] - 0s 13ms/step

# %%
from sklearn.metrics import confusion_matrix

# Create confusion matrix
conf_matrix = confusion_matrix(Y_val.flatten(), Y_val_pred.flatten())

# Print the confusion matrix
print("Confusion Matrix:")
print(conf_matrix)
# Out:
# Confusion Matrix:
# [[ 0 10  0]
#  [ 0 11  0]
#  [ 0 35  0]]

# %%
# Calculate total accuracy
total_accuracy = np.sum(Y_val.flatten() == Y_val_pred.flatten()) / len(Y_val)
print(f"Total Accuracy: {total_accuracy * 100:.2f}%")
# Out:
# Total Accuracy: 19.64%

# %%
# Generate predictions for the validation set
Y_val_pred = model.predict(X_test_filtered)
Y_val_pred = np.where(Y_val_pred > 0.2, 1, -1)

# Plot the true values and predictions
plt.figure(figsize=(10, 6))
plt.plot(Y_test_filtered, label='True Values', color='blue', marker='o')
plt.plot(Y_val_pred, label='Predictions', color='red', linestyle='dashed', marker='o')
plt.title('Validation True Values vs Predictions')
plt.xlabel('Sample Index')
plt.ylabel('Value')
plt.legend()
plt.show()
# Out:
# 2/2 [==============================] - 0s 7ms/step

# %%
# import matplotlib.pyplot as plt
# import numpy as np

# # Generate predictions for the validation set
# Y_val_pred = model.predict(X_test_filtered)
# Y_val_pred = np.where(Y_val_pred > 0.2, 1, -1)

# # Plot the true values and predictions
# plt.figure(figsize=(12, 6))

# # Add soft gray vertical lines for each sample index
# for i in range(len(Y_test_filtered)):
#     plt.axvline(x=i, color='gray', linestyle='-', linewidth=0.5, alpha=0.7)

# # Plot using scatter (no connecting lines)
# plt.scatter(range(len(Y_test_filtered)), Y_test_filtered, label='True Values', color='blue', marker='o')
# plt.scatter(range(len(Y_val_pred)), Y_val_pred, label='Predictions', color='red', marker='o')

# # Labels and title
# plt.title('Validation True Values vs Predictions')
# plt.xlabel('Sample Index')
# plt.ylabel('Value')
# plt.legend()
# plt.grid(False)
# plt.tight_layout()
# plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Generate predictions for the validation set
Y_val_pred = model.predict(X_test_filtered)
Y_val_pred = np.where(Y_val_pred > 0.2, 1, -1)

# Flatten if needed
Y_val_pred = Y_val_pred.flatten()
Y_test_filtered = Y_test_filtered.flatten()

# Prepare index and classification of correctness
indices = np.arange(len(Y_test_filtered))
correct = Y_val_pred == Y_test_filtered
incorrect = ~correct

# Plot the figure
plt.figure(figsize=(12, 6))

# Add vertical gray lines
for i in range(len(Y_test_filtered)):
    plt.axvline(x=i, color='gray', linestyle='-', linewidth=0.7, alpha=0.7)

# Plot true values as reference shadow
# plt.scatter(indices, Y_test_filtered, color='blue', label='True Value (Reference)', marker='o', alpha=0.3)

# Plot correct predictions (overlapping with true values)
plt.scatter(indices[correct], Y_val_pred[correct], color='blue', marker='o', label='Correct Prediction')

# Plot incorrect predictions
plt.scatter(indices[incorrect], Y_val_pred[incorrect], color='red', marker='o', label='Incorrect Prediction')

# Labels and title
plt.title('Testing True Values vs Predictions')
plt.xlabel('Sample Index')
plt.ylabel('Value')
plt.legend()
plt.grid(False)
plt.tight_layout()
plt.show()
# Out:
# 2/2 [==============================] - 0s 10ms/step

# %%
from sklearn.metrics import confusion_matrix

# Create confusion matrix
conf_matrix = confusion_matrix(Y_test_filtered.flatten(), Y_val_pred.flatten())

# Print the confusion matrix
print("Confusion Matrix:")
print(conf_matrix)
# Out:
# Confusion Matrix:
# [[ 1  9]
#  [ 1 34]]

# %%
# Calculate total accuracy
total_accuracy = np.sum(Y_test_filtered.flatten() == Y_val_pred.flatten()) / len(Y_test_filtered)
print(f"Total Accuracy: {total_accuracy * 100:.2f}%")
# Out:
# Total Accuracy: 77.78%
