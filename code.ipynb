# %%
import numpy as np
import matplotlib.pyplot as plt
import math
from collections import Counter
import pandas as pd

# %%
bali = pd.read_csv('bali_min4.csv')
jabar = pd.read_csv('jawabarat_min4.csv')
# df = pd.concat([bali, jabar], axis=0)
jatengjatim = pd.read_csv('jatengjatim_min4.csv')
# df = pd.concat([bali, jatengjatim], axis=0)
# df = pd.concat([jabar, jatengjatim], axis=0)
df = pd.concat([bali, jabar, jatengjatim], axis=0)
# df = pd.read_csv('southern_california_min25.csv')
df['timestamp'] = pd.to_datetime(df['time'], errors='coerce', utc=False)
df['Datetime'] = df['timestamp']
df.set_index('timestamp', inplace=True)
df = df.sort_index(ascending=True)
df
# Out:
#                                                       time  latitude  \
# timestamp
# 1995-01-01 02:02:25.490000+00:00  1995-01-01T02:02:25.490Z  -10.9270
# 1995-01-07 15:02:59.810000+00:00  1995-01-07T15:02:59.810Z   -9.0250
# 1995-01-07 18:37:28.920000+00:00  1995-01-07T18:37:28.920Z   -9.2310
# 1995-01-19 09:19:57.180000+00:00  1995-01-19T09:19:57.180Z  -10.7640
# 1995-02-16 16:27:25.400000+00:00  1995-02-16T16:27:25.400Z  -10.0560
# ...                                                    ...       ...
# 2020-12-20 15:16:45.796000+00:00  2020-12-20T15:16:45.796Z   -9.2506
# 2020-12-20 15:53:57.395000+00:00  2020-12-20T15:53:57.395Z   -9.2936
# 2020-12-22 03:27:21.031000+00:00  2020-12-22T03:27:21.031Z   -9.5505
# 2020-12-24 22:09:10.232000+00:00  2020-12-24T22:09:10.232Z   -9.0282
# 2020-12-26 18:23:21.550000+00:00  2020-12-26T18:23:21.550Z   -9.0928
#
#                                   longitude   depth  mag magType  nst    gap  \
# timestamp
# 1995-01-01 02:02:25.490000+00:00   113.0110   18.90  4.5      mb  NaN    NaN
# 1995-01-07 15:02:59.810000+00:00   110.7550  114.80  4.7      mb  NaN    NaN
# 1995-01-07 18:37:28.920000+00:00   117.1110   33.00  4.2      mb  NaN    NaN
# 1995-01-19 09:19:57.180000+00:00   117.1200   33.00  4.9      mb  NaN    NaN
# 1995-02-16 16:27:25.400000+00:00   113.8580   33.00  4.0      mb  NaN    NaN
# ...                                     ...     ...  ...     ...  ...    ...
# 2020-12-20 15:16:45.796000+00:00   110.8510   35.00  4.2      mb  NaN  148.0
# 2020-12-20 15:53:57.395000+00:00   112.1503   35.00  4.3      mb  NaN   53.0
# 2020-12-22 03:27:21.031000+00:00   112.5698   35.00  4.1      mb  NaN  120.0
# 2020-12-24 22:09:10.232000+00:00   117.3729  104.10  4.4      mb  NaN   95.0
# 2020-12-26 18:23:21.550000+00:00   117.1835   63.84  4.1      mb  NaN   71.0
#
#                                    dmin   rms  ...  \
# timestamp                                      ...
# 1995-01-01 02:02:25.490000+00:00    NaN  1.20  ...
# 1995-01-07 15:02:59.810000+00:00    NaN  0.80  ...
# 1995-01-07 18:37:28.920000+00:00    NaN  0.90  ...
# 1995-01-19 09:19:57.180000+00:00    NaN  1.30  ...
# 1995-02-16 16:27:25.400000+00:00    NaN  0.40  ...
# ...                                 ...   ...  ...
# 2020-12-20 15:16:45.796000+00:00  1.368  0.58  ...
# 2020-12-20 15:53:57.395000+00:00  2.114  0.90  ...
# 2020-12-22 03:27:21.031000+00:00  1.896  0.94  ...
# 2020-12-24 22:09:10.232000+00:00  3.231  0.54  ...
# 2020-12-26 18:23:21.550000+00:00  3.059  0.62  ...
#
#                                                                   place  \
# timestamp
# 1995-01-01 02:02:25.490000+00:
# ...                                     ...                              ...
# 2020-12-20 15:16:45.796000+00:00         us 2020-12-20 15:16:45.796000+00:00
# 2020-12-20 15:53:57.395000+00:00         us 2020-12-20 15:53:57.395000+00:00
# 2020-12-22 03:27:21.031000+00:00         us 2020-12-22 03:27:21.031000+00:00
# 2020-12-24 22:09:10.232000+00:00         us 2020-12-24 22:09:10.232000+00:00
# 2020-12-26 18:23:21.550000+00:00         us 2020-12-26 18:23:21.550000+00:00
#
# [1698 rows x 23 columns]

# %%
df = df[['depth', 'mag']]
df
# Out:
#                                    depth  mag
# timestamp
# 1995-01-01 02:02:25.490000+00:00   18.90  4.5
# 1995-01-07 15:02:59.810000+00:00  114.80  4.7
# 1995-01-07 18:37:28.920000+00:00   33.00  4.2
# 1995-01-19 09:19:57.180000+00:00   33.00  4.9
# 1995-02-16 16:27:25.400000+00:00   33.00  4.0
# ...                                  ...  ...
# 2020-12-20 15:16:45.796000+00:00   35.00  4.2
# 2020-12-20 15:53:57.395000+00:00   35.00  4.3
# 2020-12-22 03:27:21.031000+00:00   35.00  4.1
# 2020-12-24 22:09:10.232000+00:00  104.10  4.4
# 2020-12-26 18:23:21.550000+00:00   63.84  4.1
#
# [1698 rows x 2 columns]

# %%
print(df.isna().sum())
# Out:
# depth    0
# mag      0
# dtype: int64

# %%
mag_unique, frequency = np.unique(df['mag'], return_counts=True)

plt.figure(figsize=(10,8))
plt.hist(df['mag'], bins=1000, color='black', edgecolor='black')

bins = [0, 20, 40, 60]

from matplotlib.ticker import MultipleLocator
# Set x-axis scale to increment by 0.5
plt.gca().xaxis.set_major_locator(MultipleLocator(0.2))
# Add titles and labels
plt.title('Frequency by Magnitude')
plt.xlabel('Magnitude')
plt.ylabel('Frequency')
plt.xticks(fontsize=12, fontname='Times New Roman', rotation=45)

# Show the plot
plt.show()

# %%
mag_filter = 4.5
depth_filter = 100
resample_rate = '1M'

# %%
# def occurence_criterion(raw_array):
#     print(raw_array)
#     print("---------------------")
#     target = -1
#     if len(raw_array) > 0:
#         if raw_array['earthquake'].eq(1).any():
#             target = 1
#         if raw_array['earthquake'].eq(0).any():
#             target = 0
#     if len(raw_array) == 0:
#         target = 0

        
#     return target

# earthquake_occurence = df.resample(resample_rate).apply(occurence_criterion)

# earthquake_occurence = earthquake_occurence.to_frame(name='earthquake')

# earthquake_occurence = earthquake_occurence.sort_index(ascending=True)
# earthquake_occurence['earthquake'].value_counts()

# %%
# Initialize the 'ED' column with NaN values
df['ED'] = np.nan

# Filter the dataframe for earthquakes with magnitude greater than mag_filter
filtered_df = df[df['mag'] > mag_filter]

n = 50

# Calculate the elapsed days for the last n earthquake events
for i in range(n, len(filtered_df)):
    current_time = filtered_df.index[i]
    past_time = filtered_df.index[i-n]
    elapsed_days = (current_time - past_time).days
    df.loc[current_time, 'ED'] = elapsed_days

# Fill NaN values in 'ED' column
for i in range(len(df)):
    if pd.isna(df.iloc[i]['ED']):
        # Find the latest valid 'ED' value before the current index
        last_valid_index = df.iloc[:i]['ED'].last_valid_index()
        if last_valid_index is not None:
            time_since_last_valid = (df.index[i] - last_valid_index).days
            df.at[df.index[i], 'ED'] = df.at[last_valid_index, 'ED'] + time_since_last_valid

# df = df.dropna(subset=['ED'])
df
# Out:
# C:\Users\SteinSteffi1\AppData\Local\Temp\ipykernel_11680\388928700.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['ED'] = np.nan
#                                    depth  mag     ED
# timestamp
# 1995-01-01 02:02:25.490000+00:00   18.90  4.5    NaN
# 1995-01-07 15:02:59.810000+00:00  114.80  4.7    NaN
# 1995-01-07 18:37:28.920000+00:00   33.00  4.2    NaN
# 1995-01-19 09:19:57.180000+00:00   33.00  4.9    NaN
# 1995-02-16 16:27:25.400000+00:00   33.00  4.0    NaN
# ...                                  ...  ...    ...
# 2020-12-20 15:16:45.796000+00:00   35.00  4.2  875.0
# 2020-12-20 15:53:57.395000+00:00   35.00  4.3  875.0
# 2020-12-22 03:27:21.031000+00:00   35.00  4.1  876.0
# 2020-12-24 22:09:10.232000+00:00  104.10  4.4  878.0
# 2020-12-26 18:23:21.550000+00:00   63.84  4.1  879.0
#
# [1698 rows x 3 columns]

# %%
# Initialize the 'energy_squared' and 'cumulative_energy_squared' columns with NaN values
df['energy_squared_root'] = np.nan
df['cumulative_energy_squared'] = np.nan

df['energy'] = 10**(11.8+1.5*df['mag'])

# Calculate the energy squared for each data point
df['energy_squared_root'] = np.sqrt(df['energy'])

# Calculate the cumulative sum of energy squared for the last 50 data points
# for i in range(n, len(df)):
#     df.iloc[i, df.columns.get_loc('cumulative_energy_squared')] = df.iloc[i-n:i]['energy_squared_root'].sum()

df['cumulative_energy_squared'] = df['energy_squared_root'].rolling(n).sum()

# Calculate the RSRER
df['RSRER'] = df['cumulative_energy_squared'] / df['ED']

df['mean_mag'] = df['mag'].rolling(n).mean()
df['min_mag'] = df['mag'].rolling(n).min()
df['b_value'] = np.log10(np.e)/(df['mean_mag'] - df['min_mag'])

df['event_counts'] = df['mag'].rolling(n).apply(lambda x: (x > mag_filter).sum(), raw=True)
df['a_value'] = (np.log10(df['event_counts']) + df['b_value']*df['min_mag'])/n
# df['MSD'] = np.sum((np.log10(df['event_counts'])-(df['a_value']-(df['b_value']*df['mag'])))**2)/(n-1)
df['max_mag'] = df['mag'].rolling(n).max()
df['MD'] = df['a_value']/df['b_value'] - df['max_mag']
# print(df['event_counts'])

df
# Out:
# C:\Users\SteinSteffi1\AppData\Local\Temp\ipykernel_11680\2738765218.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['energy_squared_root'] = np.nan
# C:\Users\SteinSteffi1\AppData\Local\Temp\ipykernel_11680\2738765218.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['cumulative_energy_squared'] = np.nan
# C:\Users\SteinSteffi1\AppData\Local\Temp\ipykernel_11680\2738765218.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['energy'] = 10**(11.8+1.5*df['mag'])
# C:\Users\SteinSteffi1\AppData\Local\Temp\ipykernel_11680\2738765218.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['energy_squared_root'] = np.sqrt(df['energy'])
# C:\Users\SteinSteffi1\AppData\Local\Temp\ipykernel_11680\2738765218.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['cumulative_energy_squared'] = df['energy_squared_root'].rolling(n).sum()
# C:\Users\SteinSteffi1\AppData\Local\Temp\ipykernel_11680\2738765218.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['RSRER'] = df['cumulative_energy_squared'] / df['ED']
# C:\Users\SteinSteffi1\AppData\Local\Temp\ipykernel_11680\2738765218.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['mean_mag'] = df['mag'].rolling(n).mean()
# C:\Users\SteinSteffi1\AppData\Local\Temp\ipykernel_11680\2738765218.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['min_mag'] = df['mag'].rolling(n).min()
# C:\Users\SteinSteffi1\AppData\Local\Temp\ipykernel_11680\2738765218.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['b_value'] = np.log10(np.e)/(df['mean_mag'] - df['min_mag'])
# C:\Users\SteinSteffi1\AppData\Local\Temp\ipykernel_11680\2738765218.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['event_counts'] = df['mag'].rolling(n).apply(lambda x: (x > mag_filter).sum(), raw=True)
# C:\Users\SteinSteffi1\AppData\Local\Temp\ipykernel_11680\2738765218.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df
# 1995-02-16 16:27:25.400000+00:00           NaN       NaN      NaN       NaN
# ...                                        ...       ...      ...       ...
# 2020-12-20 15:16:45.796000+00:00          13.0  0.103078      5.2 -5.097941
# 2020-12-20 15:53:57.395000+00:00          13.0  0.103078      5.2 -5.097941
# 2020-12-22 03:27:21.031000+00:00          13.0  0.104610      5.2 -5.098352
# 2020-12-24 22:09:10.232000+00:00          13.0  0.104610      5.2 -5.098352
# 2020-12-26 18:23:21.550000+00:00          13.0  0.105397      5.2 -5.098557
#
# [1698 rows x 14 columns]

# %%
# Drop the intermediate columns
df.drop(columns=['energy_squared_root', 'cumulative_energy_squared', 'mean_mag', 'min_mag', 'event_counts', 'a_value', 'max_mag'], inplace=True)
# Out:
# C:\Users\SteinSteffi1\AppData\Local\Temp\ipykernel_11680\1093842324.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.drop(columns=['energy_squared_root', 'cumulative_energy_squared', 'mean_mag', 'min_mag', 'event_counts', 'a_value', 'max_mag'], inplace=True)

# %%
df.dropna(subset=['RSRER'], inplace=True)
df.isna().sum()
# Out:
# C:\Users\SteinSteffi1\AppData\Local\Temp\ipykernel_11680\2534608267.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.dropna(subset=['RSRER'], inplace=True)
# depth      0
# mag        0
# ED         0
# energy     0
# RSRER      0
# b_value    0
# MD         0
# dtype: int64

# %%
df['earthquake'] = np.where((df['mag'] > mag_filter) & (df['depth'] < depth_filter), 1, 
                            np.where(df['mag']<=mag_filter, -1, 0) )

df['earthquake'].value_counts()
# Out:
# C:\Users\SteinSteffi1\AppData\Local\Temp\ipykernel_11680\14959589.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['earthquake'] = np.where((df['mag'] > mag_filter) & (df['depth'] < depth_filter), 1,
# earthquake
# -1    845
#  1    673
#  0      3
# Name: count, dtype: int64

# %%
def occurence_criterion(raw_array):
    # print(raw_array)
    # print("---------------------")
    target = -1
    if len(raw_array) > 0:
        if raw_array['earthquake'].eq(1).any():
            target = 1
        if raw_array['earthquake'].eq(0).any():
            target = 0
    if len(raw_array) == 0:
        target = 0

        
    return target


earthquake_occurence = df[['earthquake']].resample(resample_rate).apply(occurence_criterion)
print(earthquake_occurence.value_counts())
monthly_df = df.resample(resample_rate).mean()
monthly_df = monthly_df.fillna(0)
monthly_df['earthquake'] = earthquake_occurence
print(monthly_df)
# Out:
# C:\Users\SteinSteffi1\AppData\Local\Temp\ipykernel_11680\3388938703.py:17: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   earthquake_occurence = df[['earthquake']].resample(resample_rate).apply(occurence_criterion)
#  1    186
# -1     47
#  0     14
# Name: count, dtype: int64
#                                depth       mag           ED        energy  \
# timestamp
# 2000-06-30 00:00:00+00:00  42.400000  4.466667  1976.333333  3.760890e+18
# 2000-07-31 00:00:00+00:00  61.000000  4.300000  1911.666667  2.473703e+18
# 2000-08-31 00:00:00+00:00  69.166667  4.733333  1802.666667  8.052972e+18
# 2000-09-30 00:00:00+00:00  33.000000  4.800000  1720.000000  1.000000e+19
# 2000-10-31 00:00:00+00:00  33.000000  4.400000  1708.666667  5.511537e+18
# ...                              ...       ...          ...           ...
# 2020-08-31 00:00:00+00:00  29.616667  4.683333   769.500000  1.302972e+19
# 2020-09-30 00:00:00+00:00  38.920000  4.500000   783.250000  5.029166e+18
# 2020-10-31 00:00:00+00:00  39.796667  4.400000   813.666667  3.848987e+18
# 2020-11-30 00:00:00+00:00   0.000000  0.000000     0.000000  0.000000e+00
# 2020-12-31 00:00:00+00:00  48.049091  4.281818   870.909091  2.118022e+18
#
#                                   RSRER   b_value        MD  earthquake
# timestamp
# 2000-06-30 00:00:00+00:00  6.731465e+07  0.787837 -5.686084           1
# 2000-07-31 00:00:00+00:00  6.605044e+07  0.806484 -5.686699           1
# 2000-08-31 00:00:00+00:00  6.976356e+07  0.789647 -5.685196           1
# 2000-09-30 00:00:00+00:00  7.443554e+07  0.770026 -5.683691           1
# 2000-10-31 00:00:00+00:00  7.245997e+07  0.802452 -5.685743           1
# ...                                 ...       ...       ...         ...
# 2020-08-31 00:00:00+00:00  1.229447e+08  0.996355 -4.929817           1
# 2020-09-30 00:00:00+00:00  1.258752e+08  0.961991 -5.095252           1
# 2020-10-31 00:00:00+00:00  1.249103e+08  0.928547 -5.093374           1
# 2020-11-30 00:00:00+00:00  0.000000e+00  0.000000  0.000000           0
# 2020-12-31 00:00:00+00:00  1.102451e+08  0.984145 -5.096561           1
#
# [247 rows x 8 columns]
# C:\Users\SteinSteffi1\AppData\Local\Temp\ipykernel_11680\3388938703.py:19: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   monthly_df = df.resample(resample_rate).mean()

# %%
df = monthly_df[['depth', 'mag', 'ED', 'RSRER', 'b_value', 'MD', 'earthquake']]
# df = monthly_df[['mag', 'ED','MD', 'earthquake']]
df
# Out:
#                                depth       mag           ED         RSRER  \
# timestamp
# 2000-06-30 00:00:00+00:00  42.400000  4.466667  1976.333333  6.731465e+07
# 2000-07-31 00:00:00+00:00  61.000000  4.300000  1911.666667  6.605044e+07
# 2000-08-31 00:00:00+00:00  69.166667  4.733333  1802.666667  6.976356e+07
# 2000-09-30 00:00:00+00:00  33.000000  4.800000  1720.000000  7.443554e+07
# 2000-10-31 00:00:00+00:00  33.000000  4.400000  1708.666667  7.245997e+07
# ...                              ...       ...          ...           ...
# 2020-08-31 00:00:00+00:00  29.616667  4.683333   769.500000  1.229447e+08
# 2020-09-30 00:00:00+00:00  38.920000  4.500000   783.250000  1.258752e+08
# 2020-10-31 00:00:00+00:00  39.796667  4.400000   813.666667  1.249103e+08
# 2020-11-30 00:00:00+00:00   0.000000  0.000000     0.000000  0.000000e+00
# 2020-12-31 00:00:00+00:00  48.049091  4.281818   870.909091  1.102451e+08
#
#                             b_value        MD  earthquake
# timestamp
# 2000-06-30 00:00:00+00:00  0.787837 -5.686084           1
# 2000-07-31 00:00:00+00:00  0.806484 -5.686699           1
# 2000-08-31 00:00:00+00:00  0.789647 -5.685196           1
# 2000-09-30 00:00:00+00:00  0.770026 -5.683691           1
# 2000-10-31 00:00:00+00:00  0.802452 -5.685743           1
# ...                             ...       ...         ...
# 2020-08-31 00:00:00+00:00  0.996355 -4.929817           1
# 2020-09-30 00:00:00+00:00  0.961991 -5.095252           1
# 2020-10-31 00:00:00+00:00  0.928547 -5.093374           1
# 2020-11-30 00:00:00+00:00  0.000000  0.000000           0
# 2020-12-31 00:00:00+00:00  0.984145 -5.096561           1
#
# [247 rows x 7 columns]

# %%
correlation_matrix = df.corr()
correlation_matrix
# Out:
#                depth       mag        ED     RSRER   b_value        MD  \
# depth       1.000000  0.450107  0.356803 -0.176684  0.507566 -0.475532
# mag         0.450107  1.000000  0.453395  0.097815  0.675032 -0.936609
# ED          0.356803  0.453395  1.000000 -0.285788  0.225485 -0.469613
# RSRER      -0.176684  0.097815 -0.285788  1.000000 -0.043020 -0.082054
# b_value     0.507566  0.675032  0.225485 -0.043020  1.000000 -0.571020
# MD         -0.475532 -0.936609 -0.469613 -0.082054 -0.571020  1.000000
# earthquake -0.142769  0.266427  0.010623  0.090382  0.042685 -0.166463
#
#             earthquake
# depth        -0.142769
# mag           0.266427
# ED            0.010623
# RSRER         0.090382
# b_value       0.042685
# MD           -0.166463
# earthquake    1.000000

# %%
# Replace infinite values with a large number
df.replace([np.inf, -np.inf], 1e10, inplace=True)
# Out:
# C:\Users\SteinSteffi1\AppData\Local\Temp\ipykernel_11680\2297783001.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.replace([np.inf, -np.inf], 1e10, inplace=True)

# %%
from sklearn.preprocessing import MinMaxScaler

# Initialize the MinMaxScaler with the desired feature range
scaler = MinMaxScaler(feature_range=(-1, 1))

# Apply the scaler to the dataframe
df[df.columns] = scaler.fit_transform(df)

# Display the scaled dataframe
df
# Out:
# C:\Users\SteinSteffi1\AppData\Local\Temp\ipykernel_11680\3980167207.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[df.columns] = scaler.fit_transform(df)
#                               depth       mag        ED     RSRER   b_value  \
# timestamp
# 2000-06-30 00:00:00+00:00 -0.096334  0.654321  1.000000 -0.986537  0.060149
# 2000-07-31 00:00:00+00:00  0.300085  0.592593  0.934559 -0.986790  0.085240
# 2000-08-31 00:00:00+00:00  0.474140  0.753086  0.824254 -0.986047  0.062584
# 2000-09-30 00:00:00+00:00 -0.296675  0.777778  0.740597 -0.985113  0.036181
# 2000-10-31 00:00:00+00:00 -0.296675  0.629630  0.729128 -0.985508  0.079816
# ...                             ...       ...       ...       ...       ...
# 2020-08-31 00:00:00+00:00 -0.368784  0.734568 -0.221285 -0.975411  0.340739
# 2020-09-30 00:00:00+00:00 -0.170503  0.666667 -0.207371 -0.974825  0.294497
# 2020-10-31 00:00:00+00:00 -0.151819  0.629630 -0.176590 -0.975018  0.249494
# 2020-11-30 00:00:00+00:00 -1.000000 -1.000000 -1.000000 -1.000000 -1.000000
# 2020-12-31 00:00:00+00:00  0.024064  0.585859 -0.118662 -0.977951  0.324309
#
#                                  MD  earthquake
# timestamp
# 2000-06-30 00:00:00+00:00 -0.726867         1.0
# 2000-07-31 00:00:00+00:00 -0.727054         1.0
# 2000-08-31 00:00:00+00:00 -0.726597         1.0
# 2000-09-30 00:00:00+00:00 -0.726140         1.0
# 2000-10-31 00:00:00+00:00 -0.726764         1.0
# ...                             ...         ...
# 2020-08-31 00:00:00+00:00 -0.497188         1.0
# 2020-09-30 00:00:00+00:00 -0.547431         1.0
# 2020-10-31 00:00:00+00:00 -0.546861         1.0
# 2020-11-30 00:00:00+00:00  1.000000         0.0
# 2020-12-31 00:00:00+00:00 -0.547829         1.0
#
# [247 rows x 7 columns]

# %%
import numpy as np

def create_lstm_dataset(df, lookback, n_future):
    """
    Creates an LSTM dataset from the given DataFrame.

    Parameters:
    - df: pandas DataFrame containing features.
    - lookback: Number of past timesteps to include in each X sample.

    Returns:
    - X: 3D NumPy array of shape (samples, lookback, features)
    - Y: 1D NumPy array of shape (samples,)
    """
    data = df.values  # Convert dataframe to NumPy array
    X, Y = [], []
    
    for i in range(len(data) - lookback):
        X.append(data[i:i + lookback, :7])  # First 6 columns
        Y.append(data[(i + lookback):(i + lookback + n_future), -1])     # 7th column as label
    
    return np.array(X), np.array(Y)
look_back = 10
X, Y = create_lstm_dataset(df, lookback=look_back, n_future=1)

print(X.shape)  # (number of samples, lookback, 6)
print(Y.shape)  # (number of samples,)
# Out:
# (237, 10, 7)
# (237, 1)

# %%
from sklearn.model_selection import train_test_split

# Split the data
X_train, X_val, Y_train, Y_val = train_test_split(X, Y, test_size=0.15, shuffle=False)

# Print the shapes of the resulting datasets
print("X_train shape:", X_train.shape)
print("X_val shape:", X_val.shape)
print("Y_train shape:", Y_train.shape)
print("Y_val shape:", Y_val.shape)
# Out:
# X_train shape: (201, 10, 7)
# X_val shape: (36, 10, 7)
# Y_train shape: (201, 1)
# Y_val shape: (36, 1)

# %%
print(X_train[0])
# Out:
# [[-0.09633419  0.65432099  1.         -0.98653707  0.06014875 -0.7268671
#    1.        ]
#  [ 0.30008525  0.59259259  0.93455895 -0.98678991  0.0852403  -0.72705386
#    1.        ]
#  [ 0.47414038  0.75308642  0.82425367 -0.98604729  0.06258435 -0.72659745
#    1.        ]
#  [-0.29667519  0.77777778  0.74059707 -0.98511289  0.03618064 -0.72614031
#    1.        ]
#  [-0.29667519  0.62962963  0.72912801 -0.98550801  0.07981557 -0.72676354
#    1.        ]
#  [-0.29667519  0.81481481  0.72744139 -0.98527461  0.06643409 -0.72645313
#    1.        ]
#  [-0.29667519  0.51851852  0.73351324 -0.98543589  0.08223311 -0.72660954
#   -1.        ]
#  [-0.29667519  0.98148148  0.64547141 -0.98354231  0.03664993 -0.7260717
#    1.        ]
#  [-0.29667519  0.75925926  0.61308821 -0.98239227 -0.01281664 -0.72525052
#    1.        ]
#  [-0.29667519  0.76851852  0.61055827 -0.98189796 -0.0332126  -0.72489985
#    1.        ]]

# %%
# Count occurrences of 0 and 1 in Y_train
unique_train, counts_train = np.unique(Y_train, return_counts=True)
print("Y_train counts:", dict(zip(unique_train, counts_train)))

# Count occurrences of 0 and 1 in Y_val
unique_val, counts_val = np.unique(Y_val, return_counts=True)
print("Y_val counts:", dict(zip(unique_val, counts_val)))
# Out:
# Y_train counts: {-1.0: 39, 0.0: 9, 1.0: 153}
# Y_val counts: {-1.0: 7, 0.0: 5, 1.0: 24}

# %%
# root mean squared error (rmse) for regression (only for Keras tensors)
def rmse(y_true, y_pred):
    from keras import backend
    return backend.sqrt(backend.mean(backend.square(y_pred - y_true), axis=-1))

# mean squared error (mse) for regression  (only for Keras tensors)
def mse(y_true, y_pred):
    from keras import backend
    return backend.mean(backend.square(y_pred - y_true), axis=-1)

# coefficient of determination (R^2) for regression  (only for Keras tensors)
def r_square(y_true, y_pred):
    from keras import backend as K
    SS_res =  K.sum(K.square(y_true - y_pred)) 
    SS_tot = K.sum(K.square(y_true - K.mean(y_true))) 
    return ( 1 - SS_res/(SS_tot + K.epsilon()) )

# %%
# import tensorflow as tf
# from tensorflow.keras.layers import *
# from tensorflow.keras.models import Model
# from tensorflow.keras.layers import Input, LSTM, Dense, Layer, Dropout

# from tensorflow.keras.optimizers.legacy import Adam

# from tensorflow.keras.regularizers import L1L2
# from tensorflow.keras.layers import Layer, Dense, Dot, Activation

# from tensorflow.keras.callbacks import Callback, EarlyStopping

# from tensorflow.keras import backend as K

# from matplotlib import pyplot as plt

# K.clear_session()

   
# l1 = 0.0001
# l2 = 0.0001

# lstm_dropout = 0.2
# recurrent_dropout = 0.1
# dense_dropout = 0.2
# loss = 'mse'

# n_target = Y_train.shape[-2:]

# regularization_criteria = L1L2(l1=l1, l2=l2)

# n_target_y = Y_train.shape[-1]

# def build_model(input_shape):
#     input_layer = Input(shape=input_shape, name='Input_1')
#     sequence = input_layer
#     sequence = LSTM(20, return_sequences = True,  name="LSTM-1", kernel_regularizer = regularization_criteria, dropout=lstm_dropout, recurrent_dropout=recurrent_dropout)(input_layer)
#     sequence = Flatten()(sequence)
#     # sequence = Dropout(dense_dropout)(sequence)
#     # sequence = LSTM(16, return_sequences = False,  name="LSTM-2", kernel_regularizer = regularization_criteria, dropout=lstm_dropout, recurrent_dropout=recurrent_dropout)(sequence)
#     # sequence = Dense(4, activation = 'tanh', name='Dense_3')(sequence)
#     sequence = Dense(n_target_y, activation = 'tanh', name='Dense_4')(sequence)
#     output_layer = sequence

#     model = Model(inputs=input_layer, outputs=output_layer)

#     return model

# input_shape = (look_back, X_train.shape[2])

# learning_rate = 0.0005

# optimizer = Adam(learning_rate=learning_rate)

# model = build_model(input_shape)
# model.compile(optimizer=optimizer, loss=loss, metrics=[mse, rmse, r_square])
# model.summary()

# import time

# start_time = time.time()

# # early_stopping = EarlyStopping(monitor='val_loss', patience=500, restore_best_weights=True)

# history = model.fit(X_train, Y_train, epochs=700, batch_size=64, validation_data=(X_val, Y_val),
#                     # callbacks=[early_stopping]
#                     )

# end_time = time.time()
# difference_in_seconds = end_time - start_time
# print(f"The difference in seconds is: {difference_in_seconds}")

# %%
# import keras_tuner as kt
# import tensorflow as tf
# from tensorflow import keras
# from tensorflow.keras.layers import LSTM, Bidirectional, Dense, Dropout, Flatten

# def build_model(hp):
#     model = keras.Sequential()
    
#     model.add(LSTM(units=hp.Int('lstm_units', min_value=16, max_value=128, step=16),
#                    return_sequences=True,
#                      input_shape=(look_back, X_train.shape[2])))
    
#     # model.add(Dropout(hp.Float('dropout', min_value=0.0, max_value=0.5, step=0.1)))
    
#     # model.add(Bidirectional(LSTM(units=hp.Int('bidirectional_units', min_value=4, max_value=16, step=4),
#     #                              return_sequences=True)))
    
#     # model.add(Bidirectional(LSTM(units=hp.Int('bidirectional_units', min_value=4, max_value=32, step=4),
#     #                              return_sequences=True)))
    
#     model.add(Flatten())
    
#     model.add(Dropout(hp.Float('dropout', min_value=0.0, max_value=0.5, step=0.1)))
    
#     model.add(Dense(hp.Float('dense_units', min_value=0, max_value=32, step=8), activation='tanh'))
    
#     model.add(Dense(1, activation='tanh'))
    
#     model.compile(optimizer=keras.optimizers.Adam(hp.Choice('learning_rate', values=[1e-4, 1e-5])),
#                     loss='mse',
#                     metrics=[rmse, r_square])
    
#     return model

# %%
# import keras_tuner as kt
# import tensorflow as tf
# from tensorflow import keras
# from tensorflow.keras.layers import LSTM, Bidirectional, Dense, Dropout, Flatten, Attention, Input
# from tensorflow.keras.models import Model

# def build_model(hp):
#     inputs = Input(shape=(look_back, X_train.shape[2]))
    
#     lstm_out = LSTM(units=60,
#                     return_sequences=True)(inputs)

    
#     flatten = Flatten()(lstm_out)
    
#     dropout = Dropout(hp.Float('dropout', min_value=0.0, max_value=0.5, step=0.1))(flatten)
    
#     dense = Dense(hp.Int('dense_units', min_value=0, max_value=32, step=4), activation='tanh')(dropout)
    
#     output = Dense(1, activation='tanh')(dense)
    
#     model = Model(inputs=inputs, outputs=output)
    
#     model.compile(optimizer=keras.optimizers.Adam(hp.Choice('learning_rate', values=[1e-4, 1e-5])),
#                   loss='mse',
#                   metrics=[rmse, r_square])
    
#     return model

# %%
# tuner = kt.RandomSearch(build_model,
#                         objective=kt.Objective("val_r_square", direction="max"),
#                         max_trials=20,
#                         executions_per_trial=2,
#                         directory='my_dir',
#                         project_name='earthquake')

# %%
# tuner.search(X_train, Y_train, epochs=150, validation_data=(X_val, Y_val))

# %%
# from tensorflow.keras.callbacks import Callback, EarlyStopping
# best_hps = tuner.get_best_hyperparameters(num_trials=5)[0]

# # print(f"Best LSTM units: {best_hps.get('lstm_units')}")
# # print(f"Best BiLSTM usage: {best_hps.get('bidirectional_units')}")
# print(f"Best Dropout Rate: {best_hps.get('dropout')}")
# print(f"Best Dense Units: {best_hps.get('dense_units')}")
# print(f"Best Learning Rate: {best_hps.get('learning_rate')}")

# # Train the best model
# best_model = tuner.hypermodel.build(best_hps)
# early_stopping = EarlyStopping(monitor='val_loss', patience=700, restore_best_weights=True)
# history = best_model.fit(X_train, Y_train, epochs=1000, validation_data=(X_val, Y_val), callbacks=[early_stopping])

# %%
# # Generate predictions for the training set
# Y_train_pred = best_model.predict(X_train)

# # Plot the true values and predictions
# plt.figure(figsize=(10, 6))
# plt.plot(Y_train, label='True Values', color='blue',  marker='o')
# plt.plot(Y_train_pred, label='Predictions', color='red', linestyle='dashed', marker='o')
# plt.title('Training True Values vs Predictions')
# plt.xlabel('Sample Index')
# plt.ylabel('Value')
# plt.legend()
# plt.show()

# %%
# # Generate predictions for the validation set
# Y_val_pred = best_model.predict(X_val)

# # Plot the true values and predictions
# plt.figure(figsize=(10, 6))
# plt.plot(Y_val, label='True Values', color='blue', marker='o')
# plt.plot(Y_val_pred, label='Predictions', color='red', linestyle='dashed', marker='o')
# plt.title('Validation True Values vs Predictions')
# plt.xlabel('Sample Index')
# plt.ylabel('Value')
# plt.legend()
# plt.show()

# %%
# # Generate predictions for the validation set
# Y_val_pred = best_model.predict(X_val)
# Y_val_pred = np.where(Y_val_pred > 0.5, 1,np.where(Y_val_pred<-0.5, -1, 0) )

# # Plot the true values and predictions
# plt.figure(figsize=(10, 6))
# plt.plot(Y_val, label='True Values', color='blue', marker='o')
# plt.plot(Y_val_pred, label='Predictions', color='red', linestyle='dashed', marker='o')
# plt.title('Validation True Values vs Predictions')
# plt.xlabel('Sample Index')
# plt.ylabel('Value')
# plt.legend()
# plt.show()

# %%
# from sklearn.metrics import confusion_matrix

# # Create confusion matrix
# conf_matrix = confusion_matrix(Y_val.flatten(), Y_val_pred.flatten())

# # Print the confusion matrix
# print("Confusion Matrix:")
# print(conf_matrix)

# %%
# # Calculate total accuracy
# total_accuracy = np.sum(Y_val.flatten() == Y_val_pred.flatten()) / len(Y_val)
# print(f"Total Accuracy: {total_accuracy * 100:.2f}%")

# %%
# Create a mask to filter out values in Y_test that are not equal to 0
mask = Y_val != 0
# print(X_test.shape)
# Apply the mask to filter X_test and Y_test
X_test_filtered = np.array([x for x, m in zip(X_val, mask) if m])
Y_test_filtered = Y_val[mask]

# Print the shapes of the filtered arrays to verify
print(X_test_filtered.shape)
print(Y_test_filtered.shape)
# Out:
# (31, 10, 7)
# (31,)

# %%
# # Generate predictions for the validation set
# Y_val_pred = best_model.predict(X_test_filtered)
# Y_val_pred = np.where(Y_val_pred > 0.15, 1, -1)

# # Plot the true values and predictions
# plt.figure(figsize=(10, 6))
# plt.plot(Y_test_filtered, label='True Values', color='blue', marker='o')
# plt.plot(Y_val_pred, label='Predictions', color='red', linestyle='dashed', marker='o')
# plt.title('Validation True Values vs Predictions')
# plt.xlabel('Sample Index')
# plt.ylabel('Value')
# plt.legend()
# plt.show()

# %%
# from sklearn.metrics import confusion_matrix

# # Create confusion matrix
# conf_matrix = confusion_matrix(Y_test_filtered.flatten(), Y_val_pred.flatten())

# # Print the confusion matrix
# print("Confusion Matrix:")
# print(conf_matrix)

# %%
# # Calculate total accuracy
# total_accuracy = np.sum(Y_test_filtered.flatten() == Y_val_pred.flatten()) / len(Y_test_filtered)
# print(f"Total Accuracy: {total_accuracy * 100:.2f}%")

# %%
import tensorflow as tf
from tensorflow.keras.layers import *
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, LSTM, Dense, Layer, Dropout

from tensorflow.keras.optimizers.legacy import Adam

from tensorflow.keras.regularizers import L1L2
from tensorflow.keras.layers import Layer, Dense, Dot, Activation

from tensorflow.keras.callbacks import Callback, EarlyStopping

from tensorflow.keras import backend as K

from matplotlib import pyplot as plt

K.clear_session()

   
l1 = 0.0
l2 = 0.0

lstm_dropout = 0.0
recurrent_dropout = 0.0
dense_dropout = 0.1
loss = 'mse'

n_target = Y_train.shape[-2:]

regularization_criteria = L1L2(l1=l1, l2=l2)

n_target_y = Y_train.shape[-1]

def build_model(input_shape):
    input_layer = Input(shape=input_shape, name='Input_1')
    sequence = input_layer
    sequence = LSTM(60, return_sequences = True,  name="LSTM-1", kernel_regularizer = regularization_criteria, dropout=lstm_dropout, recurrent_dropout=recurrent_dropout)(input_layer)
    
    sequence = Flatten()(sequence)
    sequence = Dropout(0.2)(sequence)
    # sequence = LSTM(16, return_sequences = False,  name="LSTM-2", kernel_regularizer = regularization_criteria, dropout=lstm_dropout, recurrent_dropout=recurrent_dropout)(sequence)
    sequence = Dense(12, activation = 'tanh', name='Dense_3')(sequence)
    sequence = Dense(n_target_y, activation = 'tanh', name='Dense_4')(sequence)
    output_layer = sequence

    model = Model(inputs=input_layer, outputs=output_layer)

    return model

input_shape = (look_back, X_train.shape[2])

learning_rate = 0.0001

optimizer = Adam(learning_rate=learning_rate)

model = build_model(input_shape)
model.compile(optimizer=optimizer, loss=loss, metrics=[mse, rmse, r_square])
model.summary()

import time

start_time = time.time()

early_stopping = EarlyStopping(monitor='val_loss', patience=700, restore_best_weights=True)

history = model.fit(X_train, Y_train, epochs=1000, batch_size=64, validation_data=(X_val, Y_val),
                    callbacks=[early_stopping]
                    )

end_time = time.time()
difference_in_seconds = end_time - start_time
print(f"The difference in seconds is: {difference_in_seconds}")
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  Input_1 (InputLayer)        [(None, 10, 7)]           0
#
#  LSTM-1 (LSTM)               (None, 10, 60)            16320
#
#  flatten (Flatten)           (None, 600)               0
#
#  dropout (Dropout)           (None, 600)               0
#
#  Dense_3 (Dense)             (None, 12)                7212
#
#  Dense_4 (Dense)             (None, 1)                 13
#
# =================================================================
# Total params: 23,545
# Trainable params: 23,545
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/1000
# 4/4 [==============================] - 2s 236ms/step - loss: 0.8192 - mse: 0.8192 - rmse: 0.8751 - r_square: -0.4616 - val_loss: 0.7120 - val_mse: 0.7120 - val_rmse: 0.7867 - val_r_square: -0.1157
# Epoch 2/1000
# 4/4 [==============================] - 0s 24ms/step - loss: 0.7491 - mse: 0.7491 - rmse: 0.8221 - r_square: -0.2156 - val_loss: 0.6801 - val_mse: 0.6801 - val_rmse: 0.7589 - val_r_square: -0.0659
# Epoch 3/1000
# 4/4 [==============================] - 0s 29ms/step - loss: 0.7025 - mse: 0.7025 - rmse: 0.7808 - r_square: -0.1440 - val_loss: 0.6651 - val_mse: 0.6651 - val_rmse: 0.7379 - val_r_square: -0.0423
# Epoch 4/1000
# 4/4 [==============================] - 0s 28ms/step - loss: 0.6736 - mse: 0.6736 - rmse: 0.7525 - r_square: -9960863.0000 - val_loss: 0.6589 - val_mse: 0.6589 - val_rmse: 0.7227 - val_r_square: -0.0326
# Epoch 5/1000
# 4/4 [==============================] - 0s 29ms/step - loss: 0.6820 - mse: 0.6820 - rmse: 0.7336 - r_square: -0.1358 - val_loss: 0.6568 - val_mse: 0.6568 - val_rmse: 0.7072 - val_r_square: -0.0293
# Epoch 6/1000
# 4/4 [==============================] - 0s 19ms/step - loss: 0.6742 - mse: 0.6742 - rmse: 0.7164 - r_square: -0.3963 - val_loss: 0.6579 - val_mse: 0.6579 - val_rmse: 0.6957 - val_r_square: -0.0310
# Epoch 7/1000
# 4/4 [==============================] - 0s 25ms/step - loss: 0.6555 - mse: 0.6555 - rmse: 0.6977 - r_square: -6041428.0000 - val_loss: 0.6592 - val_mse: 0.6592 - val_rmse: 0.6907 - val_r_square: -0.0331
# Epoch 8/1000
# 4/4 [==============================] - 0s 29ms/step - loss: 0.6460 - mse: 0.6460 - rmse: 0.6848 - r_square: 0.0359 - val_loss: 0.6615 - val_mse: 0.6615 - val_rmse: 0.6844 - val_r_square: -0.0366
# Epoch 9/1000
# 4/4 [==============================] - 0s 58ms/step - loss: 0.6534 - mse: 0.6534 - rmse: 0.6779 - r_square: -0.0991 - val_loss: 0.6640 - val_mse: 0.6640 - val_rmse: 0.6791 - val_r_square: -0.0405
# Epoch 10/1000
# 4/4 [==============================] - 0s 26ms/step - loss: 0.6405 - mse: 0.6405 - rmse: 0.6684 - r_square: -0.0263 - val_loss: 0.6663 - val_mse: 0.6663 - val_rmse: 0.6747 - val_r_square: -0.0441
# Epoch 11/1000
# 4/4 [==============================] - 0s 24ms/step - loss: 0.6473 - mse: 0.6473 - rmse: 0.6617 - r_square: -0.0231 - val_loss: 0.6687 - val_mse: 0.6687 - val_rmse: 0.6707 - val_r_square: -0.0479
# Epoch 12/1000
# 4/4 [==============================] - 0s 27ms/step - loss: 0
# 4/4 [==============================] - 0s 18ms/step - loss: 0.5865 - mse: 0.5865 - rmse: 0.6418 - r_square: 0.0278 - val_loss: 0.6592 - val_mse: 0.6592 - val_rmse: 0.6783 - val_r_square: -0.0331
# Epoch 163/1000
# 4/4 [==============================] - 0s 22ms/step - loss: 0.5747 - mse: 0.5747 - rmse: 0.6234 - r_square: 0.0838 - val_loss: 0.6603 - val_mse: 0.6603 - val_rmse: 0.6767 - val_r_square: -0.0348
# Epoch 164/1000
# 4/4 [==============================] - 0s 19ms/step - loss: 0.5742 - mse: 0.5742 - rmse: 0.6258 - r_square: -0.0089 - val_loss: 0.6601 - val_mse: 0.6601 - val_rmse: 0.6782 - val_r_square: -0.0344
# Epoch 165/1000
# 4/4 [==============================] - 0s 22ms/step - loss: 0.5777 - mse: 0.5777 - rmse: 0.6261 - r_square: -3875467.0000 - val_loss: 0.6594 - val_mse: 0.6594 - val_rmse: 0.6800 - val_r_square: -0.0334
# Epoch 166/1000
# 4/4 [==============================] - 0s 19ms/step - loss: 0.5718 - mse: 0.5718 - rmse: 0.6242 - r_square: 0.0119 - val_loss: 0.6606 - val_mse: 0.6606 - val_rmse: 0.6773 - val_r_square: -0.0353
# Epoch 167/1000
# 4/4 [==============================] - 0s 23ms/step - loss: 0.5753 - mse: 0.5753 - rmse: 0.6275 - r_square: -4866457.0000 - val_loss: 0.6635 - val_mse: 0.6635 - val_rmse: 0.6720 - val_r_square: -0.0398
# Epoch 168/1000
# 4/4 [==============================] - 0s 20ms/step - loss: 0.5916 - mse: 0.5916 - rmse: 0.6272 - r_square: -0.0899 - val_loss: 0.6690 - val_mse: 0.6690 - val_rmse: 0.6636 - val_r_square: -0.0485
# Epoch 169/1000
# 4/4 [==============================] - 0s 19ms/step - loss: 0.5825 - mse: 0.5825 - rmse: 0.6031 - r_square: 0.0703 - val_loss: 0.6741 - val_mse: 0.6741 - val_rmse: 0.6571 - val_r_square: -0.0564
# Epoch 170/1000
# 4/4 [==============================] - 0s 19ms/step - loss: 0.5738 - mse: 0.5738 - rmse: 0.5940 - r_square: 0.1346 - val_loss: 0.6761 - val_mse: 0.6761 - val_rmse: 0.6550 - val_r_square: -0.0595
# Epoch 171/1000
# 4/4 [==============================] - 0s 22ms/step - loss: 0.5796 - mse: 0.5796 - rmse: 0.5928 - r_square: 0.0294 - val_loss: 0.6764 - val_mse: 0.6764 - val_rmse: 0.6551 - val_r_square: -0.0600
# Epoch 172/1000
# 4/4 [==============================] - 0s 21ms/step - loss: 0.5950 - mse: 0.5950 - rmse: 0.6054 - r_square: 2.5398e-04 - val_loss: 0.6770 - val_mse: 0.6770 - val_rmse: 0.6548 - val_r_square: -0.0609
# Epoch 173/1000
# 4/4 [==============================] - 0s 19ms/step - loss: 0.5764 - mse: 0.5764 - rmse: 0.5906 - r_square: -0.0399 - val_loss: 0.6779 - val_mse: 0.6779 - val_rmse: 0.6539 - val_r_square: -0.0624
# Epoch 174/1000
# 4/4 [==============================] - 0s 18ms/step - loss: 0.5846 - mse: 0.5846 - rmse: 0.5982 - r_square: -0.0576 - val_loss: 0.6786 - val_mse: 0.6786 - val_rmse: 0.6534 - val_r_square: -0.0635
# Epoch 175/1000
# 4/4 [==============================] - 0s 20ms/step - loss: 0.5915 - mse: 0.5915 - rmse: 0.6018 - r_square: 0.0536 - val_loss: 0.6747 - val_mse: 0.6747 - val_rmse: 0.6584 - val_r_square: -0.0574
# Epoch 176/1000
# 4/4 [==============================] - 0s 22ms/step - loss: 0.5647 - mse: 0.5647 - rmse: 0.5982 - r_square: 0.0585 - val_loss: 0.6711 - val_mse: 0.6711 - val_rmse: 0.6634 - val_r_square: -0.0517
# Epoch 177/1000
# 4/4 [==============================] - 0s 19ms/step - loss: 0.
1000
# 4/4 [==============================] - 0s 19ms/step - loss: 0.5815 - mse: 0.5815 - rmse: 0.6365 - r_square: 0.1496 - val_loss: 0.6592 - val_mse: 0.6592 - val_rmse: 0.6902 - val_r_square: -0.0331
# Epoch 193/1000
# 4/4 [==============================] - 0s 21ms/step - loss: 0.5881 - mse: 0.5881 - rmse: 0.6508 - r_square: 0.0570 - val_loss: 0.6593 - val_mse: 0.6593 - val_rmse: 0.6909 - val_r_square: -0.0332
# Epoch 194/1000
# 4/4 [==============================] - 0s 19ms/step - loss: 0.5616 - mse: 0.5616 - rmse: 0.6336 - r_square: -4290932.0000 - val_loss: 0.6603 - val_mse: 0.6603 - val_rmse: 0.6870 - val_r_square: -0.0348
# Epoch 195/1000
# 4/4 [==============================] - 0s 22ms/step - loss: 0.5816 - mse: 0.5816 - rmse: 0.6376 - r_square: 0.1204 - val_loss: 0.6633 - val_mse: 0.6633 - val_rmse: 0.6785 - val_r_square: -0.0395
# Epoch 196/1000
# 4/4 [==============================] - 0s 20ms/step - loss: 0.5773 - mse: 0.5773 - rmse: 0.6261 - r_square: 0.0957 - val_loss: 0.6674 - val_mse: 0.6674 - val_rmse: 0.6701 - val_r_square: -0.0459
# Epoch 197/1000
# 4/4 [==============================] - 0s 19ms/step - loss: 0.5634 - mse: 0.5634 - rmse: 0.6046 - r_square: 0.0549 - val_loss: 0.6708 - val_mse: 0.6708 - val_rmse: 0.6643 - val_r_square: -0.0512
# Epoch 198/1000
# 4/4 [==============================] - 0s 20ms/step - loss: 0.5745 - mse: 0.5745 - rmse: 0.6016 - r_square: 0.0812 - val_loss: 0.6729 - val_mse: 0.6729 - val_rmse: 0.6614 - val_r_square: -0.0545
# Epoch 199/1000
# 4/4 [==============================] - 0s 22ms/step - loss: 0.5729 - mse: 0.5729 - rmse: 0.5993 - r_square: 0.0495 - val_loss: 0.6726 - val_mse: 0.6726 - val_rmse: 0.6619 - val_r_square: -0.0541
# Epoch 200/1000
# 4/4 [==============================] - 0s 19ms/step - loss: 0.5804 - mse: 0.5804 - rmse: 0.6085 - r_square: 0.0756 - val_loss: 0.6692 - val_mse: 0.6692 - val_rmse: 0.6672 - val_r_square: -0.0487
# Epoch 201/1000
# 4/4 [==============================] - 0s 23ms/step - loss: 0.5759 - mse: 0.5759 - rmse: 0.6080 - r_square: -0.0115 - val_loss: 0.6669 - val_mse: 0.6669 - val_rmse: 0.6713 - val_r_square: -0.0452
# Epoch 202/1000
# 4/4 [==============================] - 0s 22ms/step - loss: 0.5767 - mse: 0.5767 - rmse: 0.6119 - r_square: 0.0571 - val_loss: 0.6666 - val_mse: 0.6666 - val_rmse: 0.6722 - val_r_square: -0.0447
# Epoch 203/1000
# 4/4 [==============================] - 0s 19ms/step - loss: 0.5710 - mse: 0.5710 - rmse: 0.6119 - r_square: -4229946.0000 - val_loss: 0.6665 - val_mse: 0.6665 - val_rmse: 0.6733 - val_r_square: -0.0445
# Epoch 204/1000
# 4/4 [==============================] - 0s 22ms/step - loss: 0.5707 - mse: 0.5707 - rmse: 0.6088 - r_square: 0.1327 - val_loss: 0.6681 - val_mse: 0.6681 - val_rmse: 0.6712 - val_r_square: -0.0470
# Epoch 205/1000
# 4/4 [==============================] - 0s 21ms/step - loss: 0.5754 - mse: 0.5754 - rmse: 0.6090 - r_square: 0.0748 - val_loss: 0.6682 - val_mse: 0.6682 - val_rmse: 0.6717 - val_r_square: -0.0471
# Epoch 206/1000
# 4/4 [==============================] - 0s 22ms/step - loss: 0.5620 - mse: 0.5620 - rmse: 0.6075 - r_square: 0.1141 - val_loss: 0.6673 - val_mse: 0.6673 - val_rmse: 0.6737 - val_r_square: -0.0457
# Epoch 207/1000
# 4/4 [==============================] - 0s 19ms/step - loss: 0.5582 - mse: 0.5582 - rmse: 0.6033 - r_square: 0.2139 - val_loss: 0.6664 - val_mse: 0.6664 - val_rmse: 0.6760 - val_r_square: -0.0443
# Epoch 208/1000
# 4/4 [==============================] - 0s 22ms/step - loss: 0.5643 - mse: 0.5643 - rmse: 0.6086 - r_square: -4722848.0000 - val_loss: 0.6664 - val_mse: 0.6664 - val_rmse: 0.6762 - val_r_square: -0.0443
# Epoch 209/1000
# 4/4 [==============================] - 0s 19ms/step - loss: 0.5642 - mse: 0.5642 - rmse: 0.6104 - r_square: 0.0338 - val_loss: 0.6685 - val_mse: 0.6685 - val_rmse: 0.6720 - val_r_square: -0.0476
# Epoch 210/1000
# 4/4 [==============================] - 0s 20ms/step - loss: 0.5707 - mse: 0.5707 - rmse: 0.6014 - r_square: 0.0861 - val_loss: 0.6707 - val_mse: 0.6707 - val_rmse: 0.6683 - val_r_square: -0.0510
# Epoch 211/1000
# 4/4 [==============================] - 0s 19ms/step - loss: 0.5696 - mse: 0.5696 - rmse: 0.6006 - r_square: 0.0757 - val_loss: 0.6720 - val_mse: 0.6720 - val_rmse: 0.6667 - val_r_square: -0.0531
# Epoch 212/1000
# 4/4 [==============================] - 0s 22ms/step - loss: 0.5724 - mse: 0.5724 - rmse: 0.5975 - r_square: 0.0982 - val_loss: 0.6721 - val_mse: 0.6721 - val_rmse: 0.6669 - val_r_square: -0.0533
# Epoch 213/1000
# 4/4 [==============================] - 0s 18ms/step - loss: 0.5604 - mse: 0.5604 - rmse: 0.6024 - r_square: 0.1188 - val_loss: 0.6698 - val_mse: 0.6698 - val_rmse: 0.6713 - val_r_square: -0.0497
# Epoch 214/1000
# 4/4 [==============================] - 0s 19ms/step - loss: 0.5643 - mse: 0.5643 - rmse: 0.6079 - r_square: -0.0789 - val_loss: 0.6670 - val_mse: 0.6670 - val_rmse: 0.6782 - val_r_square: -0.0453
# Epoch 215/1000
# 4/4 [==============================] - 0s 19ms/step - loss: 0.5650 - mse: 0.5650 - rmse: 0.6144 - r_square: 0.0171 - val_loss: 0.6645 - val_mse: 0.6645 - val_rmse: 0.6885 - val_r_square: -0.0414
# Epoch 216/1000
# 4/4 [==============================] - 0s 19ms/step - loss: 0.5725 - mse: 0.5725 - rmse: 0.6252 - r_square: 0.1127 - val_loss: 0.6647 - val_mse: 0.6647 - val_rmse: 0.6906 - val_r_square: -0.0416
# Epoch 217/1000
# 4/4 [==============================] - 0s 19ms/step - loss: 0.5617 - mse: 0.5617 - rmse: 0.6196 - r_square: 0.0891 - val_loss: 0.6657 - val_mse: 0.6657 - val_rmse: 0.6886 - val_r_square: -0.0433
# Epoch 218/1000
# 4/4 [==============================] - 0s 22ms/step - loss: 0.5806 - mse: 0.5806 - rmse: 0.6314 - r_square: -0.0225 - val_loss: 0.6665 - val_mse: 0.6665 - val_rmse: 0.6875 - val_r_square: -0.0445
# Epoch 219/1000
# 4/4 [==============================] - 0s 19ms/step - loss: 0.5613 - mse: 0.5613 - rmse: 0.6166 - r_square: 0.1881 - val_loss: 0.6686 - val_mse: 0.6686 - val_rmse: 0.6821 - val_r_square: -0.0477
# Epoch 220/1000
# 4/4 [==============================] - 0s 20ms/step - loss: 0.5688 - mse: 0.5688 - rmse: 0.6155 - r_square: 0.0918 - val_loss: 0.6702 - val_mse: 0.6702 - val_rmse: 0.6791 - val_r_square: -0.0503
# Epoch 221/1000
# 4/4 [==============================] - 0s 22ms/step - loss: 0.5548 - mse: 0.5548 - rmse: 0.6008 - r_square: 0.1319 - val_loss: 0.6727 - val_mse: 0.6727 - val_rmse: 0.6740 - val_r_square: -0.0541
# Epoch 222/1000
# 4/4 [==============================] - 0s 22ms/step - loss: 0.5535 - mse: 0.5535 - rmse: 0.5897 - r_square: -3235525.5000 - val_loss: 0.6738 - val_mse: 0.6738 - val_rmse: 0.6715 - val_r_square: -0.0559
# Epoch 223/1000
# ...
# Epoch 713/1000
# 4/4 [==============================] - 0s 30ms/step - loss:
1000
# 4/4 [==============================] - 0s 24ms/step - loss: 0.4736 - mse: 0.4736 - rmse: 0.5273 - r_square: -4977897.0000 - val_loss: 0.7575 - val_mse: 0.7575 - val_rmse: 0.7042 - val_r_square: -0.1870
# Epoch 730/1000
# 4/4 [==============================] - 0s 30ms/step - loss: 0.4584 - mse: 0.4584 - rmse: 0.5103 - r_square: 0.1379 - val_loss: 0.7573 - val_mse: 0.7573 - val_rmse: 0.6993 - val_r_square: -0.1867
# Epoch 731/1000
# 4/4 [==============================] - 0s 78ms/step - loss: 0.4701 - mse: 0.4701 - rmse: 0.5165 - r_square: -2223316.5000 - val_loss: 0.7576 - val_mse: 0.7576 - val_rmse: 0.7052 - val_r_square: -0.1873
# Epoch 732/1000
# 4/4 [==============================] - 0s 38ms/step - loss: 0.4615 - mse: 0.4615 - rmse: 0.5130 - r_square: 0.3307 - val_loss: 0.7577 - val_mse: 0.7577 - val_rmse: 0.7049 - val_r_square: -0.1873
# Epoch 733/1000
# 4/4 [==============================] - 0s 37ms/step - loss: 0.4828 - mse: 0.4828 - rmse: 0.5265 - r_square: 0.1789 - val_loss: 0.7580 - val_mse: 0.7580 - val_rmse: 0.7054 - val_r_square: -0.1879
# Epoch 734/1000
# 4/4 [==============================] - 0s 28ms/step - loss: 0.4466 - mse: 0.4466 - rmse: 0.5031 - r_square: 0.3384 - val_loss: 0.7581 - val_mse: 0.7581 - val_rmse: 0.7068 - val_r_square: -0.1881
# Epoch 735/1000
# 4/4 [==============================] - 0s 24ms/step - loss: 0.4699 - mse: 0.4699 - rmse: 0.5179 - r_square: 0.2940 - val_loss: 0.7579 - val_mse: 0.7579 - val_rmse: 0.7079 - val_r_square: -0.1878
# Epoch 736/1000
# 4/4 [==============================] - 0s 37ms/step - loss: 0.4638 - mse: 0.4638 - rmse: 0.5186 - r_square: 0.3433 - val_loss: 0.7585 - val_mse: 0.7585 - val_rmse: 0.7117 - val_r_square: -0.1886
# Epoch 737/1000
# 4/4 [==============================] - 0s 24ms/step - loss: 0.4728 - mse: 0.4728 - rmse: 0.5278 - r_square: 0.2737 - val_loss: 0.7581 - val_mse: 0.7581 - val_rmse: 0.7109 - val_r_square: -0.1880
# Epoch 738/1000
# 4/4 [==============================] - 0s 24ms/step - loss: 0.4590 - mse: 0.4590 - rmse: 0.5204 - r_square: 0.2499 - val_loss: 0.7578 - val_mse: 0.7578 - val_rmse: 0.7110 - val_r_square: -0.1876
# Epoch 739/1000
# 4/4 [==============================] - 0s 24ms/step - loss: 0.4717 - mse: 0.4717 - rmse: 0.5283 - r_square: 0.0708 - val_loss: 0.7567 - val_mse: 0.7567 - val_rmse: 0.7039 - val_r_square: -0.1859
# Epoch 740/1000
# 4/4 [==============================] - 0s 25ms/step - loss: 0.4730 - mse: 0.4730 - rmse: 0.5129 - r_square: -2408916.2500 - val_loss: 0.7562 - val_mse: 0.7562 - val_rmse: 0.6934 - val_r_square: -0.1851
# Epoch 741/1000
# 4/4 [==============================] - 0s 23ms/step - loss: 0.4576 - mse: 0.4576 - rmse: 0.4979 - r_square: 0.3679 - val_loss: 0.7565 - val_mse: 0.7565 - val_rmse: 0.6865 - val_r_square: -0.1856
# Epoch 742/1000
# 4/4 [==============================] - 0s 25ms/step - loss: 0.4696 - mse: 0.4696 - rmse: 0.4952 - r_square: 0.3236 - val_loss: 0.7567 - val_mse: 0.7567 - val_rmse: 0.6866 - val_r_square: -0.1858
# Epoch 743/1000
# 4/4 [==============================] - 0s 24ms/step - loss: 0.4657 - mse: 0.4657 - rmse: 0.4952 - r_square: 0.3193 - val_loss: 0.7564 - val_mse: 0.7564 - val_rmse: 0.6926 - val_r_square: -0.1854
# Epoch 744/1000
# 4/4 [==============================] - 0s 83ms/step - loss: 0.4727 - mse: 0.4727 - rmse: 0.5108 - r_square: 0.2598 - val_loss: 0.7571 - val_mse: 0.7571 - val_rmse: 0.7040 - val_r_square: -0.1865
# Epoch 745/1000
# 4/4 [==============================] - 0s 44ms/step - loss: 0.4746 - mse: 0.4746 - rmse: 0.5261 - r_square: 0.2636 - val_loss: 0.7600 - val_mse: 0.7600 - val_rmse: 0.7166 - val_r_square: -0.1910
# Epoch 746/1000
# 4/4 [==============================] - 0s 24ms/step - loss: 0.4701 - mse: 0.4701 - rmse: 0.5351 - r_square: -4782227.0000 - val_loss: 0.7648 - val_mse: 0.7648 - val_rmse: 0.7285 - val_r_square: -0.1985
# Epoch 747/1000
# 4/4 [==============================] - 0s 24ms/step - loss: 0.4718 - mse: 0.4718 - rmse: 0.5423 - r_square: 0.2426 - val_loss: 0.7633 - val_mse: 0.7633 - val_rmse: 0.7224 - val_r_square: -0.1962
# Epoch 748/1000
# 4/4 [==============================] - 0s 30ms/step - loss: 0.4702 - mse: 0.4702 - rmse: 0.5287 - r_square: 0.2579 - val_loss: 0.7611 - val_mse: 0.7611 - val_rmse: 0.7116 - val_r_square: -0.1928
# Epoch 749/1000
# 4/4 [==============================] - 0s 30ms/step - loss: 0.4447 - mse: 0.4447 - rmse: 0.5094 - r_square: -6253574.0000 - val_loss: 0.7606 - val_mse: 0.7606 - val_rmse: 0.7045 - val_r_square: -0.1919
# Epoch 750/1000
# 4/4 [==============================] - 0s 49ms/step - loss: 0.4759 - mse: 0.4759 - rmse: 0.5118 - r_square: 0.2080 - val_loss: 0.7604 - val_mse: 0.7604 - val_rmse: 0.6910 - val_r_square: -0.1917
# Epoch 751/1000
# 4/4 [==============================] - 0s 41ms/step - loss: 0.4754 - mse: 0.4754 - rmse: 0.5040 - r_square: 0.2011 - val_loss: 0.7608 - val_mse: 0.7608 - val_rmse: 0.6941 - val_r_square: -0.1923
# Epoch 752/1000
# 4/4 [==============================] - 0s 66ms/step - loss: 0.4832 - mse: 0.4832 - rmse: 0.5116 - r_square: 0.0190 - val_loss: 0.7609 - val_mse: 0.7609 - val_rmse: 0.7000 - val_r_square: -0.1924
# Epoch 753/1000
# 4/4 [==============================] - 0s 28ms/step - loss: 0.4776 - mse: 0.4776 - rmse: 0.5151 - r_square: 0.2303 - val_loss: 0.7612 - val_mse: 0.7612 - val_rmse: 0.7044 - val_r_square: -0.1928
# Epoch 754/1000
# 4/4 [==============================] - 0s 41ms/step - loss: 0.4588 - mse: 0.4588 - rmse: 0.5099 - r_square: 0.3091 - val_loss: 0.7624 - val_mse: 0.7624 - val_rmse: 0.7114 - val_r_square: -0.1947
# Epoch 755/1000
# 4/4 [==============================] - 0s 35ms/step - loss: 0.4730 - mse: 0.4730 - rmse: 0.5204 - r_square: 0.3187 - val_loss: 0.7632 - val_mse: 0.7632 - val_rmse: 0.7139 - val_r_square: -0.1960
# Epoch 756/1000
# 4/4 [==============================] - 0s 28ms/step - loss: 0.4603 - mse: 0.4603 - rmse: 0.5164 - r_square: 0.2912 - val_loss: 0.7647 - val_mse: 0.7647 - val_rmse: 0.7169 - val_r_square: -0.1984
# Epoch 757/1000
# 4/4 [==============================] - 0s 30ms/step - loss: 0.4684 - mse: 0.4684 - rmse: 0.5211 - r_square: 0.3300 - val_loss: 0.7654 - val_mse: 0.7654 - val_rmse: 0.7174 - val_r_square: -0.1995
# Epoch 758/1000
# 4/4 [==============================] - 0s 27ms/step - loss: 0.4754 - mse: 0.4754 - rmse: 0.5274 - r_square: 0.2076 - val_loss: 0.7660 - val_mse: 0.7660 - val_rmse: 0.7175 - val_r_square: -0.2003
# Epoch 759/1000
# 4/4 [==============================] - 0s 32ms/step - loss: 0.5008 - mse: 0.5008 - rmse: 0.5435 - r_square: 0.2258 - val_loss: 0.7667 - val_mse: 0.7667 - val_rmse: 0.7185 - val_r_square: -0.2014
# Epoch 760/1000
# 4/4 [==============================] - 0s 24ms/step - loss: 0.4658 - mse: 0.4658 - rmse: 0.5250 - r_square: 0.3464 - val_loss: 0.7658 - val_mse: 0.7658 - val_rmse: 0.7152 - val_r_square: -0.2000
# Epoch 761/1000
# 4/4 [==============================] - 0s 26ms/step - loss: 0.4480 - mse: 0.4480 - rmse: 0.5148 - r_square: 0.2535 - val_loss: 0.7649 - val_mse: 0.7649 - val_rmse: 0.7127 - val_r_square: -0.1987
# Epoch 762/1000
# 4/4 [==============================] - 0s 24ms/step - loss: 0.4583 - mse: 0.4583 - rmse: 0.5166 - r_square: 0.2300 - val_loss: 0.7643 - val_mse: 0.7643 - val_rmse: 0.7123 - val_r_square: -0.1978
# Epoch 763/1000
# 4/4 [==============================] - 0s 24ms/step - loss: 0.4633 - mse: 0.4633 - rmse: 0.5239 - r_square: 0.3469 - val_loss: 0.7633 - val_mse: 0.7633 - val_rmse: 0.7102 - val_r_square: -0.1962
# Epoch 764/1000
# 4/4 [==============================] - 0s 28ms/step - loss: 0.4771 - mse: 0.4771 - rmse: 0.5249 - r_square: 0.2279 - val_loss: 0.7624 - val_mse: 0.7624 - val_rmse: 0.7068 - val_r_square: -0.1947
# Epoch 765/1000
# 4/4 [==============================] - 0s 25ms/step - loss: 0.4734 - mse: 0.4734 - rmse: 0.5241 - r_square: 0.2063 - val_loss: 0.7635 - val_mse: 0.7635 - val_rmse: 0.7114 - val_r_square: -0.1965
# Epoch 766/1000
# 4/4 [==============================] - 0s 25ms/step - loss: 0.4671 - mse: 0.4671 - rmse: 0.5171 - r_square: 0.3417 - val_loss: 0.7649 - val_mse: 0.7649 - val_rmse: 0.7151 - val_r_square: -0.1986
# Epoch 767/1000
# 4/4 [==============================] - 0s 39ms/step - loss: 0.4536 - mse: 0.4536 - rmse: 0.5171 - r_square: 0.1881 - val_loss: 0.7649 - val_mse: 0.7649 - val_rmse: 0.7149 - val_r_square: -0.1987
# Epoch 768/1000
# 4/4 [==============================] - 0s 98ms/step - loss: 0.4747 - mse: 0.4747 - rmse: 0.5234 - r_square: 0.2609 - val_loss: 0.7644 - val_mse: 0.7644 - val_rmse: 0.7125 - val_r_square: -0.1979
# Epoch 769/1000
# 4/4 [==============================] - 0s 29ms/step - loss: 0.4558 - mse: 0.4558 - rmse: 0.5177 - r_square: 0.2494 - val_loss: 0.7644 - val_mse: 0.7644 - val_rmse: 0.7096 - val_r_square: -0.1978
# Epoch 770/1000
# 4/4 [==============================] - 0s 24ms/step - loss: 0.4720 - mse: 0.4720 - rmse: 0.5134 - r_square: 0.2617 - val_loss: 0.7645 - val_mse: 0.7645 - val_rmse: 0.7081 - val_r_square: -0.1981
# Epoch 771/1000
# 4/4 [==============================] - 0s 28ms/step - loss: 0.4633 - mse: 0.4633 - rmse: 0.5086 - r_square: 0.2539 - val_loss: 0.7648 - val_mse: 0.7648 - val_rmse: 0.7128 - val_r_square: -0.1985
# Epoch 772/1000
# 4/4 [==============================] - 0s 34ms/step - loss: 0.4656 - mse: 0.4656 - rmse: 0.5173 - r_square: 0.2839 - val_loss: 0.7662 - val_mse: 0.7662 - val_rmse: 0.7213 - val_r_square: -0.2008
# Epoch 773/1000
# 4/4 [==============================] - 0s 39ms/step - loss: 0.4456 - mse: 0.4456 - rmse: 0.5134 - r_square: 0.3429 - val_loss: 0.7664 - val_mse: 0.7664 - val_rmse: 0.7239 - val_r_square: -0.2010
# Epoch 774/1000
# 4/4 [==============================] - 0s 38ms/step - loss: 0.4543 - mse: 0.4543 - rmse: 0.5236 - r_square: 0.2479 - val_loss: 0.7671 - val_mse: 0.7671 - val_rmse: 0.7281 - val_r_square: -0.2021
# Epoch 775/1000
# 4/4 [==============================] - 0s 24ms/step - loss: 0.4690 - mse: 0.4690 - rmse: 0.5406 - r_square: 0.1939 - val_loss: 0.7664 - val_mse: 0.7664 - val_rmse: 0.7284 - val_r_square: -0.2010
# Epoch 776/1000
# 4/4 [==============================] - 0s 25ms/step - loss: 0.4465 - mse: 0.4465 - rmse: 0.5303 - r_square: 0.3519 - val_loss: 0.7604 - val_mse: 0.7604 - val_rmse: 0.7136 - val_r_square: -0.1916
# Epoch 777/1000
# 4/4 [==============================] - 0s 89ms/step - loss: 0.4815 - mse: 0.4815 - rmse: 0.5377 - r_square: -2481767.2500 - val_loss: 0.7574 - val_mse: 0.7574 - val_rmse: 0.6936 - val_r_square: -0.1869
# Epoch 778/1000
# 4/4 [==============================] - 0s 35ms/step - loss: 0.4645 - mse: 0.4645 - rmse: 0.5061 - r_square: 0.0615 - val_loss: 0.7580 - val_mse: 0.7580 - val_rmse: 0.6809 - val_r_square: -0.1879
# Epoch 779/1000
# 4/4 [==============================] - 0s 37ms/step - loss: 0.4818 - mse: 0.4818 - rmse: 0.5049 - r_square: 0.1886 - val_loss: 0.7568 - val_mse: 0.7568 - val_rmse: 0.6899 - val_r_square: -0.1860
# Epoch 780/1000
# 4/4 [==============================] - 0s 28ms/step - loss: 0.4743 - mse: 0.4743 - rmse: 0.5166 - r_square: -2580603.2500 - val_loss: 0.7568 - val_mse: 0.7568 - val_rmse: 0.6970 - val_r_square: -0.1860
# Epoch 781/1000
# 4/4 [==============================] - 0s 24ms/step - loss: 0.4616 - mse: 0.4616 - rmse: 0.5091 - r_square: 0.3346 - val_loss: 0.7572 - val_mse: 0.7572 - val_rmse: 0.6987 - val_r_square: -0.1867
# Epoch 782/1000
# 4/4 [==============================] - 0s 24ms/step - loss: 0.4551 - mse: 0.4551 - rmse: 0.5059 - r_square: 0.3327 - val_loss: 0.7580 - val_mse: 0.7580 - val_rmse: 0.7016 - val_r_square: -0.1879
# Epoch 783/1000
# 4/4 [==============================] - 0s 25ms/step - loss: 0.4599 - mse: 0.4599 - rmse: 0.5118 - r_square: 0.3062 - val_loss: 0.7584 - val_mse: 0.7584 - val_rmse: 0.6985 - val_r_square: -0.1885
# Epoch 784/1000
# 4/4 [==============================] - 0s 24ms/step - loss: 0.4565 - mse: 0.4565 - rmse: 0.4978 - r_square: 0.1918 - val_loss: 0.7585 - val_mse: 0.7585 - val_rmse: 0.6920 - val_r_square: -0.1887
# Epoch 785/1000
# 4/4 [==============================] - 0s 28ms/step - loss: 0.4616 - mse: 0.4616 - rmse: 0.5026 - r_square: 0.3383 - val_loss: 0.7588 - val_mse: 0.7588 - val_rmse: 0.6918 - val_r_square: -0.1892
# Epoch 786/1000
# 4/4 [==============================] - 0s 32ms/step - loss: 0.4734 - mse: 0.4734 - rmse: 0.5089 - r_square: 0.3250 - val_loss: 0.7592 - val_mse: 0.7592 - val_rmse: 0.6936 - val_r_square: -0.1897
# Epoch 787/1000
# 4/4 [==============================] - 0s 28ms/step - loss: 0.4436 - mse: 0.4436 - rmse: 0.4996 - r_square: 0.2589 - val_loss: 0.7598 - val_mse: 0.7598 - val_rmse: 0.6952 - val_r_square: -0.1906
# The difference in seconds is: 84.89553880691528

# %%
# Extract the metrics from the history object
loss = history.history['loss']
val_loss = history.history['val_loss']
r_square = history.history['r_square']
val_r_square = history.history['val_r_square']

# Plot loss and val_loss
plt.figure(figsize=(12, 6))
plt.plot(loss, label='Training Loss', color='blue')
plt.plot(val_loss, label='Validation Loss', color='orange')
plt.title('Training Loss vs Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.grid()
plt.show()

# Plot r_square and val_r_square
plt.figure(figsize=(12, 6))
plt.plot(r_square, label='Training R^2', color='green')
plt.plot(val_r_square, label='Validation R^2', color='red')
plt.title('Training R^2 vs Validation R^2')
plt.xlabel('Epochs')
plt.ylabel('R^2')
plt.legend()
plt.grid()
plt.show()

# %%
# Find the minimum loss for training and validation
min_training_loss = min(loss)
min_validation_loss = min(val_loss)

# Print the results
print(f"Minimum Training Loss: {min_training_loss}")
print(f"Minimum Validation Loss: {min_validation_loss}")
# Out:
# Minimum Training Loss: 0.44358348846435547
# Minimum Validation Loss: 0.6476031541824341

# %%
# Find the maximum R² values for training and validation
max_r_square_train = max(r_square)
max_r_square_val = max(val_r_square)

# Print the results
print(f"Maximum Training R²: {max_r_square_train}")
print(f"Maximum Validation R²: {max_r_square_val}")
# Out:
# Maximum Training R²: 0.36790579557418823
# Maximum Validation R²: -0.014865279197692871

# %%
# model = best_model

# %%
# Generate predictions for the training set
Y_train_pred = model.predict(X_train)

# Plot the true values and predictions
plt.figure(figsize=(10, 6))
plt.plot(Y_train, label='True Values', color='blue',  marker='o')
plt.plot(Y_train_pred, label='Predictions', color='red', linestyle='dashed', marker='o')
plt.title('Training True Values vs Predictions')
plt.xlabel('Sample Index')
plt.ylabel('Value')
plt.legend()
plt.show()
# Out:
# 7/7 [==============================] - 0s 4ms/step

# %%
# Generate predictions for the validation set
Y_val_pred = model.predict(X_val)

# Plot the true values and predictions
plt.figure(figsize=(10, 6))
plt.plot(Y_val, label='True Values', color='blue', marker='o')
plt.plot(Y_val_pred, label='Predictions', color='red', linestyle='dashed', marker='o')
plt.title('Validation True Values vs Predictions')
plt.xlabel('Sample Index')
plt.ylabel('Value')
plt.legend()
plt.show()
# Out:
# 2/2 [==============================] - 0s 8ms/step

# %%
# Generate predictions for the validation set
Y_val_pred = model.predict(X_val)
Y_val_pred = np.where(Y_val_pred > 0.5, 1,np.where(Y_val_pred<-0.5, -1, 0) )

# Plot the true values and predictions
plt.figure(figsize=(10, 6))
plt.plot(Y_val, label='True Values', color='blue', marker='o')
plt.plot(Y_val_pred, label='Predictions', color='red', linestyle='dashed', marker='o')
plt.title('Validation True Values vs Predictions')
plt.xlabel('Sample Index')
plt.ylabel('Value')
plt.legend()
plt.show()
# Out:
# 2/2 [==============================] - 0s 5ms/step

# %%
import matplotlib.pyplot as plt
import numpy as np

# Generate predictions for the validation set
Y_val_pred = model.predict(X_val)
Y_val_pred = np.where(Y_val_pred > 0.5, 1, np.where(Y_val_pred < -0.5, -1, 0))

# Plot
plt.figure(figsize=(12, 6))

# Add soft gray vertical lines for each sample
for i in range(len(Y_val)):
    plt.axvline(x=i, color='gray', linestyle='-', linewidth=0.5, alpha=0.3)

# Plot true values and predictions as scatter
plt.scatter(range(len(Y_val)), Y_val, label='True Values', color='blue', marker='o')
plt.scatter(range(len(Y_val_pred)), Y_val_pred, label='Predictions', color='red', marker='o')

# Styling
plt.title('Validation True Values vs Predictions')
plt.xlabel('Sample Index')
plt.ylabel('Value')
plt.legend()
plt.grid(False)  # Remove default grid
plt.tight_layout()
plt.show()
# Out:
# 2/2 [==============================] - 0s 6ms/step

# %%
from sklearn.metrics import confusion_matrix

# Create confusion matrix
conf_matrix = confusion_matrix(Y_val.flatten(), Y_val_pred.flatten())

# Print the confusion matrix
print("Confusion Matrix:")
print(conf_matrix)
# Out:
# Confusion Matrix:
# [[ 0  3  4]
#  [ 0  3  2]
#  [ 0 13 11]]

# %%
# Calculate total accuracy
total_accuracy = np.sum(Y_val.flatten() == Y_val_pred.flatten()) / len(Y_val)
print(f"Total Accuracy: {total_accuracy * 100:.2f}%")
# Out:
# Total Accuracy: 38.89%

# %%
# Generate predictions for the validation set
Y_val_pred = model.predict(X_test_filtered)
Y_val_pred = np.where(Y_val_pred > 0.42, 1, -1)

# Plot the true values and predictions
plt.figure(figsize=(10, 6))
plt.plot(Y_test_filtered, label='True Values', color='blue', marker='o')
plt.plot(Y_val_pred, label='Predictions', color='red', linestyle='dashed', marker='o')
plt.title('Validation True Values vs Predictions')
plt.xlabel('Sample Index')
plt.ylabel('Value')
plt.legend()
plt.show()
# Out:
# 1/1 [==============================] - 0s 37ms/step

# %%
import matplotlib.pyplot as plt
import numpy as np

# Generate predictions for the validation set
Y_val_pred = model.predict(X_test_filtered)
Y_val_pred = np.where(Y_val_pred > 0.2, 1, -1)

# Plot the true values and predictions
plt.figure(figsize=(12, 6))

# Add soft gray vertical lines for each sample index
for i in range(len(Y_test_filtered)):
    plt.axvline(x=i, color='gray', linestyle='-', linewidth=0.5, alpha=0.7)

# Plot using scatter (no connecting lines)
plt.scatter(range(len(Y_test_filtered)), Y_test_filtered, label='True Values', color='blue', marker='o')
plt.scatter(range(len(Y_val_pred)), Y_val_pred, label='Predictions', color='red', marker='o')

# Labels and title
plt.title('Validation True Values vs Predictions')
plt.xlabel('Sample Index')
plt.ylabel('Value')
plt.legend()
plt.grid(False)
plt.tight_layout()
plt.show()
# Out:
# 1/1 [==============================] - 0s 37ms/step

# %%
import matplotlib.pyplot as plt
import numpy as np

# Generate predictions for the validation set
Y_val_pred = model.predict(X_test_filtered)
Y_val_pred = np.where(Y_val_pred > 0.42, 1, -1)

# Flatten if needed
Y_val_pred = Y_val_pred.flatten()
Y_test_filtered = Y_test_filtered.flatten()

# Prepare index and classification of correctness
indices = np.arange(len(Y_test_filtered))
correct = Y_val_pred == Y_test_filtered
incorrect = ~correct

# Plot the figure
plt.figure(figsize=(12, 6))

# Add vertical gray lines
for i in range(len(Y_test_filtered)):
    plt.axvline(x=i, color='gray', linestyle='-', linewidth=0.7, alpha=0.7)

# Plot true values as reference shadow
# plt.scatter(indices, Y_test_filtered, color='blue', label='True Value (Reference)', marker='o', alpha=0.3)

# Plot correct predictions (overlapping with true values)
plt.scatter(indices[correct], Y_val_pred[correct], color='blue', marker='o', label='Correct Prediction')

# Plot incorrect predictions
plt.scatter(indices[incorrect], Y_val_pred[incorrect], color='red', marker='o', label='Incorrect Prediction')

# Labels and title
plt.title('Testing True Values vs Predictions')
plt.xlabel('Sample Index')
plt.ylabel('Value')
plt.legend()
plt.grid(False)
plt.tight_layout()
plt.show()
# Out:
# 1/1 [==============================] - 0s 19ms/step

# %%
from sklearn.metrics import confusion_matrix

# Create confusion matrix
conf_matrix = confusion_matrix(Y_test_filtered.flatten(), Y_val_pred.flatten())

# Print the confusion matrix
print("Confusion Matrix:")
print(conf_matrix)
# Out:
# Confusion Matrix:
# [[ 1  6]
#  [ 4 20]]

# %%
# Calculate total accuracy
total_accuracy = np.sum(Y_test_filtered.flatten() == Y_val_pred.flatten()) / len(Y_test_filtered)
print(f"Total Accuracy: {total_accuracy * 100:.2f}%")
# Out:
# Total Accuracy: 67.74%
