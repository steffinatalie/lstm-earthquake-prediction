# %%
import numpy as np
import matplotlib.pyplot as plt
import math
from collections import Counter
import pandas as pd

# %%
bali = pd.read_csv('bali_min4.csv')
jabar = pd.read_csv('jawabarat_min4.csv')
# df = pd.concat([bali, jabar], axis=0)
jatengjatim = pd.read_csv('jatengjatim_min4.csv')
# df = pd.concat([bali, jatengjatim], axis=0)
# df = pd.concat([jabar, jatengjatim], axis=0)
df = pd.concat([bali, jabar, jatengjatim], axis=0)
# df = pd.read_csv('southern_california_min25.csv')
df['timestamp'] = pd.to_datetime(df['time'], errors='coerce', utc=False)
df['Datetime'] = df['timestamp']
df.set_index('timestamp', inplace=True)
df = df.sort_index(ascending=True)
df
# Out:
#                                                       time  latitude  \
# timestamp
# 1995-01-01 02:02:25.490000+00:00  1995-01-01T02:02:25.490Z  -10.9270
# 1995-01-07 15:02:59.810000+00:00  1995-01-07T15:02:59.810Z   -9.0250
# 1995-01-07 18:37:28.920000+00:00  1995-01-07T18:37:28.920Z   -9.2310
# 1995-01-19 09:19:57.180000+00:00  1995-01-19T09:19:57.180Z  -10.7640
# 1995-02-16 16:27:25.400000+00:00  1995-02-16T16:27:25.400Z  -10.0560
# ...                                                    ...       ...
# 2020-12-20 15:16:45.796000+00:00  2020-12-20T15:16:45.796Z   -9.2506
# 2020-12-20 15:53:57.395000+00:00  2020-12-20T15:53:57.395Z   -9.2936
# 2020-12-22 03:27:21.031000+00:00  2020-12-22T03:27:21.031Z   -9.5505
# 2020-12-24 22:09:10.232000+00:00  2020-12-24T22:09:10.232Z   -9.0282
# 2020-12-26 18:23:21.550000+00:00  2020-12-26T18:23:21.550Z   -9.0928
#
#                                   longitude   depth  mag magType  nst    gap  \
# timestamp
# 1995-01-01 02:02:25.490000+00:00   113.0110   18.90  4.5      mb  NaN    NaN
# 1995-01-07 15:02:59.810000+00:00   110.7550  114.80  4.7      mb  NaN    NaN
# 1995-01-07 18:37:28.920000+00:00   117.1110   33.00  4.2      mb  NaN    NaN
# 1995-01-19 09:19:57.180000+00:00   117.1200   33.00  4.9      mb  NaN    NaN
# 1995-02-16 16:27:25.400000+00:00   113.8580   33.00  4.0      mb  NaN    NaN
# ...                                     ...     ...  ...     ...  ...    ...
# 2020-12-20 15:16:45.796000+00:00   110.8510   35.00  4.2      mb  NaN  148.0
# 2020-12-20 15:53:57.395000+00:00   112.1503   35.00  4.3      mb  NaN   53.0
# 2020-12-22 03:27:21.031000+00:00   112.5698   35.00  4.1      mb  NaN  120.0
# 2020-12-24 22:09:10.232000+00:00   117.3729  104.10  4.4      mb  NaN   95.0
# 2020-12-26 18:23:21.550000+00:00   117.1835   63.84  4.1      mb  NaN   71.0
#
#                                    dmin   rms  ...  \
# timestamp                                      ...
# 1995-01-01 02:02:25.490000+00:00    NaN  1.20  ...
# 1995-01-07 15:02:59.810000+00:00    NaN  0.80  ...
# 1995-01-07 18:37:28.920000+00:00    NaN  0.90  ...
# 1995-01-19 09:19:57.180000+00:00    NaN  1.30  ...
# 1995-02-16 16:27:25.400000+00:00    NaN  0.40  ...
# ...                                 ...   ...  ...
# 2020-12-20 15:16:45.796000+00:00  1.368  0.58  ...
# 2020-12-20 15:53:57.395000+00:00  2.114  0.90  ...
# 2020-12-22 03:27:21.031000+00:00  1.896  0.94  ...
# 2020-12-24 22:09:10.232000+00:00  3.231  0.54  ...
# 2020-12-26 18:23:21.550000+00:00  3.059  0.62  ...
#
#                                                                   place  \
# timestamp
# 1995-01-01 02:02:25.490000+00:00         294 km S of Kencong, Indonesia
# 1995-01-07 15:02:59.810000+00:00       126 km SSE of Pundong, Indonesia
# 1995-01-07 18:37:28.920000+00:00  88 km SSW of Sumbawa Besar, Indonesia
# 1995-01-19 09:19:57.180000+00:00         246 km SSE of Praya, Indonesia
# 1995-02-16 16:27:25.400000+00:00   186 km S of Gambiran Satu, Indonesia
# ...                                                                 ...
# 2020-12-20 15:16:45.796000+00:00       153 km SSE of Pundong, Indonesia
# 2020-12-20 15:53:57.395000+00:00  130 km SSW of Sumberpucung, Indonesia
# 2020-12-22 03:27:21.031000+00:00          149 km S of Dampit, Indonesia
# 2020-12-24 22:09:10.232000+00:00    59 km S of Sumbawa Besar, Indonesia
# 2020-12-26 18:23:21.550000+00:00  71 km SSW of Sumbawa Besar, Indonesia
#
#                                         type horizontalError depthError  \
# timestamp
# 1995-01-01 02:02:25.490000+00:00  earthquake             NaN        8.5
# 1995-01-07 15:02:59.810000+00:00  earthquake             NaN       21.5
# 1995-01-07 18:37:28.920000+00:00  earthquake             NaN        NaN
# 1995-01-19 09:19:57.180000+00:00  earthquake             NaN        NaN
# 1995-02-16 16:27:25.400000+00:00  earthquake             NaN        NaN
# ...                                      ...             ...        ...
# 2020-12-20 15:16:45.796000+00:00  earthquake             8.9        1.9
# 2020-12-20 15:53:57.395000+00:00  earthquake             5.3        2.0
# 2020-12-22 03:27:21.031000+00:00  earthquake             5.6        1.9
# 2020-12-24 22:09:10.232000+00:00  earthquake             7.6        8.3
# 2020-12-26 18:23:21.550000+00:00  earthquake             7.1        8.5
#
#                                  magError  magNst    status  locationSource  \
# timestamp
# 1995-01-01 02:02:25.490000+00:00      NaN     4.0  reviewed              us
# 1995-01-07 15:02:59.810000+00:00      NaN    12.0  reviewed              us
# 1995-01-07 18:37:28.920000+00:00      NaN     5.0  reviewed              us
# 1995-01-19 09:19:57.180000+00:00      NaN     8.0  reviewed              us
# 1995-02-16 16:27:25.400000+00:00      NaN     5.0  reviewed              us
# ...                                   ...     ...       ...             ...
# 2020-12-20 15:16:45.796000+00:00    0.186     8.0  reviewed              us
# 2020-12-20 15:53:57.395000+00:00    0.142    14.0  reviewed              us
# 2020-12-22 03:27:21.031000+00:00    0.175     9.0  reviewed              us
# 2020-12-24 22:09:10.232000+00:00    0.134    16.0  reviewed              us
# 2020-12-26 18:23:21.550000+00:00    0.165    13.0  reviewed              us
#
#                                   magSource                         Datetime
# timestamp
# 1995-01-01 02:02:25.490000+00:00         us 1995-01-01 02:02:25.490000+00:00
# 1995-01-07 15:02:59.810000+00:00         us 1995-01-07 15:02:59.810000+00:00
# 1995-01-07 18:37:28.920000+00:00         us 1995-01-07 18:37:28.920000+00:00
# 1995-01-19 09:19:57.180000+00:00         us 1995-01-19 09:19:57.180000+00:00
# 1995-02-16 16:27:25.400000+00:00         us 1995-02-16 16:27:25.400000+00:00
# ...                                     ...                              ...
# 2020-12-20 15:16:45.796000+00:00         us 2020-12-20 15:16:45.796000+00:00
# 2020-12-20 15:53:57.395000+00:00         us 2020-12-20 15:53:57.395000+00:00
# 2020-12-22 03:27:21.031000+00:00         us 2020-12-22 03:27:21.031000+00:00
# 2020-12-24 22:09:10.232000+00:00         us 2020-12-24 22:09:10.232000+00:00
# 2020-12-26 18:23:21.550000+00:00         us 2020-12-26 18:23:21.550000+00:00
#
# [1698 rows x 23 columns]

# %%
df = df[['depth', 'mag']]
df
# Out:
#                                    depth  mag
# timestamp
# 1995-01-01 02:02:25.490000+00:00   18.90  4.5
# 1995-01-07 15:02:59.810000+00:00  114.80  4.7
# 1995-01-07 18:37:28.920000+00:00   33.00  4.2
# 1995-01-19 09:19:57.180000+00:00   33.00  4.9
# 1995-02-16 16:27:25.400000+00:00   33.00  4.0
# ...                                  ...  ...
# 2020-12-20 15:16:45.796000+00:00   35.00  4.2
# 2020-12-20 15:53:57.395000+00:00   35.00  4.3
# 2020-12-22 03:27:21.031000+00:00   35.00  4.1
# 2020-12-24 22:09:10.232000+00:00  104.10  4.4
# 2020-12-26 18:23:21.550000+00:00   63.84  4.1
#
# [1698 rows x 2 columns]

# %%
print(df.isna().sum())
# Out:
# depth    0
# mag      0
# dtype: int64

# %%
mag_unique, frequency = np.unique(df['mag'], return_counts=True)

plt.figure(figsize=(10,8))
plt.hist(df['mag'], bins=1000, color='black', edgecolor='black')

bins = [0, 20, 40, 60]

from matplotlib.ticker import MultipleLocator
# Set x-axis scale to increment by 0.5
plt.gca().xaxis.set_major_locator(MultipleLocator(0.2))
# Add titles and labels
plt.title('Frequency by Magnitude')
plt.xlabel('Magnitude')
plt.ylabel('Frequency')
plt.xticks(fontsize=12, fontname='Times New Roman', rotation=45)

# Show the plot
plt.show()

# %%
mag_filter = 4.5
depth_filter = 100
resample_rate = '1M'

# %%
# def occurence_criterion(raw_array):
#     print(raw_array)
#     print("---------------------")
#     target = -1
#     if len(raw_array) > 0:
#         if raw_array['earthquake'].eq(1).any():
#             target = 1
#         if raw_array['earthquake'].eq(0).any():
#             target = 0
#     if len(raw_array) == 0:
#         target = 0

        
#     return target

# earthquake_occurence = df.resample(resample_rate).apply(occurence_criterion)

# earthquake_occurence = earthquake_occurence.to_frame(name='earthquake')

# earthquake_occurence = earthquake_occurence.sort_index(ascending=True)
# earthquake_occurence['earthquake'].value_counts()

# %%
# Initialize the 'ED' column with NaN values
df['ED'] = np.nan

# Filter the dataframe for earthquakes with magnitude greater than mag_filter
filtered_df = df[df['mag'] > mag_filter]

n = 50

# Calculate the elapsed days for the last n earthquake events
for i in range(n, len(filtered_df)):
    current_time = filtered_df.index[i]
    past_time = filtered_df.index[i-n]
    elapsed_days = (current_time - past_time).days
    df.loc[current_time, 'ED'] = elapsed_days

# Fill NaN values in 'ED' column
for i in range(len(df)):
    if pd.isna(df.iloc[i]['ED']):
        # Find the latest valid 'ED' value before the current index
        last_valid_index = df.iloc[:i]['ED'].last_valid_index()
        if last_valid_index is not None:
            time_since_last_valid = (df.index[i] - last_valid_index).days
            df.at[df.index[i], 'ED'] = df.at[last_valid_index, 'ED'] + time_since_last_valid

# df = df.dropna(subset=['ED'])
df
# Out:
# C:\Users\SteinSteffi1\AppData\Local\Temp\ipykernel_16740\388928700.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['ED'] = np.nan
#                                    depth  mag     ED
# timestamp
# 1995-01-01 02:02:25.490000+00:00   18.90  4.5    NaN
# 1995-01-07 15:02:59.810000+00:00  114.80  4.7    NaN
# 1995-01-07 18:37:28.920000+00:00   33.00  4.2    NaN
# 1995-01-19 09:19:57.180000+00:00   33.00  4.9    NaN
# 1995-02-16 16:27:25.400000+00:00   33.00  4.0    NaN
# ...                                  ...  ...    ...
# 2020-12-20 15:16:45.796000+00:00   35.00  4.2  875.0
# 2020-12-20 15:53:57.395000+00:00   35.00  4.3  875.0
# 2020-12-22 03:27:21.031000+00:00   35.00  4.1  876.0
# 2020-12-24 22:09:10.232000+00:00  104.10  4.4  878.0
# 2020-12-26 18:23:21.550000+00:00   63.84  4.1  879.0
#
# [1698 rows x 3 columns]

# %%
# Initialize the 'energy_squared' and 'cumulative_energy_squared' columns with NaN values
df['energy_squared_root'] = np.nan
df['cumulative_energy_squared'] = np.nan

df['energy'] = 10**(11.8+1.5*df['mag'])

# Calculate the energy squared for each data point
df['energy_squared_root'] = np.sqrt(df['energy'])

# Calculate the cumulative sum of energy squared for the last 50 data points
# for i in range(n, len(df)):
#     df.iloc[i, df.columns.get_loc('cumulative_energy_squared')] = df.iloc[i-n:i]['energy_squared_root'].sum()

df['cumulative_energy_squared'] = df['energy_squared_root'].rolling(n).sum()

# Calculate the RSRER
df['RSRER'] = df['cumulative_energy_squared'] / df['ED']

df['mean_mag'] = df['mag'].rolling(n).mean()
df['min_mag'] = df['mag'].rolling(n).min()
df['b_value'] = np.log10(np.e)/(df['mean_mag'] - df['min_mag'])

df['event_counts'] = df['mag'].rolling(n).apply(lambda x: (x > mag_filter).sum(), raw=True)
df['a_value'] = (np.log10(df['event_counts']) + df['b_value']*df['min_mag'])/n
# df['MSD'] = np.sum((np.log10(df['event_counts'])-(df['a_value']-(df['b_value']*df['mag'])))**2)/(n-1)
df['max_mag'] = df['mag'].rolling(n).max()
df['MD'] = df['a_value']/df['b_value'] - df['max_mag']
# print(df['event_counts'])

df
# Out:
# C:\Users\SteinSteffi1\AppData\Local\Temp\ipykernel_16740\2738765218.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['energy_squared_root'] = np.nan
# C:\Users\SteinSteffi1\AppData\Local\Temp\ipykernel_16740\2738765218.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['cumulative_energy_squared'] = np.nan
# C:\Users\SteinSteffi1\AppData\Local\Temp\ipykernel_16740\2738765218.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['energy'] = 10**(11.8+1.5*df['mag'])
# C:\Users\SteinSteffi1\AppData\Local\Temp\ipykernel_16740\2738765218.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['energy_squared_root'] = np.sqrt(df['energy'])
# C:\Users\SteinSteffi1\AppData\Local\Temp\ipykernel_16740\2738765218.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['cumulative_energy_squared'] = df['energy_squared_root'].rolling(n).sum()
# C:\Users\SteinSteffi1\AppData\Local\Temp\ipykernel_16740\2738765218.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['RSRER'] = df['cumulative_energy_squared'] / df['ED']
# C:\Users\SteinSteffi1\AppData\Local\Temp\ipykernel_16740\2738765218.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['mean_mag'] = df['mag'].rolling(n).mean()
# C:\Users\SteinSteffi1\AppData\Local\Temp\ipykernel_16740\2738765218.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['min_mag'] = df['mag'].rolling(n).min()
# C:\Users\SteinSteffi1\AppData\Local\Temp\ipykernel_16740\2738765218.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['b_value'] = np.log10(np.e)/(df['mean_mag'] - df['min_mag'])
# C:\Users\SteinSteffi1\AppData\Local\Temp\ipykernel_16740\2738765218.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['event_counts'] = df['mag'].rolling(n).apply(lambda x: (x > mag_filter).sum(), raw=True)
# C:\Users\SteinSteffi1\AppData\Local\Temp\ipykernel_16740\2738765218.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['a_value'] = (np.log10(df['event_counts']) + df['b_value']*df['min_mag'])/n
# C:\Users\SteinSteffi1\AppData\Local\Temp\ipykernel_16740\2738765218.py:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['max_mag'] = df['mag'].rolling(n).max()
# C:\Users\SteinSteffi1\AppData\Local\Temp\ipykernel_16740\2738765218.py:27: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['MD'] = df['a_value']/df['b_value'] - df['max_mag']
#                                    depth  mag     ED  energy_squared_root  \
# timestamp
# 1995-01-01 02:02:25.490000+00:00   18.90  4.5    NaN         1.883649e+09
# 1995-01-07 15:02:59.810000+00:00  114.80  4.7    NaN         2.660725e+09
# 1995-01-07 18:37:28.920000+00:00   33.00  4.2    NaN         1.122018e+09
# 1995-01-19 09:19:57.180000+00:00   33.00  4.9    NaN         3.758374e+09
# 1995-02-16 16:27:25.400000+00:00   33.00  4.0    NaN         7.943282e+08
# ...                                  ...  ...    ...                  ...
# 2020-12-20 15:16:45.796000+00:00   35.00  4.2  875.0         1.122018e+09
# 2020-12-20 15:53:57.395000+00:00   35.00  4.3  875.0         1.333521e+09
# 2020-12-22 03:27:21.031000+00:00   35.00  4.1  876.0         9.440609e+08
# 2020-12-24 22:09:10.232000+00:00  104.10  4.4  878.0         1.584893e+09
# 2020-12-26 18:23:21.550000+00:00   63.84  4.1  879.0         9.440609e+08
#
#                                   cumulative_energy_squared        energy  \
# timestamp
# 1995-01-01 02:02:25.490000+00:00                        NaN  3.548134e+18
# 1995-01-07 15:02:59.810000+00:00                        NaN  7.079458e+18
# 1995-01-07 18:37:28.920000+00:00                        NaN  1.258925e+18
# 1995-01-19 09:19:57.180000+00:00                        NaN  1.412538e+19
# 1995-02-16 16:27:25.400000+00:00                        NaN  6.309573e+17
# ...                                                     ...           ...
# 2020-12-20 15:16:45.796000+00:00               9.353097e+10  1.258925e+18
# 2020-12-20 15:53:57.395000+00:00               9.353097e+10  1.778279e+18
# 2020-12-22 03:27:21.031000+00:00               9.259138e+10  8.912509e+17
# 2020-12-24 22:09:10.232000+00:00               9.259138e+10  2.511886e+18
# 2020-12-26 18:23:21.550000+00:00               9.220192e+10  8.912509e+17
#
#                                          RSRER  mean_mag  min_mag   b_value  \
# timestamp
# 1995-01-01 02:02:25.490000+00:00           NaN       NaN      NaN       NaN
# 1995-01-07 15:02:59.810000+00:00           NaN       NaN      NaN       NaN
# 1995-01-07 18:37:28.920000+00:00           NaN       NaN      NaN       NaN
# 1995-01-19 09:19:57.180000+00:00           NaN       NaN      NaN       NaN
# 1995-02-16 16:27:25.400000+00:00           NaN       NaN      NaN       NaN
# ...                                        ...       ...      ...       ...
# 2020-12-20 15:16:45.796000+00:00  1.068925e+08     4.430      4.0  1.009987
# 2020-12-20 15:53:57.395000+00:00  1.068925e+08     4.430      4.0  1.009987
# 2020-12-22 03:27:21.031000+00:00  1.056979e+08     4.422      4.0  1.029134
# 2020-12-24 22:09:10.232000+00:00  1.054572e+08     4.422      4.0  1.029134
# 2020-12-26 18:23:21.550000+00:00  1.048941e+08     4.418      4.0  1.038982
#
#                                   event_counts   a_value  max_mag        MD
# timestamp
# 1995-01-01 02:02:25.490000+00:00           NaN       NaN      NaN       NaN
# 1995-01-07 15:02:59.810000+00:00           NaN       NaN      NaN       NaN
# 1995-01-07 18:37:28.920000+00:00           NaN       NaN      NaN       NaN
# 1995-01-19 09:19:57.180000+00:00           NaN       NaN      NaN       NaN
# 1995-02-16 16:27:25.400000+00:00           NaN       NaN      NaN       NaN
# ...                                        ...       ...      ...       ...
# 2020-12-20 15:16:45.796000+00:00          13.0  0.103078      5.2 -5.097941
# 2020-12-20 15:53:57.395000+00:00          13.0  0.103078      5.2 -5.097941
# 2020-12-22 03:27:21.031000+00:00          13.0  0.104610      5.2 -5.098352
# 2020-12-24 22:09:10.232000+00:00          13.0  0.104610      5.2 -5.098352
# 2020-12-26 18:23:21.550000+00:00          13.0  0.105397      5.2 -5.098557
#
# [1698 rows x 14 columns]

# %%
# Drop the intermediate columns
df.drop(columns=['energy_squared_root', 'cumulative_energy_squared', 'mean_mag', 'min_mag', 'event_counts', 'a_value', 'max_mag'], inplace=True)
# Out:
# C:\Users\SteinSteffi1\AppData\Local\Temp\ipykernel_16740\1093842324.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.drop(columns=['energy_squared_root', 'cumulative_energy_squared', 'mean_mag', 'min_mag', 'event_counts', 'a_value', 'max_mag'], inplace=True)

# %%
df.dropna(subset=['RSRER'], inplace=True)
df.isna().sum()
# Out:
# C:\Users\SteinSteffi1\AppData\Local\Temp\ipykernel_16740\2534608267.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.dropna(subset=['RSRER'], inplace=True)
# depth      0
# mag        0
# ED         0
# energy     0
# RSRER      0
# b_value    0
# MD         0
# dtype: int64

# %%
df['earthquake'] = np.where(df['mag'] > mag_filter, 1,  0) 

df['earthquake'].value_counts()
# Out:
# C:\Users\SteinSteffi1\AppData\Local\Temp\ipykernel_16740\567041027.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['earthquake'] = np.where(df['mag'] > mag_filter, 1,  0)
# earthquake
# 0    845
# 1    676
# Name: count, dtype: int64

# %%
def occurence_criterion(raw_array):
    # print(raw_array)
    # print("---------------------")
    target = 0
    if len(raw_array) > 0:
        if raw_array['earthquake'].eq(1).any():
            target = 1
        if raw_array['earthquake'].eq(0).all():
            target = 0
    # if len(raw_array) == 0:
    #     target = 0

        
    return target


earthquake_occurence = df[['earthquake']].resample(resample_rate).apply(occurence_criterion)
print(earthquake_occurence.value_counts())
monthly_df = df.resample(resample_rate).mean()
# monthly_df = monthly_df.fillna(0)
monthly_df = monthly_df.dropna()
monthly_df['earthquake'] = earthquake_occurence
print(monthly_df)
# Out:
# 1    189
# 0     58
# Name: count, dtype: int64
#                                depth       mag           ED        energy  \
# timestamp
# 2000-06-30 00:00:00+00:00  42.400000  4.466667  1976.333333  3.760890e+18
# 2000-07-31 00:00:00+00:00  61.000000  4.300000  1911.666667  2.473703e+18
# 2000-08-31 00:00:00+00:00  69.166667  4.733333  1802.666667  8.052972e+18
# 2000-09-30 00:00:00+00:00  33.000000  4.800000  1720.000000  1.000000e+19
# 2000-10-31 00:00:00+00:00  33.000000  4.400000  1708.666667  5.511537e+18
# ...                              ...       ...          ...           ...
# 2020-07-31 00:00:00+00:00  41.480000  4.475000   793.250000  4.512269e+18
# 2020-08-31 00:00:00+00:00  29.616667  4.683333   769.500000  1.302972e+19
# 2020-09-30 00:00:00+00:00  38.920000  4.500000   783.250000  5.029166e+18
# 2020-10-31 00:00:00+00:00  39.796667  4.400000   813.666667  3.848987e+18
# 2020-12-31 00:00:00+00:00  48.049091  4.281818   870.909091  2.118022e+18
#
#                                   RSRER   b_value        MD  earthquake
# timestamp
# 2000-06-30 00:00:00+00:00  6.731465e+07  0.787837 -5.686084           1
# 2000-07-31 00:00:00+00:00  6.605044e+07  0.806484 -5.686699           1
# 2000-08-31 00:00:00+00:00  6.976356e+07  0.789647 -5.685196           1
# 2000-09-30 00:00:00+00:00  7.443554e+07  0.770026 -5.683691           1
# 2000-10-31 00:00:00+00:00  7.245997e+07  0.802452 -5.685743           1
# ...                                 ...       ...       ...         ...
# 2020-07-31 00:00:00+00:00  1.226671e+08  0.959921 -4.870344           1
# 2020-08-31 00:00:00+00:00  1.229447e+08  0.996355 -4.929817           1
# 2020-09-30 00:00:00+00:00  1.258752e+08  0.961991 -5.095252           1
# 2020-10-31 00:00:00+00:00  1.249103e+08  0.928547 -5.093374           1
# 2020-12-31 00:00:00+00:00  1.102451e+08  0.984145 -5.096561           1
#
# [236 rows x 8 columns]
# C:\Users\SteinSteffi1\AppData\Local\Temp\ipykernel_16740\404483629.py:17: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   earthquake_occurence = df[['earthquake']].resample(resample_rate).apply(occurence_criterion)
# C:\Users\SteinSteffi1\AppData\Local\Temp\ipykernel_16740\404483629.py:19: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   monthly_df = df.resample(resample_rate).mean()

# %%
df = monthly_df[['depth', 'mag', 'ED', 'RSRER', 'b_value', 'MD', 'earthquake']]
# df = monthly_df[['mag', 'ED','MD', 'earthquake']]
df
# Out:
#                                depth       mag           ED         RSRER  \
# timestamp
# 2000-06-30 00:00:00+00:00  42.400000  4.466667  1976.333333  6.731465e+07
# 2000-07-31 00:00:00+00:00  61.000000  4.300000  1911.666667  6.605044e+07
# 2000-08-31 00:00:00+00:00  69.166667  4.733333  1802.666667  6.976356e+07
# 2000-09-30 00:00:00+00:00  33.000000  4.800000  1720.000000  7.443554e+07
# 2000-10-31 00:00:00+00:00  33.000000  4.400000  1708.666667  7.245997e+07
# ...                              ...       ...          ...           ...
# 2020-07-31 00:00:00+00:00  41.480000  4.475000   793.250000  1.226671e+08
# 2020-08-31 00:00:00+00:00  29.616667  4.683333   769.500000  1.229447e+08
# 2020-09-30 00:00:00+00:00  38.920000  4.500000   783.250000  1.258752e+08
# 2020-10-31 00:00:00+00:00  39.796667  4.400000   813.666667  1.249103e+08
# 2020-12-31 00:00:00+00:00  48.049091  4.281818   870.909091  1.102451e+08
#
#                             b_value        MD  earthquake
# timestamp
# 2000-06-30 00:00:00+00:00  0.787837 -5.686084           1
# 2000-07-31 00:00:00+00:00  0.806484 -5.686699           1
# 2000-08-31 00:00:00+00:00  0.789647 -5.685196           1
# 2000-09-30 00:00:00+00:00  0.770026 -5.683691           1
# 2000-10-31 00:00:00+00:00  0.802452 -5.685743           1
# ...                             ...       ...         ...
# 2020-07-31 00:00:00+00:00  0.959921 -4.870344           1
# 2020-08-31 00:00:00+00:00  0.996355 -4.929817           1
# 2020-09-30 00:00:00+00:00  0.961991 -5.095252           1
# 2020-10-31 00:00:00+00:00  0.928547 -5.093374           1
# 2020-12-31 00:00:00+00:00  0.984145 -5.096561           1
#
# [236 rows x 7 columns]

# %%
correlation_matrix = df.corr()
correlation_matrix
# Out:
#                depth       mag        ED     RSRER   b_value        MD  \
# depth       1.000000 -0.198931  0.167325 -0.256542  0.237642 -0.001971
# mag        -0.198931  1.000000  0.052948  0.059047 -0.261769 -0.187194
# ED          0.167325  0.052948  1.000000 -0.368020 -0.178110 -0.137300
# RSRER      -0.256542  0.059047 -0.368020  1.000000 -0.158173  0.000729
# b_value     0.237642 -0.261769 -0.178110 -0.158173  1.000000  0.568635
# MD         -0.001971 -0.187194 -0.137300  0.000729  0.568635  1.000000
# earthquake -0.237962  0.536719 -0.074258  0.076379 -0.102987 -0.063872
#
#             earthquake
# depth        -0.237962
# mag           0.536719
# ED           -0.074258
# RSRER         0.076379
# b_value      -0.102987
# MD           -0.063872
# earthquake    1.000000

# %%
# Replace infinite values with a large number
df.replace([np.inf, -np.inf], 1e10, inplace=True)
# Out:
# C:\Users\SteinSteffi1\AppData\Local\Temp\ipykernel_16740\2297783001.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.replace([np.inf, -np.inf], 1e10, inplace=True)

# %%
from sklearn.preprocessing import MinMaxScaler

# Initialize the MinMaxScaler with the desired feature range
scaler = MinMaxScaler(feature_range=(-1, 1))

# Apply the scaler to the first 6 columns of the dataframe
df.iloc[:, :6] = scaler.fit_transform(df.iloc[:, :6])

# Display the dataframe
df
# Out:
#                               depth       mag        ED     RSRER   b_value  \
# timestamp
# 2000-06-30 00:00:00+00:00 -0.227099 -0.333333  1.000000 -0.999711 -0.626768
# 2000-07-31 00:00:00+00:00  0.216603 -0.571429  0.933845 -0.999965 -0.583338
# 2000-08-31 00:00:00+00:00  0.411419  0.047619  0.822337 -0.999218 -0.622552
# 2000-09-30 00:00:00+00:00 -0.451336  0.142857  0.737768 -0.998277 -0.668254
# 2000-10-31 00:00:00+00:00 -0.451336 -0.428571  0.726174 -0.998675 -0.592727
# ...                             ...       ...       ...       ...       ...
# 2020-07-31 00:00:00+00:00 -0.249046 -0.321429 -0.210307 -0.988567 -0.225960
# 2020-08-31 00:00:00+00:00 -0.532045 -0.023810 -0.234604 -0.988511 -0.141100
# 2020-09-30 00:00:00+00:00 -0.310115 -0.285714 -0.220537 -0.987921 -0.221140
# 2020-10-31 00:00:00+00:00 -0.289202 -0.428571 -0.189421 -0.988115 -0.299034
# 2020-12-31 00:00:00+00:00 -0.092340 -0.597403 -0.130861 -0.991068 -0.169538
#
#                                  MD  earthquake
# timestamp
# 2000-06-30 00:00:00+00:00  0.008768           1
# 2000-07-31 00:00:00+00:00  0.008078           1
# 2000-08-31 00:00:00+00:00  0.009764           1
# 2000-09-30 00:00:00+00:00  0.011452           1
# 2000-10-31 00:00:00+00:00  0.009150           1
# ...                             ...         ...
# 2020-07-31 00:00:00+00:00  0.923755           1
# 2020-08-31 00:00:00+00:00  0.857046           1
# 2020-09-30 00:00:00+00:00  0.671483           1
# 2020-10-31 00:00:00+00:00  0.673590           1
# 2020-12-31 00:00:00+00:00  0.670015           1
#
# [236 rows x 7 columns]

# %%
import numpy as np

def create_lstm_dataset(df, lookback, n_future):
    """
    Creates an LSTM dataset from the given DataFrame.

    Parameters:
    - df: pandas DataFrame containing features.
    - lookback: Number of past timesteps to include in each X sample.

    Returns:
    - X: 3D NumPy array of shape (samples, lookback, features)
    - Y: 1D NumPy array of shape (samples,)
    """
    data = df.values  # Convert dataframe to NumPy array
    X, Y = [], []
    
    for i in range(len(data) - lookback):
        X.append(data[i:i + lookback, :7])  # First 6 columns
        Y.append(data[(i + lookback):(i + lookback + n_future), -1])     # 7th column as label
    
    return np.array(X), np.array(Y)
look_back = 10
X, Y = create_lstm_dataset(df, lookback=look_back, n_future=1)

print(X.shape)  # (number of samples, lookback, 6)
print(Y.shape)  # (number of samples,)
# Out:
# (226, 10, 7)
# (226, 1)

# %%
from sklearn.model_selection import train_test_split

# Split the data
X_train, X_val, Y_train, Y_val = train_test_split(X, Y, test_size=0.15, shuffle=False)

# Print the shapes of the resulting datasets
print("X_train shape:", X_train.shape)
print("X_val shape:", X_val.shape)
print("Y_train shape:", Y_train.shape)
print("Y_val shape:", Y_val.shape)
# Out:
# X_train shape: (192, 10, 7)
# X_val shape: (34, 10, 7)
# Y_train shape: (192, 1)
# Y_val shape: (34, 1)

# %%
print(X_train[0])
# Out:
# [[-0.22709924 -0.33333333  1.         -0.99971071 -0.626768    0.00876778
#    1.        ]
#  [ 0.21660305 -0.57142857  0.93384529 -0.99996523 -0.58333759  0.00807799
#    1.        ]
#  [ 0.41141858  0.04761905  0.8223371  -0.99921768 -0.62255228  0.00976367
#    1.        ]
#  [-0.45133588  0.14285714  0.7377682  -0.99827708 -0.66825388  0.01145205
#    1.        ]
#  [-0.45133588 -0.42857143  0.72617408 -0.99867482 -0.59272713  0.00915024
#    1.        ]
#  [-0.45133588  0.28571429  0.72446906 -0.99843987 -0.61588885  0.01029669
#    1.        ]
#  [-0.45133588 -0.85714286  0.73060712 -0.99860222 -0.58854266  0.00971901
#    0.        ]
#  [-0.45133588  0.92857143  0.64160517 -0.99669609 -0.66744161  0.01170545
#    1.        ]
#  [-0.45133588  0.07142857  0.60886882 -0.99553842 -0.7530622   0.01473832
#    1.        ]
#  [-0.45133588  0.10714286  0.6063113  -0.99504083 -0.78836512  0.01603344
#    1.        ]]

# %%
# Count occurrences of 0 and 1 in Y_train
unique_train, counts_train = np.unique(Y_train, return_counts=True)
print("Y_train counts:", dict(zip(unique_train, counts_train)))

# Count occurrences of 0 and 1 in Y_val
unique_val, counts_val = np.unique(Y_val, return_counts=True)
print("Y_val counts:", dict(zip(unique_val, counts_val)))
# Out:
# Y_train counts: {0.0: 39, 1.0: 153}
# Y_val counts: {0.0: 7, 1.0: 27}

# %%
# root mean squared error (rmse) for regression (only for Keras tensors)
def rmse(y_true, y_pred):
    from keras import backend
    return backend.sqrt(backend.mean(backend.square(y_pred - y_true), axis=-1))

# mean squared error (mse) for regression  (only for Keras tensors)
def mse(y_true, y_pred):
    from keras import backend
    return backend.mean(backend.square(y_pred - y_true), axis=-1)

# coefficient of determination (R^2) for regression  (only for Keras tensors)
def r_square(y_true, y_pred):
    from keras import backend as K
    SS_res =  K.sum(K.square(y_true - y_pred)) 
    SS_tot = K.sum(K.square(y_true - K.mean(y_true))) 
    return ( 1 - SS_res/(SS_tot + K.epsilon()) )

# %%
# import tensorflow as tf
# from tensorflow.keras.layers import *
# from tensorflow.keras.models import Model
# from tensorflow.keras.layers import Input, LSTM, Dense, Layer, Dropout

# from tensorflow.keras.optimizers.legacy import Adam

# from tensorflow.keras.regularizers import L1L2
# from tensorflow.keras.layers import Layer, Dense, Dot, Activation

# from tensorflow.keras.callbacks import Callback, EarlyStopping

# from tensorflow.keras import backend as K

# from matplotlib import pyplot as plt

# K.clear_session()

   
# l1 = 0.0001
# l2 = 0.0001

# lstm_dropout = 0.2
# recurrent_dropout = 0.1
# dense_dropout = 0.2
# loss = 'mse'

# n_target = Y_train.shape[-2:]

# regularization_criteria = L1L2(l1=l1, l2=l2)

# n_target_y = Y_train.shape[-1]

# def build_model(input_shape):
#     input_layer = Input(shape=input_shape, name='Input_1')
#     sequence = input_layer
#     sequence = LSTM(20, return_sequences = True,  name="LSTM-1", kernel_regularizer = regularization_criteria, dropout=lstm_dropout, recurrent_dropout=recurrent_dropout)(input_layer)
#     sequence = Flatten()(sequence)
#     # sequence = Dropout(dense_dropout)(sequence)
#     # sequence = LSTM(16, return_sequences = False,  name="LSTM-2", kernel_regularizer = regularization_criteria, dropout=lstm_dropout, recurrent_dropout=recurrent_dropout)(sequence)
#     # sequence = Dense(4, activation = 'tanh', name='Dense_3')(sequence)
#     sequence = Dense(n_target_y, activation = 'tanh', name='Dense_4')(sequence)
#     output_layer = sequence

#     model = Model(inputs=input_layer, outputs=output_layer)

#     return model

# input_shape = (look_back, X_train.shape[2])

# learning_rate = 0.0005

# optimizer = Adam(learning_rate=learning_rate)

# model = build_model(input_shape)
# model.compile(optimizer=optimizer, loss=loss, metrics=[mse, rmse, r_square])
# model.summary()

# import time

# start_time = time.time()

# # early_stopping = EarlyStopping(monitor='val_loss', patience=500, restore_best_weights=True)

# history = model.fit(X_train, Y_train, epochs=700, batch_size=64, validation_data=(X_val, Y_val),
#                     # callbacks=[early_stopping]
#                     )

# end_time = time.time()
# difference_in_seconds = end_time - start_time
# print(f"The difference in seconds is: {difference_in_seconds}")

# %%
# import keras_tuner as kt
# import tensorflow as tf
# from tensorflow import keras
# from tensorflow.keras.layers import LSTM, Bidirectional, Dense, Dropout, Flatten

# def build_model(hp):
#     model = keras.Sequential()
    
#     model.add(LSTM(units=hp.Int('lstm_units', min_value=16, max_value=128, step=16),
#                    return_sequences=True,
#                      input_shape=(look_back, X_train.shape[2])))
    
#     # model.add(Dropout(hp.Float('dropout', min_value=0.0, max_value=0.5, step=0.1)))
    
#     # model.add(Bidirectional(LSTM(units=hp.Int('bidirectional_units', min_value=4, max_value=16, step=4),
#     #                              return_sequences=True)))
    
#     # model.add(Bidirectional(LSTM(units=hp.Int('bidirectional_units', min_value=4, max_value=32, step=4),
#     #                              return_sequences=True)))
    
#     model.add(Flatten())
    
#     model.add(Dropout(hp.Float('dropout', min_value=0.0, max_value=0.5, step=0.1)))
    
#     model.add(Dense(hp.Float('dense_units', min_value=0, max_value=32, step=8), activation='tanh'))
    
#     model.add(Dense(1, activation='tanh'))
    
#     model.compile(optimizer=keras.optimizers.Adam(hp.Choice('learning_rate', values=[1e-4, 1e-5])),
#                     loss='mse',
#                     metrics=[rmse, r_square])
    
#     return model

# %%
# import keras_tuner as kt
# import tensorflow as tf
# from tensorflow import keras
# from tensorflow.keras.layers import LSTM, Bidirectional, Dense, Dropout, Flatten, Attention, Input
# from tensorflow.keras.models import Model

# def build_model(hp):
#     inputs = Input(shape=(look_back, X_train.shape[2]))
    
#     lstm_out = LSTM(units=60,
#                     return_sequences=True)(inputs)

    
#     flatten = Flatten()(lstm_out)
    
#     dropout = Dropout(hp.Float('dropout', min_value=0.0, max_value=0.5, step=0.1))(flatten)
    
#     dense = Dense(hp.Int('dense_units', min_value=0, max_value=32, step=4), activation='tanh')(dropout)
    
#     output = Dense(1, activation='tanh')(dense)
    
#     model = Model(inputs=inputs, outputs=output)
    
#     model.compile(optimizer=keras.optimizers.Adam(hp.Choice('learning_rate', values=[1e-4, 1e-5])),
#                   loss='mse',
#                   metrics=[rmse, r_square])
    
#     return model

# %%
# tuner = kt.RandomSearch(build_model,
#                         objective=kt.Objective("val_r_square", direction="max"),
#                         max_trials=20,
#                         executions_per_trial=2,
#                         directory='my_dir',
#                         project_name='earthquake')

# %%
# tuner.search(X_train, Y_train, epochs=150, validation_data=(X_val, Y_val))

# %%
# from tensorflow.keras.callbacks import Callback, EarlyStopping
# best_hps = tuner.get_best_hyperparameters(num_trials=5)[0]

# # print(f"Best LSTM units: {best_hps.get('lstm_units')}")
# # print(f"Best BiLSTM usage: {best_hps.get('bidirectional_units')}")
# print(f"Best Dropout Rate: {best_hps.get('dropout')}")
# print(f"Best Dense Units: {best_hps.get('dense_units')}")
# print(f"Best Learning Rate: {best_hps.get('learning_rate')}")

# # Train the best model
# best_model = tuner.hypermodel.build(best_hps)
# early_stopping = EarlyStopping(monitor='val_loss', patience=700, restore_best_weights=True)
# history = best_model.fit(X_train, Y_train, epochs=1000, validation_data=(X_val, Y_val), callbacks=[early_stopping])

# %%
# # Generate predictions for the training set
# Y_train_pred = best_model.predict(X_train)

# # Plot the true values and predictions
# plt.figure(figsize=(10, 6))
# plt.plot(Y_train, label='True Values', color='blue',  marker='o')
# plt.plot(Y_train_pred, label='Predictions', color='red', linestyle='dashed', marker='o')
# plt.title('Training True Values vs Predictions')
# plt.xlabel('Sample Index')
# plt.ylabel('Value')
# plt.legend()
# plt.show()

# %%
# # Generate predictions for the validation set
# Y_val_pred = best_model.predict(X_val)

# # Plot the true values and predictions
# plt.figure(figsize=(10, 6))
# plt.plot(Y_val, label='True Values', color='blue', marker='o')
# plt.plot(Y_val_pred, label='Predictions', color='red', linestyle='dashed', marker='o')
# plt.title('Validation True Values vs Predictions')
# plt.xlabel('Sample Index')
# plt.ylabel('Value')
# plt.legend()
# plt.show()

# %%
# # Generate predictions for the validation set
# Y_val_pred = best_model.predict(X_val)
# Y_val_pred = np.where(Y_val_pred > 0.5, 1,np.where(Y_val_pred<-0.5, -1, 0) )

# # Plot the true values and predictions
# plt.figure(figsize=(10, 6))
# plt.plot(Y_val, label='True Values', color='blue', marker='o')
# plt.plot(Y_val_pred, label='Predictions', color='red', linestyle='dashed', marker='o')
# plt.title('Validation True Values vs Predictions')
# plt.xlabel('Sample Index')
# plt.ylabel('Value')
# plt.legend()
# plt.show()

# %%
# from sklearn.metrics import confusion_matrix

# # Create confusion matrix
# conf_matrix = confusion_matrix(Y_val.flatten(), Y_val_pred.flatten())

# # Print the confusion matrix
# print("Confusion Matrix:")
# print(conf_matrix)

# %%
# # Calculate total accuracy
# total_accuracy = np.sum(Y_val.flatten() == Y_val_pred.flatten()) / len(Y_val)
# print(f"Total Accuracy: {total_accuracy * 100:.2f}%")

# %%
# Create a mask to filter out values in Y_test that are not equal to 0
mask = Y_val != 0
# print(X_test.shape)
# Apply the mask to filter X_test and Y_test
X_test_filtered = np.array([x for x, m in zip(X_val, mask) if m])
Y_test_filtered = Y_val[mask]

# Print the shapes of the filtered arrays to verify
print(X_test_filtered.shape)
print(Y_test_filtered.shape)
# Out:
# (27, 10, 7)
# (27,)

# %%
# # Generate predictions for the validation set
# Y_val_pred = best_model.predict(X_test_filtered)
# Y_val_pred = np.where(Y_val_pred > 0.15, 1, -1)

# # Plot the true values and predictions
# plt.figure(figsize=(10, 6))
# plt.plot(Y_test_filtered, label='True Values', color='blue', marker='o')
# plt.plot(Y_val_pred, label='Predictions', color='red', linestyle='dashed', marker='o')
# plt.title('Validation True Values vs Predictions')
# plt.xlabel('Sample Index')
# plt.ylabel('Value')
# plt.legend()
# plt.show()

# %%
# from sklearn.metrics import confusion_matrix

# # Create confusion matrix
# conf_matrix = confusion_matrix(Y_test_filtered.flatten(), Y_val_pred.flatten())

# # Print the confusion matrix
# print("Confusion Matrix:")
# print(conf_matrix)

# %%
# # Calculate total accuracy
# total_accuracy = np.sum(Y_test_filtered.flatten() == Y_val_pred.flatten()) / len(Y_test_filtered)
# print(f"Total Accuracy: {total_accuracy * 100:.2f}%")

# %%
import tensorflow as tf
from tensorflow.keras.layers import *
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, LSTM, Dense, Layer, Dropout

from tensorflow.keras.optimizers.legacy import Adam

from tensorflow.keras.regularizers import L1L2
from tensorflow.keras.layers import Layer, Dense, Dot, Activation

from tensorflow.keras.callbacks import Callback, EarlyStopping

from tensorflow.keras import backend as K

from matplotlib import pyplot as plt

K.clear_session()

   
l1 = 0.0
l2 = 0.0

lstm_dropout = 0.0
recurrent_dropout = 0.0
dense_dropout = 0.1
loss = 'mse'

n_target = Y_train.shape[-2:]

regularization_criteria = L1L2(l1=l1, l2=l2)

n_target_y = Y_train.shape[-1]

def build_model(input_shape):
    input_layer = Input(shape=input_shape, name='Input_1')
    sequence = input_layer
    sequence = LSTM(50, return_sequences = True,  name="LSTM-1", kernel_regularizer = regularization_criteria, dropout=lstm_dropout, recurrent_dropout=recurrent_dropout)(input_layer)
    
    sequence = Flatten()(sequence)
    sequence = Dense(20, activation = 'tanh', name='Dense_2')(sequence)
    sequence = Dropout(0.3)(sequence)
    # sequence = LSTM(16, return_sequences = False,  name="LSTM-2", kernel_regularizer = regularization_criteria, dropout=lstm_dropout, recurrent_dropout=recurrent_dropout)(sequence)
    sequence = Dense(10, activation = 'tanh', name='Dense_3')(sequence)
    sequence = Dense(n_target_y, activation = 'sigmoid', name='Dense_4')(sequence)
    output_layer = sequence

    model = Model(inputs=input_layer, outputs=output_layer)

    return model

input_shape = (look_back, X_train.shape[2])

learning_rate = 0.001

optimizer = Adam(learning_rate=learning_rate)

model = build_model(input_shape)
model.compile(optimizer=optimizer, loss=loss, metrics=[mse])
model.summary()

import time

start_time = time.time()

early_stopping = EarlyStopping(monitor='val_loss', patience=700, restore_best_weights=True)

history = model.fit(X_train, Y_train, epochs=1000, batch_size=64, validation_data=(X_val, Y_val),
                    callbacks=[early_stopping]
                    )

end_time = time.time()
difference_in_seconds = end_time - start_time
print(f"The difference in seconds is: {difference_in_seconds}")
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  Input_1 (InputLayer)        [(None, 10, 7)]           0
#
#  LSTM-1 (LSTM)               (None, 10, 50)            11600
#
#  flatten (Flatten)           (None, 500)               0
#
#  Dense_2 (Dense)             (None, 20)                10020
#
#  dropout (Dropout)           (None, 20)                0
#
#  Dense_3 (Dense)             (None, 10)                210
#
#  Dense_4 (Dense)             (None, 1)                 11
#
# =================================================================
# Total params: 21,841
# Trainable params: 21,841
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/1000
# 3/3 [==============================] - 3s 336ms/step - loss: 0.2406 - mse: 0.2406 - val_loss: 0.1925 - val_mse: 0.1925
# Epoch 2/1000
# 3/3 [==============================] - 0s 42ms/step - loss: 0.1823 - mse: 0.1823 - val_loss: 0.1685 - val_mse: 0.1685
# Epoch 3/1000
# 3/3 [==============================] - 0s 39ms/step - loss: 0.1701 - mse: 0.1701 - val_loss: 0.1655 - val_mse: 0.1655
# Epoch 4/1000
# 3/3 [==============================] - 0s 36ms/step - loss: 0.1653 - mse: 0.1653 - val_loss: 0.1669 - val_mse: 0.1669
# Epoch 5/1000
# 3/3 [==============================] - 0s 35ms/step - loss: 0.1633 - mse: 0.1633 - val_loss: 0.1681 - val_mse: 0.1681
# Epoch 6/1000
# 3/3 [==============================] - 0s 40ms/step - loss: 0.1620 - mse: 0.1620 - val_loss: 0.1682 - val_mse: 0.1682
# Epoch 7/1000
# 3/3 [==============================] - 0s 34ms/step - loss: 0.1651 - mse: 0.1651 - val_loss: 0.1677 - val_mse: 0.1677
# Epoch 8/1000
# 3/3 [==============================] - 0s 31ms/step - loss: 0.1664 - mse: 0.1664 - val_loss: 0.1667 - val_mse: 0.1667
# Epoch 9/1000
# 3/3 [==============================] - 0s 31ms/step - loss: 0.1654 - mse: 0.1654 - val_loss: 0.1658 - val_mse: 0.1658
# Epoch 10/1000
# 3/3 [==============================] - 0s 30ms/step - loss: 0.1632 - mse: 0.1632 - val_loss: 0.1652 - val_mse: 0.1652
# Epoch 11/1000
# 3/3 [==============================] - 0s 38ms/step - loss: 0.1616 - mse: 0.1616 - val_loss: 0.1649 - val_mse: 0.1649
# Epoch 12/1000
# 3/3 [==============================] - 0s 34ms/step - loss: 0.1627 - mse: 0.1627 - val_loss: 0.1646 - val_mse: 0.1646
# Epoch 13/1000
# 3/3 [==============================] - 0s 40ms/step - loss: 0.1611 - mse: 0.1611 - val_loss: 0.1645 - val_mse: 0.1645
# Epoch 14/1000
# 3/3 [==============================] - 0s 37ms/step - loss: 0.1625 - mse: 0.1625 - val_loss: 0.1644 - val_mse: 0.1644
# Epoch 15/1000
# 3/3 [==============================] - 0s 40ms/step - loss: 0.1622 - mse: 0.1622 - val_loss: 0.1644 - val_mse: 0.1644
# Epoch 16/1000
# 3/3 [==============================] - 0s 33ms/step - loss: 0.1606 - mse: 0.1606 - val_loss: 0.1644 - val_mse: 0.1644
# Epoch 17/1000
# 3/3 [==============================] - 0s 33ms/step - loss: 0.1626 - mse: 0.1626 - val_loss: 0.1644 - val_mse: 0.1644
# Epoch 18/1000
# 3/3 [==============================] - 0s 36ms/step - loss: 0.1619 - mse: 0.1619 - val_loss: 0.1644 - val_mse: 0.1644
# Epoch 19/1000
# 3/3 [==============================] - 0s 34ms/step - loss: 0.1611 - mse: 0.1611 - val_loss: 0.1645 - val_mse: 0.1645
# Epoch 20/1000
# 3/3 [==============================] - 0s 33ms/step - loss: 0.1624 - mse: 0.1624 - val_loss: 0.1646 - val_mse: 0.1646
# Epoch 21/1000
# 3/3 [==============================] - 0s 33ms/step - loss: 0.1620 - mse: 0.1620 - val_loss: 0.1646 - val_mse: 0.1646
# Epoch 22/1000
# 3/3 [==============================] - 0s 35ms/step - loss: 0.1626 - mse: 0.1626 - val_loss: 0.1648 - val_mse: 0.1648
# Epoch 23/1000
# 3/3 [==============================] - 0s 33ms/step - loss: 0.1629 - mse: 0.1629 - val_loss: 0.1648 - val_mse: 0.1648
# Epoch 24/1000
# 3/3 [==============================] - 0s 33ms/step - loss: 0.1605 - mse: 0.1605 - val_loss: 0.1648 - val_mse: 0.1648
# Epoch 25/1000
# 3/3 [==============================] - 0s 34ms/step - loss: 0.1602 - mse: 0.1602 - val_loss: 0.1649 - val_mse: 0.1649
# Epoch 26/1000
# 3/3 [==============================] - 0s 39ms/step - loss: 0.1593 - mse: 0.1593 - val_loss: 0.1648 - val_mse: 0.1648
# Epoch 27/1000
# 3/3 [==============================] - 0s 38ms/step - loss: 0.1591 - mse: 0.1591 - val_loss: 0.1648 - val_mse: 0.1648
# Epoch 28/1000
# 3/3 [==============================] - 0s 37ms/step - loss: 0.1619 - mse: 0.1619 - val_loss: 0.1648 - val_mse: 0.1648
# Epoch 29/1000
# 3/3 [==============================] - 0s 80ms/step - loss: 0.1615 - mse: 0.1615 - val_loss: 0.1648 - val_mse: 0.1648
# Epoch 30/1000
# 3/3 [==============================] - 0s 30ms/step - loss: 0.1599 - mse: 0.1599 - val_loss: 0.1649 - val_mse: 0.1649
# Epoch 31/1000
# 3/3 [==============================] - 0s 26ms/step - loss: 0.1602 - mse: 0.1602 - val_loss: 0.1649 - val_mse: 0.1649
# Epoch 32/1000
# 3/3 [==============================] - 0s 31ms/step - loss: 0.1573 - mse: 0.1573 - val_loss: 0.1650 - val_mse: 0.1650
# Epoch 33/1000
# 3/3 [==============================] - 0s 27ms/step - loss: 0.1585 - mse: 0.1585 - val_loss: 0.1652 - val_mse: 0.1652
# Epoch 34/1000
# 3/3 [==============================] - 0s 26ms/step - loss: 0.1594 - mse: 0.1594 - val_loss: 0.1653 - val_mse: 0.1653
# Epoch 35/1000
# 3/3 [==============================] - 0s 29ms/step - loss: 0.1587 - mse: 0.1587 - val_loss: 0.1656 - val_mse: 0.1656
# Epoch 36/1000
# 3/3 [==============================] - 0s 25ms/step - loss: 0.1582 - mse: 0.1582 - val_loss: 0.1660 - val_mse: 0.1660
# Epoch 37/1000
# 3/3 [==============================] - 0s 36ms/step - loss: 0.1565 - mse: 0.1565 - val_loss: 0.1664 - val_mse: 0.1664
# Epoch 38/1000
# 3/3 [==============================] - 0s 27ms/step - loss: 0.1567 - mse: 0.1567 - val_loss: 0.1667 - val_mse: 0.1667
# Epoch 39/1000
# 3/3 [==============================] - 0s 30ms/step - loss: 0.1545 - mse: 0.1545 - val_loss: 0.1671 - val_mse: 0.1671
# Epoch 40/1000
# 3/3 [==============================] - 0s 28ms/step - loss: 0.1605 - mse: 0.1605 - val_loss: 0.1678 - val_mse: 0.1678
# Epoch 41/1000
# 3/3 [==============================] - 0s 32ms/step - loss: 0.1535 - mse: 0.1535 - val_loss: 0.1686 - val_mse: 0.1686
# Epoch 42/1000
# 3/3 [==============================] - 0s 27ms/step - loss: 0.1521 - mse: 0.1521 - val_loss: 0.1701 - val_mse: 0.1701
# Epoch 43/1000
# 3/3 [==============================] - 0s 30ms/step - loss: 0.1536 - mse: 0.1536 - val_loss: 0.1715 - val_mse: 0.1715
# Epoch 44/1000
# 3/3 [==============================] - 0s 29ms/step - loss: 0.1541 - mse: 0.1541 - val_loss: 0.1730 - val_mse: 0.1730
# Epoch 45/1000
# 3/3 [==============================] - 0s 30ms/step - loss: 0.1519 - mse: 0.1519 - val_loss: 0.1733 - val_mse: 0.1733
# Epoch 46/1000
# 3/3 [==============================] - 0s 29ms/step - loss: 0.1506 - mse: 0.1506 - val_loss: 0.1751 - val_mse: 0.1751
# Epoch 47/1000
# 3/3 [==============================] - 0s 29ms/step - loss: 0.1551 - mse: 0.1551 - val_loss: 0.1762 - val_mse: 0.1762
# Epoch 48/1000
# 3/3 [==============================] - 0s 27ms/step - loss: 0.1521 - mse: 0.1521 - val_loss: 0.1773 - val_mse: 0.1773
# Epoch 49/1000
# 3/3 [==============================] - 0s 26ms/step - loss: 0.1501 - mse: 0.1501 - val_loss: 0.1793 - val_mse: 0.1793
# Epoch 50/1000
# 3/3 [==============================] - 0s 29ms/step - loss: 0.1492 - mse: 0.1492 - val_loss: 0.1803 - val_mse: 0.1803
# Epoch 51/1000
# 3/3 [==============================] - 0s 31ms/step - loss: 0.1499 - mse: 0.1499 - val_loss: 0.1800 - val_mse: 0.1800
# Epoch 52/1000
# 3/3 [==============================] - 0s 27ms/step - loss: 0.1506 - mse: 0.1506 - val_loss: 0.1803 - val_mse: 0.1803
# Epoch 53/1000
# 3/3 [==============================] - 0s 27ms/step - loss: 0.1506 - mse: 0.1506 - val_loss: 0.1806 - val_mse: 0.1806
# Epoch 54/1000
# 3/3 [==============================] - 0s 28ms/step - loss: 0.1472 - mse: 0.1472 - val_loss: 0.1841 - val_mse: 0.1841
# Epoch 55/1000
# 3/3 [==============================] - 0s 25ms/step - loss: 0.1482 - mse: 0.1482 - val_loss: 0.1871 - val_mse: 0.1871
# Epoch 56/1000
# 3/3 [==============================] - 0s 25ms/step - loss: 0.1536 - mse: 0.1536 - val_loss: 0.1879 - val_mse: 0.1879
# Epoch 57/1000
# 3/3 [==============================] - 0s 25ms/step - loss: 0.1490 - mse: 0.1490 - val_loss: 0.1829 - val_mse: 0.1829
# Epoch 58/1000
# 3/3 [==============================] - 0s 26ms/step - loss: 0.1488 - mse: 0.1488 - val_loss: 0.1817 - val_mse: 0.1817
# Epoch 59/1000
# 3/3 [==============================] - 0s 26ms/step - loss: 0.1479 - mse: 0.1479 - val_loss: 0.1832 - val_mse: 0.1832
# Epoch 60/1000
# 3/3 [==============================] - 0s 25ms/step - loss: 0.1481 - mse: 0.1481 - val_loss: 0.1855 - val_mse: 0.1855
# Epoch 61/1000
# 3/3 [==============================] - 0s 26ms/step - loss: 0.1497 - mse: 0.1497 - val_loss: 0.1813 - val_mse: 0.1813
# Epoch 62/1000
# 3/3 [==============================] - 0s 27ms/step - loss: 0.1465 - mse: 0.1465 - val_loss: 0.1792 - val_mse: 0.1792
# Epoch 63/1000
# 3/3 [==============================] - 0s 26ms/step - loss: 0.1489 - mse: 0.1489 - val_loss: 0.1782 - val_mse: 0.1782
# Epoch 64/1000
# 3/3 [==============================] - 0s 26ms/step - loss: 0.1501 - mse: 0.1501 - val_loss: 0.1795 - val_mse: 0.1795
# Epoch 65/1000
# 3/3 [==============================] - 0s 26ms/step - loss: 0.1430 - mse: 0.1430 - val_loss: 0.1809 - val_mse: 0.1809
# Epoch 66/1000
# 3/3 [==============================] - 0s 26ms/step - loss: 0.1437 - mse: 0.1437 - val_loss: 0.1817 - val_mse: 0.1817
# Epoch 67/1000
# 3/3 [==============================] - 0s 25ms/step - loss: 0.1493 - mse: 0.1493 - val_loss: 0.1813 - val_mse: 0.1813
# Epoch 68/1000
# 3/3 [==============================] - 0s 25ms/step - loss: 0.1468 - mse: 0.1468 - val_loss: 0.1819 - val_mse: 0.1819
# Epoch 69/1000
# 3/3 [==============================] - 0s 26ms/step - loss: 0.1455 - mse: 0.1455 - val_loss: 0.1830 - val_mse: 0.1830
# Epoch 70/1000
# 3/3 [==============================] - 0s 27ms/step - loss: 0.1476 - mse: 0.1476 - val_loss: 0.1842 - val_mse: 0.1842
# Epoch 71/1000
# 3/3 [==============================] - 0s 28ms/step - loss: 0.1415 - mse: 0.1415 - val_loss: 0.1852 - val_mse: 0.1852
# Epoch 72/1000
# 3/3 [==============================] - 0s 38ms/step - loss: 0.1464 - mse: 0.1464 - val_loss: 0.1842 - val_mse: 0.1842
# Epoch 73/1000
# 3/3 [==============================] - 0s 29ms/step - loss: 0.1452 - mse: 0.1452 - val_loss: 0.1822 - val_mse: 0.1822
# Epoch 74/1000
# 3/3 [==============================] - 0s 25ms/step - loss: 0.1437 - mse: 0.1437 - val_loss: 0.1823 - val_mse: 0.1823
# Epoch 75/1000
# 3/3 [==============================] - 0s 32ms/step - loss: 0.1419 - mse: 0.1419 - val_loss: 0.1831 - val_mse: 0.1831
# Epoch 76/1000
# 3/3 [==============================] - 0s 33ms/step - loss: 0.1413 - mse: 0.1413 - val_loss: 0.1831 - val_mse: 0.1831
# Epoch 77/1000
# 3/3 [==============================] - 0s 30ms/step - loss: 0.1428 - mse: 0.1428 - val_loss: 0.1833 - val_mse: 0.1833
# Epoch 78/1000
# 3/3 [==============================] - 0s 33ms/step - loss: 0.1450 - mse: 0.1450 - val_loss: 0.1832 - val_mse: 0.1832
# Epoch 79/1000
# 3/3 [==============================] - 0s 139ms/step - loss: 0.1396 - mse: 0.1396 - val_loss: 0.1832 - val_mse: 0.1832
# Epoch 80/1000
# 3/3 [==============================] - 0s 43ms/step - loss: 0.1410 - mse: 0.1410 - val_loss: 0.1865 - val_mse: 0.1865
# Epoch 81/1000
# 3/3 [==============================] - 0s 38ms/step - loss: 0.1366 - mse: 0.1366 - val_loss: 0.1949 - val_mse: 0.1949
# Epoch 82/1000
# 3/3 [==============================] - 0s 35ms/step - loss: 0.1385 - mse: 0.1385 - val_loss: 0.1895 - val_mse: 0.1895
# Epoch 83/1000
# 3/3 [==============================] - 0s 38ms/step - loss: 0.1356 - mse: 0.1356 - val_loss: 0.1902 - val_mse: 0.1902
# Epoch 84/1000
# 3/3 [==============================] - 0s 35ms/step - loss: 0.1369 - mse: 0.1369 - val_loss: 0.1960 - val_mse: 0.1960
# Epoch 85/1000
# 3/3 [==============================] - 0s 37ms/step - loss: 0.1352 - mse: 0.1352 - val_loss: 0.1954 - val_mse: 0.1954
# Epoch 86/1000
# 3/3 [==============================] - 0s 36ms/step - loss: 0.1359 - mse: 0.1359 - val_loss: 0.1864 - val_mse: 0.1864
# Epoch 87/1000
# 3/3 [==============================] - 0s 37ms/step - loss: 0.1340 - mse: 0.1340 - val_loss: 0.1880 - val_mse: 0.1880
# Epoch 88/1000
# 3/3 [==============================] - 0s 32ms/step - loss: 0.1348 - mse: 0.1348 - val_loss: 0.1896 - val_mse: 0.1896
# Epoch 89/1000
# 3/3 [==============================] - 0s 33ms/step - loss: 0.1346 - mse: 0.1346 - val_loss: 0.1914 - val_mse: 0.1914
# Epoch 90/1000
# 3/3 [==============================] - 0s 39ms/step - loss: 0.1335 - mse: 0.1335 - val_loss: 0.1864 - val_mse: 0.1864
# Epoch 91/1000
# 3/3 [==============================] - 0s 38ms/step - loss: 0.1355 - mse: 0.1355 - val_loss: 0.1848 - val_mse: 0.1848
# Epoch 92/1000
# 3/3 [==============================] - 0s 32ms/step - loss: 0.1298 - mse: 0.1298 - val_loss: 0.1896 - val_mse: 0.1896
# Epoch 93/1000
# 3/3 [==============================] - 0s 27ms/step - loss: 0.1283 - mse: 0.1283 - val_loss: 0.1884 - val_mse: 0.1884
# Epoch 94/1000
# 3/3 [==============================] - 0s 28ms/step - loss: 0.1313 - mse: 0.1313 - val_loss: 0.1865 - val_mse: 0.1865
# Epoch 95/1000
# 3/3 [==============================] - 0s 27ms/step - loss: 0.1349 - mse: 0.1349 - val_loss: 0.1829 - val_mse: 0.1829
# Epoch 96/1000
# 3/3 [==============================] - 0s 25ms/step - loss: 0.1275 - mse: 0.1275 - val_loss: 0.1940 - val_mse: 0.1940
# Epoch 97/1000
# 3/3 [==============================] - 0s 30ms/step - loss: 0.1250 - mse: 0.1250 - val_loss: 0.2000 - val_mse: 0.2000
# Epoch 98/1000
# 3/3 [==============================] - 0s 30ms/step - loss: 0.1275 - mse: 0.1275 - val_loss: 0.2002 - val_mse: 0.2002
# Epoch 99/1000
# 3/3 [==============================] - 0s 29ms/step - loss: 0.1238 - mse: 0.1238 - val_loss: 0.1912 - val_mse: 0.1912
# Epoch 100/1000
# 3/3 [==============================] - 0s 30ms/step - loss: 0.1248 - mse: 0.1248 - val_loss: 0.1905 - val_mse: 0.1905
# Epoch 101/1000
# 3/3 [==============================] - 0s 43ms/step - loss: 0.1283 - mse: 0.1283 - val_loss: 0.2020 - val_mse: 0.2020
# Epoch 102/1000
# 3/3 [==============================] - 0s 26ms/step - loss: 0.1244 - mse: 0.1244 - val_loss: 0.1958 - val_mse: 0.1958
# Epoch 103/1000
# 3/3 [==============================] - 0s 27ms/step - loss: 0.1278 - mse: 0.1278 - val_loss: 0.1950 - val_mse: 0.1950
# Epoch 104/1000
# 3/3 [==============================] - 0s 30ms/step - loss: 0.1266 - mse: 0.1266 - val_loss: 0.2074 - val_mse: 0.2074
# Epoch 105/1000
# 3/3 [==============================] - 0s 28ms/step - loss: 0.1244 - mse: 0.1244 - val_loss: 0.2172 - val_mse: 0.2172
# Epoch 106/1000
# 3/3 [==============================] - 0s 27ms/step - loss: 0.1206 - mse: 0.1206 - val_loss: 0.2152 - val_mse: 0.2152
# Epoch 107/1000
# 3/3 [==============================] - 0s 27ms/step - loss: 0.1216 - mse: 0.1216 - val_loss: 0.1966 - val_mse: 0.1966
# Epoch 108/1000
# 3/3 [==============================] - 0s 30ms/step - loss: 0.1148 - mse: 0.1148 - val_loss: 0.2013 - val_mse: 0.2013
# Epoch 109/1000
# 3/3 [==============================] - 0s 30ms/step - loss: 0.1152 - mse: 0.1152 - val_loss: 0.2092 - val_mse: 0.2092
# Epoch 110/1000
# 3/3 [==============================] - 0s 29ms/step - loss: 0.1149 - mse: 0.1149 - val_loss: 0.2160 - val_mse: 0.2160
# Epoch 111/1000
# 3/3 [==============================] - 0s 31ms/step - loss: 0.1167 - mse: 0.1167 - val_loss: 0.2100 - val_mse: 0.2100
# Epoch 112/1000
# 3/3 [==============================] - 0s 30ms/step - loss: 0.1120 - mse: 0.1120 - val_loss: 0.2344 - val_mse: 0.2344
# Epoch 113/1000
# 3/3 [==============================] - 0s 29ms/step - loss: 0.1097 - mse: 0.1097 - val_loss: 0.2403 - val_mse: 0.2403
# Epoch 114/1000
# 3/3 [==============================] - 0s 27ms/step - loss: 0.1101 - mse: 0.1101 - val_loss: 0.2592 - val_mse: 0.2592
# Epoch 115/1000
# 3/3 [==============================] - 0s 30ms/step - loss: 0.1099 - mse: 0.1099 - val_loss: 0.2356 - val_mse: 0.2356
# Epoch 116/1000
# 3/3 [==============================] - 0s 30ms/step - loss: 0.1040 - mse: 0.1040 - val_loss: 0.2394 - val_mse: 0.2394
# Epoch 117/1000
# 3/3 [==============================] - 0s 31ms/step - loss: 0.1115 - mse: 0.1115 - val_loss: 0.2255 - val_mse: 0.2255
# Epoch 118/1000
# 3/3 [==============================] - 0s 29ms/step - loss: 0.1158 - mse: 0.1158 - val_loss: 0.2045 - val_mse: 0.2045
# Epoch 119/1000
# 3/3 [==============================] - 0s 29ms/step - loss: 0.1031 - mse: 0.1031 - val_loss: 0.2783 - val_mse: 0.2783
# Epoch 120/1000
# 3/3 [==============================] - 0s 31ms/step - loss: 0.1036 - mse: 0.1036 - val_loss: 0.2320 - val_mse: 0.2320
# Epoch 121/1000
# 3/3 [==============================] - 0s 31ms/step - loss: 0.0980 - mse: 0.0980 - val_loss: 0.2454 - val_mse: 0.2454
# Epoch 122/1000
# 3/3 [==============================] - 0s 28ms/step - loss: 0.1012 - mse: 0.1012 - val_loss: 0.2601 - val_mse: 0.2601
# Epoch 123/1000
# 3/3 [==============================] - 0s 26ms/step - loss: 0.0982 - mse: 0.0982 - val_loss: 0.2213 - val_mse: 0.2213
# Epoch 124/1000
# 3/3 [==============================] - 0s 26ms/step - loss: 0.0979 - mse: 0.0979 - val_loss: 0.2538 - val_mse: 0.2538
# Epoch 125/1000
# 3/3 [==============================] - 0s 33ms/step - loss: 0.0940 - mse: 0.0940 - val_loss: 0.2803 - val_mse: 0.2803
# Epoch 126/1000
# 3/3 [==============================] - 0s 32ms/step - loss: 0.0918 - mse: 0.0918 - val_loss: 0.2281 - val_mse: 0.2281
# Epoch 127/1000
# 3/3 [==============================] - 0s 27ms/step - loss: 0.0927 - mse: 0.0927 - val_loss: 0.2808 - val_mse: 0.2808
# Epoch 128/1000
# 3/3 [==============================] - 0s 42ms/step - loss: 0.0933 - mse: 0.0933 - val_loss: 0.2977 - val_mse: 0.2977
# Epoch 129/1000
# 3/3 [==============================] - 0s 28ms/step - loss: 0.0960 - mse: 0.0960 - val_loss: 0.2394 - val_mse: 0.2394
# Epoch 130/1000
# 3/3 [==============================] - 0s 30ms/step - loss: 0.0992 - mse: 0.0992 - val_loss: 0.2913 - val_mse: 0.2913
# Epoch 131/1000
# 3/3 [==============================] - 0s 29ms/step - loss: 0.0864 - mse: 0.0864 - val_loss: 0.2107 - val_mse: 0.2107
# Epoch 132/1000
# 3/3 [==============================] - 0s 29ms/step - loss: 0.0908 - mse: 0.0908 - val_loss: 0.3154 - val_mse: 0.3154
# Epoch 133/1000
# 3/3 [==============================] - 0s 28ms/step - loss: 0.0883 - mse: 0.0883 - val_loss: 0.2904 - val_mse: 0.2904
# Epoch 134/1000
# 3/3 [==============================] - 0s 31ms/step - loss: 0.0863 - mse: 0.0863 - val_loss: 0.2247 - val_mse: 0.2247
# Epoch 135/1000
# 3/3 [==============================] - 0s 32ms/step - loss: 0.0839 - mse: 0.0839 - val_loss: 0.2779 - val_mse: 0.2779
# Epoch 136/1000
# 3/3 [==============================] - 0s 34ms/step - loss: 0.0830 - mse: 0.0830 - val_loss: 0.2651 - val_mse: 0.2651
# Epoch 137/1000
# 3/3 [==============================] - 0s 28ms/step - loss: 0.0790 - mse: 0.0790 - val_loss: 0.2454 - val_mse: 0.2454
# Epoch 138/1000
# 3/3 [==============================] - 0s 26ms/step - loss: 0.0837 - mse: 0.0837 - val_loss: 0.2893 - val_mse: 0.2893
# Epoch 139/1000
# 3/3 [==============================] - 0s 30ms/step - loss: 0.0721 - mse: 0.0721 - val_loss: 0.2337 - val_mse: 0.2337
# Epoch 140/1000
# 3/3 [==============================] - 0s 29ms/step - loss: 0.0759 - mse: 0.0759 - val_loss: 0.2922 - val_mse: 0.2922
# Epoch 141/1000
# 3/3 [==============================] - 0s 28ms/step - loss: 0.0766 - mse: 0.0766 - val_loss: 0.3072 - val_mse: 0.3072
# Epoch 142/1000
# 3/3 [==============================] - 0s 31ms/step - loss: 0.0706 - mse: 0.0706 - val_loss: 0.2881 - val_mse: 0.2881
# Epoch 143/1000
# 3/3 [==============================] - 0s 35ms/step - loss: 0.0724 - mse: 0.0724 - val_loss: 0.3393 - val_mse: 0.3393
# Epoch 144/1000
# 3/3 [==============================] - 0s 32ms/step - loss: 0.0693 - mse: 0.0693 - val_loss: 0.2864 - val_mse: 0.2864
# Epoch 145/1000
# 3/3 [==============================] - 0s 30ms/step - loss: 0.0648 - mse: 0.0648 - val_loss: 0.3153 - val_mse: 0.3153
# Epoch 146/1000
# 3/3 [==============================] - 0s 28ms/step - loss: 0.0655 - mse: 0.0655 - val_loss: 0.3271 - val_mse: 0.3271
# Epoch 147/1000
# 3/3 [==============================] - 0s 29ms/step - loss: 0.0685 - mse: 0.0685 - val_loss: 0.3220 - val_mse: 0.3220
# Epoch 148/1000
# 3/3 [==============================] - 0s 28ms/step - loss: 0.0580 - mse: 0.0580 - val_loss: 0.3109 - val_mse: 0.3109
# Epoch 149/1000
# 3/3 [==============================] - 0s 31ms/step - loss: 0.0649 - mse: 0.0649 - val_loss: 0.2947 - val_mse: 0.2947
# Epoch 150/1000
# 3/3 [==============================] - 0s 27ms/step - loss: 0.0661 - mse: 0.0661 - val_loss: 0.3300 - val_mse: 0.3300
# Epoch 151/1000
# 3/3 [==============================] - 0s 27ms/step - loss: 0.0564 - mse: 0.0564 - val_loss: 0.2884 - val_mse: 0.2884
# Epoch 152/1000
# 3/3 [==============================] - 0s 29ms/step - loss: 0.0649 - mse: 0.0649 - val_loss: 0.3135 - val_mse: 0.3135
# Epoch 153/1000
# 3/3 [==============================] - 0s 32ms/step - loss: 0.0608 - mse: 0.0608 - val_loss: 0.3126 - val_mse: 0.3126
# Epoch 154/1000
# 3/3 [==============================] - 0s 31ms/step - loss: 0.0626 - mse: 0.0626 - val_loss: 0.2997 - val_mse: 0.2997
# Epoch 155/1000
# 3/3 [==============================] - 0s 28ms/step - loss: 0.0646 - mse: 0.0646 - val_loss: 0.3549 - val_mse: 0.3549
# Epoch 156/1000
# 3/3 [==============================] - 0s 30ms/step - loss: 0.0533 - mse: 0.0533 - val_loss: 0.3381 - val_mse: 0.3381
# Epoch 157/1000
# 3/3 [==============================] - 0s 27ms/step - loss: 0.0556 - mse: 0.0556 - val_loss: 0.3412 - val_mse: 0.3412
# Epoch 158/1000
# 3/3 [==============================] - 0s 29ms/step - loss: 0.0624 - mse: 0.0624 - val_loss: 0.3429 - val_mse: 0.3429
# Epoch 159/1000
# 3/3 [==============================] - 0s 29ms/step - loss: 0.0507 - mse: 0.0507 - val_loss: 0.3084 - val_mse: 0.3084
# Epoch 160/1000
# 3/3 [==============================] - 0s 29ms/step - loss: 0.0492 - mse: 0.0492 - val_loss: 0.3917 - val_mse: 0.3917
# Epoch 161/1000
# 3/3 [==============================] - 0s 28ms/step - loss: 0.0554 - mse: 0.0554 - val_loss: 0.3478 - val_mse: 0.3478
# Epoch 162/1000
# 3/3 [==============================] - 0s 31ms/step - loss: 0.0541 - mse: 0.0541 - val_loss: 0.3895 - val_mse: 0.3895
# Epoch 163/1000
# 3/3 [==============================] - 0s 32ms/step - loss: 0.0470 - mse: 0.0470 - val_loss: 0.3401 - val_mse: 0.3401
# Epoch 164/1000
# 3/3 [==============================] - 0s 46ms/step - loss: 0.0449 - mse: 0.0449 - val_loss: 0.3635 - val_mse: 0.3635
# Epoch 165/1000
# 3/3 [==============================] - 0s 31ms/step - loss: 0.0482 - mse: 0.0482 - val_loss: 0.3842 - val_mse: 0.3842
# Epoch 166/1000
# 3/3 [==============================] - 0s 28ms/step - loss: 0.0462 - mse: 0.0462 - val_loss: 0.3767 - val_mse: 0.3767
# Epoch 167/1000
# 3/3 [==============================] - 0s 29ms/step - loss: 0.0459 - mse: 0.0459 - val_loss: 0.3870 - val_mse: 0.3870
# Epoch 168/1000
# 3/3 [==============================] - 0s 27ms/step - loss: 0.0405 - mse: 0.0405 - val_loss: 0.3714 - val_mse: 0.3714
# Epoch 169/1000
# 3/3 [==============================] - 0s 28ms/step - loss: 0.0396 - mse: 0.0396 - val_loss: 0.3743 - val_mse: 0.3743
# Epoch 170/1000
# 3/3 [==============================] - 0s 28ms/step - loss: 0.0456 - mse: 0.0456 - val_loss: 0.3509 - val_mse: 0.3509
# Epoch 171/1000
# 3/3 [==============================] - 0s 31ms/step - loss: 0.0435 - mse: 0.0435 - val_loss: 0.4136 - val_mse: 0.4136
# Epoch 172/1000
# 3/3 [==============================] - 0s 31ms/step - loss: 0.0398 - mse: 0.0398 - val_loss: 0.3699 - val_mse: 0.3699
# Epoch 173/1000
# 3/3 [==============================] - 0s 30ms/step - loss: 0.0399 - mse: 0.0399 - val_loss: 0.3551 - val_mse: 0.3551
# Epoch 174/1000
# 3/3 [==============================] - 0s 35ms/step - loss: 0.0380 - mse: 0.0380 - val_loss: 0.3898 - val_mse: 0.3898
# Epoch 175/1000
# 3/3 [==============================] - 0s 49ms/step - loss: 0.0353 - mse: 0.0353 - val_loss: 0.3823 - val_mse: 0.3823
# Epoch 176/1000
# 3/3 [==============================] - 0s 36ms/step - loss: 0.0339 - mse: 0.0339 - val_loss: 0.3892 - val_mse: 0.3892
# Epoch 177/1000
# 3/3 [==============================] - 0s 36ms/step - loss: 0.0403 - mse: 0.0403 - val_loss: 0.4248 - val_mse: 0.4248
# Epoch 178/1000
# 3/3 [==============================] - 0s 34ms/step - loss: 0.0341 - mse: 0.0341 - val_loss: 0.3709 - val_mse: 0.3709
# Epoch 179/1000
# 3/3 [==============================] - 0s 32ms/step - loss: 0.0339 - mse: 0.0339 - val_loss: 0.3834 - val_mse: 0.3834
# Epoch 180/1000
# 3/3 [==============================] - 0s 34ms/step - loss: 0.0360 - mse: 0.0360 - val_loss: 0.3652 - val_mse: 0.3652
# Epoch 181/1000
# 3/3 [==============================] - 0s 32ms/step - loss: 0.0377 - mse: 0.0377 - val_loss: 0.4449 - val_mse: 0.4449
# Epoch 182/1000
# 3/3 [==============================] - 0s 33ms/step - loss: 0.0339 - mse: 0.0339 - val_loss: 0.4337 - val_mse: 0.4337
# Epoch 183/1000
# 3/3 [==============================] - 0s 32ms/step - loss: 0.0384 - mse: 0.0384 - val_loss: 0.3773 - val_mse: 0.3773
# Epoch 184/1000
# 3/3 [==============================] - 0s 33ms/step - loss: 0.0300 - mse: 0.0300 - val_loss: 0.3790 - val_mse: 0.3790
# Epoch 185/1000
# 3/3 [==============================] - 0s 35ms/step - loss: 0.0338 - mse: 0.0338 - val_loss: 0.3795 - val_mse: 0.3795
# Epoch 186/1000
# 3/3 [==============================] - 0s 34ms/step - loss: 0.0289 - mse: 0.0289 - val_loss: 0.4090 - val_mse: 0.4090
# Epoch 187/1000
# 3/3 [==============================] - 0s 32ms/step - loss: 0.0316 - mse: 0.0316 - val_loss: 0.3951 - val_mse: 0.3951
# Epoch 188/1000
# 3/3 [==============================] - 0s 32ms/step - loss: 0.0303 - mse: 0.0303 - val_loss: 0.3688 - val_mse: 0.3688
# Epoch 189/1000
# 3/3 [==============================] - 0s 30ms/step - loss: 0.0266 - mse: 0.0266 - val_loss: 0.4551 - val_mse: 0.4551
# Epoch 190/1000
# 3/3 [==============================] - 0s 31ms/step - loss: 0.0373 - mse: 0.0373 - val_loss: 0.3400 - val_mse: 0.3400
# Epoch 191/1000
# 3/3 [==============================] - 0s 32ms/step - loss: 0.0314 - mse: 0.0314 - val_loss: 0.4056 - val_mse: 0.4056
# Epoch 192/1000
# 3/3 [==============================] - 0s 30ms/step - loss: 0.0284 - mse: 0.0284 - val_loss: 0.3883 - val_mse: 0.3883
# Epoch 193/1000
# 3/3 [==============================] - 0s 31ms/step - loss: 0.0319 - mse: 0.0319 - val_loss: 0.4470 - val_mse: 0.4470
# Epoch 194/1000
# 3/3 [==============================] - 0s 28ms/step - loss: 0.0270 - mse: 0.0270 - val_loss: 0.3981 - val_mse: 0.3981
# Epoch 195/1000
# 3/3 [==============================] - 0s 29ms/step - loss: 0.0342 - mse: 0.0342 - val_loss: 0.3926 - val_mse: 0.3926
# Epoch 196/1000
# 3/3 [==============================] - 0s 32ms/step - loss: 0.0285 - mse: 0.0285 - val_loss: 0.4247 - val_mse: 0.4247
# Epoch 197/1000
# 3/3 [==============================] - 0s 32ms/step - loss: 0.0260 - mse: 0.0260 - val_loss: 0.4243 - val_mse: 0.4243
# Epoch 198/1000
# 3/3 [==============================] - 0s 29ms/step - loss: 0.0315 - mse: 0.0315 - val_loss: 0.4344 - val_mse: 0.4344
# Epoch 199/1000
# 3/3 [==============================] - 0s 27ms/step - loss: 0.0259 - mse: 0.0259 - val_loss: 0.3704 - val_mse: 0.3704
# Epoch 200/1000
# 3/3 [==============================] - 0s 27ms/step - loss: 0.0278 - mse: 0.0278 - val_loss: 0.4078 - val_mse: 0.4078
# Epoch 201/1000
# 3/3 [==============================] - 0s 30ms/step - loss: 0.0265 - mse: 0.0265 - val_loss: 0.4589 - val_mse: 0.4589
# Epoch 202/1000
# 3/3 [==============================] - 0s 55ms/step - loss: 0.0240 - mse: 0.0240 - val_loss: 0.4135 - val_mse: 0.4135
# Epoch 203/1000
# 3/3 [==============================] - 0s 49ms/step - loss: 0.0279 - mse: 0.0279 - val_loss: 0.4324 - val_mse: 0.4324
# Epoch 204/1000
# 3/3 [==============================] - 0s 63ms/step - loss: 0.0249 - mse: 0.0249 - val_loss: 0.4475 - val_mse: 0.4475
# Epoch 205/1000
# 3/3 [==============================] - 0s 56ms/step - loss: 0.0268 - mse: 0.0268 - val_loss: 0.4115 - val_mse: 0.4115
# Epoch 206/1000
# 3/3 [==============================] - 0s 57ms/step - loss: 0.0234 - mse: 0.0234 - val_loss: 0.4203 - val_mse: 0.4203
# Epoch 207/1000
# 3/3 [==============================] - 0s 58ms/step - loss: 0.0250 - mse: 0.0250 - val_loss: 0.3948 - val_mse: 0.3948
# Epoch 208/1000
# 3/3 [==============================] - 0s 60ms/step - loss: 0.0207 - mse: 0.0207 - val_loss: 0.3746 - val_mse: 0.3746
# Epoch 209/1000
# 3/3 [==============================] - 0s 66ms/step - loss: 0.0221 - mse: 0.0221 - val_loss: 0.4429 - val_mse: 0.4429
# Epoch 210/1000
# 3/3 [==============================] - 0s 71ms/step - loss: 0.0231 - mse: 0.0231 - val_loss: 0.4519 - val_mse: 0.4519
# Epoch 211/1000
# 3/3 [==============================] - 0s 43ms/step - loss: 0.0182 - mse: 0.0182 - val_loss: 0.4450 - val_mse: 0.4450
# Epoch 212/1000
# 3/3 [==============================] - 0s 103ms/step - loss: 0.0237 - mse: 0.0237 - val_loss: 0.4298 - val_mse: 0.4298
# Epoch 213/1000
# 3/3 [==============================] - 0s 66ms/step - loss: 0.0221 - mse: 0.0221 - val_loss: 0.4808 - val_mse: 0.4808
# Epoch 214/1000
# 3/3 [==============================] - 0s 161ms/step - loss: 0.0205 - mse: 0.0205 - val_loss: 0.4210 - val_mse: 0.4210
# Epoch 215/1000
# 3/3 [==============================] - 0s 78ms/step - loss: 0.0185 - mse: 0.0185 - val_loss: 0.4265 - val_mse: 0.4265
# Epoch 216/1000
# 3/3 [==============================] - 0s 65ms/step - loss: 0.0199 - mse: 0.0199 - val_loss: 0.4403 - val_mse: 0.4403
# Epoch 217/1000
# 3/3 [==============================] - 0s 62ms/step - loss: 0.0198 - mse: 0.0198 - val_loss: 0.4217 - val_mse: 0.4217
# Epoch 218/1000
# 3/3 [==============================] - 0s 74ms/step - loss: 0.0205 - mse: 0.0205 - val_loss: 0.4501 - val_mse: 0.4501
# Epoch 219/1000
# 3/3 [==============================] - 0s 82ms/step - loss: 0.0196 - mse: 0.0196 - val_loss: 0.4648 - val_mse: 0.4648
# Epoch 220/1000
# 3/3 [==============================] - 0s 72ms/step - loss: 0.0198 - mse: 0.0198 - val_loss: 0.4622 - val_mse: 0.4622
# Epoch 221/1000
# 3/3 [==============================] - 0s 80ms/step - loss: 0.0185 - mse: 0.0185 - val_loss: 0.4319 - val_mse: 0.4319
# Epoch 222/1000
# 3/3 [==============================] - 0s 78ms/step - loss: 0.0192 - mse: 0.0192 - val_loss: 0.4032 - val_mse: 0.4032
# Epoch 223/1000
# 3/3 [==============================] - 0s 65ms/step - loss: 0.0209 - mse: 0.0209 - val_loss: 0.4274 - val_mse: 0.4274
# Epoch 224/1000
# 3/3 [==============================] - 0s 64ms/step - loss: 0.0175 - mse: 0.0175 - val_loss: 0.4352 - val_mse: 0.4352
# Epoch 225/1000
# 3/3 [==============================] - 0s 83ms/step - loss: 0.0184 - mse: 0.0184 - val_loss: 0.4172 - val_mse: 0.4172
# Epoch 226/1000
# 3/3 [==============================] - 0s 54ms/step - loss: 0.0169 - mse: 0.0169 - val_loss: 0.4188 - val_mse: 0.4188
# Epoch 227/1000
# 3/3 [==============================] - 0s 45ms/step - loss: 0.0174 - mse: 0.0174 - val_loss: 0.4378 - val_mse: 0.4378
# Epoch 228/1000
# 3/3 [==============================] - 0s 54ms/step - loss: 0.0180 - mse: 0.0180 - val_loss: 0.4720 - val_mse: 0.4720
# Epoch 229/1000
# 3/3 [==============================] - 0s 45ms/step - loss: 0.0175 - mse: 0.0175 - val_loss: 0.4708 - val_mse: 0.4708
# Epoch 230/1000
# 3/3 [==============================] - 0s 46ms/step - loss: 0.0169 - mse: 0.0169 - val_loss: 0.4460 - val_mse: 0.4460
# Epoch 231/1000
# 3/3 [==============================] - 0s 43ms/step - loss: 0.0171 - mse: 0.0171 - val_loss: 0.4384 - val_mse: 0.4384
# Epoch 232/1000
# 3/3 [==============================] - 0s 40ms/step - loss: 0.0168 - mse: 0.0168 - val_loss: 0.4337 - val_mse: 0.4337
# Epoch 233/1000
# 3/3 [==============================] - 0s 53ms/step - loss: 0.0169 - mse: 0.0169 - val_loss: 0.4159 - val_mse: 0.4159
# Epoch 234/1000
# 3/3 [==============================] - 0s 52ms/step - loss: 0.0168 - mse: 0.0168 - val_loss: 0.4086 - val_mse: 0.4086
# Epoch 235/1000
# 3/3 [==============================] - 0s 51ms/step - loss: 0.0166 - mse: 0.0166 - val_loss: 0.4093 - val_mse: 0.4093
# Epoch 236/1000
# 3/3 [==============================] - 0s 76ms/step - loss: 0.0177 - mse: 0.0177 - val_loss: 0.4056 - val_mse: 0.4056
# Epoch 237/1000
# 3/3 [==============================] - 0s 55ms/step - loss: 0.0167 - mse: 0.0167 - val_loss: 0.4073 - val_mse: 0.4073
# Epoch 238/1000
# 3/3 [==============================] - 0s 45ms/step - loss: 0.0172 - mse: 0.0172 - val_loss: 0.4259 - val_mse: 0.4259
# Epoch 239/1000
# 3/3 [==============================] - 0s 43ms/step - loss: 0.0167 - mse: 0.0167 - val_loss: 0.4424 - val_mse: 0.4424
# Epoch 240/1000
# 3/3 [==============================] - 0s 42ms/step - loss: 0.0166 - mse: 0.0166 - val_loss: 0.4388 - val_mse: 0.4388
# Epoch 241/1000
# 3/3 [==============================] - 0s 53ms/step - loss: 0.0169 - mse: 0.0169 - val_loss: 0.4394 - val_mse: 0.4394
# Epoch 242/1000
# 3/3 [==============================] - 0s 52ms/step - loss: 0.0171 - mse: 0.0171 - val_loss: 0.4228 - val_mse: 0.4228
# Epoch 243/1000
# 3/3 [==============================] - 0s 146ms/step - loss: 0.0164 - mse: 0.0164 - val_loss: 0.4166 - val_mse: 0.4166
# Epoch 244/1000
# 3/3 [==============================] - 0s 56ms/step - loss: 0.0168 - mse: 0.0168 - val_loss: 0.4308 - val_mse: 0.4308
# Epoch 245/1000
# 3/3 [==============================] - 0s 51ms/step - loss: 0.0166 - mse: 0.0166 - val_loss: 0.4343 - val_mse: 0.4343
# Epoch 246/1000
# 3/3 [==============================] - 0s 58ms/step - loss: 0.0171 - mse: 0.0171 - val_loss: 0.4328 - val_mse: 0.4328
# Epoch 247/1000
# 3/3 [==============================] - 0s 61ms/step - loss: 0.0171 - mse: 0.0171 - val_loss: 0.4265 - val_mse: 0.4265
# Epoch 248/1000
# 3/3 [==============================] - 0s 55ms/step - loss: 0.0169 - mse: 0.0169 - val_loss: 0.4286 - val_mse: 0.4286
# Epoch 249/1000
# 3/3 [==============================] - 0s 57ms/step - loss: 0.0165 - mse: 0.0165 - val_loss: 0.4398 - val_mse: 0.4398
# Epoch 250/1000
# 3/3 [==============================] - 0s 47ms/step - loss: 0.0162 - mse: 0.0162 - val_loss: 0.4424 - val_mse: 0.4424
# Epoch 251/1000
# 3/3 [==============================] - 0s 54ms/step - loss: 0.0163 - mse: 0.0163 - val_loss: 0.4381 - val_mse: 0.4381
# Epoch 252/1000
# 3/3 [==============================] - 0s 65ms/step - loss: 0.0169 - mse: 0.0169 - val_loss: 0.4408 - val_mse: 0.4408
# Epoch 253/1000
# 3/3 [==============================] - 0s 56ms/step - loss: 0.0164 - mse: 0.0164 - val_loss: 0.4479 - val_mse: 0.4479
# Epoch 254/1000
# 3/3 [==============================] - 0s 46ms/step - loss: 0.0162 - mse: 0.0162 - val_loss: 0.4479 - val_mse: 0.4479
# Epoch 255/1000
# 3/3 [==============================] - 0s 48ms/step - loss: 0.0163 - mse: 0.0163 - val_loss: 0.4363 - val_mse: 0.4363
# Epoch 256/1000
# 3/3 [==============================] - 0s 42ms/step - loss: 0.0164 - mse: 0.0164 - val_loss: 0.4324 - val_mse: 0.4324
# Epoch 257/1000
# 3/3 [==============================] - 0s 57ms/step - loss: 0.0167 - mse: 0.0167 - val_loss: 0.4329 - val_mse: 0.4329
# Epoch 258/1000
# 3/3 [==============================] - 0s 64ms/step - loss: 0.0163 - mse: 0.0163 - val_loss: 0.4338 - val_mse: 0.4338
# Epoch 259/1000
# 3/3 [==============================] - 0s 75ms/step - loss: 0.0165 - mse: 0.0165 - val_loss: 0.4320 - val_mse: 0.4320
# Epoch 260/1000
# 3/3 [==============================] - 0s 58ms/step - loss: 0.0161 - mse: 0.0161 - val_loss: 0.4339 - val_mse: 0.4339
# Epoch 261/1000
# 3/3 [==============================] - 0s 57ms/step - loss: 0.0162 - mse: 0.0162 - val_loss: 0.4345 - val_mse: 0.4345
# Epoch 262/1000
# 3/3 [==============================] - 0s 54ms/step - loss: 0.0164 - mse: 0.0164 - val_loss: 0.4443 - val_mse: 0.4443
# Epoch 263/1000
# 3/3 [==============================] - 0s 86ms/step - loss: 0.0163 - mse: 0.0163 - val_loss: 0.4608 - val_mse: 0.4608
# Epoch 264/1000
# 3/3 [==============================] - 0s 53ms/step - loss: 0.0162 - mse: 0.0162 - val_loss: 0.4694 - val_mse: 0.4694
# Epoch 265/1000
# 3/3 [==============================] - 0s 59ms/step - loss: 0.0163 - mse: 0.0163 - val_loss: 0.4634 - val_mse: 0.4634
# Epoch 266/1000
# 3/3 [==============================] - 0s 53ms/step - loss: 0.0163 - mse: 0.0163 - val_loss: 0.4442 - val_mse: 0.4442
# Epoch 267/1000
# 3/3 [==============================] - 0s 57ms/step - loss: 0.0162 - mse: 0.0162 - val_loss: 0.4333 - val_mse: 0.4333
# Epoch 268/1000
# 3/3 [==============================] - 0s 55ms/step - loss: 0.0163 - mse: 0.0163 - val_loss: 0.4438 - val_mse: 0.4438
# Epoch 269/1000
# 3/3 [==============================] - 0s 51ms/step - loss: 0.0167 - mse: 0.0167 - val_loss: 0.4577 - val_mse: 0.4577
# Epoch 270/1000
# 3/3 [==============================] - 0s 43ms/step - loss: 0.0161 - mse: 0.0161 - val_loss: 0.4622 - val_mse: 0.4622
# Epoch 271/1000
# 3/3 [==============================] - 0s 41ms/step - loss: 0.0162 - mse: 0.0162 - val_loss: 0.4520 - val_mse: 0.4520
# Epoch 272/1000
# 3/3 [==============================] - 0s 52ms/step - loss: 0.0161 - mse: 0.0161 - val_loss: 0.4425 - val_mse: 0.4425
# Epoch 273/1000
# 3/3 [==============================] - 0s 125ms/step - loss: 0.0159 - mse: 0.0159 - val_loss: 0.4352 - val_mse: 0.4352
# Epoch 274/1000
# 3/3 [==============================] - 0s 54ms/step - loss: 0.0162 - mse: 0.0162 - val_loss: 0.4331 - val_mse: 0.4331
# Epoch 275/1000
# 3/3 [==============================] - 0s 45ms/step - loss: 0.0160 - mse: 0.0160 - val_loss: 0.4374 - val_mse: 0.4374
# Epoch 276/1000
# 3/3 [==============================] - 0s 46ms/step - loss: 0.0160 - mse: 0.0160 - val_loss: 0.4428 - val_mse: 0.4428
# Epoch 277/1000
# 3/3 [==============================] - 0s 50ms/step - loss: 0.0161 - mse: 0.0161 - val_loss: 0.4431 - val_mse: 0.4431
# Epoch 278/1000
# 3/3 [==============================] - 0s 53ms/step - loss: 0.0161 - mse: 0.0161 - val_loss: 0.4374 - val_mse: 0.4374
# Epoch 279/1000
# 3/3 [==============================] - 0s 53ms/step - loss: 0.0161 - mse: 0.0161 - val_loss: 0.4350 - val_mse: 0.4350
# Epoch 280/1000
# 3/3 [==============================] - 0s 56ms/step - loss: 0.0159 - mse: 0.0159 - val_loss: 0.4374 - val_mse: 0.4374
# Epoch 281/1000
# 3/3 [==============================] - 0s 52ms/step - loss: 0.0160 - mse: 0.0160 - val_loss: 0.4375 - val_mse: 0.4375
# Epoch 282/1000
# 3/3 [==============================] - 0s 53ms/step - loss: 0.0163 - mse: 0.0163 - val_loss: 0.4503 - val_mse: 0.4503
# Epoch 283/1000
# 3/3 [==============================] - 0s 52ms/step - loss: 0.0161 - mse: 0.0161 - val_loss: 0.4555 - val_mse: 0.4555
# Epoch 284/1000
# 3/3 [==============================] - 0s 49ms/step - loss: 0.0164 - mse: 0.0164 - val_loss: 0.4611 - val_mse: 0.4611
# Epoch 285/1000
# 3/3 [==============================] - 0s 51ms/step - loss: 0.0162 - mse: 0.0162 - val_loss: 0.4595 - val_mse: 0.4595
# Epoch 286/1000
# 3/3 [==============================] - 0s 52ms/step - loss: 0.0161 - mse: 0.0161 - val_loss: 0.4516 - val_mse: 0.4516
# Epoch 287/1000
# 3/3 [==============================] - 0s 43ms/step - loss: 0.0162 - mse: 0.0162 - val_loss: 0.4472 - val_mse: 0.4472
# Epoch 288/1000
# 3/3 [==============================] - 0s 80ms/step - loss: 0.0163 - mse: 0.0163 - val_loss: 0.4496 - val_mse: 0.4496
# Epoch 289/1000
# 3/3 [==============================] - 0s 54ms/step - loss: 0.0162 - mse: 0.0162 - val_loss: 0.4502 - val_mse: 0.4502
# Epoch 290/1000
# 3/3 [==============================] - 0s 46ms/step - loss: 0.0159 - mse: 0.0159 - val_loss: 0.4531 - val_mse: 0.4531
# Epoch 291/1000
# 3/3 [==============================] - 0s 37ms/step - loss: 0.0164 - mse: 0.0164 - val_loss: 0.4556 - val_mse: 0.4556
# Epoch 292/1000
# 3/3 [==============================] - 0s 54ms/step - loss: 0.0160 - mse: 0.0160 - val_loss: 0.4572 - val_mse: 0.4572
# Epoch 293/1000
# 3/3 [==============================] - 0s 47ms/step - loss: 0.0160 - mse: 0.0160 - val_loss: 0.4513 - val_mse: 0.4513
# Epoch 294/1000
# 3/3 [==============================] - 0s 37ms/step - loss: 0.0160 - mse: 0.0160 - val_loss: 0.4448 - val_mse: 0.4448
# Epoch 295/1000
# 3/3 [==============================] - 0s 51ms/step - loss: 0.0161 - mse: 0.0161 - val_loss: 0.4454 - val_mse: 0.4454
# Epoch 296/1000
# 3/3 [==============================] - 0s 50ms/step - loss: 0.0160 - mse: 0.0160 - val_loss: 0.4431 - val_mse: 0.4431
# Epoch 297/1000
# 3/3 [==============================] - 0s 60ms/step - loss: 0.0160 - mse: 0.0160 - val_loss: 0.4451 - val_mse: 0.4451
# Epoch 298/1000
# 3/3 [==============================] - 0s 53ms/step - loss: 0.0160 - mse: 0.0160 - val_loss: 0.4504 - val_mse: 0.4504
# Epoch 299/1000
# 3/3 [==============================] - 0s 56ms/step - loss: 0.0158 - mse: 0.0158 - val_loss: 0.4536 - val_mse: 0.4536
# Epoch 300/1000
# 3/3 [==============================] - 0s 44ms/step - loss: 0.0161 - mse: 0.0161 - val_loss: 0.4517 - val_mse: 0.4517
# Epoch 301/1000
# 3/3 [==============================] - 0s 113ms/step - loss: 0.0160 - mse: 0.0160 - val_loss: 0.4504 - val_mse: 0.4504
# Epoch 302/1000
# 3/3 [==============================] - 0s 51ms/step - loss: 0.0161 - mse: 0.0161 - val_loss: 0.4487 - val_mse: 0.4487
# Epoch 303/1000
# 3/3 [==============================] - 0s 54ms/step - loss: 0.0160 - mse: 0.0160 - val_loss: 0.4494 - val_mse: 0.4494
# Epoch 304/1000
# 3/3 [==============================] - 0s 46ms/step - loss: 0.0159 - mse: 0.0159 - val_loss: 0.4506 - val_mse: 0.4506
# Epoch 305/1000
# 3/3 [==============================] - 0s 46ms/step - loss: 0.0160 - mse: 0.0160 - val_loss: 0.4584 - val_mse: 0.4584
# Epoch 306/1000
# 3/3 [==============================] - 0s 52ms/step - loss: 0.0160 - mse: 0.0160 - val_loss: 0.4653 - val_mse: 0.4653
# Epoch 307/1000
# 3/3 [==============================] - 0s 60ms/step - loss: 0.0159 - mse: 0.0159 - val_loss: 0.4614 - val_mse: 0.4614
# Epoch 308/1000
# 3/3 [==============================] - 0s 51ms/step - loss: 0.0160 - mse: 0.0160 - val_loss: 0.4470 - val_mse: 0.4470
# Epoch 309/1000
# 3/3 [==============================] - 0s 55ms/step - loss: 0.0159 - mse: 0.0159 - val_loss: 0.4399 - val_mse: 0.4399
# Epoch 310/1000
# 3/3 [==============================] - 0s 51ms/step - loss: 0.0162 - mse: 0.0162 - val_loss: 0.4475 - val_mse: 0.4475
# Epoch 311/1000
# 3/3 [==============================] - 0s 47ms/step - loss: 0.0160 - mse: 0.0160 - val_loss: 0.4476 - val_mse: 0.4476
# Epoch 312/1000
# 3/3 [==============================] - 0s 87ms/step - loss: 0.0160 - mse: 0.0160 - val_loss: 0.4552 - val_mse: 0.4552
# Epoch 313/1000
# 3/3 [==============================] - 0s 56ms/step - loss: 0.0159 - mse: 0.0159 - val_loss: 0.4599 - val_mse: 0.4599
# Epoch 314/1000
# 3/3 [==============================] - 0s 54ms/step - loss: 0.0160 - mse: 0.0160 - val_loss: 0.4510 - val_mse: 0.4510
# Epoch 315/1000
# 3/3 [==============================] - 0s 60ms/step - loss: 0.0158 - mse: 0.0158 - val_loss: 0.4442 - val_mse: 0.4442
# Epoch 316/1000
# 3/3 [==============================] - 0s 47ms/step - loss: 0.0162 - mse: 0.0162 - val_loss: 0.4446 - val_mse: 0.4446
# Epoch 317/1000
# 3/3 [==============================] - 0s 54ms/step - loss: 0.0158 - mse: 0.0158 - val_loss: 0.4502 - val_mse: 0.4502
# Epoch 318/1000
# 3/3 [==============================] - 0s 51ms/step - loss: 0.0158 - mse: 0.0158 - val_loss: 0.4533 - val_mse: 0.4533
# Epoch 319/1000
# 3/3 [==============================] - 0s 56ms/step - loss: 0.0160 - mse: 0.0160 - val_loss: 0.4512 - val_mse: 0.4512
# Epoch 320/1000
# 3/3 [==============================] - 0s 44ms/step - loss: 0.0159 - mse: 0.0159 - val_loss: 0.4472 - val_mse: 0.4472
# Epoch 321/1000
# 3/3 [==============================] - 0s 39ms/step - loss: 0.0158 - mse: 0.0158 - val_loss: 0.4451 - val_mse: 0.4451
# Epoch 322/1000
# 3/3 [==============================] - 0s 40ms/step - loss: 0.0159 - mse: 0.0159 - val_loss: 0.4444 - val_mse: 0.4444
# Epoch 323/1000
# 3/3 [==============================] - 0s 42ms/step - loss: 0.0160 - mse: 0.0160 - val_loss: 0.4422 - val_mse: 0.4422
# Epoch 324/1000
# 3/3 [==============================] - 0s 45ms/step - loss: 0.0159 - mse: 0.0159 - val_loss: 0.4412 - val_mse: 0.4412
# Epoch 325/1000
# 3/3 [==============================] - 0s 43ms/step - loss: 0.0161 - mse: 0.0161 - val_loss: 0.4400 - val_mse: 0.4400
# Epoch 326/1000
# 3/3 [==============================] - 0s 50ms/step - loss: 0.0159 - mse: 0.0159 - val_loss: 0.4447 - val_mse: 0.4447
# Epoch 327/1000
# 3/3 [==============================] - 0s 46ms/step - loss: 0.0160 - mse: 0.0160 - val_loss: 0.4518 - val_mse: 0.4518
# Epoch 328/1000
# 3/3 [==============================] - 0s 124ms/step - loss: 0.0158 - mse: 0.0158 - val_loss: 0.4560 - val_mse: 0.4560
# Epoch 329/1000
# 3/3 [==============================] - 0s 45ms/step - loss: 0.0158 - mse: 0.0158 - val_loss: 0.4537 - val_mse: 0.4537
# Epoch 330/1000
# 3/3 [==============================] - 0s 51ms/step - loss: 0.0159 - mse: 0.0159 - val_loss: 0.4517 - val_mse: 0.4517
# Epoch 331/1000
# 3/3 [==============================] - 0s 44ms/step - loss: 0.0158 - mse: 0.0158 - val_loss: 0.4487 - val_mse: 0.4487
# Epoch 332/1000
# 3/3 [==============================] - 0s 34ms/step - loss: 0.0157 - mse: 0.0157 - val_loss: 0.4498 - val_mse: 0.4498
# Epoch 333/1000
# 3/3 [==============================] - 0s 52ms/step - loss: 0.0159 - mse: 0.0159 - val_loss: 0.4511 - val_mse: 0.4511
# Epoch 334/1000
# 3/3 [==============================] - 0s 49ms/step - loss: 0.0159 - mse: 0.0159 - val_loss: 0.4534 - val_mse: 0.4534
# Epoch 335/1000
# 3/3 [==============================] - 0s 56ms/step - loss: 0.0159 - mse: 0.0159 - val_loss: 0.4526 - val_mse: 0.4526
# Epoch 336/1000
# 3/3 [==============================] - 0s 48ms/step - loss: 0.0158 - mse: 0.0158 - val_loss: 0.4506 - val_mse: 0.4506
# Epoch 337/1000
# 3/3 [==============================] - 0s 84ms/step - loss: 0.0163 - mse: 0.0163 - val_loss: 0.4511 - val_mse: 0.4511
# Epoch 338/1000
# 3/3 [==============================] - 0s 49ms/step - loss: 0.0160 - mse: 0.0160 - val_loss: 0.4608 - val_mse: 0.4608
# Epoch 339/1000
# 3/3 [==============================] - 0s 54ms/step - loss: 0.0156 - mse: 0.0156 - val_loss: 0.4675 - val_mse: 0.4675
# Epoch 340/1000
# 3/3 [==============================] - 0s 43ms/step - loss: 0.0159 - mse: 0.0159 - val_loss: 0.4750 - val_mse: 0.4750
# Epoch 341/1000
# 3/3 [==============================] - 0s 51ms/step - loss: 0.0160 - mse: 0.0160 - val_loss: 0.4823 - val_mse: 0.4823
# Epoch 342/1000
# 3/3 [==============================] - 0s 49ms/step - loss: 0.0159 - mse: 0.0159 - val_loss: 0.4789 - val_mse: 0.4789
# Epoch 343/1000
# 3/3 [==============================] - 0s 49ms/step - loss: 0.0159 - mse: 0.0159 - val_loss: 0.4713 - val_mse: 0.4713
# Epoch 344/1000
# 3/3 [==============================] - 0s 50ms/step - loss: 0.0160 - mse: 0.0160 - val_loss: 0.4554 - val_mse: 0.4554
# Epoch 345/1000
# 3/3 [==============================] - 0s 42ms/step - loss: 0.0159 - mse: 0.0159 - val_loss: 0.4474 - val_mse: 0.4474
# Epoch 346/1000
# 3/3 [==============================] - 0s 41ms/step - loss: 0.0158 - mse: 0.0158 - val_loss: 0.4490 - val_mse: 0.4490
# Epoch 347/1000
# 3/3 [==============================] - 0s 44ms/step - loss: 0.0159 - mse: 0.0159 - val_loss: 0.4536 - val_mse: 0.4536
# Epoch 348/1000
# 3/3 [==============================] - 0s 42ms/step - loss: 0.0158 - mse: 0.0158 - val_loss: 0.4541 - val_mse: 0.4541
# Epoch 349/1000
# 3/3 [==============================] - 0s 53ms/step - loss: 0.0159 - mse: 0.0159 - val_loss: 0.4486 - val_mse: 0.4486
# Epoch 350/1000
# 3/3 [==============================] - 0s 50ms/step - loss: 0.0158 - mse: 0.0158 - val_loss: 0.4429 - val_mse: 0.4429
# Epoch 351/1000
# 3/3 [==============================] - 0s 52ms/step - loss: 0.0158 - mse: 0.0158 - val_loss: 0.4371 - val_mse: 0.4371
# Epoch 352/1000
# ...
# Epoch 598/1000
# 3/3 [==============================] - 0s 53ms/step - loss: 0.0156 - mse: 0.0156 - val_loss: 0.4843 - val_mse: 0.4843
# Epoch 599/1000
# 3/3 [==============================] - 0s 78ms/step - loss: 0.0156 - mse: 0.0156 - val_loss: 0.4824 - val_mse: 0.4824
# Epoch 600/1000
# 3/3 [==============================] - 0s 54ms/step - loss: 0.0156 - mse: 0.0156 - val_loss: 0.4820 - val_mse: 0.4820
# Epoch 601/1000
# 3/3 [==============================] - 0s 57ms/step - loss: 0.0156 - mse: 0.0156 - val_loss: 0.4814 - val_mse: 0.4814
# Epoch 602/1000
# 3/3 [==============================] - 0s 54ms/step - loss: 0.0157 - mse: 0.0157 - val_loss: 0.4852 - val_mse: 0.4852
# Epoch 603/1000
# 3/3 [==============================] - 0s 48ms/step - loss: 0.0156 - mse: 0.0156 - val_loss: 0.4855 - val_mse: 0.4855
# Epoch 604/1000
# 3/3 [==============================] - 0s 48ms/step - loss: 0.0156 - mse: 0.0156 - val_loss: 0.4830 - val_mse: 0.4830
# Epoch 605/1000
# 3/3 [==============================] - 0s 43ms/step - loss: 0.0156 - mse: 0.0156 - val_loss: 0.4771 - val_mse: 0.4771
# Epoch 606/1000
# 3/3 [==============================] - 0s 46ms/step - loss: 0.0157 - mse: 0.0157 - val_loss: 0.4727 - val_mse: 0.4727
# Epoch 607/1000
# 3/3 [==============================] - 0s 45ms/step - loss: 0.0156 - mse: 0.0156 - val_loss: 0.4694 - val_mse: 0.4694
# Epoch 608/1000
# 3/3 [==============================] - 0s 42ms/step - loss: 0.0156 - mse: 0.0156 - val_loss: 0.4681 - val_mse: 0.4681
# Epoch 609/1000
# 3/3 [==============================] - 0s 53ms/step - loss: 0.0156 - mse: 0.0156 - val_loss: 0.4726 - val_mse: 0.4726
# Epoch 610/1000
# 3/3 [==============================] - 0s 120ms/step - loss: 0.0157 - mse: 0.0157 - val_loss: 0.4805 - val_mse: 0.4805
# Epoch 611/1000
# 3/3 [==============================] - 0s 59ms/step - loss: 0.0156 - mse: 0.0156 - val_loss: 0.4861 - val_mse: 0.4861
# Epoch 612/1000
# 3/3 [==============================] - 0s 44ms/step - loss: 0.0156 - mse: 0.0156 - val_loss: 0.4871 - val_mse: 0.4871
# Epoch 613/1000
# 3/3 [==============================] - 0s 76ms/step - loss: 0.0156 - mse: 0.0156 - val_loss: 0.4872 - val_mse: 0.4872
# Epoch 614/1000
# 3/3 [==============================] - 0s 60ms/step - loss: 0.0157 - mse: 0.0157 - val_loss: 0.4878 - val_mse: 0.4878
# Epoch 615/1000
# 3/3 [==============================] - 0s 58ms/step - loss: 0.0156 - mse: 0.0156 - val_loss: 0.4878 - val_mse: 0.4878
# Epoch 616/1000
# 3/3 [==============================] - 0s 58ms/step - loss: 0.0156 - mse: 0.0156 - val_loss: 0.4884 - val_mse: 0.4884
# Epoch 617/1000
# 3/3 [==============================] - 0s 50ms/step - loss: 0.0157 - mse: 0.0157 - val_loss: 0.4846 - val_mse: 0.4846
# Epoch 618/1000
# 3/3 [==============================] - 0s 45ms/step - loss: 0.0157 - mse: 0.0157 - val_loss: 0.4798 - val_mse: 0.4798
# Epoch 619/1000
# 3/3 [==============================] - 0s 47ms/step - loss: 0.0156 - mse: 0.0156 - val_loss: 0.4789 - val_mse: 0.4789
# Epoch 620/1000
# 3/3 [==============================] - 0s 50ms/step - loss: 0.0156 - mse: 0.0156 - val_loss: 0.4823 - val_mse: 0.4823
# Epoch 621/1000
# 3/3 [==============================] - 0s 44ms/step - loss: 0.0156 - mse: 0.0156 - val_loss: 0.4858 - val_mse: 0.4858
# Epoch 622/1000
# 3/3 [==============================] - 0s 58ms/step - loss: 0.0156 - mse: 0.0156 - val_loss: 0.4873 - val_mse: 0.4873
# Epoch 623/1000
# 3/3 [==============================] - 0s 47ms/step - loss: 0.0156 - mse: 0.0156 - val_loss: 0.4830 - val_mse: 0.4830
# Epoch 624/1000
# 3/3 [==============================] - 0s 44ms/step - loss: 0.0157 - mse: 0.0157 - val_loss: 0.4820 - val_mse: 0.4820
# Epoch 625/1000
# 3/3 [==============================] - 0s 59ms/step - loss: 0.0156 - mse: 0.0156 - val_loss: 0.4840 - val_mse: 0.4840
# Epoch 626/1000
# 3/3 [==============================] - 0s 45ms/step - loss: 0.0157 - mse: 0.0157 - val_loss: 0.4896 - val_mse: 0.4896
# Epoch 627/1000
# 3/3 [==============================] - 0s 151ms/step - loss: 0.0156 - mse: 0.0156 - val_loss: 0.4956 - val_mse: 0.4956
# Epoch 628/1000
# 3/3 [==============================] - 0s 59ms/step - loss: 0.0156 - mse: 0.0156 - val_loss: 0.4989 - val_mse: 0.4989
# Epoch 629/1000
# 3/3 [==============================] - 0s 48ms/step - loss: 0.0157 - mse: 0.0157 - val_loss: 0.4942 - val_mse: 0.4942
# Epoch 630/1000
# 3/3 [==============================] - 0s 55ms/step - loss: 0.0156 - mse: 0.0156 - val_loss: 0.4869 - val_mse: 0.4869
# Epoch 631/1000
# 3/3 [==============================] - 0s 47ms/step - loss: 0.0156 - mse: 0.0156 - val_loss: 0.4810 - val_mse: 0.4810
# Epoch 632/1000
# 3/3 [==============================] - 0s 54ms/step - loss: 0.0156 - mse: 0.0156 - val_loss: 0.4800 - val_mse: 0.4800
# Epoch 633/1000
# 3/3 [==============================] - 0s 48ms/step - loss: 0.0156 - mse: 0.0156 - val_loss: 0.4784 - val_mse: 0.4784
# Epoch 634/1000
# 3/3 [==============================] - 0s 50ms/step - loss: 0.0156 - mse: 0.0156 - val_loss: 0.4810 - val_mse: 0.4810
# Epoch 635/1000
# 3/3 [==============================] - 0s 44ms/step - loss: 0.0156 - mse: 0.0156 - val_loss: 0.4865 - val_mse: 0.4865
# Epoch 636/1000
# 3/3 [==============================] - 0s 44ms/step - loss: 0.0156 - mse: 0.0156 - val_loss: 0.4904 - val_mse: 0.4904
# Epoch 637/1000
# 3/3 [==============================] - 0s 45ms/step - loss: 0.0156 - mse: 0.0156 - val_loss: 0.4959 - val_mse: 0.4959
# Epoch 638/1000
# 3/3 [==============================] - 0s 47ms/step - loss: 0.0156 - mse: 0.0156 - val_loss: 0.4987 - val_mse: 0.4987
# Epoch 639/1000
# 3/3 [==============================] - 0s 58ms/step - loss: 0.0156 - mse: 0.0156 - val_loss: 0.4950 - val_mse: 0.4950
# Epoch 640/1000
# 3/3 [==============================] - 0s 159ms/step - loss: 0.0156 - mse: 0.0156 - val_loss: 0.4900 - val_mse: 0.4900
# Epoch 641/1000
# 3/3 [==============================] - 0s 43ms/step - loss: 0.0156 - mse: 0.0156 - val_loss: 0.4841 - val_mse: 0.4841
# Epoch 642/1000
# 3/3 [==============================] - 0s 55ms/step - loss: 0.0156 - mse: 0.0156 - val_loss: 0.4835 - val_mse: 0.4835
# Epoch 643/1000
# 3/3 [==============================] - 0s 56ms/step - loss: 0.0156 - mse: 0.0156 - val_loss: 0.4836 - val_mse: 0.4836
# Epoch 644/1000
# 3/3 [==============================] - 0s 55ms/step - loss: 0.0156 - mse: 0.0156 - val_loss: 0.4839 - val_mse: 0.4839
# Epoch 645/1000
# 3/3 [==============================] - 0s 51ms/step - loss: 0.0156 - mse: 0.0156 - val_loss: 0.4848 - val_mse: 0.4848
# Epoch 646/1000
# 3/3 [==============================] - 0s 44ms/step - loss: 0.0156 - mse: 0.0156 - val_loss: 0.4857 - val_mse: 0.4857
# Epoch 647/1000
# 3/3 [==============================] - 0s 51ms/step - loss: 0.0156 - mse: 0.0156 - val_loss: 0.4878 - val_mse: 0.4878
# Epoch 648/1000
# 3/3 [==============================] - 0s 46ms/step - loss: 0.0156 - mse: 0.0156 - val_loss: 0.4899 - val_mse: 0.4899
# Epoch 649/1000
# 3/3 [==============================] - 0s 49ms/step - loss: 0.0156 - mse: 0.0156 - val_loss: 0.4898 - val_mse: 0.4898
# Epoch 650/1000
# 3/3 [==============================] - 0s 45ms/step - loss: 0.0156 - mse: 0.0156 - val_loss: 0.4889 - val_mse: 0.4889
# Epoch 651/1000
# 3/3 [==============================] - 0s 52ms/step - loss: 0.0156 - mse: 0.0156 - val_loss: 0.4879 - val_mse: 0.4879
# Epoch 652/1000
# 3/3 [==============================] - 0s 113ms/step - loss: 0.0156 - mse: 0.0156 - val_loss: 0.4856 - val_mse: 0.4856
# Epoch 653/1000
# 3/3 [==============================] - 0s 52ms/step - loss: 0.0156 - mse: 0.0156 - val_loss: 0.4823 - val_mse: 0.4823
# Epoch 654/1000
# 3/3 [==============================] - 0s 75ms/step - loss: 0.0156 - mse: 0.0156 - val_loss: 0.4826 - val_mse: 0.4826
# Epoch 655/1000
# 3/3 [==============================] - 0s 49ms/step - loss: 0.0156 - mse: 0.0156 - val_loss: 0.4848 - val_mse: 0.4848
# Epoch 656/1000
# 3/3 [==============================] - 0s 54ms/step - loss: 0.0156 - mse: 0.0156 - val_loss: 0.4859 - val_mse: 0.4859
# Epoch 657/1000
# 3/3 [==============================] - 0s 45ms/step - loss: 0.0156 - mse: 0.0156 - val_loss: 0.4862 - val_mse: 0.4862
# Epoch 658/1000
# 3/3 [==============================] - 0s 46ms/step - loss: 0.0157 - mse: 0.0157 - val_loss: 0.4951 - val_mse: 0.4951
# Epoch 659/1000
# 3/3 [==============================] - 0s 51ms/step - loss: 0.0157 - mse: 0.0157 - val_loss: 0.5077 - val_mse: 0.5077
# Epoch 660/1000
# 3/3 [==============================] - 0s 46ms/step - loss: 0.0156 - mse: 0.0156 - val_loss: 0.5142 - val_mse: 0.5142
# Epoch 661/1000
# 3/3 [==============================] - 0s 56ms/step - loss: 0.0156 - mse: 0.0156 - val_loss: 0.5170 - val_mse: 0.5170
# Epoch 662/1000
# 3/3 [==============================] - 0s 43ms/step - loss: 0.0156 - mse: 0.0156 - val_loss: 0.5134 - val_mse: 0.5134
# Epoch 663/1000
# 3/3 [==============================] - 0s 52ms/step - loss: 0.0156 - mse: 0.0156 - val_loss: 0.5061 - val_mse: 0.5061
# Epoch 664/1000
# 3/3 [==============================] - 0s 52ms/step - loss: 0.0156 - mse: 0.0156 - val_loss: 0.5006 - val_mse: 0.5006
# Epoch 665/1000
# 3/3 [==============================] - 0s 41ms/step - loss: 0.0156 - mse: 0.0156 - val_loss: 0.5000 - val_mse: 0.5000
# Epoch 666/1000
# 3/3 [==============================] - 0s 49ms/step - loss: 0.0157 - mse: 0.0157 - val_loss: 0.5011 - val_mse: 0.5011
# Epoch 667/1000
# 3/3 [==============================] - 0s 74ms/step - loss: 0.0156 - mse: 0.0156 - val_loss: 0.5011 - val_mse: 0.5011
# Epoch 668/1000
# 3/3 [==============================] - 0s 120ms/step - loss: 0.0156 - mse: 0.0156 - val_loss: 0.5002 - val_mse: 0.5002
# Epoch 669/1000
# 3/3 [==============================] - 0s 55ms/step - loss: 0.0156 - mse: 0.0156 - val_loss: 0.4991 - val_mse: 0.4991
# Epoch 670/1000
# 3/3 [==============================] - 0s 50ms/step - loss: 0.0156 - mse: 0.0156 - val_loss: 0.5008 - val_mse: 0.5008
# Epoch 671/1000
# 3/3 [==============================] - 0s 46ms/step - loss: 0.0157 - mse: 0.0157 - val_loss: 0.5006 - val_mse: 0.5006
# Epoch 672/1000
# 3/3 [==============================] - 0s 41ms/step - loss: 0.0156 - mse: 0.0156 - val_loss: 0.4963 - val_mse: 0.4963
# Epoch 673/1000
# 3/3 [==============================] - 0s 55ms/step - loss: 0.0156 - mse: 0.0156 - val_loss: 0.4937 - val_mse: 0.4937
# Epoch 674/1000
# 3/3 [==============================] - 0s 41ms/step - loss: 0.0157 - mse: 0.0157 - val_loss: 0.4953 - val_mse: 0.4953
# Epoch 675/1000
# 3/3 [==============================] - 0s 53ms/step - loss: 0.0156 - mse: 0.0156 - val_loss: 0.4958 - val_mse: 0.4958
# Epoch 676/1000
# 3/3 [==============================] - 0s 51ms/step - loss: 0.0156 - mse: 0.0156 - val_loss: 0.4953 - val_mse: 0.4953
# Epoch 677/1000
# 3/3 [==============================] - 0s 45ms/step - loss: 0.0156 - mse: 0.0156 - val_loss: 0.4959 - val_mse: 0.4959
# Epoch 678/1000
# 3/3 [==============================] - 0s 45ms/step - loss: 0.0156 - mse: 0.0156 - val_loss: 0.4983 - val_mse: 0.4983
# Epoch 679/1000
# 3/3 [==============================] - 0s 43ms/step - loss: 0.0157 - mse: 0.0157 - val_loss: 0.4919 - val_mse: 0.4919
# Epoch 680/1000
# 3/3 [==============================] - 0s 151ms/step - loss: 0.0156 - mse: 0.0156 - val_loss: 0.4876 - val_mse: 0.4876
# Epoch 681/1000
# 3/3 [==============================] - 0s 48ms/step - loss: 0.0157 - mse: 0.0157 - val_loss: 0.4982 - val_mse: 0.4982
# Epoch 682/1000
# 3/3 [==============================] - 0s 53ms/step - loss: 0.0156 - mse: 0.0156 - val_loss: 0.5068 - val_mse: 0.5068
# Epoch 683/1000
# 3/3 [==============================] - 0s 49ms/step - loss: 0.0156 - mse: 0.0156 - val_loss: 0.5111 - val_mse: 0.5111
# Epoch 684/1000
# 3/3 [==============================] - 0s 50ms/step - loss: 0.0156 - mse: 0.0156 - val_loss: 0.5132 - val_mse: 0.5132
# Epoch 685/1000
# 3/3 [==============================] - 0s 52ms/step - loss: 0.0157 - mse: 0.0157 - val_loss: 0.5103 - val_mse: 0.5103
# Epoch 686/1000
# 3/3 [==============================] - 0s 54ms/step - loss: 0.0155 - mse: 0.0155 - val_loss: 0.5041 - val_mse: 0.5041
# Epoch 687/1000
# 3/3 [==============================] - 0s 53ms/step - loss: 0.0156 - mse: 0.0156 - val_loss: 0.4971 - val_mse: 0.4971
# Epoch 688/1000
# 3/3 [==============================] - 0s 46ms/step - loss: 0.0156 - mse: 0.0156 - val_loss: 0.4896 - val_mse: 0.4896
# Epoch 689/1000
# 3/3 [==============================] - 0s 42ms/step - loss: 0.0156 - mse: 0.0156 - val_loss: 0.4853 - val_mse: 0.4853
# Epoch 690/1000
# 3/3 [==============================] - 0s 46ms/step - loss: 0.0156 - mse: 0.0156 - val_loss: 0.4836 - val_mse: 0.4836
# Epoch 691/1000
# 3/3 [==============================] - 0s 150ms/step - loss: 0.0156 - mse: 0.0156 - val_loss: 0.4900 - val_mse: 0.4900
# Epoch 692/1000
# 3/3 [==============================] - 0s 55ms/step - loss: 0.0157 - mse: 0.0157 - val_loss: 0.5019 - val_mse: 0.5019
# Epoch 693/1000
# 3/3 [==============================] - 0s 45ms/step - loss: 0.0156 - mse: 0.0156 - val_loss: 0.5105 - val_mse: 0.5105
# Epoch 694/1000
# 3/3 [==============================] - 0s 41ms/step - loss: 0.0156 - mse: 0.0156 - val_loss: 0.5116 - val_mse: 0.5116
# Epoch 695/1000
# 3/3 [==============================] - 0s 53ms/step - loss: 0.0156 - mse: 0.0156 - val_loss: 0.5044 - val_mse: 0.5044
# Epoch 696/1000
# 3/3 [==============================] - 0s 64ms/step - loss: 0.0156 - mse: 0.0156 - val_loss: 0.4910 - val_mse: 0.4910
# Epoch 697/1000
# 3/3 [==============================] - 0s 45ms/step - loss: 0.0156 - mse: 0.0156 - val_loss: 0.4791 - val_mse: 0.4791
# Epoch 698/1000
# 3/3 [==============================] - 0s 43ms/step - loss: 0.0156 - mse: 0.0156 - val_loss: 0.4717 - val_mse: 0.4717
# Epoch 699/1000
# 3/3 [==============================] - 0s 50ms/step - loss: 0.0156 - mse: 0.0156 - val_loss: 0.4687 - val_mse: 0.4687
# Epoch 700/1000
# 3/3 [==============================] - 0s 54ms/step - loss: 0.0156 - mse: 0.0156 - val_loss: 0.4694 - val_mse: 0.4694
# Epoch 701/1000
# 3/3 [==============================] - 0s 52ms/step - loss: 0.0156 - mse: 0.0156 - val_loss: 0.4745 - val_mse: 0.4745
# Epoch 702/1000
# 3/3 [==============================] - 0s 76ms/step - loss: 0.0157 - mse: 0.0157 - val_loss: 0.4762 - val_mse: 0.4762
# Epoch 703/1000
# 3/3 [==============================] - 0s 55ms/step - loss: 0.0156 - mse: 0.0156 - val_loss: 0.4879 - val_mse: 0.4879
# Epoch 704/1000
# 3/3 [==============================] - 0s 42ms/step - loss: 0.0156 - mse: 0.0156 - val_loss: 0.4947 - val_mse: 0.4947
# Epoch 705/1000
# 3/3 [==============================] - 0s 52ms/step - loss: 0.0156 - mse: 0.0156 - val_loss: 0.4985 - val_mse: 0.4985
# Epoch 706/1000
# 3/3 [==============================] - 0s 129ms/step - loss: 0.0156 - mse: 0.0156 - val_loss: 0.5014 - val_mse: 0.5014
# Epoch 707/1000
# 3/3 [==============================] - 0s 53ms/step - loss: 0.0156 - mse: 0.0156 - val_loss: 0.5042 - val_mse: 0.5042
# Epoch 708/1000
# 3/3 [==============================] - 0s 40ms/step - loss: 0.0156 - mse: 0.0156 - val_loss: 0.5047 - val_mse: 0.5047
# Epoch 709/1000
# 3/3 [==============================] - 0s 52ms/step - loss: 0.0157 - mse: 0.0157 - val_loss: 0.4946 - val_mse: 0.4946
# Epoch 710/1000
# 3/3 [==============================] - 0s 50ms/step - loss: 0.0156 - mse: 0.0156 - val_loss: 0.4779 - val_mse: 0.4779
# Epoch 711/1000
# 3/3 [==============================] - 0s 42ms/step - loss: 0.0156 - mse: 0.0156 - val_loss: 0.4658 - val_mse: 0.4658
# Epoch 712/1000
# 3/3 [==============================] - 0s 84ms/step - loss: 0.0156 - mse: 0.0156 - val_loss: 0.4601 - val_mse: 0.4601
# Epoch 713/1000
# 3/3 [==============================] - 0s 55ms/step - loss: 0.0156 - mse: 0.0156 - val_loss: 0.4593 - val_mse: 0.4593
# Epoch 714/1000
# 3/3 [==============================] - 0s 42ms/step - loss: 0.0156 - mse: 0.0156 - val_loss: 0.4618 - val_mse: 0.4618
# Epoch 715/1000
# 3/3 [==============================] - 0s 55ms/step - loss: 0.0156 - mse: 0.0156 - val_loss: 0.4683 - val_mse: 0.4683
# Epoch 716/1000
# 3/3 [==============================] - 0s 57ms/step - loss: 0.0156 - mse: 0.0156 - val_loss: 0.4759 - val_mse: 0.4759
# The difference in seconds is: 89.15349340438843

# %%
# # Extract the metrics from the history object
loss = history.history['loss']
val_loss = history.history['val_loss']
# r_square = history.history['r_square']
# val_r_square = history.history['val_r_square']

# # Plot loss and val_loss
# plt.figure(figsize=(12, 6))
# plt.plot(loss, label='Training Loss', color='blue')
# plt.plot(val_loss, label='Validation Loss', color='orange')
# plt.title('Training Loss vs Validation Loss')
# plt.xlabel('Epochs')
# plt.ylabel('Loss')
# plt.legend()
# plt.grid()
# plt.show()

# # Plot r_square and val_r_square
# plt.figure(figsize=(12, 6))
# plt.plot(r_square, label='Training R^2', color='green')
# plt.plot(val_r_square, label='Validation R^2', color='red')
# plt.title('Training R^2 vs Validation R^2')
# plt.xlabel('Epochs')
# plt.ylabel('R^2')
# plt.legend()
# plt.grid()
# plt.show()

# %%
# Find the minimum loss for training and validation
min_training_loss = min(loss)
min_validation_loss = min(val_loss)

# Print the results
print(f"Minimum Training Loss: {min_training_loss}")
print(f"Minimum Validation Loss: {min_validation_loss}")
# Out:
# Minimum Training Loss: 0.015530209057033062
# Minimum Validation Loss: 0.164407879114151

# %%
# # Find the maximum R² values for training and validation
# max_r_square_train = max(r_square)
# max_r_square_val = max(val_r_square)

# # Print the results
# print(f"Maximum Training R²: {max_r_square_train}")
# print(f"Maximum Validation R²: {max_r_square_val}")
# Out:
# Maximum Training R²: 0.3449629843235016
# Maximum Validation R²: -0.017218351364135742

# %%
# model = best_model

# %%
# Generate predictions for the training set
Y_train_pred = model.predict(X_train)

# Plot the true values and predictions
plt.figure(figsize=(10, 6))
plt.plot(Y_train, label='True Values', color='blue',  marker='o')
plt.plot(Y_train_pred, label='Predictions', color='red', linestyle='dashed', marker='o')
plt.title('Training True Values vs Predictions')
plt.xlabel('Sample Index')
plt.ylabel('Value')
plt.legend()
plt.show()
# Out:
# 6/6 [==============================] - 0s 3ms/step

# %%
# Generate predictions for the validation set
Y_val_pred = model.predict(X_val)

# Plot the true values and predictions
plt.figure(figsize=(10, 6))
plt.plot(Y_val, label='True Values', color='blue', marker='o')
plt.plot(Y_val_pred, label='Predictions', color='red', linestyle='dashed', marker='o')
plt.title('Validation True Values vs Predictions')
plt.xlabel('Sample Index')
plt.ylabel('Value')
plt.legend()
plt.show()
# Out:
# 2/2 [==============================] - 0s 8ms/step

# %%
# Generate predictions for the validation set
Y_val_pred = model.predict(X_val)
Y_val_pred = np.where(Y_val_pred > 0.5, 1,np.where(Y_val_pred<-0.5, -1, 0) )

# Plot the true values and predictions
plt.figure(figsize=(10, 6))
plt.plot(Y_val, label='True Values', color='blue', marker='o')
plt.plot(Y_val_pred, label='Predictions', color='red', linestyle='dashed', marker='o')
plt.title('Validation True Values vs Predictions')
plt.xlabel('Sample Index')
plt.ylabel('Value')
plt.legend()
plt.show()
# Out:
# 2/2 [==============================] - 0s 8ms/step

# %%
# import matplotlib.pyplot as plt
# import numpy as np

# # Generate predictions for the validation set
# Y_val_pred = model.predict(X_val)
# Y_val_pred = np.where(Y_val_pred > 0.5, 1, np.where(Y_val_pred < -0.5, -1, 0))

# # Plot
# plt.figure(figsize=(12, 6))

# # Add soft gray vertical lines for each sample
# for i in range(len(Y_val)):
#     plt.axvline(x=i, color='gray', linestyle='-', linewidth=0.5, alpha=0.3)

# # Plot true values and predictions as scatter
# plt.scatter(range(len(Y_val)), Y_val, label='True Values', color='blue', marker='o')
# plt.scatter(range(len(Y_val_pred)), Y_val_pred, label='Predictions', color='red', marker='o')

# # Styling
# plt.title('Validation True Values vs Predictions')
# plt.xlabel('Sample Index')
# plt.ylabel('Value')
# plt.legend()
# plt.grid(False)  # Remove default grid
# plt.tight_layout()
# plt.show()

# %%
# from sklearn.metrics import confusion_matrix

# # Create confusion matrix
# conf_matrix = confusion_matrix(Y_val.flatten(), Y_val_pred.flatten())

# # Print the confusion matrix
# print("Confusion Matrix:")
# print(conf_matrix)

# %%
# # Calculate total accuracy
# total_accuracy = np.sum(Y_val.flatten() == Y_val_pred.flatten()) / len(Y_val)
# print(f"Total Accuracy: {total_accuracy * 100:.2f}%")

# %%
# # Generate predictions for the validation set
# Y_val_pred = model.predict(X_test_filtered)
# Y_val_pred = np.where(Y_val_pred > 0.42, 1, -1)

# # Plot the true values and predictions
# plt.figure(figsize=(10, 6))
# plt.plot(Y_test_filtered, label='True Values', color='blue', marker='o')
# plt.plot(Y_val_pred, label='Predictions', color='red', linestyle='dashed', marker='o')
# plt.title('Validation True Values vs Predictions')
# plt.xlabel('Sample Index')
# plt.ylabel('Value')
# plt.legend()
# plt.show()

# %%
# import matplotlib.pyplot as plt
# import numpy as np

# # Generate predictions for the validation set
# Y_val_pred = model.predict(X_test_filtered)
# Y_val_pred = np.where(Y_val_pred > 0.2, 1, -1)

# # Plot the true values and predictions
# plt.figure(figsize=(12, 6))

# # Add soft gray vertical lines for each sample index
# for i in range(len(Y_test_filtered)):
#     plt.axvline(x=i, color='gray', linestyle='-', linewidth=0.5, alpha=0.7)

# # Plot using scatter (no connecting lines)
# plt.scatter(range(len(Y_test_filtered)), Y_test_filtered, label='True Values', color='blue', marker='o')
# plt.scatter(range(len(Y_val_pred)), Y_val_pred, label='Predictions', color='red', marker='o')

# # Labels and title
# plt.title('Validation True Values vs Predictions')
# plt.xlabel('Sample Index')
# plt.ylabel('Value')
# plt.legend()
# plt.grid(False)
# plt.tight_layout()
# plt.show()

# %%
# import matplotlib.pyplot as plt
# import numpy as np

# # Generate predictions for the validation set
# Y_val_pred = model.predict(X_test_filtered)
# Y_val_pred = np.where(Y_val_pred > 0.42, 1, -1)

# # Flatten if needed
# Y_val_pred = Y_val_pred.flatten()
# Y_test_filtered = Y_test_filtered.flatten()

# # Prepare index and classification of correctness
# indices = np.arange(len(Y_test_filtered))
# correct = Y_val_pred == Y_test_filtered
# incorrect = ~correct

# # Plot the figure
# plt.figure(figsize=(12, 6))

# # Add vertical gray lines
# for i in range(len(Y_test_filtered)):
#     plt.axvline(x=i, color='gray', linestyle='-', linewidth=0.7, alpha=0.7)

# # Plot true values as reference shadow
# # plt.scatter(indices, Y_test_filtered, color='blue', label='True Value (Reference)', marker='o', alpha=0.3)

# # Plot correct predictions (overlapping with true values)
# plt.scatter(indices[correct], Y_val_pred[correct], color='blue', marker='o', label='Correct Prediction')

# # Plot incorrect predictions
# plt.scatter(indices[incorrect], Y_val_pred[incorrect], color='red', marker='o', label='Incorrect Prediction')

# # Labels and title
# plt.title('Testing True Values vs Predictions')
# plt.xlabel('Sample Index')
# plt.ylabel('Value')
# plt.legend()
# plt.grid(False)
# plt.tight_layout()
# plt.show()

# %%
# from sklearn.metrics import confusion_matrix

# # Create confusion matrix
# conf_matrix = confusion_matrix(Y_test_filtered.flatten(), Y_val_pred.flatten())

# # Print the confusion matrix
# print("Confusion Matrix:")
# print(conf_matrix)

# %%
# # Calculate total accuracy
# total_accuracy = np.sum(Y_test_filtered.flatten() == Y_val_pred.flatten()) / len(Y_test_filtered)
# print(f"Total Accuracy: {total_accuracy * 100:.2f}%")
