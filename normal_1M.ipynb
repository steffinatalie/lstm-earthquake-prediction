# %%
import numpy as np
import matplotlib.pyplot as plt
import math
from collections import Counter
import pandas as pd

# %%
bali = pd.read_csv('bali_min4.csv')
jabar = pd.read_csv('jawabarat_min4.csv')
# df = pd.concat([bali, jabar], axis=0)
jatengjatim = pd.read_csv('jatengjatim_min4.csv')
# df = pd.concat([bali, jatengjatim], axis=0)
# df = pd.concat([jabar, jatengjatim], axis=0)
df = pd.concat([bali, jabar, jatengjatim], axis=0)
# df = pd.read_csv('southern_california_min25.csv')
df['timestamp'] = pd.to_datetime(df['time'], errors='coerce', utc=False)
df['Datetime'] = df['timestamp']
df.set_index('timestamp', inplace=True)
df = df.sort_index(ascending=True)
df
# Out:
#                                                       time  latitude  \
# timestamp
# 1995-01-01 02:02:25.490000+00:00  1995-01-01T02:02:25.490Z  -10.9270
# 1995-01-07 15:02:59.810000+00:00  1995-01-07T15:02:59.810Z   -9.0250
# 1995-01-07 18:37:28.920000+00:00  1995-01-07T18:37:28.920Z   -9.2310
# 1995-01-19 09:19:57.180000+00:00  1995-01-19T09:19:57.180Z  -10.7640
# 1995-02-16 16:27:25.400000+00:00  1995-02-16T16:27:25.400Z  -10.0560
# ...                                                    ...       ...
# 2020-12-20 15:16:45.796000+00:00  2020-12-20T15:16:45.796Z   -9.2506
# 2020-12-20 15:53:57.395000+00:00  2020-12-20T15:53:57.395Z   -9.2936
# 2020-12-22 03:27:21.031000+00:00  2020-12-22T03:27:21.031Z   -9.5505
# 2020-12-24 22:09:10.232000+00:00  2020-12-24T22:09:10.232Z   -9.0282
# 2020-12-26 18:23:21.550000+00:00  2020-12-26T18:23:21.550Z   -9.0928
#
#                                   longitude   depth  mag magType  nst    gap  \
# timestamp
# 1995-01-01 02:02:25.490000+00:00   113.0110   18.90  4.5      mb  NaN    NaN
# 1995-01-07 15:02:59.810000+00:00   110.7550  114.80  4.7      mb  NaN    NaN
# 1995-01-07 18:37:28.920000+00:00   117.1110   33.00  4.2      mb  NaN    NaN
# 1995-01-19 09:19:57.180000+00:00   117.1200   33.00  4.9      mb  NaN    NaN
# 1995-02-16 16:27:25.400000+00:00   113.8580   33.00  4.0      mb  NaN    NaN
# ...                                     ...     ...  ...     ...  ...    ...
# 2020-12-20 15:16:45.796000+00:00   110.8510   35.00  4.2      mb  NaN  148.0
# 2020-12-20 15:53:57.395000+00:00   112.1503   35.00  4.3      mb  NaN   53.0
# 2020-12-22 03:27:21.031000+00:00   112.5698   35.00  4.1      mb  NaN  120.0
# 2020-12-24 22:09:10.232000+00:00   117.3729  104.10  4.4      mb  NaN   95.0
# 2020-12-26 18:23:21.550000+00:00   117.1835   63.84  4.1      mb  NaN   71.0
#
#                                    dmin   rms  ...  \
# timestamp                                      ...
# 1995-01-01 02:02:25.490000+00:00    NaN  1.20  ...
# 1995-01-07 15:02:59.810000+00:00    NaN  0.80  ...
# 1995-01-07 18:37:28.920000+00:00    NaN  0.90  ...
# 1995-01-19 09:19:57.180000+00:00    NaN  1.30  ...
# 1995-02-16 16:27:25.400000+00:00    NaN  0.40  ...
# ...                                 ...   ...  ...
# 2020-12-20 15:16:45.796000+00:00  1.368  0.58  ...
# 2020-12-20 15:53:57.395000+00:00  2.114  0.90  ...
# 2020-12-22 03:27:21.031000+00:00  1.896  0.94  ...
# 2020-12-24 22:09:10.232000+00:00  3.231  0.54  ...
# 2020-12-26 18:23:21.550000+00:00  3.059  0.62  ...
#
#                                                                   place  \
# timestamp
# 1995-01-01 02:02:25.490000+00:00         294 km S of Kencong, Indonesia
# 1995-01-07 15:02:59.810000+00:00       126 km SSE of Pundong, Indonesia
# 1995-01-07 18:37:28.920000+00:00  88 km SSW of Sumbawa Besar, Indonesia
# 1995-01-19 09:19:57.180000+00:00         246 km SSE of Praya, Indonesia
# 1995-02-16 16:27:25.400000+00:00   186 km S of Gambiran Satu, Indonesia
# ...                                                                 ...
# 2020-12-20 15:16:45.796000+00:00       153 km SSE of Pundong, Indonesia
# 2020-12-20 15:53:57.395000+00:00  130 km SSW of Sumberpucung, Indonesia
# 2020-12-22 03:27:21.031000+00:00          149 km S of Dampit, Indonesia
# 2020-12-24 22:09:10.232000+00:00    59 km S of Sumbawa Besar, Indonesia
# 2020-12-26 18:23:21.550000+00:00  71 km SSW of Sumbawa Besar, Indonesia
#
#                                         type horizontalError depthError  \
# timestamp
# 1995-01-01 02:02:25.490000+00:00  earthquake             NaN        8.5
# 1995-01-07 15:02:59.810000+00:00  earthquake             NaN       21.5
# 1995-01-07 18:37:28.920000+00:00  earthquake             NaN        NaN
# 1995-01-19 09:19:57.180000+00:00  earthquake             NaN        NaN
# 1995-02-16 16:27:25.400000+00:00  earthquake             NaN        NaN
# ...                                      ...             ...        ...
# 2020-12-20 15:16:45.796000+00:00  earthquake             8.9        1.9
# 2020-12-20 15:53:57.395000+00:00  earthquake             5.3        2.0
# 2020-12-22 03:27:21.031000+00:00  earthquake             5.6        1.9
# 2020-12-24 22:09:10.232000+00:00  earthquake             7.6        8.3
# 2020-12-26 18:23:21.550000+00:00  earthquake             7.1        8.5
#
#                                  magError  magNst    status  locationSource  \
# timestamp
# 1995-01-01 02:02:25.490000+00:00      NaN     4.0  reviewed              us
# 1995-01-07 15:02:59.810000+00:00      NaN    12.0  reviewed              us
# 1995-01-07 18:37:28.920000+00:00      NaN     5.0  reviewed              us
# 1995-01-19 09:19:57.180000+00:00      NaN     8.0  reviewed              us
# 1995-02-16 16:27:25.400000+00:00      NaN     5.0  reviewed              us
# ...                                   ...     ...       ...             ...
# 2020-12-20 15:16:45.796000+00:00    0.186     8.0  reviewed              us
# 2020-12-20 15:53:57.395000+00:00    0.142    14.0  reviewed              us
# 2020-12-22 03:27:21.031000+00:00    0.175     9.0  reviewed              us
# 2020-12-24 22:09:10.232000+00:00    0.134    16.0  reviewed              us
# 2020-12-26 18:23:21.550000+00:00    0.165    13.0  reviewed              us
#
#                                   magSource                         Datetime
# timestamp
# 1995-01-01 02:02:25.490000+00:00         us 1995-01-01 02:02:25.490000+00:00
# 1995-01-07 15:02:59.810000+00:00         us 1995-01-07 15:02:59.810000+00:00
# 1995-01-07 18:37:28.920000+00:00         us 1995-01-07 18:37:28.920000+00:00
# 1995-01-19 09:19:57.180000+00:00         us 1995-01-19 09:19:57.180000+00:00
# 1995-02-16 16:27:25.400000+00:00         us 1995-02-16 16:27:25.400000+00:00
# ...                                     ...                              ...
# 2020-12-20 15:16:45.796000+00:00         us 2020-12-20 15:16:45.796000+00:00
# 2020-12-20 15:53:57.395000+00:00         us 2020-12-20 15:53:57.395000+00:00
# 2020-12-22 03:27:21.031000+00:00         us 2020-12-22 03:27:21.031000+00:00
# 2020-12-24 22:09:10.232000+00:00         us 2020-12-24 22:09:10.232000+00:00
# 2020-12-26 18:23:21.550000+00:00         us 2020-12-26 18:23:21.550000+00:00
#
# [1698 rows x 23 columns]

# %%
df = df[['depth', 'mag']]
df
# Out:
#                                    depth  mag
# timestamp
# 1995-01-01 02:02:25.490000+00:00   18.90  4.5
# 1995-01-07 15:02:59.810000+00:00  114.80  4.7
# 1995-01-07 18:37:28.920000+00:00   33.00  4.2
# 1995-01-19 09:19:57.180000+00:00   33.00  4.9
# 1995-02-16 16:27:25.400000+00:00   33.00  4.0
# ...                                  ...  ...
# 2020-12-20 15:16:45.796000+00:00   35.00  4.2
# 2020-12-20 15:53:57.395000+00:00   35.00  4.3
# 2020-12-22 03:27:21.031000+00:00   35.00  4.1
# 2020-12-24 22:09:10.232000+00:00  104.10  4.4
# 2020-12-26 18:23:21.550000+00:00   63.84  4.1
#
# [1698 rows x 2 columns]

# %%
print(df.isna().sum())
# Out:
# depth    0
# mag      0
# dtype: int64

# %%
mag_unique, frequency = np.unique(df['mag'], return_counts=True)

plt.figure(figsize=(10,8))
plt.hist(df['mag'], bins=1000, color='black', edgecolor='black')

bins = [0, 20, 40, 60]

from matplotlib.ticker import MultipleLocator
# Set x-axis scale to increment by 0.5
plt.gca().xaxis.set_major_locator(MultipleLocator(0.2))
# Add titles and labels
plt.title('Frequency by Magnitude')
plt.xlabel('Magnitude')
plt.ylabel('Frequency')
plt.xticks(fontsize=12, fontname='Times New Roman', rotation=45)

# Show the plot
plt.show()

# %%
mag_filter = 4.5
depth_filter = 100
resample_rate = '1M'

# %%
# def occurence_criterion(raw_array):
#     print(raw_array)
#     print("---------------------")
#     target = -1
#     if len(raw_array) > 0:
#         if raw_array['earthquake'].eq(1).any():
#             target = 1
#         if raw_array['earthquake'].eq(0).any():
#             target = 0
#     if len(raw_array) == 0:
#         target = 0

        
#     return target

# earthquake_occurence = df.resample(resample_rate).apply(occurence_criterion)

# earthquake_occurence = earthquake_occurence.to_frame(name='earthquake')

# earthquake_occurence = earthquake_occurence.sort_index(ascending=True)
# earthquake_occurence['earthquake'].value_counts()

# %%
# Initialize the 'ED' column with NaN values
df['ED'] = np.nan

# Filter the dataframe for earthquakes with magnitude greater than mag_filter
filtered_df = df[df['mag'] > mag_filter]

n = 50

# Calculate the elapsed days for the last n earthquake events
for i in range(n, len(filtered_df)):
    current_time = filtered_df.index[i]
    past_time = filtered_df.index[i-n]
    elapsed_days = (current_time - past_time).days
    df.loc[current_time, 'ED'] = elapsed_days

# Fill NaN values in 'ED' column
for i in range(len(df)):
    if pd.isna(df.iloc[i]['ED']):
        # Find the latest valid 'ED' value before the current index
        last_valid_index = df.iloc[:i]['ED'].last_valid_index()
        if last_valid_index is not None:
            time_since_last_valid = (df.index[i] - last_valid_index).days
            df.at[df.index[i], 'ED'] = df.at[last_valid_index, 'ED'] + time_since_last_valid

# df = df.dropna(subset=['ED'])
df
# Out:
# C:\Users\SteinSteffi1\AppData\Local\Temp\ipykernel_16380\388928700.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['ED'] = np.nan
#                                    depth  mag     ED
# timestamp
# 1995-01-01 02:02:25.490000+00:00   18.90  4.5    NaN
# 1995-01-07 15:02:59.810000+00:00  114.80  4.7    NaN
# 1995-01-07 18:37:28.920000+00:00   33.00  4.2    NaN
# 1995-01-19 09:19:57.180000+00:00   33.00  4.9    NaN
# 1995-02-16 16:27:25.400000+00:00   33.00  4.0    NaN
# ...                                  ...  ...    ...
# 2020-12-20 15:16:45.796000+00:00   35.00  4.2  875.0
# 2020-12-20 15:53:57.395000+00:00   35.00  4.3  875.0
# 2020-12-22 03:27:21.031000+00:00   35.00  4.1  876.0
# 2020-12-24 22:09:10.232000+00:00  104.10  4.4  878.0
# 2020-12-26 18:23:21.550000+00:00   63.84  4.1  879.0
#
# [1698 rows x 3 columns]

# %%
# Initialize the 'energy_squared' and 'cumulative_energy_squared' columns with NaN values
df['energy_squared_root'] = np.nan
df['cumulative_energy_squared'] = np.nan

df['energy'] = 10**(11.8+1.5*df['mag'])

# Calculate the energy squared for each data point
df['energy_squared_root'] = np.sqrt(df['energy'])

# Calculate the cumulative sum of energy squared for the last 50 data points
# for i in range(n, len(df)):
#     df.iloc[i, df.columns.get_loc('cumulative_energy_squared')] = df.iloc[i-n:i]['energy_squared_root'].sum()

df['cumulative_energy_squared'] = df['energy_squared_root'].rolling(n).sum()

# Calculate the RSRER
df['RSRER'] = df['cumulative_energy_squared'] / df['ED']

df['mean_mag'] = df['mag'].rolling(n).mean()
df['min_mag'] = df['mag'].rolling(n).min()
df['b_value'] = np.log10(np.e)/(df['mean_mag'] - df['min_mag'])

df['event_counts'] = df['mag'].rolling(n).apply(lambda x: (x > mag_filter).sum(), raw=True)
df['a_value'] = (np.log10(df['event_counts']) + df['b_value']*df['min_mag'])/n
# df['MSD'] = np.sum((np.log10(df['event_counts'])-(df['a_value']-(df['b_value']*df['mag'])))**2)/(n-1)
df['max_mag'] = df['mag'].rolling(n).max()
df['MD'] = df['a_value']/df['b_value'] - df['max_mag']
# print(df['event_counts'])

df
# Out:
# C:\Users\SteinSteffi1\AppData\Local\Temp\ipykernel_16380\2738765218.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['energy_squared_root'] = np.nan
# C:\Users\SteinSteffi1\AppData\Local\Temp\ipykernel_16380\2738765218.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['cumulative_energy_squared'] = np.nan
# C:\Users\SteinSteffi1\AppData\Local\Temp\ipykernel_16380\2738765218.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['energy'] = 10**(11.8+1.5*df['mag'])
# C:\Users\SteinSteffi1\AppData\Local\Temp\ipykernel_16380\2738765218.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['energy_squared_root'] = np.sqrt(df['energy'])
# C:\Users\SteinSteffi1\AppData\Local\Temp\ipykernel_16380\2738765218.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['cumulative_energy_squared'] = df['energy_squared_root'].rolling(n).sum()
# C:\Users\SteinSteffi1\AppData\Local\Temp\ipykernel_16380\2738765218.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['RSRER'] = df['cumulative_energy_squared'] / df['ED']
# C:\Users\SteinSteffi1\AppData\Local\Temp\ipykernel_16380\2738765218.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['mean_mag'] = df['mag'].rolling(n).mean()
# C:\Users\SteinSteffi1\AppData\Local\Temp\ipykernel_16380\2738765218.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['min_mag'] = df['mag'].rolling(n).min()
# C:\Users\SteinSteffi1\AppData\Local\Temp\ipykernel_16380\2738765218.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['b_value'] = np.log10(np.e)/(df['mean_mag'] - df['min_mag'])
# C:\Users\SteinSteffi1\AppData\Local\Temp\ipykernel_16380\2738765218.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['event_counts'] = df['mag'].rolling(n).apply(lambda x: (x > mag_filter).sum(), raw=True)
# C:\Users\SteinSteffi1\AppData\Local\Temp\ipykernel_16380\2738765218.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['a_value'] = (np.log10(df['event_counts']) + df['b_value']*df['min_mag'])/n
# C:\Users\SteinSteffi1\AppData\Local\Temp\ipykernel_16380\2738765218.py:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['max_mag'] = df['mag'].rolling(n).max()
# C:\Users\SteinSteffi1\AppData\Local\Temp\ipykernel_16380\2738765218.py:27: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['MD'] = df['a_value']/df['b_value'] - df['max_mag']
#                                    depth  mag     ED  energy_squared_root  \
# timestamp
# 1995-01-01 02:02:25.490000+00:00   18.90  4.5    NaN         1.883649e+09
# 1995-01-07 15:02:59.810000+00:00  114.80  4.7    NaN         2.660725e+09
# 1995-01-07 18:37:28.920000+00:00   33.00  4.2    NaN         1.122018e+09
# 1995-01-19 09:19:57.180000+00:00   33.00  4.9    NaN         3.758374e+09
# 1995-02-16 16:27:25.400000+00:00   33.00  4.0    NaN         7.943282e+08
# ...                                  ...  ...    ...                  ...
# 2020-12-20 15:16:45.796000+00:00   35.00  4.2  875.0         1.122018e+09
# 2020-12-20 15:53:57.395000+00:00   35.00  4.3  875.0         1.333521e+09
# 2020-12-22 03:27:21.031000+00:00   35.00  4.1  876.0         9.440609e+08
# 2020-12-24 22:09:10.232000+00:00  104.10  4.4  878.0         1.584893e+09
# 2020-12-26 18:23:21.550000+00:00   63.84  4.1  879.0         9.440609e+08
#
#                                   cumulative_energy_squared        energy  \
# timestamp
# 1995-01-01 02:02:25.490000+00:00                        NaN  3.548134e+18
# 1995-01-07 15:02:59.810000+00:00                        NaN  7.079458e+18
# 1995-01-07 18:37:28.920000+00:00                        NaN  1.258925e+18
# 1995-01-19 09:19:57.180000+00:00                        NaN  1.412538e+19
# 1995-02-16 16:27:25.400000+00:00                        NaN  6.309573e+17
# ...                                                     ...           ...
# 2020-12-20 15:16:45.796000+00:00               9.353097e+10  1.258925e+18
# 2020-12-20 15:53:57.395000+00:00               9.353097e+10  1.778279e+18
# 2020-12-22 03:27:21.031000+00:00               9.259138e+10  8.912509e+17
# 2020-12-24 22:09:10.232000+00:00               9.259138e+10  2.511886e+18
# 2020-12-26 18:23:21.550000+00:00               9.220192e+10  8.912509e+17
#
#                                          RSRER  mean_mag  min_mag   b_value  \
# timestamp
# 1995-01-01 02:02:25.490000+00:00           NaN       NaN      NaN       NaN
# 1995-01-07 15:02:59.810000+00:00           NaN       NaN      NaN       NaN
# 1995-01-07 18:37:28.920000+00:00           NaN       NaN      NaN       NaN
# 1995-01-19 09:19:57.180000+00:00           NaN       NaN      NaN       NaN
# 1995-02-16 16:27:25.400000+00:00           NaN       NaN      NaN       NaN
# ...                                        ...       ...      ...       ...
# 2020-12-20 15:16:45.796000+00:00  1.068925e+08     4.430      4.0  1.009987
# 2020-12-20 15:53:57.395000+00:00  1.068925e+08     4.430      4.0  1.009987
# 2020-12-22 03:27:21.031000+00:00  1.056979e+08     4.422      4.0  1.029134
# 2020-12-24 22:09:10.232000+00:00  1.054572e+08     4.422      4.0  1.029134
# 2020-12-26 18:23:21.550000+00:00  1.048941e+08     4.418      4.0  1.038982
#
#                                   event_counts   a_value  max_mag        MD
# timestamp
# 1995-01-01 02:02:25.490000+00:00           NaN       NaN      NaN       NaN
# 1995-01-07 15:02:59.810000+00:00           NaN       NaN      NaN       NaN
# 1995-01-07 18:37:28.920000+00:00           NaN       NaN      NaN       NaN
# 1995-01-19 09:19:57.180000+00:00           NaN       NaN      NaN       NaN
# 1995-02-16 16:27:25.400000+00:00           NaN       NaN      NaN       NaN
# ...                                        ...       ...      ...       ...
# 2020-12-20 15:16:45.796000+00:00          13.0  0.103078      5.2 -5.097941
# 2020-12-20 15:53:57.395000+00:00          13.0  0.103078      5.2 -5.097941
# 2020-12-22 03:27:21.031000+00:00          13.0  0.104610      5.2 -5.098352
# 2020-12-24 22:09:10.232000+00:00          13.0  0.104610      5.2 -5.098352
# 2020-12-26 18:23:21.550000+00:00          13.0  0.105397      5.2 -5.098557
#
# [1698 rows x 14 columns]

# %%
# Drop the intermediate columns
df.drop(columns=['energy_squared_root', 'cumulative_energy_squared', 'mean_mag', 'min_mag', 'event_counts', 'a_value', 'max_mag'], inplace=True)
# Out:
# C:\Users\SteinSteffi1\AppData\Local\Temp\ipykernel_16380\1093842324.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.drop(columns=['energy_squared_root', 'cumulative_energy_squared', 'mean_mag', 'min_mag', 'event_counts', 'a_value', 'max_mag'], inplace=True)

# %%
df.dropna(subset=['RSRER'], inplace=True)
df.isna().sum()
# Out:
# C:\Users\SteinSteffi1\AppData\Local\Temp\ipykernel_16380\2534608267.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.dropna(subset=['RSRER'], inplace=True)
# depth      0
# mag        0
# ED         0
# energy     0
# RSRER      0
# b_value    0
# MD         0
# dtype: int64

# %%
df['earthquake'] = np.where((df['mag'] > mag_filter) & (df['depth'] < depth_filter), 1,  0) 

df['earthquake'].value_counts()
# Out:
# C:\Users\SteinSteffi1\AppData\Local\Temp\ipykernel_16380\3861059285.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['earthquake'] = np.where((df['mag'] > mag_filter) & (df['depth'] < depth_filter), 1,  0)
# earthquake
# 0    848
# 1    673
# Name: count, dtype: int64

# %%
def occurence_criterion(raw_array):
    # print(raw_array)
    # print("---------------------")
    target = 0
    if len(raw_array) > 0:
        if raw_array['earthquake'].eq(1).any():
            target = 1
        if raw_array['earthquake'].eq(0).all():
            target = 0
    # if len(raw_array) == 0:
    #     target = 0

        
    return target


earthquake_occurence = df[['earthquake']].resample(resample_rate).apply(occurence_criterion)
print(earthquake_occurence.value_counts())
monthly_df = df.resample(resample_rate).mean()
# monthly_df = monthly_df.fillna(0)
monthly_df = monthly_df.dropna()
monthly_df['earthquake'] = earthquake_occurence
print(monthly_df)
# Out:
# C:\Users\SteinSteffi1\AppData\Local\Temp\ipykernel_16380\404483629.py:17: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   earthquake_occurence = df[['earthquake']].resample(resample_rate).apply(occurence_criterion)
# 1    189
# 0     58
# Name: count, dtype: int64
#                                depth       mag           ED        energy  \
# timestamp
# 2000-06-30 00:00:00+00:00  42.400000  4.466667  1976.333333  3.760890e+18
# 2000-07-31 00:00:00+00:00  61.000000  4.300000  1911.666667  2.473703e+18
# 2000-08-31 00:00:00+00:00  69.166667  4.733333  1802.666667  8.052972e+18
# 2000-09-30 00:00:00+00:00  33.000000  4.800000  1720.000000  1.000000e+19
# 2000-10-31 00:00:00+00:00  33.000000  4.400000  1708.666667  5.511537e+18
# ...                              ...       ...          ...           ...
# 2020-07-31 00:00:00+00:00  41.480000  4.475000   793.250000  4.512269e+18
# 2020-08-31 00:00:00+00:00  29.616667  4.683333   769.500000  1.302972e+19
# 2020-09-30 00:00:00+00:00  38.920000  4.500000   783.250000  5.029166e+18
# 2020-10-31 00:00:00+00:00  39.796667  4.400000   813.666667  3.848987e+18
# 2020-12-31 00:00:00+00:00  48.049091  4.281818   870.909091  2.118022e+18
#
#                                   RSRER   b_value        MD  earthquake
# timestamp
# 2000-06-30 00:00:00+00:00  6.731465e+07  0.787837 -5.686084           1
# 2000-07-31 00:00:00+00:00  6.605044e+07  0.806484 -5.686699           1
# 2000-08-31 00:00:00+00:00  6.976356e+07  0.789647 -5.685196           1
# 2000-09-30 00:00:00+00:00  7.443554e+07  0.770026 -5.683691           1
# 2000-10-31 00:00:00+00:00  7.245997e+07  0.802452 -5.685743           1
# ...                                 ...       ...       ...         ...
# 2020-07-31 00:00:00+00:00  1.226671e+08  0.959921 -4.870344           1
# 2020-08-31 00:00:00+00:00  1.229447e+08  0.996355 -4.929817           1
# 2020-09-30 00:00:00+00:00  1.258752e+08  0.961991 -5.095252           1
# 2020-10-31 00:00:00+00:00  1.249103e+08  0.928547 -5.093374           1
# 2020-12-31 00:00:00+00:00  1.102451e+08  0.984145 -5.096561           1
#
# [236 rows x 8 columns]
# C:\Users\SteinSteffi1\AppData\Local\Temp\ipykernel_16380\404483629.py:19: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   monthly_df = df.resample(resample_rate).mean()

# %%
df = monthly_df[['depth', 'mag', 'ED', 'RSRER', 'b_value', 'MD', 'earthquake']]
# df = monthly_df[['mag', 'ED','MD', 'earthquake']]
df
# Out:
#                                depth       mag           ED         RSRER  \
# timestamp
# 2000-06-30 00:00:00+00:00  42.400000  4.466667  1976.333333  6.731465e+07
# 2000-07-31 00:00:00+00:00  61.000000  4.300000  1911.666667  6.605044e+07
# 2000-08-31 00:00:00+00:00  69.166667  4.733333  1802.666667  6.976356e+07
# 2000-09-30 00:00:00+00:00  33.000000  4.800000  1720.000000  7.443554e+07
# 2000-10-31 00:00:00+00:00  33.000000  4.400000  1708.666667  7.245997e+07
# ...                              ...       ...          ...           ...
# 2020-07-31 00:00:00+00:00  41.480000  4.475000   793.250000  1.226671e+08
# 2020-08-31 00:00:00+00:00  29.616667  4.683333   769.500000  1.229447e+08
# 2020-09-30 00:00:00+00:00  38.920000  4.500000   783.250000  1.258752e+08
# 2020-10-31 00:00:00+00:00  39.796667  4.400000   813.666667  1.249103e+08
# 2020-12-31 00:00:00+00:00  48.049091  4.281818   870.909091  1.102451e+08
#
#                             b_value        MD  earthquake
# timestamp
# 2000-06-30 00:00:00+00:00  0.787837 -5.686084           1
# 2000-07-31 00:00:00+00:00  0.806484 -5.686699           1
# 2000-08-31 00:00:00+00:00  0.789647 -5.685196           1
# 2000-09-30 00:00:00+00:00  0.770026 -5.683691           1
# 2000-10-31 00:00:00+00:00  0.802452 -5.685743           1
# ...                             ...       ...         ...
# 2020-07-31 00:00:00+00:00  0.959921 -4.870344           1
# 2020-08-31 00:00:00+00:00  0.996355 -4.929817           1
# 2020-09-30 00:00:00+00:00  0.961991 -5.095252           1
# 2020-10-31 00:00:00+00:00  0.928547 -5.093374           1
# 2020-12-31 00:00:00+00:00  0.984145 -5.096561           1
#
# [236 rows x 7 columns]

# %%
correlation_matrix = df.corr()
correlation_matrix
# Out:
#                depth       mag        ED     RSRER   b_value        MD  \
# depth       1.000000 -0.198931  0.167325 -0.256542  0.237642 -0.001971
# mag        -0.198931  1.000000  0.052948  0.059047 -0.261769 -0.187194
# ED          0.167325  0.052948  1.000000 -0.368020 -0.178110 -0.137300
# RSRER      -0.256542  0.059047 -0.368020  1.000000 -0.158173  0.000729
# b_value     0.237642 -0.261769 -0.178110 -0.158173  1.000000  0.568635
# MD         -0.001971 -0.187194 -0.137300  0.000729  0.568635  1.000000
# earthquake -0.237962  0.536719 -0.074258  0.076379 -0.102987 -0.063872
#
#             earthquake
# depth        -0.237962
# mag           0.536719
# ED           -0.074258
# RSRER         0.076379
# b_value      -0.102987
# MD           -0.063872
# earthquake    1.000000

# %%
# Replace infinite values with a large number
df.replace([np.inf, -np.inf], 1e10, inplace=True)
# Out:
# C:\Users\SteinSteffi1\AppData\Local\Temp\ipykernel_16380\2297783001.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.replace([np.inf, -np.inf], 1e10, inplace=True)

# %%
from sklearn.preprocessing import MinMaxScaler

# Initialize the MinMaxScaler with the desired feature range
scaler = MinMaxScaler(feature_range=(-1, 1))

# Apply the scaler to the first 6 columns of the dataframe
df.iloc[:, :6] = scaler.fit_transform(df.iloc[:, :6])

# Display the dataframe
df
# Out:
#                               depth       mag        ED     RSRER   b_value  \
# timestamp
# 2000-06-30 00:00:00+00:00 -0.227099 -0.333333  1.000000 -0.999711 -0.626768
# 2000-07-31 00:00:00+00:00  0.216603 -0.571429  0.933845 -0.999965 -0.583338
# 2000-08-31 00:00:00+00:00  0.411419  0.047619  0.822337 -0.999218 -0.622552
# 2000-09-30 00:00:00+00:00 -0.451336  0.142857  0.737768 -0.998277 -0.668254
# 2000-10-31 00:00:00+00:00 -0.451336 -0.428571  0.726174 -0.998675 -0.592727
# ...                             ...       ...       ...       ...       ...
# 2020-07-31 00:00:00+00:00 -0.249046 -0.321429 -0.210307 -0.988567 -0.225960
# 2020-08-31 00:00:00+00:00 -0.532045 -0.023810 -0.234604 -0.988511 -0.141100
# 2020-09-30 00:00:00+00:00 -0.310115 -0.285714 -0.220537 -0.987921 -0.221140
# 2020-10-31 00:00:00+00:00 -0.289202 -0.428571 -0.189421 -0.988115 -0.299034
# 2020-12-31 00:00:00+00:00 -0.092340 -0.597403 -0.130861 -0.991068 -0.169538
#
#                                  MD  earthquake
# timestamp
# 2000-06-30 00:00:00+00:00  0.008768           1
# 2000-07-31 00:00:00+00:00  0.008078           1
# 2000-08-31 00:00:00+00:00  0.009764           1
# 2000-09-30 00:00:00+00:00  0.011452           1
# 2000-10-31 00:00:00+00:00  0.009150           1
# ...                             ...         ...
# 2020-07-31 00:00:00+00:00  0.923755           1
# 2020-08-31 00:00:00+00:00  0.857046           1
# 2020-09-30 00:00:00+00:00  0.671483           1
# 2020-10-31 00:00:00+00:00  0.673590           1
# 2020-12-31 00:00:00+00:00  0.670015           1
#
# [236 rows x 7 columns]

# %%
import numpy as np

def create_lstm_dataset(df, lookback, n_future):
    """
    Creates an LSTM dataset from the given DataFrame.

    Parameters:
    - df: pandas DataFrame containing features.
    - lookback: Number of past timesteps to include in each X sample.

    Returns:
    - X: 3D NumPy array of shape (samples, lookback, features)
    - Y: 1D NumPy array of shape (samples,)
    """
    data = df.values  # Convert dataframe to NumPy array
    X, Y = [], []
    
    for i in range(len(data) - lookback):
        X.append(data[i:i + lookback, :7])  # First 6 columns
        Y.append(data[(i + lookback):(i + lookback + n_future), -1])     # 7th column as label
    
    return np.array(X), np.array(Y)
look_back = 10
X, Y = create_lstm_dataset(df, lookback=look_back, n_future=1)

print(X.shape)  # (number of samples, lookback, 6)
print(Y.shape)  # (number of samples,)
# Out:
# (226, 10, 7)
# (226, 1)

# %%
from sklearn.model_selection import train_test_split

# Split the data
X_train, X_val, Y_train, Y_val = train_test_split(X, Y, test_size=0.15, shuffle=False)

# Print the shapes of the resulting datasets
print("X_train shape:", X_train.shape)
print("X_val shape:", X_val.shape)
print("Y_train shape:", Y_train.shape)
print("Y_val shape:", Y_val.shape)
# Out:
# X_train shape: (192, 10, 7)
# X_val shape: (34, 10, 7)
# Y_train shape: (192, 1)
# Y_val shape: (34, 1)

# %%
print(X_train[0])
# Out:
# [[-0.22709924 -0.33333333  1.         -0.99971071 -0.626768    0.00876778
#    1.        ]
#  [ 0.21660305 -0.57142857  0.93384529 -0.99996523 -0.58333759  0.00807799
#    1.        ]
#  [ 0.41141858  0.04761905  0.8223371  -0.99921768 -0.62255228  0.00976367
#    1.        ]
#  [-0.45133588  0.14285714  0.7377682  -0.99827708 -0.66825388  0.01145205
#    1.        ]
#  [-0.45133588 -0.42857143  0.72617408 -0.99867482 -0.59272713  0.00915024
#    1.        ]
#  [-0.45133588  0.28571429  0.72446906 -0.99843987 -0.61588885  0.01029669
#    1.        ]
#  [-0.45133588 -0.85714286  0.73060712 -0.99860222 -0.58854266  0.00971901
#    0.        ]
#  [-0.45133588  0.92857143  0.64160517 -0.99669609 -0.66744161  0.01170545
#    1.        ]
#  [-0.45133588  0.07142857  0.60886882 -0.99553842 -0.7530622   0.01473832
#    1.        ]
#  [-0.45133588  0.10714286  0.6063113  -0.99504083 -0.78836512  0.01603344
#    1.        ]]

# %%
# Count occurrences of 0 and 1 in Y_train
unique_train, counts_train = np.unique(Y_train, return_counts=True)
print("Y_train counts:", dict(zip(unique_train, counts_train)))

# Count occurrences of 0 and 1 in Y_val
unique_val, counts_val = np.unique(Y_val, return_counts=True)
print("Y_val counts:", dict(zip(unique_val, counts_val)))
# Out:
# Y_train counts: {0.0: 39, 1.0: 153}
# Y_val counts: {0.0: 7, 1.0: 27}

# %%
# root mean squared error (rmse) for regression (only for Keras tensors)
def rmse(y_true, y_pred):
    from keras import backend
    return backend.sqrt(backend.mean(backend.square(y_pred - y_true), axis=-1))

# mean squared error (mse) for regression  (only for Keras tensors)
def mse(y_true, y_pred):
    from keras import backend
    return backend.mean(backend.square(y_pred - y_true), axis=-1)

# coefficient of determination (R^2) for regression  (only for Keras tensors)
def r_square(y_true, y_pred):
    from keras import backend as K
    SS_res =  K.sum(K.square(y_true - y_pred)) 
    SS_tot = K.sum(K.square(y_true - K.mean(y_true))) 
    return ( 1 - SS_res/(SS_tot + K.epsilon()) )

# %%
# import tensorflow as tf
# from tensorflow.keras.layers import *
# from tensorflow.keras.models import Model
# from tensorflow.keras.layers import Input, LSTM, Dense, Layer, Dropout

# from tensorflow.keras.optimizers.legacy import Adam

# from tensorflow.keras.regularizers import L1L2
# from tensorflow.keras.layers import Layer, Dense, Dot, Activation

# from tensorflow.keras.callbacks import Callback, EarlyStopping

# from tensorflow.keras import backend as K

# from matplotlib import pyplot as plt

# K.clear_session()

   
# l1 = 0.0001
# l2 = 0.0001

# lstm_dropout = 0.2
# recurrent_dropout = 0.1
# dense_dropout = 0.2
# loss = 'mse'

# n_target = Y_train.shape[-2:]

# regularization_criteria = L1L2(l1=l1, l2=l2)

# n_target_y = Y_train.shape[-1]

# def build_model(input_shape):
#     input_layer = Input(shape=input_shape, name='Input_1')
#     sequence = input_layer
#     sequence = LSTM(20, return_sequences = True,  name="LSTM-1", kernel_regularizer = regularization_criteria, dropout=lstm_dropout, recurrent_dropout=recurrent_dropout)(input_layer)
#     sequence = Flatten()(sequence)
#     # sequence = Dropout(dense_dropout)(sequence)
#     # sequence = LSTM(16, return_sequences = False,  name="LSTM-2", kernel_regularizer = regularization_criteria, dropout=lstm_dropout, recurrent_dropout=recurrent_dropout)(sequence)
#     # sequence = Dense(4, activation = 'tanh', name='Dense_3')(sequence)
#     sequence = Dense(n_target_y, activation = 'tanh', name='Dense_4')(sequence)
#     output_layer = sequence

#     model = Model(inputs=input_layer, outputs=output_layer)

#     return model

# input_shape = (look_back, X_train.shape[2])

# learning_rate = 0.0005

# optimizer = Adam(learning_rate=learning_rate)

# model = build_model(input_shape)
# model.compile(optimizer=optimizer, loss=loss, metrics=[mse, rmse, r_square])
# model.summary()

# import time

# start_time = time.time()

# # early_stopping = EarlyStopping(monitor='val_loss', patience=500, restore_best_weights=True)

# history = model.fit(X_train, Y_train, epochs=700, batch_size=64, validation_data=(X_val, Y_val),
#                     # callbacks=[early_stopping]
#                     )

# end_time = time.time()
# difference_in_seconds = end_time - start_time
# print(f"The difference in seconds is: {difference_in_seconds}")

# %%
# import keras_tuner as kt
# import tensorflow as tf
# from tensorflow import keras
# from tensorflow.keras.layers import LSTM, Bidirectional, Dense, Dropout, Flatten

# def build_model(hp):
#     model = keras.Sequential()
    
#     model.add(LSTM(units=hp.Int('lstm_units', min_value=16, max_value=128, step=16),
#                    return_sequences=True,
#                      input_shape=(look_back, X_train.shape[2])))
    
#     # model.add(Dropout(hp.Float('dropout', min_value=0.0, max_value=0.5, step=0.1)))
    
#     # model.add(Bidirectional(LSTM(units=hp.Int('bidirectional_units', min_value=4, max_value=16, step=4),
#     #                              return_sequences=True)))
    
#     # model.add(Bidirectional(LSTM(units=hp.Int('bidirectional_units', min_value=4, max_value=32, step=4),
#     #                              return_sequences=True)))
    
#     model.add(Flatten())
    
#     model.add(Dropout(hp.Float('dropout', min_value=0.0, max_value=0.5, step=0.1)))
    
#     model.add(Dense(hp.Float('dense_units', min_value=0, max_value=32, step=8), activation='tanh'))
    
#     model.add(Dense(1, activation='tanh'))
    
#     model.compile(optimizer=keras.optimizers.Adam(hp.Choice('learning_rate', values=[1e-4, 1e-5])),
#                     loss='mse',
#                     metrics=[rmse, r_square])
    
#     return model

# %%
# import keras_tuner as kt
# import tensorflow as tf
# from tensorflow import keras
# from tensorflow.keras.layers import LSTM, Bidirectional, Dense, Dropout, Flatten, Attention, Input
# from tensorflow.keras.models import Model

# def build_model(hp):
#     inputs = Input(shape=(look_back, X_train.shape[2]))
    
#     lstm_out = LSTM(units=60,
#                     return_sequences=True)(inputs)

    
#     flatten = Flatten()(lstm_out)
    
#     dropout = Dropout(hp.Float('dropout', min_value=0.0, max_value=0.5, step=0.1))(flatten)
    
#     dense = Dense(hp.Int('dense_units', min_value=0, max_value=32, step=4), activation='tanh')(dropout)
    
#     output = Dense(1, activation='tanh')(dense)
    
#     model = Model(inputs=inputs, outputs=output)
    
#     model.compile(optimizer=keras.optimizers.Adam(hp.Choice('learning_rate', values=[1e-4, 1e-5])),
#                   loss='mse',
#                   metrics=[rmse, r_square])
    
#     return model

# %%
# tuner = kt.RandomSearch(build_model,
#                         objective=kt.Objective("val_r_square", direction="max"),
#                         max_trials=20,
#                         executions_per_trial=2,
#                         directory='my_dir',
#                         project_name='earthquake')

# %%
# tuner.search(X_train, Y_train, epochs=150, validation_data=(X_val, Y_val))

# %%
# from tensorflow.keras.callbacks import Callback, EarlyStopping
# best_hps = tuner.get_best_hyperparameters(num_trials=5)[0]

# # print(f"Best LSTM units: {best_hps.get('lstm_units')}")
# # print(f"Best BiLSTM usage: {best_hps.get('bidirectional_units')}")
# print(f"Best Dropout Rate: {best_hps.get('dropout')}")
# print(f"Best Dense Units: {best_hps.get('dense_units')}")
# print(f"Best Learning Rate: {best_hps.get('learning_rate')}")

# # Train the best model
# best_model = tuner.hypermodel.build(best_hps)
# early_stopping = EarlyStopping(monitor='val_loss', patience=700, restore_best_weights=True)
# history = best_model.fit(X_train, Y_train, epochs=1000, validation_data=(X_val, Y_val), callbacks=[early_stopping])

# %%
# # Generate predictions for the training set
# Y_train_pred = best_model.predict(X_train)

# # Plot the true values and predictions
# plt.figure(figsize=(10, 6))
# plt.plot(Y_train, label='True Values', color='blue',  marker='o')
# plt.plot(Y_train_pred, label='Predictions', color='red', linestyle='dashed', marker='o')
# plt.title('Training True Values vs Predictions')
# plt.xlabel('Sample Index')
# plt.ylabel('Value')
# plt.legend()
# plt.show()

# %%
# # Generate predictions for the validation set
# Y_val_pred = best_model.predict(X_val)

# # Plot the true values and predictions
# plt.figure(figsize=(10, 6))
# plt.plot(Y_val, label='True Values', color='blue', marker='o')
# plt.plot(Y_val_pred, label='Predictions', color='red', linestyle='dashed', marker='o')
# plt.title('Validation True Values vs Predictions')
# plt.xlabel('Sample Index')
# plt.ylabel('Value')
# plt.legend()
# plt.show()

# %%
# # Generate predictions for the validation set
# Y_val_pred = best_model.predict(X_val)
# Y_val_pred = np.where(Y_val_pred > 0.5, 1,np.where(Y_val_pred<-0.5, -1, 0) )

# # Plot the true values and predictions
# plt.figure(figsize=(10, 6))
# plt.plot(Y_val, label='True Values', color='blue', marker='o')
# plt.plot(Y_val_pred, label='Predictions', color='red', linestyle='dashed', marker='o')
# plt.title('Validation True Values vs Predictions')
# plt.xlabel('Sample Index')
# plt.ylabel('Value')
# plt.legend()
# plt.show()

# %%
# from sklearn.metrics import confusion_matrix

# # Create confusion matrix
# conf_matrix = confusion_matrix(Y_val.flatten(), Y_val_pred.flatten())

# # Print the confusion matrix
# print("Confusion Matrix:")
# print(conf_matrix)

# %%
# # Calculate total accuracy
# total_accuracy = np.sum(Y_val.flatten() == Y_val_pred.flatten()) / len(Y_val)
# print(f"Total Accuracy: {total_accuracy * 100:.2f}%")

# %%
# Create a mask to filter out values in Y_test that are not equal to 0
mask = Y_val != 0
# print(X_test.shape)
# Apply the mask to filter X_test and Y_test
X_test_filtered = np.array([x for x, m in zip(X_val, mask) if m])
Y_test_filtered = Y_val[mask]

# Print the shapes of the filtered arrays to verify
print(X_test_filtered.shape)
print(Y_test_filtered.shape)
# Out:
# (27, 10, 7)
# (27,)

# %%
# # Generate predictions for the validation set
# Y_val_pred = best_model.predict(X_test_filtered)
# Y_val_pred = np.where(Y_val_pred > 0.15, 1, -1)

# # Plot the true values and predictions
# plt.figure(figsize=(10, 6))
# plt.plot(Y_test_filtered, label='True Values', color='blue', marker='o')
# plt.plot(Y_val_pred, label='Predictions', color='red', linestyle='dashed', marker='o')
# plt.title('Validation True Values vs Predictions')
# plt.xlabel('Sample Index')
# plt.ylabel('Value')
# plt.legend()
# plt.show()

# %%
# from sklearn.metrics import confusion_matrix

# # Create confusion matrix
# conf_matrix = confusion_matrix(Y_test_filtered.flatten(), Y_val_pred.flatten())

# # Print the confusion matrix
# print("Confusion Matrix:")
# print(conf_matrix)

# %%
# # Calculate total accuracy
# total_accuracy = np.sum(Y_test_filtered.flatten() == Y_val_pred.flatten()) / len(Y_test_filtered)
# print(f"Total Accuracy: {total_accuracy * 100:.2f}%")

# %%
import tensorflow as tf
from tensorflow.keras.layers import *
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, LSTM, Dense, Layer, Dropout

from tensorflow.keras.optimizers.legacy import Adam

from tensorflow.keras.regularizers import L1L2
from tensorflow.keras.layers import Layer, Dense, Dot, Activation

from tensorflow.keras.callbacks import Callback, EarlyStopping

from tensorflow.keras import backend as K

from matplotlib import pyplot as plt

K.clear_session()

   
l1 = 0.0
l2 = 0.0

lstm_dropout = 0.0
recurrent_dropout = 0.0
dense_dropout = 0.1
loss = 'mse'

n_target = Y_train.shape[-2:]

regularization_criteria = L1L2(l1=l1, l2=l2)

n_target_y = Y_train.shape[-1]

def build_model(input_shape):
    input_layer = Input(shape=input_shape, name='Input_1')
    sequence = input_layer
    sequence = LSTM(50, return_sequences = True,  name="LSTM-1", kernel_regularizer = regularization_criteria, dropout=lstm_dropout, recurrent_dropout=recurrent_dropout)(input_layer)
    
    sequence = Flatten()(sequence)
    sequence = Dense(20, activation = 'tanh', name='Dense_2')(sequence)
    sequence = Dropout(0.3)(sequence)
    # sequence = LSTM(16, return_sequences = False,  name="LSTM-2", kernel_regularizer = regularization_criteria, dropout=lstm_dropout, recurrent_dropout=recurrent_dropout)(sequence)
    sequence = Dense(10, activation = 'tanh', name='Dense_3')(sequence)
    sequence = Dense(n_target_y, activation = 'sigmoid', name='Dense_4')(sequence)
    output_layer = sequence

    model = Model(inputs=input_layer, outputs=output_layer)

    return model

input_shape = (look_back, X_train.shape[2])

learning_rate = 0.001

optimizer = Adam(learning_rate=learning_rate)

model = build_model(input_shape)
model.compile(optimizer=optimizer, loss=loss, metrics=[mse])
model.summary()

import time

start_time = time.time()

early_stopping = EarlyStopping(monitor='val_loss', patience=700, restore_best_weights=True)

history = model.fit(X_train, Y_train, epochs=1000, batch_size=64, validation_data=(X_val, Y_val),
                    callbacks=[early_stopping]
                    )

end_time = time.time()
difference_in_seconds = end_time - start_time
print(f"The difference in seconds is: {difference_in_seconds}")
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  Input_1 (InputLayer)        [(None, 10, 7)]           0
#
#  LSTM-1 (LSTM)               (None, 10, 50)            11600
#
#  flatten (Flatten)           (None, 500)               0
#
#  Dense_2 (Dense)             (None, 20)                10020
#
#  dropout (Dropout)           (None, 20)                0
#
#  Dense_3 (Dense)             (None, 10)                210
#
#  Dense_4 (Dense)             (None, 1)                 11
#
# =================================================================
# Total params: 21,841
# Trainable params: 21,841
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/1000
# 3/3 [==============================] - 23s 338ms/step - loss: 0.2359 - mse: 0.2359 - val_loss: 0.1797 - val_mse: 0.1797
# Epoch 2/1000
# 3/3 [==============================] - 0s 41ms/step - loss: 0.1811 - mse: 0.1811 - val_loss: 0.1659 - val_mse: 0.1659
# Epoch 3/1000
# 3/3 [==============================] - 0s 44ms/step - loss: 0.1665 - mse: 0.1665 - val_loss: 0.1675 - val_mse: 0.1675
# Epoch 4/1000
# 3/3 [==============================] - 0s 38ms/step - loss: 0.1681 - mse: 0.1681 - val_loss: 0.1702 - val_mse: 0.1702
# Epoch 5/1000
# 3/3 [==============================] - 0s 36ms/step - loss: 0.1645 - mse: 0.1645 - val_loss: 0.1715 - val_mse: 0.1715
# Epoch 6/1000
# 3/3 [==============================] - 0s 49ms/step - loss: 0.1683 - mse: 0.1683 - val_loss: 0.1715 - val_mse: 0.1715
# Epoch 7/1000
# 3/3 [==============================] - 0s 35ms/step - loss: 0.1632 - mse: 0.1632 - val_loss: 0.1709 - val_mse: 0.1709
# Epoch 8/1000
# 3/3 [==============================] - 0s 36ms/step - loss: 0.1620 - mse: 0.1620 - val_loss: 0.1698 - val_mse: 0.1698
# Epoch 9/1000
# 3/3 [==============================] - 0s 34ms/step - loss: 0.1670 - mse: 0.1670 - val_loss: 0.1683 - val_mse: 0.1683
# Epoch 10/1000
# 3/3 [==============================] - 0s 42ms/step - loss: 0.1670 - mse: 0.1670 - val_loss: 0.1670 - val_mse: 0.1670
# Epoch 11/1000
# 3/3 [==============================] - 0s 34ms/step - loss: 0.1626 - mse: 0.1626 - val_loss: 0.1664 - val_mse: 0.1664
# Epoch 12/1000
# 3/3 [==============================] - 0s 48ms/step - loss: 0.1612 - mse: 0.1612 - val_loss: 0.1664 - val_mse: 0.1664
# Epoch 13/1000
# 3/3 [==============================] - 0s 35ms/step - loss: 0.1615 - mse: 0.1615 - val_loss: 0.1666 - val_mse: 0.1666
# Epoch 14/1000
# 3/3 [==============================] - 0s 45ms/step - loss: 0.1619 - mse: 0.1619 - val_loss: 0.1667 - val_mse: 0.1667
# Epoch 15/1000
# 3/3 [==============================] - 0s 33ms/step - loss: 0.1613 - mse: 0.1613 - val_loss: 0.1665 - val_mse: 0.1665
# Epoch 16/1000
# 3/3 [==============================] - 0s 54ms/step - loss: 0.1588 - mse: 0.1588 - val_loss: 0.1663 - val_mse: 0.1663
# Epoch 17/1000
# 3/3 [==============================] - 0s 48ms/step - loss: 0.1587 - mse: 0.1587 - val_loss: 0.1663 - val_mse: 0.1663
# Epoch 18/1000
# 3/3 [==============================] - 0s 34ms/step - loss: 0.1573 - mse: 0.1573 - val_loss: 0.1664 - val_mse: 0.1664
# Epoch 19/1000
# 3/3 [==============================] - 0s 33ms/step - loss: 0.1587 - mse: 0.1587 - val_loss: 0.1665 - val_mse: 0.1665
# Epoch 20/1000
# 3/3 [==============================] - 0s 37ms/step - loss: 0.1548 - mse: 0.1548 - val_loss: 0.1666 - val_mse: 0.1666
# Epoch 21/1000
# 3/3 [==============================] - 0s 45ms/step - loss: 0.1579 - mse: 0.1579 - val_loss: 0.1668 - val_mse: 0.1668
# Epoch 22/1000
# 3/3 [==============================] - 0s 35ms/step - loss: 0.1555 - mse: 0.1555 - val_loss: 0.1672 - val_mse: 0.1672
# Epoch 23/1000
# 3/3 [==============================] - 0s 41ms/step - loss: 0.1582 - mse: 0.1582 - val_loss: 0.1672 - val_mse: 0.1672
# Epoch 24/1000
# 3/3 [==============================] - 0s 34ms/step - loss: 0.1572 - mse: 0.1572 - val_loss: 0.1677 - val_mse: 0.1677
# Epoch 25/1000
# 3/3 [==============================] - 0s 34ms/step - loss: 0.1550 - mse: 0.1550 - val_loss: 0.1683 - val_mse: 0.1683
# Epoch 26/1000
# 3/3 [==============================] - 0s 44ms/step - loss: 0.1524 - mse: 0.1524 - val_loss: 0.1693 - val_mse: 0.1693
# Epoch 27/1000
# 3/3 [==============================] - 0s 36ms/step - loss: 0.1522 - mse: 0.1522 - val_loss: 0.1709 - val_mse: 0.1709
# Epoch 28/1000
# 3/3 [==============================] - 0s 34ms/step - loss: 0.1538 - mse: 0.1538 - val_loss: 0.1728 - val_mse: 0.1728
# Epoch 29/1000
# 3/3 [==============================] - 0s 36ms/step - loss: 0.1519 - mse: 0.1519 - val_loss: 0.1731 - val_mse: 0.1731
# Epoch 30/1000
# 3/3 [==============================] - 0s 34ms/step - loss: 0.1527 - mse: 0.1527 - val_loss: 0.1723 - val_mse: 0.1723
# Epoch 31/1000
# 3/3 [==============================] - 0s 35ms/step - loss: 0.1524 - mse: 0.1524 - val_loss: 0.1725 - val_mse: 0.1725
# Epoch 32/1000
# 3/3 [==============================] - 0s 35ms/step - loss: 0.1516 - mse: 0.1516 - val_loss: 0.1745 - val_mse: 0.1745
# Epoch 33/1000
# 3/3 [==============================] - 0s 54ms/step - loss: 0.1511 - mse: 0.1511 - val_loss: 0.1748 - val_mse: 0.1748
# Epoch 34/1000
# 3/3 [==============================] - 0s 38ms/step - loss: 0.1498 - mse: 0.1498 - val_loss: 0.1775 - val_mse: 0.1775
# Epoch 35/1000
# 3/3 [==============================] - 0s 29ms/step - loss: 0.1473 - mse: 0.1473 - val_loss: 0.1809 - val_mse: 0.1809
# Epoch 36/1000
# 3/3 [==============================] - 0s 40ms/step - loss: 0.1504 - mse: 0.1504 - val_loss: 0.1807 - val_mse: 0.1807
# Epoch 37/1000
# 3/3 [==============================] - 0s 55ms/step - loss: 0.1510 - mse: 0.1510 - val_loss: 0.1761 - val_mse: 0.1761
# Epoch 38/1000
# 3/3 [==============================] - 0s 80ms/step - loss: 0.1481 - mse: 0.1481 - val_loss: 0.1773 - val_mse: 0.1773
# Epoch 39/1000
# 3/3 [==============================] - 0s 66ms/step - loss: 0.1467 - mse: 0.1467 - val_loss: 0.1785 - val_mse: 0.1785
# Epoch 40/1000
# 3/3 [==============================] - 0s 38ms/step - loss: 0.1501 - mse: 0.1501 - val_loss: 0.1875 - val_mse: 0.1875
# Epoch 41/1000
# 3/3 [==============================] - 0s 33ms/step - loss: 0.1487 - mse: 0.1487 - val_loss: 0.1783 - val_mse: 0.1783
# Epoch 42/1000
# 3/3 [==============================] - 0s 47ms/step - loss: 0.1466 - mse: 0.1466 - val_loss: 0.1742 - val_mse: 0.1742
# Epoch 43/1000
# 3/3 [==============================] - 0s 43ms/step - loss: 0.1457 - mse: 0.1457 - val_loss: 0.1755 - val_mse: 0.1755
# Epoch 44/1000
# 3/3 [==============================] - 0s 33ms/step - loss: 0.1458 - mse: 0.1458 - val_loss: 0.1805 - val_mse: 0.1805
# Epoch 45/1000
# 3/3 [==============================] - 0s 46ms/step - loss: 0.1467 - mse: 0.1467 - val_loss: 0.1826 - val_mse: 0.1826
# Epoch 46/1000
# 3/3 [==============================] - 0s 43ms/step - loss: 0.1475 - mse: 0.1475 - val_loss: 0.1789 - val_mse: 0.1789
# Epoch 47/1000
# 3/3 [==============================] - 0s 34ms/step - loss: 0.1485 - mse: 0.1485 - val_loss: 0.1743 - val_mse: 0.1743
# Epoch 48/1000
# 3/3 [==============================] - 0s 41ms/step - loss: 0.1438 - mse: 0.1438 - val_loss: 0.1735 - val_mse: 0.1735
# Epoch 49/1000
# 3/3 [==============================] - 0s 34ms/step - loss: 0.1427 - mse: 0.1427 - val_loss: 0.1752 - val_mse: 0.1752
# Epoch 50/1000
# 3/3 [==============================] - 0s 46ms/step - loss: 0.1409 - mse: 0.1409 - val_loss: 0.1797 - val_mse: 0.1797
# Epoch 51/1000
# 3/3 [==============================] - 0s 44ms/step - loss: 0.1433 - mse: 0.1433 - val_loss: 0.1799 - val_mse: 0.1799
# Epoch 52/1000
# 3/3 [==============================] - 0s 34ms/step - loss: 0.1442 - mse: 0.1442 - val_loss: 0.1748 - val_mse: 0.1748
# Epoch 53/1000
# 3/3 [==============================] - 0s 33ms/step - loss: 0.1409 - mse: 0.1409 - val_loss: 0.1743 - val_mse: 0.1743
# Epoch 54/1000
# 3/3 [==============================] - 0s 32ms/step - loss: 0.1382 - mse: 0.1382 - val_loss: 0.1756 - val_mse: 0.1756
# Epoch 55/1000
# 3/3 [==============================] - 0s 45ms/step - loss: 0.1400 - mse: 0.1400 - val_loss: 0.1806 - val_mse: 0.1806
# Epoch 56/1000
# 3/3 [==============================] - 0s 109ms/step - loss: 0.1351 - mse: 0.1351 - val_loss: 0.1855 - val_mse: 0.1855
# Epoch 57/1000
# 3/3 [==============================] - 0s 38ms/step - loss: 0.1398 - mse: 0.1398 - val_loss: 0.1836 - val_mse: 0.1836
# Epoch 58/1000
# 3/3 [==============================] - 0s 34ms/step - loss: 0.1399 - mse: 0.1399 - val_loss: 0.1795 - val_mse: 0.1795
# Epoch 59/1000
# 3/3 [==============================] - 0s 46ms/step - loss: 0.1379 - mse: 0.1379 - val_loss: 0.1773 - val_mse: 0.1773
# Epoch 60/1000
# 3/3 [==============================] - 0s 43ms/step - loss: 0.1393 - mse: 0.1393 - val_loss: 0.1843 - val_mse: 0.1843
# Epoch 61/1000
# 3/3 [==============================] - 0s 35ms/step - loss: 0.1374 - mse: 0.1374 - val_loss: 0.1811 - val_mse: 0.1811
# Epoch 62/1000
# 3/3 [==============================] - 0s 44ms/step - loss: 0.1358 - mse: 0.1358 - val_loss: 0.1745 - val_mse: 0.1745
# Epoch 63/1000
# 3/3 [==============================] - 0s 44ms/step - loss: 0.1367 - mse: 0.1367 - val_loss: 0.1725 - val_mse: 0.1725
# Epoch 64/1000
# 3/3 [==============================] - 0s 44ms/step - loss: 0.1309 - mse: 0.1309 - val_loss: 0.1749 - val_mse: 0.1749
# Epoch 65/1000
# 3/3 [==============================] - 0s 46ms/step - loss: 0.1359 - mse: 0.1359 - val_loss: 0.1752 - val_mse: 0.1752
# Epoch 66/1000
# 3/3 [==============================] - 0s 35ms/step - loss: 0.1357 - mse: 0.1357 - val_loss: 0.1750 - val_mse: 0.1750
# Epoch 67/1000
# 3/3 [==============================] - 0s 34ms/step - loss: 0.1313 - mse: 0.1313 - val_loss: 0.1748 - val_mse: 0.1748
# Epoch 68/1000
# 3/3 [==============================] - 0s 34ms/step - loss: 0.1356 - mse: 0.1356 - val_loss: 0.1779 - val_mse: 0.1779
# Epoch 69/1000
# 3/3 [==============================] - 0s 34ms/step - loss: 0.1305 - mse: 0.1305 - val_loss: 0.1743 - val_mse: 0.1743
# Epoch 70/1000
# 3/3 [==============================] - 0s 38ms/step - loss: 0.1284 - mse: 0.1284 - val_loss: 0.1725 - val_mse: 0.1725
# Epoch 71/1000
# 3/3 [==============================] - 0s 51ms/step - loss: 0.1281 - mse: 0.1281 - val_loss: 0.1729 - val_mse: 0.1729
# Epoch 72/1000
# 3/3 [==============================] - 0s 43ms/step - loss: 0.1304 - mse: 0.1304 - val_loss: 0.1756 - val_mse: 0.1756
# Epoch 73/1000
# 3/3 [==============================] - 0s 33ms/step - loss: 0.1324 - mse: 0.1324 - val_loss: 0.1720 - val_mse: 0.1720
# Epoch 74/1000
# 3/3 [==============================] - 0s 50ms/step - loss: 0.1303 - mse: 0.1303 - val_loss: 0.1692 - val_mse: 0.1692
# Epoch 75/1000
# 3/3 [==============================] - 0s 37ms/step - loss: 0.1271 - mse: 0.1271 - val_loss: 0.1681 - val_mse: 0.1681
# Epoch 76/1000
# 3/3 [==============================] - 0s 47ms/step - loss: 0.1330 - mse: 0.1330 - val_loss: 0.1708 - val_mse: 0.1708
# Epoch 77/1000
# 3/3 [==============================] - 0s 35ms/step - loss: 0.1269 - mse: 0.1269 - val_loss: 0.1832 - val_mse: 0.1832
# Epoch 78/1000
# 3/3 [==============================] - 0s 37ms/step - loss: 0.1273 - mse: 0.1273 - val_loss: 0.1787 - val_mse: 0.1787
# Epoch 79/1000
# 3/3 [==============================] - 0s 46ms/step - loss: 0.1277 - mse: 0.1277 - val_loss: 0.1700 - val_mse: 0.1700
# Epoch 80/1000
# 3/3 [==============================] - 0s 47ms/step - loss: 0.1303 - mse: 0.1303 - val_loss: 0.1650 - val_mse: 0.1650
# Epoch 81/1000
# 3/3 [==============================] - 0s 34ms/step - loss: 0.1284 - mse: 0.1284 - val_loss: 0.1658 - val_mse: 0.1658
# Epoch 82/1000
# 3/3 [==============================] - 0s 35ms/step - loss: 0.1216 - mse: 0.1216 - val_loss: 0.1728 - val_mse: 0.1728
# Epoch 83/1000
# 3/3 [==============================] - 0s 34ms/step - loss: 0.1300 - mse: 0.1300 - val_loss: 0.1757 - val_mse: 0.1757
# Epoch 84/1000
# 3/3 [==============================] - 0s 32ms/step - loss: 0.1193 - mse: 0.1193 - val_loss: 0.1721 - val_mse: 0.1721
# Epoch 85/1000
# 3/3 [==============================] - 0s 42ms/step - loss: 0.1215 - mse: 0.1215 - val_loss: 0.1690 - val_mse: 0.1690
# Epoch 86/1000
# 3/3 [==============================] - 0s 33ms/step - loss: 0.1225 - mse: 0.1225 - val_loss: 0.1743 - val_mse: 0.1743
# Epoch 87/1000
# 3/3 [==============================] - 0s 44ms/step - loss: 0.1187 - mse: 0.1187 - val_loss: 0.1689 - val_mse: 0.1689
# Epoch 88/1000
# 3/3 [==============================] - 0s 34ms/step - loss: 0.1200 - mse: 0.1200 - val_loss: 0.1694 - val_mse: 0.1694
# Epoch 89/1000
# 3/3 [==============================] - 0s 43ms/step - loss: 0.1170 - mse: 0.1170 - val_loss: 0.1672 - val_mse: 0.1672
# Epoch 90/1000
# 3/3 [==============================] - 0s 35ms/step - loss: 0.1243 - mse: 0.1243 - val_loss: 0.1598 - val_mse: 0.1598
# Epoch 91/1000
# 3/3 [==============================] - 0s 34ms/step - loss: 0.1197 - mse: 0.1197 - val_loss: 0.1648 - val_mse: 0.1648
# Epoch 92/1000
# 3/3 [==============================] - 0s 32ms/step - loss: 0.1132 - mse: 0.1132 - val_loss: 0.1754 - val_mse: 0.1754
# Epoch 93/1000
# 3/3 [==============================] - 0s 45ms/step - loss: 0.1166 - mse: 0.1166 - val_loss: 0.1694 - val_mse: 0.1694
# Epoch 94/1000
# 3/3 [==============================] - 0s 38ms/step - loss: 0.1175 - mse: 0.1175 - val_loss: 0.1590 - val_mse: 0.1590
# Epoch 95/1000
# 3/3 [==============================] - 0s 34ms/step - loss: 0.1140 - mse: 0.1140 - val_loss: 0.1614 - val_mse: 0.1614
# Epoch 96/1000
# 3/3 [==============================] - 0s 46ms/step - loss: 0.1120 - mse: 0.1120 - val_loss: 0.1718 - val_mse: 0.1718
# Epoch 97/1000
# 3/3 [==============================] - 0s 45ms/step - loss: 0.1150 - mse: 0.1150 - val_loss: 0.1602 - val_mse: 0.1602
# Epoch 98/1000
# 3/3 [==============================] - 0s 44ms/step - loss: 0.1125 - mse: 0.1125 - val_loss: 0.1663 - val_mse: 0.1663
# Epoch 99/1000
# 3/3 [==============================] - 0s 33ms/step - loss: 0.1075 - mse: 0.1075 - val_loss: 0.1601 - val_mse: 0.1601
# Epoch 100/1000
# 3/3 [==============================] - 0s 48ms/step - loss: 0.1073 - mse: 0.1073 - val_loss: 0.1593 - val_mse: 0.1593
# Epoch 101/1000
# 3/3 [==============================] - 0s 34ms/step - loss: 0.1098 - mse: 0.1098 - val_loss: 0.1632 - val_mse: 0.1632
# Epoch 102/1000
# 3/3 [==============================] - 0s 32ms/step - loss: 0.1044 - mse: 0.1044 - val_loss: 0.1765 - val_mse: 0.1765
# Epoch 103/1000
# 3/3 [==============================] - 0s 35ms/step - loss: 0.1032 - mse: 0.1032 - val_loss: 0.1535 - val_mse: 0.1535
# Epoch 104/1000
# 3/3 [==============================] - 0s 45ms/step - loss: 0.1037 - mse: 0.1037 - val_loss: 0.1622 - val_mse: 0.1622
# Epoch 105/1000
# 3/3 [==============================] - 0s 33ms/step - loss: 0.1047 - mse: 0.1047 - val_loss: 0.1838 - val_mse: 0.1838
# Epoch 106/1000
# 3/3 [==============================] - 0s 35ms/step - loss: 0.1004 - mse: 0.1004 - val_loss: 0.1560 - val_mse: 0.1560
# Epoch 107/1000
# 3/3 [==============================] - 0s 38ms/step - loss: 0.1045 - mse: 0.1045 - val_loss: 0.1506 - val_mse: 0.1506
# Epoch 108/1000
# 3/3 [==============================] - 0s 37ms/step - loss: 0.1008 - mse: 0.1008 - val_loss: 0.1754 - val_mse: 0.1754
# Epoch 109/1000
# 3/3 [==============================] - 0s 34ms/step - loss: 0.0991 - mse: 0.0991 - val_loss: 0.1691 - val_mse: 0.1691
# Epoch 110/1000
# 3/3 [==============================] - 0s 42ms/step - loss: 0.0962 - mse: 0.0962 - val_loss: 0.1598 - val_mse: 0.1598
# Epoch 111/1000
# 3/3 [==============================] - 0s 35ms/step - loss: 0.0935 - mse: 0.0935 - val_loss: 0.1638 - val_mse: 0.1638
# Epoch 112/1000
# 3/3 [==============================] - 0s 113ms/step - loss: 0.0968 - mse: 0.0968 - val_loss: 0.1770 - val_mse: 0.1770
# Epoch 113/1000
# 3/3 [==============================] - 0s 36ms/step - loss: 0.0905 - mse: 0.0905 - val_loss: 0.1529 - val_mse: 0.1529
# Epoch 114/1000
# 3/3 [==============================] - 0s 33ms/step - loss: 0.0926 - mse: 0.0926 - val_loss: 0.1622 - val_mse: 0.1622
# Epoch 115/1000
# 3/3 [==============================] - 0s 35ms/step - loss: 0.0904 - mse: 0.0904 - val_loss: 0.1842 - val_mse: 0.1842
# Epoch 116/1000
# 3/3 [==============================] - 0s 33ms/step - loss: 0.0968 - mse: 0.0968 - val_loss: 0.1658 - val_mse: 0.1658
# Epoch 117/1000
# 3/3 [==============================] - 0s 32ms/step - loss: 0.0866 - mse: 0.0866 - val_loss: 0.1605 - val_mse: 0.1605
# Epoch 118/1000
# 3/3 [==============================] - 0s 44ms/step - loss: 0.0902 - mse: 0.0902 - val_loss: 0.2046 - val_mse: 0.2046
# Epoch 119/1000
# 3/3 [==============================] - 0s 34ms/step - loss: 0.0847 - mse: 0.0847 - val_loss: 0.1787 - val_mse: 0.1787
# Epoch 120/1000
# 3/3 [==============================] - 0s 38ms/step - loss: 0.0857 - mse: 0.0857 - val_loss: 0.1720 - val_mse: 0.1720
# Epoch 121/1000
# 3/3 [==============================] - 0s 47ms/step - loss: 0.0801 - mse: 0.0801 - val_loss: 0.2010 - val_mse: 0.2010
# Epoch 122/1000
# 3/3 [==============================] - 0s 47ms/step - loss: 0.0795 - mse: 0.0795 - val_loss: 0.2060 - val_mse: 0.2060
# Epoch 123/1000
# 3/3 [==============================] - 0s 35ms/step - loss: 0.0737 - mse: 0.0737 - val_loss: 0.1821 - val_mse: 0.1821
# Epoch 124/1000
# 3/3 [==============================] - 0s 46ms/step - loss: 0.0820 - mse: 0.0820 - val_loss: 0.2154 - val_mse: 0.2154
# Epoch 125/1000
# 3/3 [==============================] - 0s 42ms/step - loss: 0.0772 - mse: 0.0772 - val_loss: 0.2049 - val_mse: 0.2049
# Epoch 126/1000
# 3/3 [==============================] - 0s 34ms/step - loss: 0.0761 - mse: 0.0761 - val_loss: 0.1940 - val_mse: 0.1940
# Epoch 127/1000
# 3/3 [==============================] - 0s 33ms/step - loss: 0.0729 - mse: 0.0729 - val_loss: 0.2246 - val_mse: 0.2246
# Epoch 128/1000
# 3/3 [==============================] - 0s 35ms/step - loss: 0.0740 - mse: 0.0740 - val_loss: 0.2266 - val_mse: 0.2266
# Epoch 129/1000
# 3/3 [==============================] - 0s 45ms/step - loss: 0.0797 - mse: 0.0797 - val_loss: 0.2084 - val_mse: 0.2084
# Epoch 130/1000
# 3/3 [==============================] - 0s 34ms/step - loss: 0.0693 - mse: 0.0693 - val_loss: 0.2254 - val_mse: 0.2254
# Epoch 131/1000
# 3/3 [==============================] - 0s 33ms/step - loss: 0.0758 - mse: 0.0758 - val_loss: 0.2377 - val_mse: 0.2377
# Epoch 132/1000
# 3/3 [==============================] - 0s 35ms/step - loss: 0.0700 - mse: 0.0700 - val_loss: 0.2041 - val_mse: 0.2041
# Epoch 133/1000
# 3/3 [==============================] - 0s 45ms/step - loss: 0.0634 - mse: 0.0634 - val_loss: 0.2804 - val_mse: 0.2804
# Epoch 134/1000
# 3/3 [==============================] - 0s 45ms/step - loss: 0.0834 - mse: 0.0834 - val_loss: 0.2735 - val_mse: 0.2735
# Epoch 135/1000
# 3/3 [==============================] - 0s 34ms/step - loss: 0.0647 - mse: 0.0647 - val_loss: 0.1908 - val_mse: 0.1908
# Epoch 136/1000
# 3/3 [==============================] - 0s 34ms/step - loss: 0.0697 - mse: 0.0697 - val_loss: 0.2794 - val_mse: 0.2794
# Epoch 137/1000
# 3/3 [==============================] - 0s 45ms/step - loss: 0.0678 - mse: 0.0678 - val_loss: 0.3008 - val_mse: 0.3008
# Epoch 138/1000
# 3/3 [==============================] - 0s 38ms/step - loss: 0.0571 - mse: 0.0571 - val_loss: 0.1858 - val_mse: 0.1858
# Epoch 139/1000
# 3/3 [==============================] - 0s 34ms/step - loss: 0.0692 - mse: 0.0692 - val_loss: 0.2214 - val_mse: 0.2214
# Epoch 140/1000
# 3/3 [==============================] - 0s 44ms/step - loss: 0.0658 - mse: 0.0658 - val_loss: 0.3050 - val_mse: 0.3050
# Epoch 141/1000
# 3/3 [==============================] - 0s 36ms/step - loss: 0.0603 - mse: 0.0603 - val_loss: 0.2205 - val_mse: 0.2205
# Epoch 142/1000
# 3/3 [==============================] - 0s 35ms/step - loss: 0.0657 - mse: 0.0657 - val_loss: 0.2331 - val_mse: 0.2331
# Epoch 143/1000
# 3/3 [==============================] - 0s 45ms/step - loss: 0.0623 - mse: 0.0623 - val_loss: 0.3354 - val_mse: 0.3354
# Epoch 144/1000
# 3/3 [==============================] - 0s 44ms/step - loss: 0.0673 - mse: 0.0673 - val_loss: 0.2778 - val_mse: 0.2778
# Epoch 145/1000
# 3/3 [==============================] - 0s 34ms/step - loss: 0.0566 - mse: 0.0566 - val_loss: 0.2295 - val_mse: 0.2295
# Epoch 146/1000
# 3/3 [==============================] - 0s 43ms/step - loss: 0.0592 - mse: 0.0592 - val_loss: 0.2687 - val_mse: 0.2687
# Epoch 147/1000
# 3/3 [==============================] - 0s 36ms/step - loss: 0.0533 - mse: 0.0533 - val_loss: 0.3016 - val_mse: 0.3016
# Epoch 148/1000
# 3/3 [==============================] - 0s 33ms/step - loss: 0.0500 - mse: 0.0500 - val_loss: 0.2666 - val_mse: 0.2666
# Epoch 149/1000
# 3/3 [==============================] - 0s 35ms/step - loss: 0.0501 - mse: 0.0501 - val_loss: 0.2912 - val_mse: 0.2912
# Epoch 150/1000
# 3/3 [==============================] - 0s 35ms/step - loss: 0.0485 - mse: 0.0485 - val_loss: 0.3067 - val_mse: 0.3067
# Epoch 151/1000
# 3/3 [==============================] - 0s 54ms/step - loss: 0.0505 - mse: 0.0505 - val_loss: 0.2941 - val_mse: 0.2941
# Epoch 152/1000
# 3/3 [==============================] - 0s 47ms/step - loss: 0.0494 - mse: 0.0494 - val_loss: 0.2698 - val_mse: 0.2698
# Epoch 153/1000
# 3/3 [==============================] - 0s 34ms/step - loss: 0.0463 - mse: 0.0463 - val_loss: 0.3215 - val_mse: 0.3215
# Epoch 154/1000
# 3/3 [==============================] - 0s 45ms/step - loss: 0.0482 - mse: 0.0482 - val_loss: 0.2880 - val_mse: 0.2880
# Epoch 155/1000
# 3/3 [==============================] - 0s 44ms/step - loss: 0.0438 - mse: 0.0438 - val_loss: 0.2851 - val_mse: 0.2851
# Epoch 156/1000
# 3/3 [==============================] - 0s 58ms/step - loss: 0.0450 - mse: 0.0450 - val_loss: 0.3296 - val_mse: 0.3296
# Epoch 157/1000
# 3/3 [==============================] - 0s 35ms/step - loss: 0.0436 - mse: 0.0436 - val_loss: 0.3017 - val_mse: 0.3017
# Epoch 158/1000
# 3/3 [==============================] - 0s 33ms/step - loss: 0.0467 - mse: 0.0467 - val_loss: 0.2917 - val_mse: 0.2917
# Epoch 159/1000
# 3/3 [==============================] - 0s 32ms/step - loss: 0.0422 - mse: 0.0422 - val_loss: 0.3665 - val_mse: 0.3665
# Epoch 160/1000
# 3/3 [==============================] - 0s 36ms/step - loss: 0.0428 - mse: 0.0428 - val_loss: 0.2997 - val_mse: 0.2997
# Epoch 161/1000
# 3/3 [==============================] - 0s 34ms/step - loss: 0.0439 - mse: 0.0439 - val_loss: 0.3103 - val_mse: 0.3103
# Epoch 162/1000
# 3/3 [==============================] - 0s 33ms/step - loss: 0.0413 - mse: 0.0413 - val_loss: 0.3638 - val_mse: 0.3638
# Epoch 163/1000
# 3/3 [==============================] - 0s 99ms/step - loss: 0.0402 - mse: 0.0402 - val_loss: 0.3105 - val_mse: 0.3105
# Epoch 164/1000
# 3/3 [==============================] - 0s 47ms/step - loss: 0.0393 - mse: 0.0393 - val_loss: 0.3154 - val_mse: 0.3154
# Epoch 165/1000
# 3/3 [==============================] - 0s 36ms/step - loss: 0.0369 - mse: 0.0369 - val_loss: 0.3301 - val_mse: 0.3301
# Epoch 166/1000
# 3/3 [==============================] - 0s 44ms/step - loss: 0.0391 - mse: 0.0391 - val_loss: 0.3438 - val_mse: 0.3438
# Epoch 167/1000
# 3/3 [==============================] - 0s 36ms/step - loss: 0.0400 - mse: 0.0400 - val_loss: 0.3202 - val_mse: 0.3202
# Epoch 168/1000
# 3/3 [==============================] - 0s 33ms/step - loss: 0.0371 - mse: 0.0371 - val_loss: 0.3369 - val_mse: 0.3369
# Epoch 169/1000
# 3/3 [==============================] - 0s 33ms/step - loss: 0.0358 - mse: 0.0358 - val_loss: 0.3377 - val_mse: 0.3377
# Epoch 170/1000
# 3/3 [==============================] - 0s 45ms/step - loss: 0.0335 - mse: 0.0335 - val_loss: 0.3387 - val_mse: 0.3387
# Epoch 171/1000
# 3/3 [==============================] - 0s 47ms/step - loss: 0.0358 - mse: 0.0358 - val_loss: 0.3413 - val_mse: 0.3413
# Epoch 172/1000
# 3/3 [==============================] - 0s 44ms/step - loss: 0.0341 - mse: 0.0341 - val_loss: 0.3488 - val_mse: 0.3488
# Epoch 173/1000
# 3/3 [==============================] - 0s 45ms/step - loss: 0.0337 - mse: 0.0337 - val_loss: 0.3446 - val_mse: 0.3446
# Epoch 174/1000
# 3/3 [==============================] - 0s 30ms/step - loss: 0.0332 - mse: 0.0332 - val_loss: 0.3728 - val_mse: 0.3728
# Epoch 175/1000
# 3/3 [==============================] - 0s 28ms/step - loss: 0.0339 - mse: 0.0339 - val_loss: 0.3568 - val_mse: 0.3568
# Epoch 176/1000
# 3/3 [==============================] - 0s 44ms/step - loss: 0.0314 - mse: 0.0314 - val_loss: 0.3467 - val_mse: 0.3467
# Epoch 177/1000
# 3/3 [==============================] - 0s 35ms/step - loss: 0.0301 - mse: 0.0301 - val_loss: 0.3344 - val_mse: 0.3344
# Epoch 178/1000
# 3/3 [==============================] - 0s 45ms/step - loss: 0.0309 - mse: 0.0309 - val_loss: 0.3283 - val_mse: 0.3283
# Epoch 179/1000
# 3/3 [==============================] - 0s 44ms/step - loss: 0.0310 - mse: 0.0310 - val_loss: 0.3824 - val_mse: 0.3824
# Epoch 180/1000
# 3/3 [==============================] - 0s 35ms/step - loss: 0.0310 - mse: 0.0310 - val_loss: 0.3687 - val_mse: 0.3687
# Epoch 181/1000
# 3/3 [==============================] - 0s 33ms/step - loss: 0.0310 - mse: 0.0310 - val_loss: 0.3642 - val_mse: 0.3642
# Epoch 182/1000
# 3/3 [==============================] - 0s 35ms/step - loss: 0.0324 - mse: 0.0324 - val_loss: 0.3440 - val_mse: 0.3440
# Epoch 183/1000
# 3/3 [==============================] - 0s 34ms/step - loss: 0.0311 - mse: 0.0311 - val_loss: 0.3929 - val_mse: 0.3929
# Epoch 184/1000
# 3/3 [==============================] - 0s 37ms/step - loss: 0.0338 - mse: 0.0338 - val_loss: 0.3428 - val_mse: 0.3428
# Epoch 185/1000
# 3/3 [==============================] - 0s 47ms/step - loss: 0.0386 - mse: 0.0386 - val_loss: 0.3028 - val_mse: 0.3028
# Epoch 186/1000
# 3/3 [==============================] - 0s 46ms/step - loss: 0.0307 - mse: 0.0307 - val_loss: 0.4193 - val_mse: 0.4193
# Epoch 187/1000
# 3/3 [==============================] - 0s 44ms/step - loss: 0.0359 - mse: 0.0359 - val_loss: 0.3691 - val_mse: 0.3691
# Epoch 188/1000
# 3/3 [==============================] - 0s 39ms/step - loss: 0.0322 - mse: 0.0322 - val_loss: 0.3621 - val_mse: 0.3621
# Epoch 189/1000
# 3/3 [==============================] - 0s 44ms/step - loss: 0.0292 - mse: 0.0292 - val_loss: 0.4034 - val_mse: 0.4034
# Epoch 190/1000
# 3/3 [==============================] - 0s 43ms/step - loss: 0.0304 - mse: 0.0304 - val_loss: 0.3946 - val_mse: 0.3946
# Epoch 191/1000
# 3/3 [==============================] - 0s 35ms/step - loss: 0.0306 - mse: 0.0306 - val_loss: 0.3097 - val_mse: 0.3097
# Epoch 192/1000
# 3/3 [==============================] - 0s 46ms/step - loss: 0.0342 - mse: 0.0342 - val_loss: 0.3419 - val_mse: 0.3419
# Epoch 193/1000
# 3/3 [==============================] - 0s 45ms/step - loss: 0.0324 - mse: 0.0324 - val_loss: 0.4068 - val_mse: 0.4068
# Epoch 194/1000
# 3/3 [==============================] - 0s 51ms/step - loss: 0.0300 - mse: 0.0300 - val_loss: 0.3595 - val_mse: 0.3595
# Epoch 195/1000
# 3/3 [==============================] - 0s 34ms/step - loss: 0.0308 - mse: 0.0308 - val_loss: 0.3619 - val_mse: 0.3619
# Epoch 196/1000
# 3/3 [==============================] - 0s 45ms/step - loss: 0.0294 - mse: 0.0294 - val_loss: 0.4043 - val_mse: 0.4043
# Epoch 197/1000
# 3/3 [==============================] - 0s 44ms/step - loss: 0.0298 - mse: 0.0298 - val_loss: 0.3984 - val_mse: 0.3984
# Epoch 198/1000
# 3/3 [==============================] - 0s 46ms/step - loss: 0.0278 - mse: 0.0278 - val_loss: 0.3522 - val_mse: 0.3522
# Epoch 199/1000
# 3/3 [==============================] - 0s 35ms/step - loss: 0.0293 - mse: 0.0293 - val_loss: 0.3492 - val_mse: 0.3492
# Epoch 200/1000
# 3/3 [==============================] - 0s 44ms/step - loss: 0.0282 - mse: 0.0282 - val_loss: 0.3739 - val_mse: 0.3739
# Epoch 201/1000
# 3/3 [==============================] - 0s 45ms/step - loss: 0.0290 - mse: 0.0290 - val_loss: 0.3709 - val_mse: 0.3709
# Epoch 202/1000
# 3/3 [==============================] - 0s 34ms/step - loss: 0.0298 - mse: 0.0298 - val_loss: 0.3491 - val_mse: 0.3491
# Epoch 203/1000
# 3/3 [==============================] - 0s 36ms/step - loss: 0.0288 - mse: 0.0288 - val_loss: 0.3883 - val_mse: 0.3883
# Epoch 204/1000
# 3/3 [==============================] - 0s 43ms/step - loss: 0.0283 - mse: 0.0283 - val_loss: 0.3878 - val_mse: 0.3878
# Epoch 205/1000
# 3/3 [==============================] - 0s 96ms/step - loss: 0.0275 - mse: 0.0275 - val_loss: 0.3737 - val_mse: 0.3737
# Epoch 206/1000
# 3/3 [==============================] - 0s 35ms/step - loss: 0.0281 - mse: 0.0281 - val_loss: 0.3901 - val_mse: 0.3901
# Epoch 207/1000
# 3/3 [==============================] - 0s 34ms/step - loss: 0.0275 - mse: 0.0275 - val_loss: 0.4020 - val_mse: 0.4020
# Epoch 208/1000
# 3/3 [==============================] - 0s 35ms/step - loss: 0.0276 - mse: 0.0276 - val_loss: 0.4157 - val_mse: 0.4157
# Epoch 209/1000
# 3/3 [==============================] - 0s 36ms/step - loss: 0.0281 - mse: 0.0281 - val_loss: 0.4112 - val_mse: 0.4112
# Epoch 210/1000
# 3/3 [==============================] - 0s 33ms/step - loss: 0.0274 - mse: 0.0274 - val_loss: 0.3968 - val_mse: 0.3968
# Epoch 211/1000
# 3/3 [==============================] - 0s 44ms/step - loss: 0.0273 - mse: 0.0273 - val_loss: 0.3823 - val_mse: 0.3823
# Epoch 212/1000
# 3/3 [==============================] - 0s 35ms/step - loss: 0.0281 - mse: 0.0281 - val_loss: 0.3829 - val_mse: 0.3829
# Epoch 213/1000
# 3/3 [==============================] - 0s 43ms/step - loss: 0.0273 - mse: 0.0273 - val_loss: 0.4056 - val_mse: 0.4056
# Epoch 214/1000
# 3/3 [==============================] - 0s 34ms/step - loss: 0.0275 - mse: 0.0275 - val_loss: 0.4100 - val_mse: 0.4100
# Epoch 215/1000
# 3/3 [==============================] - 0s 36ms/step - loss: 0.0277 - mse: 0.0277 - val_loss: 0.3952 - val_mse: 0.3952
# Epoch 216/1000
# 3/3 [==============================] - 0s 35ms/step - loss: 0.0271 - mse: 0.0271 - val_loss: 0.3884 - val_mse: 0.3884
# Epoch 217/1000
# 3/3 [==============================] - 0s 35ms/step - loss: 0.0275 - mse: 0.0275 - val_loss: 0.3896 - val_mse: 0.3896
# Epoch 218/1000
# 3/3 [==============================] - 0s 47ms/step - loss: 0.0270 - mse: 0.0270 - val_loss: 0.3922 - val_mse: 0.3922
# Epoch 219/1000
# 3/3 [==============================] - 0s 33ms/step - loss: 0.0279 - mse: 0.0279 - val_loss: 0.3951 - val_mse: 0.3951
# Epoch 220/1000
# 3/3 [==============================] - 0s 35ms/step - loss: 0.0273 - mse: 0.0273 - val_loss: 0.3976 - val_mse: 0.3976
# Epoch 221/1000
# 3/3 [==============================] - 0s 44ms/step - loss: 0.0269 - mse: 0.0269 - val_loss: 0.3974 - val_mse: 0.3974
# Epoch 222/1000
# 3/3 [==============================] - 0s 36ms/step - loss: 0.0272 - mse: 0.0272 - val_loss: 0.3943 - val_mse: 0.3943
# Epoch 223/1000
# 3/3 [==============================] - 0s 35ms/step - loss: 0.0273 - mse: 0.0273 - val_loss: 0.4052 - val_mse: 0.4052
# Epoch 224/1000
# 3/3 [==============================] - 0s 47ms/step - loss: 0.0277 - mse: 0.0277 - val_loss: 0.4089 - val_mse: 0.4089
# Epoch 225/1000
# 3/3 [==============================] - 0s 35ms/step - loss: 0.0269 - mse: 0.0269 - val_loss: 0.4063 - val_mse: 0.4063
# Epoch 226/1000
# 3/3 [==============================] - 0s 33ms/step - loss: 0.0269 - mse: 0.0269 - val_loss: 0.3948 - val_mse: 0.3948
# Epoch 227/1000
# 3/3 [==============================] - 0s 39ms/step - loss: 0.0271 - mse: 0.0271 - val_loss: 0.3805 - val_mse: 0.3805
# Epoch 228/1000
# 3/3 [==============================] - 0s 48ms/step - loss: 0.0270 - mse: 0.0270 - val_loss: 0.3800 - val_mse: 0.3800
# Epoch 229/1000
# 3/3 [==============================] - 0s 46ms/step - loss: 0.0272 - mse: 0.0272 - val_loss: 0.3977 - val_mse: 0.3977
# Epoch 230/1000
# 3/3 [==============================] - 0s 45ms/step - loss: 0.0267 - mse: 0.0267 - val_loss: 0.4179 - val_mse: 0.4179
# Epoch 231/1000
# 3/3 [==============================] - 0s 35ms/step - loss: 0.0270 - mse: 0.0270 - val_loss: 0.4234 - val_mse: 0.4234
# Epoch 232/1000
# 3/3 [==============================] - 0s 43ms/step - loss: 0.0274 - mse: 0.0274 - val_loss: 0.4036 - val_mse: 0.4036
# Epoch 233/1000
# 3/3 [==============================] - 0s 34ms/step - loss: 0.0269 - mse: 0.0269 - val_loss: 0.3916 - val_mse: 0.3916
# Epoch 234/1000
# 3/3 [==============================] - 0s 71ms/step - loss: 0.0273 - mse: 0.0273 - val_loss: 0.4102 - val_mse: 0.4102
# Epoch 235/1000
# 3/3 [==============================] - 0s 84ms/step - loss: 0.0273 - mse: 0.0273 - val_loss: 0.4167 - val_mse: 0.4167
# Epoch 236/1000
# 3/3 [==============================] - 0s 58ms/step - loss: 0.0265 - mse: 0.0265 - val_loss: 0.3935 - val_mse: 0.3935
# Epoch 237/1000
# 3/3 [==============================] - 0s 35ms/step - loss: 0.0268 - mse: 0.0268 - val_loss: 0.3806 - val_mse: 0.3806
# Epoch 238/1000
# 3/3 [==============================] - 0s 34ms/step - loss: 0.0262 - mse: 0.0262 - val_loss: 0.3983 - val_mse: 0.3983
# Epoch 239/1000
# 3/3 [==============================] - 0s 35ms/step - loss: 0.0270 - mse: 0.0270 - val_loss: 0.4060 - val_mse: 0.4060
# Epoch 240/1000
# 3/3 [==============================] - 0s 44ms/step - loss: 0.0253 - mse: 0.0253 - val_loss: 0.4087 - val_mse: 0.4087
# Epoch 241/1000
# 3/3 [==============================] - 0s 49ms/step - loss: 0.0229 - mse: 0.0229 - val_loss: 0.4025 - val_mse: 0.4025
# Epoch 242/1000
# 3/3 [==============================] - 0s 41ms/step - loss: 0.0240 - mse: 0.0240 - val_loss: 0.3919 - val_mse: 0.3919
# Epoch 243/1000
# 3/3 [==============================] - 0s 51ms/step - loss: 0.0246 - mse: 0.0246 - val_loss: 0.4116 - val_mse: 0.4116
# Epoch 244/1000
# 3/3 [==============================] - 0s 98ms/step - loss: 0.0234 - mse: 0.0234 - val_loss: 0.4140 - val_mse: 0.4140
# Epoch 245/1000
# 3/3 [==============================] - 0s 35ms/step - loss: 0.0230 - mse: 0.0230 - val_loss: 0.4109 - val_mse: 0.4109
# Epoch 246/1000
# 3/3 [==============================] - 0s 46ms/step - loss: 0.0242 - mse: 0.0242 - val_loss: 0.4167 - val_mse: 0.4167
# Epoch 247/1000
# 3/3 [==============================] - 0s 45ms/step - loss: 0.0242 - mse: 0.0242 - val_loss: 0.4176 - val_mse: 0.4176
# Epoch 248/1000
# 3/3 [==============================] - 0s 45ms/step - loss: 0.0225 - mse: 0.0225 - val_loss: 0.4385 - val_mse: 0.4385
# Epoch 249/1000
# 3/3 [==============================] - 0s 45ms/step - loss: 0.0234 - mse: 0.0234 - val_loss: 0.4543 - val_mse: 0.4543
# Epoch 250/1000
# 3/3 [==============================] - 0s 33ms/step - loss: 0.0231 - mse: 0.0231 - val_loss: 0.4328 - val_mse: 0.4328
# Epoch 251/1000
# 3/3 [==============================] - 0s 46ms/step - loss: 0.0223 - mse: 0.0223 - val_loss: 0.4054 - val_mse: 0.4054
# Epoch 252/1000
# 3/3 [==============================] - 0s 44ms/step - loss: 0.0221 - mse: 0.0221 - val_loss: 0.4015 - val_mse: 0.4015
# Epoch 253/1000
# 3/3 [==============================] - 0s 34ms/step - loss: 0.0215 - mse: 0.0215 - val_loss: 0.4281 - val_mse: 0.4281
# Epoch 254/1000
# 3/3 [==============================] - 0s 45ms/step - loss: 0.0218 - mse: 0.0218 - val_loss: 0.4329 - val_mse: 0.4329
# Epoch 255/1000
# 3/3 [==============================] - 0s 46ms/step - loss: 0.0218 - mse: 0.0218 - val_loss: 0.4249 - val_mse: 0.4249
# Epoch 256/1000
# 3/3 [==============================] - 0s 42ms/step - loss: 0.0217 - mse: 0.0217 - val_loss: 0.3893 - val_mse: 0.3893
# Epoch 257/1000
# 3/3 [==============================] - 0s 41ms/step - loss: 0.0219 - mse: 0.0219 - val_loss: 0.3901 - val_mse: 0.3901
# Epoch 258/1000
# 3/3 [==============================] - 0s 35ms/step - loss: 0.0218 - mse: 0.0218 - val_loss: 0.4323 - val_mse: 0.4323
# Epoch 259/1000
# 3/3 [==============================] - 0s 46ms/step - loss: 0.0218 - mse: 0.0218 - val_loss: 0.4498 - val_mse: 0.4498
# Epoch 260/1000
# 3/3 [==============================] - 0s 34ms/step - loss: 0.0219 - mse: 0.0219 - val_loss: 0.4261 - val_mse: 0.4261
# Epoch 261/1000
# 3/3 [==============================] - 0s 33ms/step - loss: 0.0214 - mse: 0.0214 - val_loss: 0.3948 - val_mse: 0.3948
# Epoch 262/1000
# 3/3 [==============================] - 0s 45ms/step - loss: 0.0220 - mse: 0.0220 - val_loss: 0.4265 - val_mse: 0.4265
# Epoch 263/1000
# 3/3 [==============================] - 0s 46ms/step - loss: 0.0214 - mse: 0.0214 - val_loss: 0.4538 - val_mse: 0.4538
# Epoch 264/1000
# 3/3 [==============================] - 0s 44ms/step - loss: 0.0216 - mse: 0.0216 - val_loss: 0.4389 - val_mse: 0.4389
# Epoch 265/1000
# 3/3 [==============================] - 0s 67ms/step - loss: 0.0213 - mse: 0.0213 - val_loss: 0.4233 - val_mse: 0.4233
# Epoch 266/1000
# 3/3 [==============================] - 0s 36ms/step - loss: 0.0214 - mse: 0.0214 - val_loss: 0.4206 - val_mse: 0.4206
# Epoch 267/1000
# 3/3 [==============================] - 0s 34ms/step - loss: 0.0214 - mse: 0.0214 - val_loss: 0.4248 - val_mse: 0.4248
# Epoch 268/1000
# 3/3 [==============================] - 0s 43ms/step - loss: 0.0218 - mse: 0.0218 - val_loss: 0.4242 - val_mse: 0.4242
# Epoch 269/1000
# 3/3 [==============================] - 0s 32ms/step - loss: 0.0213 - mse: 0.0213 - val_loss: 0.4281 - val_mse: 0.4281
# Epoch 270/1000
# 3/3 [==============================] - 0s 43ms/step - loss: 0.0214 - mse: 0.0214 - val_loss: 0.4342 - val_mse: 0.4342
# Epoch 271/1000
# 3/3 [==============================] - 0s 35ms/step - loss: 0.0213 - mse: 0.0213 - val_loss: 0.4367 - val_mse: 0.4367
# Epoch 272/1000
# 3/3 [==============================] - 0s 45ms/step - loss: 0.0213 - mse: 0.0213 - val_loss: 0.4383 - val_mse: 0.4383
# Epoch 273/1000
# 3/3 [==============================] - 0s 42ms/step - loss: 0.0213 - mse: 0.0213 - val_loss: 0.4276 - val_mse: 0.4276
# Epoch 274/1000
# 3/3 [==============================] - 0s 35ms/step - loss: 0.0212 - mse: 0.0212 - val_loss: 0.4192 - val_mse: 0.4192
# Epoch 275/1000
# 3/3 [==============================] - 0s 38ms/step - loss: 0.0212 - mse: 0.0212 - val_loss: 0.4186 - val_mse: 0.4186
# Epoch 276/1000
# 3/3 [==============================] - 0s 46ms/step - loss: 0.0214 - mse: 0.0214 - val_loss: 0.4191 - val_mse: 0.4191
# Epoch 277/1000
# 3/3 [==============================] - 0s 46ms/step - loss: 0.0212 - mse: 0.0212 - val_loss: 0.4262 - val_mse: 0.4262
# Epoch 278/1000
# 3/3 [==============================] - 0s 104ms/step - loss: 0.0215 - mse: 0.0215 - val_loss: 0.4360 - val_mse: 0.4360
# Epoch 279/1000
# 3/3 [==============================] - 0s 36ms/step - loss: 0.0215 - mse: 0.0215 - val_loss: 0.4360 - val_mse: 0.4360
# Epoch 280/1000
# 3/3 [==============================] - 0s 41ms/step - loss: 0.0212 - mse: 0.0212 - val_loss: 0.4338 - val_mse: 0.4338
# Epoch 281/1000
# 3/3 [==============================] - 0s 34ms/step - loss: 0.0211 - mse: 0.0211 - val_loss: 0.4373 - val_mse: 0.4373
# Epoch 282/1000
# 3/3 [==============================] - 0s 46ms/step - loss: 0.0212 - mse: 0.0212 - val_loss: 0.4383 - val_mse: 0.4383
# Epoch 283/1000
# 3/3 [==============================] - 0s 45ms/step - loss: 0.0210 - mse: 0.0210 - val_loss: 0.4351 - val_mse: 0.4351
# Epoch 284/1000
# 3/3 [==============================] - 0s 51ms/step - loss: 0.0214 - mse: 0.0214 - val_loss: 0.4259 - val_mse: 0.4259
# Epoch 285/1000
# 3/3 [==============================] - 0s 36ms/step - loss: 0.0211 - mse: 0.0211 - val_loss: 0.4256 - val_mse: 0.4256
# Epoch 286/1000
# 3/3 [==============================] - 0s 35ms/step - loss: 0.0212 - mse: 0.0212 - val_loss: 0.4317 - val_mse: 0.4317
# Epoch 287/1000
# 3/3 [==============================] - 0s 34ms/step - loss: 0.0212 - mse: 0.0212 - val_loss: 0.4289 - val_mse: 0.4289
# Epoch 288/1000
# 3/3 [==============================] - 0s 37ms/step - loss: 0.0214 - mse: 0.0214 - val_loss: 0.4221 - val_mse: 0.4221
# Epoch 289/1000
# 3/3 [==============================] - 0s 45ms/step - loss: 0.0210 - mse: 0.0210 - val_loss: 0.4301 - val_mse: 0.4301
# Epoch 290/1000
# 3/3 [==============================] - 0s 43ms/step - loss: 0.0209 - mse: 0.0209 - val_loss: 0.4377 - val_mse: 0.4377
# Epoch 291/1000
# 3/3 [==============================] - 0s 34ms/step - loss: 0.0213 - mse: 0.0213 - val_loss: 0.4398 - val_mse: 0.4398
# Epoch 292/1000
# 3/3 [==============================] - 0s 34ms/step - loss: 0.0211 - mse: 0.0211 - val_loss: 0.4284 - val_mse: 0.4284
# Epoch 293/1000
# 3/3 [==============================] - 0s 33ms/step - loss: 0.0211 - mse: 0.0211 - val_loss: 0.4222 - val_mse: 0.4222
# Epoch 294/1000
# 3/3 [==============================] - 0s 35ms/step - loss: 0.0211 - mse: 0.0211 - val_loss: 0.4318 - val_mse: 0.4318
# Epoch 295/1000
# 3/3 [==============================] - 0s 55ms/step - loss: 0.0212 - mse: 0.0212 - val_loss: 0.4428 - val_mse: 0.4428
# Epoch 296/1000
# 3/3 [==============================] - 0s 35ms/step - loss: 0.0210 - mse: 0.0210 - val_loss: 0.4530 - val_mse: 0.4530
# Epoch 297/1000
# 3/3 [==============================] - 0s 43ms/step - loss: 0.0216 - mse: 0.0216 - val_loss: 0.4628 - val_mse: 0.4628
# Epoch 298/1000
# 3/3 [==============================] - 0s 36ms/step - loss: 0.0209 - mse: 0.0209 - val_loss: 0.4597 - val_mse: 0.4597
# Epoch 299/1000
# 3/3 [==============================] - 0s 33ms/step - loss: 0.0209 - mse: 0.0209 - val_loss: 0.4482 - val_mse: 0.4482
# Epoch 300/1000
# 3/3 [==============================] - 0s 44ms/step - loss: 0.0209 - mse: 0.0209 - val_loss: 0.4461 - val_mse: 0.4461
# Epoch 301/1000
# 3/3 [==============================] - 0s 35ms/step - loss: 0.0212 - mse: 0.0212 - val_loss: 0.4423 - val_mse: 0.4423
# Epoch 302/1000
# 3/3 [==============================] - 0s 44ms/step - loss: 0.0204 - mse: 0.0204 - val_loss: 0.4621 - val_mse: 0.4621
# Epoch 303/1000
# 3/3 [==============================] - 0s 45ms/step - loss: 0.0224 - mse: 0.0224 - val_loss: 0.4705 - val_mse: 0.4705
# Epoch 304/1000
# 3/3 [==============================] - 0s 46ms/step - loss: 0.0199 - mse: 0.0199 - val_loss: 0.4461 - val_mse: 0.4461
# Epoch 305/1000
# 3/3 [==============================] - 0s 51ms/step - loss: 0.0201 - mse: 0.0201 - val_loss: 0.4713 - val_mse: 0.4713
# Epoch 306/1000
# 3/3 [==============================] - 0s 34ms/step - loss: 0.0177 - mse: 0.0177 - val_loss: 0.4706 - val_mse: 0.4706
# Epoch 307/1000
# 3/3 [==============================] - 0s 45ms/step - loss: 0.0174 - mse: 0.0174 - val_loss: 0.4383 - val_mse: 0.4383
# Epoch 308/1000
# 3/3 [==============================] - 0s 45ms/step - loss: 0.0166 - mse: 0.0166 - val_loss: 0.4467 - val_mse: 0.4467
# Epoch 309/1000
# 3/3 [==============================] - 0s 46ms/step - loss: 0.0166 - mse: 0.0166 - val_loss: 0.4710 - val_mse: 0.4710
# Epoch 310/1000
# 3/3 [==============================] - 0s 47ms/step - loss: 0.0170 - mse: 0.0170 - val_loss: 0.4741 - val_mse: 0.4741
# Epoch 311/1000
# 3/3 [==============================] - 0s 105ms/step - loss: 0.0166 - mse: 0.0166 - val_loss: 0.4599 - val_mse: 0.4599
# Epoch 312/1000
# 3/3 [==============================] - 0s 47ms/step - loss: 0.0176 - mse: 0.0176 - val_loss: 0.4453 - val_mse: 0.4453
# Epoch 313/1000
# 3/3 [==============================] - 0s 37ms/step - loss: 0.0163 - mse: 0.0163 - val_loss: 0.4457 - val_mse: 0.4457
# Epoch 314/1000
# 3/3 [==============================] - 0s 44ms/step - loss: 0.0167 - mse: 0.0167 - val_loss: 0.4522 - val_mse: 0.4522
# Epoch 315/1000
# 3/3 [==============================] - 0s 44ms/step - loss: 0.0170 - mse: 0.0170 - val_loss: 0.4501 - val_mse: 0.4501
# Epoch 316/1000
# 3/3 [==============================] - 0s 34ms/step - loss: 0.0163 - mse: 0.0163 - val_loss: 0.4515 - val_mse: 0.4515
# Epoch 317/1000
# 3/3 [==============================] - 0s 43ms/step - loss: 0.0163 - mse: 0.0163 - val_loss: 0.4660 - val_mse: 0.4660
# Epoch 318/1000
# 3/3 [==============================] - 0s 36ms/step - loss: 0.0160 - mse: 0.0160 - val_loss: 0.4775 - val_mse: 0.4775
# Epoch 319/1000
# 3/3 [==============================] - 0s 44ms/step - loss: 0.0166 - mse: 0.0166 - val_loss: 0.4701 - val_mse: 0.4701
# Epoch 320/1000
# 3/3 [==============================] - 0s 35ms/step - loss: 0.0161 - mse: 0.0161 - val_loss: 0.4566 - val_mse: 0.4566
# Epoch 321/1000
# 3/3 [==============================] - 0s 35ms/step - loss: 0.0162 - mse: 0.0162 - val_loss: 0.4488 - val_mse: 0.4488
# Epoch 322/1000
# 3/3 [==============================] - 0s 43ms/step - loss: 0.0159 - mse: 0.0159 - val_loss: 0.4555 - val_mse: 0.4555
# Epoch 323/1000
# 3/3 [==============================] - 0s 35ms/step - loss: 0.0160 - mse: 0.0160 - val_loss: 0.4633 - val_mse: 0.4633
# Epoch 324/1000
# 3/3 [==============================] - 0s 48ms/step - loss: 0.0160 - mse: 0.0160 - val_loss: 0.4645 - val_mse: 0.4645
# Epoch 325/1000
# 3/3 [==============================] - 0s 36ms/step - loss: 0.0166 - mse: 0.0166 - val_loss: 0.4618 - val_mse: 0.4618
# Epoch 326/1000
# 3/3 [==============================] - 0s 34ms/step - loss: 0.0160 - mse: 0.0160 - val_loss: 0.4528 - val_mse: 0.4528
# Epoch 327/1000
# 3/3 [==============================] - 0s 44ms/step - loss: 0.0162 - mse: 0.0162 - val_loss: 0.4518 - val_mse: 0.4518
# Epoch 328/1000
# 3/3 [==============================] - 0s 36ms/step - loss: 0.0160 - mse: 0.0160 - val_loss: 0.4551 - val_mse: 0.4551
# Epoch 329/1000
# 3/3 [==============================] - 0s 46ms/step - loss: 0.0160 - mse: 0.0160 - val_loss: 0.4607 - val_mse: 0.4607
# Epoch 330/1000
# 3/3 [==============================] - 0s 44ms/step - loss: 0.0161 - mse: 0.0161 - val_loss: 0.4535 - val_mse: 0.4535
# Epoch 331/1000
# 3/3 [==============================] - 0s 44ms/step - loss: 0.0161 - mse: 0.0161 - val_loss: 0.4441 - val_mse: 0.4441
# Epoch 332/1000
# 3/3 [==============================] - 0s 37ms/step - loss: 0.0162 - mse: 0.0162 - val_loss: 0.4417 - val_mse: 0.4417
# Epoch 333/1000
# 3/3 [==============================] - 0s 35ms/step - loss: 0.0161 - mse: 0.0161 - val_loss: 0.4519 - val_mse: 0.4519
# Epoch 334/1000
# 3/3 [==============================] - 0s 49ms/step - loss: 0.0164 - mse: 0.0164 - val_loss: 0.4595 - val_mse: 0.4595
# Epoch 335/1000
# 3/3 [==============================] - 0s 35ms/step - loss: 0.0163 - mse: 0.0163 - val_loss: 0.4513 - val_mse: 0.4513
# Epoch 336/1000
# 3/3 [==============================] - 0s 44ms/step - loss: 0.0159 - mse: 0.0159 - val_loss: 0.4295 - val_mse: 0.4295
# Epoch 337/1000
# 3/3 [==============================] - 0s 44ms/step - loss: 0.0161 - mse: 0.0161 - val_loss: 0.4401 - val_mse: 0.4401
# Epoch 338/1000
# 3/3 [==============================] - 0s 88ms/step - loss: 0.0161 - mse: 0.0161 - val_loss: 0.4579 - val_mse: 0.4579
# Epoch 339/1000
# 3/3 [==============================] - 0s 62ms/step - loss: 0.0161 - mse: 0.0161 - val_loss: 0.4707 - val_mse: 0.4707
# Epoch 340/1000
# 3/3 [==============================] - 0s 35ms/step - loss: 0.0158 - mse: 0.0158 - val_loss: 0.4682 - val_mse: 0.4682
# Epoch 341/1000
# 3/3 [==============================] - 0s 34ms/step - loss: 0.0159 - mse: 0.0159 - val_loss: 0.4590 - val_mse: 0.4590
# Epoch 342/1000
# 3/3 [==============================] - 0s 44ms/step - loss: 0.0158 - mse: 0.0158 - val_loss: 0.4488 - val_mse: 0.4488
# Epoch 343/1000
# 3/3 [==============================] - 0s 38ms/step - loss: 0.0159 - mse: 0.0159 - val_loss: 0.4407 - val_mse: 0.4407
# Epoch 344/1000
# 3/3 [==============================] - 0s 41ms/step - loss: 0.0160 - mse: 0.0160 - val_loss: 0.4438 - val_mse: 0.4438
# Epoch 345/1000
# 3/3 [==============================] - 0s 35ms/step - loss: 0.0158 - mse: 0.0158 - val_loss: 0.4488 - val_mse: 0.4488
# Epoch 346/1000
# 3/3 [==============================] - 0s 46ms/step - loss: 0.0159 - mse: 0.0159 - val_loss: 0.4544 - val_mse: 0.4544
# Epoch 347/1000
# 3/3 [==============================] - 0s 46ms/step - loss: 0.0158 - mse: 0.0158 - val_loss: 0.4544 - val_mse: 0.4544
# Epoch 348/1000
# 3/3 [==============================] - 0s 47ms/step - loss: 0.0158 - mse: 0.0158 - val_loss: 0.4493 - val_mse: 0.4493
# Epoch 349/1000
# 3/3 [==============================] - 0s 34ms/step - loss: 0.0158 - mse: 0.0158 - val_loss: 0.4467 - val_mse: 0.4467
# Epoch 350/1000
# 3/3 [==============================] - 0s 45ms/step - loss: 0.0159 - mse: 0.0159 - val_loss: 0.4477 - val_mse: 0.4477
# Epoch 351/1000
# 3/3 [==============================] - 0s 38ms/step - loss: 0.0159 - mse: 0.0159 - val_loss: 0.4497 - val_mse: 0.4497
# Epoch 352/1000
# ...
# 3/3 [==============================] - 0s 93ms/step - loss: 0.0156 - mse: 0.0156 - val_loss: 0.4312 - val_mse: 0.4312
# Epoch 689/1000
# 3/3 [==============================] - 0s 37ms/step - loss: 0.0156 - mse: 0.0156 - val_loss: 0.4323 - val_mse: 0.4323
# Epoch 690/1000
# 3/3 [==============================] - 0s 48ms/step - loss: 0.0156 - mse: 0.0156 - val_loss: 0.4323 - val_mse: 0.4323
# Epoch 691/1000
# 3/3 [==============================] - 0s 36ms/step - loss: 0.0156 - mse: 0.0156 - val_loss: 0.4321 - val_mse: 0.4321
# Epoch 692/1000
# 3/3 [==============================] - 0s 46ms/step - loss: 0.0156 - mse: 0.0156 - val_loss: 0.4336 - val_mse: 0.4336
# Epoch 693/1000
# 3/3 [==============================] - 0s 45ms/step - loss: 0.0156 - mse: 0.0156 - val_loss: 0.4377 - val_mse: 0.4377
# Epoch 694/1000
# 3/3 [==============================] - 0s 69ms/step - loss: 0.0156 - mse: 0.0156 - val_loss: 0.4396 - val_mse: 0.4396
# Epoch 695/1000
# 3/3 [==============================] - 0s 48ms/step - loss: 0.0156 - mse: 0.0156 - val_loss: 0.4401 - val_mse: 0.4401
# Epoch 696/1000
# 3/3 [==============================] - 0s 48ms/step - loss: 0.0157 - mse: 0.0157 - val_loss: 0.4377 - val_mse: 0.4377
# Epoch 697/1000
# 3/3 [==============================] - 0s 35ms/step - loss: 0.0156 - mse: 0.0156 - val_loss: 0.4332 - val_mse: 0.4332
# Epoch 698/1000
# 3/3 [==============================] - 0s 42ms/step - loss: 0.0156 - mse: 0.0156 - val_loss: 0.4309 - val_mse: 0.4309
# Epoch 699/1000
# 3/3 [==============================] - 0s 99ms/step - loss: 0.0157 - mse: 0.0157 - val_loss: 0.4344 - val_mse: 0.4344
# Epoch 700/1000
# 3/3 [==============================] - 0s 35ms/step - loss: 0.0156 - mse: 0.0156 - val_loss: 0.4363 - val_mse: 0.4363
# Epoch 701/1000
# 3/3 [==============================] - 0s 37ms/step - loss: 0.0156 - mse: 0.0156 - val_loss: 0.4365 - val_mse: 0.4365
# Epoch 702/1000
# 3/3 [==============================] - 0s 50ms/step - loss: 0.0156 - mse: 0.0156 - val_loss: 0.4359 - val_mse: 0.4359
# Epoch 703/1000
# 3/3 [==============================] - 0s 36ms/step - loss: 0.0157 - mse: 0.0157 - val_loss: 0.4345 - val_mse: 0.4345
# Epoch 704/1000
# 3/3 [==============================] - 0s 47ms/step - loss: 0.0156 - mse: 0.0156 - val_loss: 0.4336 - val_mse: 0.4336
# Epoch 705/1000
# 3/3 [==============================] - 0s 37ms/step - loss: 0.0156 - mse: 0.0156 - val_loss: 0.4336 - val_mse: 0.4336
# Epoch 706/1000
# 3/3 [==============================] - 0s 44ms/step - loss: 0.0156 - mse: 0.0156 - val_loss: 0.4337 - val_mse: 0.4337
# Epoch 707/1000
# 3/3 [==============================] - 0s 46ms/step - loss: 0.0156 - mse: 0.0156 - val_loss: 0.4341 - val_mse: 0.4341
# Epoch 708/1000
# 3/3 [==============================] - 0s 48ms/step - loss: 0.0156 - mse: 0.0156 - val_loss: 0.4351 - val_mse: 0.4351
# Epoch 709/1000
# 3/3 [==============================] - 0s 46ms/step - loss: 0.0156 - mse: 0.0156 - val_loss: 0.4361 - val_mse: 0.4361
# Epoch 710/1000
# 3/3 [==============================] - 0s 49ms/step - loss: 0.0156 - mse: 0.0156 - val_loss: 0.4372 - val_mse: 0.4372
# Epoch 711/1000
# 3/3 [==============================] - 0s 35ms/step - loss: 0.0156 - mse: 0.0156 - val_loss: 0.4380 - val_mse: 0.4380
# Epoch 712/1000
# 3/3 [==============================] - 0s 38ms/step - loss: 0.0156 - mse: 0.0156 - val_loss: 0.4374 - val_mse: 0.4374
# Epoch 713/1000
# 3/3 [==============================] - 0s 48ms/step - loss: 0.0156 - mse: 0.0156 - val_loss: 0.4364 - val_mse: 0.4364
# Epoch 714/1000
# 3/3 [==============================] - 0s 93ms/step - loss: 0.0157 - mse: 0.0157 - val_loss: 0.4366 - val_mse: 0.4366
# Epoch 715/1000
# 3/3 [==============================] - 0s 64ms/step - loss: 0.0156 - mse: 0.0156 - val_loss: 0.4359 - val_mse: 0.4359
# Epoch 716/1000
# 3/3 [==============================] - 0s 43ms/step - loss: 0.0156 - mse: 0.0156 - val_loss: 0.4346 - val_mse: 0.4346
# Epoch 717/1000
# 3/3 [==============================] - 0s 53ms/step - loss: 0.0156 - mse: 0.0156 - val_loss: 0.4327 - val_mse: 0.4327
# Epoch 718/1000
# 3/3 [==============================] - 0s 37ms/step - loss: 0.0156 - mse: 0.0156 - val_loss: 0.4283 - val_mse: 0.4283
# Epoch 719/1000
# 3/3 [==============================] - 0s 36ms/step - loss: 0.0157 - mse: 0.0157 - val_loss: 0.4275 - val_mse: 0.4275
# Epoch 720/1000
# 3/3 [==============================] - 0s 57ms/step - loss: 0.0156 - mse: 0.0156 - val_loss: 0.4282 - val_mse: 0.4282
# Epoch 721/1000
# 3/3 [==============================] - 0s 37ms/step - loss: 0.0156 - mse: 0.0156 - val_loss: 0.4281 - val_mse: 0.4281
# Epoch 722/1000
# 3/3 [==============================] - 0s 36ms/step - loss: 0.0156 - mse: 0.0156 - val_loss: 0.4287 - val_mse: 0.4287
# Epoch 723/1000
# 3/3 [==============================] - 0s 50ms/step - loss: 0.0156 - mse: 0.0156 - val_loss: 0.4275 - val_mse: 0.4275
# Epoch 724/1000
# 3/3 [==============================] - 0s 39ms/step - loss: 0.0156 - mse: 0.0156 - val_loss: 0.4266 - val_mse: 0.4266
# Epoch 725/1000
# 3/3 [==============================] - 0s 89ms/step - loss: 0.0157 - mse: 0.0157 - val_loss: 0.4339 - val_mse: 0.4339
# Epoch 726/1000
# 3/3 [==============================] - 0s 51ms/step - loss: 0.0156 - mse: 0.0156 - val_loss: 0.4384 - val_mse: 0.4384
# Epoch 727/1000
# 3/3 [==============================] - 0s 50ms/step - loss: 0.0156 - mse: 0.0156 - val_loss: 0.4400 - val_mse: 0.4400
# Epoch 728/1000
# 3/3 [==============================] - 0s 34ms/step - loss: 0.0156 - mse: 0.0156 - val_loss: 0.4391 - val_mse: 0.4391
# Epoch 729/1000
# 3/3 [==============================] - 0s 65ms/step - loss: 0.0156 - mse: 0.0156 - val_loss: 0.4369 - val_mse: 0.4369
# Epoch 730/1000
# 3/3 [==============================] - 0s 35ms/step - loss: 0.0156 - mse: 0.0156 - val_loss: 0.4330 - val_mse: 0.4330
# Epoch 731/1000
# 3/3 [==============================] - 0s 35ms/step - loss: 0.0156 - mse: 0.0156 - val_loss: 0.4292 - val_mse: 0.4292
# Epoch 732/1000
# 3/3 [==============================] - 0s 37ms/step - loss: 0.0156 - mse: 0.0156 - val_loss: 0.4266 - val_mse: 0.4266
# Epoch 733/1000
# 3/3 [==============================] - 0s 50ms/step - loss: 0.0156 - mse: 0.0156 - val_loss: 0.4243 - val_mse: 0.4243
# Epoch 734/1000
# 3/3 [==============================] - 0s 36ms/step - loss: 0.0156 - mse: 0.0156 - val_loss: 0.4239 - val_mse: 0.4239
# Epoch 735/1000
# 3/3 [==============================] - 0s 96ms/step - loss: 0.0156 - mse: 0.0156 - val_loss: 0.4252 - val_mse: 0.4252
# Epoch 736/1000
# 3/3 [==============================] - 0s 48ms/step - loss: 0.0156 - mse: 0.0156 - val_loss: 0.4274 - val_mse: 0.4274
# Epoch 737/1000
# 3/3 [==============================] - 0s 35ms/step - loss: 0.0156 - mse: 0.0156 - val_loss: 0.4284 - val_mse: 0.4284
# Epoch 738/1000
# 3/3 [==============================] - 0s 41ms/step - loss: 0.0156 - mse: 0.0156 - val_loss: 0.4286 - val_mse: 0.4286
# Epoch 739/1000
# 3/3 [==============================] - 0s 50ms/step - loss: 0.0156 - mse: 0.0156 - val_loss: 0.4277 - val_mse: 0.4277
# Epoch 740/1000
# 3/3 [==============================] - 0s 35ms/step - loss: 0.0156 - mse: 0.0156 - val_loss: 0.4261 - val_mse: 0.4261
# Epoch 741/1000
# 3/3 [==============================] - 0s 63ms/step - loss: 0.0156 - mse: 0.0156 - val_loss: 0.4246 - val_mse: 0.4246
# Epoch 742/1000
# 3/3 [==============================] - 0s 37ms/step - loss: 0.0156 - mse: 0.0156 - val_loss: 0.4239 - val_mse: 0.4239
# Epoch 743/1000
# 3/3 [==============================] - 0s 47ms/step - loss: 0.0156 - mse: 0.0156 - val_loss: 0.4225 - val_mse: 0.4225
# Epoch 744/1000
# 3/3 [==============================] - 0s 47ms/step - loss: 0.0156 - mse: 0.0156 - val_loss: 0.4231 - val_mse: 0.4231
# Epoch 745/1000
# 3/3 [==============================] - 0s 50ms/step - loss: 0.0156 - mse: 0.0156 - val_loss: 0.4279 - val_mse: 0.4279
# Epoch 746/1000
# 3/3 [==============================] - 0s 50ms/step - loss: 0.0156 - mse: 0.0156 - val_loss: 0.4309 - val_mse: 0.4309
# Epoch 747/1000
# 3/3 [==============================] - 0s 50ms/step - loss: 0.0156 - mse: 0.0156 - val_loss: 0.4310 - val_mse: 0.4310
# Epoch 748/1000
# 3/3 [==============================] - 0s 36ms/step - loss: 0.0156 - mse: 0.0156 - val_loss: 0.4307 - val_mse: 0.4307
# Epoch 749/1000
# 3/3 [==============================] - 0s 49ms/step - loss: 0.0156 - mse: 0.0156 - val_loss: 0.4299 - val_mse: 0.4299
# Epoch 750/1000
# 3/3 [==============================] - 0s 72ms/step - loss: 0.0156 - mse: 0.0156 - val_loss: 0.4273 - val_mse: 0.4273
# Epoch 751/1000
# 3/3 [==============================] - 0s 66ms/step - loss: 0.0156 - mse: 0.0156 - val_loss: 0.4258 - val_mse: 0.4258
# Epoch 752/1000
# 3/3 [==============================] - 0s 37ms/step - loss: 0.0156 - mse: 0.0156 - val_loss: 0.4251 - val_mse: 0.4251
# Epoch 753/1000
# 3/3 [==============================] - 0s 35ms/step - loss: 0.0156 - mse: 0.0156 - val_loss: 0.4242 - val_mse: 0.4242
# Epoch 754/1000
# 3/3 [==============================] - 0s 49ms/step - loss: 0.0156 - mse: 0.0156 - val_loss: 0.4238 - val_mse: 0.4238
# Epoch 755/1000
# 3/3 [==============================] - 0s 36ms/step - loss: 0.0156 - mse: 0.0156 - val_loss: 0.4231 - val_mse: 0.4231
# Epoch 756/1000
# 3/3 [==============================] - 0s 52ms/step - loss: 0.0156 - mse: 0.0156 - val_loss: 0.4234 - val_mse: 0.4234
# Epoch 757/1000
# 3/3 [==============================] - 0s 48ms/step - loss: 0.0156 - mse: 0.0156 - val_loss: 0.4238 - val_mse: 0.4238
# Epoch 758/1000
# 3/3 [==============================] - 0s 35ms/step - loss: 0.0156 - mse: 0.0156 - val_loss: 0.4259 - val_mse: 0.4259
# Epoch 759/1000
# 3/3 [==============================] - 0s 47ms/step - loss: 0.0156 - mse: 0.0156 - val_loss: 0.4275 - val_mse: 0.4275
# Epoch 760/1000
# 3/3 [==============================] - 0s 49ms/step - loss: 0.0156 - mse: 0.0156 - val_loss: 0.4288 - val_mse: 0.4288
# Epoch 761/1000
# 3/3 [==============================] - 0s 49ms/step - loss: 0.0156 - mse: 0.0156 - val_loss: 0.4297 - val_mse: 0.4297
# Epoch 762/1000
# 3/3 [==============================] - 0s 37ms/step - loss: 0.0156 - mse: 0.0156 - val_loss: 0.4279 - val_mse: 0.4279
# Epoch 763/1000
# 3/3 [==============================] - 0s 34ms/step - loss: 0.0156 - mse: 0.0156 - val_loss: 0.4281 - val_mse: 0.4281
# Epoch 764/1000
# 3/3 [==============================] - 0s 48ms/step - loss: 0.0156 - mse: 0.0156 - val_loss: 0.4303 - val_mse: 0.4303
# Epoch 765/1000
# 3/3 [==============================] - 0s 37ms/step - loss: 0.0156 - mse: 0.0156 - val_loss: 0.4333 - val_mse: 0.4333
# Epoch 766/1000
# 3/3 [==============================] - 0s 35ms/step - loss: 0.0156 - mse: 0.0156 - val_loss: 0.4364 - val_mse: 0.4364
# Epoch 767/1000
# 3/3 [==============================] - 0s 110ms/step - loss: 0.0156 - mse: 0.0156 - val_loss: 0.4340 - val_mse: 0.4340
# Epoch 768/1000
# 3/3 [==============================] - 0s 38ms/step - loss: 0.0157 - mse: 0.0157 - val_loss: 0.4320 - val_mse: 0.4320
# Epoch 769/1000
# 3/3 [==============================] - 0s 36ms/step - loss: 0.0156 - mse: 0.0156 - val_loss: 0.4298 - val_mse: 0.4298
# Epoch 770/1000
# 3/3 [==============================] - 0s 35ms/step - loss: 0.0156 - mse: 0.0156 - val_loss: 0.4282 - val_mse: 0.4282
# Epoch 771/1000
# 3/3 [==============================] - 0s 35ms/step - loss: 0.0156 - mse: 0.0156 - val_loss: 0.4268 - val_mse: 0.4268
# Epoch 772/1000
# 3/3 [==============================] - 0s 47ms/step - loss: 0.0156 - mse: 0.0156 - val_loss: 0.4267 - val_mse: 0.4267
# Epoch 773/1000
# 3/3 [==============================] - 0s 66ms/step - loss: 0.0156 - mse: 0.0156 - val_loss: 0.4273 - val_mse: 0.4273
# Epoch 774/1000
# 3/3 [==============================] - 0s 36ms/step - loss: 0.0156 - mse: 0.0156 - val_loss: 0.4267 - val_mse: 0.4267
# Epoch 775/1000
# 3/3 [==============================] - 0s 49ms/step - loss: 0.0156 - mse: 0.0156 - val_loss: 0.4257 - val_mse: 0.4257
# Epoch 776/1000
# 3/3 [==============================] - 0s 51ms/step - loss: 0.0156 - mse: 0.0156 - val_loss: 0.4256 - val_mse: 0.4256
# Epoch 777/1000
# 3/3 [==============================] - 0s 99ms/step - loss: 0.0156 - mse: 0.0156 - val_loss: 0.4257 - val_mse: 0.4257
# Epoch 778/1000
# 3/3 [==============================] - 0s 38ms/step - loss: 0.0156 - mse: 0.0156 - val_loss: 0.4253 - val_mse: 0.4253
# Epoch 779/1000
# 3/3 [==============================] - 0s 34ms/step - loss: 0.0156 - mse: 0.0156 - val_loss: 0.4244 - val_mse: 0.4244
# Epoch 780/1000
# 3/3 [==============================] - 0s 49ms/step - loss: 0.0156 - mse: 0.0156 - val_loss: 0.4235 - val_mse: 0.4235
# Epoch 781/1000
# 3/3 [==============================] - 0s 49ms/step - loss: 0.0156 - mse: 0.0156 - val_loss: 0.4225 - val_mse: 0.4225
# Epoch 782/1000
# 3/3 [==============================] - 0s 36ms/step - loss: 0.0156 - mse: 0.0156 - val_loss: 0.4226 - val_mse: 0.4226
# Epoch 783/1000
# 3/3 [==============================] - 0s 45ms/step - loss: 0.0156 - mse: 0.0156 - val_loss: 0.4247 - val_mse: 0.4247
# Epoch 784/1000
# 3/3 [==============================] - 0s 51ms/step - loss: 0.0156 - mse: 0.0156 - val_loss: 0.4271 - val_mse: 0.4271
# Epoch 785/1000
# 3/3 [==============================] - 0s 35ms/step - loss: 0.0156 - mse: 0.0156 - val_loss: 0.4299 - val_mse: 0.4299
# Epoch 786/1000
# 3/3 [==============================] - 0s 47ms/step - loss: 0.0156 - mse: 0.0156 - val_loss: 0.4291 - val_mse: 0.4291
# Epoch 787/1000
# 3/3 [==============================] - 0s 49ms/step - loss: 0.0156 - mse: 0.0156 - val_loss: 0.4280 - val_mse: 0.4280
# Epoch 788/1000
# 3/3 [==============================] - 0s 41ms/step - loss: 0.0156 - mse: 0.0156 - val_loss: 0.4266 - val_mse: 0.4266
# Epoch 789/1000
# 3/3 [==============================] - 0s 47ms/step - loss: 0.0156 - mse: 0.0156 - val_loss: 0.4258 - val_mse: 0.4258
# Epoch 790/1000
# 3/3 [==============================] - 0s 47ms/step - loss: 0.0156 - mse: 0.0156 - val_loss: 0.4248 - val_mse: 0.4248
# Epoch 791/1000
# 3/3 [==============================] - 0s 90ms/step - loss: 0.0156 - mse: 0.0156 - val_loss: 0.4245 - val_mse: 0.4245
# Epoch 792/1000
# 3/3 [==============================] - 0s 43ms/step - loss: 0.0156 - mse: 0.0156 - val_loss: 0.4252 - val_mse: 0.4252
# Epoch 793/1000
# 3/3 [==============================] - 0s 61ms/step - loss: 0.0156 - mse: 0.0156 - val_loss: 0.4257 - val_mse: 0.4257
# Epoch 794/1000
# 3/3 [==============================] - 0s 50ms/step - loss: 0.0156 - mse: 0.0156 - val_loss: 0.4272 - val_mse: 0.4272
# Epoch 795/1000
# 3/3 [==============================] - 0s 33ms/step - loss: 0.0156 - mse: 0.0156 - val_loss: 0.4296 - val_mse: 0.4296
# Epoch 796/1000
# 3/3 [==============================] - 0s 34ms/step - loss: 0.0156 - mse: 0.0156 - val_loss: 0.4321 - val_mse: 0.4321
# Epoch 797/1000
# 3/3 [==============================] - 0s 48ms/step - loss: 0.0156 - mse: 0.0156 - val_loss: 0.4329 - val_mse: 0.4329
# Epoch 798/1000
# 3/3 [==============================] - 0s 33ms/step - loss: 0.0156 - mse: 0.0156 - val_loss: 0.4327 - val_mse: 0.4327
# Epoch 799/1000
# 3/3 [==============================] - 0s 52ms/step - loss: 0.0156 - mse: 0.0156 - val_loss: 0.4312 - val_mse: 0.4312
# Epoch 800/1000
# 3/3 [==============================] - 0s 48ms/step - loss: 0.0156 - mse: 0.0156 - val_loss: 0.4292 - val_mse: 0.4292
# Epoch 801/1000
# 3/3 [==============================] - 0s 35ms/step - loss: 0.0156 - mse: 0.0156 - val_loss: 0.4273 - val_mse: 0.4273
# Epoch 802/1000
# 3/3 [==============================] - 0s 36ms/step - loss: 0.0156 - mse: 0.0156 - val_loss: 0.4254 - val_mse: 0.4254
# Epoch 803/1000
# 3/3 [==============================] - 0s 36ms/step - loss: 0.0156 - mse: 0.0156 - val_loss: 0.4247 - val_mse: 0.4247
# Epoch 804/1000
# 3/3 [==============================] - 0s 37ms/step - loss: 0.0158 - mse: 0.0158 - val_loss: 0.4295 - val_mse: 0.4295
# Epoch 805/1000
# 3/3 [==============================] - 0s 116ms/step - loss: 0.0156 - mse: 0.0156 - val_loss: 0.4351 - val_mse: 0.4351
# Epoch 806/1000
# 3/3 [==============================] - 0s 50ms/step - loss: 0.0156 - mse: 0.0156 - val_loss: 0.4391 - val_mse: 0.4391
# Epoch 807/1000
# 3/3 [==============================] - 0s 39ms/step - loss: 0.0156 - mse: 0.0156 - val_loss: 0.4414 - val_mse: 0.4414
# The difference in seconds is: 109.87789607048035

# %%
# # Extract the metrics from the history object
loss = history.history['loss']
val_loss = history.history['val_loss']
# r_square = history.history['r_square']
# val_r_square = history.history['val_r_square']

# # Plot loss and val_loss
# plt.figure(figsize=(12, 6))
# plt.plot(loss, label='Training Loss', color='blue')
# plt.plot(val_loss, label='Validation Loss', color='orange')
# plt.title('Training Loss vs Validation Loss')
# plt.xlabel('Epochs')
# plt.ylabel('Loss')
# plt.legend()
# plt.grid()
# plt.show()

# # Plot r_square and val_r_square
# plt.figure(figsize=(12, 6))
# plt.plot(r_square, label='Training R^2', color='green')
# plt.plot(val_r_square, label='Validation R^2', color='red')
# plt.title('Training R^2 vs Validation R^2')
# plt.xlabel('Epochs')
# plt.ylabel('R^2')
# plt.legend()
# plt.grid()
# plt.show()

# %%
# Find the minimum loss for training and validation
min_training_loss = min(loss)
min_validation_loss = min(val_loss)

# Print the results
print(f"Minimum Training Loss: {min_training_loss}")
print(f"Minimum Validation Loss: {min_validation_loss}")
# Out:
# Minimum Training Loss: 0.015597025863826275
# Minimum Validation Loss: 0.15057532489299774

# %%
# # Find the maximum R² values for training and validation
# max_r_square_train = max(r_square)
# max_r_square_val = max(val_r_square)

# # Print the results
# print(f"Maximum Training R²: {max_r_square_train}")
# print(f"Maximum Validation R²: {max_r_square_val}")

# %%
# model = best_model

# %%
# Generate predictions for the training set
Y_train_pred = model.predict(X_train)

# Plot the true values and predictions
plt.figure(figsize=(10, 6))
plt.plot(Y_train, label='True Values', color='blue',  marker='o')
plt.plot(Y_train_pred, label='Predictions', color='red', linestyle='dashed', marker='o')
plt.title('Training True Values vs Predictions')
plt.xlabel('Sample Index')
plt.ylabel('Value')
plt.legend()
plt.show()
# Out:
# 6/6 [==============================] - 1s 5ms/step

# %%
# Generate predictions for the validation set
Y_val_pred = model.predict(X_val)

# Plot the true values and predictions
plt.figure(figsize=(10, 6))
plt.plot(Y_val, label='True Values', color='blue', marker='o')
plt.plot(Y_val_pred, label='Predictions', color='red', linestyle='dashed', marker='o')
plt.title('Validation True Values vs Predictions')
plt.xlabel('Sample Index')
plt.ylabel('Value')
plt.legend()
plt.show()
# Out:
# 2/2 [==============================] - 0s 8ms/step

# %%
# Generate predictions for the validation set
Y_val_pred = model.predict(X_val)
Y_val_pred = np.where(Y_val_pred > 0.5, 1,np.where(Y_val_pred<-0.5, -1, 0) )

# Plot the true values and predictions
plt.figure(figsize=(10, 6))
plt.plot(Y_val, label='True Values', color='blue', marker='o')
plt.plot(Y_val_pred, label='Predictions', color='red', linestyle='dashed', marker='o')
plt.title('Validation True Values vs Predictions')
plt.xlabel('Sample Index')
plt.ylabel('Value')
plt.legend()
plt.show()
# Out:
# 2/2 [==============================] - 0s 23ms/step

# %%
from sklearn.metrics import confusion_matrix

# Create confusion matrix
conf_matrix = confusion_matrix(Y_val.flatten(), Y_val_pred.flatten())

# Print the confusion matrix
print("Confusion Matrix:")
print(conf_matrix)
# Out:
# Confusion Matrix:
# [[ 2  5]
#  [ 1 26]]

# %%
# import matplotlib.pyplot as plt
# import numpy as np

# # Generate predictions for the validation set
# Y_val_pred = model.predict(X_val)
# Y_val_pred = np.where(Y_val_pred > 0.5, 1, np.where(Y_val_pred < -0.5, -1, 0))

# # Plot
# plt.figure(figsize=(12, 6))

# # Add soft gray vertical lines for each sample
# for i in range(len(Y_val)):
#     plt.axvline(x=i, color='gray', linestyle='-', linewidth=0.5, alpha=0.3)

# # Plot true values and predictions as scatter
# plt.scatter(range(len(Y_val)), Y_val, label='True Values', color='blue', marker='o')
# plt.scatter(range(len(Y_val_pred)), Y_val_pred, label='Predictions', color='red', marker='o')

# # Styling
# plt.title('Validation True Values vs Predictions')
# plt.xlabel('Sample Index')
# plt.ylabel('Value')
# plt.legend()
# plt.grid(False)  # Remove default grid
# plt.tight_layout()
# plt.show()

# %%
# from sklearn.metrics import confusion_matrix

# # Create confusion matrix
# conf_matrix = confusion_matrix(Y_val.flatten(), Y_val_pred.flatten())

# # Print the confusion matrix
# print("Confusion Matrix:")
# print(conf_matrix)

# %%
# Calculate total accuracy
total_accuracy = np.sum(Y_val.flatten() == Y_val_pred.flatten()) / len(Y_val)
print(f"Total Accuracy: {total_accuracy * 100:.2f}%")
# Out:
# Total Accuracy: 82.35%

# %%
# # Generate predictions for the validation set
# Y_val_pred = model.predict(X_test_filtered)
# Y_val_pred = np.where(Y_val_pred > 0.42, 1, -1)

# # Plot the true values and predictions
# plt.figure(figsize=(10, 6))
# plt.plot(Y_test_filtered, label='True Values', color='blue', marker='o')
# plt.plot(Y_val_pred, label='Predictions', color='red', linestyle='dashed', marker='o')
# plt.title('Validation True Values vs Predictions')
# plt.xlabel('Sample Index')
# plt.ylabel('Value')
# plt.legend()
# plt.show()

# %%
# import matplotlib.pyplot as plt
# import numpy as np

# # Generate predictions for the validation set
# Y_val_pred = model.predict(X_test_filtered)
# Y_val_pred = np.where(Y_val_pred > 0.2, 1, -1)

# # Plot the true values and predictions
# plt.figure(figsize=(12, 6))

# # Add soft gray vertical lines for each sample index
# for i in range(len(Y_test_filtered)):
#     plt.axvline(x=i, color='gray', linestyle='-', linewidth=0.5, alpha=0.7)

# # Plot using scatter (no connecting lines)
# plt.scatter(range(len(Y_test_filtered)), Y_test_filtered, label='True Values', color='blue', marker='o')
# plt.scatter(range(len(Y_val_pred)), Y_val_pred, label='Predictions', color='red', marker='o')

# # Labels and title
# plt.title('Validation True Values vs Predictions')
# plt.xlabel('Sample Index')
# plt.ylabel('Value')
# plt.legend()
# plt.grid(False)
# plt.tight_layout()
# plt.show()

# %%
# import matplotlib.pyplot as plt
# import numpy as np

# # Generate predictions for the validation set
# Y_val_pred = model.predict(X_test_filtered)
# Y_val_pred = np.where(Y_val_pred > 0.42, 1, -1)

# # Flatten if needed
# Y_val_pred = Y_val_pred.flatten()
# Y_test_filtered = Y_test_filtered.flatten()

# # Prepare index and classification of correctness
# indices = np.arange(len(Y_test_filtered))
# correct = Y_val_pred == Y_test_filtered
# incorrect = ~correct

# # Plot the figure
# plt.figure(figsize=(12, 6))

# # Add vertical gray lines
# for i in range(len(Y_test_filtered)):
#     plt.axvline(x=i, color='gray', linestyle='-', linewidth=0.7, alpha=0.7)

# # Plot true values as reference shadow
# # plt.scatter(indices, Y_test_filtered, color='blue', label='True Value (Reference)', marker='o', alpha=0.3)

# # Plot correct predictions (overlapping with true values)
# plt.scatter(indices[correct], Y_val_pred[correct], color='blue', marker='o', label='Correct Prediction')

# # Plot incorrect predictions
# plt.scatter(indices[incorrect], Y_val_pred[incorrect], color='red', marker='o', label='Incorrect Prediction')

# # Labels and title
# plt.title('Testing True Values vs Predictions')
# plt.xlabel('Sample Index')
# plt.ylabel('Value')
# plt.legend()
# plt.grid(False)
# plt.tight_layout()
# plt.show()

# %%
# from sklearn.metrics import confusion_matrix

# # Create confusion matrix
# conf_matrix = confusion_matrix(Y_test_filtered.flatten(), Y_val_pred.flatten())

# # Print the confusion matrix
# print("Confusion Matrix:")
# print(conf_matrix)

# %%
# # Calculate total accuracy
# total_accuracy = np.sum(Y_test_filtered.flatten() == Y_val_pred.flatten()) / len(Y_test_filtered)
# print(f"Total Accuracy: {total_accuracy * 100:.2f}%")
