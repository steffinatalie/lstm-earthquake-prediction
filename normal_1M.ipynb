# %%
import numpy as np
import matplotlib.pyplot as plt
import math
from collections import Counter
import pandas as pd

# %%
bali = pd.read_csv('bali_min4.csv')
jabar = pd.read_csv('jawabarat_min4.csv')
# df = pd.concat([bali, jabar], axis=0)
jatengjatim = pd.read_csv('jatengjatim_min4.csv')
# df = pd.concat([bali, jatengjatim], axis=0)
# df = pd.concat([jabar, jatengjatim], axis=0)
df = pd.concat([bali, jabar, jatengjatim], axis=0)
# df = pd.read_csv('southern_california_min25.csv')
df['timestamp'] = pd.to_datetime(df['time'], errors='coerce', utc=False)
df['Datetime'] = df['timestamp']
df.set_index('timestamp', inplace=True)
df = df.sort_index(ascending=True)
df
# Out:
#                                                       time  latitude  \
# timestamp
# 1995-01-01 02:02:25.490000+00:00  1995-01-01T02:02:25.490Z  -10.9270
# 1995-01-07 15:02:59.810000+00:00  1995-01-07T15:02:59.810Z   -9.0250
# 1995-01-07 18:37:28.920000+00:00  1995-01-07T18:37:28.920Z   -9.2310
# 1995-01-19 09:19:57.180000+00:00  1995-01-19T09:19:57.180Z  -10.7640
# 1995-02-16 16:27:25.400000+00:00  1995-02-16T16:27:25.400Z  -10.0560
# ...                                                    ...       ...
# 2020-12-20 15:16:45.796000+00:00  2020-12-20T15:16:45.796Z   -9.2506
# 2020-12-20 15:53:57.395000+00:00  2020-12-20T15:53:57.395Z   -9.2936
# 2020-12-22 03:27:21.031000+00:00  2020-12-22T03:27:21.031Z   -9.5505
# 2020-12-24 22:09:10.232000+00:00  2020-12-24T22:09:10.232Z   -9.0282
# 2020-12-26 18:23:21.550000+00:00  2020-12-26T18:23:21.550Z   -9.0928
#
#                                   longitude   depth  mag magType  nst    gap  \
# timestamp
# 1995-01-01 02:02:25.490000+00:00   113.0110   18.90  4.5      mb  NaN    NaN
# 1995-01-07 15:02:59.810000+00:00   110.7550  114.80  4.7      mb  NaN    NaN
# 1995-01-07 18:37:28.920000+00:00   117.1110   33.00  4.2      mb  NaN    NaN
# 1995-01-19 09:19:57.180000+00:00   117.1200   33.00  4.9      mb  NaN    NaN
# 1995-02-16 16:27:25.400000+00:00   113.8580   33.00  4.0      mb  NaN    NaN
# ...                                     ...     ...  ...     ...  ...    ...
# 2020-12-20 15:16:45.796000+00:00   110.8510   35.00  4.2      mb  NaN  148.0
# 2020-12-20 15:53:57.395000+00:00   112.1503   35.00  4.3      mb  NaN   53.0
# 2020-12-22 03:27:21.031000+00:00   112.5698   35.00  4.1      mb  NaN  120.0
# 2020-12-24 22:09:10.232000+00:00   117.3729  104.10  4.4      mb  NaN   95.0
# 2020-12-26 18:23:21.550000+00:00   117.1835   63.84  4.1      mb  NaN   71.0
#
#                                    dmin   rms  ...  \
# timestamp                                      ...
# 1995-01-01 02:02:25.490000+00:00    NaN  1.20  ...
# 1995-01-07 15:02:59.810000+00:00    NaN  0.80  ...
# 1995-01-07 18:37:28.920000+00:00    NaN  0.90  ...
# 1995-01-19 09:19:57.180000+00:00    NaN  1.30  ...
# 1995-02-16 16:27:25.400000+00:00    NaN  0.40  ...
# ...                                 ...   ...  ...
# 2020-12-20 15:16:45.796000+00:00  1.368  0.58  ...
# 2020-12-20 15:53:57.395000+00:00  2.114  0.90  ...
# 2020-12-22 03:27:21.031000+00:00  1.896  0.94  ...
# 2020-12-24 22:09:10.232000+00:00  3.231  0.54  ...
# 2020-12-26 18:23:21.550000+00:00  3.059  0.62  ...
#
#                                                                   place  \
# timestamp
# 1995-01-01 02:02:25.490000+00:00         294 km S of Kencong, Indonesia
# 1995-01-07 15:02:59.810000+00:00       126 km SSE of Pundong, Indonesia
# 1995-01-07 18:37:28.920000+00:00  88 km SSW of Sumbawa Besar, Indonesia
# 1995-01-19 09:19:57.180000+00:00         246 km SSE of Praya, Indonesia
# 1995-02-16 16:27:25.400000+00:00   186 km S of Gambiran Satu, Indonesia
# ...                                                                 ...
# 2020-12-20 15:16:45.796000+00:00       153 km SSE of Pundong, Indonesia
# 2020-12-20 15:53:57.395000+00:00  130 km SSW of Sumberpucung, Indonesia
# 2020-12-22 03:27:21.031000+00:00          149 km S of Dampit, Indonesia
# 2020-12-24 22:09:10.232000+00:00    59 km S of Sumbawa Besar, Indonesia
# 2020-12-26 18:23:21.550000+00:00  71 km SSW of Sumbawa Besar, Indonesia
#
#                                         type horizontalError depthError  \
# timestamp
# 1995-01-01 02:02:25.490000+00:00  earthquake             NaN        8.5
# 1995-01-07 15:02:59.810000+00:00  earthquake             NaN       21.5
# 1995-01-07 18:37:28.920000+00:00  earthquake             NaN        NaN
# 1995-01-19 09:19:57.180000+00:00  earthquake             NaN        NaN
# 1995-02-16 16:27:25.400000+00:00  earthquake             NaN        NaN
# ...                                      ...             ...        ...
# 2020-12-20 15:16:45.796000+00:00  earthquake             8.9        1.9
# 2020-12-20 15:53:57.395000+00:00  earthquake             5.3        2.0
# 2020-12-22 03:27:21.031000+00:00  earthquake             5.6        1.9
# 2020-12-24 22:09:10.232000+00:00  earthquake             7.6        8.3
# 2020-12-26 18:23:21.550000+00:00  earthquake             7.1        8.5
#
#                                  magError  magNst    status  locationSource  \
# timestamp
# 1995-01-01 02:02:25.490000+00:00      NaN     4.0  reviewed              us
# 1995-01-07 15:02:59.810000+00:00      NaN    12.0  reviewed              us
# 1995-01-07 18:37:28.920000+00:00      NaN     5.0  reviewed              us
# 1995-01-19 09:19:57.180000+00:00      NaN     8.0  reviewed              us
# 1995-02-16 16:27:25.400000+00:00      NaN     5.0  reviewed              us
# ...                                   ...     ...       ...             ...
# 2020-12-20 15:16:45.796000+00:00    0.186     8.0  reviewed              us
# 2020-12-20 15:53:57.395000+00:00    0.142    14.0  reviewed              us
# 2020-12-22 03:27:21.031000+00:00    0.175     9.0  reviewed              us
# 2020-12-24 22:09:10.232000+00:00    0.134    16.0  reviewed              us
# 2020-12-26 18:23:21.550000+00:00    0.165    13.0  reviewed              us
#
#                                   magSource                         Datetime
# timestamp
# 1995-01-01 02:02:25.490000+00:00         us 1995-01-01 02:02:25.490000+00:00
# 1995-01-07 15:02:59.810000+00:00         us 1995-01-07 15:02:59.810000+00:00
# 1995-01-07 18:37:28.920000+00:00         us 1995-01-07 18:37:28.920000+00:00
# 1995-01-19 09:19:57.180000+00:00         us 1995-01-19 09:19:57.180000+00:00
# 1995-02-16 16:27:25.400000+00:00         us 1995-02-16 16:27:25.400000+00:00
# ...                                     ...                              ...
# 2020-12-20 15:16:45.796000+00:00         us 2020-12-20 15:16:45.796000+00:00
# 2020-12-20 15:53:57.395000+00:00         us 2020-12-20 15:53:57.395000+00:00
# 2020-12-22 03:27:21.031000+00:00         us 2020-12-22 03:27:21.031000+00:00
# 2020-12-24 22:09:10.232000+00:00         us 2020-12-24 22:09:10.232000+00:00
# 2020-12-26 18:23:21.550000+00:00         us 2020-12-26 18:23:21.550000+00:00
#
# [1698 rows x 23 columns]

# %%
df = df[['depth', 'mag']]
df
# Out:
#                                    depth  mag
# timestamp
# 1995-01-01 02:02:25.490000+00:00   18.90  4.5
# 1995-01-07 15:02:59.810000+00:00  114.80  4.7
# 1995-01-07 18:37:28.920000+00:00   33.00  4.2
# 1995-01-19 09:19:57.180000+00:00   33.00  4.9
# 1995-02-16 16:27:25.400000+00:00   33.00  4.0
# ...                                  ...  ...
# 2020-12-20 15:16:45.796000+00:00   35.00  4.2
# 2020-12-20 15:53:57.395000+00:00   35.00  4.3
# 2020-12-22 03:27:21.031000+00:00   35.00  4.1
# 2020-12-24 22:09:10.232000+00:00  104.10  4.4
# 2020-12-26 18:23:21.550000+00:00   63.84  4.1
#
# [1698 rows x 2 columns]

# %%
print(df.isna().sum())
# Out:
# depth    0
# mag      0
# dtype: int64

# %%
mag_unique, frequency = np.unique(df['mag'], return_counts=True)

plt.figure(figsize=(10,8))
plt.hist(df['mag'], bins=1000, color='black', edgecolor='black')

bins = [0, 20, 40, 60]

from matplotlib.ticker import MultipleLocator
# Set x-axis scale to increment by 0.5
plt.gca().xaxis.set_major_locator(MultipleLocator(0.2))
# Add titles and labels
plt.title('Frequency by Magnitude')
plt.xlabel('Magnitude')
plt.ylabel('Frequency')
plt.xticks(fontsize=12, fontname='Times New Roman', rotation=45)

# Show the plot
plt.show()

# %%
mag_filter = 4.5
depth_filter = 100
resample_rate = '1M'

# %%
# def occurence_criterion(raw_array):
#     print(raw_array)
#     print("---------------------")
#     target = -1
#     if len(raw_array) > 0:
#         if raw_array['earthquake'].eq(1).any():
#             target = 1
#         if raw_array['earthquake'].eq(0).any():
#             target = 0
#     if len(raw_array) == 0:
#         target = 0

        
#     return target

# earthquake_occurence = df.resample(resample_rate).apply(occurence_criterion)

# earthquake_occurence = earthquake_occurence.to_frame(name='earthquake')

# earthquake_occurence = earthquake_occurence.sort_index(ascending=True)
# earthquake_occurence['earthquake'].value_counts()

# %%
# Initialize the 'ED' column with NaN values
df['ED'] = np.nan

# Filter the dataframe for earthquakes with magnitude greater than mag_filter
filtered_df = df[df['mag'] > mag_filter]

n = 50

# Calculate the elapsed days for the last n earthquake events
for i in range(n, len(filtered_df)):
    current_time = filtered_df.index[i]
    past_time = filtered_df.index[i-n]
    elapsed_days = (current_time - past_time).days
    df.loc[current_time, 'ED'] = elapsed_days

# Fill NaN values in 'ED' column
for i in range(len(df)):
    if pd.isna(df.iloc[i]['ED']):
        # Find the latest valid 'ED' value before the current index
        last_valid_index = df.iloc[:i]['ED'].last_valid_index()
        if last_valid_index is not None:
            time_since_last_valid = (df.index[i] - last_valid_index).days
            df.at[df.index[i], 'ED'] = df.at[last_valid_index, 'ED'] + time_since_last_valid

# df = df.dropna(subset=['ED'])
df
# Out:
# C:\Users\SteinSteffi1\AppData\Local\Temp\ipykernel_9012\388928700.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['ED'] = np.nan
#                                    depth  mag     ED
# timestamp
# 1995-01-01 02:02:25.490000+00:00   18.90  4.5    NaN
# 1995-01-07 15:02:59.810000+00:00  114.80  4.7    NaN
# 1995-01-07 18:37:28.920000+00:00   33.00  4.2    NaN
# 1995-01-19 09:19:57.180000+00:00   33.00  4.9    NaN
# 1995-02-16 16:27:25.400000+00:00   33.00  4.0    NaN
# ...                                  ...  ...    ...
# 2020-12-20 15:16:45.796000+00:00   35.00  4.2  875.0
# 2020-12-20 15:53:57.395000+00:00   35.00  4.3  875.0
# 2020-12-22 03:27:21.031000+00:00   35.00  4.1  876.0
# 2020-12-24 22:09:10.232000+00:00  104.10  4.4  878.0
# 2020-12-26 18:23:21.550000+00:00   63.84  4.1  879.0
#
# [1698 rows x 3 columns]

# %%
# Initialize the 'energy_squared' and 'cumulative_energy_squared' columns with NaN values
df['energy_squared_root'] = np.nan
df['cumulative_energy_squared'] = np.nan

df['energy'] = 10**(11.8+1.5*df['mag'])

# Calculate the energy squared for each data point
df['energy_squared_root'] = np.sqrt(df['energy'])

# Calculate the cumulative sum of energy squared for the last 50 data points
# for i in range(n, len(df)):
#     df.iloc[i, df.columns.get_loc('cumulative_energy_squared')] = df.iloc[i-n:i]['energy_squared_root'].sum()

df['cumulative_energy_squared'] = df['energy_squared_root'].rolling(n).sum()

# Calculate the RSRER
df['RSRER'] = df['cumulative_energy_squared'] / df['ED']

df['mean_mag'] = df['mag'].rolling(n).mean()
df['min_mag'] = df['mag'].rolling(n).min()
df['b_value'] = np.log10(np.e)/(df['mean_mag'] - df['min_mag'])

df['event_counts'] = df['mag'].rolling(n).apply(lambda x: (x > mag_filter).sum(), raw=True)
df['a_value'] = (np.log10(df['event_counts']) + df['b_value']*df['min_mag'])/n
# df['MSD'] = np.sum((np.log10(df['event_counts'])-(df['a_value']-(df['b_value']*df['mag'])))**2)/(n-1)
df['max_mag'] = df['mag'].rolling(n).max()
df['MD'] = df['a_value']/df['b_value'] - df['max_mag']
# print(df['event_counts'])

df
# Out:
# C:\Users\SteinSteffi1\AppData\Local\Temp\ipykernel_9012\2738765218.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['energy_squared_root'] = np.nan
# C:\Users\SteinSteffi1\AppData\Local\Temp\ipykernel_9012\2738765218.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['cumulative_energy_squared'] = np.nan
# C:\Users\SteinSteffi1\AppData\Local\Temp\ipykernel_9012\2738765218.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['energy'] = 10**(11.8+1.5*df['mag'])
# C:\Users\SteinSteffi1\AppData\Local\Temp\ipykernel_9012\2738765218.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['energy_squared_root'] = np.sqrt(df['energy'])
# C:\Users\SteinSteffi1\AppData\Local\Temp\ipykernel_9012\2738765218.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['cumulative_energy_squared'] = df['energy_squared_root'].rolling(n).sum()
# C:\Users\SteinSteffi1\AppData\Local\Temp\ipykernel_9012\2738765218.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['RSRER'] = df['cumulative_energy_squared'] / df['ED']
# C:\Users\SteinSteffi1\AppData\Local\Temp\ipykernel_9012\2738765218.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['mean_mag'] = df['mag'].rolling(n).mean()
# C:\Users\SteinSteffi1\AppData\Local\Temp\ipykernel_9012\2738765218.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['min_mag'] = df['mag'].rolling(n).min()
# C:\Users\SteinSteffi1\AppData\Local\Temp\ipykernel_9012\2738765218.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['b_value'] = np.log10(np.e)/(df['mean_mag'] - df['min_mag'])
# C:\Users\SteinSteffi1\AppData\Local\Temp\ipykernel_9012\2738765218.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['event_counts'] = df['mag'].rolling(n).apply(lambda x: (x > mag_filter).sum(), raw=True)
# C:\Users\SteinSteffi1\AppData\Local\Temp\ipykernel_9012\2738765218.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['a_value'] = (np.log10(df['event_counts']) + df['b_value']*df['min_mag'])/n
# C:\Users\SteinSteffi1\AppData\Local\Temp\ipykernel_9012\2738765218.py:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['max_mag'] = df['mag'].rolling(n).max()
# C:\Users\SteinSteffi1\AppData\Local\Temp\ipykernel_9012\2738765218.py:27: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['MD'] = df['a_value']/df['b_value'] - df['max_mag']
#                                    depth  mag     ED  energy_squared_root  \
# timestamp
# 1995-01-01 02:02:25.490000+00:00   18.90  4.5    NaN         1.883649e+09
# 1995-01-07 15:02:59.810000+00:00  114.80  4.7    NaN         2.660725e+09
# 1995-01-07 18:37:28.920000+00:00   33.00  4.2    NaN         1.122018e+09
# 1995-01-19 09:19:57.180000+00:00   33.00  4.9    NaN         3.758374e+09
# 1995-02-16 16:27:25.400000+00:00   33.00  4.0    NaN         7.943282e+08
# ...                                  ...  ...    ...                  ...
# 2020-12-20 15:16:45.796000+00:00   35.00  4.2  875.0         1.122018e+09
# 2020-12-20 15:53:57.395000+00:00   35.00  4.3  875.0         1.333521e+09
# 2020-12-22 03:27:21.031000+00:00   35.00  4.1  876.0         9.440609e+08
# 2020-12-24 22:09:10.232000+00:00  104.10  4.4  878.0         1.584893e+09
# 2020-12-26 18:23:21.550000+00:00   63.84  4.1  879.0         9.440609e+08
#
#                                   cumulative_energy_squared        energy  \
# timestamp
# 1995-01-01 02:02:25.490000+00:00                        NaN  3.548134e+18
# 1995-01-07 15:02:59.810000+00:00                        NaN  7.079458e+18
# 1995-01-07 18:37:28.920000+00:00                        NaN  1.258925e+18
# 1995-01-19 09:19:57.180000+00:00                        NaN  1.412538e+19
# 1995-02-16 16:27:25.400000+00:00                        NaN  6.309573e+17
# ...                                                     ...           ...
# 2020-12-20 15:16:45.796000+00:00               9.353097e+10  1.258925e+18
# 2020-12-20 15:53:57.395000+00:00               9.353097e+10  1.778279e+18
# 2020-12-22 03:27:21.031000+00:00               9.259138e+10  8.912509e+17
# 2020-12-24 22:09:10.232000+00:00               9.259138e+10  2.511886e+18
# 2020-12-26 18:23:21.550000+00:00               9.220192e+10  8.912509e+17
#
#                                          RSRER  mean_mag  min_mag   b_value  \
# timestamp
# 1995-01-01 02:02:25.490000+00:00           NaN       NaN      NaN       NaN
# 1995-01-07 15:02:59.810000+00:00           NaN       NaN      NaN       NaN
# 1995-01-07 18:37:28.920000+00:00           NaN       NaN      NaN       NaN
# 1995-01-19 09:19:57.180000+00:00           NaN       NaN      NaN       NaN
# 1995-02-16 16:27:25.400000+00:00           NaN       NaN      NaN       NaN
# ...                                        ...       ...      ...       ...
# 2020-12-20 15:16:45.796000+00:00  1.068925e+08     4.430      4.0  1.009987
# 2020-12-20 15:53:57.395000+00:00  1.068925e+08     4.430      4.0  1.009987
# 2020-12-22 03:27:21.031000+00:00  1.056979e+08     4.422      4.0  1.029134
# 2020-12-24 22:09:10.232000+00:00  1.054572e+08     4.422      4.0  1.029134
# 2020-12-26 18:23:21.550000+00:00  1.048941e+08     4.418      4.0  1.038982
#
#                                   event_counts   a_value  max_mag        MD
# timestamp
# 1995-01-01 02:02:25.490000+00:00           NaN       NaN      NaN       NaN
# 1995-01-07 15:02:59.810000+00:00           NaN       NaN      NaN       NaN
# 1995-01-07 18:37:28.920000+00:00           NaN       NaN      NaN       NaN
# 1995-01-19 09:19:57.180000+00:00           NaN       NaN      NaN       NaN
# 1995-02-16 16:27:25.400000+00:00           NaN       NaN      NaN       NaN
# ...                                        ...       ...      ...       ...
# 2020-12-20 15:16:45.796000+00:00          13.0  0.103078      5.2 -5.097941
# 2020-12-20 15:53:57.395000+00:00          13.0  0.103078      5.2 -5.097941
# 2020-12-22 03:27:21.031000+00:00          13.0  0.104610      5.2 -5.098352
# 2020-12-24 22:09:10.232000+00:00          13.0  0.104610      5.2 -5.098352
# 2020-12-26 18:23:21.550000+00:00          13.0  0.105397      5.2 -5.098557
#
# [1698 rows x 14 columns]

# %%
# Drop the intermediate columns
df.drop(columns=['energy_squared_root', 'cumulative_energy_squared', 'mean_mag', 'min_mag', 'event_counts', 'a_value', 'max_mag'], inplace=True)
# Out:
# C:\Users\SteinSteffi1\AppData\Local\Temp\ipykernel_9012\1093842324.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.drop(columns=['energy_squared_root', 'cumulative_energy_squared', 'mean_mag', 'min_mag', 'event_counts', 'a_value', 'max_mag'], inplace=True)

# %%
df.dropna(subset=['RSRER'], inplace=True)
df.isna().sum()
# Out:
# C:\Users\SteinSteffi1\AppData\Local\Temp\ipykernel_9012\2534608267.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.dropna(subset=['RSRER'], inplace=True)
# depth      0
# mag        0
# ED         0
# energy     0
# RSRER      0
# b_value    0
# MD         0
# dtype: int64

# %%
df['earthquake'] = np.where((df['mag'] > mag_filter) & (df['depth'] < depth_filter), 1,  0) 

df['earthquake'].value_counts()
# Out:
# C:\Users\SteinSteffi1\AppData\Local\Temp\ipykernel_9012\3861059285.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['earthquake'] = np.where((df['mag'] > mag_filter) & (df['depth'] < depth_filter), 1,  0)
# earthquake
# 0    848
# 1    673
# Name: count, dtype: int64

# %%
def occurence_criterion(raw_array):
    # print(raw_array)
    # print("---------------------")
    target = 0
    if len(raw_array) > 0:
        if raw_array['earthquake'].eq(1).any():
            target = 1
        if raw_array['earthquake'].eq(0).all():
            target = 0
    # if len(raw_array) == 0:
    #     target = 0

        
    return target


earthquake_occurence = df[['earthquake']].resample(resample_rate).apply(occurence_criterion)
# print(earthquake_occurence.value_counts())
monthly_df = df.resample(resample_rate).mean()
# monthly_df = monthly_df.fillna(0)
monthly_df = monthly_df.dropna()
monthly_df['earthquake'] = earthquake_occurence
print(monthly_df['earthquake'].value_counts())
# Out:
# C:\Users\SteinSteffi1\AppData\Local\Temp\ipykernel_9012\3117913790.py:17: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   earthquake_occurence = df[['earthquake']].resample(resample_rate).apply(occurence_criterion)
# C:\Users\SteinSteffi1\AppData\Local\Temp\ipykernel_9012\3117913790.py:19: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   monthly_df = df.resample(resample_rate).mean()
# earthquake
# 1    189
# 0     47
# Name: count, dtype: int64

# %%
df = monthly_df[['depth', 'mag', 'ED', 'RSRER', 'b_value', 'MD', 'earthquake']]
# df = monthly_df[['mag', 'ED','MD', 'earthquake']]
df
# Out:
#                                depth       mag           ED         RSRER  \
# timestamp
# 2000-06-30 00:00:00+00:00  42.400000  4.466667  1976.333333  6.731465e+07
# 2000-07-31 00:00:00+00:00  61.000000  4.300000  1911.666667  6.605044e+07
# 2000-08-31 00:00:00+00:00  69.166667  4.733333  1802.666667  6.976356e+07
# 2000-09-30 00:00:00+00:00  33.000000  4.800000  1720.000000  7.443554e+07
# 2000-10-31 00:00:00+00:00  33.000000  4.400000  1708.666667  7.245997e+07
# ...                              ...       ...          ...           ...
# 2020-07-31 00:00:00+00:00  41.480000  4.475000   793.250000  1.226671e+08
# 2020-08-31 00:00:00+00:00  29.616667  4.683333   769.500000  1.229447e+08
# 2020-09-30 00:00:00+00:00  38.920000  4.500000   783.250000  1.258752e+08
# 2020-10-31 00:00:00+00:00  39.796667  4.400000   813.666667  1.249103e+08
# 2020-12-31 00:00:00+00:00  48.049091  4.281818   870.909091  1.102451e+08
#
#                             b_value        MD  earthquake
# timestamp
# 2000-06-30 00:00:00+00:00  0.787837 -5.686084           1
# 2000-07-31 00:00:00+00:00  0.806484 -5.686699           1
# 2000-08-31 00:00:00+00:00  0.789647 -5.685196           1
# 2000-09-30 00:00:00+00:00  0.770026 -5.683691           1
# 2000-10-31 00:00:00+00:00  0.802452 -5.685743           1
# ...                             ...       ...         ...
# 2020-07-31 00:00:00+00:00  0.959921 -4.870344           1
# 2020-08-31 00:00:00+00:00  0.996355 -4.929817           1
# 2020-09-30 00:00:00+00:00  0.961991 -5.095252           1
# 2020-10-31 00:00:00+00:00  0.928547 -5.093374           1
# 2020-12-31 00:00:00+00:00  0.984145 -5.096561           1
#
# [236 rows x 7 columns]

# %%
correlation_matrix = df.corr()
correlation_matrix
# Out:
#                depth       mag        ED     RSRER   b_value        MD  \
# depth       1.000000 -0.198931  0.167325 -0.256542  0.237642 -0.001971
# mag        -0.198931  1.000000  0.052948  0.059047 -0.261769 -0.187194
# ED          0.167325  0.052948  1.000000 -0.368020 -0.178110 -0.137300
# RSRER      -0.256542  0.059047 -0.368020  1.000000 -0.158173  0.000729
# b_value     0.237642 -0.261769 -0.178110 -0.158173  1.000000  0.568635
# MD         -0.001971 -0.187194 -0.137300  0.000729  0.568635  1.000000
# earthquake -0.237962  0.536719 -0.074258  0.076379 -0.102987 -0.063872
#
#             earthquake
# depth        -0.237962
# mag           0.536719
# ED           -0.074258
# RSRER         0.076379
# b_value      -0.102987
# MD           -0.063872
# earthquake    1.000000

# %%
# Replace infinite values with a large number
df.replace([np.inf, -np.inf], 1e10, inplace=True)
# Out:
# C:\Users\SteinSteffi1\AppData\Local\Temp\ipykernel_9012\2297783001.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.replace([np.inf, -np.inf], 1e10, inplace=True)

# %%
from sklearn.preprocessing import MinMaxScaler

# Initialize the MinMaxScaler with the desired feature range
scaler = MinMaxScaler(feature_range=(-1, 1))

# Apply the scaler to the first 6 columns of the dataframe
df.iloc[:, :6] = scaler.fit_transform(df.iloc[:, :6])

# Display the dataframe
df
# Out:
#                               depth       mag        ED     RSRER   b_value  \
# timestamp
# 2000-06-30 00:00:00+00:00 -0.227099 -0.333333  1.000000 -0.999711 -0.626768
# 2000-07-31 00:00:00+00:00  0.216603 -0.571429  0.933845 -0.999965 -0.583338
# 2000-08-31 00:00:00+00:00  0.411419  0.047619  0.822337 -0.999218 -0.622552
# 2000-09-30 00:00:00+00:00 -0.451336  0.142857  0.737768 -0.998277 -0.668254
# 2000-10-31 00:00:00+00:00 -0.451336 -0.428571  0.726174 -0.998675 -0.592727
# ...                             ...       ...       ...       ...       ...
# 2020-07-31 00:00:00+00:00 -0.249046 -0.321429 -0.210307 -0.988567 -0.225960
# 2020-08-31 00:00:00+00:00 -0.532045 -0.023810 -0.234604 -0.988511 -0.141100
# 2020-09-30 00:00:00+00:00 -0.310115 -0.285714 -0.220537 -0.987921 -0.221140
# 2020-10-31 00:00:00+00:00 -0.289202 -0.428571 -0.189421 -0.988115 -0.299034
# 2020-12-31 00:00:00+00:00 -0.092340 -0.597403 -0.130861 -0.991068 -0.169538
#
#                                  MD  earthquake
# timestamp
# 2000-06-30 00:00:00+00:00  0.008768           1
# 2000-07-31 00:00:00+00:00  0.008078           1
# 2000-08-31 00:00:00+00:00  0.009764           1
# 2000-09-30 00:00:00+00:00  0.011452           1
# 2000-10-31 00:00:00+00:00  0.009150           1
# ...                             ...         ...
# 2020-07-31 00:00:00+00:00  0.923755           1
# 2020-08-31 00:00:00+00:00  0.857046           1
# 2020-09-30 00:00:00+00:00  0.671483           1
# 2020-10-31 00:00:00+00:00  0.673590           1
# 2020-12-31 00:00:00+00:00  0.670015           1
#
# [236 rows x 7 columns]

# %%
import numpy as np

def create_lstm_dataset(df, lookback, n_future):
    """
    Creates an LSTM dataset from the given DataFrame.

    Parameters:
    - df: pandas DataFrame containing features.
    - lookback: Number of past timesteps to include in each X sample.

    Returns:
    - X: 3D NumPy array of shape (samples, lookback, features)
    - Y: 1D NumPy array of shape (samples,)
    """
    data = df.values  # Convert dataframe to NumPy array
    X, Y = [], []
    
    for i in range(len(data) - lookback):
        X.append(data[i:i + lookback, :7])  # First 6 columns
        Y.append(data[(i + lookback):(i + lookback + n_future), -1])     # 7th column as label
    
    return np.array(X), np.array(Y)
look_back = 30
X, Y = create_lstm_dataset(df, lookback=look_back, n_future=1)

print(X.shape)  # (number of samples, lookback, 6)
print(Y.shape)  # (number of samples,)
# Out:
# (206, 30, 7)
# (206, 1)

# %%
from sklearn.model_selection import train_test_split

# Split the data
X_train, X_val, Y_train, Y_val = train_test_split(X, Y, test_size=0.15, shuffle=False)

# Print the shapes of the resulting datasets
print("X_train shape:", X_train.shape)
print("X_val shape:", X_val.shape)
print("Y_train shape:", Y_train.shape)
print("Y_val shape:", Y_val.shape)
# Out:
# X_train shape: (175, 30, 7)
# X_val shape: (31, 30, 7)
# Y_train shape: (175, 1)
# Y_val shape: (31, 1)

# %%
print(X_train[0])
# Out:
# [[-2.27099237e-01 -3.33333333e-01  1.00000000e+00 -9.99710707e-01
#   -6.26767998e-01  8.76777696e-03  1.00000000e+00]
#  [ 2.16603053e-01 -5.71428571e-01  9.33845293e-01 -9.99965226e-01
#   -5.83337591e-01  8.07798523e-03  1.00000000e+00]
#  [ 4.11418575e-01  4.76190476e-02  8.22337103e-01 -9.99217676e-01
#   -6.22552276e-01  9.76367184e-03  1.00000000e+00]
#  [-4.51335878e-01  1.42857143e-01  7.37768199e-01 -9.98277085e-01
#   -6.68253883e-01  1.14520501e-02  1.00000000e+00]
#  [-4.51335878e-01 -4.28571429e-01  7.26174076e-01 -9.98674818e-01
#   -5.92727133e-01  9.15024449e-03  1.00000000e+00]
#  [-4.51335878e-01  2.85714286e-01  7.24469057e-01 -9.98439873e-01
#   -6.15888848e-01  1.02966910e-02  1.00000000e+00]
#  [-4.51335878e-01 -8.57142857e-01  7.30607123e-01 -9.98602221e-01
#   -5.88542664e-01  9.71901141e-03  0.00000000e+00]
#  [-4.51335878e-01  9.28571429e-01  6.41605172e-01 -9.96696088e-01
#   -6.67441609e-01  1.17054467e-02  1.00000000e+00]
#  [-4.51335878e-01  7.14285714e-02  6.08868823e-01 -9.95538421e-01
#   -7.53062199e-01  1.47383161e-02  1.00000000e+00]
#  [-4.51335878e-01  1.07142857e-01  6.06311295e-01 -9.95040835e-01
#   -7.88365122e-01  1.60334441e-02  1.00000000e+00]
#  [-4.51335878e-01 -8.88178420e-16  5.98127208e-01 -9.94699957e-01
#   -8.11612656e-01  1.70313503e-02  1.00000000e+00]
#  [-4.51335878e-01 -2.85714286e-01  5.81247528e-01 -9.94782345e-01
#   -7.87028880e-01  1.58760180e-02  0.00000000e+00]
#  [ 8.77862595e-02 -1.90476190e-01  5.15433825e-01 -9.93967626e-01
#   -7.88846901e-01  1.62438870e-02  1.00000000e+00]
#  [-4.51335878e-01 -4.76190476e-02  5.33166014e-01 -9.93853901e-01
#   -8.33700152e-01  1.81333844e-02  1.00000000e+00]
#  [-4.51335878e-01  2.85714286e-01  4.90199555e-01 -9.92769502e-01
#   -8.86156049e-01  2.01824960e-02  1.00000000e+00]
#  [ 5.55343511e-01  0.00000000e+00  4.46210086e-01 -9.92155413e-01
#   -8.86156049e-01  2.01824960e-02  1.00000000e+00]
#  [-4.11736641e-01 -5.14285714e-01  3.87898463e-01 -9.93309477e-01
#   -8.17278709e-01  3.76724169e-01  1.00000000e+00]
#  [-1.40028626e-01 -2.85714286e-01  4.13985241e-01 -9.94930719e-01
#   -7.41438162e-01  4.63577838e-01  1.00000000e+00]
#  [-4.51335878e-01 -7.14285714e-02  3.71018782e-01 -9.93649257e-01
#   -7.86955427e-01  4.65476480e-01  1.00000000e+00]
#  [-4.51335878e-01  2.85714286e-01  3.15264687e-01 -9.92570739e-01
#   -8.03501609e-01  4.66382986e-01  1.00000000e+00]
#  [-4.51335878e-01 -8.57142857e-01  3.71530288e-01 -9.93822328e-01
#   -7.58834815e-01  4.64713480e-01  0.00000000e+00]
#  [ 1.15617048e-01 -2.85714286e-01  3.55844120e-01 -9.93656678e-01
#   -7.51150996e-01  4.64510013e-01  1.00000000e+00]
#  [-2.83078880e-02 -4.76190476e-01  2.45529442e-01 -9.92141662e-01
#   -7.29634570e-01  4.63655143e-01  1.00000000e+00]
#  [-3.07410941e-01 -4.76190476e-02  2.11599580e-01 -9.91358783e-01
#   -7.51019777e-01  4.63907046e-01  1.00000000e+00]
#  [ 7.18750000e-01 -9.28571429e-01  2.32400802e-01 -9.92162903e-01
#   -6.96160580e-01  4.61993442e-01  0.00000000e+00]
#  [-4.51335878e-01 -2.85714286e-01  2.38538868e-01 -9.92627107e-01
#   -6.55443152e-01  4.60321555e-01  0.00000000e+00]
#  [-1.35257634e-01  1.42857143e-01  2.75367261e-01 -9.92768751e-01
#   -7.01920311e-01  4.61665967e-01  1.00000000e+00]
#  [-3.08206107e-01 -1.42857143e-01  2.62323872e-01 -9.92679676e-01
#   -7.00797571e-01  4.61505390e-01  1.00000000e+00]
#  [-9.35114504e-02 -2.85714286e-01  2.44421180e-01 -9.94365121e-01
#   -5.89701298e-01  6.82875859e-01  1.00000000e+00]
#  [-2.61688931e-01  1.42857143e-01  2.51838010e-01 -9.94041744e-01
#   -5.81371132e-01  3.45950642e-01  1.00000000e+00]]

# %%
# Count occurrences of 0 and 1 in Y_train
unique_train, counts_train = np.unique(Y_train, return_counts=True)
print("Y_train counts:", dict(zip(unique_train, counts_train)))

# Count occurrences of 0 and 1 in Y_val
unique_val, counts_val = np.unique(Y_val, return_counts=True)
print("Y_val counts:", dict(zip(unique_val, counts_val)))
# Out:
# Y_train counts: {0.0: 35, 1.0: 140}
# Y_val counts: {0.0: 7, 1.0: 24}

# %%
# root mean squared error (rmse) for regression (only for Keras tensors)
def rmse(y_true, y_pred):
    from keras import backend
    return backend.sqrt(backend.mean(backend.square(y_pred - y_true), axis=-1))

# mean squared error (mse) for regression  (only for Keras tensors)
def mse(y_true, y_pred):
    from keras import backend
    return backend.mean(backend.square(y_pred - y_true), axis=-1)

# coefficient of determination (R^2) for regression  (only for Keras tensors)
def r_square(y_true, y_pred):
    from keras import backend as K
    SS_res =  K.sum(K.square(y_true - y_pred)) 
    SS_tot = K.sum(K.square(y_true - K.mean(y_true))) 
    return ( 1 - SS_res/(SS_tot + K.epsilon()) )

# %%
# import tensorflow as tf
# from tensorflow.keras.layers import *
# from tensorflow.keras.models import Model
# from tensorflow.keras.layers import Input, LSTM, Dense, Layer, Dropout

# from tensorflow.keras.optimizers.legacy import Adam

# from tensorflow.keras.regularizers import L1L2
# from tensorflow.keras.layers import Layer, Dense, Dot, Activation

# from tensorflow.keras.callbacks import Callback, EarlyStopping

# from tensorflow.keras import backend as K

# from matplotlib import pyplot as plt

# K.clear_session()

   
# l1 = 0.0001
# l2 = 0.0001

# lstm_dropout = 0.2
# recurrent_dropout = 0.1
# dense_dropout = 0.2
# loss = 'mse'

# n_target = Y_train.shape[-2:]

# regularization_criteria = L1L2(l1=l1, l2=l2)

# n_target_y = Y_train.shape[-1]

# def build_model(input_shape):
#     input_layer = Input(shape=input_shape, name='Input_1')
#     sequence = input_layer
#     sequence = LSTM(20, return_sequences = True,  name="LSTM-1", kernel_regularizer = regularization_criteria, dropout=lstm_dropout, recurrent_dropout=recurrent_dropout)(input_layer)
#     sequence = Flatten()(sequence)
#     # sequence = Dropout(dense_dropout)(sequence)
#     # sequence = LSTM(16, return_sequences = False,  name="LSTM-2", kernel_regularizer = regularization_criteria, dropout=lstm_dropout, recurrent_dropout=recurrent_dropout)(sequence)
#     # sequence = Dense(4, activation = 'tanh', name='Dense_3')(sequence)
#     sequence = Dense(n_target_y, activation = 'tanh', name='Dense_4')(sequence)
#     output_layer = sequence

#     model = Model(inputs=input_layer, outputs=output_layer)

#     return model

# input_shape = (look_back, X_train.shape[2])

# learning_rate = 0.0005

# optimizer = Adam(learning_rate=learning_rate)

# model = build_model(input_shape)
# model.compile(optimizer=optimizer, loss=loss, metrics=[mse, rmse, r_square])
# model.summary()

# import time

# start_time = time.time()

# # early_stopping = EarlyStopping(monitor='val_loss', patience=500, restore_best_weights=True)

# history = model.fit(X_train, Y_train, epochs=700, batch_size=64, validation_data=(X_val, Y_val),
#                     # callbacks=[early_stopping]
#                     )

# end_time = time.time()
# difference_in_seconds = end_time - start_time
# print(f"The difference in seconds is: {difference_in_seconds}")

# %%
# import keras_tuner as kt
# import tensorflow as tf
# from tensorflow import keras
# from tensorflow.keras.layers import LSTM, Bidirectional, Dense, Dropout, Flatten

# def build_model(hp):
#     model = keras.Sequential()
    
#     model.add(LSTM(units=hp.Int('lstm_units', min_value=16, max_value=128, step=16),
#                    return_sequences=True,
#                      input_shape=(look_back, X_train.shape[2])))
    
#     # model.add(Dropout(hp.Float('dropout', min_value=0.0, max_value=0.5, step=0.1)))
    
#     # model.add(Bidirectional(LSTM(units=hp.Int('bidirectional_units', min_value=4, max_value=16, step=4),
#     #                              return_sequences=True)))
    
#     # model.add(Bidirectional(LSTM(units=hp.Int('bidirectional_units', min_value=4, max_value=32, step=4),
#     #                              return_sequences=True)))
    
#     model.add(Flatten())
    
#     model.add(Dropout(hp.Float('dropout', min_value=0.0, max_value=0.5, step=0.1)))
    
#     model.add(Dense(hp.Float('dense_units', min_value=0, max_value=32, step=8), activation='tanh'))
    
#     model.add(Dense(1, activation='tanh'))
    
#     model.compile(optimizer=keras.optimizers.Adam(hp.Choice('learning_rate', values=[1e-4, 1e-5])),
#                     loss='mse',
#                     metrics=[rmse, r_square])
    
#     return model

# %%
# import keras_tuner as kt
# import tensorflow as tf
# from tensorflow import keras
# from tensorflow.keras.layers import LSTM, Bidirectional, Dense, Dropout, Flatten, Attention, Input
# from tensorflow.keras.models import Model

# def build_model(hp):
#     inputs = Input(shape=(look_back, X_train.shape[2]))
    
#     lstm_out = LSTM(units=60,
#                     return_sequences=True)(inputs)

    
#     flatten = Flatten()(lstm_out)
    
#     dropout = Dropout(hp.Float('dropout', min_value=0.0, max_value=0.5, step=0.1))(flatten)
    
#     dense = Dense(hp.Int('dense_units', min_value=0, max_value=32, step=4), activation='tanh')(dropout)
    
#     output = Dense(1, activation='tanh')(dense)
    
#     model = Model(inputs=inputs, outputs=output)
    
#     model.compile(optimizer=keras.optimizers.Adam(hp.Choice('learning_rate', values=[1e-4, 1e-5])),
#                   loss='mse',
#                   metrics=[rmse, r_square])
    
#     return model

# %%
# tuner = kt.RandomSearch(build_model,
#                         objective=kt.Objective("val_r_square", direction="max"),
#                         max_trials=20,
#                         executions_per_trial=2,
#                         directory='my_dir',
#                         project_name='earthquake')

# %%
# tuner.search(X_train, Y_train, epochs=150, validation_data=(X_val, Y_val))

# %%
# from tensorflow.keras.callbacks import Callback, EarlyStopping
# best_hps = tuner.get_best_hyperparameters(num_trials=5)[0]

# # print(f"Best LSTM units: {best_hps.get('lstm_units')}")
# # print(f"Best BiLSTM usage: {best_hps.get('bidirectional_units')}")
# print(f"Best Dropout Rate: {best_hps.get('dropout')}")
# print(f"Best Dense Units: {best_hps.get('dense_units')}")
# print(f"Best Learning Rate: {best_hps.get('learning_rate')}")

# # Train the best model
# best_model = tuner.hypermodel.build(best_hps)
# early_stopping = EarlyStopping(monitor='val_loss', patience=700, restore_best_weights=True)
# history = best_model.fit(X_train, Y_train, epochs=1000, validation_data=(X_val, Y_val), callbacks=[early_stopping])

# %%
# # Generate predictions for the training set
# Y_train_pred = best_model.predict(X_train)

# # Plot the true values and predictions
# plt.figure(figsize=(10, 6))
# plt.plot(Y_train, label='True Values', color='blue',  marker='o')
# plt.plot(Y_train_pred, label='Predictions', color='red', linestyle='dashed', marker='o')
# plt.title('Training True Values vs Predictions')
# plt.xlabel('Sample Index')
# plt.ylabel('Value')
# plt.legend()
# plt.show()

# %%
# # Generate predictions for the validation set
# Y_val_pred = best_model.predict(X_val)

# # Plot the true values and predictions
# plt.figure(figsize=(10, 6))
# plt.plot(Y_val, label='True Values', color='blue', marker='o')
# plt.plot(Y_val_pred, label='Predictions', color='red', linestyle='dashed', marker='o')
# plt.title('Validation True Values vs Predictions')
# plt.xlabel('Sample Index')
# plt.ylabel('Value')
# plt.legend()
# plt.show()

# %%
# # Generate predictions for the validation set
# Y_val_pred = best_model.predict(X_val)
# Y_val_pred = np.where(Y_val_pred > 0.5, 1,np.where(Y_val_pred<-0.5, -1, 0) )

# # Plot the true values and predictions
# plt.figure(figsize=(10, 6))
# plt.plot(Y_val, label='True Values', color='blue', marker='o')
# plt.plot(Y_val_pred, label='Predictions', color='red', linestyle='dashed', marker='o')
# plt.title('Validation True Values vs Predictions')
# plt.xlabel('Sample Index')
# plt.ylabel('Value')
# plt.legend()
# plt.show()

# %%
# from sklearn.metrics import confusion_matrix

# # Create confusion matrix
# conf_matrix = confusion_matrix(Y_val.flatten(), Y_val_pred.flatten())

# # Print the confusion matrix
# print("Confusion Matrix:")
# print(conf_matrix)

# %%
# # Calculate total accuracy
# total_accuracy = np.sum(Y_val.flatten() == Y_val_pred.flatten()) / len(Y_val)
# print(f"Total Accuracy: {total_accuracy * 100:.2f}%")

# %%
# Create a mask to filter out values in Y_test that are not equal to 0
mask = Y_val != 0
# print(X_test.shape)
# Apply the mask to filter X_test and Y_test
X_test_filtered = np.array([x for x, m in zip(X_val, mask) if m])
Y_test_filtered = Y_val[mask]

# Print the shapes of the filtered arrays to verify
print(X_test_filtered.shape)
print(Y_test_filtered.shape)
# Out:
# (24, 30, 7)
# (24,)

# %%
# # Generate predictions for the validation set
# Y_val_pred = best_model.predict(X_test_filtered)
# Y_val_pred = np.where(Y_val_pred > 0.15, 1, -1)

# # Plot the true values and predictions
# plt.figure(figsize=(10, 6))
# plt.plot(Y_test_filtered, label='True Values', color='blue', marker='o')
# plt.plot(Y_val_pred, label='Predictions', color='red', linestyle='dashed', marker='o')
# plt.title('Validation True Values vs Predictions')
# plt.xlabel('Sample Index')
# plt.ylabel('Value')
# plt.legend()
# plt.show()

# %%
# from sklearn.metrics import confusion_matrix

# # Create confusion matrix
# conf_matrix = confusion_matrix(Y_test_filtered.flatten(), Y_val_pred.flatten())

# # Print the confusion matrix
# print("Confusion Matrix:")
# print(conf_matrix)

# %%
# # Calculate total accuracy
# total_accuracy = np.sum(Y_test_filtered.flatten() == Y_val_pred.flatten()) / len(Y_test_filtered)
# print(f"Total Accuracy: {total_accuracy * 100:.2f}%")

# %%
import tensorflow as tf
from tensorflow.keras.layers import *
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, LSTM, Dense, Layer, Dropout

from tensorflow.keras.optimizers.legacy import Adam

from tensorflow.keras.regularizers import L1L2
from tensorflow.keras.layers import Layer, Dense, Dot, Activation

from tensorflow.keras.callbacks import Callback, EarlyStopping

from tensorflow.keras import backend as K

from matplotlib import pyplot as plt

K.clear_session()

METRICS = [
    mse,
    tf.keras.metrics.BinaryCrossentropy(name='binary_crossentropy', from_logits=False),
    tf.keras.metrics.BinaryAccuracy(name='accuracy', threshold=0.5),
]
   
l1 = 0.0
l2 = 0.0

lstm_dropout = 0.0
recurrent_dropout = 0.0
dense_dropout = 0.1
loss = 'mse'

n_target = Y_train.shape[-2:]

regularization_criteria = L1L2(l1=l1, l2=l2)

n_target_y = Y_train.shape[-1]

def build_model(input_shape):
    input_layer = Input(shape=input_shape, name='Input_1')
    sequence = input_layer
    sequence = LSTM(50, return_sequences = True,  name="LSTM-1", kernel_regularizer = regularization_criteria, dropout=lstm_dropout, recurrent_dropout=recurrent_dropout)(input_layer)
    
    sequence = Flatten()(sequence)
    sequence = Dense(20, activation = 'tanh', name='Dense_2')(sequence)
    sequence = Dropout(0.3)(sequence)
    # sequence = LSTM(16, return_sequences = False,  name="LSTM-2", kernel_regularizer = regularization_criteria, dropout=lstm_dropout, recurrent_dropout=recurrent_dropout)(sequence)
    sequence = Dense(10, activation = 'tanh', name='Dense_3')(sequence)
    sequence = Dense(n_target_y, activation = 'sigmoid', name='Dense_4')(sequence)
    output_layer = sequence

    model = Model(inputs=input_layer, outputs=output_layer)

    return model

input_shape = (look_back, X_train.shape[2])

learning_rate = 0.001

optimizer = Adam(learning_rate=learning_rate)

model = build_model(input_shape)
model.compile(optimizer=optimizer, loss=loss, metrics=[METRICS])
model.summary()

import time

start_time = time.time()

early_stopping = EarlyStopping(monitor='val_loss', patience=700, restore_best_weights=True)

history = model.fit(X_train, Y_train, epochs=1000, batch_size=64, validation_data=(X_val, Y_val),
                    callbacks=[early_stopping]
                    )

end_time = time.time()
difference_in_seconds = end_time - start_time
print(f"The difference in seconds is: {difference_in_seconds}")
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  Input_1 (InputLayer)        [(None, 30, 7)]           0
#
#  LSTM-1 (LSTM)               (None, 30, 50)            11600
#
#  flatten (Flatten)           (None, 1500)              0
#
#  Dense_2 (Dense)             (None, 20)                30020
#
#  dropout (Dropout)           (None, 20)                0
#
#  Dense_3 (Dense)             (None, 10)                210
#
#  Dense_4 (Dense)             (None, 1)                 11
#
# =================================================================
# Total params: 41,841
# Trainable params: 41,841
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/1000
# 3/3 [==============================] - 2s 247ms/step - loss: 0.1840 - mse: 0.1840 - binary_crossentropy: 0.5620 - accuracy: 0.7600 - val_loss: 0.1859 - val_mse: 0.1859 - val_binary_crossentropy: 0.5774 - val_accuracy: 0.7742
# Epoch 2/1000
# 3/3 [==============================] - 0s 39ms/step - loss: 0.1681 - mse: 0.1681 - binary_crossentropy: 0.5389 - accuracy: 0.8000 - val_loss: 0.1916 - val_mse: 0.1916 - val_binary_crossentropy: 0.6071 - val_accuracy: 0.7742
# Epoch 3/1000
# 3/3 [==============================] - 0s 42ms/step - loss: 0.1706 - mse: 0.1706 - binary_crossentropy: 0.5497 - accuracy: 0.8000 - val_loss: 0.1894 - val_mse: 0.1894 - val_binary_crossentropy: 0.5947 - val_accuracy: 0.7742
# Epoch 4/1000
# 3/3 [==============================] - 0s 52ms/step - loss: 0.1693 - mse: 0.1693 - binary_crossentropy: 0.5384 - accuracy: 0.8000 - val_loss: 0.1834 - val_mse: 0.1834 - val_binary_crossentropy: 0.5662 - val_accuracy: 0.7742
# Epoch 5/1000
# 3/3 [==============================] - 0s 41ms/step - loss: 0.1626 - mse: 0.1626 - binary_crossentropy: 0.5114 - accuracy: 0.8000 - val_loss: 0.1780 - val_mse: 0.1780 - val_binary_crossentropy: 0.5448 - val_accuracy: 0.7742
# Epoch 6/1000
# 3/3 [==============================] - 0s 42ms/step - loss: 0.1651 - mse: 0.1651 - binary_crossentropy: 0.5167 - accuracy: 0.8000 - val_loss: 0.1758 - val_mse: 0.1758 - val_binary_crossentropy: 0.5372 - val_accuracy: 0.7742
# Epoch 7/1000
# 3/3 [==============================] - 0s 41ms/step - loss: 0.1553 - mse: 0.1553 - binary_crossentropy: 0.4871 - accuracy: 0.8000 - val_loss: 0.1757 - val_mse: 0.1757 - val_binary_crossentropy: 0.5369 - val_accuracy: 0.7742
# Epoch 8/1000
# 3/3 [==============================] - 0s 36ms/step - loss: 0.1675 - mse: 0.1675 - binary_crossentropy: 0.5198 - accuracy: 0.8000 - val_loss: 0.1759 - val_mse: 0.1759 - val_binary_crossentropy: 0.5376 - val_accuracy: 0.7742
# Epoch 9/1000
# 3/3 [==============================] - 0s 37ms/step - loss: 0.1576 - mse: 0.1576 - binary_crossentropy: 0.4939 - accuracy: 0.8000 - val_loss: 0.1765 - val_mse: 0.1765 - val_binary_crossentropy: 0.5398 - val_accuracy: 0.7742
# Epoch 10/1000
# 3/3 [==============================] - 0s 38ms/step - loss: 0.1621 - mse: 0.1621 - binary_crossentropy: 0.5062 - accuracy: 0.8000 - val_loss: 0.1762 - val_mse: 0.1762 - val_binary_crossentropy: 0.5388 - val_accuracy: 0.7742
# Epoch 11/1000
# 3/3 [==============================] - 0s 38ms/step - loss: 0.1569 - mse: 0.1569 - binary_crossentropy: 0.4924 - accuracy: 0.8000 - val_loss: 0.1766 - val_mse: 0.1766 - val_binary_crossentropy: 0.5403 - val_accuracy: 0.7742
# Epoch 12/1000
# 3/3 [==============================] - 0s 37ms/step - loss: 0.1572 - mse: 0.1572 - binary_crossentropy: 0.4929 - accuracy: 0.8000 - val_loss: 0.1767 - val_mse: 0.1767 - val_binary_crossentropy: 0.5409 - val_accuracy: 0.7742
# Epoch 13/1000
# 3/3 [==============================] - 0s 40ms/step - loss: 0.1538 - mse: 0.1538 - binary_crossentropy: 0.4787 - accuracy: 0.8000 - val_loss: 0.1766 - val_mse: 0.1766 - val_binary_crossentropy: 0.5405 - val_accuracy: 0.7742
# Epoch 14/1000
# 3/3 [==============================] - 0s 37ms/step - loss: 0.1563 - mse: 0.1563 - binary_crossentropy: 0.4892 - accuracy: 0.8000 - val_loss: 0.1762 - val_mse: 0.1762 - val_binary_crossentropy: 0.5394 - val_accuracy: 0.7742
# Epoch 15/1000
# 3/3 [==============================] - 0s 40ms/step - loss: 0.1594 - mse: 0.1594 - binary_crossentropy: 0.4987 - accuracy: 0.8000 - val_loss: 0.1754 - val_mse: 0.1754 - val_binary_crossentropy: 0.5367 - val_accuracy: 0.7742
# Epoch 16/1000
# 3/3 [==============================] - 0s 44ms/step - loss: 0.1485 - mse: 0.1485 - binary_crossentropy: 0.4669 - accuracy: 0.8000 - val_loss: 0.1753 - val_mse: 0.1753 - val_binary_crossentropy: 0.5367 - val_accuracy: 0.7742
# Epoch 17/1000
# 3/3 [==============================] - 0s 38ms/step - loss: 0.1510 - mse: 0.1510 - binary_crossentropy: 0.4741 - accuracy: 0.8000 - val_loss: 0.1752 - val_mse: 0.1752 - val_binary_crossentropy: 0.5364 - val_accuracy: 0.7742
# Epoch 18/1000
# 3/3 [==============================] - 0s 39ms/step - loss: 0.1536 - mse: 0.1536 - binary_crossentropy: 0.4813 - accuracy: 0.8000 - val_loss: 0.1762 - val_mse: 0.1762 - val_binary_crossentropy: 0.5402 - val_accuracy: 0.7742
# Epoch 19/1000
# 3/3 [==============================] - 0s 37ms/step - loss: 0.1523 - mse: 0.1523 - binary_crossentropy: 0.4786 - accuracy: 0.8000 - val_loss: 0.1776 - val_mse: 0.1776 - val_binary_crossentropy: 0.5457 - val_accuracy: 0.7742
# Epoch 20/1000
# 3/3 [==============================] - 0s 36ms/step - loss: 0.1477 - mse: 0.1477 - binary_crossentropy: 0.4641 - accuracy: 0.8000 - val_loss: 0.1772 - val_mse: 0.1772 - val_binary_crossentropy: 0.5449 - val_accuracy: 0.7742
# Epoch 21/1000
# 3/3 [==============================] - 0s 38ms/step - loss: 0.1515 - mse: 0.1515 - binary_crossentropy: 0.4721 - accuracy: 0.8000 - val_loss: 0.1758 - val_mse: 0.1758 - val_binary_crossentropy: 0.5406 - val_accuracy: 0.7742
# Epoch 22/1000
# 3/3 [==============================] - 0s 35ms/step - loss: 0.1503 - mse: 0.1503 - binary_crossentropy: 0.4695 - accuracy: 0.8000 - val_loss: 0.1753 - val_mse: 0.1753 - val_binary_crossentropy: 0.5389 - val_accuracy: 0.7742
# Epoch 23/1000
# 3/3 [==============================] - 0s 40ms/step - loss: 0.1473 - mse: 0.1473 - binary_crossentropy: 0.4611 - accuracy: 0.8000 - val_loss: 0.1755 - val_mse: 0.1755 - val_binary_crossentropy: 0.5403 - val_accuracy: 0.7742
# Epoch 24/1000
# 3/3 [==============================] - 0s 37ms/step - loss: 0.1462 - mse: 0.1462 - binary_crossentropy: 0.4598 - accuracy: 0.8000 - val_loss: 0.1756 - val_mse: 0.1756 - val_binary_crossentropy: 0.5413 - val_accuracy: 0.7742
# Epoch 25/1000
# 3/3 [==============================] - 0s 37ms/step - loss: 0.1485 - mse: 0.1485 - binary_crossentropy: 0.4635 - accuracy: 0.8000 - val_loss: 0.1757 - val_mse: 0.1757 - val_binary_crossentropy: 0.5427 - val_accuracy: 0.7742
# Epoch 26/1000
# 3/3 [==============================] - 0s 37ms/step - loss: 0.1410 - mse: 0.1410 - binary_crossentropy: 0.4430 - accuracy: 0.8000 - val_loss: 0.1763 - val_mse: 0.1763 - val_binary_crossentropy: 0.5461 - val_accuracy: 0.7742
# Epoch 27/1000
# 3/3 [==============================] - 0s 37ms/step - loss: 0.1423 - mse: 0.1423 - binary_crossentropy: 0.4476 - accuracy: 0.8000 - val_loss: 0.1763 - val_mse: 0.1763 - val_binary_crossentropy: 0.5475 - val_accuracy: 0.7742
# Epoch 28/1000
# 3/3 [==============================] - 0s 38ms/step - loss: 0.1432 - mse: 0.1432 - binary_crossentropy: 0.4516 - accuracy: 0.8000 - val_loss: 0.1755 - val_mse: 0.1755 - val_binary_crossentropy: 0.5451 - val_accuracy: 0.7742
# Epoch 29/1000
# 3/3 [==============================] - 0s 41ms/step - loss: 0.1441 - mse: 0.1441 - binary_crossentropy: 0.4522 - accuracy: 0.8000 - val_loss: 0.1744 - val_mse: 0.1744 - val_binary_crossentropy: 0.5411 - val_accuracy: 0.7742
# Epoch 30/1000
# 3/3 [==============================] - 0s 41ms/step - loss: 0.1417 - mse: 0.1417 - binary_crossentropy: 0.4441 - accuracy: 0.8000 - val_loss: 0.1736 - val_mse: 0.1736 - val_binary_crossentropy: 0.5388 - val_accuracy: 0.7742
# Epoch 31/1000
# 3/3 [==============================] - 0s 43ms/step - loss: 0.1385 - mse: 0.1385 - binary_crossentropy: 0.4355 - accuracy: 0.8000 - val_loss: 0.1735 - val_mse: 0.1735 - val_binary_crossentropy: 0.5396 - val_accuracy: 0.7742
# Epoch 32/1000
# 3/3 [==============================] - 0s 66ms/step - loss: 0.1393 - mse: 0.1393 - binary_crossentropy: 0.4382 - accuracy: 0.8057 - val_loss: 0.1736 - val_mse: 0.1736 - val_binary_crossentropy: 0.5401 - val_accuracy: 0.7742
# Epoch 33/1000
# 3/3 [==============================] - 0s 43ms/step - loss: 0.1337 - mse: 0.1337 - binary_crossentropy: 0.4236 - accuracy: 0.8000 - val_loss: 0.1728 - val_mse: 0.1728 - val_binary_crossentropy: 0.5376 - val_accuracy: 0.7742
# Epoch 34/1000
# 3/3 [==============================] - 0s 41ms/step - loss: 0.1305 - mse: 0.1305 - binary_crossentropy: 0.4200 - accuracy: 0.8343 - val_loss: 0.1724 - val_mse: 0.1724 - val_binary_crossentropy: 0.5361 - val_accuracy: 0.8065
# Epoch 35/1000
# 3/3 [==============================] - 0s 39ms/step - loss: 0.1312 - mse: 0.1312 - binary_crossentropy: 0.4170 - accuracy: 0.8286 - val_loss: 0.1703 - val_mse: 0.1703 - val_binary_crossentropy: 0.5313 - val_accuracy: 0.8065
# Epoch 36/1000
# 3/3 [==============================] - 0s 41ms/step - loss: 0.1325 - mse: 0.1325 - binary_crossentropy: 0.4186 - accuracy: 0.8114 - val_loss: 0.1681 - val_mse: 0.1681 - val_binary_crossentropy: 0.5282 - val_accuracy: 0.7742
# Epoch 37/1000
# 3/3 [==============================] - 0s 41ms/step - loss: 0.1289 - mse: 0.1289 - binary_crossentropy: 0.4093 - accuracy: 0.8114 - val_loss: 0.1659 - val_mse: 0.1659 - val_binary_crossentropy: 0.5241 - val_accuracy: 0.8065
# Epoch 38/1000
# 3/3 [==============================] - 0s 41ms/step - loss: 0.1318 - mse: 0.1318 - binary_crossentropy: 0.4178 - accuracy: 0.8229 - val_loss: 0.1655 - val_mse: 0.1655 - val_binary_crossentropy: 0.5221 - val_accuracy: 0.7742
# Epoch 39/1000
# 3/3 [==============================] - 0s 38ms/step - loss: 0.1253 - mse: 0.1253 - binary_crossentropy: 0.3996 - accuracy: 0.8057 - val_loss: 0.1648 - val_mse: 0.1648 - val_binary_crossentropy: 0.5205 - val_accuracy: 0.7742
# Epoch 40/1000
# 3/3 [==============================] - 0s 39ms/step - loss: 0.1243 - mse: 0.1243 - binary_crossentropy: 0.3971 - accuracy: 0.8229 - val_loss: 0.1661 - val_mse: 0.1661 - val_binary_crossentropy: 0.5229 - val_accuracy: 0.7742
# Epoch 41/1000
# 3/3 [==============================] - 0s 41ms/step - loss: 0.1184 - mse: 0.1184 - binary_crossentropy: 0.3807 - accuracy: 0.8343 - val_loss: 0.1708 - val_mse: 0.1708 - val_binary_crossentropy: 0.5298 - val_accuracy: 0.7742
# Epoch 42/1000
# 3/3 [==============================] - 0s 43ms/step - loss: 0.1271 - mse: 0.1271 - binary_crossentropy: 0.4082 - accuracy: 0.8171 - val_loss: 0.1721 - val_mse: 0.1721 - val_binary_crossentropy: 0.5326 - val_accuracy: 0.7742
# Epoch 43/1000
# 3/3 [==============================] - 0s 40ms/step - loss: 0.1172 - mse: 0.1172 - binary_crossentropy: 0.3782 - accuracy: 0.8229 - val_loss: 0.1630 - val_mse: 0.1630 - val_binary_crossentropy: 0.5208 - val_accuracy: 0.7742
# Epoch 44/1000
# 3/3 [==============================] - 0s 44ms/step - loss: 0.1226 - mse: 0.1226 - binary_crossentropy: 0.3893 - accuracy: 0.8286 - val_loss: 0.1614 - val_mse: 0.1614 - val_binary_crossentropy: 0.5188 - val_accuracy: 0.7742
# Epoch 45/1000
# 3/3 [==============================] - 0s 32ms/step - loss: 0.1136 - mse: 0.1136 - binary_crossentropy: 0.3703 - accuracy: 0.8400 - val_loss: 0.1682 - val_mse: 0.1682 - val_binary_crossentropy: 0.5347 - val_accuracy: 0.7742
# Epoch 46/1000
# 3/3 [==============================] - 0s 63ms/step - loss: 0.1192 - mse: 0.1192 - binary_crossentropy: 0.3903 - accuracy: 0.8457 - val_loss: 0.1685 - val_mse: 0.1685 - val_binary_crossentropy: 0.5360 - val_accuracy: 0.7742
# Epoch 47/1000
# 3/3 [==============================] - 0s 42ms/step - loss: 0.1078 - mse: 0.1078 - binary_crossentropy: 0.3601 - accuracy: 0.8629 - val_loss: 0.1638 - val_mse: 0.1638 - val_binary_crossentropy: 0.5279 - val_accuracy: 0.7742
# Epoch 48/1000
# 3/3 [==============================] - 0s 38ms/step - loss: 0.1111 - mse: 0.1111 - binary_crossentropy: 0.3631 - accuracy: 0.8343 - val_loss: 0.1645 - val_mse: 0.1645 - val_binary_crossentropy: 0.5298 - val_accuracy: 0.7742
# Epoch 49/1000
# 3/3 [==============================] - 0s 40ms/step - loss: 0.1030 - mse: 0.1030 - binary_crossentropy: 0.3457 - accuracy: 0.8629 - val_loss: 0.1718 - val_mse: 0.1718 - val_binary_crossentropy: 0.5444 - val_accuracy: 0.7742
# Epoch 50/1000
# 3/3 [==============================] - 0s 46ms/step - loss: 0.1040 - mse: 0.1040 - binary_crossentropy: 0.3508 - accuracy: 0.8743 - val_loss: 0.1759 - val_mse: 0.1759 - val_binary_crossentropy: 0.5525 - val_accuracy: 0.7742
# Epoch 51/1000
# 3/3 [==============================] - 0s 47ms/step - loss: 0.1064 - mse: 0.1064 - binary_crossentropy: 0.3516 - accuracy: 0.8686 - val_loss: 0.1725 - val_mse: 0.1725 - val_binary_crossentropy: 0.5503 - val_accuracy: 0.7742
# Epoch 52/1000
# 3/3 [==============================] - 0s 38ms/step - loss: 0.0993 - mse: 0.0993 - binary_crossentropy: 0.3326 - accuracy: 0.8686 - val_loss: 0.1727 - val_mse: 0.1727 - val_binary_crossentropy: 0.5499 - val_accuracy: 0.7742
# Epoch 53/1000
# 3/3 [==============================] - 0s 40ms/step - loss: 0.1004 - mse: 0.1004 - binary_crossentropy: 0.3364 - accuracy: 0.8743 - val_loss: 0.1770 - val_mse: 0.1770 - val_binary_crossentropy: 0.5607 - val_accuracy: 0.7742
# Epoch 54/1000
# 3/3 [==============================] - 0s 38ms/step - loss: 0.0921 - mse: 0.0921 - binary_crossentropy: 0.3166 - accuracy: 0.9086 - val_loss: 0.1738 - val_mse: 0.1738 - val_binary_crossentropy: 0.5563 - val_accuracy: 0.7742
# Epoch 55/1000
# 3/3 [==============================] - 0s 39ms/step - loss: 0.0921 - mse: 0.0921 - binary_crossentropy: 0.3134 - accuracy: 0.9029 - val_loss: 0.1793 - val_mse: 0.1793 - val_binary_crossentropy: 0.5717 - val_accuracy: 0.7742
# Epoch 56/1000
# 3/3 [==============================] - 0s 40ms/step - loss: 0.0857 - mse: 0.0857 - binary_crossentropy: 0.3012 - accuracy: 0.9143 - val_loss: 0.1845 - val_mse: 0.1845 - val_binary_crossentropy: 0.5857 - val_accuracy: 0.7419
# Epoch 57/1000
# 3/3 [==============================] - 0s 41ms/step - loss: 0.0900 - mse: 0.0900 - binary_crossentropy: 0.3111 - accuracy: 0.9029 - val_loss: 0.1886 - val_mse: 0.1886 - val_binary_crossentropy: 0.5970 - val_accuracy: 0.7097
# Epoch 58/1000
# 3/3 [==============================] - 0s 38ms/step - loss: 0.0853 - mse: 0.0853 - binary_crossentropy: 0.3027 - accuracy: 0.9029 - val_loss: 0.1843 - val_mse: 0.1843 - val_binary_crossentropy: 0.5882 - val_accuracy: 0.7742
# Epoch 59/1000
# 3/3 [==============================] - 0s 38ms/step - loss: 0.0850 - mse: 0.0850 - binary_crossentropy: 0.3020 - accuracy: 0.9086 - val_loss: 0.1840 - val_mse: 0.1840 - val_binary_crossentropy: 0.5910 - val_accuracy: 0.7742
# Epoch 60/1000
# 3/3 [==============================] - 0s 38ms/step - loss: 0.0847 - mse: 0.0847 - binary_crossentropy: 0.2996 - accuracy: 0.9143 - val_loss: 0.1932 - val_mse: 0.1932 - val_binary_crossentropy: 0.6189 - val_accuracy: 0.7419
# Epoch 61/1000
# 3/3 [==============================] - 0s 40ms/step - loss: 0.0844 - mse: 0.0844 - binary_crossentropy: 0.2991 - accuracy: 0.9029 - val_loss: 0.1961 - val_mse: 0.1961 - val_binary_crossentropy: 0.6293 - val_accuracy: 0.7419
# Epoch 62/1000
# 3/3 [==============================] - 0s 39ms/step - loss: 0.0735 - mse: 0.0735 - binary_crossentropy: 0.2709 - accuracy: 0.9257 - val_loss: 0.1926 - val_mse: 0.1926 - val_binary_crossentropy: 0.6227 - val_accuracy: 0.7419
# Epoch 63/1000
# 3/3 [==============================] - 0s 53ms/step - loss: 0.0797 - mse: 0.0797 - binary_crossentropy: 0.2885 - accuracy: 0.9314 - val_loss: 0.1841 - val_mse: 0.1841 - val_binary_crossentropy: 0.6028 - val_accuracy: 0.7742
# Epoch 64/1000
# 3/3 [==============================] - 0s 37ms/step - loss: 0.0842 - mse: 0.0842 - binary_crossentropy: 0.2892 - accuracy: 0.9029 - val_loss: 0.1874 - val_mse: 0.1874 - val_binary_crossentropy: 0.6137 - val_accuracy: 0.7419
# Epoch 65/1000
# 3/3 [==============================] - 0s 37ms/step - loss: 0.0807 - mse: 0.0807 - binary_crossentropy: 0.2867 - accuracy: 0.9086 - val_loss: 0.1875 - val_mse: 0.1875 - val_binary_crossentropy: 0.6173 - val_accuracy: 0.7742
# Epoch 66/1000
# 3/3 [==============================] - 0s 40ms/step - loss: 0.0761 - mse: 0.0761 - binary_crossentropy: 0.2743 - accuracy: 0.9257 - val_loss: 0.1965 - val_mse: 0.1965 - val_binary_crossentropy: 0.6447 - val_accuracy: 0.7419
# Epoch 67/1000
# 3/3 [==============================] - 0s 39ms/step - loss: 0.0737 - mse: 0.0737 - binary_crossentropy: 0.2714 - accuracy: 0.9257 - val_loss: 0.1938 - val_mse: 0.1938 - val_binary_crossentropy: 0.6406 - val_accuracy: 0.7419
# Epoch 68/1000
# 3/3 [==============================] - 0s 37ms/step - loss: 0.0722 - mse: 0.0722 - binary_crossentropy: 0.2645 - accuracy: 0.9143 - val_loss: 0.1954 - val_mse: 0.1954 - val_binary_crossentropy: 0.6480 - val_accuracy: 0.7419
# Epoch 69/1000
# 3/3 [==============================] - 0s 38ms/step - loss: 0.0680 - mse: 0.0680 - binary_crossentropy: 0.2497 - accuracy: 0.9200 - val_loss: 0.2047 - val_mse: 0.2047 - val_binary_crossentropy: 0.6777 - val_accuracy: 0.7419
# Epoch 70/1000
# 3/3 [==============================] - 0s 37ms/step - loss: 0.0749 - mse: 0.0749 - binary_crossentropy: 0.2755 - accuracy: 0.9371 - val_loss: 0.2073 - val_mse: 0.2073 - val_binary_crossentropy: 0.6890 - val_accuracy: 0.7419
# Epoch 71/1000
# 3/3 [==============================] - 0s 36ms/step - loss: 0.0708 - mse: 0.0708 - binary_crossentropy: 0.2612 - accuracy: 0.9200 - val_loss: 0.1978 - val_mse: 0.1978 - val_binary_crossentropy: 0.6675 - val_accuracy: 0.7742
# Epoch 72/1000
# 3/3 [==============================] - 0s 37ms/step - loss: 0.0656 - mse: 0.0656 - binary_crossentropy: 0.2477 - accuracy: 0.9371 - val_loss: 0.1987 - val_mse: 0.1987 - val_binary_crossentropy: 0.6697 - val_accuracy: 0.7419
# Epoch 73/1000
# 3/3 [==============================] - 0s 37ms/step - loss: 0.0607 - mse: 0.0607 - binary_crossentropy: 0.2362 - accuracy: 0.9429 - val_loss: 0.1961 - val_mse: 0.1961 - val_binary_crossentropy: 0.6653 - val_accuracy: 0.7742
# Epoch 74/1000
# 3/3 [==============================] - 0s 32ms/step - loss: 0.0650 - mse: 0.0650 - binary_crossentropy: 0.2435 - accuracy: 0.9371 - val_loss: 0.1947 - val_mse: 0.1947 - val_binary_crossentropy: 0.6656 - val_accuracy: 0.7742
# Epoch 75/1000
# 3/3 [==============================] - 0s 37ms/step - loss: 0.0593 - mse: 0.0593 - binary_crossentropy: 0.2239 - accuracy: 0.9371 - val_loss: 0.2008 - val_mse: 0.2008 - val_binary_crossentropy: 0.6828 - val_accuracy: 0.7419
# Epoch 76/1000
# 3/3 [==============================] - 0s 40ms/step - loss: 0.0596 - mse: 0.0596 - binary_crossentropy: 0.2367 - accuracy: 0.9429 - val_loss: 0.2085 - val_mse: 0.2085 - val_binary_crossentropy: 0.7079 - val_accuracy: 0.7419
# Epoch 77/1000
# 3/3 [==============================] - 0s 37ms/step - loss: 0.0645 - mse: 0.0645 - binary_crossentropy: 0.2506 - accuracy: 0.9314 - val_loss: 0.2091 - val_mse: 0.2091 - val_binary_crossentropy: 0.7215 - val_accuracy: 0.7419
# Epoch 78/1000
# 3/3 [==============================] - 0s 39ms/step - loss: 0.0621 - mse: 0.0621 - binary_crossentropy: 0.2371 - accuracy: 0.9086 - val_loss: 0.1999 - val_mse: 0.1999 - val_binary_crossentropy: 0.6925 - val_accuracy: 0.7419
# Epoch 79/1000
# 3/3 [==============================] - 0s 37ms/step - loss: 0.0621 - mse: 0.0621 - binary_crossentropy: 0.2311 - accuracy: 0.9143 - val_loss: 0.1952 - val_mse: 0.1952 - val_binary_crossentropy: 0.6800 - val_accuracy: 0.7419
# Epoch 80/1000
# 3/3 [==============================] - 0s 40ms/step - loss: 0.0535 - mse: 0.0535 - binary_crossentropy: 0.2183 - accuracy: 0.9429 - val_loss: 0.1941 - val_mse: 0.1941 - val_binary_crossentropy: 0.6732 - val_accuracy: 0.7742
# Epoch 81/1000
# 3/3 [==============================] - 0s 39ms/step - loss: 0.0540 - mse: 0.0540 - binary_crossentropy: 0.2129 - accuracy: 0.9371 - val_loss: 0.1969 - val_mse: 0.1969 - val_binary_crossentropy: 0.6843 - val_accuracy: 0.7742
# Epoch 82/1000
# 3/3 [==============================] - 0s 39ms/step - loss: 0.0502 - mse: 0.0502 - binary_crossentropy: 0.2008 - accuracy: 0.9543 - val_loss: 0.2012 - val_mse: 0.2012 - val_binary_crossentropy: 0.7006 - val_accuracy: 0.7419
# Epoch 83/1000
# 3/3 [==============================] - 0s 37ms/step - loss: 0.0523 - mse: 0.0523 - binary_crossentropy: 0.2137 - accuracy: 0.9486 - val_loss: 0.2019 - val_mse: 0.2019 - val_binary_crossentropy: 0.7056 - val_accuracy: 0.7419
# Epoch 84/1000
# 3/3 [==============================] - 0s 38ms/step - loss: 0.0466 - mse: 0.0466 - binary_crossentropy: 0.1963 - accuracy: 0.9543 - val_loss: 0.1962 - val_mse: 0.1962 - val_binary_crossentropy: 0.6905 - val_accuracy: 0.7419
# Epoch 85/1000
# 3/3 [==============================] - 0s 39ms/step - loss: 0.0501 - mse: 0.0501 - binary_crossentropy: 0.2006 - accuracy: 0.9486 - val_loss: 0.1970 - val_mse: 0.1970 - val_binary_crossentropy: 0.6951 - val_accuracy: 0.7419
# Epoch 86/1000
# 3/3 [==============================] - 0s 39ms/step - loss: 0.0458 - mse: 0.0458 - binary_crossentropy: 0.1939 - accuracy: 0.9657 - val_loss: 0.2048 - val_mse: 0.2048 - val_binary_crossentropy: 0.7251 - val_accuracy: 0.7419
# Epoch 87/1000
# 3/3 [==============================] - 0s 41ms/step - loss: 0.0498 - mse: 0.0498 - binary_crossentropy: 0.2032 - accuracy: 0.9486 - val_loss: 0.2047 - val_mse: 0.2047 - val_binary_crossentropy: 0.7277 - val_accuracy: 0.7419
# Epoch 88/1000
# 3/3 [==============================] - 0s 37ms/step - loss: 0.0446 - mse: 0.0446 - binary_crossentropy: 0.1820 - accuracy: 0.9429 - val_loss: 0.2047 - val_mse: 0.2047 - val_binary_crossentropy: 0.7323 - val_accuracy: 0.7419
# Epoch 89/1000
# 3/3 [==============================] - 0s 36ms/step - loss: 0.0449 - mse: 0.0449 - binary_crossentropy: 0.1890 - accuracy: 0.9543 - val_loss: 0.2051 - val_mse: 0.2051 - val_binary_crossentropy: 0.7354 - val_accuracy: 0.7419
# Epoch 90/1000
# 3/3 [==============================] - 0s 39ms/step - loss: 0.0424 - mse: 0.0424 - binary_crossentropy: 0.1902 - accuracy: 0.9657 - val_loss: 0.2059 - val_mse: 0.2059 - val_binary_crossentropy: 0.7440 - val_accuracy: 0.7742
# Epoch 91/1000
# 3/3 [==============================] - 0s 40ms/step - loss: 0.0405 - mse: 0.0405 - binary_crossentropy: 0.1715 - accuracy: 0.9657 - val_loss: 0.1985 - val_mse: 0.1985 - val_binary_crossentropy: 0.7245 - val_accuracy: 0.7419
# Epoch 92/1000
# 3/3 [==============================] - 0s 36ms/step - loss: 0.0402 - mse: 0.0402 - binary_crossentropy: 0.1770 - accuracy: 0.9657 - val_loss: 0.2028 - val_mse: 0.2028 - val_binary_crossentropy: 0.7405 - val_accuracy: 0.7419
# Epoch 93/1000
# 3/3 [==============================] - 0s 37ms/step - loss: 0.0383 - mse: 0.0383 - binary_crossentropy: 0.1730 - accuracy: 0.9771 - val_loss: 0.2036 - val_mse: 0.2036 - val_binary_crossentropy: 0.7419 - val_accuracy: 0.7419
# Epoch 94/1000
# 3/3 [==============================] - 0s 36ms/step - loss: 0.0412 - mse: 0.0412 - binary_crossentropy: 0.1796 - accuracy: 0.9600 - val_loss: 0.2064 - val_mse: 0.2064 - val_binary_crossentropy: 0.7539 - val_accuracy: 0.7419
# Epoch 95/1000
# 3/3 [==============================] - 0s 35ms/step - loss: 0.0384 - mse: 0.0384 - binary_crossentropy: 0.1699 - accuracy: 0.9714 - val_loss: 0.2083 - val_mse: 0.2083 - val_binary_crossentropy: 0.7660 - val_accuracy: 0.7419
# Epoch 96/1000
# 3/3 [==============================] - 0s 34ms/step - loss: 0.0326 - mse: 0.0326 - binary_crossentropy: 0.1600 - accuracy: 0.9829 - val_loss: 0.2062 - val_mse: 0.2062 - val_binary_crossentropy: 0.7633 - val_accuracy: 0.7419
# Epoch 97/1000
# 3/3 [==============================] - 0s 38ms/step - loss: 0.0345 - mse: 0.0345 - binary_crossentropy: 0.1610 - accuracy: 0.9714 - val_loss: 0.2055 - val_mse: 0.2055 - val_binary_crossentropy: 0.7635 - val_accuracy: 0.7419
# Epoch 98/1000
# 3/3 [==============================] - 0s 37ms/step - loss: 0.0335 - mse: 0.0335 - binary_crossentropy: 0.1568 - accuracy: 0.9714 - val_loss: 0.2141 - val_mse: 0.2141 - val_binary_crossentropy: 0.7962 - val_accuracy: 0.7419
# Epoch 99/1000
# 3/3 [==============================] - 0s 34ms/step - loss: 0.0316 - mse: 0.0316 - binary_crossentropy: 0.1541 - accuracy: 0.9771 - val_loss: 0.2071 - val_mse: 0.2071 - val_binary_crossentropy: 0.7724 - val_accuracy: 0.7419
# Epoch 100/1000
# 3/3 [==============================] - 0s 34ms/step - loss: 0.0302 - mse: 0.0302 - binary_crossentropy: 0.1487 - accuracy: 0.9829 - val_loss: 0.1997 - val_mse: 0.1997 - val_binary_crossentropy: 0.7529 - val_accuracy: 0.7742
# Epoch 101/1000
# 3/3 [==============================] - 0s 38ms/step - loss: 0.0305 - mse: 0.0305 - binary_crossentropy: 0.1538 - accuracy: 0.9771 - val_loss: 0.2015 - val_mse: 0.2015 - val_binary_crossentropy: 0.7612 - val_accuracy: 0.7742
# Epoch 102/1000
# 3/3 [==============================] - 0s 35ms/step - loss: 0.0308 - mse: 0.0308 - binary_crossentropy: 0.1481 - accuracy: 0.9714 - val_loss: 0.2084 - val_mse: 0.2084 - val_binary_crossentropy: 0.7868 - val_accuracy: 0.7419
# Epoch 103/1000
# 3/3 [==============================] - 0s 36ms/step - loss: 0.0281 - mse: 0.0281 - binary_crossentropy: 0.1386 - accuracy: 0.9829 - val_loss: 0.2121 - val_mse: 0.2121 - val_binary_crossentropy: 0.7997 - val_accuracy: 0.7419
# Epoch 104/1000
# 3/3 [==============================] - 0s 34ms/step - loss: 0.0267 - mse: 0.0267 - binary_crossentropy: 0.1359 - accuracy: 0.9771 - val_loss: 0.2122 - val_mse: 0.2122 - val_binary_crossentropy: 0.8037 - val_accuracy: 0.7419
# Epoch 105/1000
# 3/3 [==============================] - 0s 39ms/step - loss: 0.0290 - mse: 0.0290 - binary_crossentropy: 0.1449 - accuracy: 0.9771 - val_loss: 0.2133 - val_mse: 0.2133 - val_binary_crossentropy: 0.8110 - val_accuracy: 0.7419
# Epoch 106/1000
# 3/3 [==============================] - 0s 56ms/step - loss: 0.0274 - mse: 0.0274 - binary_crossentropy: 0.1422 - accuracy: 0.9829 - val_loss: 0.2126 - val_mse: 0.2126 - val_binary_crossentropy: 0.8141 - val_accuracy: 0.7419
# Epoch 107/1000
# 3/3 [==============================] - 0s 36ms/step - loss: 0.0285 - mse: 0.0285 - binary_crossentropy: 0.1381 - accuracy: 0.9829 - val_loss: 0.2138 - val_mse: 0.2138 - val_binary_crossentropy: 0.8206 - val_accuracy: 0.7419
# Epoch 108/1000
# 3/3 [==============================] - 0s 36ms/step - loss: 0.0288 - mse: 0.0288 - binary_crossentropy: 0.1378 - accuracy: 0.9771 - val_loss: 0.2146 - val_mse: 0.2146 - val_binary_crossentropy: 0.8243 - val_accuracy: 0.7419
# Epoch 109/1000
# 3/3 [==============================] - 0s 33ms/step - loss: 0.0299 - mse: 0.0299 - binary_crossentropy: 0.1429 - accuracy: 0.9714 - val_loss: 0.2103 - val_mse: 0.2103 - val_binary_crossentropy: 0.8191 - val_accuracy: 0.7419
# Epoch 110/1000
# 3/3 [==============================] - 0s 36ms/step - loss: 0.0239 - mse: 0.0239 - binary_crossentropy: 0.1243 - accuracy: 0.9829 - val_loss: 0.2049 - val_mse: 0.2049 - val_binary_crossentropy: 0.7972 - val_accuracy: 0.7419
# Epoch 111/1000
# 3/3 [==============================] - 0s 38ms/step - loss: 0.0278 - mse: 0.0278 - binary_crossentropy: 0.1316 - accuracy: 0.9829 - val_loss: 0.2116 - val_mse: 0.2116 - val_binary_crossentropy: 0.8275 - val_accuracy: 0.7742
# Epoch 112/1000
# 3/3 [==============================] - 0s 36ms/step - loss: 0.0244 - mse: 0.0244 - binary_crossentropy: 0.1249 - accuracy: 0.9829 - val_loss: 0.2125 - val_mse: 0.2125 - val_binary_crossentropy: 0.8371 - val_accuracy: 0.7742
# Epoch 113/1000
# 3/3 [==============================] - 0s 38ms/step - loss: 0.0267 - mse: 0.0267 - binary_crossentropy: 0.1397 - accuracy: 0.9829 - val_loss: 0.2179 - val_mse: 0.2179 - val_binary_crossentropy: 0.8444 - val_accuracy: 0.7419
# Epoch 114/1000
# 3/3 [==============================] - 0s 33ms/step - loss: 0.0281 - mse: 0.0281 - binary_crossentropy: 0.1338 - accuracy: 0.9829 - val_loss: 0.2212 - val_mse: 0.2212 - val_binary_crossentropy: 0.8669 - val_accuracy: 0.7419
# Epoch 115/1000
# 3/3 [==============================] - 0s 36ms/step - loss: 0.0228 - mse: 0.0228 - binary_crossentropy: 0.1221 - accuracy: 0.9829 - val_loss: 0.2186 - val_mse: 0.2186 - val_binary_crossentropy: 0.8675 - val_accuracy: 0.7419
# Epoch 116/1000
# 3/3 [==============================] - 0s 34ms/step - loss: 0.0285 - mse: 0.0285 - binary_crossentropy: 0.1395 - accuracy: 0.9714 - val_loss: 0.2169 - val_mse: 0.2169 - val_binary_crossentropy: 0.8468 - val_accuracy: 0.7419
# Epoch 117/1000
# 3/3 [==============================] - 0s 35ms/step - loss: 0.0289 - mse: 0.0289 - binary_crossentropy: 0.1328 - accuracy: 0.9657 - val_loss: 0.2219 - val_mse: 0.2219 - val_binary_crossentropy: 0.8690 - val_accuracy: 0.7419
# Epoch 118/1000
# 3/3 [==============================] - 0s 36ms/step - loss: 0.0243 - mse: 0.0243 - binary_crossentropy: 0.1231 - accuracy: 0.9829 - val_loss: 0.2233 - val_mse: 0.2233 - val_binary_crossentropy: 0.8813 - val_accuracy: 0.7097
# Epoch 119/1000
# 3/3 [==============================] - 0s 35ms/step - loss: 0.0229 - mse: 0.0229 - binary_crossentropy: 0.1214 - accuracy: 0.9829 - val_loss: 0.2180 - val_mse: 0.2180 - val_binary_crossentropy: 0.8542 - val_accuracy: 0.7419
# Epoch 120/1000
# 3/3 [==============================] - 0s 35ms/step - loss: 0.0231 - mse: 0.0231 - binary_crossentropy: 0.1169 - accuracy: 0.9829 - val_loss: 0.2127 - val_mse: 0.2127 - val_binary_crossentropy: 0.8286 - val_accuracy: 0.7419
# Epoch 121/1000
# 3/3 [==============================] - 0s 33ms/step - loss: 0.0207 - mse: 0.0207 - binary_crossentropy: 0.1091 - accuracy: 0.9771 - val_loss: 0.2036 - val_mse: 0.2036 - val_binary_crossentropy: 0.8108 - val_accuracy: 0.7742
# Epoch 122/1000
# 3/3 [==============================] - 0s 38ms/step - loss: 0.0207 - mse: 0.0207 - binary_crossentropy: 0.1065 - accuracy: 0.9829 - val_loss: 0.2046 - val_mse: 0.2046 - val_binary_crossentropy: 0.8239 - val_accuracy: 0.7742
# Epoch 123/1000
# 3/3 [==============================] - 0s 33ms/step - loss: 0.0237 - mse: 0.0237 - binary_crossentropy: 0.1211 - accuracy: 0.9829 - val_loss: 0.2041 - val_mse: 0.2041 - val_binary_crossentropy: 0.8186 - val_accuracy: 0.7742
# Epoch 124/1000
# 3/3 [==============================] - 0s 36ms/step - loss: 0.0222 - mse: 0.0222 - binary_crossentropy: 0.1155 - accuracy: 0.9829 - val_loss: 0.2065 - val_mse: 0.2065 - val_binary_crossentropy: 0.8162 - val_accuracy: 0.7419
# Epoch 125/1000
# 3/3 [==============================] - 0s 36ms/step - loss: 0.0231 - mse: 0.0231 - binary_crossentropy: 0.1210 - accuracy: 0.9829 - val_loss: 0.2086 - val_mse: 0.2086 - val_binary_crossentropy: 0.8410 - val_accuracy: 0.7742
# Epoch 126/1000
# 3/3 [==============================] - 0s 36ms/step - loss: 0.0214 - mse: 0.0214 - binary_crossentropy: 0.1099 - accuracy: 0.9829 - val_loss: 0.2153 - val_mse: 0.2153 - val_binary_crossentropy: 0.8713 - val_accuracy: 0.7742
# Epoch 127/1000
# 3/3 [==============================] - 0s 38ms/step - loss: 0.0212 - mse: 0.0212 - binary_crossentropy: 0.1134 - accuracy: 0.9829 - val_loss: 0.2197 - val_mse: 0.2197 - val_binary_crossentropy: 0.8777 - val_accuracy: 0.7419
# Epoch 128/1000
# 3/3 [==============================] - 0s 36ms/step - loss: 0.0203 - mse: 0.0203 - binary_crossentropy: 0.1111 - accuracy: 0.9829 - val_loss: 0.2174 - val_mse: 0.2174 - val_binary_crossentropy: 0.8723 - val_accuracy: 0.7419
# Epoch 129/1000
# 3/3 [==============================] - 0s 36ms/step - loss: 0.0182 - mse: 0.0182 - binary_crossentropy: 0.1036 - accuracy: 0.9829 - val_loss: 0.2093 - val_mse: 0.2093 - val_binary_crossentropy: 0.8548 - val_accuracy: 0.7742
# Epoch 130/1000
# 3/3 [==============================] - 0s 38ms/step - loss: 0.0197 - mse: 0.0197 - binary_crossentropy: 0.1093 - accuracy: 0.9829 - val_loss: 0.2039 - val_mse: 0.2039 - val_binary_crossentropy: 0.8494 - val_accuracy: 0.7742
# Epoch 131/1000
# 3/3 [==============================] - 0s 35ms/step - loss: 0.0198 - mse: 0.0198 - binary_crossentropy: 0.1071 - accuracy: 0.9829 - val_loss: 0.2132 - val_mse: 0.2132 - val_binary_crossentropy: 0.8773 - val_accuracy: 0.7742
# Epoch 132/1000
# 3/3 [==============================] - 0s 37ms/step - loss: 0.0194 - mse: 0.0194 - binary_crossentropy: 0.1079 - accuracy: 0.9829 - val_loss: 0.2226 - val_mse: 0.2226 - val_binary_crossentropy: 0.9102 - val_accuracy: 0.7419
# Epoch 133/1000
# 3/3 [==============================] - 0s 37ms/step - loss: 0.0204 - mse: 0.0204 - binary_crossentropy: 0.1075 - accuracy: 0.9829 - val_loss: 0.2166 - val_mse: 0.2166 - val_binary_crossentropy: 0.9002 - val_accuracy: 0.7742
# Epoch 134/1000
# 3/3 [==============================] - 0s 35ms/step - loss: 0.0166 - mse: 0.0166 - binary_crossentropy: 0.0964 - accuracy: 0.9886 - val_loss: 0.2073 - val_mse: 0.2073 - val_binary_crossentropy: 0.8548 - val_accuracy: 0.7742
# Epoch 135/1000
# 3/3 [==============================] - 0s 48ms/step - loss: 0.0164 - mse: 0.0164 - binary_crossentropy: 0.0947 - accuracy: 0.9886 - val_loss: 0.2091 - val_mse: 0.2091 - val_binary_crossentropy: 0.8631 - val_accuracy: 0.7742
# Epoch 136/1000
# 3/3 [==============================] - 0s 32ms/step - loss: 0.0175 - mse: 0.0175 - binary_crossentropy: 0.1038 - accuracy: 0.9886 - val_loss: 0.2203 - val_mse: 0.2203 - val_binary_crossentropy: 0.9141 - val_accuracy: 0.7419
# Epoch 137/1000
# 3/3 [==============================] - 0s 35ms/step - loss: 0.0178 - mse: 0.0178 - binary_crossentropy: 0.0971 - accuracy: 0.9829 - val_loss: 0.2290 - val_mse: 0.2290 - val_binary_crossentropy: 0.9631 - val_accuracy: 0.7419
# Epoch 138/1000
# 3/3 [==============================] - 0s 37ms/step - loss: 0.0170 - mse: 0.0170 - binary_crossentropy: 0.0956 - accuracy: 0.9829 - val_loss: 0.2298 - val_mse: 0.2298 - val_binary_crossentropy: 0.9673 - val_accuracy: 0.7419
# Epoch 139/1000
# 3/3 [==============================] - 0s 37ms/step - loss: 0.0198 - mse: 0.0198 - binary_crossentropy: 0.1043 - accuracy: 0.9829 - val_loss: 0.2160 - val_mse: 0.2160 - val_binary_crossentropy: 0.8965 - val_accuracy: 0.7419
# Epoch 140/1000
# 3/3 [==============================] - 0s 37ms/step - loss: 0.0161 - mse: 0.0161 - binary_crossentropy: 0.0930 - accuracy: 0.9886 - val_loss: 0.2120 - val_mse: 0.2120 - val_binary_crossentropy: 0.8800 - val_accuracy: 0.7742
# Epoch 141/1000
# 3/3 [==============================] - 0s 37ms/step - loss: 0.0156 - mse: 0.0156 - binary_crossentropy: 0.0962 - accuracy: 0.9886 - val_loss: 0.2117 - val_mse: 0.2117 - val_binary_crossentropy: 0.8765 - val_accuracy: 0.7742
# Epoch 142/1000
# 3/3 [==============================] - 0s 38ms/step - loss: 0.0173 - mse: 0.0173 - binary_crossentropy: 0.0957 - accuracy: 0.9829 - val_loss: 0.2189 - val_mse: 0.2189 - val_binary_crossentropy: 0.9117 - val_accuracy: 0.7419
# Epoch 143/1000
# 3/3 [==============================] - 0s 34ms/step - loss: 0.0153 - mse: 0.0153 - binary_crossentropy: 0.0937 - accuracy: 0.9886 - val_loss: 0.2240 - val_mse: 0.2240 - val_binary_crossentropy: 0.9524 - val_accuracy: 0.7419
# Epoch 144/1000
# 3/3 [==============================] - 0s 36ms/step - loss: 0.0150 - mse: 0.0150 - binary_crossentropy: 0.0849 - accuracy: 0.9829 - val_loss: 0.2259 - val_mse: 0.2259 - val_binary_crossentropy: 0.9717 - val_accuracy: 0.7419
# Epoch 145/1000
# 3/3 [==============================] - 0s 33ms/step - loss: 0.0134 - mse: 0.0134 - binary_crossentropy: 0.0874 - accuracy: 0.9886 - val_loss: 0.2197 - val_mse: 0.2197 - val_binary_crossentropy: 0.9443 - val_accuracy: 0.7419
# Epoch 146/1000
# 3/3 [==============================] - 0s 37ms/step - loss: 0.0133 - mse: 0.0133 - binary_crossentropy: 0.0855 - accuracy: 0.9886 - val_loss: 0.2164 - val_mse: 0.2164 - val_binary_crossentropy: 0.9219 - val_accuracy: 0.7742
# Epoch 147/1000
# 3/3 [==============================] - 0s 33ms/step - loss: 0.0137 - mse: 0.0137 - binary_crossentropy: 0.0833 - accuracy: 0.9886 - val_loss: 0.2160 - val_mse: 0.2160 - val_binary_crossentropy: 0.9180 - val_accuracy: 0.7742
# Epoch 148/1000
# 3/3 [==============================] - 0s 36ms/step - loss: 0.0143 - mse: 0.0143 - binary_crossentropy: 0.0865 - accuracy: 0.9886 - val_loss: 0.2151 - val_mse: 0.2151 - val_binary_crossentropy: 0.9253 - val_accuracy: 0.7742
# Epoch 149/1000
# 3/3 [==============================] - 0s 37ms/step - loss: 0.0134 - mse: 0.0134 - binary_crossentropy: 0.0823 - accuracy: 0.9886 - val_loss: 0.2184 - val_mse: 0.2184 - val_binary_crossentropy: 0.9374 - val_accuracy: 0.7419
# Epoch 150/1000
# 3/3 [==============================] - 0s 67ms/step - loss: 0.0138 - mse: 0.0138 - binary_crossentropy: 0.0869 - accuracy: 0.9886 - val_loss: 0.2210 - val_mse: 0.2210 - val_binary_crossentropy: 0.9480 - val_accuracy: 0.7419
# Epoch 151/1000
# 3/3 [==============================] - 0s 34ms/step - loss: 0.0132 - mse: 0.0132 - binary_crossentropy: 0.0832 - accuracy: 0.9886 - val_loss: 0.2186 - val_mse: 0.2186 - val_binary_crossentropy: 0.9426 - val_accuracy: 0.7419
# Epoch 152/1000
# 3/3 [==============================] - 0s 34ms/step - loss: 0.0137 - mse: 0.0137 - binary_crossentropy: 0.0869 - accuracy: 0.9886 - val_loss: 0.2161 - val_mse: 0.2161 - val_binary_crossentropy: 0.9262 - val_accuracy: 0.7742
# Epoch 153/1000
# 3/3 [==============================] - 0s 33ms/step - loss: 0.0133 - mse: 0.0133 - binary_crossentropy: 0.0843 - accuracy: 0.9886 - val_loss: 0.2136 - val_mse: 0.2136 - val_binary_crossentropy: 0.9147 - val_accuracy: 0.7742
# Epoch 154/1000
# 3/3 [==============================] - 0s 38ms/step - loss: 0.0135 - mse: 0.0135 - binary_crossentropy: 0.0835 - accuracy: 0.9886 - val_loss: 0.2133 - val_mse: 0.2133 - val_binary_crossentropy: 0.9156 - val_accuracy: 0.7742
# Epoch 155/1000
# 3/3 [==============================] - 0s 39ms/step - loss: 0.0133 - mse: 0.0133 - binary_crossentropy: 0.0766 - accuracy: 0.9886 - val_loss: 0.2153 - val_mse: 0.2153 - val_binary_crossentropy: 0.9289 - val_accuracy: 0.7742
# Epoch 156/1000
# 3/3 [==============================] - 0s 38ms/step - loss: 0.0132 - mse: 0.0132 - binary_crossentropy: 0.0836 - accuracy: 0.9886 - val_loss: 0.2181 - val_mse: 0.2181 - val_binary_crossentropy: 0.9583 - val_accuracy: 0.7742
# Epoch 157/1000
# 3/3 [==============================] - 0s 37ms/step - loss: 0.0127 - mse: 0.0127 - binary_crossentropy: 0.0810 - accuracy: 0.9886 - val_loss: 0.2250 - val_mse: 0.2250 - val_binary_crossentropy: 0.9901 - val_accuracy: 0.7419
# Epoch 158/1000
# 3/3 [==============================] - 0s 32ms/step - loss: 0.0132 - mse: 0.0132 - binary_crossentropy: 0.0803 - accuracy: 0.9886 - val_loss: 0.2255 - val_mse: 0.2255 - val_binary_crossentropy: 0.9940 - val_accuracy: 0.7419
# Epoch 159/1000
# 3/3 [==============================] - 0s 37ms/step - loss: 0.0135 - mse: 0.0135 - binary_crossentropy: 0.0823 - accuracy: 0.9886 - val_loss: 0.2230 - val_mse: 0.2230 - val_binary_crossentropy: 0.9753 - val_accuracy: 0.7419
# Epoch 160/1000
# 3/3 [==============================] - 0s 47ms/step - loss: 0.0125 - mse: 0.0125 - binary_crossentropy: 0.0740 - accuracy: 0.9886 - val_loss: 0.2158 - val_mse: 0.2158 - val_binary_crossentropy: 0.9459 - val_accuracy: 0.7742
# Epoch 161/1000
# 3/3 [==============================] - 0s 35ms/step - loss: 0.0132 - mse: 0.0132 - binary_crossentropy: 0.0838 - accuracy: 0.9886 - val_loss: 0.2093 - val_mse: 0.2093 - val_binary_crossentropy: 0.9210 - val_accuracy: 0.7742
# Epoch 162/1000
# 3/3 [==============================] - 0s 36ms/step - loss: 0.0125 - mse: 0.0125 - binary_crossentropy: 0.0743 - accuracy: 0.9886 - val_loss: 0.2103 - val_mse: 0.2103 - val_binary_crossentropy: 0.9207 - val_accuracy: 0.7742
# Epoch 163/1000
# 3/3 [==============================] - 0s 34ms/step - loss: 0.0128 - mse: 0.0128 - binary_crossentropy: 0.0738 - accuracy: 0.9886 - val_loss: 0.2152 - val_mse: 0.2152 - val_binary_crossentropy: 0.9372 - val_accuracy: 0.7742
# Epoch 164/1000
# 3/3 [==============================] - 0s 36ms/step - loss: 0.0126 - mse: 0.0126 - binary_crossentropy: 0.0770 - accuracy: 0.9886 - val_loss: 0.2161 - val_mse: 0.2161 - val_binary_crossentropy: 0.9489 - val_accuracy: 0.7742
# Epoch 165/1000
# 3/3 [==============================] - 0s 32ms/step - loss: 0.0124 - mse: 0.0124 - binary_crossentropy: 0.0777 - accuracy: 0.9886 - val_loss: 0.2131 - val_mse: 0.2131 - val_binary_crossentropy: 0.9526 - val_accuracy: 0.7742
# Epoch 166/1000
# 3/3 [==============================] - 0s 38ms/step - loss: 0.0124 - mse: 0.0124 - binary_crossentropy: 0.0787 - accuracy: 0.9886 - val_loss: 0.2130 - val_mse: 0.2130 - val_binary_crossentropy: 0.9588 - val_accuracy: 0.7742
# Epoch 167/1000
# 3/3 [==============================] - 0s 36ms/step - loss: 0.0124 - mse: 0.0124 - binary_crossentropy: 0.0776 - accuracy: 0.9886 - val_loss: 0.2158 - val_mse: 0.2158 - val_binary_crossentropy: 0.9662 - val_accuracy: 0.7742
# Epoch 168/1000
# 3/3 [==============================] - 0s 36ms/step - loss: 0.0122 - mse: 0.0122 - binary_crossentropy: 0.0754 - accuracy: 0.9886 - val_loss: 0.2184 - val_mse: 0.2184 - val_binary_crossentropy: 0.9671 - val_accuracy: 0.7742
# Epoch 169/1000
# 3/3 [==============================] - 0s 37ms/step - loss: 0.0128 - mse: 0.0128 - binary_crossentropy: 0.0772 - accuracy: 0.9886 - val_loss: 0.2168 - val_mse: 0.2168 - val_binary_crossentropy: 0.9564 - val_accuracy: 0.7742
# Epoch 170/1000
# 3/3 [==============================] - 0s 39ms/step - loss: 0.0118 - mse: 0.0118 - binary_crossentropy: 0.0673 - accuracy: 0.9886 - val_loss: 0.2136 - val_mse: 0.2136 - val_binary_crossentropy: 0.9475 - val_accuracy: 0.7742
# Epoch 171/1000
# 3/3 [==============================] - 0s 33ms/step - loss: 0.0121 - mse: 0.0121 - binary_crossentropy: 0.0699 - accuracy: 0.9886 - val_loss: 0.2086 - val_mse: 0.2086 - val_binary_crossentropy: 0.9312 - val_accuracy: 0.7742
# Epoch 172/1000
# 3/3 [==============================] - 0s 38ms/step - loss: 0.0118 - mse: 0.0118 - binary_crossentropy: 0.0675 - accuracy: 0.9886 - val_loss: 0.2039 - val_mse: 0.2039 - val_binary_crossentropy: 0.9071 - val_accuracy: 0.7742
# Epoch 173/1000
# 3/3 [==============================] - 0s 33ms/step - loss: 0.0113 - mse: 0.0113 - binary_crossentropy: 0.0663 - accuracy: 0.9886 - val_loss: 0.2014 - val_mse: 0.2014 - val_binary_crossentropy: 0.8841 - val_accuracy: 0.7742
# Epoch 174/1000
# 3/3 [==============================] - 0s 38ms/step - loss: 0.0102 - mse: 0.0102 - binary_crossentropy: 0.0601 - accuracy: 0.9886 - val_loss: 0.1980 - val_mse: 0.1980 - val_binary_crossentropy: 0.8745 - val_accuracy: 0.7742
# Epoch 175/1000
# 3/3 [==============================] - 0s 37ms/step - loss: 0.0122 - mse: 0.0122 - binary_crossentropy: 0.0678 - accuracy: 0.9886 - val_loss: 0.1984 - val_mse: 0.1984 - val_binary_crossentropy: 0.8811 - val_accuracy: 0.7742
# Epoch 176/1000
# 3/3 [==============================] - 0s 32ms/step - loss: 0.0088 - mse: 0.0088 - binary_crossentropy: 0.0607 - accuracy: 0.9943 - val_loss: 0.1954 - val_mse: 0.1954 - val_binary_crossentropy: 0.8709 - val_accuracy: 0.8065
# Epoch 177/1000
# 3/3 [==============================] - 0s 35ms/step - loss: 0.0109 - mse: 0.0109 - binary_crossentropy: 0.0661 - accuracy: 0.9886 - val_loss: 0.2045 - val_mse: 0.2045 - val_binary_crossentropy: 0.8887 - val_accuracy: 0.7742
# Epoch 178/1000
# 3/3 [==============================] - 0s 35ms/step - loss: 0.0125 - mse: 0.0125 - binary_crossentropy: 0.0688 - accuracy: 0.9886 - val_loss: 0.2245 - val_mse: 0.2245 - val_binary_crossentropy: 0.9811 - val_accuracy: 0.7419
# Epoch 179/1000
# 3/3 [==============================] - 0s 37ms/step - loss: 0.0090 - mse: 0.0090 - binary_crossentropy: 0.0594 - accuracy: 0.9943 - val_loss: 0.2115 - val_mse: 0.2115 - val_binary_crossentropy: 0.9905 - val_accuracy: 0.7742
# Epoch 180/1000
# 3/3 [==============================] - 0s 77ms/step - loss: 0.0088 - mse: 0.0088 - binary_crossentropy: 0.0615 - accuracy: 0.9943 - val_loss: 0.2034 - val_mse: 0.2034 - val_binary_crossentropy: 0.9172 - val_accuracy: 0.7742
# Epoch 181/1000
# 3/3 [==============================] - 0s 48ms/step - loss: 0.0082 - mse: 0.0082 - binary_crossentropy: 0.0575 - accuracy: 0.9943 - val_loss: 0.2007 - val_mse: 0.2007 - val_binary_crossentropy: 0.8740 - val_accuracy: 0.7742
# Epoch 182/1000
# 3/3 [==============================] - 0s 38ms/step - loss: 0.0116 - mse: 0.0116 - binary_crossentropy: 0.0665 - accuracy: 0.9886 - val_loss: 0.2041 - val_mse: 0.2041 - val_binary_crossentropy: 0.9247 - val_accuracy: 0.7742
# Epoch 183/1000
# 3/3 [==============================] - 0s 38ms/step - loss: 0.0122 - mse: 0.0122 - binary_crossentropy: 0.0696 - accuracy: 0.9829 - val_loss: 0.2037 - val_mse: 0.2037 - val_binary_crossentropy: 0.9205 - val_accuracy: 0.7742
# Epoch 184/1000
# 3/3 [==============================] - 0s 35ms/step - loss: 0.0097 - mse: 0.0097 - binary_crossentropy: 0.0609 - accuracy: 0.9886 - val_loss: 0.1977 - val_mse: 0.1977 - val_binary_crossentropy: 0.9056 - val_accuracy: 0.8065
# Epoch 185/1000
# 3/3 [==============================] - 0s 36ms/step - loss: 0.0072 - mse: 0.0072 - binary_crossentropy: 0.0524 - accuracy: 0.9943 - val_loss: 0.1948 - val_mse: 0.1948 - val_binary_crossentropy: 0.9064 - val_accuracy: 0.8065
# Epoch 186/1000
# 3/3 [==============================] - 0s 35ms/step - loss: 0.0099 - mse: 0.0099 - binary_crossentropy: 0.0650 - accuracy: 0.9943 - val_loss: 0.1944 - val_mse: 0.1944 - val_binary_crossentropy: 0.8960 - val_accuracy: 0.8065
# Epoch 187/1000
# 3/3 [==============================] - 0s 37ms/step - loss: 0.0074 - mse: 0.0074 - binary_crossentropy: 0.0564 - accuracy: 0.9943 - val_loss: 0.1906 - val_mse: 0.1906 - val_binary_crossentropy: 0.8912 - val_accuracy: 0.8065
# Epoch 188/1000
# 3/3 [==============================] - 0s 38ms/step - loss: 0.0085 - mse: 0.0085 - binary_crossentropy: 0.0597 - accuracy: 0.9943 - val_loss: 0.1894 - val_mse: 0.1894 - val_binary_crossentropy: 0.8562 - val_accuracy: 0.8065
# Epoch 189/1000
# 3/3 [==============================] - 0s 37ms/step - loss: 0.0095 - mse: 0.0095 - binary_crossentropy: 0.0633 - accuracy: 0.9943 - val_loss: 0.1957 - val_mse: 0.1957 - val_binary_crossentropy: 0.9101 - val_accuracy: 0.8065
# Epoch 190/1000
# 3/3 [==============================] - 0s 35ms/step - loss: 0.0086 - mse: 0.0086 - binary_crossentropy: 0.0580 - accuracy: 0.9943 - val_loss: 0.2074 - val_mse: 0.2074 - val_binary_crossentropy: 0.9661 - val_accuracy: 0.7742
# Epoch 191/1000
# 3/3 [==============================] - 0s 36ms/step - loss: 0.0087 - mse: 0.0087 - binary_crossentropy: 0.0591 - accuracy: 0.9943 - val_loss: 0.2123 - val_mse: 0.2123 - val_binary_crossentropy: 0.9684 - val_accuracy: 0.7419
# Epoch 192/1000
# 3/3 [==============================] - 0s 36ms/step - loss: 0.0078 - mse: 0.0078 - binary_crossentropy: 0.0544 - accuracy: 0.9943 - val_loss: 0.2221 - val_mse: 0.2221 - val_binary_crossentropy: 0.9969 - val_accuracy: 0.7419
# Epoch 193/1000
# 3/3 [==============================] - 0s 39ms/step - loss: 0.0085 - mse: 0.0085 - binary_crossentropy: 0.0565 - accuracy: 0.9943 - val_loss: 0.2086 - val_mse: 0.2086 - val_binary_crossentropy: 0.9855 - val_accuracy: 0.7742
# Epoch 194/1000
# 3/3 [==============================] - 0s 38ms/step - loss: 0.0107 - mse: 0.0107 - binary_crossentropy: 0.0652 - accuracy: 0.9886 - val_loss: 0.2038 - val_mse: 0.2038 - val_binary_crossentropy: 0.9075 - val_accuracy: 0.7742
# Epoch 195/1000
# 3/3 [==============================] - 0s 41ms/step - loss: 0.0070 - mse: 0.0070 - binary_crossentropy: 0.0512 - accuracy: 0.9943 - val_loss: 0.2069 - val_mse: 0.2069 - val_binary_crossentropy: 0.8531 - val_accuracy: 0.7419
# Epoch 196/1000
# ...
# Epoch 839/1000
# 3/3 [==============================] - 0s 143ms/step - loss: 0.0057 - mse: 0.0057 - binary_crossentropy: 0.0373 - accuracy: 0.9943 - val_loss: 0.2167 - val_mse: 0.2167 - val_binary_crossentropy: 1.1840 - val_accuracy: 0.7742
# Epoch 840/1000
# 3/3 [==============================] - 0s 60ms/step - loss: 0.0057 - mse: 0.0057 - binary_crossentropy: 0.0394 - accuracy: 0.9943 - val_loss: 0.2169 - val_mse: 0.2169 - val_binary_crossentropy: 1.1860 - val_accuracy: 0.7742
# Epoch 841/1000
# 3/3 [==============================] - 0s 99ms/step - loss: 0.0057 - mse: 0.0057 - binary_crossentropy: 0.0391 - accuracy: 0.9943 - val_loss: 0.2168 - val_mse: 0.2168 - val_binary_crossentropy: 1.1854 - val_accuracy: 0.7742
# Epoch 842/1000
# 3/3 [==============================] - 0s 48ms/step - loss: 0.0057 - mse: 0.0057 - binary_crossentropy: 0.0398 - accuracy: 0.9943 - val_loss: 0.2168 - val_mse: 0.2168 - val_binary_crossentropy: 1.1853 - val_accuracy: 0.7742
# Epoch 843/1000
# 3/3 [==============================] - 0s 45ms/step - loss: 0.0057 - mse: 0.0057 - binary_crossentropy: 0.0393 - accuracy: 0.9943 - val_loss: 0.2167 - val_mse: 0.2167 - val_binary_crossentropy: 1.1859 - val_accuracy: 0.7742
# Epoch 844/1000
# 3/3 [==============================] - 0s 45ms/step - loss: 0.0057 - mse: 0.0057 - binary_crossentropy: 0.0396 - accuracy: 0.9943 - val_loss: 0.2167 - val_mse: 0.2167 - val_binary_crossentropy: 1.1868 - val_accuracy: 0.7742
# Epoch 845/1000
# 3/3 [==============================] - 0s 47ms/step - loss: 0.0057 - mse: 0.0057 - binary_crossentropy: 0.0397 - accuracy: 0.9943 - val_loss: 0.2168 - val_mse: 0.2168 - val_binary_crossentropy: 1.1873 - val_accuracy: 0.7742
# Epoch 846/1000
# 3/3 [==============================] - 0s 70ms/step - loss: 0.0057 - mse: 0.0057 - binary_crossentropy: 0.0393 - accuracy: 0.9943 - val_loss: 0.2167 - val_mse: 0.2167 - val_binary_crossentropy: 1.1860 - val_accuracy: 0.7742
# Epoch 847/1000
# 3/3 [==============================] - 0s 45ms/step - loss: 0.0057 - mse: 0.0057 - binary_crossentropy: 0.0393 - accuracy: 0.9943 - val_loss: 0.2165 - val_mse: 0.2165 - val_binary_crossentropy: 1.1845 - val_accuracy: 0.7742
# Epoch 848/1000
# 3/3 [==============================] - 0s 47ms/step - loss: 0.0057 - mse: 0.0057 - binary_crossentropy: 0.0393 - accuracy: 0.9943 - val_loss: 0.2163 - val_mse: 0.2163 - val_binary_crossentropy: 1.1823 - val_accuracy: 0.7742
# Epoch 849/1000
# 3/3 [==============================] - 0s 47ms/step - loss: 0.0057 - mse: 0.0057 - binary_crossentropy: 0.0391 - accuracy: 0.9943 - val_loss: 0.2165 - val_mse: 0.2165 - val_binary_crossentropy: 1.1821 - val_accuracy: 0.7742
# Epoch 850/1000
# 3/3 [==============================] - 0s 67ms/step - loss: 0.0057 - mse: 0.0057 - binary_crossentropy: 0.0396 - accuracy: 0.9943 - val_loss: 0.2168 - val_mse: 0.2168 - val_binary_crossentropy: 1.1826 - val_accuracy: 0.7742
# Epoch 851/1000
# 3/3 [==============================] - 0s 45ms/step - loss: 0.0057 - mse: 0.0057 - binary_crossentropy: 0.0392 - accuracy: 0.9943 - val_loss: 0.2169 - val_mse: 0.2169 - val_binary_crossentropy: 1.1817 - val_accuracy: 0.7742
# Epoch 852/1000
# 3/3 [==============================] - 0s 47ms/step - loss: 0.0057 - mse: 0.0057 - binary_crossentropy: 0.0397 - accuracy: 0.9943 - val_loss: 0.2168 - val_mse: 0.2168 - val_binary_crossentropy: 1.1799 - val_accuracy: 0.7742
# Epoch 853/1000
# 3/3 [==============================] - 0s 63ms/step - loss: 0.0057 - mse: 0.0057 - binary_crossentropy: 0.0393 - accuracy: 0.9943 - val_loss: 0.2169 - val_mse: 0.2169 - val_binary_crossentropy: 1.1798 - val_accuracy: 0.7742
# Epoch 854/1000
# 3/3 [==============================] - 0s 81ms/step - loss: 0.0057 - mse: 0.0057 - binary_crossentropy: 0.0398 - accuracy: 0.9943 - val_loss: 0.2170 - val_mse: 0.2170 - val_binary_crossentropy: 1.1799 - val_accuracy: 0.7742
# Epoch 855/1000
# 3/3 [==============================] - 0s 102ms/step - loss: 0.0057 - mse: 0.0057 - binary_crossentropy: 0.0394 - accuracy: 0.9943 - val_loss: 0.2171 - val_mse: 0.2171 - val_binary_crossentropy: 1.1803 - val_accuracy: 0.7742
# Epoch 856/1000
# 3/3 [==============================] - 0s 39ms/step - loss: 0.0057 - mse: 0.0057 - binary_crossentropy: 0.0395 - accuracy: 0.9943 - val_loss: 0.2172 - val_mse: 0.2172 - val_binary_crossentropy: 1.1807 - val_accuracy: 0.7742
# Epoch 857/1000
# 3/3 [==============================] - 0s 45ms/step - loss: 0.0057 - mse: 0.0057 - binary_crossentropy: 0.0398 - accuracy: 0.9943 - val_loss: 0.2172 - val_mse: 0.2172 - val_binary_crossentropy: 1.1799 - val_accuracy: 0.7742
# Epoch 858/1000
# 3/3 [==============================] - 0s 58ms/step - loss: 0.0057 - mse: 0.0057 - binary_crossentropy: 0.0392 - accuracy: 0.9943 - val_loss: 0.2170 - val_mse: 0.2170 - val_binary_crossentropy: 1.1779 - val_accuracy: 0.7742
# Epoch 859/1000
# 3/3 [==============================] - 0s 51ms/step - loss: 0.0057 - mse: 0.0057 - binary_crossentropy: 0.0392 - accuracy: 0.9943 - val_loss: 0.2169 - val_mse: 0.2169 - val_binary_crossentropy: 1.1768 - val_accuracy: 0.7742
# Epoch 860/1000
# 3/3 [==============================] - 0s 50ms/step - loss: 0.0057 - mse: 0.0057 - binary_crossentropy: 0.0389 - accuracy: 0.9943 - val_loss: 0.2169 - val_mse: 0.2169 - val_binary_crossentropy: 1.1776 - val_accuracy: 0.7742
# Epoch 861/1000
# 3/3 [==============================] - 0s 50ms/step - loss: 0.0057 - mse: 0.0057 - binary_crossentropy: 0.0396 - accuracy: 0.9943 - val_loss: 0.2172 - val_mse: 0.2172 - val_binary_crossentropy: 1.1808 - val_accuracy: 0.7742
# Epoch 862/1000
# 3/3 [==============================] - 0s 63ms/step - loss: 0.0057 - mse: 0.0057 - binary_crossentropy: 0.0369 - accuracy: 0.9943 - val_loss: 0.2174 - val_mse: 0.2174 - val_binary_crossentropy: 1.1842 - val_accuracy: 0.7742
# Epoch 863/1000
# 3/3 [==============================] - 0s 39ms/step - loss: 0.0057 - mse: 0.0057 - binary_crossentropy: 0.0390 - accuracy: 0.9943 - val_loss: 0.2174 - val_mse: 0.2174 - val_binary_crossentropy: 1.1864 - val_accuracy: 0.7742
# Epoch 864/1000
# 3/3 [==============================] - 0s 125ms/step - loss: 0.0057 - mse: 0.0057 - binary_crossentropy: 0.0390 - accuracy: 0.9943 - val_loss: 0.2175 - val_mse: 0.2175 - val_binary_crossentropy: 1.1883 - val_accuracy: 0.7742
# Epoch 865/1000
# 3/3 [==============================] - 0s 59ms/step - loss: 0.0057 - mse: 0.0057 - binary_crossentropy: 0.0393 - accuracy: 0.9943 - val_loss: 0.2175 - val_mse: 0.2175 - val_binary_crossentropy: 1.1896 - val_accuracy: 0.7742
# Epoch 866/1000
# 3/3 [==============================] - 0s 88ms/step - loss: 0.0057 - mse: 0.0057 - binary_crossentropy: 0.0393 - accuracy: 0.9943 - val_loss: 0.2175 - val_mse: 0.2175 - val_binary_crossentropy: 1.1908 - val_accuracy: 0.7742
# Epoch 867/1000
# 3/3 [==============================] - 0s 60ms/step - loss: 0.0057 - mse: 0.0057 - binary_crossentropy: 0.0392 - accuracy: 0.9943 - val_loss: 0.2175 - val_mse: 0.2175 - val_binary_crossentropy: 1.1914 - val_accuracy: 0.7742
# Epoch 868/1000
# 3/3 [==============================] - 0s 47ms/step - loss: 0.0057 - mse: 0.0057 - binary_crossentropy: 0.0391 - accuracy: 0.9943 - val_loss: 0.2175 - val_mse: 0.2175 - val_binary_crossentropy: 1.1917 - val_accuracy: 0.7742
# Epoch 869/1000
# 3/3 [==============================] - 0s 47ms/step - loss: 0.0057 - mse: 0.0057 - binary_crossentropy: 0.0396 - accuracy: 0.9943 - val_loss: 0.2175 - val_mse: 0.2175 - val_binary_crossentropy: 1.1933 - val_accuracy: 0.7742
# Epoch 870/1000
# 3/3 [==============================] - 0s 66ms/step - loss: 0.0057 - mse: 0.0057 - binary_crossentropy: 0.0391 - accuracy: 0.9943 - val_loss: 0.2176 - val_mse: 0.2176 - val_binary_crossentropy: 1.1943 - val_accuracy: 0.7742
# Epoch 871/1000
# 3/3 [==============================] - 0s 48ms/step - loss: 0.0057 - mse: 0.0057 - binary_crossentropy: 0.0395 - accuracy: 0.9943 - val_loss: 0.2173 - val_mse: 0.2173 - val_binary_crossentropy: 1.1923 - val_accuracy: 0.7742
# Epoch 872/1000
# 3/3 [==============================] - 0s 65ms/step - loss: 0.0057 - mse: 0.0057 - binary_crossentropy: 0.0391 - accuracy: 0.9943 - val_loss: 0.2174 - val_mse: 0.2174 - val_binary_crossentropy: 1.1929 - val_accuracy: 0.7742
# Epoch 873/1000
# 3/3 [==============================] - 0s 139ms/step - loss: 0.0057 - mse: 0.0057 - binary_crossentropy: 0.0396 - accuracy: 0.9943 - val_loss: 0.2171 - val_mse: 0.2171 - val_binary_crossentropy: 1.1917 - val_accuracy: 0.7742
# Epoch 874/1000
# 3/3 [==============================] - 0s 74ms/step - loss: 0.0057 - mse: 0.0057 - binary_crossentropy: 0.0392 - accuracy: 0.9943 - val_loss: 0.2169 - val_mse: 0.2169 - val_binary_crossentropy: 1.1901 - val_accuracy: 0.7742
# Epoch 875/1000
# 3/3 [==============================] - 0s 65ms/step - loss: 0.0057 - mse: 0.0057 - binary_crossentropy: 0.0388 - accuracy: 0.9943 - val_loss: 0.2167 - val_mse: 0.2167 - val_binary_crossentropy: 1.1884 - val_accuracy: 0.7742
# Epoch 876/1000
# 3/3 [==============================] - 0s 65ms/step - loss: 0.0057 - mse: 0.0057 - binary_crossentropy: 0.0396 - accuracy: 0.9943 - val_loss: 0.2163 - val_mse: 0.2163 - val_binary_crossentropy: 1.1846 - val_accuracy: 0.7742
# Epoch 877/1000
# 3/3 [==============================] - 0s 38ms/step - loss: 0.0057 - mse: 0.0057 - binary_crossentropy: 0.0394 - accuracy: 0.9943 - val_loss: 0.2161 - val_mse: 0.2161 - val_binary_crossentropy: 1.1826 - val_accuracy: 0.7742
# Epoch 878/1000
# 3/3 [==============================] - 0s 48ms/step - loss: 0.0057 - mse: 0.0057 - binary_crossentropy: 0.0393 - accuracy: 0.9943 - val_loss: 0.2159 - val_mse: 0.2159 - val_binary_crossentropy: 1.1811 - val_accuracy: 0.7742
# Epoch 879/1000
# 3/3 [==============================] - 0s 47ms/step - loss: 0.0057 - mse: 0.0057 - binary_crossentropy: 0.0397 - accuracy: 0.9943 - val_loss: 0.2165 - val_mse: 0.2165 - val_binary_crossentropy: 1.1858 - val_accuracy: 0.7742
# Epoch 880/1000
# 3/3 [==============================] - 0s 102ms/step - loss: 0.0057 - mse: 0.0057 - binary_crossentropy: 0.0393 - accuracy: 0.9943 - val_loss: 0.2170 - val_mse: 0.2170 - val_binary_crossentropy: 1.1907 - val_accuracy: 0.7742
# Epoch 881/1000
# 3/3 [==============================] - 0s 46ms/step - loss: 0.0057 - mse: 0.0057 - binary_crossentropy: 0.0388 - accuracy: 0.9943 - val_loss: 0.2175 - val_mse: 0.2175 - val_binary_crossentropy: 1.1946 - val_accuracy: 0.7742
# Epoch 882/1000
# 3/3 [==============================] - 0s 38ms/step - loss: 0.0057 - mse: 0.0057 - binary_crossentropy: 0.0390 - accuracy: 0.9943 - val_loss: 0.2177 - val_mse: 0.2177 - val_binary_crossentropy: 1.1964 - val_accuracy: 0.7742
# Epoch 883/1000
# 3/3 [==============================] - 0s 46ms/step - loss: 0.0057 - mse: 0.0057 - binary_crossentropy: 0.0392 - accuracy: 0.9943 - val_loss: 0.2179 - val_mse: 0.2179 - val_binary_crossentropy: 1.1975 - val_accuracy: 0.7742
# Epoch 884/1000
# 3/3 [==============================] - 0s 91ms/step - loss: 0.0057 - mse: 0.0057 - binary_crossentropy: 0.0393 - accuracy: 0.9943 - val_loss: 0.2179 - val_mse: 0.2179 - val_binary_crossentropy: 1.1978 - val_accuracy: 0.7742
# Epoch 885/1000
# 3/3 [==============================] - 0s 59ms/step - loss: 0.0057 - mse: 0.0057 - binary_crossentropy: 0.0392 - accuracy: 0.9943 - val_loss: 0.2180 - val_mse: 0.2180 - val_binary_crossentropy: 1.1980 - val_accuracy: 0.7742
# Epoch 886/1000
# 3/3 [==============================] - 0s 44ms/step - loss: 0.0057 - mse: 0.0057 - binary_crossentropy: 0.0395 - accuracy: 0.9943 - val_loss: 0.2180 - val_mse: 0.2180 - val_binary_crossentropy: 1.1979 - val_accuracy: 0.7742
# Epoch 887/1000
# 3/3 [==============================] - 0s 44ms/step - loss: 0.0057 - mse: 0.0057 - binary_crossentropy: 0.0393 - accuracy: 0.9943 - val_loss: 0.2181 - val_mse: 0.2181 - val_binary_crossentropy: 1.1993 - val_accuracy: 0.7742
# Epoch 888/1000
# 3/3 [==============================] - 0s 86ms/step - loss: 0.0057 - mse: 0.0057 - binary_crossentropy: 0.0394 - accuracy: 0.9943 - val_loss: 0.2183 - val_mse: 0.2183 - val_binary_crossentropy: 1.2008 - val_accuracy: 0.7742
# Epoch 889/1000
# 3/3 [==============================] - 0s 49ms/step - loss: 0.0057 - mse: 0.0057 - binary_crossentropy: 0.0393 - accuracy: 0.9943 - val_loss: 0.2182 - val_mse: 0.2182 - val_binary_crossentropy: 1.1997 - val_accuracy: 0.7742
# Epoch 890/1000
# 3/3 [==============================] - 0s 46ms/step - loss: 0.0057 - mse: 0.0057 - binary_crossentropy: 0.0394 - accuracy: 0.9943 - val_loss: 0.2180 - val_mse: 0.2180 - val_binary_crossentropy: 1.1984 - val_accuracy: 0.7742
# Epoch 891/1000
# 3/3 [==============================] - 0s 46ms/step - loss: 0.0057 - mse: 0.0057 - binary_crossentropy: 0.0395 - accuracy: 0.9943 - val_loss: 0.2178 - val_mse: 0.2178 - val_binary_crossentropy: 1.1965 - val_accuracy: 0.7742
# Epoch 892/1000
# 3/3 [==============================] - 0s 40ms/step - loss: 0.0057 - mse: 0.0057 - binary_crossentropy: 0.0393 - accuracy: 0.9943 - val_loss: 0.2175 - val_mse: 0.2175 - val_binary_crossentropy: 1.1944 - val_accuracy: 0.7742
# Epoch 893/1000
# 3/3 [==============================] - 0s 65ms/step - loss: 0.0057 - mse: 0.0057 - binary_crossentropy: 0.0394 - accuracy: 0.9943 - val_loss: 0.2174 - val_mse: 0.2174 - val_binary_crossentropy: 1.1928 - val_accuracy: 0.7742
# Epoch 894/1000
# 3/3 [==============================] - 0s 45ms/step - loss: 0.0057 - mse: 0.0057 - binary_crossentropy: 0.0395 - accuracy: 0.9943 - val_loss: 0.2172 - val_mse: 0.2172 - val_binary_crossentropy: 1.1918 - val_accuracy: 0.7742
# Epoch 895/1000
# 3/3 [==============================] - 0s 47ms/step - loss: 0.0057 - mse: 0.0057 - binary_crossentropy: 0.0391 - accuracy: 0.9943 - val_loss: 0.2170 - val_mse: 0.2170 - val_binary_crossentropy: 1.1909 - val_accuracy: 0.7742
# Epoch 896/1000
# 3/3 [==============================] - 0s 47ms/step - loss: 0.0057 - mse: 0.0057 - binary_crossentropy: 0.0396 - accuracy: 0.9943 - val_loss: 0.2167 - val_mse: 0.2167 - val_binary_crossentropy: 1.1901 - val_accuracy: 0.7742
# Epoch 897/1000
# 3/3 [==============================] - 0s 69ms/step - loss: 0.0057 - mse: 0.0057 - binary_crossentropy: 0.0391 - accuracy: 0.9943 - val_loss: 0.2166 - val_mse: 0.2166 - val_binary_crossentropy: 1.1903 - val_accuracy: 0.7742
# Epoch 898/1000
# 3/3 [==============================] - 0s 47ms/step - loss: 0.0057 - mse: 0.0057 - binary_crossentropy: 0.0392 - accuracy: 0.9943 - val_loss: 0.2165 - val_mse: 0.2165 - val_binary_crossentropy: 1.1903 - val_accuracy: 0.7742
# Epoch 899/1000
# 3/3 [==============================] - 0s 45ms/step - loss: 0.0057 - mse: 0.0057 - binary_crossentropy: 0.0392 - accuracy: 0.9943 - val_loss: 0.2165 - val_mse: 0.2165 - val_binary_crossentropy: 1.1914 - val_accuracy: 0.7742
# Epoch 900/1000
# 3/3 [==============================] - 0s 48ms/step - loss: 0.0057 - mse: 0.0057 - binary_crossentropy: 0.0390 - accuracy: 0.9943 - val_loss: 0.2166 - val_mse: 0.2166 - val_binary_crossentropy: 1.1920 - val_accuracy: 0.7742
# Epoch 901/1000
# 3/3 [==============================] - 0s 65ms/step - loss: 0.0057 - mse: 0.0057 - binary_crossentropy: 0.0392 - accuracy: 0.9943 - val_loss: 0.2165 - val_mse: 0.2165 - val_binary_crossentropy: 1.1920 - val_accuracy: 0.7742
# Epoch 902/1000
# 3/3 [==============================] - 0s 50ms/step - loss: 0.0057 - mse: 0.0057 - binary_crossentropy: 0.0393 - accuracy: 0.9943 - val_loss: 0.2163 - val_mse: 0.2163 - val_binary_crossentropy: 1.1894 - val_accuracy: 0.7742
# Epoch 903/1000
# 3/3 [==============================] - 0s 44ms/step - loss: 0.0057 - mse: 0.0057 - binary_crossentropy: 0.0391 - accuracy: 0.9943 - val_loss: 0.2160 - val_mse: 0.2160 - val_binary_crossentropy: 1.1870 - val_accuracy: 0.7742
# Epoch 904/1000
# 3/3 [==============================] - 0s 47ms/step - loss: 0.0057 - mse: 0.0057 - binary_crossentropy: 0.0390 - accuracy: 0.9943 - val_loss: 0.2158 - val_mse: 0.2158 - val_binary_crossentropy: 1.1855 - val_accuracy: 0.7742
# The difference in seconds is: 117.4765112400055

# %%
# # Extract the metrics from the history object
loss = history.history['loss']
val_loss = history.history['val_loss']
r_square = history.history['accuracy']
val_r_square = history.history['val_accuracy']

# Plot loss and val_loss
plt.figure(figsize=(12, 6))
plt.plot(loss, label='Training Loss', color='blue')
plt.plot(val_loss, label='Validation Loss', color='orange')
plt.title('Training Loss vs Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.grid()
plt.show()

# Plot r_square and val_r_square
plt.figure(figsize=(12, 6))
plt.plot(r_square, label='Training Accuracy', color='green')
plt.plot(val_r_square, label='Validation Accuracy', color='red')
plt.title('Training Accuracy vs Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.grid()
plt.show()

# %%
# Find the minimum loss for training and validation
min_training_loss = min(loss)
min_validation_loss = min(val_loss)

# Print the results
print(f"Minimum Training Loss: {min_training_loss}")
print(f"Minimum Validation Loss: {min_validation_loss}")
# Out:
# Minimum Training Loss: 0.005702604074031115
# Minimum Validation Loss: 0.15391063690185547

# %%
# # Find the maximum R² values for training and validation
# max_r_square_train = max(r_square)
# max_r_square_val = max(val_r_square)

# # Print the results
# print(f"Maximum Training R²: {max_r_square_train}")
# print(f"Maximum Validation R²: {max_r_square_val}")

# %%
# model = best_model

# %%
# Generate predictions for the training set
Y_train_pred = model.predict(X_train)

# Plot the true values and predictions
plt.figure(figsize=(10, 6))
plt.plot(Y_train, label='True Values', color='blue',  marker='o')
plt.plot(Y_train_pred, label='Predictions', color='red', linestyle='dashed', marker='o')
plt.title('Training True Values vs Predictions')
plt.xlabel('Sample Index')
plt.ylabel('Value')
plt.legend()
plt.show()
# Out:
# 6/6 [==============================] - 0s 6ms/step

# %%
# Generate predictions for the validation set
Y_val_pred = model.predict(X_val)

# Plot the true values and predictions
plt.figure(figsize=(10, 6))
plt.plot(Y_val, label='True Values', color='blue', marker='o')
plt.plot(Y_val_pred, label='Predictions', color='red', linestyle='dashed', marker='o')
plt.title('Validation True Values vs Predictions')
plt.xlabel('Sample Index')
plt.ylabel('Value')
plt.legend()
plt.show()
# Out:
# 1/1 [==============================] - 0s 36ms/step

# %%
# Generate predictions for the validation set
Y_val_pred = model.predict(X_val)
Y_val_pred = np.where(Y_val_pred > 0.5, 1,np.where(Y_val_pred<-0.5, -1, 0) )

# Plot the true values and predictions
plt.figure(figsize=(10, 6))
plt.plot(Y_val, label='True Values', color='blue', marker='o')
plt.plot(Y_val_pred, label='Predictions', color='red', linestyle='dashed', marker='o')
plt.title('Validation True Values vs Predictions')
plt.xlabel('Sample Index')
plt.ylabel('Value')
plt.legend()
plt.show()
# Out:
# 1/1 [==============================] - 0s 26ms/step

# %%
from sklearn.metrics import confusion_matrix

# Create confusion matrix
conf_matrix = confusion_matrix(Y_val.flatten(), Y_val_pred.flatten())

# Print the confusion matrix
print("Confusion Matrix:")
print(conf_matrix)
# Out:
# Confusion Matrix:
# [[ 4  3]
#  [ 2 22]]

# %%
# import matplotlib.pyplot as plt
# import numpy as np

# # Generate predictions for the validation set
# Y_val_pred = model.predict(X_val)
# Y_val_pred = np.where(Y_val_pred > 0.5, 1, np.where(Y_val_pred < -0.5, -1, 0))

# # Plot
# plt.figure(figsize=(12, 6))

# # Add soft gray vertical lines for each sample
# for i in range(len(Y_val)):
#     plt.axvline(x=i, color='gray', linestyle='-', linewidth=0.5, alpha=0.3)

# # Plot true values and predictions as scatter
# plt.scatter(range(len(Y_val)), Y_val, label='True Values', color='blue', marker='o')
# plt.scatter(range(len(Y_val_pred)), Y_val_pred, label='Predictions', color='red', marker='o')

# # Styling
# plt.title('Validation True Values vs Predictions')
# plt.xlabel('Sample Index')
# plt.ylabel('Value')
# plt.legend()
# plt.grid(False)  # Remove default grid
# plt.tight_layout()
# plt.show()

# %%
# Calculate total accuracy
total_accuracy = np.sum(Y_val.flatten() == Y_val_pred.flatten()) / len(Y_val)
print(f"Total Accuracy: {total_accuracy * 100:.2f}%")
# Out:
# Total Accuracy: 83.87%

# %%
# # Generate predictions for the validation set
# Y_val_pred = model.predict(X_test_filtered)
# Y_val_pred = np.where(Y_val_pred > 0.42, 1, -1)

# # Plot the true values and predictions
# plt.figure(figsize=(10, 6))
# plt.plot(Y_test_filtered, label='True Values', color='blue', marker='o')
# plt.plot(Y_val_pred, label='Predictions', color='red', linestyle='dashed', marker='o')
# plt.title('Validation True Values vs Predictions')
# plt.xlabel('Sample Index')
# plt.ylabel('Value')
# plt.legend()
# plt.show()

# %%
# import matplotlib.pyplot as plt
# import numpy as np

# # Generate predictions for the validation set
# Y_val_pred = model.predict(X_test_filtered)
# Y_val_pred = np.where(Y_val_pred > 0.2, 1, -1)

# # Plot the true values and predictions
# plt.figure(figsize=(12, 6))

# # Add soft gray vertical lines for each sample index
# for i in range(len(Y_test_filtered)):
#     plt.axvline(x=i, color='gray', linestyle='-', linewidth=0.5, alpha=0.7)

# # Plot using scatter (no connecting lines)
# plt.scatter(range(len(Y_test_filtered)), Y_test_filtered, label='True Values', color='blue', marker='o')
# plt.scatter(range(len(Y_val_pred)), Y_val_pred, label='Predictions', color='red', marker='o')

# # Labels and title
# plt.title('Validation True Values vs Predictions')
# plt.xlabel('Sample Index')
# plt.ylabel('Value')
# plt.legend()
# plt.grid(False)
# plt.tight_layout()
# plt.show()

# %%
# import matplotlib.pyplot as plt
# import numpy as np

# # Generate predictions for the validation set
# Y_val_pred = model.predict(X_test_filtered)
# Y_val_pred = np.where(Y_val_pred > 0.42, 1, -1)

# # Flatten if needed
# Y_val_pred = Y_val_pred.flatten()
# Y_test_filtered = Y_test_filtered.flatten()

# # Prepare index and classification of correctness
# indices = np.arange(len(Y_test_filtered))
# correct = Y_val_pred == Y_test_filtered
# incorrect = ~correct

# # Plot the figure
# plt.figure(figsize=(12, 6))

# # Add vertical gray lines
# for i in range(len(Y_test_filtered)):
#     plt.axvline(x=i, color='gray', linestyle='-', linewidth=0.7, alpha=0.7)

# # Plot true values as reference shadow
# # plt.scatter(indices, Y_test_filtered, color='blue', label='True Value (Reference)', marker='o', alpha=0.3)

# # Plot correct predictions (overlapping with true values)
# plt.scatter(indices[correct], Y_val_pred[correct], color='blue', marker='o', label='Correct Prediction')

# # Plot incorrect predictions
# plt.scatter(indices[incorrect], Y_val_pred[incorrect], color='red', marker='o', label='Incorrect Prediction')

# # Labels and title
# plt.title('Testing True Values vs Predictions')
# plt.xlabel('Sample Index')
# plt.ylabel('Value')
# plt.legend()
# plt.grid(False)
# plt.tight_layout()
# plt.show()

# %%
# from sklearn.metrics import confusion_matrix

# # Create confusion matrix
# conf_matrix = confusion_matrix(Y_test_filtered.flatten(), Y_val_pred.flatten())

# # Print the confusion matrix
# print("Confusion Matrix:")
# print(conf_matrix)

# %%
# # Calculate total accuracy
# total_accuracy = np.sum(Y_test_filtered.flatten() == Y_val_pred.flatten()) / len(Y_test_filtered)
# print(f"Total Accuracy: {total_accuracy * 100:.2f}%")
