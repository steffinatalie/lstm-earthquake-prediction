# %%
import numpy as np
import matplotlib.pyplot as plt
import math
from collections import Counter
import pandas as pd

# %%
bali = pd.read_csv('bali_min4.csv')
jabar = pd.read_csv('jawabarat_min4.csv')
# df = pd.concat([bali, jabar], axis=0)
jatengjatim = pd.read_csv('jatengjatim_min4.csv')
# df = pd.concat([bali, jatengjatim], axis=0)
# df = pd.concat([jabar, jatengjatim], axis=0)
df = pd.concat([bali, jabar, jatengjatim], axis=0)
# df = pd.read_csv('southern_california_min25.csv')
df['timestamp'] = pd.to_datetime(df['time'], errors='coerce', utc=False)
df['Datetime'] = df['timestamp']
df.set_index('timestamp', inplace=True)
df = df.sort_index(ascending=True)
df
# Out:
#                                                       time  latitude  \
# timestamp
# 1995-01-01 02:02:25.490000+00:00  1995-01-01T02:02:25.490Z  -10.9270
# 1995-01-07 15:02:59.810000+00:00  1995-01-07T15:02:59.810Z   -9.0250
# 1995-01-07 18:37:28.920000+00:00  1995-01-07T18:37:28.920Z   -9.2310
# 1995-01-19 09:19:57.180000+00:00  1995-01-19T09:19:57.180Z  -10.7640
# 1995-02-16 16:27:25.400000+00:00  1995-02-16T16:27:25.400Z  -10.0560
# ...                                                    ...       ...
# 2020-12-20 15:16:45.796000+00:00  2020-12-20T15:16:45.796Z   -9.2506
# 2020-12-20 15:53:57.395000+00:00  2020-12-20T15:53:57.395Z   -9.2936
# 2020-12-22 03:27:21.031000+00:00  2020-12-22T03:27:21.031Z   -9.5505
# 2020-12-24 22:09:10.232000+00:00  2020-12-24T22:09:10.232Z   -9.0282
# 2020-12-26 18:23:21.550000+00:00  2020-12-26T18:23:21.550Z   -9.0928
#
#                                   longitude   depth  mag magType  nst    gap  \
# timestamp
# 1995-01-01 02:02:25.490000+00:00   113.0110   18.90  4.5      mb  NaN    NaN
# 1995-01-07 15:02:59.810000+00:00   110.7550  114.80  4.7      mb  NaN    NaN
# 1995-01-07 18:37:28.920000+00:00   117.1110   33.00  4.2      mb  NaN    NaN
# 1995-01-19 09:19:57.180000+00:00   117.1200   33.00  4.9      mb  NaN    NaN
# 1995-02-16 16:27:25.400000+00:00   113.8580   33.00  4.0      mb  NaN    NaN
# ...                                     ...     ...  ...     ...  ...    ...
# 2020-12-20 15:16:45.796000+00:00   110.8510   35.00  4.2      mb  NaN  148.0
# 2020-12-20 15:53:57.395000+00:00   112.1503   35.00  4.3      mb  NaN   53.0
# 2020-12-22 03:27:21.031000+00:00   112.5698   35.00  4.1      mb  NaN  120.0
# 2020-12-24 22:09:10.232000+00:00   117.3729  104.10  4.4      mb  NaN   95.0
# 2020-12-26 18:23:21.550000+00:00   117.1835   63.84  4.1      mb  NaN   71.0
#
#                                    dmin   rms  ...  \
# timestamp                                      ...
# 1995-01-01 02:02:25.490000+00:00    NaN  1.20  ...
# 1995-01-07 15:02:59.810000+00:00    NaN  0.80  ...
# 1995-01-07 18:37:28.920000+00:00    NaN  0.90  ...
# 1995-01-19 09:19:57.180000+00:00    NaN  1.30  ...
# 1995-02-16 16:27:25.400000+00:00    NaN  0.40  ...
# ...                                 ...   ...  ...
# 2020-12-20 15:16:45.796000+00:00  1.368  0.58  ...
# 2020-12-20 15:53:57.395000+00:00  2.114  0.90  ...
# 2020-12-22 03:27:21.031000+00:00  1.896  0.94  ...
# 2020-12-24 22:09:10.232000+00:00  3.231  0.54  ...
# 2020-12-26 18:23:21.550000+00:00  3.059  0.62  ...
#
#                                                                   place  \
# timestamp
# 1995-01-01 02:02:25.490000+00:
# 2020-12-20 15:53:57.395000+00:00         us 2020-12-20 15:53:57.395000+00:00
# 2020-12-22 03:27:21.031000+00:00         us 2020-12-22 03:27:21.031000+00:00
# 2020-12-24 22:09:10.232000+00:00         us 2020-12-24 22:09:10.232000+00:00
# 2020-12-26 18:23:21.550000+00:00         us 2020-12-26 18:23:21.550000+00:00
#
# [1698 rows x 23 columns]

# %%
df = df[['depth', 'mag']]
df
# Out:
#                                    depth  mag
# timestamp
# 1995-01-01 02:02:25.490000+00:00   18.90  4.5
# 1995-01-07 15:02:59.810000+00:00  114.80  4.7
# 1995-01-07 18:37:28.920000+00:00   33.00  4.2
# 1995-01-19 09:19:57.180000+00:00   33.00  4.9
# 1995-02-16 16:27:25.400000+00:00   33.00  4.0
# ...                                  ...  ...
# 2020-12-20 15:16:45.796000+00:00   35.00  4.2
# 2020-12-20 15:53:57.395000+00:00   35.00  4.3
# 2020-12-22 03:27:21.031000+00:00   35.00  4.1
# 2020-12-24 22:09:10.232000+00:00  104.10  4.4
# 2020-12-26 18:23:21.550000+00:00   63.84  4.1
#
# [1698 rows x 2 columns]

# %%
print(df.isna().sum())
# Out:
# depth    0
# mag      0
# dtype: int64

# %%
mag_unique, frequency = np.unique(df['mag'], return_counts=True)

plt.figure(figsize=(10,8))
plt.hist(df['mag'], bins=1000, color='black', edgecolor='black')

bins = [0, 20, 40, 60]

from matplotlib.ticker import MultipleLocator
# Set x-axis scale to increment by 0.5
plt.gca().xaxis.set_major_locator(MultipleLocator(0.2))
# Add titles and labels
plt.title('Frequency by Magnitude')
plt.xlabel('Magnitude')
plt.ylabel('Frequency')
plt.xticks(fontsize=12, fontname='Times New Roman', rotation=45)

# Show the plot
plt.show()

# %%
mag_filter = 4.5
depth_filter = 100
resample_rate = '2W'

# %%
# def occurence_criterion(raw_array):
#     print(raw_array)
#     print("---------------------")
#     target = -1
#     if len(raw_array) > 0:
#         if raw_array['earthquake'].eq(1).any():
#             target = 1
#         if raw_array['earthquake'].eq(0).any():
#             target = 0
#     if len(raw_array) == 0:
#         target = 0

        
#     return target

# earthquake_occurence = df.resample(resample_rate).apply(occurence_criterion)

# earthquake_occurence = earthquake_occurence.to_frame(name='earthquake')

# earthquake_occurence = earthquake_occurence.sort_index(ascending=True)
# earthquake_occurence['earthquake'].value_counts()

# %%
# Initialize the 'ED' column with NaN values
df['ED'] = np.nan

# Filter the dataframe for earthquakes with magnitude greater than mag_filter
filtered_df = df[df['mag'] > mag_filter]

n = 50

# Calculate the elapsed days for the last n earthquake events
for i in range(n, len(filtered_df)):
    current_time = filtered_df.index[i]
    past_time = filtered_df.index[i-n]
    elapsed_days = (current_time - past_time).days
    df.loc[current_time, 'ED'] = elapsed_days

# Fill NaN values in 'ED' column
for i in range(len(df)):
    if pd.isna(df.iloc[i]['ED']):
        # Find the latest valid 'ED' value before the current index
        last_valid_index = df.iloc[:i]['ED'].last_valid_index()
        if last_valid_index is not None:
            time_since_last_valid = (df.index[i] - last_valid_index).days
            df.at[df.index[i], 'ED'] = df.at[last_valid_index, 'ED'] + time_since_last_valid

# df = df.dropna(subset=['ED'])
df
# Out:
# C:\Users\SteinSteffi1\AppData\Local\Temp\ipykernel_4552\388928700.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['ED'] = np.nan
#                                    depth  mag     ED
# timestamp
# 1995-01-01 02:02:25.490000+00:00   18.90  4.5    NaN
# 1995-01-07 15:02:59.810000+00:00  114.80  4.7    NaN
# 1995-01-07 18:37:28.920000+00:00   33.00  4.2    NaN
# 1995-01-19 09:19:57.180000+00:00   33.00  4.9    NaN
# 1995-02-16 16:27:25.400000+00:00   33.00  4.0    NaN
# ...                                  ...  ...    ...
# 2020-12-20 15:16:45.796000+00:00   35.00  4.2  875.0
# 2020-12-20 15:53:57.395000+00:00   35.00  4.3  875.0
# 2020-12-22 03:27:21.031000+00:00   35.00  4.1  876.0
# 2020-12-24 22:09:10.232000+00:00  104.10  4.4  878.0
# 2020-12-26 18:23:21.550000+00:00   63.84  4.1  879.0
#
# [1698 rows x 3 columns]

# %%
# Initialize the 'energy_squared' and 'cumulative_energy_squared' columns with NaN values
df['energy_squared_root'] = np.nan
df['cumulative_energy_squared'] = np.nan

df['energy'] = 10**(11.8+1.5*df['mag'])

# Calculate the energy squared for each data point
df['energy_squared_root'] = np.sqrt(df['energy'])

# Calculate the cumulative sum of energy squared for the last 50 data points
# for i in range(n, len(df)):
#     df.iloc[i, df.columns.get_loc('cumulative_energy_squared')] = df.iloc[i-n:i]['energy_squared_root'].sum()

df['cumulative_energy_squared'] = df['energy_squared_root'].rolling(n).sum()

# Calculate the RSRER
df['RSRER'] = df['cumulative_energy_squared'] / df['ED']

df['mean_mag'] = df['mag'].rolling(n).mean()
df['min_mag'] = df['mag'].rolling(n).min()
df['b_value'] = np.log10(np.e)/(df['mean_mag'] - df['min_mag'])

df['event_counts'] = df['mag'].rolling(n).apply(lambda x: (x > mag_filter).sum(), raw=True)
df['a_value'] = (np.log10(df['event_counts']) + df['b_value']*df['min_mag'])/n
# df['MSD'] = np.sum((np.log10(df['event_counts'])-(df['a_value']-(df['b_value']*df['mag'])))**2)/(n-1)
df['max_mag'] = df['mag'].rolling(n).max()
df['MD'] = df['a_value']/df['b_value'] - df['max_mag']
# print(df['event_counts'])

df
# Out:
# C:\Users\SteinSteffi1\AppData\Local\Temp\ipykernel_4552\2738765218.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['energy_squared_root'] = np.nan
# C:\Users\SteinSteffi1\AppData\Local\Temp\ipykernel_4552\2738765218.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['cumulative_energy_squared'] = np.nan
# C:\Users\SteinSteffi1\AppData\Local\Temp\ipykernel_4552\2738765218.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['energy'] = 10**(11.8+1.5*df['mag'])
# C:\Users\SteinSteffi1\AppData\Local\Temp\ipykernel_4552\2738765218.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['energy_squared_root'] = np.sqrt(df['energy'])
# C:\Users\SteinSteffi1\AppData\Local\Temp\ipykernel_4552\2738765218.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['cumulative_energy_squared'] = df['energy_squared_root'].rolling(n).sum()
# C:\Users\SteinSteffi1\AppData\Local\Temp\ipykernel_4552\2738765218.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['RSRER'] = df['cumulative_energy_squared'] / df['ED']
# C:\Users\SteinSteffi1\AppData\Local\Temp\ipykernel_4552\2738765218.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['mean_mag'] = df['mag'].rolling(n).mean()
# C:\Users\SteinSteffi1\AppData\Local\Temp\ipykernel_4552\2738765218.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['min_mag'] = df['mag'].rolling(n).min()
# C:\Users\SteinSteffi1\AppData\Local\Temp\ipykernel_4552\2738765218.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['b_value'] = np.log10(np.e)/(df['mean_mag'] - df['min_mag'])
# C:\Users\SteinSteffi1\AppData\Local\Temp\ipykernel_4552\2738765218.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['event_counts'] = df['mag'].rolling(n).apply(lambda x: (x > mag_filter).sum(), raw=True)
# C:\Users\SteinSteffi1\AppData\Local\Temp\ipykernel_4552\2738765218.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['a_value'] = (np.log10(df['event_counts']) + df['b_value']*df['min_mag'])/n
# C:\Users\SteinSteffi1\AppData\Local\Temp\ipykernel_4552\2738765218.py:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['max_mag'] = df['mag'].rolling(n).max()
# C:\Users\SteinSteffi1\AppData\Local\Temp\ipykernel_4552\2738765218.py:27: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['
# 2020-12-20 15:53:57.395000+00:00          13.0  0.103078      5.2 -5.097941
# 2020-12-22 03:27:21.031000+00:00          13.0  0.104610      5.2 -5.098352
# 2020-12-24 22:09:10.232000+00:00          13.0  0.104610      5.2 -5.098352
# 2020-12-26 18:23:21.550000+00:00          13.0  0.105397      5.2 -5.098557
#
# [1698 rows x 14 columns]

# %%
# Drop the intermediate columns
df.drop(columns=['energy_squared_root', 'cumulative_energy_squared', 'mean_mag', 'min_mag', 'event_counts', 'a_value', 'max_mag'], inplace=True)
# Out:
# C:\Users\SteinSteffi1\AppData\Local\Temp\ipykernel_4552\1093842324.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.drop(columns=['energy_squared_root', 'cumulative_energy_squared', 'mean_mag', 'min_mag', 'event_counts', 'a_value', 'max_mag'], inplace=True)

# %%
df.dropna(subset=['RSRER'], inplace=True)
df.isna().sum()
# Out:
# C:\Users\SteinSteffi1\AppData\Local\Temp\ipykernel_4552\2534608267.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.dropna(subset=['RSRER'], inplace=True)
# depth      0
# mag        0
# ED         0
# energy     0
# RSRER      0
# b_value    0
# MD         0
# dtype: int64

# %%
df['earthquake'] = np.where((df['mag'] > mag_filter) & (df['depth'] < depth_filter), 1,  0) 

df['earthquake'].value_counts()
# Out:
# C:\Users\SteinSteffi1\AppData\Local\Temp\ipykernel_4552\3861059285.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['earthquake'] = np.where((df['mag'] > mag_filter) & (df['depth'] < depth_filter), 1,  0)
# earthquake
# 0    848
# 1    673
# Name: count, dtype: int64

# %%
def occurence_criterion(raw_array):
    # print(raw_array)
    # print("---------------------")
    target = 0
    if len(raw_array) > 0:
        if raw_array['earthquake'].eq(1).any():
            target = 1
        if raw_array['earthquake'].eq(0).all():
            target = 0
    # if len(raw_array) == 0:
    #     target = 0

        
    return target


earthquake_occurence = df[['earthquake']].resample(resample_rate).apply(occurence_criterion)
print(earthquake_occurence.value_counts())
monthly_df = df.resample(resample_rate).mean()
# monthly_df = monthly_df.fillna(0)
monthly_df = monthly_df.dropna()
monthly_df['earthquake'] = earthquake_occurence
print(monthly_df)
# Out:
# 0    277
# 1    260
# Name: count, dtype: int64
#                                depth       mag           ED        energy  \
# timestamp
# 2000-06-18 00:00:00+00:00  42.400000  4.466667  1976.333333  3.760890e+18
# 2000-07-16 00:00:00+00:00  33.000000  4.000000  1997.000000  6.309573e+17
# 2000-07-30 00:00:00+00:00  75.000000  4.450000  1869.000000  3.395076e+18
# 2000-08-27 00:00:00+00:00  69.166667  4.733333  1802.666667  8.052972e+18
# 2000-10-08 00:00:00+00:00  33.000000  4.366667  1724.666667  4.136412e+18
# ...                              ...       ...          ...           ...
# 2020-10-25 00:00:00+00:00  43.895000  4.525000   815.750000  4.642977e+18
# 2020-11-08 00:00:00+00:00  38.795000  4.250000   824.000000  2.089546e+18
# 2020-12-06 00:00:00+00:00  63.400000  4.200000   857.000000  1.334765e+18
# 2020-12-20 00:00:00+00:00  33.133333  4.350000   872.166667  2.722388e+18
# 2021-01-03 00:00:00+00:00  67.646667  4.200000   877.666667  1.431463e+18
#
#                                   RSRER   b_value        MD  earthquake
# timestamp
# 2000-06-18 00:00:00+00:00  6.731465e+07  0.787837 -5.686084           1
# 2000-07-16 00:00:00+00:00  6.669723e+07  0.786765 -5.685875           0
# 2000-07-30 00:00:00+00:00  6.572704e+07  0.816343 -5.687111           1
# 2000-08-27 00:00:00+00:00  6.976356e+07  0.789647 -5.685196           1
# 2000-10-08 00:00:00+00:00  7.258950e+07  0.791045 -5.685081           1
# ...                                 ...       ...       ...         ...
# 2020-10-25 00:00:00+00:00  1.246791e+08  0.929113 -5.093240           1
# 2020-11-08 00:00:00+00:00  1.239858e+08  0.922173 -5.093311           0
# 2020-12-06 00:00:00+00:00  1.171056e+08  0.933971 -5.094215           0
# 2020-12-20 00:00:00+00:00  1.104060e+08  0.976734 -5.096413           1
# 2021-01-03 00:00:00+00:00  1.053497e+08  1.032417 -5.098420           0
#
# [432 rows x 8 columns]

# %%
df = monthly_df[['depth', 'mag', 'ED', 'RSRER', 'b_value', 'MD', 'earthquake']]
# df = monthly_df[['mag', 'ED','MD', 'earthquake']]
df
# Out:
#                                depth       mag           ED         RSRER  \
# timestamp
# 2000-06-18 00:00:00+00:00  42.400000  4.466667  1976.333333  6.731465e+07
# 2000-07-16 00:00:00+00:00  33.000000  4.000000  1997.000000  6.669723e+07
# 2000-07-30 00:00:00+00:00  75.000000  4.450000  1869.000000  6.572704e+07
# 2000-08-27 00:00:00+00:00  69.166667  4.733333  1802.666667  6.976356e+07
# 2000-10-08 00:00:00+00:00  33.000000  4.366667  1724.666667  7.258950e+07
# ...                              ...       ...          ...           ...
# 2020-10-25 00:00:00+00:00  43.895000  4.525000   815.750000  1.246791e+08
# 2020-11-08 00:00:00+00:00  38.795000  4.250000   824.000000  1.239858e+08
# 2020-12-06 00:00:00+00:00  63.400000  4.200000   857.000000  1.171056e+08
# 2020-12-20 00:00:00+00:00  33.133333  4.350000   872.166667  1.104060e+08
# 2021-01-03 00:00:00+00:00  67.646667  4.200000   877.666667  1.053497e+08
#
#                             b_value        MD  earthquake
# timestamp
# 2000-06-18 00:00:00+00:00  0.787837 -5.686084           1
# 2000-07-16 00:00:00+00:00  0.786765 -5.685875           0
# 2000-07-30 00:00:00+00:00  0.816343 -5.687111           1
# 2000-08-27 00:00:00+00:00  0.789647 -5.685196           1
# 2000-10-08 00:00:00+00:00  0.791045 -5.685081           1
# ...                             ...       ...         ...
# 2020-10-25 00:00:00+00:00  0.929113 -5.093240           1
# 2020-11-08 00:00:00+00:00  0.922173 -5.093311           0
# 2020-12-06 00:00:00+00:00  0.933971 -5.094215           0
# 2020-12-20 00:00:00+00:00  0.976734 -5.096413           1
# 2021-01-03 00:00:00+00:00  1.032417 -5.098420           0
#
# [432 rows x 7 columns]

# %%
correlation_matrix = df.corr()
correlation_matrix
# Out:
#                depth       mag        ED     RSRER   b_value        MD  \
# depth       1.000000 -0.173283  0.129770 -0.149255  0.196980  0.024364
# mag        -0.173283  1.000000  0.052014  0.054431 -0.225276 -0.189082
# ED          0.129770  0.052014  1.000000 -0.255509 -0.140959 -0.123904
# RSRER      -0.149255  0.054431 -0.255509  1.000000 -0.105147  0.038042
# b_value     0.196980 -0.225276 -0.140959 -0.105147  1.000000  0.576970
# MD          0.024364 -0.189082 -0.123904  0.038042  0.576970  1.000000
# earthquake -0.188992  0.671843  0.021710  0.064389 -0.160870 -0.106870
#
#             earthquake
# depth        -0.188992
# mag           0.671843
# ED            0.021710
# RSRER         0.064389
# b_value      -0.160870
# MD           -0.106870
# earthquake    1.000000

# %%
# Replace infinite values with a large number
df.replace([np.inf, -np.inf], 1e10, inplace=True)
# Out:
# C:\Users\SteinSteffi1\AppData\Local\Temp\ipykernel_4552\2297783001.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.replace([np.inf, -np.inf], 1e10, inplace=True)

# %%
from sklearn.preprocessing import MinMaxScaler

# Initialize the MinMaxScaler with the desired feature range
scaler = MinMaxScaler(feature_range=(-1, 1))

# Apply the scaler to the first 6 columns of the dataframe
df.iloc[:, :6] = scaler.fit_transform(df.iloc[:, :6])

# Display the dataframe
df
# Out:
#                               depth       mag        ED     RSRER   b_value  \
# timestamp
# 2000-06-18 00:00:00+00:00 -0.505948 -0.575758  0.979235 -0.999670 -0.625948
# 2000-07-16 00:00:00+00:00 -0.637509 -1.000000  1.000000 -0.999719 -0.628450
# 2000-07-30 00:00:00+00:00 -0.049685 -0.590909  0.871393 -0.999795 -0.559409
# 2000-08-27 00:00:00+00:00 -0.131327 -0.333333  0.804744 -0.999479 -0.621723
# 2000-10-08 00:00:00+00:00 -0.637509 -0.666667  0.726374 -0.999257 -0.618461
# ...                             ...       ...       ...       ...       ...
# 2020-10-25 00:00:00+00:00 -0.485024 -0.522727 -0.186856 -0.995178 -0.296174
# 2020-11-08 00:00:00+00:00 -0.556403 -0.772727 -0.178566 -0.995233 -0.312374
# 2020-12-06 00:00:00+00:00 -0.212036 -0.818182 -0.145410 -0.995771 -0.284834
# 2020-12-20 00:00:00+00:00 -0.635643 -0.681818 -0.130171 -0.996296 -0.185013
# 2021-01-03 00:00:00+00:00 -0.152601 -0.818182 -0.124645 -0.996692 -0.055036
#
#                                  MD  earthquake
# timestamp
# 2000-06-18 00:00:00+00:00  0.008880           1
# 2000-07-16 00:00:00+00:00  0.009115           0
# 2000-07-30 00:00:00+00:00  0.007731           1
# 2000-08-27 00:00:00+00:00  0.009874           1
# 2000-10-08 00:00:00+00:00  0.010003           1
# ...                             ...         ...
# 2020-10-25 00:00:00+00:00  0.672537           1
# 2020-11-08 00:00:00+00:00  0.672457           0
# 2020-12-06 00:00:00+00:00  0.671445           0
# 2020-12-20 00:00:00+00:00  0.668984           1
# 2021-01-03 00:00:00+00:00  0.666738           0
#
# [432 rows x 7 columns]

# %%
import numpy as np

def create_lstm_dataset(df, lookback, n_future):
    """
    Creates an LSTM dataset from the given DataFrame.

    Parameters:
    - df: pandas DataFrame containing features.
    - lookback: Number of past timesteps to include in each X sample.

    Returns:
    - X: 3D NumPy array of shape (samples, lookback, features)
    - Y: 1D NumPy array of shape (samples,)
    """
    data = df.values  # Convert dataframe to NumPy array
    X, Y = [], []
    
    for i in range(len(data) - lookback):
        X.append(data[i:i + lookback, :7])  # First 6 columns
        Y.append(data[(i + lookback):(i + lookback + n_future), -1])     # 7th column as label
    
    return np.array(X), np.array(Y)
look_back = 10
X, Y = create_lstm_dataset(df, lookback=look_back, n_future=1)

print(X.shape)  # (number of samples, lookback, 6)
print(Y.shape)  # (number of samples,)
# Out:
# (422, 10, 7)
# (422, 1)

# %%
from sklearn.model_selection import train_test_split

# Split the data
X_train, X_val, Y_train, Y_val = train_test_split(X, Y, test_size=0.15, shuffle=False)

# Print the shapes of the resulting datasets
print("X_train shape:", X_train.shape)
print("X_val shape:", X_val.shape)
print("Y_train shape:", Y_train.shape)
print("Y_val shape:", Y_val.shape)
# Out:
# X_train shape: (358, 10, 7)
# X_val shape: (64, 10, 7)
# Y_train shape: (358, 1)
# Y_val shape: (64, 1)

# %%
print(X_train[0])
# Out:
# [[-0.50594822 -0.57575758  0.97923526 -0.99967043 -0.6259483   0.00888045
#    1.        ]
#  [-0.63750875 -1.          1.         -0.99971878 -0.62845049  0.00911476
#    0.        ]
#  [-0.04968509 -0.59090909  0.87139258 -0.99979475 -0.55940853  0.00773066
#    1.        ]
#  [-0.13132727 -0.33333333  0.80474446 -0.99947867 -0.62172332  0.00987437
#    1.        ]
#  [-0.63750875 -0.66666667  0.72637431 -0.99925737 -0.61846144  0.01000321
#    1.        ]
#  [-0.63750875 -0.18181818  0.67345772 -0.99914325 -0.58763902  0.00933626
#    1.        ]
#  [-0.63750875 -0.18181818  0.70862381 -0.99917614 -0.61504526  0.01040634
#    1.        ]
#  [-0.63750875 -0.90909091  0.71465228 -0.99923928 -0.58763902  0.0098298
#    0.        ]
#  [-0.63750875  0.22727273  0.62723942 -0.99849788 -0.66671124  0.01181231
#    1.        ]
#  [-0.63750875 -0.18181818  0.59508757 -0.99806366 -0.74673458  0.01444977
#    1.        ]]

# %%
# Count occurrences of 0 and 1 in Y_train
unique_train, counts_train = np.unique(Y_train, return_counts=True)
print("Y_train counts:", dict(zip(unique_train, counts_train)))

# Count occurrences of 0 and 1 in Y_val
unique_val, counts_val = np.unique(Y_val, return_counts=True)
print("Y_val counts:", dict(zip(unique_val, counts_val)))
# Out:
# Y_train counts: {0.0: 141, 1.0: 217}
# Y_val counts: {0.0: 29, 1.0: 35}

# %%
# root mean squared error (rmse) for regression (only for Keras tensors)
def rmse(y_true, y_pred):
    from keras import backend
    return backend.sqrt(backend.mean(backend.square(y_pred - y_true), axis=-1))

# mean squared error (mse) for regression  (only for Keras tensors)
def mse(y_true, y_pred):
    from keras import backend
    return backend.mean(backend.square(y_pred - y_true), axis=-1)

# coefficient of determination (R^2) for regression  (only for Keras tensors)
def r_square(y_true, y_pred):
    from keras import backend as K
    SS_res =  K.sum(K.square(y_true - y_pred)) 
    SS_tot = K.sum(K.square(y_true - K.mean(y_true))) 
    return ( 1 - SS_res/(SS_tot + K.epsilon()) )

# %%
# import tensorflow as tf
# from tensorflow.keras.layers import *
# from tensorflow.keras.models import Model
# from tensorflow.keras.layers import Input, LSTM, Dense, Layer, Dropout

# from tensorflow.keras.optimizers.legacy import Adam

# from tensorflow.keras.regularizers import L1L2
# from tensorflow.keras.layers import Layer, Dense, Dot, Activation

# from tensorflow.keras.callbacks import Callback, EarlyStopping

# from tensorflow.keras import backend as K

# from matplotlib import pyplot as plt

# K.clear_session()

   
# l1 = 0.0001
# l2 = 0.0001

# lstm_dropout = 0.2
# recurrent_dropout = 0.1
# dense_dropout = 0.2
# loss = 'mse'

# n_target = Y_train.shape[-2:]

# regularization_criteria = L1L2(l1=l1, l2=l2)

# n_target_y = Y_train.shape[-1]

# def build_model(input_shape):
#     input_layer = Input(shape=input_shape, name='Input_1')
#     sequence = input_layer
#     sequence = LSTM(20, return_sequences = True,  name="LSTM-1", kernel_regularizer = regularization_criteria, dropout=lstm_dropout, recurrent_dropout=recurrent_dropout)(input_layer)
#     sequence = Flatten()(sequence)
#     # sequence = Dropout(dense_dropout)(sequence)
#     # sequence = LSTM(16, return_sequences = False,  name="LSTM-2", kernel_regularizer = regularization_criteria, dropout=lstm_dropout, recurrent_dropout=recurrent_dropout)(sequence)
#     # sequence = Dense(4, activation = 'tanh', name='Dense_3')(sequence)
#     sequence = Dense(n_target_y, activation = 'tanh', name='Dense_4')(sequence)
#     output_layer = sequence

#     model = Model(inputs=input_layer, outputs=output_layer)

#     return model

# input_shape = (look_back, X_train.shape[2])

# learning_rate = 0.0005

# optimizer = Adam(learning_rate=learning_rate)

# model = build_model(input_shape)
# model.compile(optimizer=optimizer, loss=loss, metrics=[mse, rmse, r_square])
# model.summary()

# import time

# start_time = time.time()

# # early_stopping = EarlyStopping(monitor='val_loss', patience=500, restore_best_weights=True)

# history = model.fit(X_train, Y_train, epochs=700, batch_size=64, validation_data=(X_val, Y_val),
#                     # callbacks=[early_stopping]
#                     )

# end_time = time.time()
# difference_in_seconds = end_time - start_time
# print(f"The difference in seconds is: {difference_in_seconds}")

# %%
# import keras_tuner as kt
# import tensorflow as tf
# from tensorflow import keras
# from tensorflow.keras.layers import LSTM, Bidirectional, Dense, Dropout, Flatten

# def build_model(hp):
#     model = keras.Sequential()
    
#     model.add(LSTM(units=hp.Int('lstm_units', min_value=16, max_value=128, step=16),
#                    return_sequences=True,
#                      input_shape=(look_back, X_train.shape[2])))
    
#     # model.add(Dropout(hp.Float('dropout', min_value=0.0, max_value=0.5, step=0.1)))
    
#     # model.add(Bidirectional(LSTM(units=hp.Int('bidirectional_units', min_value=4, max_value=16, step=4),
#     #                              return_sequences=True)))
    
#     # model.add(Bidirectional(LSTM(units=hp.Int('bidirectional_units', min_value=4, max_value=32, step=4),
#     #                              return_sequences=True)))
    
#     model.add(Flatten())
    
#     model.add(Dropout(hp.Float('dropout', min_value=0.0, max_value=0.5, step=0.1)))
    
#     model.add(Dense(hp.Float('dense_units', min_value=0, max_value=32, step=8), activation='tanh'))
    
#     model.add(Dense(1, activation='tanh'))
    
#     model.compile(optimizer=keras.optimizers.Adam(hp.Choice('learning_rate', values=[1e-4, 1e-5])),
#                     loss='mse',
#                     metrics=[rmse, r_square])
    
#     return model

# %%
# import keras_tuner as kt
# import tensorflow as tf
# from tensorflow import keras
# from tensorflow.keras.layers import LSTM, Bidirectional, Dense, Dropout, Flatten, Attention, Input
# from tensorflow.keras.models import Model

# def build_model(hp):
#     inputs = Input(shape=(look_back, X_train.shape[2]))
    
#     lstm_out = LSTM(units=60,
#                     return_sequences=True)(inputs)

    
#     flatten = Flatten()(lstm_out)
    
#     dropout = Dropout(hp.Float('dropout', min_value=0.0, max_value=0.5, step=0.1))(flatten)
    
#     dense = Dense(hp.Int('dense_units', min_value=0, max_value=32, step=4), activation='tanh')(dropout)
    
#     output = Dense(1, activation='tanh')(dense)
    
#     model = Model(inputs=inputs, outputs=output)
    
#     model.compile(optimizer=keras.optimizers.Adam(hp.Choice('learning_rate', values=[1e-4, 1e-5])),
#                   loss='mse',
#                   metrics=[rmse, r_square])
    
#     return model

# %%
# tuner = kt.RandomSearch(build_model,
#                         objective=kt.Objective("val_r_square", direction="max"),
#                         max_trials=20,
#                         executions_per_trial=2,
#                         directory='my_dir',
#                         project_name='earthquake')

# %%
# tuner.search(X_train, Y_train, epochs=150, validation_data=(X_val, Y_val))

# %%
# from tensorflow.keras.callbacks import Callback, EarlyStopping
# best_hps = tuner.get_best_hyperparameters(num_trials=5)[0]

# # print(f"Best LSTM units: {best_hps.get('lstm_units')}")
# # print(f"Best BiLSTM usage: {best_hps.get('bidirectional_units')}")
# print(f"Best Dropout Rate: {best_hps.get('dropout')}")
# print(f"Best Dense Units: {best_hps.get('dense_units')}")
# print(f"Best Learning Rate: {best_hps.get('learning_rate')}")

# # Train the best model
# best_model = tuner.hypermodel.build(best_hps)
# early_stopping = EarlyStopping(monitor='val_loss', patience=700, restore_best_weights=True)
# history = best_model.fit(X_train, Y_train, epochs=1000, validation_data=(X_val, Y_val), callbacks=[early_stopping])

# %%
# # Generate predictions for the training set
# Y_train_pred = best_model.predict(X_train)

# # Plot the true values and predictions
# plt.figure(figsize=(10, 6))
# plt.plot(Y_train, label='True Values', color='blue',  marker='o')
# plt.plot(Y_train_pred, label='Predictions', color='red', linestyle='dashed', marker='o')
# plt.title('Training True Values vs Predictions')
# plt.xlabel('Sample Index')
# plt.ylabel('Value')
# plt.legend()
# plt.show()

# %%
# # Generate predictions for the validation set
# Y_val_pred = best_model.predict(X_val)

# # Plot the true values and predictions
# plt.figure(figsize=(10, 6))
# plt.plot(Y_val, label='True Values', color='blue', marker='o')
# plt.plot(Y_val_pred, label='Predictions', color='red', linestyle='dashed', marker='o')
# plt.title('Validation True Values vs Predictions')
# plt.xlabel('Sample Index')
# plt.ylabel('Value')
# plt.legend()
# plt.show()

# %%
# # Generate predictions for the validation set
# Y_val_pred = best_model.predict(X_val)
# Y_val_pred = np.where(Y_val_pred > 0.5, 1,np.where(Y_val_pred<-0.5, -1, 0) )

# # Plot the true values and predictions
# plt.figure(figsize=(10, 6))
# plt.plot(Y_val, label='True Values', color='blue', marker='o')
# plt.plot(Y_val_pred, label='Predictions', color='red', linestyle='dashed', marker='o')
# plt.title('Validation True Values vs Predictions')
# plt.xlabel('Sample Index')
# plt.ylabel('Value')
# plt.legend()
# plt.show()

# %%
# from sklearn.metrics import confusion_matrix

# # Create confusion matrix
# conf_matrix = confusion_matrix(Y_val.flatten(), Y_val_pred.flatten())

# # Print the confusion matrix
# print("Confusion Matrix:")
# print(conf_matrix)

# %%
# # Calculate total accuracy
# total_accuracy = np.sum(Y_val.flatten() == Y_val_pred.flatten()) / len(Y_val)
# print(f"Total Accuracy: {total_accuracy * 100:.2f}%")

# %%
# Create a mask to filter out values in Y_test that are not equal to 0
mask = Y_val != 0
# print(X_test.shape)
# Apply the mask to filter X_test and Y_test
X_test_filtered = np.array([x for x, m in zip(X_val, mask) if m])
Y_test_filtered = Y_val[mask]

# Print the shapes of the filtered arrays to verify
print(X_test_filtered.shape)
print(Y_test_filtered.shape)
# Out:
# (35, 10, 7)
# (35,)

# %%
# # Generate predictions for the validation set
# Y_val_pred = best_model.predict(X_test_filtered)
# Y_val_pred = np.where(Y_val_pred > 0.15, 1, -1)

# # Plot the true values and predictions
# plt.figure(figsize=(10, 6))
# plt.plot(Y_test_filtered, label='True Values', color='blue', marker='o')
# plt.plot(Y_val_pred, label='Predictions', color='red', linestyle='dashed', marker='o')
# plt.title('Validation True Values vs Predictions')
# plt.xlabel('Sample Index')
# plt.ylabel('Value')
# plt.legend()
# plt.show()

# %%
# from sklearn.metrics import confusion_matrix

# # Create confusion matrix
# conf_matrix = confusion_matrix(Y_test_filtered.flatten(), Y_val_pred.flatten())

# # Print the confusion matrix
# print("Confusion Matrix:")
# print(conf_matrix)

# %%
# # Calculate total accuracy
# total_accuracy = np.sum(Y_test_filtered.flatten() == Y_val_pred.flatten()) / len(Y_test_filtered)
# print(f"Total Accuracy: {total_accuracy * 100:.2f}%")

# %%
import tensorflow as tf
from tensorflow.keras.layers import *
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, LSTM, Dense, Layer, Dropout

from tensorflow.keras.optimizers.legacy import Adam

from tensorflow.keras.regularizers import L1L2
from tensorflow.keras.layers import Layer, Dense, Dot, Activation

from tensorflow.keras.callbacks import Callback, EarlyStopping

from tensorflow.keras import backend as K

from matplotlib import pyplot as plt

K.clear_session()

   
l1 = 0.0
l2 = 0.0

lstm_dropout = 0.0
recurrent_dropout = 0.0
dense_dropout = 0.1
loss = 'mse'

n_target = Y_train.shape[-2:]

regularization_criteria = L1L2(l1=l1, l2=l2)

n_target_y = Y_train.shape[-1]

def build_model(input_shape):
    input_layer = Input(shape=input_shape, name='Input_1')
    sequence = input_layer
    sequence = LSTM(50, return_sequences = True,  name="LSTM-1", kernel_regularizer = regularization_criteria, dropout=lstm_dropout, recurrent_dropout=recurrent_dropout)(input_layer)
    
    sequence = Flatten()(sequence)
    sequence = Dense(20, activation = 'tanh', name='Dense_2')(sequence)
    sequence = Dropout(0.3)(sequence)
    # sequence = LSTM(16, return_sequences = False,  name="LSTM-2", kernel_regularizer = regularization_criteria, dropout=lstm_dropout, recurrent_dropout=recurrent_dropout)(sequence)
    sequence = Dense(10, activation = 'tanh', name='Dense_3')(sequence)
    sequence = Dense(n_target_y, activation = 'sigmoid', name='Dense_4')(sequence)
    output_layer = sequence

    model = Model(inputs=input_layer, outputs=output_layer)

    return model

input_shape = (look_back, X_train.shape[2])

learning_rate = 0.001

optimizer = Adam(learning_rate=learning_rate)

model = build_model(input_shape)
model.compile(optimizer=optimizer, loss=loss, metrics=[mse])
model.summary()

import time

start_time = time.time()

early_stopping = EarlyStopping(monitor='val_loss', patience=700, restore_best_weights=True)

history = model.fit(X_train, Y_train, epochs=1000, batch_size=64, validation_data=(X_val, Y_val),
                    callbacks=[early_stopping]
                    )

end_time = time.time()
difference_in_seconds = end_time - start_time
print(f"The difference in seconds is: {difference_in_seconds}")
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  Input_1 (InputLayer)        [(None, 10, 7)]           0
#
#  LSTM-1 (LSTM)               (None, 10, 50)            11600
#
#  flatten (Flatten)           (None, 500)               0
#
#  Dense_2 (Dense)             (None, 20)                10020
#
#  dropout (Dropout)           (None, 20)                0
#
#  Dense_3 (Dense)             (None, 10)                210
#
#  Dense_4 (Dense)             (None, 1)                 11
#
# =================================================================
# Total params: 21,841
# Trainable params: 21,841
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/1000
# 6/6 [==============================] - 4s 112ms/step - loss: 0.2632 - mse: 0.2632 - val_loss: 0.2639 - val_mse: 0.2639
# Epoch 2/1000
# 6/6 [==============================] - 0s 13ms/step - loss: 0.2458 - mse: 0.2458 - val_loss: 0.2520 - val_mse: 0.2520
# Epoch 3/1000
# 6/6 [==============================] - 0s 14ms/step - loss: 0.2404 - mse: 0.2404 - val_loss: 0.2475 - val_mse: 0.2475
# Epoch 4/1000
# 6/6 [==============================] - 0s 13ms/step - loss: 0.2390 - mse: 0.2390 - val_loss: 0.2481 - val_mse: 0.2481
# Epoch 5/1000
# 6/6 [==============================] - 0s 13ms/step - loss: 0.2390 - mse: 0.2390 - val_loss: 0.2524 - val_mse: 0.2524
# Epoch 6/1000
# 6/6 [==============================] - 0s 13ms/step - loss: 0.2344 - mse: 0.2344 - val_loss: 0.2517 - val_mse: 0.2517
# Epoch 7/1000
# 6/6 [==============================] - 0s 13ms/step - loss: 0.2379 - mse: 0.2379 - val_loss: 0.2498 - val_mse: 0.2498
# Epoch 8/1000
# 6/6 [==============================] - 0s 13ms/step - loss: 0.2366 - mse: 0.2366 - val_loss: 0.2530 - val_mse: 0.2530
# Epoch 9/1000
# 6/6 [==============================] - 0s 13ms/step - loss: 0.2337 - mse: 0.2337 - val_loss: 0.2546 - val_mse: 0.2546
# Epoch 10/1000
# 6/6 [==============================] - 0s 13ms/step - loss: 0.2324 - mse: 0.2324 - val_loss: 0.2544 - val_mse: 0.2544
# Epoch 11/1000
# 6/6 [==============================] - 0s 13ms/step - loss: 0.2326 - mse: 0.2326 - val_loss: 0.2549 - val_mse: 0.2549
# Epoch 12/1000
# 6/6 [==============================] - 0s 13ms/step - loss: 0.2331 - mse: 0.2331 - val_loss: 0.2559 - val_mse: 0.2559
# Epoch 13/1000
# 6/6 [==============================] - 0s 14ms/step - loss: 0.2375 - mse: 0.2375 - val_loss: 0.2526 - val_mse: 0.2526
# Epoch 14/1000
# 6/6 [==============================] - 0s 13ms/step - loss: 0.2340 - mse: 0.2340 - val_loss: 0.2542 - val_mse: 0.2542
# Epoch 15/1000
# 6/6 [==============================] - 0s 13ms/step - loss: 0.2334 - mse: 0.2334 - val_loss: 0.2558 - val_mse: 0.2558
# Epoch 16/1000
# 6/6 [==============================] - 0s 13ms/step - loss: 0.2326 - mse: 0.2326 - val_loss: 0.2554 - val_mse: 0.2554
# Epoch 17/1000
# 6/6 [==============================] - 0s 26ms/step - loss: 0.2313 - mse: 0.2313 - val_loss: 0.2569 - val_mse: 0.2569
# Epoch 18/1000
# 6/6 [==============================] - 0s 13ms/step - loss: 0.2310 - mse: 0.2310 - val_loss: 0.2622 - val_mse: 0.2622
# Epoch 19/1000
# 6/6 [==============================] - 0s 12ms/step - loss: 0.2328 - mse: 0.2328 - val_loss: 0.2593 - val_mse: 0.2593
# Epoch 20/1000
# 6/6 [==============================] - 0s 13ms/step - loss: 0.2330 - mse: 0.2330 - val_loss: 0.2589 - val_mse: 0.2589
# Epoch 21/1000
# 6/6 [==============================] - 0s 13ms/step - loss: 0.2305 - mse: 0.2305 - val_loss: 0.2591 - val_mse: 0.2591
# Epoch 22/1000
# 6/6 [==============================] - 0s 13ms/step - loss: 0.2338 - mse: 0.2338 - val_loss: 0.2591 - val_mse: 0.2591
# Epoch 23/1000
# 6/6 [==============================] - 0s 13ms/step - loss: 0.2328 - mse: 0.2328 - val_loss: 0.2636 - val_mse: 0.2636
# Epoch 24/1000
# 6/6 [==============================] - 0s 13ms/step - loss: 0.2284 - mse: 0.2284 - val_loss: 0.2657 - val_mse: 0.2657
# Epoch 25/1000
# 6/6 [==============================] - 0s 14ms/step - loss: 0.2305 - mse: 0.2305 - val_loss: 0.2599 - val_mse: 0.2599
# Epoch 26/1000
# 6/6 [==============================] - 0s 14ms/step - loss: 0.2318 - mse: 0.2318 - val_loss: 0.2611 - val_mse: 0.2611
# Epoch 27/1000
# 6/6 [==============================] - 0s 13ms/step - loss: 0.2299 - mse: 0.2299 - val_loss: 0.2700 - val_mse: 0.2700
# Epoch 28/1000
# 6/6 [==============================] - 0s 14ms/step - loss: 0.2284 - mse: 0.2284 - val_loss: 0.2613 - val_mse: 0.2613
# Epoch 29/1000
# 6/6 [==============================] - 0s 14ms/step - loss: 0.2270 - mse: 0.2270 - val_loss: 0.2621 - val_mse: 0.2621
# Epoch 30/1000
# 6/6 [==============================] - 0s 14ms/step - loss: 0.2290 - mse: 0.2290 - val_loss: 0.2653 - val_mse: 0.2653
# Epoch 31/1000
# 6/6 [==============================] - 0s 15ms/step - loss: 0.2302 - mse: 0.2302 - val_loss: 0.2755 - val_mse: 0.2755
# Epoch 32/1000
# 6/6 [==============================] - 0s 14ms/step - loss: 0.2264 - mse: 0.2264 - val_loss: 0.2654 - val_mse: 0.2654
# Epoch 33/1000
# 6/6 [==============================] - 0s 14ms/step - loss: 0.2251 - mse: 0.2251 - val_loss: 0.2620 - val_mse: 0.2620
# Epoch 34/1000
# 6/6 [==============================] - 0s 14ms/step - loss: 0.2306 - mse: 0.2306 - val_loss: 0.2669 - val_mse: 0.2669
# Epoch 35/1000
# 6/6 [==============================] - 0s 14ms/step - loss: 0.2311 - mse: 0.2311 - val_loss: 0.2689 - val_mse: 0.2689
# Epoch 36/1000
# 6/6 [==============================] - 0s 13ms/step - loss: 0.2264 - mse: 0.2264 - val_loss: 0.2720 - val_mse: 0.2720
# Epoch 37/1000
# 6/6 [==============================] - 0s 13ms/step - loss: 0.2236 - mse: 0.2236 - val_loss: 0.2741 - val_mse: 0.2741
# Epoch 38/1000
# 6/6 [==============================] - 0s 14ms/step - loss: 0.2285 - mse: 0.2285 - val_loss: 0.2646 - val_mse: 0.2646
# Epoch 39/1000
# 6/6 [==============================] - 0s 13ms/step - loss: 0.2260 - mse: 0.2260 - val_loss: 0.2725 - val_mse: 0.2725
# Epoch 40/1000
# 6/6 [==============================] - 0s 13ms/step - loss: 0.2299 - mse: 0.2299 - val_loss: 0.2740 - val_mse: 0.2740
# Epoch 41/1000
# 6/6 [==============================] - 0s 20ms/step - loss: 0.2238 - mse: 0.2238 - val_loss: 0.2693 - val_mse: 0.2693
# Epoch 42/1000
# 6/6 [==============================] - 0s 21ms/step - loss: 0.2285 - mse: 0.2285 - val_loss: 0.2686 - val_mse: 0.2686
# Epoch 43/1000
# 6/6 [==============================] - 0s 13ms/step - loss: 0.2297 - mse: 0.2297 - val_loss: 0.2800 - val_mse: 0.2800
# Epoch 44/1000
# 6/6 [==============================] - 0s 14ms/step - loss: 0.2244 - mse: 0.2244 - val_loss: 0.2708 - val_mse: 0.2708
# Epoch 45/1000
# 6/6 [==============================] - 0s 14ms/step - loss: 0.2278 - mse: 0.2278 - val_loss: 0.2722 - val_mse: 0.2722
# Epoch 46/1000
# 6/6 [==============================] - 0s 14ms/step - loss: 0.2225 - mse: 0.2225 - val_loss: 0.2741 - val_mse: 0.2741
# Epoch 47/1000
# 6/6 [==============================] - 0s 14ms/step - loss: 0.2250 - mse: 0.2250 - val_loss: 0.2760 - val_mse: 0.2760
# Epoch 48/1000
# 6/6 [==============================] - 0s 14ms/step - loss: 0.2219 - mse: 0.2219 - val_loss: 0.2743 - val_mse: 0.2743
# Epoch 49/1000
# 6/6 [==============================] - 0s 13ms/step - loss: 0.2244 - mse: 0.2244 - val_loss: 0.2765 - val_mse: 0.2765
# Epoch 50/1000
# 6/6 [==============================] - 0s 14ms/step - loss: 0.2226 - mse: 0.2226 - val_loss: 0.2781 - val_mse: 0.2781
# Epoch 51/1000
# 6/6 [==============================] - 0s 13ms/step - loss: 0.2241 - mse: 0.2241 - val_loss: 0.2809 - val_mse: 0.2809
# Epoch 52/1000
# 6/6 [==============================] - 0s 13ms/step - loss: 0.2209 - mse: 0.2209 - val_loss: 0.2807 - val_mse: 0.2807
# Epoch 53/1000
# 6/6 [==============================] - 0s 14ms/step - loss: 0.2240 - mse: 0.2240 - val_loss: 0.2848 - val_mse: 0.2848
# Epoch 54/1000
# 6/6 [==============================] - 0s 14ms/step - loss: 0.2203 - mse: 0.2203 - val_loss: 0.2726 - val_mse: 0.2726
# Epoch 55/1000
# 6/6 [==============================] - 0s 14ms/step - loss: 0.2231 - mse: 0.2231 - val_loss: 0.2763 - val_mse: 0.2763
# Epoch 56/1000
# 6/6 [==============================] - 0s 14ms/step - loss: 0.2204 - mse: 0.2204 - val_loss: 0.2809 - val_mse: 0.2809
# Epoch 57/1000
# 6/6 [==============================] - 0s 14ms/step - loss: 0.2221 - mse: 0.2221 - val_loss: 0.2832 - val_mse: 0.2832
# Epoch 58/1000
# 6/6 [==============================] - 0s 14ms/step - loss: 0.2175 - mse: 0.2175 - val_loss: 0.2788 - val_mse: 0.2788
# Epoch 59/1000
# 6/6 [==============================] - 0s 14ms/step - loss: 0.2168 - mse: 0.2168 - val_loss: 0.2817 - val_mse: 0.2817
# Epoch 60/1000
# 6/6 [==============================] - 0s 13ms/step - loss: 0.2168 - mse: 0.2168 - val_loss: 0.2866 - val_mse: 0.2866
# Epoch 61/1000
# 6/6 [==============================] - 0s 14ms/step - loss: 0.2159 - mse: 0.2159 - val_loss: 0.2783 - val_mse: 0.2783
# Epoch 62/1000
# 6/6 [==============================] - 0s 14ms/step - loss: 0.2177 - mse: 0.2177 - val_loss: 0.2896 - val_mse: 0.2896
# Epoch 63/1000
# 6/6 [==============================] - 0s 14ms/step - loss: 0.2177 - mse: 0.2177 - val_loss: 0.2838 - val_mse: 0.2838
# Epoch 64/1000
# 6/6 [==============================] - 0s 13ms/step - loss: 0.2143 - mse: 0.2143 - val_loss: 0.2881 - val_mse: 0.2881
# Epoch 65/1000
# 6/6 [==============================] - 0s 14ms/step - loss: 0.2155 - mse: 0.2155 - val_loss: 0.2881 - val_mse: 0.2881
# Epoch 66/1000
# 6/6 [==============================] - 0s 13ms/step - loss: 0.2170 - mse: 0.2170 - val_loss: 0.2828 - val_mse: 0.2828
# Epoch 67/1000
# 6/6 [==============================] - 0s 14ms/step - loss: 0.2180 - mse: 0.2180 - val_loss: 0.2864 - val_mse: 0.2864
# Epoch 68/1000
# 6/6 [==============================] - 0s 13ms/step - loss: 0.2143 - mse: 0.2143 - val_loss: 0.2919 - val_mse: 0.2919
# Epoch 69/1000
# 6/6 [==============================] - 0s 13ms/step - loss: 0.2138 - mse: 0.2138 - val_loss: 0.2918 - val_mse: 0.2918
# Epoch 70/1000
# 6/6 [==============================] - 0s 13ms/step - loss: 0.2147 - mse: 0.2147 - val_loss: 0.2890 - val_mse: 0.2890
# Epoch 71/1000
# 6/6 [==============================] - 0s 14ms/step - loss: 0.2111 - mse: 0.2111 - val_loss: 0.2910 - val_mse: 0.2910
# Epoch 72/1000
# 6/6 [==============================] - 0s 14ms/step - loss: 0.2087 - mse: 0.2087 - val_loss: 0.2912 - val_mse: 0.2912
# Epoch 73/1000
# 6/6 [==============================] - 0s 14ms/step - loss: 0.2109 - mse: 0.2109 - val_loss: 0.2923 - val_mse: 0.2923
# Epoch 74/1000
# 6/6 [==============================] - 0s 13ms/step - loss: 0.2082 - mse: 0.2082 - val_loss: 0.2997 - val_mse: 0.2997
# Epoch 75/1000
# 6/6 [==============================] - 0s 13ms/step - loss: 0.2055 - mse: 0.2055 - val_loss: 0.2888 - val_mse: 0.2888
# Epoch 76/1000
# 6/6 [==============================] - 0s 14ms/step - loss: 0.2061 - mse: 0.2061 - val_loss: 0.2925 - val_mse: 0.2925
# Epoch 77/1000
# 6/6 [==============================] - 0s 14ms/step - loss: 0.2055 - mse: 0.2055 - val_loss: 0.2991 - val_mse: 0.2991
# Epoch 78/1000
# 6/6 [==============================] - 0s 17ms/step - loss: 0.2036 - mse: 0.2036 - val_loss: 0.2888 - val_mse: 0.2888
# Epoch 79/1000
# 6/6 [==============================] - 0s 14ms/step - loss: 0.2041 - mse: 0.2041 - val_loss: 0.2958 - val_mse: 0.2958
# Epoch 80/1000
# 6/6 [==============================] - 0s 14ms/step - loss: 0.2058 - mse: 0.2058 - val_loss: 0.2899 - val_mse: 0.2899
# Epoch 81/1000
# 6/6 [==============================] - 0s 14ms/step - loss: 0.2035 - mse: 0.2035 - val_loss: 0.2972 - val_mse: 0.2972
# Epoch 82/1000
# 6/6 [==============================] - 0s 14ms/step - loss: 0.2021 - mse: 0.2021 - val_loss: 0.2900 - val_mse: 0.2900
# Epoch 83/1000
# 6/6 [==============================] - 0s 14ms/step - loss: 0.2089 - mse: 0.2089 - val_loss: 0.2955 - val_mse: 0.2955
# Epoch 84/1000
# 6/6 [==============================] - 0s 14ms/step - loss: 0.1999 - mse: 0.1999 - val_loss: 0.3023 - val_mse: 0.3023
# Epoch 85/1000
# 6/6 [==============================] - 0s 13ms/step - loss: 0.2017 - mse: 0.2017 - val_loss: 0.2922 - val_mse: 0.2922
# Epoch 86/1000
# 6/6 [==============================] - 0s 13ms/step - loss: 0.2008 - mse: 0.2008 - val_loss: 0.2880 - val_mse: 0.2880
# Epoch 87/1000
# 6/6 [==============================] - 0s 14ms/step - loss: 0.1964 - mse: 0.1964 - val_loss: 0.3016 - val_mse: 0.3016
# Epoch 88/1000
# 6/6 [==============================] - 0s 15ms/step - loss: 0.2044 - mse: 0.2044 - val_loss: 0.2971 - val_mse: 0.2971
# Epoch 89/1000
# 6/6 [==============================] - 0s 13ms/step - loss: 0.1996 - mse: 0.1996 - val_loss: 0.2864 - val_mse: 0.2864
# Epoch 90/1000
# 6/6 [==============================] - 0s 14ms/step - loss: 0.1927 - mse: 0.1927 - val_loss: 0.3064 - val_mse: 0.3064
# Epoch 91/1000
# 6/6 [==============================] - 0s 15ms/step - loss: 0.2010 - mse: 0.2010 - val_loss: 0.2912 - val_mse: 0.2912
# Epoch 92/1000
# 6/6 [==============================] - 0s 15ms/step - loss: 0.1962 - mse: 0.1962 - val_loss: 0.2934 - val_mse: 0.2934
# Epoch 93/1000
# 6/6 [==============================] - 0s 14ms/step - loss: 0.1916 - mse: 0.1916 - val_loss: 0.3187 - val_mse: 0.3187
# Epoch 94/1000
# 6/6 [==============================] - 0s 15ms/step - loss: 0.1943 - mse: 0.1943 - val_loss: 0.2987 - val_mse: 0.2987
# Epoch 95/1000
# 6/6 [==============================] - 0s 15ms/step - loss: 0.1910 - mse: 0.1910 - val_loss: 0.2996 - val_mse: 0.2996
# Epoch 96/1000
# 6/6 [==============================] - 0s 14ms/step - loss: 0.1944 - mse: 0.1944 - val_loss: 0.3067 - val_mse: 0.3067
# Epoch 97/1000
# 6/6 [==============================] - 0s 14ms/step - loss: 0.1942 - mse: 0.1942 - val_loss: 0.2946 - val_mse: 0.2946
# Epoch 98/1000
# 6/6 [==============================] - 0s 14ms/step - loss: 0.1880 - mse: 0.1880 - val_loss: 0.2996 - val_mse: 0.2996
# Epoch 99/1000
# 6/6 [==============================] - 0s 14ms/step - loss: 0.1830 - mse: 0.1830 - val_loss: 0.2979 - val_mse: 0.2979
# Epoch 100/1000
# 6/6 [==============================] - 0s 25ms/step - loss: 0.1831 - mse: 0.1831 - val_loss: 0.2988 - val_mse: 0.2988
# Epoch 101/1000
# 6/6 [==============================] - 0s 14ms/step - loss: 0.1799 - mse: 0.1799 - val_loss: 0.3106 - val_mse: 0.3106
# Epoch 102/1000
# 6/6 [==============================] - 0s 15ms/step - loss: 0.1826 - mse: 0.1826 - val_loss: 0.3094 - val_mse: 0.3094
# Epoch 103/1000
# 6/6 [==============================] - 0s 14ms/step - loss: 0.1823 - mse: 0.1823 - val_loss: 0.3059 - val_mse: 0.3059
# Epoch 104/1000
# 6/6 [==============================] - 0s 14ms/step - loss: 0.1786 - mse: 0.1786 - val_loss: 0.3007 - val_mse: 0.3007
# Epoch 105/1000
# 6/6 [==============================] - 0s 15ms/step - loss: 0.1830 - mse: 0.1830 - val_loss: 0.3103 - val_mse: 0.3103
# Epoch 106/1000
# 6/6 [==============================] - 0s 15ms/step - loss: 0.1809 - mse: 0.1809 - val_loss: 0.2888 - val_mse: 0.2888
# Epoch 107/1000
# 6/6 [==============================] - 0s 15ms/step - loss: 0.1789 - mse: 0.1789 - val_loss: 0.3105 - val_mse: 0.3105
# Epoch 108/1000
# 6/6 [==============================] - 0s 14ms/step - loss: 0.1785 - mse: 0.1785 - val_loss: 0.3095 - val_mse: 0.3095
# Epoch 109/1000
# 6/6 [==============================] - 0s 15ms/step - loss: 0.1735 - mse: 0.1735 - val_loss: 0.2977 - val_mse: 0.2977
# Epoch 110/1000
# 6/6 [==============================] - 0s 15ms/step - loss: 0.1740 - mse: 0.1740 - val_loss: 0.3065 - val_mse: 0.3065
# Epoch 111/1000
# 6/6 [==============================] - 0s 15ms/step - loss: 0.1732 - mse: 0.1732 - val_loss: 0.3034 - val_mse: 0.3034
# Epoch 112/1000
# 6/6 [==============================] - 0s 15ms/step - loss: 0.1784 - mse: 0.1784 - val_loss: 0.3168 - val_mse: 0.3168
# Epoch 113/1000
# 6/6 [==============================] - 0s 15ms/step - loss: 0.1805 - mse: 0.1805 - val_loss: 0.3263 - val_mse: 0.3263
# Epoch 114/1000
# 6/6 [==============================] - 0s 14ms/step - loss: 0.1780 - mse: 0.1780 - val_loss: 0.3189 - val_mse: 0.3189
# Epoch 115/1000
# 6/6 [==============================] - 0s 16ms/step - loss: 0.1686 - mse: 0.1686 - val_loss: 0.3226 - val_mse: 0.3226
# Epoch 116/1000
# 6/6 [==============================] - 0s 14ms/step - loss: 0.1641 - mse: 0.1641 - val_loss: 0.3364 - val_mse: 0.3364
# Epoch 117/1000
# 6/6 [==============================] - 0s 14ms/step - loss: 0.1637 - mse: 0.1637 - val_loss: 0.3148 - val_mse: 0.3148
# Epoch 118/1000
# 6/6 [==============================] - 0s 14ms/step - loss: 0.1611 - mse: 0.1611 - val_loss: 0.3323 - val_mse: 0.3323
# Epoch 119/1000
# 6/6 [==============================] - 0s 15ms/step - loss: 0.1658 - mse: 0.1658 - val_loss: 0.3386 - val_mse: 0.3386
# Epoch 120/1000
# 6/6 [==============================] - 0s 16ms/step - loss: 0.1639 - mse: 0.1639 - val_loss: 0.3281 - val_mse: 0.3281
# Epoch 121/1000
# 6/6 [==============================] - 0s 16ms/step - loss: 0.1628 - mse: 0.1628 - val_loss: 0.3409 - val_mse: 0.3409
# Epoch 122/1000
# 6/6 [==============================] - 0s 15ms/step - loss: 0.1598 - mse: 0.1598 - val_loss: 0.3387 - val_mse: 0.3387
# Epoch 123/1000
# 6/6 [==============================] - 0s 15ms/step - loss: 0.1635 - mse: 0.1635 - val_loss: 0.3380 - val_mse: 0.3380
# Epoch 124/1000
# 6/6 [==============================] - 0s 16ms/step - loss: 0.1549 - mse: 0.1549 - val_loss: 0.3416 - val_mse: 0.3416
# Epoch 125/1000
# 6/6 [==============================] - 0s 16ms/step - loss: 0.1541 - mse: 0.1541 - val_loss: 0.3406 - val_mse: 0.3406
# Epoch 126/1000
# 6/6 [==============================] - 0s 15ms/step - loss: 0.1504 - mse: 0.1504 - val_loss: 0.3552 - val_mse: 0.3552
# Epoch 127/1000
# 6/6 [==============================] - 0s 16ms/step - loss: 0.1502 - mse: 0.1502 - val_loss: 0.3826 - val_mse: 0.3826
# Epoch 128/1000
# 6/6 [==============================] - 0s 16ms/step - loss: 0.1471 - mse: 0.1471 - val_loss: 0.3641 - val_mse: 0.3641
# Epoch 129/1000
# 6/6 [==============================] - 0s 16ms/step - loss: 0.1432 - mse: 0.1432 - val_loss: 0.3699 - val_mse: 0.3699
# Epoch 130/1000
# 6/6 [==============================] - 0s 16ms/step - loss: 0.1452 - mse: 0.1452 - val_loss: 0.3753 - val_mse: 0.3753
# Epoch 131/1000
# 6/6 [==============================] - 0s 15ms/step - loss: 0.
1000
# 6/6 [==============================] - 0s 24ms/step - loss: 0.0264 - mse: 0.0264 - val_loss: 0.5201 - val_mse: 0.5201
# Epoch 291/1000
# 6/6 [==============================] - 0s 23ms/step - loss: 0.0214 - mse: 0.0214 - val_loss: 0.5207 - val_mse: 0.5207
# Epoch 292/1000
# 6/6 [==============================] - 0s 21ms/step - loss: 0.0241 - mse: 0.0241 - val_loss: 0.5301 - val_mse: 0.5301
# Epoch 293/1000
# 6/6 [==============================] - 0s 24ms/step - loss: 0.0201 - mse: 0.0201 - val_loss: 0.5385 - val_mse: 0.5385
# Epoch 294/1000
# 6/6 [==============================] - 0s 23ms/step - loss: 0.0188 - mse: 0.0188 - val_loss: 0.5171 - val_mse: 0.5171
# Epoch 295/1000
# 6/6 [==============================] - 0s 23ms/step - loss: 0.0177 - mse: 0.0177 - val_loss: 0.4986 - val_mse: 0.4986
# Epoch 296/1000
# 6/6 [==============================] - 0s 23ms/step - loss: 0.0201 - mse: 0.0201 - val_loss: 0.5207 - val_mse: 0.5207
# Epoch 297/1000
# 6/6 [==============================] - 0s 24ms/step - loss: 0.0163 - mse: 0.0163 - val_loss: 0.5179 - val_mse: 0.5179
# Epoch 298/1000
# 6/6 [==============================] - 0s 22ms/step - loss: 0.0167 - mse: 0.0167 - val_loss: 0.5216 - val_mse: 0.5216
# Epoch 299/1000
# 6/6 [==============================] - 0s 24ms/step - loss: 0.0195 - mse: 0.0195 - val_loss: 0.5009 - val_mse: 0.5009
# Epoch 300/1000
# 6/6 [==============================] - 0s 21ms/step - loss: 0.0201 - mse: 0.0201 - val_loss: 0.5243 - val_mse: 0.5243
# Epoch 301/1000
# 6/6 [==============================] - 0s 23ms/step - loss: 0.0176 - mse: 0.0176 - val_loss: 0.5138 - val_mse: 0.5138
# Epoch 302/1000
# 6/6 [==============================] - 0s 23ms/step - loss: 0.0187 - mse: 0.0187 - val_loss: 0.4977 - val_mse: 0.4977
# Epoch 303/1000
# 6/6 [==============================] - 0s 23ms/step - loss: 0.0171 - mse: 0.0171 - val_loss: 0.5033 - val_mse: 0.5033
# Epoch 304/1000
# 6/6 [==============================] - 0s 23ms/step - loss: 0.0162 - mse: 0.0162 - val_loss: 0.4971 - val_mse: 0.4971
# Epoch 305/1000
# 6/6 [==============================] - 0s 25ms/step - loss: 0.0163 - mse: 0.0163 - val_loss: 0.5313 - val_mse: 0.5313
# Epoch 306/1000
# 6/6 [==============================] - 0s 24ms/step - loss: 0.0167 - mse: 0.0167 - val_loss: 0.5205 - val_mse: 0.5205
# Epoch 307/1000
# 6/6 [==============================] - 0s 22ms/step - loss: 0.0169 - mse: 0.0169 - val_loss: 0.5111 - val_mse: 0.5111
# Epoch 308/1000
# 6/6 [==============================] - 0s 23ms/step - loss: 0.0188 - mse: 0.0188 - val_loss: 0.5350 - val_mse: 0.5350
# Epoch 309/1000
# 6/6 [==============================] - 0s 48ms/step - loss: 0.0156 - mse: 0.0156 - val_loss: 0.5224 - val_mse: 0.5224
# Epoch 310/1000
# 6/6 [==============================] - 0s 23ms/step - loss: 0.0156 - mse: 0.0156 - val_loss: 0.5243 - val_mse: 0.5243
# Epoch 311/1000
# 6/6 [==============================] - 0s 22ms/step - loss: 0.0165 - mse: 0.0165 - val_loss: 0.5067 - val_mse: 0.5067
# Epoch 312/1000
# 6/6 [==============================] - 0s 23ms/step - loss: 0.0170 - mse: 0.0170 - val_loss: 0.5240 - val_mse: 0.5240
# Epoch 313/1000
# 6/6 [==============================] - 0s 23ms/step - loss: 0.0151 - mse: 0.0151 - val_loss: 0.5347 - val_mse: 0.5347
# Epoch 314/1000
# 6/6 [==============================] - 0s 23ms/step - loss: 0.0154 - mse: 0.0154 - val_loss: 0.5220 - val_mse: 0.5220
# Epoch 315/1000
# 6/6 [==============================] - 0s 23ms/step - loss: 0.0153 - mse: 0.0153 - val_loss: 0.5204 - val_mse: 0.5204
# Epoch 316/1000
# 6/6 [==============================] - 0s 23ms/step - loss: 0.0150 - mse: 0.0150 - val_loss: 0.5216 - val_mse: 0.5216
# Epoch 317/1000
# 6/6 [==============================] - 0s 23ms/step - loss: 0.0146 - mse: 0.0146 - val_loss: 0.5252 - val_mse: 0.5252
# Epoch 318/1000
# 6/6 [==============================] - 0s 23ms/step - loss: 0.0152 - mse: 0.0152 - val_loss: 0.5217 - val_mse: 0.5217
# Epoch 319/1000
# 6/6 [==============================] - 0s 22ms/step - loss: 0.0149 - mse: 0.0149 - val_loss: 0.5237 - val_mse: 0.5237
# Epoch 320/1000
# 6/6 [==============================] - 0s 24ms/step - loss: 0.0146 - mse: 0.0146 - val_loss: 0.5263 - val_mse: 0.5263
# Epoch 321/1000
# 6/6 [==============================] - 0s 23ms/step - loss: 0.0144 - mse: 0.0144 - val_loss: 0.5289 - val_mse: 0.5289
# Epoch 322/1000
# 6/6 [==============================] - 0s 22ms/step - loss: 0.0150 - mse: 0.0150 - val_loss: 0.5298 - val_mse: 0.5298
# Epoch 323/1000
# 6/6 [==============================] - 0s 23ms/step - loss: 0.0150 - mse: 0.0150 - val_loss: 0.5217 - val_mse: 0.5217
# Epoch 324/1000
# 6/6 [==============================] - 0s 22ms/step - loss: 0.0144 - mse: 0.0144 - val_loss: 0.5204 - val_mse: 0.5204
# Epoch 325/1000
# 6/6 [==============================] - 0s 24ms/step - loss: 0.0154 - mse: 0.0154 - val_loss: 0.5331 - val_mse: 0.5331
# Epoch 326/1000
# 6/6 [==============================] - 0s 23ms/step - loss: 0.0154 - mse: 0.0154 - val_loss: 0.5156 - val_mse: 0.5156
# Epoch 327/1000
# 6/6 [==============================] - 0s 22ms/step - loss: 0.0160 - mse: 0.0160 - val_loss: 0.5325 - val_mse: 0.5325
# Epoch 328/1000
# 6/6 [==============================] - 0s 23ms/step - loss: 0.0169 - mse: 0.0169 - val_loss: 0.5357 - val_mse: 0.5357
# Epoch 329/1000
# 6/6 [==============================] - 0s 46ms/step - loss: 0.0147 - mse: 0.0147 - val_loss: 0.5216 - val_mse: 0.5216
# Epoch 330/1000
# 6/6 [==============================] - 0s 23ms/step - loss: 0.0150 - mse: 0.0150 - val_loss: 0.5226 - val_mse: 0.5226
# Epoch 331/1000
# 6/6 [==============================] - 0s 23ms/step - loss: 0.0143 - mse: 0.0143 - val_loss: 0.5169 - val_mse: 0.5169
# Epoch 332/1000
# 6/6 [==============================] - 0s 24ms/step - loss: 0.0149 - mse: 0.0149 - val_loss: 0.5170 - val_mse: 0.5170
# Epoch 333/1000
# 6/6 [==============================] - 0s 24ms/step - loss: 0.0145 - mse: 0.0145 - val_loss: 0.5178 - val_mse: 0.5178
# Epoch 334/1000
# 6/6 [==============================] - 0s 23ms/step - loss: 0.0151 - mse: 0.0151 - val_loss: 0.5271 - val_mse: 0.5271
# Epoch 335/1000
# 6/6 [==============================] - 0s 22ms/step - loss: 0.0153 - mse: 0.0153 - val_loss: 0.5284 - val_mse: 0.5284
# Epoch 336/1000
# 6/6 [==============================] - 0s 22ms/step - loss: 0.0146 - mse: 0.0146 - val_loss: 0.5260 - val_mse: 0.5260
# Epoch 337/1000
# 6/6 [==============================] - 0s 23ms/step - loss: 0.0145 - mse: 0.0145 - val_loss: 0.5209 - val_mse: 0.5209
# Epoch 338/1000
# 6/6 [==============================] - 0s 22ms/step - loss: 0.0140 - mse: 0.0140 - val_loss: 0.5226 - val_mse: 0.5226
# Epoch 339/1000
# 6/6 [==============================] - 0s 23ms/step - loss: 0.0140 - mse: 0.0140 - val_loss: 0.5282 - val_mse: 0.5282
# Epoch 340/1000
# 6/6 [==============================] - 0s 23ms/step - loss: 0.0154 - mse: 0.0154 - val_loss: 0.5287 - val_mse: 0.5287
# Epoch 341/1000
# 6/6 [==============================] - 0s 22ms/step - loss: 0.0145 - mse: 0.0145 - val_loss: 0.5176 - val_mse: 0.5176
# Epoch 342/1000
# 6/6 [==============================] - 0s 23ms/step - loss: 0.0150 - mse: 0.0150 - val_loss: 0.5242 - val_mse: 0.5242
# Epoch 343/1000
# 6/6 [==============================] - 0s 22ms/step - loss: 0.0145 - mse: 0.0145 - val_loss: 0.5356 - val_mse: 0.5356
# Epoch 344/1000
# 6/6 [==============================] - 0s 22ms/step - loss: 0.0144 - mse: 0.0144 - val_loss: 0.5331 - val_mse: 0.5331
# Epoch 345/1000
# 6/6 [==============================] - 0s 22ms/step - loss: 0.0144 - mse: 0.0144 - val_loss: 0.5329 - val_mse: 0.5329
# Epoch 346/1000
# 6/6 [==============================] - 0s 26ms/step - loss: 0.0139 - mse: 0.0139 - val_loss: 0.5386 - val_mse: 0.5386
# Epoch 347/1000
# 6/6 [==============================] - 0s 23ms/step - loss: 0.0133 - mse: 0.0133 - val_loss: 0.5219 - val_mse: 0.5219
# Epoch 348/1000
# 6/6 [==============================] - 0s 23ms/step - loss: 0.0129 - mse: 0.0129 - val_loss: 0.5200 - val_mse: 0.5200
# Epoch 349/1000
# 6/6 [==============================] - 0s 43ms/step - loss: 0.0131 - mse: 0.0131 - val_loss: 0.5343 - val_mse: 0.5343
# Epoch 350/1000
# 6/6 [==============================] - 0s 24ms/step - loss: 0.0126 - mse: 0.0126 - val_loss: 0.5267 - val_mse: 0.5267
# Epoch 351/1000
# 6/6 [==============================] - 0s 24ms/step - loss: 0.0152 - mse: 0.0152 - val_loss: 0.5372 - val_mse: 0.5372
# Epoch 352/1000
# ...
# 6/6 [==============================] - 0s 24ms/step - loss: 0.0264 - mse: 0.0264 - val_loss: 0.5107 - val_mse: 0.5107
# Epoch 585/1000
# 6/6 [==============================] - 0s 24ms/step - loss: 0.0333 - mse: 0.0333 - val_loss: 0.4840 - val_mse: 0.4840
# Epoch 586/1000
# 6/6 [==============================] - 0s 23ms/step - loss: 0.0381 - mse: 0.0381 - val_loss: 0.5026 - val_mse: 0.5026
# Epoch 587/1000
# 6/6 [==============================] - 0s 24ms/step - loss: 0.
1000
# 6/6 [==============================] - 0s 23ms/step - loss: 0.0093 - mse: 0.0093 - val_loss: 0.4849 - val_mse: 0.4849
# Epoch 619/1000
# 6/6 [==============================] - 0s 24ms/step - loss: 0.0090 - mse: 0.0090 - val_loss: 0.4868 - val_mse: 0.4868
# Epoch 620/1000
# 6/6 [==============================] - 0s 23ms/step - loss: 0.0089 - mse: 0.0089 - val_loss: 0.4857 - val_mse: 0.4857
# Epoch 621/1000
# 6/6 [==============================] - 0s 24ms/step - loss: 0.0091 - mse: 0.0091 - val_loss: 0.4868 - val_mse: 0.4868
# Epoch 622/1000
# 6/6 [==============================] - 0s 25ms/step - loss: 0.0089 - mse: 0.0089 - val_loss: 0.4929 - val_mse: 0.4929
# Epoch 623/1000
# 6/6 [==============================] - 0s 23ms/step - loss: 0.0088 - mse: 0.0088 - val_loss: 0.4972 - val_mse: 0.4972
# Epoch 624/1000
# 6/6 [==============================] - 0s 26ms/step - loss: 0.0086 - mse: 0.0086 - val_loss: 0.4991 - val_mse: 0.4991
# Epoch 625/1000
# 6/6 [==============================] - 0s 24ms/step - loss: 0.0088 - mse: 0.0088 - val_loss: 0.5057 - val_mse: 0.5057
# Epoch 626/1000
# 6/6 [==============================] - 0s 24ms/step - loss: 0.0086 - mse: 0.0086 - val_loss: 0.5104 - val_mse: 0.5104
# Epoch 627/1000
# 6/6 [==============================] - 0s 22ms/step - loss: 0.0086 - mse: 0.0086 - val_loss: 0.5111 - val_mse: 0.5111
# Epoch 628/1000
# 6/6 [==============================] - 0s 48ms/step - loss: 0.0086 - mse: 0.0086 - val_loss: 0.5115 - val_mse: 0.5115
# Epoch 629/1000
# 6/6 [==============================] - 0s 22ms/step - loss: 0.0087 - mse: 0.0087 - val_loss: 0.5105 - val_mse: 0.5105
# Epoch 630/1000
# 6/6 [==============================] - 0s 23ms/step - loss: 0.0085 - mse: 0.0085 - val_loss: 0.5077 - val_mse: 0.5077
# Epoch 631/1000
# 6/6 [==============================] - 0s 24ms/step - loss: 0.0085 - mse: 0.0085 - val_loss: 0.5065 - val_mse: 0.5065
# Epoch 632/1000
# 6/6 [==============================] - 0s 24ms/step - loss: 0.0091 - mse: 0.0091 - val_loss: 0.5114 - val_mse: 0.5114
# Epoch 633/1000
# 6/6 [==============================] - 0s 23ms/step - loss: 0.0085 - mse: 0.0085 - val_loss: 0.5140 - val_mse: 0.5140
# Epoch 634/1000
# 6/6 [==============================] - 0s 23ms/step - loss: 0.0088 - mse: 0.0088 - val_loss: 0.5138 - val_mse: 0.5138
# Epoch 635/1000
# 6/6 [==============================] - 0s 25ms/step - loss: 0.0085 - mse: 0.0085 - val_loss: 0.5129 - val_mse: 0.5129
# Epoch 636/1000
# 6/6 [==============================] - 0s 24ms/step - loss: 0.0086 - mse: 0.0086 - val_loss: 0.5117 - val_mse: 0.5117
# Epoch 637/1000
# 6/6 [==============================] - 0s 25ms/step - loss: 0.0085 - mse: 0.0085 - val_loss: 0.5111 - val_mse: 0.5111
# Epoch 638/1000
# 6/6 [==============================] - 0s 24ms/step - loss: 0.0090 - mse: 0.0090 - val_loss: 0.5120 - val_mse: 0.5120
# Epoch 639/1000
# 6/6 [==============================] - 0s 23ms/step - loss: 0.0085 - mse: 0.0085 - val_loss: 0.5118 - val_mse: 0.5118
# Epoch 640/1000
# 6/6 [==============================] - 0s 49ms/step - loss: 0.0084 - mse: 0.0084 - val_loss: 0.5115 - val_mse: 0.5115
# Epoch 641/1000
# 6/6 [==============================] - 0s 26ms/step - loss: 0.0087 - mse: 0.0087 - val_loss: 0.5113 - val_mse: 0.5113
# Epoch 642/1000
# 6/6 [==============================] - 0s 24ms/step - loss: 0.0086 - mse: 0.0086 - val_loss: 0.5112 - val_mse: 0.5112
# Epoch 643/1000
# 6/6 [==============================] - 0s 24ms/step - loss: 0.0083 - mse: 0.0083 - val_loss: 0.5108 - val_mse: 0.5108
# Epoch 644/1000
# 6/6 [==============================] - 0s 23ms/step - loss: 0.0085 - mse: 0.0085 - val_loss: 0.5102 - val_mse: 0.5102
# Epoch 645/1000
# 6/6 [==============================] - 0s 24ms/step - loss: 0.0085 - mse: 0.0085 - val_loss: 0.5097 - val_mse: 0.5097
# Epoch 646/1000
# 6/6 [==============================] - 0s 24ms/step - loss: 0.0084 - mse: 0.0084 - val_loss: 0.5095 - val_mse: 0.5095
# Epoch 647/1000
# 6/6 [==============================] - 0s 23ms/step - loss: 0.0085 - mse: 0.0085 - val_loss: 0.5098 - val_mse: 0.5098
# Epoch 648/1000
# 6/6 [==============================] - 0s 24ms/step - loss: 0.0086 - mse: 0.0086 - val_loss: 0.5110 - val_mse: 0.5110
# Epoch 649/1000
# 6/6 [==============================] - 0s 25ms/step - loss: 0.0085 - mse: 0.0085 - val_loss: 0.5110 - val_mse: 0.5110
# Epoch 650/1000
# 6/6 [==============================] - 0s 24ms/step - loss: 0.0085 - mse: 0.0085 - val_loss: 0.5109 - val_mse: 0.5109
# Epoch 651/1000
# 6/6 [==============================] - 0s 23ms/step - loss: 0.0085 - mse: 0.0085 - val_loss: 0.5112 - val_mse: 0.5112
# Epoch 652/1000
# 6/6 [==============================] - 0s 23ms/step - loss: 0.0085 - mse: 0.0085 - val_loss: 0.5114 - val_mse: 0.5114
# Epoch 653/1000
# 6/6 [==============================] - 0s 47ms/step - loss: 0.0084 - mse: 0.0084 - val_loss: 0.5117 - val_mse: 0.5117
# Epoch 654/1000
# 6/6 [==============================] - 0s 23ms/step - loss: 0.0085 - mse: 0.0085 - val_loss: 0.5114 - val_mse: 0.5114
# Epoch 655/1000
# 6/6 [==============================] - 0s 32ms/step - loss: 0.0084 - mse: 0.0084 - val_loss: 0.5111 - val_mse: 0.5111
# Epoch 656/1000
# 6/6 [==============================] - 0s 25ms/step - loss: 0.0084 - mse: 0.0084 - val_loss: 0.5107 - val_mse: 0.5107
# Epoch 657/1000
# 6/6 [==============================] - 0s 24ms/step - loss: 0.0085 - mse: 0.0085 - val_loss: 0.5106 - val_mse: 0.5106
# Epoch 658/1000
# 6/6 [==============================] - 0s 25ms/step - loss: 0.0085 - mse: 0.0085 - val_loss: 0.5107 - val_mse: 0.5107
# Epoch 659/1000
# 6/6 [==============================] - 0s 24ms/step - loss: 0.0084 - mse: 0.0084 - val_loss: 0.5102 - val_mse: 0.5102
# Epoch 660/1000
# 6/6 [==============================] - 0s 22ms/step - loss: 0.0085 - mse: 0.0085 - val_loss: 0.5098 - val_mse: 0.5098
# Epoch 661/1000
# 6/6 [==============================] - 0s 21ms/step - loss: 0.0084 - mse: 0.0084 - val_loss: 0.5097 - val_mse: 0.5097
# Epoch 662/1000
# 6/6 [==============================] - 0s 23ms/step - loss: 0.0085 - mse: 0.0085 - val_loss: 0.5099 - val_mse: 0.5099
# Epoch 663/1000
# 6/6 [==============================] - 0s 23ms/step - loss: 0.0084 - mse: 0.0084 - val_loss: 0.5102 - val_mse: 0.5102
# Epoch 664/1000
# 6/6 [==============================] - 0s 22ms/step - loss: 0.0085 - mse: 0.0085 - val_loss: 0.5108 - val_mse: 0.5108
# Epoch 665/1000
# 6/6 [==============================] - 0s 21ms/step - loss: 0.0085 - mse: 0.0085 - val_loss: 0.5108 - val_mse: 0.5108
# Epoch 666/1000
# 6/6 [==============================] - 0s 21ms/step - loss: 0.0084 - mse: 0.0084 - val_loss: 0.5100 - val_mse: 0.5100
# Epoch 667/1000
# 6/6 [==============================] - 0s 22ms/step - loss: 0.0084 - mse: 0.0084 - val_loss: 0.5098 - val_mse: 0.5098
# Epoch 668/1000
# 6/6 [==============================] - 0s 47ms/step - loss: 0.0084 - mse: 0.0084 - val_loss: 0.5099 - val_mse: 0.5099
# Epoch 669/1000
# 6/6 [==============================] - 0s 21ms/step - loss: 0.0084 - mse: 0.0084 - val_loss: 0.5100 - val_mse: 0.5100
# Epoch 670/1000
# 6/6 [==============================] - 0s 22ms/step - loss: 0.0086 - mse: 0.0086 - val_loss: 0.5077 - val_mse: 0.5077
# Epoch 671/1000
# 6/6 [==============================] - 0s 23ms/step - loss: 0.0085 - mse: 0.0085 - val_loss: 0.5064 - val_mse: 0.5064
# Epoch 672/1000
# 6/6 [==============================] - 0s 22ms/step - loss: 0.0084 - mse: 0.0084 - val_loss: 0.5056 - val_mse: 0.5056
# Epoch 673/1000
# 6/6 [==============================] - 0s 23ms/step - loss: 0.0084 - mse: 0.0084 - val_loss: 0.5056 - val_mse: 0.5056
# Epoch 674/1000
# 6/6 [==============================] - 0s 24ms/step - loss: 0.0085 - mse: 0.0085 - val_loss: 0.5050 - val_mse: 0.5050
# Epoch 675/1000
# 6/6 [==============================] - 0s 23ms/step - loss: 0.0085 - mse: 0.0085 - val_loss: 0.5042 - val_mse: 0.5042
# Epoch 676/1000
# 6/6 [==============================] - 0s 24ms/step - loss: 0.0085 - mse: 0.0085 - val_loss: 0.5034 - val_mse: 0.5034
# Epoch 677/1000
# 6/6 [==============================] - 0s 50ms/step - loss: 0.0085 - mse: 0.0085 - val_loss: 0.5033 - val_mse: 0.5033
# Epoch 678/1000
# 6/6 [==============================] - 0s 26ms/step - loss: 0.0084 - mse: 0.0084 - val_loss: 0.5037 - val_mse: 0.5037
# Epoch 679/1000
# 6/6 [==============================] - 0s 25ms/step - loss: 0.0084 - mse: 0.0084 - val_loss: 0.5043 - val_mse: 0.5043
# Epoch 680/1000
# 6/6 [==============================] - 0s 24ms/step - loss: 0.0085 - mse: 0.0085 - val_loss: 0.5059 - val_mse: 0.5059
# Epoch 681/1000
# 6/6 [==============================] - 0s 25ms/step - loss: 0.0084 - mse: 0.0084 - val_loss: 0.5075 - val_mse: 0.5075
# Epoch 682/1000
# 6/6 [==============================] - 0s 24ms/step - loss: 0.0084 - mse: 0.0084 - val_loss: 0.5092 - val_mse: 0.5092
# Epoch 683/1000
# 6/6 [==============================] - 0s 24ms/step - loss: 0.0084 - mse: 0.0084 - val_loss: 0.5104 - val_mse: 0.5104
# Epoch 684/1000
# 6/6 [==============================] - 0s 25ms/step - loss: 0.0085 - mse: 0.0085 - val_loss: 0.5115 - val_mse: 0.5115
# Epoch 685/1000
# 6/6 [==============================] - 0s 24ms/step - loss: 0.0084 - mse: 0.0084 - val_loss: 0.5124 - val_mse: 0.5124
# Epoch 686/1000
# 6/6 [==============================] - 0s 24ms/step - loss: 0.0085 - mse: 0.0085 - val_loss: 0.5125 - val_mse: 0.5125
# Epoch 687/1000
# 6/6 [==============================] - 0s 23ms/step - loss: 0.0085 - mse: 0.0085 - val_loss: 0.5120 - val_mse: 0.5120
# Epoch 688/1000
# 6/6 [==============================] - 0s 23ms/step - loss: 0.0086 - mse: 0.0086 - val_loss: 0.5111 - val_mse: 0.5111
# Epoch 689/1000
# 6/6 [==============================] - 0s 50ms/step - loss: 0.0084 - mse: 0.0084 - val_loss: 0.5096 - val_mse: 0.5096
# Epoch 690/1000
# 6/6 [==============================] - 0s 24ms/step - loss: 0.0085 - mse: 0.0085 - val_loss: 0.5081 - val_mse: 0.5081
# Epoch 691/1000
# 6/6 [==============================] - 0s 25ms/step - loss: 0.0084 - mse: 0.0084 - val_loss: 0.5069 - val_mse: 0.5069
# Epoch 692/1000
# 6/6 [==============================] - 0s 23ms/step - loss: 0.0084 - mse: 0.0084 - val_loss: 0.5066 - val_mse: 0.5066
# Epoch 693/1000
# 6/6 [==============================] - 0s 24ms/step - loss: 0.0084 - mse: 0.0084 - val_loss: 0.5069 - val_mse: 0.5069
# Epoch 694/1000
# 6/6 [==============================] - 0s 24ms/step - loss: 0.0084 - mse: 0.0084 - val_loss: 0.5074 - val_mse: 0.5074
# Epoch 695/1000
# 6/6 [==============================] - 0s 26ms/step - loss: 0.0084 - mse: 0.0084 - val_loss: 0.5078 - val_mse: 0.5078
# Epoch 696/1000
# 6/6 [==============================] - 0s 25ms/step - loss: 0.0084 - mse: 0.0084 - val_loss: 0.5082 - val_mse: 0.5082
# Epoch 697/1000
# 6/6 [==============================] - 0s 24ms/step - loss: 0.0085 - mse: 0.0085 - val_loss: 0.5083 - val_mse: 0.5083
# Epoch 698/1000
# 6/6 [==============================] - 0s 23ms/step - loss: 0.0084 - mse: 0.0084 - val_loss: 0.5084 - val_mse: 0.5084
# Epoch 699/1000
# 6/6 [==============================] - 0s 21ms/step - loss: 0.0084 - mse: 0.0084 - val_loss: 0.5082 - val_mse: 0.5082
# Epoch 700/1000
# 6/6 [==============================] - 0s 23ms/step - loss: 0.0084 - mse: 0.0084 - val_loss: 0.5082 - val_mse: 0.5082
# Epoch 701/1000
# 6/6 [==============================] - 0s 24ms/step - loss: 0.0084 - mse: 0.0084 - val_loss: 0.5082 - val_mse: 0.5082
# Epoch 702/1000
# 6/6 [==============================] - 0s 50ms/step - loss: 0.0084 - mse: 0.0084 - val_loss: 0.5086 - val_mse: 0.5086
# Epoch 703/1000
# 6/6 [==============================] - 0s 26ms/step - loss: 0.0084 - mse: 0.0084 - val_loss: 0.5093 - val_mse: 0.5093
# The difference in seconds is: 93.99643635749817

# %%
# # Extract the metrics from the history object
loss = history.history['loss']
val_loss = history.history['val_loss']
# r_square = history.history['r_square']
# val_r_square = history.history['val_r_square']

# # Plot loss and val_loss
# plt.figure(figsize=(12, 6))
# plt.plot(loss, label='Training Loss', color='blue')
# plt.plot(val_loss, label='Validation Loss', color='orange')
# plt.title('Training Loss vs Validation Loss')
# plt.xlabel('Epochs')
# plt.ylabel('Loss')
# plt.legend()
# plt.grid()
# plt.show()

# # Plot r_square and val_r_square
# plt.figure(figsize=(12, 6))
# plt.plot(r_square, label='Training R^2', color='green')
# plt.plot(val_r_square, label='Validation R^2', color='red')
# plt.title('Training R^2 vs Validation R^2')
# plt.xlabel('Epochs')
# plt.ylabel('R^2')
# plt.legend()
# plt.grid()
# plt.show()

# %%
# Find the minimum loss for training and validation
min_training_loss = min(loss)
min_validation_loss = min(val_loss)

# Print the results
print(f"Minimum Training Loss: {min_training_loss}")
print(f"Minimum Validation Loss: {min_validation_loss}")
# Out:
# Minimum Training Loss: 0.008292867802083492
# Minimum Validation Loss: 0.24750825762748718

# %%
# # Find the maximum R² values for training and validation
# max_r_square_train = max(r_square)
# max_r_square_val = max(val_r_square)

# # Print the results
# print(f"Maximum Training R²: {max_r_square_train}")
# print(f"Maximum Validation R²: {max_r_square_val}")

# %%
# model = best_model

# %%
# Generate predictions for the training set
Y_train_pred = model.predict(X_train)

# Plot the true values and predictions
plt.figure(figsize=(10, 6))
plt.plot(Y_train, label='True Values', color='blue',  marker='o')
plt.plot(Y_train_pred, label='Predictions', color='red', linestyle='dashed', marker='o')
plt.title('Training True Values vs Predictions')
plt.xlabel('Sample Index')
plt.ylabel('Value')
plt.legend()
plt.show()
# Out:
# 12/12 [==============================] - 1s 6ms/step

# %%
# Generate predictions for the validation set
Y_val_pred = model.predict(X_val)

# Plot the true values and predictions
plt.figure(figsize=(10, 6))
plt.plot(Y_val, label='True Values', color='blue', marker='o')
plt.plot(Y_val_pred, label='Predictions', color='red', linestyle='dashed', marker='o')
plt.title('Validation True Values vs Predictions')
plt.xlabel('Sample Index')
plt.ylabel('Value')
plt.legend()
plt.show()
# Out:
# 2/2 [==============================] - 0s 9ms/step

# %%
# Generate predictions for the validation set
Y_val_pred = model.predict(X_val)
Y_val_pred = np.where(Y_val_pred > 0.5, 1,np.where(Y_val_pred<-0.5, -1, 0) )

# Plot the true values and predictions
plt.figure(figsize=(10, 6))
plt.plot(Y_val, label='True Values', color='blue', marker='o')
plt.plot(Y_val_pred, label='Predictions', color='red', linestyle='dashed', marker='o')
plt.title('Validation True Values vs Predictions')
plt.xlabel('Sample Index')
plt.ylabel('Value')
plt.legend()
plt.show()
# Out:
# 2/2 [==============================] - 0s 9ms/step

# %%
from sklearn.metrics import confusion_matrix

# Create confusion matrix
conf_matrix = confusion_matrix(Y_val.flatten(), Y_val_pred.flatten())

# Print the confusion matrix
print("Confusion Matrix:")
print(conf_matrix)
# Out:
# Confusion Matrix:
# [[ 0 29]
#  [ 0 35]]

# %%
# import matplotlib.pyplot as plt
# import numpy as np

# # Generate predictions for the validation set
# Y_val_pred = model.predict(X_val)
# Y_val_pred = np.where(Y_val_pred > 0.5, 1, np.where(Y_val_pred < -0.5, -1, 0))

# # Plot
# plt.figure(figsize=(12, 6))

# # Add soft gray vertical lines for each sample
# for i in range(len(Y_val)):
#     plt.axvline(x=i, color='gray', linestyle='-', linewidth=0.5, alpha=0.3)

# # Plot true values and predictions as scatter
# plt.scatter(range(len(Y_val)), Y_val, label='True Values', color='blue', marker='o')
# plt.scatter(range(len(Y_val_pred)), Y_val_pred, label='Predictions', color='red', marker='o')

# # Styling
# plt.title('Validation True Values vs Predictions')
# plt.xlabel('Sample Index')
# plt.ylabel('Value')
# plt.legend()
# plt.grid(False)  # Remove default grid
# plt.tight_layout()
# plt.show()

# %%
# from sklearn.metrics import confusion_matrix

# # Create confusion matrix
# conf_matrix = confusion_matrix(Y_val.flatten(), Y_val_pred.flatten())

# # Print the confusion matrix
# print("Confusion Matrix:")
# print(conf_matrix)

# %%
# Calculate total accuracy
total_accuracy = np.sum(Y_val.flatten() == Y_val_pred.flatten()) / len(Y_val)
print(f"Total Accuracy: {total_accuracy * 100:.2f}%")
# Out:
# Total Accuracy: 54.69%

# %%
# # Generate predictions for the validation set
# Y_val_pred = model.predict(X_test_filtered)
# Y_val_pred = np.where(Y_val_pred > 0.42, 1, -1)

# # Plot the true values and predictions
# plt.figure(figsize=(10, 6))
# plt.plot(Y_test_filtered, label='True Values', color='blue', marker='o')
# plt.plot(Y_val_pred, label='Predictions', color='red', linestyle='dashed', marker='o')
# plt.title('Validation True Values vs Predictions')
# plt.xlabel('Sample Index')
# plt.ylabel('Value')
# plt.legend()
# plt.show()

# %%
# import matplotlib.pyplot as plt
# import numpy as np

# # Generate predictions for the validation set
# Y_val_pred = model.predict(X_test_filtered)
# Y_val_pred = np.where(Y_val_pred > 0.2, 1, -1)

# # Plot the true values and predictions
# plt.figure(figsize=(12, 6))

# # Add soft gray vertical lines for each sample index
# for i in range(len(Y_test_filtered)):
#     plt.axvline(x=i, color='gray', linestyle='-', linewidth=0.5, alpha=0.7)

# # Plot using scatter (no connecting lines)
# plt.scatter(range(len(Y_test_filtered)), Y_test_filtered, label='True Values', color='blue', marker='o')
# plt.scatter(range(len(Y_val_pred)), Y_val_pred, label='Predictions', color='red', marker='o')

# # Labels and title
# plt.title('Validation True Values vs Predictions')
# plt.xlabel('Sample Index')
# plt.ylabel('Value')
# plt.legend()
# plt.grid(False)
# plt.tight_layout()
# plt.show()

# %%
# import matplotlib.pyplot as plt
# import numpy as np

# # Generate predictions for the validation set
# Y_val_pred = model.predict(X_test_filtered)
# Y_val_pred = np.where(Y_val_pred > 0.42, 1, -1)

# # Flatten if needed
# Y_val_pred = Y_val_pred.flatten()
# Y_test_filtered = Y_test_filtered.flatten()

# # Prepare index and classification of correctness
# indices = np.arange(len(Y_test_filtered))
# correct = Y_val_pred == Y_test_filtered
# incorrect = ~correct

# # Plot the figure
# plt.figure(figsize=(12, 6))

# # Add vertical gray lines
# for i in range(len(Y_test_filtered)):
#     plt.axvline(x=i, color='gray', linestyle='-', linewidth=0.7, alpha=0.7)

# # Plot true values as reference shadow
# # plt.scatter(indices, Y_test_filtered, color='blue', label='True Value (Reference)', marker='o', alpha=0.3)

# # Plot correct predictions (overlapping with true values)
# plt.scatter(indices[correct], Y_val_pred[correct], color='blue', marker='o', label='Correct Prediction')

# # Plot incorrect predictions
# plt.scatter(indices[incorrect], Y_val_pred[incorrect], color='red', marker='o', label='Incorrect Prediction')

# # Labels and title
# plt.title('Testing True Values vs Predictions')
# plt.xlabel('Sample Index')
# plt.ylabel('Value')
# plt.legend()
# plt.grid(False)
# plt.tight_layout()
# plt.show()

# %%
# from sklearn.metrics import confusion_matrix

# # Create confusion matrix
# conf_matrix = confusion_matrix(Y_test_filtered.flatten(), Y_val_pred.flatten())

# # Print the confusion matrix
# print("Confusion Matrix:")
# print(conf_matrix)

# %%
# # Calculate total accuracy
# total_accuracy = np.sum(Y_test_filtered.flatten() == Y_val_pred.flatten()) / len(Y_test_filtered)
# print(f"Total Accuracy: {total_accuracy * 100:.2f}%")
